# %%
# Running on GPU?
import setGPU

import getpass
import h5py
import pickle
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.colors import LogNorm

from tqdm import tnrange, tqdm_notebook
# Out:
# setGPU: Setting GPU to: 1

# %%
import os
import getpass
# Get permission to access EOS (Insert your NICE password)
os.system("echo %s | kinit" % getpass.getpass())
# Out:
# ········
# 0

# %%
import json
import numpy as np
import pandas as pd
from pprint import pprint

import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Dense, Lambda, BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.activations import sigmoid, linear, relu
from keras.models import Model, load_model
from keras.regularizers import l1, l2, l1_l2

from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import class_weight
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from scipy.stats import pearsonr
# Out:
# Using TensorFlow backend.

# %%
plt.rcParams.update({'font.size': 22})

# %%
PDs  = {1: 'BTagCSV',
        2: 'BTagMu',
        3: 'Charmonium',
        4: 'DisplacedJet',
        5: 'DoubleEG',
        6: 'DoubleMuon',
        7: 'DoubleMuonLowMass',
        8: 'FSQJets',
        9: 'HighMultiplicityEOF',
        10: 'HTMHT',
        11: 'JetHT',
        12: 'MET',
        13: 'MinimumBias',
        14: 'MuonEG',
        15: 'MuOnia',
        16: 'NoBPTX',
        17: 'SingleElectron',
        18: 'SingleMuon',
        19: 'SinglePhoton',
        20: 'Tau',
        21: 'ZeroBias'}

# Select PD
nPD = 11

# %%
legend = [{"name": 'pf_jets', "start": 0, "end": 776},
          {"name": 'cal_jet_mets', "start": 777, "end": 944},
          {"name": 'pho', "start": 945, "end": 1280},
          {"name": 'muons', "start": 1281, "end": 1784},
          {"name": 'pf_jets2', "start": 1785, "end": 1889},
          {"name": 'pf_mets', "start": 1890, "end": 1917},
          {"name": 'nvtx', "start": 1918, "end": 1924},
          {"name": 'cal_jet_mets2', "start": 1925},
          {"name": 'sc', "start": 2037, "end": 2127},
          {"name": 'cc', "start": 2128, "end": 2169},
          {"name": 'pho2', "start": 2170, "end": 2365},
          {"name": 'muons2', "start": 2366, "end": 2491},
          {"name": 'ebs', "start": 2492, "end": 2701},
          {"name": 'hbhef', "start": 2702, "end": 2764},
          {"name": 'presh', "start": 2765, "end": 2806},
          {"name": 'inst_lumi', "start": 2807, "end": 2808}]

# %%
# Feature description
feature_names = ['qPFJetPt', 'qPFJetEta', 'qPFJetPhi', 'qPFJet0Pt', 'qPFJet1Pt', 'qPFJet2Pt', 'qPFJet3Pt', 'qPFJet4Pt', 'qPFJet5Pt', 'qPFJet0Eta', 'qPFJet1Eta', 'qPFJet2Eta', 'qPFJet3Eta', 'qPFJet4Eta', 'qPFJet5Eta', 'qPFJet0Phi', 'qPFJet1Phi', 'qPFJet2Phi', 'qPFJet3Phi', 'qPFJet4Phi', 'qPFJet5Phi', 'qPFJet4CHS0Pt', 'qPFJet4CHS1Pt', 'qPFJet4CHS2Pt', 'qPFJet4CHS3Pt', 'qPFJet4CHS4Pt', 'qPFJet4CHS5Pt', 'qPFJet4CHS0Eta', 'qPFJet4CHS1Eta', 'qPFJet4CHS2Eta', 'qPFJet4CHS3Eta', 'qPFJet4CHS4Eta', 'qPFJet4CHS5Eta', 'qPFJet4CHS0Phi', 'qPFJet4CHS1Phi', 'qPFJet4CHS2Phi', 'qPFJet4CHS3Phi', 'qPFJet4CHS4Phi', 'qPFJet4CHS5Phi', 'qPFJet8CHS0Pt', 'qPFJet8CHS1Pt', 'qPFJet8CHS2Pt', 'qPFJet8CHS3Pt', 'qPFJet8CHS4Pt', 'qPFJet8CHS5Pt', 'qPFJet8CHS0Eta', 'qPFJet8CHS1Eta', 'qPFJet8CHS2Eta', 'qPFJet8CHS3Eta', 'qPFJet8CHS4Eta', 'qPFJet8CHS5Eta', 'qPFJet8CHS0Phi', 'qPFJet8CHS1Phi', 'qPFJet8CHS2Phi', 'qPFJet8CHS3Phi', 'qPFJet8CHS4Phi', 'qPFJet8CHS5Phi', 'qPFJetEI0Pt', 'qPFJetEI1Pt', 'qPFJetEI2Pt', 'qPFJetEI3Pt', 'qPFJetEI4Pt', 'qPFJetEI5Pt', 'qPFJetEI0Eta', 'qPFJetEI1Eta', 'qPFJetEI2Eta', 'qPFJetEI3Eta', 'qPFJetEI4Eta', 'qPFJetEI5Eta', 'qPFJetEI0Phi', 'qPFJetEI1Phi', 'qPFJetEI2Phi', 'qPFJetEI3Phi', 'qPFJetEI4Phi', 'qPFJetEI5Phi', 'qPFJet8CHSSD0Pt', 'qPFJet8CHSSD1Pt', 'qPFJet8CHSSD2Pt', 'qPFJet8CHSSD3Pt', 'qPFJet8CHSSD4Pt', 'qPFJet8CHSSD5Pt', 'qPFJet8CHSSD0Eta', 'qPFJet8CHSSD1Eta', 'qPFJet8CHSSD2Eta', 'qPFJet8CHSSD3Eta', 'qPFJet8CHSSD4Eta', 'qPFJet8CHSSD5Eta', 'qPFJet8CHSSD0Phi', 'qPFJet8CHSSD1Phi', 'qPFJet8CHSSD2Phi', 'qPFJet8CHSSD3Phi', 'qPFJet8CHSSD4Phi', 'qPFJet8CHSSD5Phi', 'qPFJetTopCHS0Pt', 'qPFJetTopCHS1Pt', 'qPFJetTopCHS2Pt', 'qPFJetTopCHS3Pt', 'qPFJetTopCHS4Pt', 'qPFJetTopCHS5Pt', 'qPFJetTopCHS0Eta', 'qPFJetTopCHS1Eta', 'qPFJetTopCHS2Eta', 'qPFJetTopCHS3Eta', 'qPFJetTopCHS4Eta', 'qPFJetTopCHS5Eta', 'qPFJetTopCHS0Phi', 'qPFJetTopCHS1Phi', 'qPFJetTopCHS2Phi', 'qPFJetTopCHS3Phi', 'qPFJetTopCHS4Phi', 'qPFJetTopCHS5Phi', 'qCalJet0Pt', 'qCalJet1Pt', 'qCalJet2Pt', 'qCalJet3Pt', 'qCalJet4Pt', 'qCalJet5Pt', 'qCalJet0Eta', 'qCalJet1Eta', 'qCalJet2Eta', 'qCalJet3Eta', 'qCalJet4Eta', 'qCalJet5Eta', 'qCalJet0Phi', 'qCalJet1Phi', 'qCalJet2Phi', 'qCalJet3Phi', 'qCalJet4Phi', 'qCalJet5Phi', 'qCalJet0En', 'qCalJet1En', 'qCalJet2En', 'qCalJet3En', 'qCalJet4En', 'qCalJet5En', 'qPho0Pt', 'qPho1Pt', 'qPho2Pt', 'qPho3Pt', 'qPho4Pt', 'qPho5Pt', 'qPho0Eta', 'qPho1Eta', 'qPho2Eta', 'qPho3Eta', 'qPho4Eta', 'qPho5Eta', 'qPho0Phi', 'qPho1Phi', 'qPho2Phi', 'qPho3Phi', 'qPho4Phi', 'qPho5Phi', 'qPho0En', 'qPho1En', 'qPho2En', 'qPho3En', 'qPho4En', 'qPho5En', 'qgedPho0Pt', 'qgedPho1Pt', 'qgedPho2Pt', 'qgedPho3Pt', 'qgedPho4Pt', 'qgedPho5Pt', 'qgedPho0Eta', 'qgedPho1Eta', 'qgedPho2Eta', 'qgedPho3Eta', 'qgedPho4Eta', 'qgedPho5Eta', 'qgedPho0Phi', 'qgedPho1Phi', 'qgedPho2Phi', 'qgedPho3Phi', 'qgedPho4Phi', 'qgedPho5Phi', 'qgedPho0En', 'qgedPho1En', 'qgedPho2En', 'qgedPho3En', 'qgedPho4En', 'qgedPho5En', 'qMu0Pt', 'qMu1Pt', 'qMu2Pt', 'qMu3Pt', 'qMu4Pt', 'qMu5Pt', 'qMu0Eta', 'qMu1Eta', 'qMu2Eta', 'qMu3Eta', 'qMu4Eta', 'qMu5Eta', 'qMu0Phi', 'qMu1Phi', 'qMu2Phi', 'qMu3Phi', 'qMu4Phi', 'qMu5Phi', 'qMu0En', 'qMu1En', 'qMu2En', 'qMu3En', 'qMu4En', 'qMu5En', 'qMuCosm0Pt', 'qMuCosm1Pt', 'qMuCosm2Pt', 'qMuCosm3Pt', 'qMuCosm4Pt', 'qMuCosm5Pt', 'qMuCosm0Eta', 'qMuCosm1Eta', 'qMuCosm2Eta', 'qMuCosm3Eta', 'qMuCosm4Eta', 'qMuCosm5Eta', 'qMuCosm0Phi', 'qMuCosm1Phi', 'qMuCosm2Phi', 'qMuCosm3Phi', 'qMuCosm4Phi', 'qMuCosm5Phi', 'qMuCosm0En', 'qMuCosm1En', 'qMuCosm2En', 'qMuCosm3En', 'qMuCosm4En', 'qMuCosm5En', 'qMuCosmLeg0Pt', 'qMuCosmLeg1Pt', 'qMuCosmLeg2Pt', 'qMuCosmLeg3Pt', 'qMuCosmLeg4Pt', 'qMuCosmLeg5Pt', 'qMuCosmLeg0Eta', 'qMuCosmLeg1Eta', 'qMuCosmLeg2Eta', 'qMuCosmLeg3Eta', 'qMuCosmLeg4Eta', 'qMuCosmLeg5Eta', 'qMuCosmLeg0Phi', 'qMuCosmLeg1Phi', 'qMuCosmLeg2Phi', 'qMuCosmLeg3Phi', 'qMuCosmLeg4Phi', 'qMuCosmLeg5Phi', 'qMuCosmLeg0En', 'qMuCosmLeg1En', 'qMuCosmLeg2En', 'qMuCosmLeg3En', 'qMuCosmLeg4En', 'qMuCosmLeg5En', 'qPFJet4CHSPt', 'qPFJet4CHSEta', 'qPFJet4CHSPhi', 'qPFJet8CHSPt', 'qPFJet8CHSEta', 'qPFJet8CHSPhi', 'qPFJetEIPt', 'qPFJetEIEta', 'qPFJetEIPhi', 'qPFJet8CHSSDPt', 'qPFJet8CHSSDEta', 'qPFJet8CHSSDPhi', 'qPFJetTopCHSPt', 'qPFJetTopCHSEta', 'qPFJetTopCHSPhi', 'qPFChMetPt', 'qPFChMetPhi', 'qPFMetPt', 'qPFMetPhi', 'qNVtx', 'qCalJetPt', 'qCalJetEta', 'qCalJetPhi', 'qCalJetEn', 'qCalMETPt', 'qCalMETPhi', 'qCalMETEn', 'qCalMETBEPt', 'qCalMETBEPhi', 'qCalMETBEEn', 'qCalMETBEFOPt', 'qCalMETBEFOPhi', 'qCalMETBEFOEn', 'qCalMETMPt', 'qCalMETMPhi', 'qCalMETMEn', 'qSCEn', 'qSCEta', 'qSCPhi', 'qSCEtaWidth', 'qSCPhiWidth', 'qSCEnhfEM', 'qSCEtahfEM', 'qSCPhihfEM', 'qSCEn5x5', 'qSCEta5x5', 'qSCPhi5x5', 'qSCEtaWidth5x5', 'qSCPhiWidth5x5', 'qCCEn', 'qCCEta', 'qCCPhi', 'qCCEn5x5', 'qCCEta5x5', 'qCCPhi5x5', 'qPhoPt', 'qPhoEta', 'qPhoPhi', 'qPhoEn_', 'qPhoe1x5_', 'qPhoe2x5_', 'qPhoe3x3_', 'qPhoe5x5_', 'qPhomaxenxtal_', 'qPhosigmaeta_', 'qPhosigmaIeta_', 'qPhor1x5_', 'qPhor2x5_', 'qPhor9_', 'qgedPhoPt', 'qgedPhoEta', 'qgedPhoPhi', 'qgedPhoEn_', 'qgedPhoe1x5_', 'qgedPhoe2x5_', 'qgedPhoe3x3_', 'qgedPhoe5x5_', 'qgedPhomaxenxtal_', 'qgedPhosigmaeta_', 'qgedPhosigmaIeta_', 'qgedPhor1x5_', 'qgedPhor2x5_', 'qgedPhor9_', 'qMuPt', 'qMuEta', 'qMuPhi', 'qMuEn_', 'qMuCh_', 'qMuChi2_', 'qMuCosmPt', 'qMuCosmEta', 'qMuCosmPhi', 'qMuCosmEn_', 'qMuCosmCh_', 'qMuCosmChi2_', 'qMuCosmLegPt', 'qMuCosmLegEta', 'qMuCosmLegPhi', 'qMuCosmLegEn_', 'qMuCosmLegCh_', 'qMuCosmLegChi2_', 'qSigmaIEta', 'qSigmaIPhi', 'qr9', 'qHadOEm', 'qdrSumPt', 'qdrSumEt', 'qeSCOP', 'qecEn', 'qUNSigmaIEta', 'qUNSigmaIPhi', 'qUNr9', 'qUNHadOEm', 'qUNdrSumPt', 'qUNdrSumEt', 'qUNeSCOP', 'qUNecEn', 'qEBenergy', 'qEBtime', 'qEBchi2', 'qEBiEta', 'qEBiPhi', 'qEEenergy', 'qEEtime', 'qEEchi2', 'qEEix', 'qEEiy', 'qESenergy', 'qEStime', 'qESix', 'qESiy', 'qHBHEenergy', 'qHBHEtime', 'qHBHEauxe', 'qHBHEieta', 'qHBHEiphi', 'qHFenergy', 'qHFtime', 'qHFieta', 'qHFiphi', 'qPreShEn', 'qPreShEta', 'qPreShPhi', 'qPreShYEn', 'qPreShYEta', 'qPreShYPhi', 'inst_luminosity']

# %%
data_directory = "/eos/project/c/cmsml4dc/fsiroky/consistentlumih5/"
label_file = "/afs/cern.ch/user/t/tkrzyzek/Documents/Data-Certification/JetHT.json"
pileup_file = "/afs/cern.ch/cms/CAF/CMSCOMM/COMM_DQM/certification/Collisions16/13TeV/PileUp/pileup_latest.txt"
model_directory = "/eos/user/t/tkrzyzek/autoencoder/30-40-JetHT/"
model_name = "model"

# %%
def get_file_list(directory, pds, npd, typeof, extension):
    files = []
    parts = ["C", "D", "E", "F", "G", "H"]
    for p in parts:
        files.append("%s%s_%s_%s%s" % (directory, pds[npd], p, typeof, extension))
    return files

files = get_file_list(data_directory, PDs, nPD, "background", ".h5")
files = files + get_file_list(data_directory, PDs, nPD, "signal", ".h5")

# %%
# Load good and bad jets
def get_data(files):
    readout = np.empty([0,2813])
    
    for file in files:
        jet = file.split("/")[-1][:-3]
        print("Reading: %s" % jet)
        try:
            h5file = h5py.File(file, "r")
            readout = np.concatenate((readout, h5file[jet][:]), axis=0)
        except OSError as error:
            print("This Primary Dataset doesn't have %s. %s" % (jet, error))
            continue

    return readout

data = pd.DataFrame(get_data(files))
# Out:
# Reading: JetHT_C_background
# Reading: JetHT_D_background
# Reading: JetHT_E_background
# Reading: JetHT_F_background
# Reading: JetHT_G_background
# Reading: JetHT_H_background
# Reading: JetHT_C_signal
# Reading: JetHT_D_signal
# Reading: JetHT_E_signal
# Reading: JetHT_F_signal
# Reading: JetHT_G_signal
# Reading: JetHT_H_signal

# %%
data["run"] = data[2807].astype(int)
data["lumi"] = data[2808].astype(int)
data["inst_lumi"] = data[2809].astype(float)

# Drop unnecessary meta data
data.drop([2808, 2809, 2810, 2811, 2812], axis=1, inplace=True)

# Append inst. luminosity at the end as well
data[2807] = data["inst_lumi"]

# Sort by runID and then by lumiID
data = data.sort_values(["run", "lumi"], ascending=[True,True])

# Reset index
data = data.reset_index(drop=True)  

runIDs  = data["run"].astype(int)
lumiIDs = data["lumi"].astype(int)
luminosity = data["inst_lumi"].astype(float)

# %%
# Apply labels
output_json = json.load(open(label_file))

def json_checker(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid >= i[0] and orig_lumid <= i[1]:
                return 0
    except KeyError:
        pass
    return 1

def add_flags(sample):
    return json_checker(output_json, sample["run"], sample["lumi"])

data["label"] = data.apply(add_flags, axis=1)

# %%
with open(pileup_file) as f:
    pileup = json.load(f)

def pileup_from_json(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid == i[0]:
                return i[3]
    except KeyError:
        print('key error')
    return 1

def add_pileup(sample):
    return pileup_from_json(pileup, sample["run"], sample["lumi"])

data["pileup"] = data.apply(add_pileup, axis=1)

# %%
data[2808] = data["pileup"]

# %%
# Split the data
TRAIN_FROM = round(0.3*len(data))
TRAIN_TO = round(0.4*len(data))
TEST_FROM = round(0.4*len(data))
TEST_TO = round(0.5*len(data))

train = data.iloc[TRAIN_FROM:TRAIN_TO]
X_train = pd.concat([train.iloc[:, :2808], train[2808]], axis=1)
y_train = train["label"]

# Adding bad data to test set
test = pd.concat([data.iloc[TEST_FROM:TEST_TO], data[:TEST_FROM][data['label'] == 1],
                 data[TEST_TO:][data['label'] == 1]]) 
X_test = pd.concat([test.iloc[:, :2808], test[2808]], axis=1)
y_test = test["label"]

normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# Train only on good
X_train = X_train[y_train == 0]
X_train_norm = X_train_norm[y_train == 0]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
INPUT_DIM = 2809

# %%
X_train_norm.shape
# Out:
# (16294, 2809)

# %%
input_layer = Input(shape=(INPUT_DIM, ))

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(INPUT_DIM)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2809)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              5754880
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 2048)              2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 1024)              1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# p_re_lu_3 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# p_re_lu_4 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# p_re_lu_5 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# p_re_lu_6 (PReLU)            (None, 64)                64
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               8320
# _________________________________________________________________
# p_re_lu_7 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               33024
# _________________________________________________________________
# p_re_lu_8 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               131584
# _________________________________________________________________
# p_re_lu_9 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_10 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 2048)              2099200
# _________________________________________________________________
# p_re_lu_11 (PReLU)           (None, 2048)              2048
# _________________________________________________________________
# dense_12 (Dense)             (None, 2809)              5755641
# =================================================================
# Total params: 17,111,417
# Trainable params: 17,111,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_norm,
                X_train_norm,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 12220 samples, validate on 4074 samples
# Epoch 1/2048
# 20s - loss: 89.0787 - val_loss: 76.2354
# Epoch 2/2048
# 3s - loss: 66.4413 - val_loss: 56.8584
# Epoch 3/2048
# 3s - loss: 49.6010 - val_loss: 42.4361
# Epoch 4/2048
# 4s - loss: 37.0572 - val_loss: 31.6988
# Epoch 5/2048
# 4s - loss: 27.7335 - val_loss: 23.7312
# Epoch 6/2048
# 4s - loss: 20.8270 - val_loss: 17.8412
# Epoch 7/2048
# 4s - loss: 15.7304 - val_loss: 13.5036
# Epoch 8/2048
# 4s - loss: 11.9833 - val_loss: 10.3216
# Epoch 9/2048
# 3s - loss: 9.2375 - val_loss: 7.9930
# Epoch 10/2048
# 4s - loss: 7.2302 - val_loss: 6.2930
# Epoch 11/2048
# 4s - loss: 5.7654 - val_loss: 5.0541
# Epoch 12/2048
# 4s - loss: 4.6980 - val_loss: 4.1483
# Epoch 13/2048
# 4s - loss: 3.9041 - val_loss: 3.4594
# Epoch 14/2048
# 4s - loss: 3.2962 - val_loss: 2.9312
# Epoch 15/2048
# 5s - loss: 2.8297 - val_loss: 2.5255
# Epoch 16/2048
# 4s - loss: 2.4689 - val_loss: 2.2059
# Epoch 17/2048
# 4s - loss: 2.1775 - val_loss: 1.9424
# Epoch 18/2048
# 4s - loss: 1.9373 - val_loss: 1.7253
# Epoch 19/2048
# 4s - loss: 1.7390 - val_loss: 1.5462
# Epoch 20/2048
# 4s - loss: 1.5755 - val_loss: 1.3989
# Epoch 21/2048
# 4s - loss: 1.4400 - val_loss: 1.2755
# Epoch 22/2048
# 4s - loss: 1.3280 - val_loss: 1.1739
# Epoch 23/2048
# 4s - loss: 1.2352 - val_loss: 1.0892
# Epoch 24/2048
# 4s - loss: 1.1569 - val_loss: 1.0172
# Epoch 25/2048
# 4s - loss: 1.0897 - val_loss: 0.9549
# Epoch 26/2048
# 4s - loss: 1.0318 - val_loss: 0.9015
# Epoch 27/2048
# 4s - loss: 0.9821 - val_loss: 0.8555
# Epoch 28/2048
# 4s - loss: 0.9394 - val_loss: 0.8166
# Epoch 29/2048
# 3s - loss: 0.9027 - val_loss: 0.7827
# Epoch 30/2048
# 4s - loss: 0.8711 - val_loss: 0.7543
# Epoch 31/2048
# 4s - loss: 0.8440 - val_loss: 0.7288
# Epoch 32/2048
# 4s - loss: 0.8208 - val_loss: 0.7076
# Epoch 33/2048
# 4s - loss: 0.8010 - val_loss: 0.6896
# Epoch 34/2048
# 4s - loss: 0.7839 - val_loss: 0.6739
# Epoch 35/2048
# 4s - loss: 0.7690 - val_loss: 0.6610
# Epoch 36/2048
# 3s - loss: 0.7561 - val_loss: 0.6478
# Epoch 37/2048
# 4s - loss: 0.7446 - val_loss: 0.6365
# Epoch 38/2048
# 3s - loss: 0.7345 - val_loss: 0.6279
# Epoch 39/2048
# 4s - loss: 0.7255 - val_loss: 0.6199
# Epoch 40/2048
# 5s - loss: 0.7179 - val_loss: 0.6124
# Epoch 41/2048
# 4s - loss: 0.7112 - val_loss: 0.6070
# Epoch 42/2048
# 4s - loss: 0.7053 - val_loss: 0.6011
# Epoch 43/2048
# 4s - loss: 0.7001 - val_loss: 0.5969
# Epoch 44/2048
# 3s - loss: 0.6956 - val_loss: 0.5929
# Epoch 45/2048
# 4s - loss: 0.6917 - val_loss: 0.5887
# Epoch 46/2048
# 4s - loss: 0.6883 - val_loss: 0.5858
# Epoch 47/2048
# 4s - loss: 0.6854 - val_loss: 0.5833
# Epoch 48/2048
# 4s - loss: 0.6828 - val_loss: 0.5817
# Epoch 49/2048
# 4s - loss: 0.6806 - val_loss: 0.5792
# Epoch 50/2048
# 4s - loss: 0.6785 - val_loss: 0.5780
# Epoch 51/2048
# 3s - loss: 0.6767 - val_loss: 0.5758
# Epoch 52/2048
# 4s - loss: 0.6751 - val_loss: 0.5746
# Epoch 53/2048
# 4s - loss: 0.6737 - val_loss: 0.5730
# Epoch 54/2048
# 4s - loss: 0.6724 - val_loss: 0.5722
# Epoch 55/2048
# 4s - loss: 0.6711 - val_loss: 0.5716
# Epoch 56/2048
# 4s - loss: 0.6700 - val_loss: 0.5705
# Epoch 57/2048
# 4s - loss: 0.6690 - val_loss: 0.5698
# Epoch 58/2048
# 4s - loss: 0.6682 - val_loss: 0.5693
# Epoch 59/2048
# 5s - loss: 0.6674 - val_loss: 0.5683
# Epoch 60/2048
# 3s - loss: 0.6666 - val_loss: 0.5674
# Epoch 61/2048
# 5s - loss: 0.6660 - val_loss: 0.5671
# Epoch 62/2048
# 4s - loss: 0.6654 - val_loss: 0.5667
# Epoch 63/2048
# 1s - loss: 0.6648 - val_loss: 0.5673
# Epoch 64/2048
# 1s - loss: 0.6644 - val_loss: 0.5670
# Epoch 65/2048
# 3s - loss: 0.6639 - val_loss: 0.5660
# Epoch 66/2048
# 4s - loss: 0.6634 - val_loss: 0.5655
# Epoch 67/2048
# 1s - loss: 0.6631 - val_loss: 0.5662
# Epoch 68/2048
# 1s - loss: 0.6628 - val_loss: 0.5659
# Epoch 69/2048
# 3s - loss: 0.6624 - val_loss: 0.5653
# Epoch 70/2048
# 1s - loss: 0.6621 - val_loss: 0.5653
# Epoch 71/2048
# 3s - loss: 0.6617 - val_loss: 0.5645
# Epoch 72/2048
# 1s - loss: 0.6614 - val_loss: 0.5645
# Epoch 73/2048
# 3s - loss: 0.6611 - val_loss: 0.5642
# Epoch 74/2048
# 1s - loss: 0.6608 - val_loss: 0.5644
# Epoch 75/2048
# 3s - loss: 0.6605 - val_loss: 0.5636
# Epoch 76/2048
# 4s - loss: 0.6603 - val_loss: 0.5634
# Epoch 77/2048
# 1s - loss: 0.6601 - val_loss: 0.5637
# Epoch 78/2048
# 1s - loss: 0.6598 - val_loss: 0.5637
# Epoch 79/2048
# 1s - loss: 0.6594 - val_loss: 0.5635
# Epoch 80/2048
# 3s - loss: 0.6593 - val_loss: 0.5628
# Epoch 81/2048
# 1s - loss: 0.6590 - val_loss: 0.5629
# Epoch 82/2048
# 3s - loss: 0.6587 - val_loss: 0.5627
# Epoch 83/2048
# 4s - loss: 0.6585 - val_loss: 0.5627
# Epoch 84/2048
# 1s - loss: 0.6583 - val_loss: 0.5630
# Epoch 85/2048
# 3s - loss: 0.6581 - val_loss: 0.5612
# Epoch 86/2048
# 1s - loss: 0.6579 - val_loss: 0.5623
# Epoch 87/2048
# 1s - loss: 0.6577 - val_loss: 0.5619
# Epoch 88/2048
# 1s - loss: 0.6575 - val_loss: 0.5620
# Epoch 89/2048
# 1s - loss: 0.6572 - val_loss: 0.5618
# Epoch 90/2048
# 1s - loss: 0.6570 - val_loss: 0.5618
# Epoch 91/2048
# 1s - loss: 0.6569 - val_loss: 0.5615
# Epoch 92/2048
# 4s - loss: 0.6567 - val_loss: 0.5612
# Epoch 93/2048
# 1s - loss: 0.6566 - val_loss: 0.5618
# Epoch 94/2048
# 3s - loss: 0.6563 - val_loss: 0.5610
# Epoch 95/2048
# 4s - loss: 0.6562 - val_loss: 0.5610
# Epoch 96/2048
# 4s - loss: 0.6560 - val_loss: 0.5607
# Epoch 97/2048
# 3s - loss: 0.6558 - val_loss: 0.5604
# Epoch 98/2048
# 4s - loss: 0.6556 - val_loss: 0.5600
# Epoch 99/2048
# 1s - loss: 0.6555 - val_loss: 0.5607
# Epoch 100/2048
# 3s - loss: 0.6553 - val_loss: 0.5598
# Epoch 101/2048
# 4s - loss: 0.6551 - val_loss: 0.5596
# Epoch 102/2048
# 1s - loss: 0.6549 - val_loss: 0.5600
# Epoch 103/2048
# 1s - loss: 0.6547 - val_loss: 0.5599
# Epoch 104/2048
# 1s - loss: 0.6546 - val_loss: 0.5599
# Epoch 105/2048
# 3s - loss: 0.6544 - val_loss: 0.5596
# Epoch 106/2048
# 4s - loss: 0.6543 - val_loss: 0.5593
# Epoch 107/2048
# 1s - loss: 0.6541 - val_loss: 0.5598
# Epoch 108/2048
# 3s - loss: 0.6540 - val_loss: 0.5586
# Epoch 109/2048
# 1s - loss: 0.6538 - val_loss: 0.5593
# Epoch 110/2048
# 1s - loss: 0.6537 - val_loss: 0.5596
# Epoch 111/2048
# 1s - loss: 0.6535 - val_loss: 0.5588
# Epoch 112/2048
# 1s - loss: 0.6533 - val_loss: 0.5590
# Epoch 113/2048
# 1s - loss: 0.6532 - val_loss: 0.5587
# Epoch 114/2048
# 4s - loss: 0.6532 - val_loss: 0.5585
# Epoch 115/2048
# 4s - loss: 0.6530 - val_loss: 0.5585
# Epoch 116/2048
# 1s - loss: 0.6527 - val_loss: 0.5585
# Epoch 117/2048
# 3s - loss: 0.6527 - val_loss: 0.5578
# Epoch 118/2048
# 4s - loss: 0.6524 - val_loss: 0.5577
# Epoch 119/2048
# 4s - loss: 0.6523 - val_loss: 0.5577
# Epoch 120/2048
# 1s - loss: 0.6522 - val_loss: 0.5577
# Epoch 121/2048
# 1s - loss: 0.6520 - val_loss: 0.5579
# Epoch 122/2048
# 1s - loss: 0.6519 - val_loss: 0.5581
# Epoch 123/2048
# 3s - loss: 0.6518 - val_loss: 0.5573
# Epoch 124/2048
# 1s - loss: 0.6516 - val_loss: 0.5575
# Epoch 125/2048
# 3s - loss: 0.6514 - val_loss: 0.5567
# Epoch 126/2048
# 1s - loss: 0.6513 - val_loss: 0.5567
# Epoch 127/2048
# 1s - loss: 0.6511 - val_loss: 0.5574
# Epoch 128/2048
# 3s - loss: 0.6511 - val_loss: 0.5565
# Epoch 129/2048
# 4s - loss: 0.6509 - val_loss: 0.5560
# Epoch 130/2048
# 1s - loss: 0.6508 - val_loss: 0.5564
# Epoch 131/2048
# 1s - loss: 0.6506 - val_loss: 0.5569
# Epoch 132/2048
# 1s - loss: 0.6505 - val_loss: 0.5560
# Epoch 133/2048
# 3s - loss: 0.6503 - val_loss: 0.5556
# Epoch 134/2048
# 1s - loss: 0.6502 - val_loss: 0.5563
# Epoch 135/2048
# 1s - loss: 0.6502 - val_loss: 0.5563
# Epoch 136/2048
# 1s - loss: 0.6500 - val_loss: 0.5560
# Epoch 137/2048
# 1s - loss: 0.6498 - val_loss: 0.5558
# Epoch 138/2048
# 3s - loss: 0.6497 - val_loss: 0.5555
# Epoch 139/2048
# 4s - loss: 0.6495 - val_loss: 0.5551
# Epoch 140/2048
# 1s - loss: 0.6496 - val_loss: 0.5554
# Epoch 141/2048
# 1s - loss: 0.6494 - val_loss: 0.5552
# Epoch 142/2048
# 4s - loss: 0.6492 - val_loss: 0.5550
# Epoch 143/2048
# 4s - loss: 0.6491 - val_loss: 0.5547
# Epoch 144/2048
# 4s - loss: 0.6491 - val_loss: 0.5543
# Epoch 145/2048
# 1s - loss: 0.6489 - val_loss: 0.5548
# Epoch 146/2048
# 1s - loss: 0.6488 - val_loss: 0.5546
# Epoch 147/2048
# 1s - loss: 0.6487 - val_loss: 0.5544
# Epoch 148/2048
# 1s - loss: 0.6486 - val_loss: 0.5544
# Epoch 149/2048
# 1s - loss: 0.6485 - val_loss: 0.5546
# Epoch 150/2048
# 1s - loss: 0.6485 - val_loss: 0.5544
# Epoch 151/2048
# 1s - loss: 0.6484 - val_loss: 0.5544
# Epoch 152/2048
# 1s - loss: 0.6482 - val_loss: 0.5546
# Epoch 153/2048
# 4s - loss: 0.6481 - val_loss: 0.5538
# Epoch 154/2048
# 4s - loss: 0.6480 - val_loss: 0.5536
# Epoch 155/2048
# 1s - loss: 0.6479 - val_loss: 0.5540
# Epoch 156/2048
# 1s - loss: 0.6477 - val_loss: 0.5540
# Epoch 157/2048
# 1s - loss: 0.6477 - val_loss: 0.5536
# Epoch 158/2048
# 3s - loss: 0.6476 - val_loss: 0.5530
# Epoch 159/2048
# 1s - loss: 0.6475 - val_loss: 0.5541
# Epoch 160/2048
# 1s - loss: 0.6474 - val_loss: 0.5536
# Epoch 161/2048
# 1s - loss: 0.6473 - val_loss: 0.5532
# Epoch 162/2048
# 1s - loss: 0.6473 - val_loss: 0.5533
# Epoch 163/2048
# 1s - loss: 0.6472 - val_loss: 0.5536
# Epoch 164/2048
# 1s - loss: 0.6471 - val_loss: 0.5533
# Epoch 165/2048
# 3s - loss: 0.6470 - val_loss: 0.5530
# Epoch 166/2048
# 1s - loss: 0.6469 - val_loss: 0.5536
# Epoch 167/2048
# 1s - loss: 0.6467 - val_loss: 0.5534
# Epoch 168/2048
# 3s - loss: 0.6467 - val_loss: 0.5529
# Epoch 169/2048
# 3s - loss: 0.6466 - val_loss: 0.5528
# Epoch 170/2048
# 1s - loss: 0.6465 - val_loss: 0.5528
# Epoch 171/2048
# 3s - loss: 0.6463 - val_loss: 0.5527
# Epoch 172/2048
# 1s - loss: 0.6464 - val_loss: 0.5531
# Epoch 173/2048
# 3s - loss: 0.6462 - val_loss: 0.5524
# Epoch 174/2048
# 4s - loss: 0.6462 - val_loss: 0.5516
# Epoch 175/2048
# 1s - loss: 0.6461 - val_loss: 0.5523
# Epoch 176/2048
# 1s - loss: 0.6460 - val_loss: 0.5518
# Epoch 177/2048
# 1s - loss: 0.6459 - val_loss: 0.5523
# Epoch 178/2048
# 1s - loss: 0.6459 - val_loss: 0.5524
# Epoch 179/2048
# 1s - loss: 0.6457 - val_loss: 0.5518
# Epoch 180/2048
# 1s - loss: 0.6456 - val_loss: 0.5517
# Epoch 181/2048
# 1s - loss: 0.6455 - val_loss: 0.5517
# Epoch 182/2048
# 3s - loss: 0.6455 - val_loss: 0.5514
# Epoch 183/2048
# 1s - loss: 0.6454 - val_loss: 0.5516
# Epoch 184/2048
# 3s - loss: 0.6453 - val_loss: 0.5510
# Epoch 185/2048
# 1s - loss: 0.6452 - val_loss: 0.5516
# Epoch 186/2048
# 1s - loss: 0.6451 - val_loss: 0.5511
# Epoch 187/2048
# 3s - loss: 0.6450 - val_loss: 0.5508
# Epoch 188/2048
# 1s - loss: 0.6449 - val_loss: 0.5514
# Epoch 189/2048
# 1s - loss: 0.6448 - val_loss: 0.5514
# Epoch 190/2048
# 1s - loss: 0.6447 - val_loss: 0.5510
# Epoch 191/2048
# 1s - loss: 0.6448 - val_loss: 0.5513
# Epoch 192/2048
# 4s - loss: 0.6446 - val_loss: 0.5506
# Epoch 193/2048
# 1s - loss: 0.6444 - val_loss: 0.5507
# Epoch 194/2048
# 3s - loss: 0.6445 - val_loss: 0.5506
# Epoch 195/2048
# 4s - loss: 0.6443 - val_loss: 0.5505
# Epoch 196/2048
# 3s - loss: 0.6443 - val_loss: 0.5503
# Epoch 197/2048
# 4s - loss: 0.6442 - val_loss: 0.5503
# Epoch 198/2048
# 1s - loss: 0.6441 - val_loss: 0.5510
# Epoch 199/2048
# 4s - loss: 0.6440 - val_loss: 0.5501
# Epoch 200/2048
# 1s - loss: 0.6440 - val_loss: 0.5507
# Epoch 201/2048
# 3s - loss: 0.6439 - val_loss: 0.5497
# Epoch 202/2048
# 1s - loss: 0.6438 - val_loss: 0.5500
# Epoch 203/2048
# 1s - loss: 0.6437 - val_loss: 0.5503
# Epoch 204/2048
# 3s - loss: 0.6436 - val_loss: 0.5495
# Epoch 205/2048
# 1s - loss: 0.6435 - val_loss: 0.5500
# Epoch 206/2048
# 1s - loss: 0.6434 - val_loss: 0.5496
# Epoch 207/2048
# 1s - loss: 0.6434 - val_loss: 0.5502
# Epoch 208/2048
# 1s - loss: 0.6433 - val_loss: 0.5499
# Epoch 209/2048
# 3s - loss: 0.6432 - val_loss: 0.5488
# Epoch 210/2048
# 1s - loss: 0.6432 - val_loss: 0.5497
# Epoch 211/2048
# 1s - loss: 0.6430 - val_loss: 0.5497
# Epoch 212/2048
# 1s - loss: 0.6430 - val_loss: 0.5492
# Epoch 213/2048
# 1s - loss: 0.6429 - val_loss: 0.5498
# Epoch 214/2048
# 1s - loss: 0.6429 - val_loss: 0.5494
# Epoch 215/2048
# 1s - loss: 0.6427 - val_loss: 0.5491
# Epoch 216/2048
# 1s - loss: 0.6427 - val_loss: 0.5498
# Epoch 217/2048
# 3s - loss: 0.6426 - val_loss: 0.5487
# Epoch 218/2048
# 1s - loss: 0.6425 - val_loss: 0.5492
# Epoch 219/2048
# 1s - loss: 0.6425 - val_loss: 0.5487
# Epoch 220/2048
# 3s - loss: 0.6423 - val_loss: 0.5486
# Epoch 221/2048
# 4s - loss: 0.6423 - val_loss: 0.5482
# Epoch 222/2048
# 1s - loss: 0.6422 - val_loss: 0.5487
# Epoch 223/2048
# 1s - loss: 0.6421 - val_loss: 0.5489
# Epoch 224/2048
# 1s - loss: 0.6422 - val_loss: 0.5483
# Epoch 225/2048
# 3s - loss: 0.6420 - val_loss: 0.5482
# Epoch 226/2048
# 4s - loss: 0.6418 - val_loss: 0.5479
# Epoch 227/2048
# 1s - loss: 0.6419 - val_loss: 0.5484
# Epoch 228/2048
# 1s - loss: 0.6418 - val_loss: 0.5483
# Epoch 229/2048
# 3s - loss: 0.6417 - val_loss: 0.5476
# Epoch 230/2048
# 4s - loss: 0.6416 - val_loss: 0.5472
# Epoch 231/2048
# 1s - loss: 0.6416 - val_loss: 0.5481
# Epoch 232/2048
# 1s - loss: 0.6415 - val_loss: 0.5484
# Epoch 233/2048
# 1s - loss: 0.6414 - val_loss: 0.5477
# Epoch 234/2048
# 1s - loss: 0.6414 - val_loss: 0.5483
# Epoch 235/2048
# 1s - loss: 0.6413 - val_loss: 0.5479
# Epoch 236/2048
# 1s - loss: 0.6412 - val_loss: 0.5481
# Epoch 237/2048
# 1s - loss: 0.6411 - val_loss: 0.5476
# Epoch 238/2048
# 1s - loss: 0.6411 - val_loss: 0.5477
# Epoch 239/2048
# 1s - loss: 0.6410 - val_loss: 0.5473
# Epoch 240/2048
# 3s - loss: 0.6411 - val_loss: 0.5465
# Epoch 241/2048
# 1s - loss: 0.6409 - val_loss: 0.5480
# Epoch 242/2048
# 1s - loss: 0.6410 - val_loss: 0.5476
# Epoch 243/2048
# 1s - loss: 0.6409 - val_loss: 0.5473
# Epoch 244/2048
# 1s - loss: 0.6407 - val_loss: 0.5478
# Epoch 245/2048
# 1s - loss: 0.6406 - val_loss: 0.5472
# Epoch 246/2048
# 3s - loss: 0.6406 - val_loss: 0.5465
# Epoch 247/2048
# 1s - loss: 0.6405 - val_loss: 0.5472
# Epoch 248/2048
# 1s - loss: 0.6404 - val_loss: 0.5472
# Epoch 249/2048
# 1s - loss: 0.6404 - val_loss: 0.5466
# Epoch 250/2048
# 1s - loss: 0.6403 - val_loss: 0.5470
# Epoch 251/2048
# 1s - loss: 0.6402 - val_loss: 0.5469
# Epoch 252/2048
# 1s - loss: 0.6403 - val_loss: 0.5471
# Epoch 253/2048
# 1s - loss: 0.6402 - val_loss: 0.5469
# Epoch 254/2048
# 3s - loss: 0.6401 - val_loss: 0.5464
# Epoch 255/2048
# 4s - loss: 0.6401 - val_loss: 0.5464
# Epoch 256/2048
# 4s - loss: 0.6399 - val_loss: 0.5464
# Epoch 257/2048
# 4s - loss: 0.6399 - val_loss: 0.5462
# Epoch 258/2048
# 1s - loss: 0.6399 - val_loss: 0.5469
# Epoch 259/2048
# 3s - loss: 0.6397 - val_loss: 0.5459
# Epoch 260/2048
# 1s - loss: 0.6398 - val_loss: 0.5461
# Epoch 261/2048
# 1s - loss: 0.6396 - val_loss: 0.5461
# Epoch 262/2048
# 3s - loss: 0.6396 - val_loss: 0.5458
# Epoch 263/2048
# 1s - loss: 0.6395 - val_loss: 0.5461
# Epoch 264/2048
# 1s - loss: 0.6394 - val_loss: 0.5459
# Epoch 265/2048
# 1s - loss: 0.6394 - val_loss: 0.5462
# Epoch 266/2048
# 3s - loss: 0.6393 - val_loss: 0.5452
# Epoch 267/2048
# 1s - loss: 0.6393 - val_loss: 0.5460
# Epoch 268/2048
# 1s - loss: 0.6392 - val_loss: 0.5463
# Epoch 269/2048
# 1s - loss: 0.6393 - val_loss: 0.5458
# Epoch 270/2048
# 3s - loss: 0.6391 - val_loss: 0.5451
# Epoch 271/2048
# 1s - loss: 0.6390 - val_loss: 0.5456
# Epoch 272/2048
# 1s - loss: 0.6390 - val_loss: 0.5456
# Epoch 273/2048
# 1s - loss: 0.6390 - val_loss: 0.5459
# Epoch 274/2048
# 1s - loss: 0.6389 - val_loss: 0.5453
# Epoch 275/2048
# 1s - loss: 0.6389 - val_loss: 0.5452
# Epoch 276/2048
# 1s - loss: 0.6387 - val_loss: 0.5457
# Epoch 277/2048
# 1s - loss: 0.6387 - val_loss: 0.5457
# Epoch 278/2048
# 1s - loss: 0.6386 - val_loss: 0.5452
# Epoch 279/2048
# 1s - loss: 0.6386 - val_loss: 0.5452
# Epoch 280/2048
# 1s - loss: 0.6385 - val_loss: 0.5453
# Epoch 281/2048
# 3s - loss: 0.6385 - val_loss: 0.5449
# Epoch 282/2048
# 1s - loss: 0.6384 - val_loss: 0.5450
# Epoch 283/2048
# 1s - loss: 0.6384 - val_loss: 0.5452
# Epoch 284/2048
# 1s - loss: 0.6384 - val_loss: 0.5453
# Epoch 285/2048
# 3s - loss: 0.6382 - val_loss: 0.5445
# Epoch 286/2048
# 1s - loss: 0.6382 - val_loss: 0.5453
# Epoch 287/2048
# 1s - loss: 0.6381 - val_loss: 0.5449
# Epoch 288/2048
# 1s - loss: 0.6380 - val_loss: 0.5446
# Epoch 289/2048
# 1s - loss: 0.6379 - val_loss: 0.5448
# Epoch 290/2048
# 1s - loss: 0.6380 - val_loss: 0.5447
# Epoch 291/2048
# 3s - loss: 0.6379 - val_loss: 0.5442
# Epoch 292/2048
# 4s - loss: 0.6378 - val_loss: 0.5439
# Epoch 293/2048
# 1s - loss: 0.6378 - val_loss: 0.5442
# Epoch 294/2048
# 1s - loss: 0.6377 - val_loss: 0.5442
# Epoch 295/2048
# 1s - loss: 0.6376 - val_loss: 0.5442
# Epoch 296/2048
# 1s - loss: 0.6376 - val_loss: 0.5441
# Epoch 297/2048
# 1s - loss: 0.6375 - val_loss: 0.5439
# Epoch 298/2048
# 3s - loss: 0.6374 - val_loss: 0.5439
# Epoch 299/2048
# 4s - loss: 0.6373 - val_loss: 0.5437
# Epoch 300/2048
# 1s - loss: 0.6373 - val_loss: 0.5441
# Epoch 301/2048
# 1s - loss: 0.6373 - val_loss: 0.5438
# Epoch 302/2048
# 1s - loss: 0.6373 - val_loss: 0.5440
# Epoch 303/2048
# 1s - loss: 0.6372 - val_loss: 0.5442
# Epoch 304/2048
# 1s - loss: 0.6371 - val_loss: 0.5441
# Epoch 305/2048
# 1s - loss: 0.6370 - val_loss: 0.5438
# Epoch 306/2048
# 1s - loss: 0.6370 - val_loss: 0.5445
# Epoch 307/2048
# 1s - loss: 0.6369 - val_loss: 0.5440
# Epoch 308/2048
# 1s - loss: 0.6368 - val_loss: 0.5441
# Epoch 309/2048
# 3s - loss: 0.6369 - val_loss: 0.5435
# Epoch 310/2048
# 4s - loss: 0.6368 - val_loss: 0.5432
# Epoch 311/2048
# 1s - loss: 0.6368 - val_loss: 0.5435
# Epoch 312/2048
# 3s - loss: 0.6366 - val_loss: 0.5431
# Epoch 313/2048
# 1s - loss: 0.6366 - val_loss: 0.5436
# Epoch 314/2048
# 1s - loss: 0.6366 - val_loss: 0.5434
# Epoch 315/2048
# 1s - loss: 0.6365 - val_loss: 0.5437
# Epoch 316/2048
# 3s - loss: 0.6364 - val_loss: 0.5430
# Epoch 317/2048
# 1s - loss: 0.6364 - val_loss: 0.5439
# Epoch 318/2048
# 1s - loss: 0.6364 - val_loss: 0.5436
# Epoch 319/2048
# 1s - loss: 0.6362 - val_loss: 0.5430
# Epoch 320/2048
# 1s - loss: 0.6362 - val_loss: 0.5436
# Epoch 321/2048
# 3s - loss: 0.6361 - val_loss: 0.5426
# Epoch 322/2048
# 1s - loss: 0.6362 - val_loss: 0.5434
# Epoch 323/2048
# 1s - loss: 0.6361 - val_loss: 0.5432
# Epoch 324/2048
# 1s - loss: 0.6360 - val_loss: 0.5434
# Epoch 325/2048
# 1s - loss: 0.6360 - val_loss: 0.5436
# Epoch 326/2048
# 1s - loss: 0.6358 - val_loss: 0.5430
# Epoch 327/2048
# 1s - loss: 0.6359 - val_loss: 0.5428
# Epoch 328/2048
# 1s - loss: 0.6357 - val_loss: 0.5427
# Epoch 329/2048
# 1s - loss: 0.6357 - val_loss: 0.5426
# Epoch 330/2048
# 1s - loss: 0.6357 - val_loss: 0.5430
# Epoch 331/2048
# 1s - loss: 0.6356 - val_loss: 0.5429
# Epoch 332/2048
# 3s - loss: 0.6356 - val_loss: 0.5422
# Epoch 333/2048
# 1s - loss: 0.6355 - val_loss: 0.5427
# Epoch 334/2048
# 1s - loss: 0.6354 - val_loss: 0.5424
# Epoch 335/2048
# 1s - loss: 0.6355 - val_loss: 0.5433
# Epoch 336/2048
# 1s - loss: 0.6353 - val_loss: 0.5426
# Epoch 337/2048
# 1s - loss: 0.6352 - val_loss: 0.5423
# Epoch 338/2048
# 1s - loss: 0.6354 - val_loss: 0.5423
# Epoch 339/2048
# 1s - loss: 0.6352 - val_loss: 0.5424
# Epoch 340/2048
# 3s - loss: 0.6351 - val_loss: 0.5421
# Epoch 341/2048
# 1s - loss: 0.6351 - val_loss: 0.5430
# Epoch 342/2048
# 1s - loss: 0.6350 - val_loss: 0.5423
# Epoch 343/2048
# 1s - loss: 0.6349 - val_loss: 0.5427
# Epoch 344/2048
# 1s - loss: 0.6349 - val_loss: 0.5425
# Epoch 345/2048
# 1s - loss: 0.6348 - val_loss: 0.5426
# Epoch 346/2048
# 1s - loss: 0.6348 - val_loss: 0.5427
# Epoch 347/2048
# 3s - loss: 0.6347 - val_loss: 0.5420
# Epoch 348/2048
# 1s - loss: 0.6347 - val_loss: 0.5421
# Epoch 349/2048
# 1s - loss: 0.6346 - val_loss: 0.5423
# Epoch 350/2048
# 1s - loss: 0.6345 - val_loss: 0.5423
# Epoch 351/2048
# 1s - loss: 0.6345 - val_loss: 0.5428
# Epoch 352/2048
# 3s - loss: 0.6345 - val_loss: 0.5418
# Epoch 353/2048
# 1s - loss: 0.6344 - val_loss: 0.5426
# Epoch 354/2048
# 1s - loss: 0.6343 - val_loss: 0.5421
# Epoch 355/2048
# 1s - loss: 0.6342 - val_loss: 0.5423
# Epoch 356/2048
# 3s - loss: 0.6342 - val_loss: 0.5418
# Epoch 357/2048
# 4s - loss: 0.6343 - val_loss: 0.5417
# Epoch 358/2048
# 4s - loss: 0.6342 - val_loss: 0.5412
# Epoch 359/2048
# 1s - loss: 0.6340 - val_loss: 0.5416
# Epoch 360/2048
# 1s - loss: 0.6340 - val_loss: 0.5417
# Epoch 361/2048
# 1s - loss: 0.6339 - val_loss: 0.5423
# Epoch 362/2048
# 1s - loss: 0.6339 - val_loss: 0.5423
# Epoch 363/2048
# 1s - loss: 0.6338 - val_loss: 0.5427
# Epoch 364/2048
# 1s - loss: 0.6337 - val_loss: 0.5416
# Epoch 365/2048
# 1s - loss: 0.6336 - val_loss: 0.5420
# Epoch 366/2048
# 1s - loss: 0.6337 - val_loss: 0.5416
# Epoch 367/2048
# 1s - loss: 0.6335 - val_loss: 0.5416
# Epoch 368/2048
# 3s - loss: 0.6336 - val_loss: 0.5411
# Epoch 369/2048
# 1s - loss: 0.6334 - val_loss: 0.5414
# Epoch 370/2048
# 1s - loss: 0.6334 - val_loss: 0.5412
# Epoch 371/2048
# 3s - loss: 0.6334 - val_loss: 0.5409
# Epoch 372/2048
# 4s - loss: 0.6331 - val_loss: 0.5408
# Epoch 373/2048
# 1s - loss: 0.6331 - val_loss: 0.5416
# Epoch 374/2048
# 1s - loss: 0.6331 - val_loss: 0.5414
# Epoch 375/2048
# 1s - loss: 0.6330 - val_loss: 0.5414
# Epoch 376/2048
# 1s - loss: 0.6329 - val_loss: 0.5410
# Epoch 377/2048
# 1s - loss: 0.6330 - val_loss: 0.5410
# Epoch 378/2048
# 1s - loss: 0.6329 - val_loss: 0.5413
# Epoch 379/2048
# 1s - loss: 0.6328 - val_loss: 0.5412
# Epoch 380/2048
# 1s - loss: 0.6328 - val_loss: 0.5413
# Epoch 381/2048
# 1s - loss: 0.6327 - val_loss: 0.5410
# Epoch 382/2048
# 1s - loss: 0.6326 - val_loss: 0.5415
# Epoch 383/2048
# 1s - loss: 0.6325 - val_loss: 0.5415
# Epoch 384/2048
# 3s - loss: 0.6325 - val_loss: 0.5406
# Epoch 385/2048
# 1s - loss: 0.6324 - val_loss: 0.5409
# Epoch 386/2048
# 1s - loss: 0.6324 - val_loss: 0.5412
# Epoch 387/2048
# 1s - loss: 0.6323 - val_loss: 0.5409
# Epoch 388/2048
# 1s - loss: 0.6323 - val_loss: 0.5415
# Epoch 389/2048
# 1s - loss: 0.6324 - val_loss: 0.5414
# Epoch 390/2048
# 1s - loss: 0.6323 - val_loss: 0.5413
# Epoch 391/2048
# 1s - loss: 0.6323 - val_loss: 0.5408
# Epoch 392/2048
# 1s - loss: 0.6322 - val_loss: 0.5407
# Epoch 393/2048
# 3s - loss: 0.6320 - val_loss: 0.5405
# Epoch 394/2048
# 1s - loss: 0.6320 - val_loss: 0.5410
# Epoch 395/2048
# 1s - loss: 0.6319 - val_loss: 0.5405
# Epoch 396/2048
# 1s - loss: 0.6319 - val_loss: 0.5410
# Epoch 397/2048
# 1s - loss: 0.6318 - val_loss: 0.5408
# Epoch 398/2048
# 1s - loss: 0.6318 - val_loss: 0.5411
# Epoch 399/2048
# 1s - loss: 0.6318 - val_loss: 0.5408
# Epoch 400/2048
# 3s - loss: 0.6318 - val_loss: 0.5402
# Epoch 401/2048
# 1s - loss: 0.6317 - val_loss: 0.5409
# Epoch 402/2048
# 1s - loss: 0.6316 - val_loss: 0.5413
# Epoch 403/2048
# 1s - loss: 0.6316 - val_loss: 0.5408
# Epoch 404/2048
# 1s - loss: 0.6316 - val_loss: 0.5405
# Epoch 405/2048
# 3s - loss: 0.6315 - val_loss: 0.5400
# Epoch 406/2048
# 1s - loss: 0.6316 - val_loss: 0.5411
# Epoch 407/2048
# 1s - loss: 0.6314 - val_loss: 0.5409
# Epoch 408/2048
# 1s - loss: 0.6313 - val_loss: 0.5408
# Epoch 409/2048
# 1s - loss: 0.6314 - val_loss: 0.5402
# Epoch 410/2048
# 1s - loss: 0.6312 - val_loss: 0.5403
# Epoch 411/2048
# 1s - loss: 0.6314 - val_loss: 0.5407
# Epoch 412/2048
# 1s - loss: 0.6312 - val_loss: 0.5409
# Epoch 413/2048
# 1s - loss: 0.6311 - val_loss: 0.5407
# Epoch 414/2048
# 1s - loss: 0.6312 - val_loss: 0.5404
# Epoch 415/2048
# 1s - loss: 0.6310 - val_loss: 0.5403
# Epoch 416/2048
# 1s - loss: 0.6310 - val_loss: 0.5408
# Epoch 417/2048
# 1s - loss: 0.6310 - val_loss: 0.5405
# Epoch 418/2048
# 1s - loss: 0.6309 - val_loss: 0.5407
# Epoch 419/2048
# 1s - loss: 0.6310 - val_loss: 0.5404
# Epoch 420/2048
# 1s - loss: 0.6308 - val_loss: 0.5406
# Epoch 421/2048
# 1s - loss: 0.6307 - val_loss: 0.5404
# Epoch 422/2048
# 1s - loss: 0.6310 - val_loss: 0.5416
# Epoch 423/2048
# 1s - loss: 0.6307 - val_loss: 0.5406
# Epoch 424/2048
# 1s - loss: 0.6305 - val_loss: 0.5402
# Epoch 425/2048
# 1s - loss: 0.6305 - val_loss: 0.5406
# Epoch 426/2048
# 1s - loss: 0.6305 - val_loss: 0.5407
# Epoch 427/2048
# 1s - loss: 0.6304 - val_loss: 0.5410
# Epoch 428/2048
# 3s - loss: 0.6305 - val_loss: 0.5399
# Epoch 429/2048
# 1s - loss: 0.6304 - val_loss: 0.5404
# Epoch 430/2048
# 1s - loss: 0.6303 - val_loss: 0.5409
# Epoch 431/2048
# 1s - loss: 0.6303 - val_loss: 0.5402
# Epoch 432/2048
# 1s - loss: 0.6302 - val_loss: 0.5407
# Epoch 433/2048
# 1s - loss: 0.6301 - val_loss: 0.5401
# Epoch 434/2048
# 1s - loss: 0.6302 - val_loss: 0.5404
# Epoch 435/2048
# 1s - loss: 0.6302 - val_loss: 0.5412
# Epoch 436/2048
# 1s - loss: 0.6300 - val_loss: 0.5399
# Epoch 437/2048
# 1s - loss: 0.6300 - val_loss: 0.5405
# Epoch 438/2048
# 1s - loss: 0.6299 - val_loss: 0.5401
# Epoch 439/2048
# 1s - loss: 0.6299 - val_loss: 0.5403
# Epoch 440/2048
# 1s - loss: 0.6298 - val_loss: 0.5409
# Epoch 441/2048
# 1s - loss: 0.6299 - val_loss: 0.5409
# Epoch 442/2048
# 1s - loss: 0.6297 - val_loss: 0.5403
# Epoch 443/2048
# 1s - loss: 0.6297 - val_loss: 0.5412
# Epoch 444/2048
# 1s - loss: 0.6296 - val_loss: 0.5405
# Epoch 445/2048
# 1s - loss: 0.6296 - val_loss: 0.5407
# Epoch 446/2048
# 1s - loss: 0.6296 - val_loss: 0.5403
# Epoch 447/2048
# 1s - loss: 0.6294 - val_loss: 0.5410
# Epoch 448/2048
# 1s - loss: 0.6294 - val_loss: 0.5407
# Epoch 449/2048
# 1s - loss: 0.6294 - val_loss: 0.5405
# Epoch 450/2048
# 3s - loss: 0.6295 - val_loss: 0.5399
# Epoch 451/2048
# 1s - loss: 0.6293 - val_loss: 0.5409
# Epoch 452/2048
# 1s - loss: 0.6292 - val_loss: 0.5409
# Epoch 453/2048
# 1s - loss: 0.6293 - val_loss: 0.5408
# Epoch 454/2048
# 1s - loss: 0.6292 - val_loss: 0.5404
# Epoch 455/2048
# 1s - loss: 0.6291 - val_loss: 0.5404
# Epoch 456/2048
# 1s - loss: 0.6291 - val_loss: 0.5410
# Epoch 457/2048
# 1s - loss: 0.6290 - val_loss: 0.5405
# Epoch 458/2048
# 1s - loss: 0.6291 - val_loss: 0.5409
# Epoch 459/2048
# 1s - loss: 0.6290 - val_loss: 0.5407
# Epoch 460/2048
# 1s - loss: 0.6288 - val_loss: 0.5409
# Epoch 461/2048
# 1s - loss: 0.6289 - val_loss: 0.5407
# Epoch 462/2048
# 1s - loss: 0.6289 - val_loss: 0.5407
# Epoch 463/2048
# 1s - loss: 0.6286 - val_loss: 0.5410
# Epoch 464/2048
# 1s - loss: 0.6286 - val_loss: 0.5403
# Epoch 465/2048
# 1s - loss: 0.6286 - val_loss: 0.5409
# Epoch 466/2048
# 1s - loss: 0.6286 - val_loss: 0.5412
# Epoch 467/2048
# 1s - loss: 0.6285 - val_loss: 0.5411
# Epoch 468/2048
# 1s - loss: 0.6286 - val_loss: 0.5408
# Epoch 469/2048
# 1s - loss: 0.6284 - val_loss: 0.5408
# Epoch 470/2048
# 1s - loss: 0.6284 - val_loss: 0.5406
# Epoch 471/2048
# 1s - loss: 0.6283 - val_loss: 0.5408
# Epoch 472/2048
# 1s - loss: 0.6284 - val_loss: 0.5410
# Epoch 473/2048
# 1s - loss: 0.6282 - val_loss: 0.5411
# Epoch 474/2048
# 1s - loss: 0.6282 - val_loss: 0.5415
# Epoch 475/2048
# 1s - loss: 0.6282 - val_loss: 0.5406
# Epoch 476/2048
# 1s - loss: 0.6281 - val_loss: 0.5410
# Epoch 477/2048
# 1s - loss: 0.6280 - val_loss: 0.5406
# Epoch 478/2048
# 1s - loss: 0.6279 - val_loss: 0.5420
# Epoch 479/2048
# 1s - loss: 0.6279 - val_loss: 0.5415
# Epoch 480/2048
# 1s - loss: 0.6279 - val_loss: 0.5409
# Epoch 481/2048
# 1s - loss: 0.6279 - val_loss: 0.5406
# Epoch 482/2048
# 1s - loss: 0.6279 - val_loss: 0.5417
# Epoch 483/2048
# 1s - loss: 0.6278 - val_loss: 0.5410
# Epoch 00482: early stopping

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name))

# %%
# Run predictions
ae_pred = autoencoder.predict(X_test_norm)
ae_pred_train = autoencoder.predict(X_train_norm)

# %%
# Exclude validation set
ae_pred_train = ae_pred_train[:int(0.75 * len(ae_pred_train)), :]

# %%
pickle.dump(ae_pred, open(model_directory + "ae_pred.p", "wb"))
pickle.dump(ae_pred_train, open(model_directory + "ae_pred_train.p", "wb"))

# %%
ae_pred = pickle.load(open(model_directory + "ae_pred.p", "rb"))
ae_pred_train = pickle.load(open(model_directory + "ae_pred_train.p", "rb"))

# %%
# Exclude validation set
X_train_wo_valid = X_train_norm[:int(0.75 * len(X_train_norm)), :]

# %%
def get_error_df(X_test, predictions, mode="allmean", n_highest = 100):
    
    if mode == "allmean":
        return np.mean(np.power(X_test - predictions, 2), axis=1)
    
    elif mode == "topn":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.mean(result, axis=1)
    
    elif mode == "topn_median":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.median(result, axis=1)
    
    elif mode == "perobj":
        mses = []
        for l in legend:
            mse = np.mean(
                np.power(X_test[:,l["start"]:l["end"]] - predictions[:,l["start"]:l["end"]], 2),
                axis=1)
            mses.append(mse)
     
        return np.maximum.reduce(mses)
    
    elif mode == "bottomn":
        temp = np.partition(np.power(X_test - predictions, 2), n_highest)
        result = temp[:,:n_highest]
        return np.mean(result, axis=1)

# %%
ae_pred.shape
# Out:
# (18628, 2809)

# %%
ae_error = get_error_df(X_test_norm, ae_pred, mode="topn", n_highest=100)
ae_error_train = get_error_df(X_train_wo_valid, ae_pred_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error, open(model_directory + "ae_error.p", "wb"))
pickle.dump(ae_error_train, open(model_directory + "ae_error_train.p", "wb"))

# %%
# Plot lumi vs error
def plot_lumi_error(pred, X_test, threshold=None, title=None):
    scores = get_error_df(X_test, pred, mode='topn')
    
    fig, ax = plt.subplots()

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 0],
             scores[y_test == 0],
             linestyle='',
             ms=2,
             marker='o',
             label="Outlier")

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 1],
             scores[y_test == 1],
             linestyle='',
             ms=2,
             marker='o',
             label="Inlier")

    ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
    
    ax.set_yscale("log")
    plt.ylabel("Score")
    plt.xlabel("Lumisection #")
    if title:
        plt.title(title)
    plt.show();

# %%
start_legend = 1414
var_legend = [{'start': start_legend, 'end': start_legend, 'name': 'mean'},
              {'start': start_legend+1, 'end': start_legend+1, 'name': 'RMS'},
              {'start': start_legend+2, 'end': start_legend+2, 'name': 'Q1'},
              {'start': start_legend+3, 'end': start_legend+3, 'name': 'Q2'},
              {'start': start_legend+4, 'end': start_legend+4, 'name': 'Q3'},
              {'start': start_legend+5, 'end': start_legend+5, 'name': 'Q4'},
              {'start': start_legend+6, 'end': start_legend+6, 'name': 'Q5'}]

# %%
corr = [pearsonr(X_train_wo_valid[:, i].reshape(-1), ae_pred_train[:, i].reshape(-1)) for i in range(INPUT_DIM)]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
corr = np.array(corr)[:, 0]

# %%
corr[np.isnan(corr)] = 0

# %%
plt.hist(corr, bins=100)
plt.title('Histogram of correlation coefficients for 2809 features')
plt.show()

# %%
corr_filter = corr > 0.5

# %%
variance = np.var(data.iloc[:, 0:INPUT_DIM])

# %%
var_filter = variance != 0

# %%
feature_filter = corr_filter & var_filter

# %%
X_train_filtered = X_train_norm[:, feature_filter]
X_train_filtered.shape
# Out:
# (16294, 1173)

# %%
X_train_filtered_wo_valid = X_train.iloc[:round(0.75*len(X_train)), :]
X_train_filtered_wo_valid = np.array(X_train_filtered_wo_valid)[:, feature_filter]

# %%
corr_names = []
for i in tnrange(2809):
    v, r = divmod(i, 7)
    corr_names.append([feature_names[v],
                      var_legend[r]['name'],
                      corr[i]])

# %%
corr_names_pd = pd.DataFrame(corr_names, columns=['name', 'group',
                                                  'corr_coeff'])

# %%
corr_groups = corr_names_pd.groupby('group')

# %%
plt.rcParams['figure.figsize'] = [6, 3]
for n in corr_groups.groups.keys():
    coeffs = corr_groups.get_group(n).corr_coeff
    used = len(coeffs[coeffs > 0.5])/len(coeffs)
    plt.hist(corr_groups.get_group(n).corr_coeff, bins=10)
    plt.title(n + ' ' + str(round(used, 2)))
    plt.xlim([0, 1])
    plt.show()

# %%
corr_groups.aggregate(np.mean)
# Out:
#        corr_coeff
# group
# Q1       0.240212
# Q2       0.532123
# Q3       0.372624
# Q4       0.574321
# Q5       0.273880
# RMS      0.595986
# mean     0.425996

# %%
corr_groups.aggregate(np.median)
# Out:
#        corr_coeff
# group
# Q1       0.234335
# Q2       0.645977
# Q3       0.101589
# Q4       0.723416
# Q5       0.243096
# RMS      0.682051
# mean     0.247906

# %%
corr_groups.aggregate(np.std)
# Out:
#        corr_coeff
# group
# Q1       0.197755
# Q2       0.395655
# Q3       0.406188
# Q4       0.380209
# Q5       0.181035
# RMS      0.325741
# mean     0.372866

# %%
csv_dir = model_directory
corr_names_pd.to_csv(csv_dir + 'correlation_coeff_feature_names.csv', index=False)

# %%
input_dim = X_train_filtered.shape[1]
input_layer = Input(shape=(input_dim, ))

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(32, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(input_dim)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1173)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              1202176
# _________________________________________________________________
# p_re_lu_12 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# p_re_lu_13 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               131328
# _________________________________________________________________
# p_re_lu_14 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# p_re_lu_15 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# p_re_lu_16 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# p_re_lu_17 (PReLU)           (None, 32)                32
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                2112
# _________________________________________________________________
# p_re_lu_18 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               8320
# _________________________________________________________________
# p_re_lu_19 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               33024
# _________________________________________________________________
# p_re_lu_20 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# p_re_lu_21 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_23 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_22 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_24 (Dense)             (None, 1173)              1202325
# =================================================================
# Total params: 3,808,213
# Trainable params: 3,808,213
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name2 = 'ae2'

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name2)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_filtered,
                X_train_filtered,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 12220 samples, validate on 4074 samples
# Epoch 1/2048
# 3s - loss: 42.5539 - val_loss: 38.0376
# Epoch 2/2048
# 1s - loss: 34.6364 - val_loss: 30.9056
# Epoch 3/2048
# 1s - loss: 28.2363 - val_loss: 25.3454
# Epoch 4/2048
# 1s - loss: 23.1546 - val_loss: 20.8229
# Epoch 5/2048
# 1s - loss: 18.9835 - val_loss: 17.1007
# Epoch 6/2048
# 1s - loss: 15.5963 - val_loss: 14.0556
# Epoch 7/2048
# 1s - loss: 12.8314 - val_loss: 11.5717
# Epoch 8/2048
# 1s - loss: 10.5799 - val_loss: 9.5540
# Epoch 9/2048
# 1s - loss: 8.7506 - val_loss: 7.9154
# Epoch 10/2048
# 1s - loss: 7.2674 - val_loss: 6.5891
# Epoch 11/2048
# 1s - loss: 6.0656 - val_loss: 5.5132
# Epoch 12/2048
# 1s - loss: 5.0925 - val_loss: 4.6418
# Epoch 13/2048
# 1s - loss: 4.3042 - val_loss: 3.9355
# Epoch 14/2048
# 1s - loss: 3.6658 - val_loss: 3.3641
# Epoch 15/2048
# 1s - loss: 3.1483 - val_loss: 2.9004
# Epoch 16/2048
# 1s - loss: 2.7282 - val_loss: 2.5241
# Epoch 17/2048
# 1s - loss: 2.3867 - val_loss: 2.2172
# Epoch 18/2048
# 1s - loss: 2.1084 - val_loss: 1.9668
# Epoch 19/2048
# 1s - loss: 1.8805 - val_loss: 1.7610
# Epoch 20/2048
# 1s - loss: 1.6913 - val_loss: 1.5884
# Epoch 21/2048
# 1s - loss: 1.5319 - val_loss: 1.4425
# Epoch 22/2048
# 1s - loss: 1.3977 - val_loss: 1.3194
# Epoch 23/2048
# 1s - loss: 1.2834 - val_loss: 1.2147
# Epoch 24/2048
# 1s - loss: 1.1853 - val_loss: 1.1236
# Epoch 25/2048
# 1s - loss: 1.0996 - val_loss: 1.0435
# Epoch 26/2048
# 1s - loss: 1.0246 - val_loss: 0.9740
# Epoch 27/2048
# 1s - loss: 0.9587 - val_loss: 0.9127
# Epoch 28/2048
# 1s - loss: 0.9009 - val_loss: 0.8589
# Epoch 29/2048
# 1s - loss: 0.8500 - val_loss: 0.8115
# Epoch 30/2048
# 1s - loss: 0.8053 - val_loss: 0.7699
# Epoch 31/2048
# 1s - loss: 0.7659 - val_loss: 0.7335
# Epoch 32/2048
# 1s - loss: 0.7310 - val_loss: 0.7005
# Epoch 33/2048
# 1s - loss: 0.7000 - val_loss: 0.6723
# Epoch 34/2048
# 1s - loss: 0.6726 - val_loss: 0.6465
# Epoch 35/2048
# 1s - loss: 0.6482 - val_loss: 0.6237
# Epoch 36/2048
# 1s - loss: 0.6259 - val_loss: 0.6031
# Epoch 37/2048
# 1s - loss: 0.6061 - val_loss: 0.5847
# Epoch 38/2048
# 1s - loss: 0.5882 - val_loss: 0.5679
# Epoch 39/2048
# 1s - loss: 0.5719 - val_loss: 0.5521
# Epoch 40/2048
# 1s - loss: 0.5572 - val_loss: 0.5381
# Epoch 41/2048
# 1s - loss: 0.5439 - val_loss: 0.5256
# Epoch 42/2048
# 1s - loss: 0.5318 - val_loss: 0.5145
# Epoch 43/2048
# 1s - loss: 0.5210 - val_loss: 0.5039
# Epoch 44/2048
# 1s - loss: 0.5111 - val_loss: 0.4951
# Epoch 45/2048
# 1s - loss: 0.5023 - val_loss: 0.4868
# Epoch 46/2048
# 1s - loss: 0.4941 - val_loss: 0.4787
# Epoch 47/2048
# 1s - loss: 0.4868 - val_loss: 0.4722
# Epoch 48/2048
# 1s - loss: 0.4802 - val_loss: 0.4654
# Epoch 49/2048
# 1s - loss: 0.4740 - val_loss: 0.4605
# Epoch 50/2048
# 1s - loss: 0.4683 - val_loss: 0.4547
# Epoch 51/2048
# 1s - loss: 0.4632 - val_loss: 0.4499
# Epoch 52/2048
# 1s - loss: 0.4584 - val_loss: 0.4457
# Epoch 53/2048
# 1s - loss: 0.4542 - val_loss: 0.4411
# Epoch 54/2048
# 1s - loss: 0.4500 - val_loss: 0.4375
# Epoch 55/2048
# 1s - loss: 0.4462 - val_loss: 0.4339
# Epoch 56/2048
# 1s - loss: 0.4428 - val_loss: 0.4304
# Epoch 57/2048
# 1s - loss: 0.4396 - val_loss: 0.4275
# Epoch 58/2048
# 1s - loss: 0.4366 - val_loss: 0.4247
# Epoch 59/2048
# 1s - loss: 0.4339 - val_loss: 0.4224
# Epoch 60/2048
# 1s - loss: 0.4314 - val_loss: 0.4199
# Epoch 61/2048
# 2s - loss: 0.4291 - val_loss: 0.4175
# Epoch 62/2048
# 1s - loss: 0.4269 - val_loss: 0.4157
# Epoch 63/2048
# 1s - loss: 0.4250 - val_loss: 0.4141
# Epoch 64/2048
# 1s - loss: 0.4229 - val_loss: 0.4116
# Epoch 65/2048
# 1s - loss: 0.4213 - val_loss: 0.4103
# Epoch 66/2048
# 1s - loss: 0.4196 - val_loss: 0.4091
# Epoch 67/2048
# 1s - loss: 0.4181 - val_loss: 0.4074
# Epoch 68/2048
# 1s - loss: 0.4167 - val_loss: 0.4059
# Epoch 69/2048
# 1s - loss: 0.4152 - val_loss: 0.4045
# Epoch 70/2048
# 1s - loss: 0.4141 - val_loss: 0.4037
# Epoch 71/2048
# 1s - loss: 0.4127 - val_loss: 0.4023
# Epoch 72/2048
# 2s - loss: 0.4116 - val_loss: 0.4012
# Epoch 73/2048
# 1s - loss: 0.4105 - val_loss: 0.4001
# Epoch 74/2048
# 3s - loss: 0.4095 - val_loss: 0.3994
# Epoch 75/2048
# 1s - loss: 0.4085 - val_loss: 0.3982
# Epoch 76/2048
# 1s - loss: 0.4074 - val_loss: 0.3972
# Epoch 77/2048
# 1s - loss: 0.4065 - val_loss: 0.3962
# Epoch 78/2048
# 1s - loss: 0.4057 - val_loss: 0.3955
# Epoch 79/2048
# 1s - loss: 0.4047 - val_loss: 0.3949
# Epoch 80/2048
# 2s - loss: 0.4039 - val_loss: 0.3937
# Epoch 81/2048
# 2s - loss: 0.4032 - val_loss: 0.3933
# Epoch 82/2048
# 1s - loss: 0.4024 - val_loss: 0.3924
# Epoch 83/2048
# 1s - loss: 0.4016 - val_loss: 0.3913
# Epoch 84/2048
# 1s - loss: 0.4008 - val_loss: 0.3911
# Epoch 85/2048
# 1s - loss: 0.4001 - val_loss: 0.3903
# Epoch 86/2048
# 1s - loss: 0.3994 - val_loss: 0.3895
# Epoch 87/2048
# 1s - loss: 0.3987 - val_loss: 0.3888
# Epoch 88/2048
# 2s - loss: 0.3980 - val_loss: 0.3881
# Epoch 89/2048
# 3s - loss: 0.3974 - val_loss: 0.3875
# Epoch 90/2048
# 1s - loss: 0.3967 - val_loss: 0.3872
# Epoch 91/2048
# 1s - loss: 0.3961 - val_loss: 0.3866
# Epoch 92/2048
# 1s - loss: 0.3956 - val_loss: 0.3861
# Epoch 93/2048
# 2s - loss: 0.3949 - val_loss: 0.3856
# Epoch 94/2048
# 1s - loss: 0.3944 - val_loss: 0.3848
# Epoch 95/2048
# 2s - loss: 0.3938 - val_loss: 0.3843
# Epoch 96/2048
# 1s - loss: 0.3933 - val_loss: 0.3835
# Epoch 97/2048
# 2s - loss: 0.3927 - val_loss: 0.3833
# Epoch 98/2048
# 1s - loss: 0.3922 - val_loss: 0.3825
# Epoch 99/2048
# 1s - loss: 0.3916 - val_loss: 0.3825
# Epoch 100/2048
# 1s - loss: 0.3912 - val_loss: 0.3817
# Epoch 101/2048
# 1s - loss: 0.3907 - val_loss: 0.3813
# Epoch 102/2048
# 1s - loss: 0.3903 - val_loss: 0.3809
# Epoch 103/2048
# 1s - loss: 0.3897 - val_loss: 0.3806
# Epoch 104/2048
# 1s - loss: 0.3892 - val_loss: 0.3798
# Epoch 105/2048
# 1s - loss: 0.3889 - val_loss: 0.3796
# Epoch 106/2048
# 1s - loss: 0.3883 - val_loss: 0.3789
# Epoch 107/2048
# 1s - loss: 0.3879 - val_loss: 0.3784
# Epoch 108/2048
# 2s - loss: 0.3875 - val_loss: 0.3779
# Epoch 109/2048
# 1s - loss: 0.3870 - val_loss: 0.3776
# Epoch 110/2048
# 1s - loss: 0.3865 - val_loss: 0.3775
# Epoch 111/2048
# 2s - loss: 0.3861 - val_loss: 0.3769
# Epoch 112/2048
# 1s - loss: 0.3857 - val_loss: 0.3765
# Epoch 113/2048
# 2s - loss: 0.3852 - val_loss: 0.3760
# Epoch 114/2048
# 2s - loss: 0.3848 - val_loss: 0.3757
# Epoch 115/2048
# 2s - loss: 0.3844 - val_loss: 0.3752
# Epoch 116/2048
# 1s - loss: 0.3840 - val_loss: 0.3743
# Epoch 117/2048
# 1s - loss: 0.3836 - val_loss: 0.3746
# Epoch 118/2048
# 2s - loss: 0.3832 - val_loss: 0.3743
# Epoch 119/2048
# 1s - loss: 0.3827 - val_loss: 0.3737
# Epoch 120/2048
# 2s - loss: 0.3824 - val_loss: 0.3732
# Epoch 121/2048
# 1s - loss: 0.3820 - val_loss: 0.3726
# Epoch 122/2048
# 2s - loss: 0.3816 - val_loss: 0.3725
# Epoch 123/2048
# 1s - loss: 0.3812 - val_loss: 0.3722
# Epoch 124/2048
# 2s - loss: 0.3808 - val_loss: 0.3716
# Epoch 125/2048
# 1s - loss: 0.3805 - val_loss: 0.3715
# Epoch 126/2048
# 2s - loss: 0.3801 - val_loss: 0.3710
# Epoch 127/2048
# 1s - loss: 0.3799 - val_loss: 0.3711
# Epoch 128/2048
# 1s - loss: 0.3794 - val_loss: 0.3702
# Epoch 129/2048
# 1s - loss: 0.3791 - val_loss: 0.3702
# Epoch 130/2048
# 1s - loss: 0.3788 - val_loss: 0.3702
# Epoch 131/2048
# 1s - loss: 0.3784 - val_loss: 0.3694
# Epoch 132/2048
# 1s - loss: 0.3781 - val_loss: 0.3691
# Epoch 133/2048
# 1s - loss: 0.3777 - val_loss: 0.3685
# Epoch 134/2048
# 1s - loss: 0.3774 - val_loss: 0.3685
# Epoch 135/2048
# 1s - loss: 0.3771 - val_loss: 0.3684
# Epoch 136/2048
# 1s - loss: 0.3768 - val_loss: 0.3682
# Epoch 137/2048
# 1s - loss: 0.3765 - val_loss: 0.3675
# Epoch 138/2048
# 1s - loss: 0.3761 - val_loss: 0.3672
# Epoch 139/2048
# 1s - loss: 0.3758 - val_loss: 0.3670
# Epoch 140/2048
# 1s - loss: 0.3755 - val_loss: 0.3667
# Epoch 141/2048
# 1s - loss: 0.3751 - val_loss: 0.3663
# Epoch 142/2048
# 1s - loss: 0.3748 - val_loss: 0.3661
# Epoch 143/2048
# 1s - loss: 0.3746 - val_loss: 0.3658
# Epoch 144/2048
# 1s - loss: 0.3744 - val_loss: 0.3653
# Epoch 145/2048
# 1s - loss: 0.3740 - val_loss: 0.3652
# Epoch 146/2048
# 1s - loss: 0.3738 - val_loss: 0.3650
# Epoch 147/2048
# 3s - loss: 0.3734 - val_loss: 0.3647
# Epoch 148/2048
# 1s - loss: 0.3731 - val_loss: 0.3643
# Epoch 149/2048
# 1s - loss: 0.3728 - val_loss: 0.3643
# Epoch 150/2048
# 1s - loss: 0.3726 - val_loss: 0.3639
# Epoch 151/2048
# 3s - loss: 0.3724 - val_loss: 0.3637
# Epoch 152/2048
# 2s - loss: 0.3720 - val_loss: 0.3632
# Epoch 153/2048
# 1s - loss: 0.3718 - val_loss: 0.3632
# Epoch 154/2048
# 1s - loss: 0.3714 - val_loss: 0.3623
# Epoch 155/2048
# 1s - loss: 0.3710 - val_loss: 0.3623
# Epoch 156/2048
# 1s - loss: 0.3708 - val_loss: 0.3623
# Epoch 157/2048
# 1s - loss: 0.3706 - val_loss: 0.3620
# Epoch 158/2048
# 1s - loss: 0.3703 - val_loss: 0.3613
# Epoch 159/2048
# 3s - loss: 0.3699 - val_loss: 0.3612
# Epoch 160/2048
# 1s - loss: 0.3697 - val_loss: 0.3613
# Epoch 161/2048
# 1s - loss: 0.3694 - val_loss: 0.3607
# Epoch 162/2048
# 1s - loss: 0.3692 - val_loss: 0.3608
# Epoch 163/2048
# 1s - loss: 0.3690 - val_loss: 0.3606
# Epoch 164/2048
# 1s - loss: 0.3687 - val_loss: 0.3603
# Epoch 165/2048
# 3s - loss: 0.3683 - val_loss: 0.3601
# Epoch 166/2048
# 1s - loss: 0.3681 - val_loss: 0.3597
# Epoch 167/2048
# 1s - loss: 0.3679 - val_loss: 0.3592
# Epoch 168/2048
# 1s - loss: 0.3676 - val_loss: 0.3590
# Epoch 169/2048
# 1s - loss: 0.3674 - val_loss: 0.3590
# Epoch 170/2048
# 2s - loss: 0.3671 - val_loss: 0.3585
# Epoch 171/2048
# 1s - loss: 0.3669 - val_loss: 0.3583
# Epoch 172/2048
# 1s - loss: 0.3666 - val_loss: 0.3584
# Epoch 173/2048
# 1s - loss: 0.3664 - val_loss: 0.3580
# Epoch 174/2048
# 1s - loss: 0.3662 - val_loss: 0.3579
# Epoch 175/2048
# 2s - loss: 0.3659 - val_loss: 0.3577
# Epoch 176/2048
# 1s - loss: 0.3656 - val_loss: 0.3573
# Epoch 177/2048
# 2s - loss: 0.3655 - val_loss: 0.3568
# Epoch 178/2048
# 1s - loss: 0.3652 - val_loss: 0.3569
# Epoch 179/2048
# 1s - loss: 0.3649 - val_loss: 0.3569
# Epoch 180/2048
# 1s - loss: 0.3647 - val_loss: 0.3565
# Epoch 181/2048
# 1s - loss: 0.3645 - val_loss: 0.3564
# Epoch 182/2048
# 1s - loss: 0.3643 - val_loss: 0.3563
# Epoch 183/2048
# 1s - loss: 0.3640 - val_loss: 0.3560
# Epoch 184/2048
# 1s - loss: 0.3639 - val_loss: 0.3555
# Epoch 185/2048
# 1s - loss: 0.3636 - val_loss: 0.3554
# Epoch 186/2048
# 2s - loss: 0.3634 - val_loss: 0.3553
# Epoch 187/2048
# 1s - loss: 0.3632 - val_loss: 0.3554
# Epoch 188/2048
# 1s - loss: 0.3629 - val_loss: 0.3547
# Epoch 189/2048
# 1s - loss: 0.3627 - val_loss: 0.3545
# Epoch 190/2048
# 1s - loss: 0.3625 - val_loss: 0.3544
# Epoch 191/2048
# 1s - loss: 0.3623 - val_loss: 0.3547
# Epoch 192/2048
# 1s - loss: 0.3620 - val_loss: 0.3539
# Epoch 193/2048
# 2s - loss: 0.3619 - val_loss: 0.3538
# Epoch 194/2048
# 1s - loss: 0.3617 - val_loss: 0.3534
# Epoch 195/2048
# 2s - loss: 0.3615 - val_loss: 0.3529
# Epoch 196/2048
# 1s - loss: 0.3613 - val_loss: 0.3533
# Epoch 197/2048
# 1s - loss: 0.3611 - val_loss: 0.3529
# Epoch 198/2048
# 1s - loss: 0.3610 - val_loss: 0.3526
# Epoch 199/2048
# 1s - loss: 0.3607 - val_loss: 0.3527
# Epoch 200/2048
# 1s - loss: 0.3605 - val_loss: 0.3522
# Epoch 201/2048
# 1s - loss: 0.3603 - val_loss: 0.3523
# Epoch 202/2048
# 1s - loss: 0.3601 - val_loss: 0.3519
# Epoch 203/2048
# 1s - loss: 0.3599 - val_loss: 0.3520
# Epoch 204/2048
# 1s - loss: 0.3598 - val_loss: 0.3517
# Epoch 205/2048
# 2s - loss: 0.3595 - val_loss: 0.3512
# Epoch 206/2048
# 1s - loss: 0.3594 - val_loss: 0.3515
# Epoch 207/2048
# 1s - loss: 0.3592 - val_loss: 0.3510
# Epoch 208/2048
# 1s - loss: 0.3590 - val_loss: 0.3513
# Epoch 209/2048
# 1s - loss: 0.3588 - val_loss: 0.3507
# Epoch 210/2048
# 1s - loss: 0.3587 - val_loss: 0.3508
# Epoch 211/2048
# 1s - loss: 0.3585 - val_loss: 0.3503
# Epoch 212/2048
# 1s - loss: 0.3583 - val_loss: 0.3506
# Epoch 213/2048
# 1s - loss: 0.3581 - val_loss: 0.3503
# Epoch 214/2048
# 1s - loss: 0.3579 - val_loss: 0.3503
# Epoch 215/2048
# 1s - loss: 0.3577 - val_loss: 0.3501
# Epoch 216/2048
# 2s - loss: 0.3576 - val_loss: 0.3497
# Epoch 217/2048
# 1s - loss: 0.3574 - val_loss: 0.3493
# Epoch 218/2048
# 1s - loss: 0.3572 - val_loss: 0.3492
# Epoch 219/2048
# 2s - loss: 0.3570 - val_loss: 0.3491
# Epoch 220/2048
# 2s - loss: 0.3569 - val_loss: 0.3489
# Epoch 221/2048
# 1s - loss: 0.3567 - val_loss: 0.3488
# Epoch 222/2048
# 1s - loss: 0.3565 - val_loss: 0.3488
# Epoch 223/2048
# 1s - loss: 0.3564 - val_loss: 0.3486
# Epoch 224/2048
# 1s - loss: 0.3562 - val_loss: 0.3484
# Epoch 225/2048
# 2s - loss: 0.3561 - val_loss: 0.3481
# Epoch 226/2048
# 1s - loss: 0.3558 - val_loss: 0.3482
# Epoch 227/2048
# 1s - loss: 0.3557 - val_loss: 0.3477
# Epoch 228/2048
# 1s - loss: 0.3555 - val_loss: 0.3476
# Epoch 229/2048
# 1s - loss: 0.3553 - val_loss: 0.3473
# Epoch 230/2048
# 1s - loss: 0.3551 - val_loss: 0.3473
# Epoch 231/2048
# 1s - loss: 0.3550 - val_loss: 0.3471
# Epoch 232/2048
# 1s - loss: 0.3549 - val_loss: 0.3474
# Epoch 233/2048
# 1s - loss: 0.3547 - val_loss: 0.3469
# Epoch 234/2048
# 1s - loss: 0.3546 - val_loss: 0.3468
# Epoch 235/2048
# 1s - loss: 0.3543 - val_loss: 0.3465
# Epoch 236/2048
# 1s - loss: 0.3541 - val_loss: 0.3467
# Epoch 237/2048
# 1s - loss: 0.3540 - val_loss: 0.3465
# Epoch 238/2048
# 1s - loss: 0.3539 - val_loss: 0.3461
# Epoch 239/2048
# 1s - loss: 0.3537 - val_loss: 0.3461
# Epoch 240/2048
# 1s - loss: 0.3535 - val_loss: 0.3458
# Epoch 241/2048
# 1s - loss: 0.3534 - val_loss: 0.3458
# Epoch 242/2048
# 1s - loss: 0.3532 - val_loss: 0.3456
# Epoch 243/2048
# 1s - loss: 0.3530 - val_loss: 0.3452
# Epoch 244/2048
# 1s - loss: 0.3529 - val_loss: 0.3454
# Epoch 245/2048
# 1s - loss: 0.3527 - val_loss: 0.3450
# Epoch 246/2048
# 1s - loss: 0.3526 - val_loss: 0.3447
# Epoch 247/2048
# 1s - loss: 0.3523 - val_loss: 0.3449
# Epoch 248/2048
# 1s - loss: 0.3522 - val_loss: 0.3444
# Epoch 249/2048
# 1s - loss: 0.3521 - val_loss: 0.3443
# Epoch 250/2048
# 1s - loss: 0.3519 - val_loss: 0.3444
# Epoch 251/2048
# 1s - loss: 0.3517 - val_loss: 0.3440
# Epoch 252/2048
# 1s - loss: 0.3516 - val_loss: 0.3441
# Epoch 253/2048
# 1s - loss: 0.3514 - val_loss: 0.3436
# Epoch 254/2048
# 1s - loss: 0.3513 - val_loss: 0.3437
# Epoch 255/2048
# 1s - loss: 0.3511 - val_loss: 0.3436
# Epoch 256/2048
# 1s - loss: 0.3509 - val_loss: 0.3436
# Epoch 257/2048
# 1s - loss: 0.3509 - val_loss: 0.3433
# Epoch 258/2048
# 1s - loss: 0.3506 - val_loss: 0.3429
# Epoch 259/2048
# 1s - loss: 0.3505 - val_loss: 0.3430
# Epoch 260/2048
# 1s - loss: 0.3503 - val_loss: 0.3432
# Epoch 261/2048
# 1s - loss: 0.3501 - val_loss: 0.3427
# Epoch 262/2048
# 1s - loss: 0.3500 - val_loss: 0.3424
# Epoch 263/2048
# 1s - loss: 0.3499 - val_loss: 0.3426
# Epoch 264/2048
# 1s - loss: 0.3497 - val_loss: 0.3424
# Epoch 265/2048
# 1s - loss: 0.3496 - val_loss: 0.3418
# Epoch 266/2048
# 1s - loss: 0.3494 - val_loss: 0.3419
# Epoch 267/2048
# 1s - loss: 0.3492 - val_loss: 0.3417
# Epoch 268/2048
# 1s - loss: 0.3491 - val_loss: 0.3415
# Epoch 269/2048
# 1s - loss: 0.3489 - val_loss: 0.3415
# Epoch 270/2048
# 1s - loss: 0.3488 - val_loss: 0.3413
# Epoch 271/2048
# 1s - loss: 0.3487 - val_loss: 0.3414
# Epoch 272/2048
# 1s - loss: 0.3485 - val_loss: 0.3412
# Epoch 273/2048
# 1s - loss: 0.3484 - val_loss: 0.3409
# Epoch 274/2048
# 1s - loss: 0.3482 - val_loss: 0.3407
# Epoch 275/2048
# 1s - loss: 0.3481 - val_loss: 0.3405
# Epoch 276/2048
# 1s - loss: 0.3479 - val_loss: 0.3405
# Epoch 277/2048
# 1s - loss: 0.3478 - val_loss: 0.3400
# Epoch 278/2048
# 1s - loss: 0.3476 - val_loss: 0.3402
# Epoch 279/2048
# 1s - loss: 0.3474 - val_loss: 0.3398
# Epoch 280/2048
# 1s - loss: 0.3473 - val_loss: 0.3399
# Epoch 281/2048
# 1s - loss: 0.3472 - val_loss: 0.3395
# Epoch 282/2048
# 1s - loss: 0.3470 - val_loss: 0.3397
# Epoch 283/2048
# 1s - loss: 0.3468 - val_loss: 0.3397
# Epoch 284/2048
# 1s - loss: 0.3467 - val_loss: 0.3393
# Epoch 285/2048
# 1s - loss: 0.3466 - val_loss: 0.3393
# Epoch 286/2048
# 1s - loss: 0.3464 - val_loss: 0.3395
# Epoch 287/2048
# 1s - loss: 0.3463 - val_loss: 0.3386
# Epoch 288/2048
# 1s - loss: 0.3461 - val_loss: 0.3386
# Epoch 289/2048
# 1s - loss: 0.3460 - val_loss: 0.3386
# Epoch 290/2048
# 1s - loss: 0.3458 - val_loss: 0.3386
# Epoch 291/2048
# 1s - loss: 0.3457 - val_loss: 0.3380
# Epoch 292/2048
# 1s - loss: 0.3455 - val_loss: 0.3384
# Epoch 293/2048
# 1s - loss: 0.3454 - val_loss: 0.3379
# Epoch 294/2048
# 1s - loss: 0.3453 - val_loss: 0.3377
# Epoch 295/2048
# 1s - loss: 0.3451 - val_loss: 0.3378
# Epoch 296/2048
# 1s - loss: 0.3450 - val_loss: 0.3378
# Epoch 297/2048
# 1s - loss: 0.3449 - val_loss: 0.3378
# Epoch 298/2048
# 1s - loss: 0.3447 - val_loss: 0.3373
# Epoch 299/2048
# 1s - loss: 0.3445 - val_loss: 0.3375
# Epoch 300/2048
# 1s - loss: 0.3444 - val_loss: 0.3370
# Epoch 301/2048
# 1s - loss: 0.3443 - val_loss: 0.3369
# Epoch 302/2048
# 1s - loss: 0.3441 - val_loss: 0.3367
# Epoch 303/2048
# 1s - loss: 0.3440 - val_loss: 0.3367
# Epoch 304/2048
# 1s - loss: 0.3438 - val_loss: 0.3365
# Epoch 305/2048
# 3s - loss: 0.3437 - val_loss: 0.3363
# Epoch 306/2048
# 1s - loss: 0.3435 - val_loss: 0.3364
# Epoch 307/2048
# 1s - loss: 0.3433 - val_loss: 0.3360
# Epoch 308/2048
# 1s - loss: 0.3432 - val_loss: 0.3360
# Epoch 309/2048
# 1s - loss: 0.3431 - val_loss: 0.3359
# Epoch 310/2048
# 1s - loss: 0.3430 - val_loss: 0.3355
# Epoch 311/2048
# 1s - loss: 0.3428 - val_loss: 0.3358
# Epoch 312/2048
# 1s - loss: 0.3427 - val_loss: 0.3353
# Epoch 313/2048
# 1s - loss: 0.3426 - val_loss: 0.3354
# Epoch 314/2048
# 1s - loss: 0.3423 - val_loss: 0.3352
# Epoch 315/2048
# 1s - loss: 0.3422 - val_loss: 0.3349
# Epoch 316/2048
# 1s - loss: 0.3421 - val_loss: 0.3347
# Epoch 317/2048
# 1s - loss: 0.3420 - val_loss: 0.3346
# Epoch 318/2048
# 1s - loss: 0.3418 - val_loss: 0.3345
# Epoch 319/2048
# 1s - loss: 0.3417 - val_loss: 0.3346
# Epoch 320/2048
# 1s - loss: 0.3415 - val_loss: 0.3344
# Epoch 321/2048
# 1s - loss: 0.3414 - val_loss: 0.3342
# Epoch 322/2048
# 1s - loss: 0.3413 - val_loss: 0.3341
# Epoch 323/2048
# 1s - loss: 0.3411 - val_loss: 0.3338
# Epoch 324/2048
# 3s - loss: 0.3410 - val_loss: 0.3336
# Epoch 325/2048
# 1s - loss: 0.3408 - val_loss: 0.3336
# Epoch 326/2048
# 1s - loss: 0.3407 - val_loss: 0.3335
# Epoch 327/2048
# 1s - loss: 0.3405 - val_loss: 0.3336
# Epoch 328/2048
# 1s - loss: 0.3405 - val_loss: 0.3331
# Epoch 329/2048
# 1s - loss: 0.3403 - val_loss: 0.3331
# Epoch 330/2048
# 1s - loss: 0.3402 - val_loss: 0.3332
# Epoch 331/2048
# 1s - loss: 0.3400 - val_loss: 0.3329
# Epoch 332/2048
# 1s - loss: 0.3399 - val_loss: 0.3325
# Epoch 333/2048
# 1s - loss: 0.3398 - val_loss: 0.3326
# Epoch 334/2048
# 1s - loss: 0.3396 - val_loss: 0.3326
# Epoch 335/2048
# 1s - loss: 0.3394 - val_loss: 0.3321
# Epoch 336/2048
# 1s - loss: 0.3393 - val_loss: 0.3322
# Epoch 337/2048
# 1s - loss: 0.3392 - val_loss: 0.3319
# Epoch 338/2048
# 1s - loss: 0.3391 - val_loss: 0.3319
# Epoch 339/2048
# 1s - loss: 0.3389 - val_loss: 0.3316
# Epoch 340/2048
# 1s - loss: 0.3387 - val_loss: 0.3318
# Epoch 341/2048
# 1s - loss: 0.3387 - val_loss: 0.3313
# Epoch 342/2048
# 1s - loss: 0.3385 - val_loss: 0.3313
# Epoch 343/2048
# 1s - loss: 0.3384 - val_loss: 0.3311
# Epoch 344/2048
# 1s - loss: 0.3382 - val_loss: 0.3309
# Epoch 345/2048
# 1s - loss: 0.3382 - val_loss: 0.3311
# Epoch 346/2048
# 1s - loss: 0.3380 - val_loss: 0.3310
# Epoch 347/2048
# 1s - loss: 0.3379 - val_loss: 0.3307
# Epoch 348/2048
# 1s - loss: 0.3377 - val_loss: 0.3307
# Epoch 349/2048
# 1s - loss: 0.3375 - val_loss: 0.3301
# Epoch 350/2048
# 1s - loss: 0.3374 - val_loss: 0.3304
# Epoch 351/2048
# 1s - loss: 0.3373 - val_loss: 0.3303
# Epoch 352/2048
# 1s - loss: 0.3371 - val_loss: 0.3300
# Epoch 353/2048
# 1s - loss: 0.3370 - val_loss: 0.3300
# Epoch 354/2048
# 1s - loss: 0.3369 - val_loss: 0.3301
# Epoch 355/2048
# 1s - loss: 0.3368 - val_loss: 0.3296
# Epoch 356/2048
# 3s - loss: 0.3366 - val_loss: 0.3295
# Epoch 357/2048
# 3s - loss: 0.3365 - val_loss: 0.3292
# Epoch 358/2048
# 1s - loss: 0.3363 - val_loss: 0.3294
# Epoch 359/2048
# 1s - loss: 0.3362 - val_loss: 0.3291
# Epoch 360/2048
# 2s - loss: 0.3360 - val_loss: 0.3289
# Epoch 361/2048
# 2s - loss: 0.3359 - val_loss: 0.3288
# Epoch 362/2048
# 1s - loss: 0.3357 - val_loss: 0.3288
# Epoch 363/2048
# 2s - loss: 0.3356 - val_loss: 0.3285
# Epoch 364/2048
# 1s - loss: 0.3354 - val_loss: 0.3285
# Epoch 365/2048
# 2s - loss: 0.3353 - val_loss: 0.3283
# Epoch 366/2048
# 1s - loss: 0.3351 - val_loss: 0.3284
# Epoch 367/2048
# 2s - loss: 0.3350 - val_loss: 0.3280
# Epoch 368/2048
# 1s - loss: 0.3348 - val_loss: 0.3277
# Epoch 369/2048
# 3s - loss: 0.3346 - val_loss: 0.3275
# Epoch 370/2048
# 3s - loss: 0.3345 - val_loss: 0.3273
# Epoch 371/2048
# 1s - loss: 0.3344 - val_loss: 0.3273
# Epoch 372/2048
# 1s - loss: 0.3342 - val_loss: 0.3271
# Epoch 373/2048
# 1s - loss: 0.3340 - val_loss: 0.3268
# Epoch 374/2048
# 3s - loss: 0.3339 - val_loss: 0.3264
# Epoch 375/2048
# 1s - loss: 0.3337 - val_loss: 0.3264
# Epoch 376/2048
# 1s - loss: 0.3335 - val_loss: 0.3266
# Epoch 377/2048
# 1s - loss: 0.3333 - val_loss: 0.3262
# Epoch 378/2048
# 1s - loss: 0.3333 - val_loss: 0.3262
# Epoch 379/2048
# 1s - loss: 0.3330 - val_loss: 0.3257
# Epoch 380/2048
# 1s - loss: 0.3328 - val_loss: 0.3257
# Epoch 381/2048
# 1s - loss: 0.3326 - val_loss: 0.3258
# Epoch 382/2048
# 1s - loss: 0.3325 - val_loss: 0.3256
# Epoch 383/2048
# 3s - loss: 0.3323 - val_loss: 0.3252
# Epoch 384/2048
# 2s - loss: 0.3321 - val_loss: 0.3251
# Epoch 385/2048
# 1s - loss: 0.3321 - val_loss: 0.3247
# Epoch 386/2048
# 1s - loss: 0.3318 - val_loss: 0.3249
# Epoch 387/2048
# 1s - loss: 0.3316 - val_loss: 0.3244
# Epoch 388/2048
# 1s - loss: 0.3315 - val_loss: 0.3249
# Epoch 389/2048
# 1s - loss: 0.3313 - val_loss: 0.3240
# Epoch 390/2048
# 1s - loss: 0.3311 - val_loss: 0.3240
# Epoch 391/2048
# 1s - loss: 0.3309 - val_loss: 0.3238
# Epoch 392/2048
# 2s - loss: 0.3307 - val_loss: 0.3238
# Epoch 393/2048
# 1s - loss: 0.3305 - val_loss: 0.3235
# Epoch 394/2048
# 3s - loss: 0.3304 - val_loss: 0.3234
# Epoch 395/2048
# 2s - loss: 0.3302 - val_loss: 0.3232
# Epoch 396/2048
# 1s - loss: 0.3300 - val_loss: 0.3231
# Epoch 397/2048
# 2s - loss: 0.3298 - val_loss: 0.3227
# Epoch 398/2048
# 2s - loss: 0.3296 - val_loss: 0.3226
# Epoch 399/2048
# 2s - loss: 0.3294 - val_loss: 0.3222
# Epoch 400/2048
# 1s - loss: 0.3292 - val_loss: 0.3224
# Epoch 401/2048
# 2s - loss: 0.3289 - val_loss: 0.3218
# Epoch 402/2048
# 1s - loss: 0.3288 - val_loss: 0.3221
# Epoch 403/2048
# 1s - loss: 0.3286 - val_loss: 0.3215
# Epoch 404/2048
# 1s - loss: 0.3283 - val_loss: 0.3211
# Epoch 405/2048
# 1s - loss: 0.3281 - val_loss: 0.3211
# Epoch 406/2048
# 1s - loss: 0.3279 - val_loss: 0.3209
# Epoch 407/2048
# 1s - loss: 0.3277 - val_loss: 0.3210
# Epoch 408/2048
# 1s - loss: 0.3274 - val_loss: 0.3205
# Epoch 409/2048
# 3s - loss: 0.3272 - val_loss: 0.3203
# Epoch 410/2048
# 3s - loss: 0.3269 - val_loss: 0.3199
# Epoch 411/2048
# 2s - loss: 0.3267 - val_loss: 0.3198
# Epoch 412/2048
# 3s - loss: 0.3265 - val_loss: 0.3193
# Epoch 413/2048
# 1s - loss: 0.3263 - val_loss: 0.3194
# Epoch 414/2048
# 1s - loss: 0.3260 - val_loss: 0.3191
# Epoch 415/2048
# 3s - loss: 0.3257 - val_loss: 0.3188
# Epoch 416/2048
# 2s - loss: 0.3255 - val_loss: 0.3183
# Epoch 417/2048
# 3s - loss: 0.3252 - val_loss: 0.3179
# Epoch 418/2048
# 1s - loss: 0.3250 - val_loss: 0.3178
# Epoch 419/2048
# 1s - loss: 0.3247 - val_loss: 0.3180
# Epoch 420/2048
# 1s - loss: 0.3245 - val_loss: 0.3174
# Epoch 421/2048
# 3s - loss: 0.3242 - val_loss: 0.3172
# Epoch 422/2048
# 2s - loss: 0.3240 - val_loss: 0.3171
# Epoch 423/2048
# 1s - loss: 0.3238 - val_loss: 0.3169
# Epoch 424/2048
# 3s - loss: 0.3234 - val_loss: 0.3164
# Epoch 425/2048
# 3s - loss: 0.3232 - val_loss: 0.3159
# Epoch 426/2048
# 2s - loss: 0.3229 - val_loss: 0.3156
# Epoch 427/2048
# 4s - loss: 0.3227 - val_loss: 0.3156
# Epoch 428/2048
# 2s - loss: 0.3224 - val_loss: 0.3152
# Epoch 429/2048
# 3s - loss: 0.3222 - val_loss: 0.3150
# Epoch 430/2048
# 1s - loss: 0.3219 - val_loss: 0.3153
# Epoch 431/2048
# 1s - loss: 0.3216 - val_loss: 0.3145
# Epoch 432/2048
# 3s - loss: 0.3214 - val_loss: 0.3143
# Epoch 433/2048
# 2s - loss: 0.3211 - val_loss: 0.3138
# Epoch 434/2048
# 1s - loss: 0.3208 - val_loss: 0.3140
# Epoch 435/2048
# 1s - loss: 0.3206 - val_loss: 0.3135
# Epoch 436/2048
# 3s - loss: 0.3203 - val_loss: 0.3128
# Epoch 437/2048
# 1s - loss: 0.3200 - val_loss: 0.3129
# Epoch 438/2048
# 1s - loss: 0.3197 - val_loss: 0.3126
# Epoch 439/2048
# 1s - loss: 0.3195 - val_loss: 0.3126
# Epoch 440/2048
# 1s - loss: 0.3193 - val_loss: 0.3125
# Epoch 441/2048
# 1s - loss: 0.3190 - val_loss: 0.3118
# Epoch 442/2048
# 3s - loss: 0.3187 - val_loss: 0.3116
# Epoch 443/2048
# 1s - loss: 0.3185 - val_loss: 0.3114
# Epoch 444/2048
# 3s - loss: 0.3183 - val_loss: 0.3112
# Epoch 445/2048
# 2s - loss: 0.3180 - val_loss: 0.3109
# Epoch 446/2048
# 1s - loss: 0.3178 - val_loss: 0.3106
# Epoch 447/2048
# 1s - loss: 0.3176 - val_loss: 0.3104
# Epoch 448/2048
# 3s - loss: 0.3173 - val_loss: 0.3104
# Epoch 449/2048
# 2s - loss: 0.3171 - val_loss: 0.3098
# Epoch 450/2048
# 1s - loss: 0.3169 - val_loss: 0.3098
# Epoch 451/2048
# 1s - loss: 0.3167 - val_loss: 0.3099
# Epoch 452/2048
# 1s - loss: 0.3165 - val_loss: 0.3093
# Epoch 453/2048
# 1s - loss: 0.3163 - val_loss: 0.3091
# Epoch 454/2048
# 1s - loss: 0.3160 - val_loss: 0.3089
# Epoch 455/2048
# 1s - loss: 0.3159 - val_loss: 0.3089
# Epoch 456/2048
# 2s - loss: 0.3156 - val_loss: 0.3084
# Epoch 457/2048
# 1s - loss: 0.3154 - val_loss: 0.3085
# Epoch 458/2048
# 1s - loss: 0.3152 - val_loss: 0.3080
# Epoch 459/2048
# 1s - loss: 0.3151 - val_loss: 0.3080
# Epoch 460/2048
# 1s - loss: 0.3149 - val_loss: 0.3077
# Epoch 461/2048
# 1s - loss: 0.3147 - val_loss: 0.3075
# Epoch 462/2048
# 1s - loss: 0.3145 - val_loss: 0.3074
# Epoch 463/2048
# 1s - loss: 0.3143 - val_loss: 0.3074
# Epoch 464/2048
# 1s - loss: 0.3141 - val_loss: 0.3068
# Epoch 465/2048
# 1s - loss: 0.3139 - val_loss: 0.3066
# Epoch 466/2048
# 1s - loss: 0.3136 - val_loss: 0.3068
# Epoch 467/2048
# 1s - loss: 0.3134 - val_loss: 0.3064
# Epoch 468/2048
# 1s - loss: 0.3133 - val_loss: 0.3063
# Epoch 469/2048
# 1s - loss: 0.3130 - val_loss: 0.3060
# Epoch 470/2048
# 1s - loss: 0.3128 - val_loss: 0.3054
# Epoch 471/2048
# 1s - loss: 0.3126 - val_loss: 0.3055
# Epoch 472/2048
# 1s - loss: 0.3124 - val_loss: 0.3053
# Epoch 473/2048
# 1s - loss: 0.3121 - val_loss: 0.3051
# Epoch 474/2048
# 2s - loss: 0.3118 - val_loss: 0.3049
# Epoch 475/2048
# 1s - loss: 0.3115 - val_loss: 0.3048
# Epoch 476/2048
# 2s - loss: 0.3114 - val_loss: 0.3045
# Epoch 477/2048
# 3s - loss: 0.3111 - val_loss: 0.3039
# Epoch 478/2048
# 2s - loss: 0.3108 - val_loss: 0.3039
# Epoch 479/2048
# 1s - loss: 0.3106 - val_loss: 0.3036
# Epoch 480/2048
# 1s - loss: 0.3104 - val_loss: 0.3034
# Epoch 481/2048
# 1s - loss: 0.3101 - val_loss: 0.3032
# Epoch 482/2048
# 1s - loss: 0.3100 - val_loss: 0.3027
# Epoch 483/2048
# 1s - loss: 0.3097 - val_loss: 0.3028
# Epoch 484/2048
# 1s - loss: 0.3095 - val_loss: 0.3024
# Epoch 485/2048
# 2s - loss: 0.3093 - val_loss: 0.3021
# Epoch 486/2048
# 1s - loss: 0.3091 - val_loss: 0.3023
# Epoch 487/2048
# 1s - loss: 0.3089 - val_loss: 0.3020
# Epoch 488/2048
# 1s - loss: 0.3087 - val_loss: 0.3018
# Epoch 489/2048
# 1s - loss: 0.3085 - val_loss: 0.3014
# Epoch 490/2048
# 1s - loss: 0.3085 - val_loss: 0.3015
# Epoch 491/2048
# 1s - loss: 0.3081 - val_loss: 0.3016
# Epoch 492/2048
# 1s - loss: 0.3080 - val_loss: 0.3008
# Epoch 493/2048
# 1s - loss: 0.3078 - val_loss: 0.3008
# Epoch 494/2048
# 1s - loss: 0.3076 - val_loss: 0.3005
# Epoch 495/2048
# 1s - loss: 0.3074 - val_loss: 0.3000
# Epoch 496/2048
# 1s - loss: 0.3072 - val_loss: 0.3003
# Epoch 497/2048
# 1s - loss: 0.3070 - val_loss: 0.3002
# Epoch 498/2048
# 1s - loss: 0.3068 - val_loss: 0.2998
# Epoch 499/2048
# 1s - loss: 0.3067 - val_loss: 0.3000
# Epoch 500/2048
# 1s - loss: 0.3065 - val_loss: 0.2993
# Epoch 501/2048
# 2s - loss: 0.3064 - val_loss: 0.2992
# Epoch 502/2048
# 1s - loss: 0.3061 - val_loss: 0.2991
# Epoch 503/2048
# 1s - loss: 0.3060 - val_loss: 0.2989
# Epoch 504/2048
# 1s - loss: 0.3058 - val_loss: 0.2988
# Epoch 505/2048
# 2s - loss: 0.3056 - val_loss: 0.2984
# Epoch 506/2048
# 1s - loss: 0.3054 - val_loss: 0.2985
# Epoch 507/2048
# 3s - loss: 0.3053 - val_loss: 0.2984
# Epoch 508/2048
# 1s - loss: 0.3051 - val_loss: 0.2978
# Epoch 509/2048
# 1s - loss: 0.3049 - val_loss: 0.2979
# Epoch 510/2048
# 1s - loss: 0.3047 - val_loss: 0.2975
# Epoch 511/2048
# 2s - loss: 0.3045 - val_loss: 0.2974
# Epoch 512/2048
# 1s - loss: 0.3043 - val_loss: 0.2973
# Epoch 513/2048
# 1s - loss: 0.3041 - val_loss: 0.2970
# Epoch 514/2048
# 1s - loss: 0.3039 - val_loss: 0.2966
# Epoch 515/2048
# 1s - loss: 0.3037 - val_loss: 0.2967
# Epoch 516/2048
# 1s - loss: 0.3036 - val_loss: 0.2965
# Epoch 517/2048
# 1s - loss: 0.3034 - val_loss: 0.2965
# Epoch 518/2048
# 1s - loss: 0.3032 - val_loss: 0.2962
# Epoch 519/2048
# 1s - loss: 0.3030 - val_loss: 0.2964
# Epoch 520/2048
# 1s - loss: 0.3028 - val_loss: 0.2959
# Epoch 521/2048
# 1s - loss: 0.3026 - val_loss: 0.2956
# Epoch 522/2048
# 1s - loss: 0.3024 - val_loss: 0.2952
# Epoch 523/2048
# 1s - loss: 0.3022 - val_loss: 0.2955
# Epoch 524/2048
# 1s - loss: 0.3020 - val_loss: 0.2953
# Epoch 525/2048
# 1s - loss: 0.3018 - val_loss: 0.2947
# Epoch 526/2048
# 1s - loss: 0.3016 - val_loss: 0.2949
# Epoch 527/2048
# 1s - loss: 0.3014 - val_loss: 0.2945
# Epoch 528/2048
# 1s - loss: 0.3012 - val_loss: 0.2941
# Epoch 529/2048
# 1s - loss: 0.3010 - val_loss: 0.2945
# Epoch 530/2048
# 1s - loss: 0.3009 - val_loss: 0.2939
# Epoch 531/2048
# 1s - loss: 0.3006 - val_loss: 0.2940
# Epoch 532/2048
# 2s - loss: 0.3004 - val_loss: 0.2937
# Epoch 533/2048
# 1s - loss: 0.3002 - val_loss: 0.2935
# Epoch 534/2048
# 1s - loss: 0.3001 - val_loss: 0.2931
# Epoch 535/2048
# 1s - loss: 0.2999 - val_loss: 0.2930
# Epoch 536/2048
# 1s - loss: 0.2997 - val_loss: 0.2929
# Epoch 537/2048
# 1s - loss: 0.2996 - val_loss: 0.2927
# Epoch 538/2048
# 2s - loss: 0.2994 - val_loss: 0.2925
# Epoch 539/2048
# 1s - loss: 0.2992 - val_loss: 0.2923
# Epoch 540/2048
# 2s - loss: 0.2990 - val_loss: 0.2920
# Epoch 541/2048
# 1s - loss: 0.2989 - val_loss: 0.2919
# Epoch 542/2048
# 1s - loss: 0.2987 - val_loss: 0.2920
# Epoch 543/2048
# 1s - loss: 0.2986 - val_loss: 0.2915
# Epoch 544/2048
# 1s - loss: 0.2984 - val_loss: 0.2915
# Epoch 545/2048
# 1s - loss: 0.2982 - val_loss: 0.2913
# Epoch 546/2048
# 1s - loss: 0.2980 - val_loss: 0.2911
# Epoch 547/2048
# 1s - loss: 0.2979 - val_loss: 0.2907
# Epoch 548/2048
# 1s - loss: 0.2977 - val_loss: 0.2910
# Epoch 549/2048
# 1s - loss: 0.2976 - val_loss: 0.2909
# Epoch 550/2048
# 1s - loss: 0.2974 - val_loss: 0.2905
# Epoch 551/2048
# 1s - loss: 0.2973 - val_loss: 0.2904
# Epoch 552/2048
# 1s - loss: 0.2970 - val_loss: 0.2899
# Epoch 553/2048
# 1s - loss: 0.2969 - val_loss: 0.2900
# Epoch 554/2048
# 1s - loss: 0.2967 - val_loss: 0.2898
# Epoch 555/2048
# 1s - loss: 0.2965 - val_loss: 0.2895
# Epoch 556/2048
# 1s - loss: 0.2964 - val_loss: 0.2897
# Epoch 557/2048
# 3s - loss: 0.2962 - val_loss: 0.2893
# Epoch 558/2048
# 1s - loss: 0.2961 - val_loss: 0.2896
# Epoch 559/2048
# 2s - loss: 0.2959 - val_loss: 0.2891
# Epoch 560/2048
# 1s - loss: 0.2957 - val_loss: 0.2891
# Epoch 561/2048
# 1s - loss: 0.2955 - val_loss: 0.2885
# Epoch 562/2048
# 1s - loss: 0.2954 - val_loss: 0.2885
# Epoch 563/2048
# 1s - loss: 0.2952 - val_loss: 0.2884
# Epoch 564/2048
# 1s - loss: 0.2951 - val_loss: 0.2882
# Epoch 565/2048
# 1s - loss: 0.2949 - val_loss: 0.2882
# Epoch 566/2048
# 1s - loss: 0.2947 - val_loss: 0.2876
# Epoch 567/2048
# 1s - loss: 0.2945 - val_loss: 0.2874
# Epoch 568/2048
# 1s - loss: 0.2944 - val_loss: 0.2876
# Epoch 569/2048
# 1s - loss: 0.2942 - val_loss: 0.2875
# Epoch 570/2048
# 1s - loss: 0.2940 - val_loss: 0.2874
# Epoch 571/2048
# 1s - loss: 0.2939 - val_loss: 0.2871
# Epoch 572/2048
# 1s - loss: 0.2937 - val_loss: 0.2872
# Epoch 573/2048
# 1s - loss: 0.2936 - val_loss: 0.2867
# Epoch 574/2048
# 2s - loss: 0.2934 - val_loss: 0.2866
# Epoch 575/2048
# 1s - loss: 0.2932 - val_loss: 0.2864
# Epoch 576/2048
# 3s - loss: 0.2931 - val_loss: 0.2862
# Epoch 577/2048
# 1s - loss: 0.2929 - val_loss: 0.2861
# Epoch 578/2048
# 1s - loss: 0.2927 - val_loss: 0.2863
# Epoch 579/2048
# 2s - loss: 0.2926 - val_loss: 0.2858
# Epoch 580/2048
# 1s - loss: 0.2925 - val_loss: 0.2856
# Epoch 581/2048
# 1s - loss: 0.2923 - val_loss: 0.2854
# Epoch 582/2048
# 1s - loss: 0.2921 - val_loss: 0.2850
# Epoch 583/2048
# 1s - loss: 0.2919 - val_loss: 0.2851
# Epoch 584/2048
# 1s - loss: 0.2918 - val_loss: 0.2849
# Epoch 585/2048
# 1s - loss: 0.2916 - val_loss: 0.2849
# Epoch 586/2048
# 1s - loss: 0.2915 - val_loss: 0.2846
# Epoch 587/2048
# 1s - loss: 0.2914 - val_loss: 0.2841
# Epoch 588/2048
# 1s - loss: 0.2912 - val_loss: 0.2841
# Epoch 589/2048
# 1s - loss: 0.2911 - val_loss: 0.2845
# Epoch 590/2048
# 1s - loss: 0.2909 - val_loss: 0.2841
# Epoch 591/2048
# 1s - loss: 0.2908 - val_loss: 0.2838
# Epoch 592/2048
# 1s - loss: 0.2906 - val_loss: 0.2836
# Epoch 593/2048
# 1s - loss: 0.2905 - val_loss: 0.2834
# Epoch 594/2048
# 1s - loss: 0.2903 - val_loss: 0.2836
# Epoch 595/2048
# 1s - loss: 0.2902 - val_loss: 0.2836
# Epoch 596/2048
# 1s - loss: 0.2901 - val_loss: 0.2833
# Epoch 597/2048
# 1s - loss: 0.2900 - val_loss: 0.2832
# Epoch 598/2048
# 1s - loss: 0.2898 - val_loss: 0.2830
# Epoch 599/2048
# 1s - loss: 0.2898 - val_loss: 0.2831
# Epoch 600/2048
# 1s - loss: 0.2896 - val_loss: 0.2828
# Epoch 601/2048
# 1s - loss: 0.2894 - val_loss: 0.2825
# Epoch 602/2048
# 1s - loss: 0.2893 - val_loss: 0.2823
# Epoch 603/2048
# 1s - loss: 0.2891 - val_loss: 0.2823
# Epoch 604/2048
# 1s - loss: 0.2890 - val_loss: 0.2821
# Epoch 605/2048
# 1s - loss: 0.2888 - val_loss: 0.2821
# Epoch 606/2048
# 1s - loss: 0.2887 - val_loss: 0.2819
# Epoch 607/2048
# 1s - loss: 0.2886 - val_loss: 0.2818
# Epoch 608/2048
# 1s - loss: 0.2885 - val_loss: 0.2819
# Epoch 609/2048
# 1s - loss: 0.2883 - val_loss: 0.2815
# Epoch 610/2048
# 2s - loss: 0.2882 - val_loss: 0.2814
# Epoch 611/2048
# 1s - loss: 0.2881 - val_loss: 0.2816
# Epoch 612/2048
# 1s - loss: 0.2880 - val_loss: 0.2813
# Epoch 613/2048
# 1s - loss: 0.2878 - val_loss: 0.2810
# Epoch 614/2048
# 1s - loss: 0.2877 - val_loss: 0.2809
# Epoch 615/2048
# 1s - loss: 0.2876 - val_loss: 0.2807
# Epoch 616/2048
# 1s - loss: 0.2874 - val_loss: 0.2809
# Epoch 617/2048
# 1s - loss: 0.2874 - val_loss: 0.2806
# Epoch 618/2048
# 1s - loss: 0.2872 - val_loss: 0.2805
# Epoch 619/2048
# 1s - loss: 0.2871 - val_loss: 0.2804
# Epoch 620/2048
# 3s - loss: 0.2870 - val_loss: 0.2803
# Epoch 621/2048
# 1s - loss: 0.2868 - val_loss: 0.2800
# Epoch 622/2048
# 2s - loss: 0.2867 - val_loss: 0.2799
# Epoch 623/2048
# 1s - loss: 0.2866 - val_loss: 0.2801
# Epoch 624/2048
# 3s - loss: 0.2865 - val_loss: 0.2797
# Epoch 625/2048
# 2s - loss: 0.2864 - val_loss: 0.2792
# Epoch 626/2048
# 1s - loss: 0.2863 - val_loss: 0.2793
# Epoch 627/2048
# 1s - loss: 0.2861 - val_loss: 0.2795
# Epoch 628/2048
# 1s - loss: 0.2860 - val_loss: 0.2794
# Epoch 629/2048
# 1s - loss: 0.2859 - val_loss: 0.2791
# Epoch 630/2048
# 1s - loss: 0.2858 - val_loss: 0.2790
# Epoch 631/2048
# 1s - loss: 0.2857 - val_loss: 0.2788
# Epoch 632/2048
# 1s - loss: 0.2855 - val_loss: 0.2790
# Epoch 633/2048
# 1s - loss: 0.2854 - val_loss: 0.2786
# Epoch 634/2048
# 1s - loss: 0.2853 - val_loss: 0.2787
# Epoch 635/2048
# 1s - loss: 0.2852 - val_loss: 0.2783
# Epoch 636/2048
# 1s - loss: 0.2851 - val_loss: 0.2783
# Epoch 637/2048
# 1s - loss: 0.2850 - val_loss: 0.2783
# Epoch 638/2048
# 1s - loss: 0.2848 - val_loss: 0.2784
# Epoch 639/2048
# 1s - loss: 0.2847 - val_loss: 0.2779
# Epoch 640/2048
# 1s - loss: 0.2846 - val_loss: 0.2779
# Epoch 641/2048
# 1s - loss: 0.2845 - val_loss: 0.2778
# Epoch 642/2048
# 1s - loss: 0.2844 - val_loss: 0.2779
# Epoch 643/2048
# 1s - loss: 0.2843 - val_loss: 0.2775
# Epoch 644/2048
# 1s - loss: 0.2842 - val_loss: 0.2774
# Epoch 645/2048
# 1s - loss: 0.2841 - val_loss: 0.2771
# Epoch 646/2048
# 1s - loss: 0.2839 - val_loss: 0.2770
# Epoch 647/2048
# 1s - loss: 0.2838 - val_loss: 0.2772
# Epoch 648/2048
# 1s - loss: 0.2837 - val_loss: 0.2770
# Epoch 649/2048
# 1s - loss: 0.2836 - val_loss: 0.2764
# Epoch 650/2048
# 1s - loss: 0.2834 - val_loss: 0.2769
# Epoch 651/2048
# 1s - loss: 0.2834 - val_loss: 0.2766
# Epoch 652/2048
# 1s - loss: 0.2832 - val_loss: 0.2764
# Epoch 653/2048
# 1s - loss: 0.2831 - val_loss: 0.2763
# Epoch 654/2048
# 1s - loss: 0.2830 - val_loss: 0.2764
# Epoch 655/2048
# 1s - loss: 0.2829 - val_loss: 0.2764
# Epoch 656/2048
# 1s - loss: 0.2828 - val_loss: 0.2760
# Epoch 657/2048
# 1s - loss: 0.2826 - val_loss: 0.2758
# Epoch 658/2048
# 1s - loss: 0.2825 - val_loss: 0.2760
# Epoch 659/2048
# 1s - loss: 0.2824 - val_loss: 0.2756
# Epoch 660/2048
# 1s - loss: 0.2823 - val_loss: 0.2758
# Epoch 661/2048
# 1s - loss: 0.2822 - val_loss: 0.2754
# Epoch 662/2048
# 1s - loss: 0.2821 - val_loss: 0.2757
# Epoch 663/2048
# 1s - loss: 0.2820 - val_loss: 0.2751
# Epoch 664/2048
# 1s - loss: 0.2818 - val_loss: 0.2753
# Epoch 665/2048
# 1s - loss: 0.2818 - val_loss: 0.2751
# Epoch 666/2048
# 1s - loss: 0.2816 - val_loss: 0.2748
# Epoch 667/2048
# 1s - loss: 0.2815 - val_loss: 0.2745
# Epoch 668/2048
# 1s - loss: 0.2814 - val_loss: 0.2747
# Epoch 669/2048
# 1s - loss: 0.2813 - val_loss: 0.2748
# Epoch 670/2048
# 1s - loss: 0.2812 - val_loss: 0.2742
# Epoch 671/2048
# 1s - loss: 0.2810 - val_loss: 0.2744
# Epoch 672/2048
# 2s - loss: 0.2809 - val_loss: 0.2742
# Epoch 673/2048
# 1s - loss: 0.2808 - val_loss: 0.2740
# Epoch 674/2048
# 1s - loss: 0.2807 - val_loss: 0.2739
# Epoch 675/2048
# 1s - loss: 0.2806 - val_loss: 0.2739
# Epoch 676/2048
# 1s - loss: 0.2805 - val_loss: 0.2736
# Epoch 677/2048
# 1s - loss: 0.2804 - val_loss: 0.2738
# Epoch 678/2048
# 1s - loss: 0.2803 - val_loss: 0.2734
# Epoch 679/2048
# 1s - loss: 0.2802 - val_loss: 0.2734
# Epoch 680/2048
# 1s - loss: 0.2800 - val_loss: 0.2733
# Epoch 681/2048
# 1s - loss: 0.2799 - val_loss: 0.2732
# Epoch 682/2048
# 1s - loss: 0.2798 - val_loss: 0.2732
# Epoch 683/2048
# 1s - loss: 0.2797 - val_loss: 0.2730
# Epoch 684/2048
# 1s - loss: 0.2796 - val_loss: 0.2730
# Epoch 685/2048
# 1s - loss: 0.2795 - val_loss: 0.2725
# Epoch 686/2048
# 1s - loss: 0.2794 - val_loss: 0.2727
# Epoch 687/2048
# 1s - loss: 0.2793 - val_loss: 0.2724
# Epoch 688/2048
# 1s - loss: 0.2791 - val_loss: 0.2724
# Epoch 689/2048
# 1s - loss: 0.2791 - val_loss: 0.2724
# Epoch 690/2048
# 1s - loss: 0.2790 - val_loss: 0.2723
# Epoch 691/2048
# 1s - loss: 0.2788 - val_loss: 0.2720
# Epoch 692/2048
# 1s - loss: 0.2788 - val_loss: 0.2720
# Epoch 693/2048
# 1s - loss: 0.2787 - val_loss: 0.2717
# Epoch 694/2048
# 1s - loss: 0.2786 - val_loss: 0.2717
# Epoch 695/2048
# 1s - loss: 0.2785 - val_loss: 0.2719
# Epoch 696/2048
# 1s - loss: 0.2784 - val_loss: 0.2715
# Epoch 697/2048
# 1s - loss: 0.2783 - val_loss: 0.2718
# Epoch 698/2048
# 1s - loss: 0.2781 - val_loss: 0.2712
# Epoch 699/2048
# 1s - loss: 0.2780 - val_loss: 0.2713
# Epoch 700/2048
# 1s - loss: 0.2779 - val_loss: 0.2711
# Epoch 701/2048
# 3s - loss: 0.2778 - val_loss: 0.2711
# Epoch 702/2048
# 1s - loss: 0.2777 - val_loss: 0.2709
# Epoch 703/2048
# 1s - loss: 0.2777 - val_loss: 0.2709
# Epoch 704/2048
# 1s - loss: 0.2775 - val_loss: 0.2709
# Epoch 705/2048
# 1s - loss: 0.2774 - val_loss: 0.2709
# Epoch 706/2048
# 1s - loss: 0.2773 - val_loss: 0.2707
# Epoch 707/2048
# 1s - loss: 0.2772 - val_loss: 0.2707
# Epoch 708/2048
# 1s - loss: 0.2772 - val_loss: 0.2705
# Epoch 709/2048
# 1s - loss: 0.2770 - val_loss: 0.2703
# Epoch 710/2048
# 1s - loss: 0.2769 - val_loss: 0.2704
# Epoch 711/2048
# 1s - loss: 0.2769 - val_loss: 0.2705
# Epoch 712/2048
# 1s - loss: 0.2767 - val_loss: 0.2701
# Epoch 713/2048
# 1s - loss: 0.2766 - val_loss: 0.2699
# Epoch 714/2048
# 1s - loss: 0.2766 - val_loss: 0.2698
# Epoch 715/2048
# 1s - loss: 0.2765 - val_loss: 0.2696
# Epoch 716/2048
# 1s - loss: 0.2764 - val_loss: 0.2695
# Epoch 717/2048
# 1s - loss: 0.2763 - val_loss: 0.2697
# Epoch 718/2048
# 1s - loss: 0.2762 - val_loss: 0.2695
# Epoch 719/2048
# 1s - loss: 0.2761 - val_loss: 0.2696
# Epoch 720/2048
# 1s - loss: 0.2760 - val_loss: 0.2694
# Epoch 721/2048
# 1s - loss: 0.2759 - val_loss: 0.2693
# Epoch 722/2048
# 1s - loss: 0.2758 - val_loss: 0.2694
# Epoch 723/2048
# 1s - loss: 0.2757 - val_loss: 0.2691
# Epoch 724/2048
# 1s - loss: 0.2756 - val_loss: 0.2688
# Epoch 725/2048
# 1s - loss: 0.2756 - val_loss: 0.2691
# Epoch 726/2048
# 1s - loss: 0.2755 - val_loss: 0.2689
# Epoch 727/2048
# 1s - loss: 0.2754 - val_loss: 0.2684
# Epoch 728/2048
# 1s - loss: 0.2753 - val_loss: 0.2689
# Epoch 729/2048
# 1s - loss: 0.2753 - val_loss: 0.2688
# Epoch 730/2048
# 1s - loss: 0.2751 - val_loss: 0.2686
# Epoch 731/2048
# 1s - loss: 0.2750 - val_loss: 0.2684
# Epoch 732/2048
# 1s - loss: 0.2750 - val_loss: 0.2682
# Epoch 733/2048
# 1s - loss: 0.2749 - val_loss: 0.2679
# Epoch 734/2048
# 1s - loss: 0.2748 - val_loss: 0.2683
# Epoch 735/2048
# 1s - loss: 0.2747 - val_loss: 0.2680
# Epoch 736/2048
# 1s - loss: 0.2746 - val_loss: 0.2679
# Epoch 737/2048
# 1s - loss: 0.2745 - val_loss: 0.2682
# Epoch 738/2048
# 1s - loss: 0.2745 - val_loss: 0.2680
# Epoch 739/2048
# 1s - loss: 0.2744 - val_loss: 0.2675
# Epoch 740/2048
# 1s - loss: 0.2742 - val_loss: 0.2676
# Epoch 741/2048
# 1s - loss: 0.2742 - val_loss: 0.2679
# Epoch 742/2048
# 1s - loss: 0.2741 - val_loss: 0.2676
# Epoch 743/2048
# 1s - loss: 0.2740 - val_loss: 0.2673
# Epoch 744/2048
# 1s - loss: 0.2739 - val_loss: 0.2673
# Epoch 745/2048
# 1s - loss: 0.2738 - val_loss: 0.2672
# Epoch 746/2048
# 1s - loss: 0.2738 - val_loss: 0.2671
# Epoch 747/2048
# 1s - loss: 0.2737 - val_loss: 0.2674
# Epoch 748/2048
# 1s - loss: 0.2737 - val_loss: 0.2670
# Epoch 749/2048
# 1s - loss: 0.2736 - val_loss: 0.2669
# Epoch 750/2048
# 1s - loss: 0.2735 - val_loss: 0.2669
# Epoch 751/2048
# 1s - loss: 0.2734 - val_loss: 0.2669
# Epoch 752/2048
# 1s - loss: 0.2733 - val_loss: 0.2665
# Epoch 753/2048
# 1s - loss: 0.2732 - val_loss: 0.2664
# Epoch 754/2048
# 1s - loss: 0.2732 - val_loss: 0.2665
# Epoch 755/2048
# 1s - loss: 0.2731 - val_loss: 0.2667
# Epoch 756/2048
# 1s - loss: 0.2730 - val_loss: 0.2665
# Epoch 757/2048
# 1s - loss: 0.2729 - val_loss: 0.2663
# Epoch 758/2048
# 2s - loss: 0.2729 - val_loss: 0.2661
# Epoch 759/2048
# 1s - loss: 0.2728 - val_loss: 0.2658
# Epoch 760/2048
# 1s - loss: 0.2727 - val_loss: 0.2660
# Epoch 761/2048
# 1s - loss: 0.2726 - val_loss: 0.2659
# Epoch 762/2048
# 1s - loss: 0.2726 - val_loss: 0.2658
# Epoch 763/2048
# 1s - loss: 0.2726 - val_loss: 0.2659
# Epoch 764/2048
# 1s - loss: 0.2724 - val_loss: 0.2656
# Epoch 765/2048
# 1s - loss: 0.2724 - val_loss: 0.2656
# Epoch 766/2048
# 1s - loss: 0.2723 - val_loss: 0.2657
# Epoch 767/2048
# 1s - loss: 0.2722 - val_loss: 0.2657
# Epoch 768/2048
# 1s - loss: 0.2722 - val_loss: 0.2653
# Epoch 769/2048
# 1s - loss: 0.2721 - val_loss: 0.2658
# Epoch 770/2048
# 1s - loss: 0.2720 - val_loss: 0.2653
# Epoch 771/2048
# 1s - loss: 0.2720 - val_loss: 0.2658
# Epoch 772/2048
# 1s - loss: 0.2719 - val_loss: 0.2655
# Epoch 773/2048
# 1s - loss: 0.2718 - val_loss: 0.2653
# Epoch 774/2048
# 1s - loss: 0.2717 - val_loss: 0.2652
# Epoch 775/2048
# 1s - loss: 0.2717 - val_loss: 0.2651
# Epoch 776/2048
# 2s - loss: 0.2716 - val_loss: 0.2650
# Epoch 777/2048
# 1s - loss: 0.2716 - val_loss: 0.2651
# Epoch 778/2048
# 1s - loss: 0.2715 - val_loss: 0.2649
# Epoch 779/2048
# 3s - loss: 0.2714 - val_loss: 0.2645
# Epoch 780/2048
# 1s - loss: 0.2713 - val_loss: 0.2648
# Epoch 781/2048
# 1s - loss: 0.2713 - val_loss: 0.2646
# Epoch 782/2048
# 1s - loss: 0.2712 - val_loss: 0.2646
# Epoch 783/2048
# 1s - loss: 0.2711 - val_loss: 0.2644
# Epoch 784/2048
# 1s - loss: 0.2711 - val_loss: 0.2645
# Epoch 785/2048
# 1s - loss: 0.2710 - val_loss: 0.2643
# Epoch 786/2048
# 1s - loss: 0.2709 - val_loss: 0.2644
# Epoch 787/2048
# 1s - loss: 0.2708 - val_loss: 0.2644
# Epoch 788/2048
# 1s - loss: 0.2708 - val_loss: 0.2641
# Epoch 789/2048
# 1s - loss: 0.2708 - val_loss: 0.2644
# Epoch 790/2048
# 1s - loss: 0.2706 - val_loss: 0.2643
# Epoch 791/2048
# 1s - loss: 0.2706 - val_loss: 0.2640
# Epoch 792/2048
# 1s - loss: 0.2705 - val_loss: 0.2641
# Epoch 793/2048
# 1s - loss: 0.2705 - val_loss: 0.2640
# Epoch 794/2048
# 1s - loss: 0.2704 - val_loss: 0.2638
# Epoch 795/2048
# 1s - loss: 0.2703 - val_loss: 0.2641
# Epoch 796/2048
# 1s - loss: 0.2703 - val_loss: 0.2638
# Epoch 797/2048
# 1s - loss: 0.2703 - val_loss: 0.2638
# Epoch 798/2048
# 1s - loss: 0.2702 - val_loss: 0.2639
# Epoch 799/2048
# 1s - loss: 0.2701 - val_loss: 0.2635
# Epoch 800/2048
# 2s - loss: 0.2700 - val_loss: 0.2635
# Epoch 801/2048
# 1s - loss: 0.2699 - val_loss: 0.2633
# Epoch 802/2048
# 1s - loss: 0.2700 - val_loss: 0.2633
# Epoch 803/2048
# 1s - loss: 0.2698 - val_loss: 0.2636
# Epoch 804/2048
# 1s - loss: 0.2698 - val_loss: 0.2631
# Epoch 805/2048
# 1s - loss: 0.2697 - val_loss: 0.2632
# Epoch 806/2048
# 1s - loss: 0.2697 - val_loss: 0.2633
# Epoch 807/2048
# 1s - loss: 0.2696 - val_loss: 0.2629
# Epoch 808/2048
# 1s - loss: 0.2695 - val_loss: 0.2631
# Epoch 809/2048
# 1s - loss: 0.2695 - val_loss: 0.2631
# Epoch 810/2048
# 1s - loss: 0.2694 - val_loss: 0.2627
# Epoch 811/2048
# 1s - loss: 0.2693 - val_loss: 0.2626
# Epoch 812/2048
# 1s - loss: 0.2693 - val_loss: 0.2625
# Epoch 813/2048
# 1s - loss: 0.2692 - val_loss: 0.2625
# Epoch 814/2048
# 1s - loss: 0.2692 - val_loss: 0.2624
# Epoch 815/2048
# 1s - loss: 0.2691 - val_loss: 0.2626
# Epoch 816/2048
# 1s - loss: 0.2690 - val_loss: 0.2627
# Epoch 817/2048
# 1s - loss: 0.2690 - val_loss: 0.2626
# Epoch 818/2048
# 1s - loss: 0.2689 - val_loss: 0.2627
# Epoch 819/2048
# 1s - loss: 0.2688 - val_loss: 0.2625
# Epoch 820/2048
# 1s - loss: 0.2688 - val_loss: 0.2621
# Epoch 821/2048
# 1s - loss: 0.2688 - val_loss: 0.2621
# Epoch 822/2048
# 1s - loss: 0.2687 - val_loss: 0.2621
# Epoch 823/2048
# 1s - loss: 0.2686 - val_loss: 0.2620
# Epoch 824/2048
# 1s - loss: 0.2686 - val_loss: 0.2617
# Epoch 825/2048
# 1s - loss: 0.2685 - val_loss: 0.2619
# Epoch 826/2048
# 1s - loss: 0.2684 - val_loss: 0.2619
# Epoch 827/2048
# 1s - loss: 0.2684 - val_loss: 0.2616
# Epoch 828/2048
# 1s - loss: 0.2683 - val_loss: 0.2616
# Epoch 829/2048
# 1s - loss: 0.2682 - val_loss: 0.2619
# Epoch 830/2048
# 1s - loss: 0.2682 - val_loss: 0.2621
# Epoch 831/2048
# 1s - loss: 0.2681 - val_loss: 0.2618
# Epoch 832/2048
# 1s - loss: 0.2681 - val_loss: 0.2617
# Epoch 833/2048
# 1s - loss: 0.2680 - val_loss: 0.2618
# Epoch 834/2048
# 1s - loss: 0.2680 - val_loss: 0.2616
# Epoch 835/2048
# 1s - loss: 0.2680 - val_loss: 0.2618
# Epoch 836/2048
# 1s - loss: 0.2678 - val_loss: 0.2615
# Epoch 837/2048
# 1s - loss: 0.2678 - val_loss: 0.2613
# Epoch 838/2048
# 1s - loss: 0.2677 - val_loss: 0.2615
# Epoch 839/2048
# 1s - loss: 0.2677 - val_loss: 0.2612
# Epoch 840/2048
# 1s - loss: 0.2676 - val_loss: 0.2614
# Epoch 841/2048
# 1s - loss: 0.2676 - val_loss: 0.2613
# Epoch 842/2048
# 1s - loss: 0.2675 - val_loss: 0.2610
# Epoch 843/2048
# 2s - loss: 0.2674 - val_loss: 0.2608
# Epoch 844/2048
# 1s - loss: 0.2674 - val_loss: 0.2610
# Epoch 845/2048
# 1s - loss: 0.2673 - val_loss: 0.2608
# Epoch 846/2048
# 1s - loss: 0.2672 - val_loss: 0.2608
# Epoch 847/2048
# 1s - loss: 0.2672 - val_loss: 0.2608
# Epoch 848/2048
# 1s - loss: 0.2671 - val_loss: 0.2605
# Epoch 849/2048
# 1s - loss: 0.2671 - val_loss: 0.2607
# Epoch 850/2048
# 1s - loss: 0.2670 - val_loss: 0.2605
# Epoch 851/2048
# 1s - loss: 0.2670 - val_loss: 0.2606
# Epoch 852/2048
# 1s - loss: 0.2670 - val_loss: 0.2609
# Epoch 853/2048
# 1s - loss: 0.2669 - val_loss: 0.2605
# Epoch 854/2048
# 1s - loss: 0.2668 - val_loss: 0.2604
# Epoch 855/2048
# 3s - loss: 0.2667 - val_loss: 0.2601
# Epoch 856/2048
# 1s - loss: 0.2667 - val_loss: 0.2602
# Epoch 857/2048
# 1s - loss: 0.2667 - val_loss: 0.2601
# Epoch 858/2048
# 1s - loss: 0.2666 - val_loss: 0.2602
# Epoch 859/2048
# 1s - loss: 0.2665 - val_loss: 0.2603
# Epoch 860/2048
# 1s - loss: 0.2665 - val_loss: 0.2599
# Epoch 861/2048
# 1s - loss: 0.2664 - val_loss: 0.2601
# Epoch 862/2048
# 1s - loss: 0.2664 - val_loss: 0.2601
# Epoch 863/2048
# 1s - loss: 0.2664 - val_loss: 0.2601
# Epoch 864/2048
# 1s - loss: 0.2664 - val_loss: 0.2598
# Epoch 865/2048
# 1s - loss: 0.2662 - val_loss: 0.2598
# Epoch 866/2048
# 1s - loss: 0.2662 - val_loss: 0.2597
# Epoch 867/2048
# 2s - loss: 0.2661 - val_loss: 0.2597
# Epoch 868/2048
# 1s - loss: 0.2661 - val_loss: 0.2597
# Epoch 869/2048
# 1s - loss: 0.2660 - val_loss: 0.2599
# Epoch 870/2048
# 1s - loss: 0.2660 - val_loss: 0.2595
# Epoch 871/2048
# 2s - loss: 0.2659 - val_loss: 0.2593
# Epoch 872/2048
# 1s - loss: 0.2659 - val_loss: 0.2593
# Epoch 873/2048
# 1s - loss: 0.2658 - val_loss: 0.2594
# Epoch 874/2048
# 1s - loss: 0.2658 - val_loss: 0.2592
# Epoch 875/2048
# 1s - loss: 0.2657 - val_loss: 0.2594
# Epoch 876/2048
# 1s - loss: 0.2657 - val_loss: 0.2593
# Epoch 877/2048
# 1s - loss: 0.2656 - val_loss: 0.2592
# Epoch 878/2048
# 1s - loss: 0.2655 - val_loss: 0.2591
# Epoch 879/2048
# 1s - loss: 0.2655 - val_loss: 0.2591
# Epoch 880/2048
# 1s - loss: 0.2655 - val_loss: 0.2590
# Epoch 881/2048
# 1s - loss: 0.2654 - val_loss: 0.2588
# Epoch 882/2048
# 1s - loss: 0.2653 - val_loss: 0.2590
# Epoch 883/2048
# 1s - loss: 0.2653 - val_loss: 0.2587
# Epoch 884/2048
# 1s - loss: 0.2652 - val_loss: 0.2588
# Epoch 885/2048
# 1s - loss: 0.2652 - val_loss: 0.2586
# Epoch 886/2048
# 1s - loss: 0.2651 - val_loss: 0.2589
# Epoch 887/2048
# 1s - loss: 0.2651 - val_loss: 0.2584
# Epoch 888/2048
# 1s - loss: 0.2650 - val_loss: 0.2587
# Epoch 889/2048
# 1s - loss: 0.2650 - val_loss: 0.2589
# Epoch 890/2048
# 1s - loss: 0.2649 - val_loss: 0.2583
# Epoch 891/2048
# 1s - loss: 0.2649 - val_loss: 0.2586
# Epoch 892/2048
# 1s - loss: 0.2648 - val_loss: 0.2581
# Epoch 893/2048
# 1s - loss: 0.2647 - val_loss: 0.2583
# Epoch 894/2048
# 1s - loss: 0.2647 - val_loss: 0.2584
# Epoch 895/2048
# 1s - loss: 0.2647 - val_loss: 0.2583
# Epoch 896/2048
# 1s - loss: 0.2646 - val_loss: 0.2579
# Epoch 897/2048
# 1s - loss: 0.2646 - val_loss: 0.2581
# Epoch 898/2048
# 1s - loss: 0.2645 - val_loss: 0.2579
# Epoch 899/2048
# 1s - loss: 0.2645 - val_loss: 0.2576
# Epoch 900/2048
# 1s - loss: 0.2644 - val_loss: 0.2579
# Epoch 901/2048
# 1s - loss: 0.2643 - val_loss: 0.2580
# Epoch 902/2048
# 1s - loss: 0.2643 - val_loss: 0.2579
# Epoch 903/2048
# 1s - loss: 0.2643 - val_loss: 0.2579
# Epoch 904/2048
# 1s - loss: 0.2642 - val_loss: 0.2579
# Epoch 905/2048
# 1s - loss: 0.2641 - val_loss: 0.2579
# Epoch 906/2048
# 1s - loss: 0.2641 - val_loss: 0.2579
# Epoch 907/2048
# 1s - loss: 0.2640 - val_loss: 0.2575
# Epoch 908/2048
# 1s - loss: 0.2640 - val_loss: 0.2578
# Epoch 909/2048
# 1s - loss: 0.2639 - val_loss: 0.2576
# Epoch 910/2048
# 1s - loss: 0.2639 - val_loss: 0.2576
# Epoch 911/2048
# 1s - loss: 0.2638 - val_loss: 0.2574
# Epoch 912/2048
# 3s - loss: 0.2638 - val_loss: 0.2572
# Epoch 913/2048
# 1s - loss: 0.2637 - val_loss: 0.2573
# Epoch 914/2048
# 1s - loss: 0.2637 - val_loss: 0.2574
# Epoch 915/2048
# 1s - loss: 0.2636 - val_loss: 0.2572
# Epoch 916/2048
# 1s - loss: 0.2636 - val_loss: 0.2574
# Epoch 917/2048
# 1s - loss: 0.2635 - val_loss: 0.2573
# Epoch 918/2048
# 1s - loss: 0.2635 - val_loss: 0.2572
# Epoch 919/2048
# 1s - loss: 0.2635 - val_loss: 0.2570
# Epoch 920/2048
# 1s - loss: 0.2634 - val_loss: 0.2569
# Epoch 921/2048
# 1s - loss: 0.2633 - val_loss: 0.2568
# Epoch 922/2048
# 1s - loss: 0.2633 - val_loss: 0.2570
# Epoch 923/2048
# 1s - loss: 0.2633 - val_loss: 0.2567
# Epoch 924/2048
# ...
# 1s - loss: 0.2361 - val_loss: 0.2308
# Epoch 1748/2048
# 1s - loss: 0.2359 - val_loss: 0.2306
# Epoch 1749/2048
# 1s - loss: 0.2358 - val_loss: 0.2308
# Epoch 1750/2048
# 1s - loss: 0.2358 - val_loss: 0.2307
# Epoch 1751/2048
# 1s - loss: 0.2359 - val_loss: 0.2309
# Epoch 1752/2048
# 1s - loss: 0.2358 - val_loss: 0.2308
# Epoch 1753/2048
# 1s - loss: 0.2358 - val_loss: 0.2307
# Epoch 1754/2048
# 1s - loss: 0.2358 - val_loss: 0.2304
# Epoch 1755/2048
# 1s - loss: 0.2358 - val_loss: 0.2305
# Epoch 1756/2048
# 1s - loss: 0.2357 - val_loss: 0.2305
# Epoch 1757/2048
# 1s - loss: 0.2357 - val_loss: 0.2306
# Epoch 1758/2048
# 1s - loss: 0.2357 - val_loss: 0.2305
# Epoch 1759/2048
# 1s - loss: 0.2357 - val_loss: 0.2303
# Epoch 1760/2048
# 1s - loss: 0.2357 - val_loss: 0.2306
# Epoch 1761/2048
# 1s - loss: 0.2356 - val_loss: 0.2304
# Epoch 1762/2048
# 1s - loss: 0.2356 - val_loss: 0.2306
# Epoch 1763/2048
# 1s - loss: 0.2356 - val_loss: 0.2305
# Epoch 1764/2048
# 1s - loss: 0.2356 - val_loss: 0.2300
# Epoch 1765/2048
# 1s - loss: 0.2356 - val_loss: 0.2307
# Epoch 1766/2048
# 1s - loss: 0.2356 - val_loss: 0.2302
# Epoch 1767/2048
# 1s - loss: 0.2355 - val_loss: 0.2304
# Epoch 1768/2048
# 1s - loss: 0.2355 - val_loss: 0.2304
# Epoch 1769/2048
# 1s - loss: 0.2355 - val_loss: 0.2303
# Epoch 1770/2048
# 1s - loss: 0.2355 - val_loss: 0.2306
# Epoch 1771/2048
# 1s - loss: 0.2355 - val_loss: 0.2304
# Epoch 1772/2048
# 1s - loss: 0.2355 - val_loss: 0.2301
# Epoch 1773/2048
# 1s - loss: 0.2354 - val_loss: 0.2300
# Epoch 1774/2048
# 1s - loss: 0.2354 - val_loss: 0.2299
# Epoch 1775/2048
# 1s - loss: 0.2354 - val_loss: 0.2303
# Epoch 1776/2048
# 1s - loss: 0.2354 - val_loss: 0.2304
# Epoch 1777/2048
# 1s - loss: 0.2353 - val_loss: 0.2303
# Epoch 1778/2048
# 1s - loss: 0.2353 - val_loss: 0.2301
# Epoch 1779/2048
# 1s - loss: 0.2353 - val_loss: 0.2299
# Epoch 1780/2048
# 1s - loss: 0.2353 - val_loss: 0.2300
# Epoch 1781/2048
# 1s - loss: 0.2353 - val_loss: 0.2300
# Epoch 1782/2048
# 1s - loss: 0.2352 - val_loss: 0.2300
# Epoch 1783/2048
# 1s - loss: 0.2353 - val_loss: 0.2301
# Epoch 1784/2048
# 1s - loss: 0.2352 - val_loss: 0.2302
# Epoch 1785/2048
# 1s - loss: 0.2352 - val_loss: 0.2299
# Epoch 1786/2048
# 1s - loss: 0.2352 - val_loss: 0.2300
# Epoch 1787/2048
# 1s - loss: 0.2352 - val_loss: 0.2299
# Epoch 1788/2048
# 1s - loss: 0.2352 - val_loss: 0.2299
# Epoch 1789/2048
# 1s - loss: 0.2351 - val_loss: 0.2299
# Epoch 1790/2048
# 1s - loss: 0.2351 - val_loss: 0.2296
# Epoch 1791/2048
# 1s - loss: 0.2351 - val_loss: 0.2298
# Epoch 1792/2048
# 1s - loss: 0.2351 - val_loss: 0.2301
# Epoch 1793/2048
# 1s - loss: 0.2351 - val_loss: 0.2297
# Epoch 1794/2048
# 1s - loss: 0.2351 - val_loss: 0.2299
# Epoch 1795/2048
# 1s - loss: 0.2351 - val_loss: 0.2299
# Epoch 1796/2048
# 1s - loss: 0.2350 - val_loss: 0.2299
# Epoch 1797/2048
# 1s - loss: 0.2350 - val_loss: 0.2302
# Epoch 1798/2048
# 1s - loss: 0.2350 - val_loss: 0.2298
# Epoch 1799/2048
# 1s - loss: 0.2350 - val_loss: 0.2297
# Epoch 1800/2048
# 1s - loss: 0.2350 - val_loss: 0.2299
# Epoch 1801/2048
# 1s - loss: 0.2349 - val_loss: 0.2298
# Epoch 1802/2048
# 1s - loss: 0.2349 - val_loss: 0.2300
# Epoch 1803/2048
# 1s - loss: 0.2349 - val_loss: 0.2298
# Epoch 1804/2048
# 1s - loss: 0.2349 - val_loss: 0.2297
# Epoch 1805/2048
# 1s - loss: 0.2349 - val_loss: 0.2301
# Epoch 1806/2048
# 1s - loss: 0.2348 - val_loss: 0.2298
# Epoch 1807/2048
# 1s - loss: 0.2348 - val_loss: 0.2298
# Epoch 1808/2048
# 1s - loss: 0.2348 - val_loss: 0.2295
# Epoch 1809/2048
# 1s - loss: 0.2348 - val_loss: 0.2295
# Epoch 1810/2048
# 1s - loss: 0.2348 - val_loss: 0.2298
# Epoch 1811/2048
# 1s - loss: 0.2347 - val_loss: 0.2296
# Epoch 1812/2048
# 1s - loss: 0.2347 - val_loss: 0.2297
# Epoch 1813/2048
# 1s - loss: 0.2347 - val_loss: 0.2297
# Epoch 1814/2048
# 1s - loss: 0.2347 - val_loss: 0.2297
# Epoch 1815/2048
# 1s - loss: 0.2347 - val_loss: 0.2296
# Epoch 1816/2048
# 1s - loss: 0.2347 - val_loss: 0.2298
# Epoch 1817/2048
# 1s - loss: 0.2346 - val_loss: 0.2296
# Epoch 1818/2048
# 1s - loss: 0.2347 - val_loss: 0.2294
# Epoch 1819/2048
# 1s - loss: 0.2346 - val_loss: 0.2296
# Epoch 1820/2048
# 1s - loss: 0.2346 - val_loss: 0.2294
# Epoch 1821/2048
# 1s - loss: 0.2346 - val_loss: 0.2297
# Epoch 1822/2048
# 1s - loss: 0.2345 - val_loss: 0.2294
# Epoch 1823/2048
# 1s - loss: 0.2345 - val_loss: 0.2295
# Epoch 1824/2048
# 1s - loss: 0.2345 - val_loss: 0.2295
# Epoch 1825/2048
# 1s - loss: 0.2345 - val_loss: 0.2294
# Epoch 1826/2048
# 1s - loss: 0.2345 - val_loss: 0.2293
# Epoch 1827/2048
# 1s - loss: 0.2344 - val_loss: 0.2296
# Epoch 1828/2048
# 1s - loss: 0.2345 - val_loss: 0.2293
# Epoch 1829/2048
# 1s - loss: 0.2345 - val_loss: 0.2294
# Epoch 1830/2048
# 1s - loss: 0.2345 - val_loss: 0.2295
# Epoch 1831/2048
# 1s - loss: 0.2344 - val_loss: 0.2293
# Epoch 1832/2048
# 1s - loss: 0.2344 - val_loss: 0.2292
# Epoch 1833/2048
# 1s - loss: 0.2343 - val_loss: 0.2292
# Epoch 1834/2048
# 1s - loss: 0.2344 - val_loss: 0.2290
# Epoch 1835/2048
# 1s - loss: 0.2343 - val_loss: 0.2293
# Epoch 1836/2048
# 1s - loss: 0.2343 - val_loss: 0.2296
# Epoch 1837/2048
# 1s - loss: 0.2343 - val_loss: 0.2292
# Epoch 1838/2048
# 1s - loss: 0.2343 - val_loss: 0.2289
# Epoch 1839/2048
# 1s - loss: 0.2343 - val_loss: 0.2292
# Epoch 1840/2048
# 1s - loss: 0.2343 - val_loss: 0.2291
# Epoch 1841/2048
# 1s - loss: 0.2342 - val_loss: 0.2291
# Epoch 1842/2048
# 1s - loss: 0.2342 - val_loss: 0.2294
# Epoch 1843/2048
# 1s - loss: 0.2342 - val_loss: 0.2289
# Epoch 1844/2048
# 1s - loss: 0.2342 - val_loss: 0.2291
# Epoch 1845/2048
# 1s - loss: 0.2342 - val_loss: 0.2290
# Epoch 1846/2048
# 1s - loss: 0.2342 - val_loss: 0.2291
# Epoch 1847/2048
# 1s - loss: 0.2342 - val_loss: 0.2290
# Epoch 1848/2048
# 1s - loss: 0.2341 - val_loss: 0.2289
# Epoch 1849/2048
# 1s - loss: 0.2341 - val_loss: 0.2289
# Epoch 1850/2048
# 1s - loss: 0.2341 - val_loss: 0.2289
# Epoch 1851/2048
# 1s - loss: 0.2341 - val_loss: 0.2293
# Epoch 1852/2048
# 1s - loss: 0.2341 - val_loss: 0.2290
# Epoch 1853/2048
# 1s - loss: 0.2340 - val_loss: 0.2290
# Epoch 1854/2048
# 1s - loss: 0.2340 - val_loss: 0.2289
# Epoch 1855/2048
# 1s - loss: 0.2340 - val_loss: 0.2291
# Epoch 1856/2048
# 1s - loss: 0.2340 - val_loss: 0.2287
# Epoch 1857/2048
# 1s - loss: 0.2340 - val_loss: 0.2290
# Epoch 1858/2048
# 1s - loss: 0.2340 - val_loss: 0.2290
# Epoch 1859/2048
# 1s - loss: 0.2339 - val_loss: 0.2289
# Epoch 1860/2048
# 1s - loss: 0.2339 - val_loss: 0.2287
# Epoch 1861/2048
# 1s - loss: 0.2340 - val_loss: 0.2288
# Epoch 1862/2048
# 1s - loss: 0.2339 - val_loss: 0.2288
# Epoch 1863/2048
# 1s - loss: 0.2339 - val_loss: 0.2288
# Epoch 1864/2048
# 1s - loss: 0.2339 - val_loss: 0.2290
# Epoch 1865/2048
# 1s - loss: 0.2338 - val_loss: 0.2288
# Epoch 1866/2048
# 1s - loss: 0.2338 - val_loss: 0.2289
# Epoch 1867/2048
# 1s - loss: 0.2338 - val_loss: 0.2287
# Epoch 1868/2048
# 1s - loss: 0.2339 - val_loss: 0.2287
# Epoch 1869/2048
# 1s - loss: 0.2338 - val_loss: 0.2288
# Epoch 1870/2048
# 1s - loss: 0.2337 - val_loss: 0.2289
# Epoch 1871/2048
# 1s - loss: 0.2338 - val_loss: 0.2289
# Epoch 1872/2048
# 1s - loss: 0.2338 - val_loss: 0.2292
# Epoch 1873/2048
# 1s - loss: 0.2337 - val_loss: 0.2285
# Epoch 1874/2048
# 1s - loss: 0.2337 - val_loss: 0.2289
# Epoch 1875/2048
# 1s - loss: 0.2337 - val_loss: 0.2286
# Epoch 1876/2048
# 1s - loss: 0.2337 - val_loss: 0.2287
# Epoch 1877/2048
# 1s - loss: 0.2336 - val_loss: 0.2286
# Epoch 1878/2048
# 1s - loss: 0.2336 - val_loss: 0.2287
# Epoch 1879/2048
# 1s - loss: 0.2336 - val_loss: 0.2285
# Epoch 1880/2048
# 1s - loss: 0.2336 - val_loss: 0.2285
# Epoch 1881/2048
# 1s - loss: 0.2336 - val_loss: 0.2288
# Epoch 1882/2048
# 1s - loss: 0.2335 - val_loss: 0.2285
# Epoch 1883/2048
# 1s - loss: 0.2336 - val_loss: 0.2286
# Epoch 1884/2048
# 1s - loss: 0.2336 - val_loss: 0.2285
# Epoch 1885/2048
# 1s - loss: 0.2335 - val_loss: 0.2287
# Epoch 1886/2048
# 1s - loss: 0.2335 - val_loss: 0.2284
# Epoch 1887/2048
# 1s - loss: 0.2335 - val_loss: 0.2286
# Epoch 1888/2048
# 1s - loss: 0.2334 - val_loss: 0.2284
# Epoch 1889/2048
# 1s - loss: 0.2335 - val_loss: 0.2283
# Epoch 1890/2048
# 1s - loss: 0.2335 - val_loss: 0.2284
# Epoch 1891/2048
# 1s - loss: 0.2334 - val_loss: 0.2286
# Epoch 1892/2048
# 1s - loss: 0.2334 - val_loss: 0.2284
# Epoch 1893/2048
# 1s - loss: 0.2334 - val_loss: 0.2283
# Epoch 1894/2048
# 1s - loss: 0.2334 - val_loss: 0.2285
# Epoch 1895/2048
# 3s - loss: 0.2334 - val_loss: 0.2282
# Epoch 1896/2048
# 1s - loss: 0.2334 - val_loss: 0.2284
# Epoch 1897/2048
# 1s - loss: 0.2333 - val_loss: 0.2287
# Epoch 1898/2048
# 1s - loss: 0.2333 - val_loss: 0.2285
# Epoch 1899/2048
# 1s - loss: 0.2333 - val_loss: 0.2283
# Epoch 1900/2048
# 1s - loss: 0.2333 - val_loss: 0.2283
# Epoch 1901/2048
# 1s - loss: 0.2333 - val_loss: 0.2283
# Epoch 1902/2048
# 1s - loss: 0.2332 - val_loss: 0.2280
# Epoch 1903/2048
# 1s - loss: 0.2333 - val_loss: 0.2282
# Epoch 1904/2048
# 1s - loss: 0.2332 - val_loss: 0.2283
# Epoch 1905/2048
# 1s - loss: 0.2332 - val_loss: 0.2285
# Epoch 1906/2048
# 1s - loss: 0.2332 - val_loss: 0.2283
# Epoch 1907/2048
# 1s - loss: 0.2332 - val_loss: 0.2280
# Epoch 1908/2048
# 1s - loss: 0.2332 - val_loss: 0.2281
# Epoch 1909/2048
# 1s - loss: 0.2331 - val_loss: 0.2284
# Epoch 1910/2048
# 1s - loss: 0.2331 - val_loss: 0.2283
# Epoch 1911/2048
# 1s - loss: 0.2331 - val_loss: 0.2282
# Epoch 1912/2048
# 1s - loss: 0.2331 - val_loss: 0.2281
# Epoch 1913/2048
# 1s - loss: 0.2331 - val_loss: 0.2283
# Epoch 1914/2048
# 1s - loss: 0.2331 - val_loss: 0.2281
# Epoch 1915/2048
# 1s - loss: 0.2331 - val_loss: 0.2283
# Epoch 1916/2048
# 1s - loss: 0.2330 - val_loss: 0.2281
# Epoch 1917/2048
# 1s - loss: 0.2330 - val_loss: 0.2281
# Epoch 1918/2048
# 1s - loss: 0.2330 - val_loss: 0.2277
# Epoch 1919/2048
# 1s - loss: 0.2330 - val_loss: 0.2282
# Epoch 1920/2048
# 1s - loss: 0.2330 - val_loss: 0.2279
# Epoch 1921/2048
# 1s - loss: 0.2330 - val_loss: 0.2282
# Epoch 1922/2048
# 1s - loss: 0.2330 - val_loss: 0.2278
# Epoch 1923/2048
# 1s - loss: 0.2330 - val_loss: 0.2279
# Epoch 1924/2048
# 1s - loss: 0.2329 - val_loss: 0.2278
# Epoch 1925/2048
# 1s - loss: 0.2329 - val_loss: 0.2279
# Epoch 1926/2048
# 1s - loss: 0.2329 - val_loss: 0.2280
# Epoch 1927/2048
# 1s - loss: 0.2329 - val_loss: 0.2279
# Epoch 1928/2048
# 1s - loss: 0.2329 - val_loss: 0.2279
# Epoch 1929/2048
# 1s - loss: 0.2328 - val_loss: 0.2280
# Epoch 1930/2048
# 1s - loss: 0.2329 - val_loss: 0.2278
# Epoch 1931/2048
# 1s - loss: 0.2328 - val_loss: 0.2279
# Epoch 1932/2048
# 2s - loss: 0.2328 - val_loss: 0.2277
# Epoch 1933/2048
# 1s - loss: 0.2328 - val_loss: 0.2278
# Epoch 1934/2048
# 1s - loss: 0.2328 - val_loss: 0.2281
# Epoch 1935/2048
# 1s - loss: 0.2328 - val_loss: 0.2277
# Epoch 1936/2048
# 1s - loss: 0.2328 - val_loss: 0.2279
# Epoch 1937/2048
# 1s - loss: 0.2327 - val_loss: 0.2278
# Epoch 1938/2048
# 1s - loss: 0.2327 - val_loss: 0.2278
# Epoch 1939/2048
# 1s - loss: 0.2327 - val_loss: 0.2278
# Epoch 1940/2048
# 1s - loss: 0.2327 - val_loss: 0.2275
# Epoch 1941/2048
# 1s - loss: 0.2327 - val_loss: 0.2277
# Epoch 1942/2048
# 1s - loss: 0.2326 - val_loss: 0.2279
# Epoch 1943/2048
# 1s - loss: 0.2326 - val_loss: 0.2277
# Epoch 1944/2048
# 1s - loss: 0.2326 - val_loss: 0.2276
# Epoch 1945/2048
# 1s - loss: 0.2326 - val_loss: 0.2277
# Epoch 1946/2048
# 1s - loss: 0.2326 - val_loss: 0.2275
# Epoch 1947/2048
# 1s - loss: 0.2326 - val_loss: 0.2275
# Epoch 1948/2048
# 1s - loss: 0.2326 - val_loss: 0.2276
# Epoch 1949/2048
# 1s - loss: 0.2326 - val_loss: 0.2276
# Epoch 1950/2048
# 1s - loss: 0.2326 - val_loss: 0.2278
# Epoch 1951/2048
# 1s - loss: 0.2325 - val_loss: 0.2273
# Epoch 1952/2048
# 1s - loss: 0.2325 - val_loss: 0.2273
# Epoch 1953/2048
# 1s - loss: 0.2325 - val_loss: 0.2275
# Epoch 1954/2048
# 1s - loss: 0.2325 - val_loss: 0.2274
# Epoch 1955/2048
# 1s - loss: 0.2325 - val_loss: 0.2277
# Epoch 1956/2048
# 1s - loss: 0.2325 - val_loss: 0.2273
# Epoch 1957/2048
# 1s - loss: 0.2325 - val_loss: 0.2275
# Epoch 1958/2048
# 1s - loss: 0.2324 - val_loss: 0.2276
# Epoch 1959/2048
# 1s - loss: 0.2324 - val_loss: 0.2275
# Epoch 1960/2048
# 1s - loss: 0.2324 - val_loss: 0.2276
# Epoch 1961/2048
# 1s - loss: 0.2324 - val_loss: 0.2274
# Epoch 1962/2048
# 1s - loss: 0.2324 - val_loss: 0.2273
# Epoch 1963/2048
# 1s - loss: 0.2323 - val_loss: 0.2270
# Epoch 1964/2048
# 1s - loss: 0.2324 - val_loss: 0.2278
# Epoch 1965/2048
# 1s - loss: 0.2324 - val_loss: 0.2271
# Epoch 1966/2048
# 1s - loss: 0.2323 - val_loss: 0.2276
# Epoch 1967/2048
# 1s - loss: 0.2323 - val_loss: 0.2271
# Epoch 1968/2048
# 1s - loss: 0.2323 - val_loss: 0.2271
# Epoch 1969/2048
# 1s - loss: 0.2323 - val_loss: 0.2274
# Epoch 1970/2048
# 1s - loss: 0.2323 - val_loss: 0.2270
# Epoch 1971/2048
# 1s - loss: 0.2323 - val_loss: 0.2276
# Epoch 1972/2048
# 1s - loss: 0.2322 - val_loss: 0.2272
# Epoch 1973/2048
# 1s - loss: 0.2322 - val_loss: 0.2274
# Epoch 1974/2048
# 1s - loss: 0.2322 - val_loss: 0.2275
# Epoch 1975/2048
# 1s - loss: 0.2322 - val_loss: 0.2273
# Epoch 1976/2048
# 1s - loss: 0.2322 - val_loss: 0.2271
# Epoch 1977/2048
# 1s - loss: 0.2322 - val_loss: 0.2275
# Epoch 1978/2048
# 1s - loss: 0.2321 - val_loss: 0.2271
# Epoch 1979/2048
# 1s - loss: 0.2321 - val_loss: 0.2274
# Epoch 1980/2048
# 1s - loss: 0.2321 - val_loss: 0.2270
# Epoch 1981/2048
# 1s - loss: 0.2321 - val_loss: 0.2274
# Epoch 1982/2048
# 1s - loss: 0.2321 - val_loss: 0.2274
# Epoch 1983/2048
# 1s - loss: 0.2321 - val_loss: 0.2272
# Epoch 1984/2048
# 1s - loss: 0.2321 - val_loss: 0.2268
# Epoch 1985/2048
# 1s - loss: 0.2321 - val_loss: 0.2272
# Epoch 1986/2048
# 1s - loss: 0.2321 - val_loss: 0.2272
# Epoch 1987/2048
# 1s - loss: 0.2321 - val_loss: 0.2271
# Epoch 1988/2048
# 1s - loss: 0.2320 - val_loss: 0.2273
# Epoch 1989/2048
# 1s - loss: 0.2320 - val_loss: 0.2271
# Epoch 1990/2048
# 1s - loss: 0.2320 - val_loss: 0.2269
# Epoch 1991/2048
# 1s - loss: 0.2320 - val_loss: 0.2270
# Epoch 1992/2048
# 1s - loss: 0.2319 - val_loss: 0.2270
# Epoch 1993/2048
# 1s - loss: 0.2319 - val_loss: 0.2271
# Epoch 1994/2048
# 1s - loss: 0.2319 - val_loss: 0.2269
# Epoch 1995/2048
# 1s - loss: 0.2319 - val_loss: 0.2270
# Epoch 1996/2048
# 1s - loss: 0.2319 - val_loss: 0.2273
# Epoch 1997/2048
# 1s - loss: 0.2318 - val_loss: 0.2272
# Epoch 1998/2048
# 1s - loss: 0.2319 - val_loss: 0.2270
# Epoch 1999/2048
# 1s - loss: 0.2318 - val_loss: 0.2270
# Epoch 2000/2048
# 1s - loss: 0.2318 - val_loss: 0.2268
# Epoch 2001/2048
# 1s - loss: 0.2318 - val_loss: 0.2270
# Epoch 2002/2048
# 1s - loss: 0.2318 - val_loss: 0.2270
# Epoch 2003/2048
# 1s - loss: 0.2318 - val_loss: 0.2269
# Epoch 2004/2048
# 1s - loss: 0.2317 - val_loss: 0.2267
# Epoch 2005/2048
# 1s - loss: 0.2318 - val_loss: 0.2269
# Epoch 2006/2048
# 1s - loss: 0.2317 - val_loss: 0.2270
# Epoch 2007/2048
# 1s - loss: 0.2317 - val_loss: 0.2266
# Epoch 2008/2048
# 1s - loss: 0.2317 - val_loss: 0.2271
# Epoch 2009/2048
# 1s - loss: 0.2317 - val_loss: 0.2264
# Epoch 2010/2048
# 1s - loss: 0.2316 - val_loss: 0.2268
# Epoch 2011/2048
# 1s - loss: 0.2316 - val_loss: 0.2267
# Epoch 2012/2048
# 1s - loss: 0.2316 - val_loss: 0.2268
# Epoch 2013/2048
# 1s - loss: 0.2316 - val_loss: 0.2267
# Epoch 2014/2048
# 1s - loss: 0.2316 - val_loss: 0.2265
# Epoch 2015/2048
# 1s - loss: 0.2316 - val_loss: 0.2270
# Epoch 2016/2048
# 1s - loss: 0.2316 - val_loss: 0.2270
# Epoch 2017/2048
# 1s - loss: 0.2315 - val_loss: 0.2264
# Epoch 2018/2048
# 1s - loss: 0.2316 - val_loss: 0.2266
# Epoch 2019/2048
# 1s - loss: 0.2315 - val_loss: 0.2269
# Epoch 2020/2048
# 1s - loss: 0.2315 - val_loss: 0.2265
# Epoch 2021/2048
# 1s - loss: 0.2315 - val_loss: 0.2265
# Epoch 2022/2048
# 1s - loss: 0.2315 - val_loss: 0.2266
# Epoch 2023/2048
# 1s - loss: 0.2315 - val_loss: 0.2268
# Epoch 2024/2048
# 1s - loss: 0.2314 - val_loss: 0.2264
# Epoch 2025/2048
# 1s - loss: 0.2314 - val_loss: 0.2265
# Epoch 2026/2048
# 1s - loss: 0.2314 - val_loss: 0.2266
# Epoch 2027/2048
# 1s - loss: 0.2314 - val_loss: 0.2263
# Epoch 2028/2048
# 1s - loss: 0.2313 - val_loss: 0.2265
# Epoch 2029/2048
# 1s - loss: 0.2314 - val_loss: 0.2264
# Epoch 2030/2048
# 1s - loss: 0.2314 - val_loss: 0.2264
# Epoch 2031/2048
# 1s - loss: 0.2313 - val_loss: 0.2266
# Epoch 2032/2048
# 1s - loss: 0.2313 - val_loss: 0.2265
# Epoch 2033/2048
# 1s - loss: 0.2313 - val_loss: 0.2266
# Epoch 2034/2048
# 1s - loss: 0.2313 - val_loss: 0.2261
# Epoch 2035/2048
# 1s - loss: 0.2313 - val_loss: 0.2265
# Epoch 2036/2048
# 1s - loss: 0.2312 - val_loss: 0.2264
# Epoch 2037/2048
# 1s - loss: 0.2312 - val_loss: 0.2261
# Epoch 2038/2048
# 1s - loss: 0.2312 - val_loss: 0.2262
# Epoch 2039/2048
# 1s - loss: 0.2312 - val_loss: 0.2266
# Epoch 2040/2048
# 1s - loss: 0.2312 - val_loss: 0.2263
# Epoch 2041/2048
# 1s - loss: 0.2312 - val_loss: 0.2263
# Epoch 2042/2048
# 1s - loss: 0.2311 - val_loss: 0.2261
# Epoch 2043/2048
# 1s - loss: 0.2311 - val_loss: 0.2259
# Epoch 2044/2048
# 1s - loss: 0.2311 - val_loss: 0.2262
# Epoch 2045/2048
# 1s - loss: 0.2311 - val_loss: 0.2263
# Epoch 2046/2048
# 1s - loss: 0.2310 - val_loss: 0.2263
# Epoch 2047/2048
# 1s - loss: 0.2311 - val_loss: 0.2264
# Epoch 2048/2048
# 1s - loss: 0.2312 - val_loss: 0.2263

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name2))

# %%
X_test_filtered = X_test_norm[:, feature_filter]

# %%
# Exclude validation set
X_train_wo_valid_filtered = X_train_wo_valid[:, feature_filter]

# %%
X_test_filtered.shape
# Out:
# (18628, 1173)

# %%
# Run predictions
ae_pred_filtered = autoencoder.predict(X_test_filtered)
ae_pred_filtered_train = autoencoder.predict(X_train_wo_valid_filtered)

# %%
pickle.dump(ae_pred_filtered, open(model_directory + "ae_pred_filtered.p", "wb"))
pickle.dump(ae_pred_filtered_train, open(model_directory + "ae_pred_filtered_train.p", "wb"))

# %%
ae_pred_filtered = pickle.load(open(model_directory + "ae_pred_filtered.p", "rb"))
ae_pred_filtered_train = pickle.load(open(model_directory + "ae_pred_filtered_train.p", "rb"))

# %%
ae_error_filtered = get_error_df(X_test_filtered, ae_pred_filtered, mode="topn", n_highest=100)
ae_error_filtered_train = get_error_df(X_train_wo_valid_filtered, ae_pred_filtered_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error_filtered, open(model_directory + "ae_error_filtered.p", "wb"))
pickle.dump(ae_error_filtered_train, open(model_directory + "ae_error_filtered_train.p", "wb"))

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plot_lumi_error(np.zeros(ae_pred.shape), X_test_norm, title='Mean square score across lumisections')
plot_lumi_error(ae_pred, X_test_norm, title='AE reco errror across lumisections')
plot_lumi_error(ae_pred_filtered, X_test_filtered, 
                title='AE filtered reco errror across lumisections')

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve(label, pred, X_tests, names):
    """Generates ROC Curves for a given array"""
    scores = [get_error_df(X_tests[i], pred[i], mode='topn') for i in range(len(pred))]
    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve_error(label, scores, names):
    """Generates ROC Curves for a given array"""    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()
    return plt

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test,
                    [ae_error,
                     get_error_df(X_test_filtered, ae_pred_filtered, mode="topn"), 
                     get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn")], 
                    ['AE',
                     'AE filtered',
                     'Mean square'])

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error, 
                     get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)], 
                    ['Squeezed AE w/o pileup',
                     'Squeezed AE with pileup',
                     'Standard AE with pileup',
                     'Standard AE w/o pileup',
                     'Mean square'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-72-0de51066cff7> in <module>()
#       1 plt.rcParams['figure.figsize'] = [20, 10]
#       2 fig = get_roc_curve_error(y_test,
# ----> 3                     [np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error,
#       4                      get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)],
#       5                     ['Squeezed AE w/o pileup',
#
# NameError: name 'np_b_ae_error' is not defined

# %%
fig.savefig(csv_dir + 'roc_auc_filtered_ae.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-a37dea40acb0> in <module>()
# ----> 1 fig.savefig(csv_dir + 'roc_auc_filtered_ae.png')
#
# NameError: name 'csv_dir' is not defined

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered,
                     get_error_df(X_test_filtered, np.zeros(X_test_filtered.shape), mode="topn", n_highest=100)], 
                    ['Squeezed AE w/o pileup',
                     'Squeezed AE with pileup',
                     'Standard AE with pileup',
                     'Standard AE w/o pileup',
                     'Mean square'])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

LABELS = ["Normal", "Anomalous"]

def conf_matrix(scores, y_true, threshold, title):
    y_pred = [1 if e > threshold else 0 for e in scores]
    conf_matrix = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(12, 12))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.title(title)
    plt.show()

    acc = accuracy_score(y_true, y_pred)
    class_imbal = np.mean(1 - y_true)
    adj_acc = (acc - class_imbal) / (1 - class_imbal)

    print("Threshold:", threshold)
    print("Adjusted accuracy:", adj_acc)
    return threshold

# %%
conf_matrix(ae_error_filtered, y_test, 1.5e0, '')
# Out:
# Threshold: 1.5
# Adjusted accuracy: -2.32898611695
# 1.5

# %%
def pred_vs_feature(y_val, x_val, y_class, y_name="", x_name="", selected=[], linear=False,
                    limit=False):
    '''
    Plots two arbitrary values agains each other.
    '''
    df = pd.DataFrame({'y_val': y_val,
                       'x_val': x_val,
                       'y_class': y_class})

    groups = df.groupby('y_class')
    fig, ax = plt.subplots()

    for name, group in groups:
        ax.plot(group.x_val, 
                group.y_val,
                color="red" if name == 1 else "blue",
                marker='o',
                ms=2,
                linestyle='',
                label= "Anomaly" if name == 1 else "Normal")

    for i in selected:
        ax.plot(x_val[i],
                y_val[i],
                color="green",
                marker='o',
                ms=4,
                linestyle='')
                 
    ax.legend()
    if not linear:
        ax.set_yscale('log')
    if limit:
        plt.xlim([limit[0], limit[1]])
    plt.grid()
    plt.ylabel(y_name)
    plt.xlabel(x_name)
    plt.show()

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error_filtered, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error, X_test[2808], y_test, "AE reco error", "Luminosity")

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error_filtered, X_test[2808], y_test, "AE reco error", "Luminosity")

# %%
model_directory_np_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_bottleneck/"
model_directory_p_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup/"
model_directory_p_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup_no_bottleneck/"
model_directory_np_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_no_pileup_no_bottleneck/"

# %%
np_b_ae_error = pickle.load(open(model_directory_np_b + "ae_error.p", "rb"))
np_b_ae_error_filtered = pickle.load(open(model_directory_np_b + "ae_error_filtered.p", "rb"))

p_b_ae_error = pickle.load(open(model_directory_p_b + "ae_error.p", "rb"))
p_b_ae_error_filtered = pickle.load(open(model_directory_p_b + "ae_error_filtered.p", "rb"))


p_nb_ae_error = pickle.load(open(model_directory_p_nb + "ae_error.p", "rb"))
p_nb_ae_error_filtered = pickle.load(open(model_directory_p_nb + "ae_error_filtered.p", "rb"))


np_nb_ae_error = pickle.load(open(model_directory_np_nb + "ae_error.p", "rb"))
np_nb_ae_error_filtered = pickle.load(open(model_directory_np_nb + "ae_error_filtered.p", "rb"))

# %%
def pred_vs_feature4(y_vals, x_val, y_class, titles, y_name="", x_name="", linear=False, 
                     limit=False, name_plt=''):
    '''
    Plots two arbitrary values agains each other.
    '''
    fig, axes = plt.subplots(2, 2)
    
    for i in range(4):
        df = pd.DataFrame({'y_val': y_vals[i],
                           'x_val': x_val,
                           'y_class': y_class})

        groups = df.groupby('y_class')
        if i < 2:
            ax = axes[0, i%2]
        else:
            ax = axes[1, i%2]
        
        for name, group in groups:
            ax.plot(group.x_val, 
                    group.y_val,
                    color="red" if name == 1 else "blue",
                    marker='o',
                    ms=2,
                    linestyle='',
                    label= "Anomaly" if name == 1 else "Normal")

        ax.legend()
        if not linear:
            ax.set_yscale('log')
        if limit:
            plt.xlim([limit[0], limit[1]])
        ax.set_ylabel(y_name)
        ax.set_xlabel(x_name)
        ax.set_title(titles[i])
        plt.grid()
    plt.show()
    plt.savefig(csv_dir + name_plt)

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2807], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2807], y_test,
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                 'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='filtered_ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2808], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='ae_vs_pileup.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2808], y_test, 
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='filtered_ae_vs_pileup.png')
