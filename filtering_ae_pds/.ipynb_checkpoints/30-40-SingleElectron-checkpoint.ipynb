# %%
# Running on GPU?
import setGPU

import getpass
import h5py
import pickle
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.colors import LogNorm

from tqdm import tnrange, tqdm_notebook
# Out:
# setGPU: Setting GPU to: 4

# %%
import os
import getpass
# Get permission to access EOS (Insert your NICE password)
os.system("echo %s | kinit" % getpass.getpass())
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error',)).History will not be written to the database.
# ········
# 0

# %%
import json
import numpy as np
import pandas as pd
from pprint import pprint

import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Dense, Lambda, BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.activations import sigmoid, linear, relu
from keras.models import Model, load_model
from keras.regularizers import l1, l2, l1_l2

from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import class_weight
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from scipy.stats import pearsonr
# Out:
# Using TensorFlow backend.

# %%
plt.rcParams.update({'font.size': 22})

# %%
PDs  = {1: 'BTagCSV',
        2: 'BTagMu',
        3: 'Charmonium',
        4: 'DisplacedJet',
        5: 'DoubleEG',
        6: 'DoubleMuon',
        7: 'DoubleMuonLowMass',
        8: 'FSQJets',
        9: 'HighMultiplicityEOF',
        10: 'HTMHT',
        11: 'JetHT',
        12: 'MET',
        13: 'MinimumBias',
        14: 'MuonEG',
        15: 'MuOnia',
        16: 'NoBPTX',
        17: 'SingleElectron',
        18: 'SingleMuon',
        19: 'SinglePhoton',
        20: 'Tau',
        21: 'ZeroBias'}

# Select PD
nPD = 17 # SingleElectron

# %%
legend = [{"name": 'pf_jets', "start": 0, "end": 776},
          {"name": 'cal_jet_mets', "start": 777, "end": 944},
          {"name": 'pho', "start": 945, "end": 1280},
          {"name": 'muons', "start": 1281, "end": 1784},
          {"name": 'pf_jets2', "start": 1785, "end": 1889},
          {"name": 'pf_mets', "start": 1890, "end": 1917},
          {"name": 'nvtx', "start": 1918, "end": 1924},
          {"name": 'cal_jet_mets2', "start": 1925},
          {"name": 'sc', "start": 2037, "end": 2127},
          {"name": 'cc', "start": 2128, "end": 2169},
          {"name": 'pho2', "start": 2170, "end": 2365},
          {"name": 'muons2', "start": 2366, "end": 2491},
          {"name": 'ebs', "start": 2492, "end": 2701},
          {"name": 'hbhef', "start": 2702, "end": 2764},
          {"name": 'presh', "start": 2765, "end": 2806},
          {"name": 'inst_lumi', "start": 2807, "end": 2808}]

# %%
# Feature description
feature_names = ['qPFJetPt', 'qPFJetEta', 'qPFJetPhi', 'qPFJet0Pt', 'qPFJet1Pt', 'qPFJet2Pt', 'qPFJet3Pt', 'qPFJet4Pt', 'qPFJet5Pt', 'qPFJet0Eta', 'qPFJet1Eta', 'qPFJet2Eta', 'qPFJet3Eta', 'qPFJet4Eta', 'qPFJet5Eta', 'qPFJet0Phi', 'qPFJet1Phi', 'qPFJet2Phi', 'qPFJet3Phi', 'qPFJet4Phi', 'qPFJet5Phi', 'qPFJet4CHS0Pt', 'qPFJet4CHS1Pt', 'qPFJet4CHS2Pt', 'qPFJet4CHS3Pt', 'qPFJet4CHS4Pt', 'qPFJet4CHS5Pt', 'qPFJet4CHS0Eta', 'qPFJet4CHS1Eta', 'qPFJet4CHS2Eta', 'qPFJet4CHS3Eta', 'qPFJet4CHS4Eta', 'qPFJet4CHS5Eta', 'qPFJet4CHS0Phi', 'qPFJet4CHS1Phi', 'qPFJet4CHS2Phi', 'qPFJet4CHS3Phi', 'qPFJet4CHS4Phi', 'qPFJet4CHS5Phi', 'qPFJet8CHS0Pt', 'qPFJet8CHS1Pt', 'qPFJet8CHS2Pt', 'qPFJet8CHS3Pt', 'qPFJet8CHS4Pt', 'qPFJet8CHS5Pt', 'qPFJet8CHS0Eta', 'qPFJet8CHS1Eta', 'qPFJet8CHS2Eta', 'qPFJet8CHS3Eta', 'qPFJet8CHS4Eta', 'qPFJet8CHS5Eta', 'qPFJet8CHS0Phi', 'qPFJet8CHS1Phi', 'qPFJet8CHS2Phi', 'qPFJet8CHS3Phi', 'qPFJet8CHS4Phi', 'qPFJet8CHS5Phi', 'qPFJetEI0Pt', 'qPFJetEI1Pt', 'qPFJetEI2Pt', 'qPFJetEI3Pt', 'qPFJetEI4Pt', 'qPFJetEI5Pt', 'qPFJetEI0Eta', 'qPFJetEI1Eta', 'qPFJetEI2Eta', 'qPFJetEI3Eta', 'qPFJetEI4Eta', 'qPFJetEI5Eta', 'qPFJetEI0Phi', 'qPFJetEI1Phi', 'qPFJetEI2Phi', 'qPFJetEI3Phi', 'qPFJetEI4Phi', 'qPFJetEI5Phi', 'qPFJet8CHSSD0Pt', 'qPFJet8CHSSD1Pt', 'qPFJet8CHSSD2Pt', 'qPFJet8CHSSD3Pt', 'qPFJet8CHSSD4Pt', 'qPFJet8CHSSD5Pt', 'qPFJet8CHSSD0Eta', 'qPFJet8CHSSD1Eta', 'qPFJet8CHSSD2Eta', 'qPFJet8CHSSD3Eta', 'qPFJet8CHSSD4Eta', 'qPFJet8CHSSD5Eta', 'qPFJet8CHSSD0Phi', 'qPFJet8CHSSD1Phi', 'qPFJet8CHSSD2Phi', 'qPFJet8CHSSD3Phi', 'qPFJet8CHSSD4Phi', 'qPFJet8CHSSD5Phi', 'qPFJetTopCHS0Pt', 'qPFJetTopCHS1Pt', 'qPFJetTopCHS2Pt', 'qPFJetTopCHS3Pt', 'qPFJetTopCHS4Pt', 'qPFJetTopCHS5Pt', 'qPFJetTopCHS0Eta', 'qPFJetTopCHS1Eta', 'qPFJetTopCHS2Eta', 'qPFJetTopCHS3Eta', 'qPFJetTopCHS4Eta', 'qPFJetTopCHS5Eta', 'qPFJetTopCHS0Phi', 'qPFJetTopCHS1Phi', 'qPFJetTopCHS2Phi', 'qPFJetTopCHS3Phi', 'qPFJetTopCHS4Phi', 'qPFJetTopCHS5Phi', 'qCalJet0Pt', 'qCalJet1Pt', 'qCalJet2Pt', 'qCalJet3Pt', 'qCalJet4Pt', 'qCalJet5Pt', 'qCalJet0Eta', 'qCalJet1Eta', 'qCalJet2Eta', 'qCalJet3Eta', 'qCalJet4Eta', 'qCalJet5Eta', 'qCalJet0Phi', 'qCalJet1Phi', 'qCalJet2Phi', 'qCalJet3Phi', 'qCalJet4Phi', 'qCalJet5Phi', 'qCalJet0En', 'qCalJet1En', 'qCalJet2En', 'qCalJet3En', 'qCalJet4En', 'qCalJet5En', 'qPho0Pt', 'qPho1Pt', 'qPho2Pt', 'qPho3Pt', 'qPho4Pt', 'qPho5Pt', 'qPho0Eta', 'qPho1Eta', 'qPho2Eta', 'qPho3Eta', 'qPho4Eta', 'qPho5Eta', 'qPho0Phi', 'qPho1Phi', 'qPho2Phi', 'qPho3Phi', 'qPho4Phi', 'qPho5Phi', 'qPho0En', 'qPho1En', 'qPho2En', 'qPho3En', 'qPho4En', 'qPho5En', 'qgedPho0Pt', 'qgedPho1Pt', 'qgedPho2Pt', 'qgedPho3Pt', 'qgedPho4Pt', 'qgedPho5Pt', 'qgedPho0Eta', 'qgedPho1Eta', 'qgedPho2Eta', 'qgedPho3Eta', 'qgedPho4Eta', 'qgedPho5Eta', 'qgedPho0Phi', 'qgedPho1Phi', 'qgedPho2Phi', 'qgedPho3Phi', 'qgedPho4Phi', 'qgedPho5Phi', 'qgedPho0En', 'qgedPho1En', 'qgedPho2En', 'qgedPho3En', 'qgedPho4En', 'qgedPho5En', 'qMu0Pt', 'qMu1Pt', 'qMu2Pt', 'qMu3Pt', 'qMu4Pt', 'qMu5Pt', 'qMu0Eta', 'qMu1Eta', 'qMu2Eta', 'qMu3Eta', 'qMu4Eta', 'qMu5Eta', 'qMu0Phi', 'qMu1Phi', 'qMu2Phi', 'qMu3Phi', 'qMu4Phi', 'qMu5Phi', 'qMu0En', 'qMu1En', 'qMu2En', 'qMu3En', 'qMu4En', 'qMu5En', 'qMuCosm0Pt', 'qMuCosm1Pt', 'qMuCosm2Pt', 'qMuCosm3Pt', 'qMuCosm4Pt', 'qMuCosm5Pt', 'qMuCosm0Eta', 'qMuCosm1Eta', 'qMuCosm2Eta', 'qMuCosm3Eta', 'qMuCosm4Eta', 'qMuCosm5Eta', 'qMuCosm0Phi', 'qMuCosm1Phi', 'qMuCosm2Phi', 'qMuCosm3Phi', 'qMuCosm4Phi', 'qMuCosm5Phi', 'qMuCosm0En', 'qMuCosm1En', 'qMuCosm2En', 'qMuCosm3En', 'qMuCosm4En', 'qMuCosm5En', 'qMuCosmLeg0Pt', 'qMuCosmLeg1Pt', 'qMuCosmLeg2Pt', 'qMuCosmLeg3Pt', 'qMuCosmLeg4Pt', 'qMuCosmLeg5Pt', 'qMuCosmLeg0Eta', 'qMuCosmLeg1Eta', 'qMuCosmLeg2Eta', 'qMuCosmLeg3Eta', 'qMuCosmLeg4Eta', 'qMuCosmLeg5Eta', 'qMuCosmLeg0Phi', 'qMuCosmLeg1Phi', 'qMuCosmLeg2Phi', 'qMuCosmLeg3Phi', 'qMuCosmLeg4Phi', 'qMuCosmLeg5Phi', 'qMuCosmLeg0En', 'qMuCosmLeg1En', 'qMuCosmLeg2En', 'qMuCosmLeg3En', 'qMuCosmLeg4En', 'qMuCosmLeg5En', 'qPFJet4CHSPt', 'qPFJet4CHSEta', 'qPFJet4CHSPhi', 'qPFJet8CHSPt', 'qPFJet8CHSEta', 'qPFJet8CHSPhi', 'qPFJetEIPt', 'qPFJetEIEta', 'qPFJetEIPhi', 'qPFJet8CHSSDPt', 'qPFJet8CHSSDEta', 'qPFJet8CHSSDPhi', 'qPFJetTopCHSPt', 'qPFJetTopCHSEta', 'qPFJetTopCHSPhi', 'qPFChMetPt', 'qPFChMetPhi', 'qPFMetPt', 'qPFMetPhi', 'qNVtx', 'qCalJetPt', 'qCalJetEta', 'qCalJetPhi', 'qCalJetEn', 'qCalMETPt', 'qCalMETPhi', 'qCalMETEn', 'qCalMETBEPt', 'qCalMETBEPhi', 'qCalMETBEEn', 'qCalMETBEFOPt', 'qCalMETBEFOPhi', 'qCalMETBEFOEn', 'qCalMETMPt', 'qCalMETMPhi', 'qCalMETMEn', 'qSCEn', 'qSCEta', 'qSCPhi', 'qSCEtaWidth', 'qSCPhiWidth', 'qSCEnhfEM', 'qSCEtahfEM', 'qSCPhihfEM', 'qSCEn5x5', 'qSCEta5x5', 'qSCPhi5x5', 'qSCEtaWidth5x5', 'qSCPhiWidth5x5', 'qCCEn', 'qCCEta', 'qCCPhi', 'qCCEn5x5', 'qCCEta5x5', 'qCCPhi5x5', 'qPhoPt', 'qPhoEta', 'qPhoPhi', 'qPhoEn_', 'qPhoe1x5_', 'qPhoe2x5_', 'qPhoe3x3_', 'qPhoe5x5_', 'qPhomaxenxtal_', 'qPhosigmaeta_', 'qPhosigmaIeta_', 'qPhor1x5_', 'qPhor2x5_', 'qPhor9_', 'qgedPhoPt', 'qgedPhoEta', 'qgedPhoPhi', 'qgedPhoEn_', 'qgedPhoe1x5_', 'qgedPhoe2x5_', 'qgedPhoe3x3_', 'qgedPhoe5x5_', 'qgedPhomaxenxtal_', 'qgedPhosigmaeta_', 'qgedPhosigmaIeta_', 'qgedPhor1x5_', 'qgedPhor2x5_', 'qgedPhor9_', 'qMuPt', 'qMuEta', 'qMuPhi', 'qMuEn_', 'qMuCh_', 'qMuChi2_', 'qMuCosmPt', 'qMuCosmEta', 'qMuCosmPhi', 'qMuCosmEn_', 'qMuCosmCh_', 'qMuCosmChi2_', 'qMuCosmLegPt', 'qMuCosmLegEta', 'qMuCosmLegPhi', 'qMuCosmLegEn_', 'qMuCosmLegCh_', 'qMuCosmLegChi2_', 'qSigmaIEta', 'qSigmaIPhi', 'qr9', 'qHadOEm', 'qdrSumPt', 'qdrSumEt', 'qeSCOP', 'qecEn', 'qUNSigmaIEta', 'qUNSigmaIPhi', 'qUNr9', 'qUNHadOEm', 'qUNdrSumPt', 'qUNdrSumEt', 'qUNeSCOP', 'qUNecEn', 'qEBenergy', 'qEBtime', 'qEBchi2', 'qEBiEta', 'qEBiPhi', 'qEEenergy', 'qEEtime', 'qEEchi2', 'qEEix', 'qEEiy', 'qESenergy', 'qEStime', 'qESix', 'qESiy', 'qHBHEenergy', 'qHBHEtime', 'qHBHEauxe', 'qHBHEieta', 'qHBHEiphi', 'qHFenergy', 'qHFtime', 'qHFieta', 'qHFiphi', 'qPreShEn', 'qPreShEta', 'qPreShPhi', 'qPreShYEn', 'qPreShYEta', 'qPreShYPhi', 'inst_luminosity']

# %%
data_directory = "/eos/cms/store/user/fsiroky/consistentlumih5/"
label_file = "/afs/cern.ch/user/t/tkrzyzek/Documents/Data-Certification/jsons/SingleElectron.json"
pileup_file = "/afs/cern.ch/cms/CAF/CMSCOMM/COMM_DQM/certification/Collisions16/13TeV/PileUp/pileup_latest.txt"
model_directory = "/eos/user/t/tkrzyzek/autoencoder/30-40-SingleElectron/"
model_name = "model"

# %%
def get_file_list(directory, pds, npd, typeof, extension):
    files = []
    parts = ["C", "D", "E", "F", "G", "H"]
    for p in parts:
        files.append("%s%s_%s_%s%s" % (directory, pds[npd], p, typeof, extension))
    return files

files = get_file_list(data_directory, PDs, nPD, "background", ".h5")
files = files + get_file_list(data_directory, PDs, nPD, "signal", ".h5")

# %%
# Load good and bad jets
def get_data(files):
    readout = np.empty([0,2813])
    
    for file in files:
        jet = file.split("/")[-1][:-3]
        print("Reading: %s" % jet)
        try:
            h5file = h5py.File(file, "r")
            readout = np.concatenate((readout, h5file[jet][:]), axis=0)
        except OSError as error:
            print("This Primary Dataset doesn't have %s. %s" % (jet, error))
            continue

    return readout

data = pd.DataFrame(get_data(files))
# Out:
# Reading: SingleElectron_C_background
# Reading: SingleElectron_D_background
# Reading: SingleElectron_E_background
# This Primary Dataset doesn't have SingleElectron_E_background. Unable to open file (Unable to open file: name = '/eos/cms/store/user/fsiroky/consistentlumih5/singleelectron_e_background.h5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)
# Reading: SingleElectron_F_background
# This Primary Dataset doesn't have SingleElectron_F_background. Unable to open file (Unable to open file: name = '/eos/cms/store/user/fsiroky/consistentlumih5/singleelectron_f_background.h5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)
# Reading: SingleElectron_G_background
# Reading: SingleElectron_H_background
# Reading: SingleElectron_C_signal
# Reading: SingleElectron_D_signal
# Reading: SingleElectron_E_signal
# This Primary Dataset doesn't have SingleElectron_E_signal. Unable to open file (Unable to open file: name = '/eos/cms/store/user/fsiroky/consistentlumih5/singleelectron_e_signal.h5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)
# Reading: SingleElectron_F_signal
# This Primary Dataset doesn't have SingleElectron_F_signal. Unable to open file (Unable to open file: name = '/eos/cms/store/user/fsiroky/consistentlumih5/singleelectron_f_signal.h5', errno = 2, error message = 'no such file or directory', flags = 0, o_flags = 0)
# Reading: SingleElectron_G_signal
# Reading: SingleElectron_H_signal

# %%
data["run"] = data[2807].astype(int)
data["lumi"] = data[2808].astype(int)
data["inst_lumi"] = data[2809].astype(float)

# Drop unnecessary meta data
data.drop([2808, 2809, 2810, 2811, 2812], axis=1, inplace=True)

# Append inst. luminosity at the end as well
data[2807] = data["inst_lumi"]

# Sort by runID and then by lumiID
data = data.sort_values(["run", "lumi"], ascending=[True,True])

# Reset index
data = data.reset_index(drop=True)  

runIDs  = data["run"].astype(int)
lumiIDs = data["lumi"].astype(int)
luminosity = data["inst_lumi"].astype(float)

# %%
# Apply labels
output_json = json.load(open(label_file))

def json_checker(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid >= i[0] and orig_lumid <= i[1]:
                return 0
    except KeyError:
        pass
    return 1

def add_flags(sample):
    return json_checker(output_json, sample["run"], sample["lumi"])

data["label"] = data.apply(add_flags, axis=1)

# %%
with open(pileup_file) as f:
    pileup = json.load(f)

def pileup_from_json(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid == i[0]:
                return i[3]
    except KeyError:
        print('key error')
    return 1

def add_pileup(sample):
    return pileup_from_json(pileup, sample["run"], sample["lumi"])

data["pileup"] = data.apply(add_pileup, axis=1)

# %%
data[2808] = data["pileup"]

# %%
# Split the data
TRAIN_FROM = round(0.3*len(data))
TRAIN_TO = round(0.4*len(data))
TEST_FROM = round(0.4*len(data))
TEST_TO = round(0.5*len(data))

train = data.iloc[TRAIN_FROM:TRAIN_TO]
X_train = pd.concat([train.iloc[:, :2808], train[2808]], axis=1)
y_train = train["label"]

# Adding bad data to test set
test = pd.concat([data.iloc[TEST_FROM:TEST_TO], data[:TEST_FROM][data['label'] == 1],
                 data[TEST_TO:][data['label'] == 1]]) 
X_test = pd.concat([test.iloc[:, :2808], test[2808]], axis=1)
y_test = test["label"]

normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# Train only on good
X_train = X_train[y_train == 0]
X_train_norm = X_train_norm[y_train == 0]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
INPUT_DIM = 2809

# %%
X_train_norm.shape
# Out:
# (10991, 2809)

# %%
X_test_norm.shape
# Out:
# (12035, 2809)

# %%
input_layer = Input(shape=(INPUT_DIM, ))

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(INPUT_DIM)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2809)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              5754880
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 2048)              2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 1024)              1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# p_re_lu_3 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# p_re_lu_4 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# p_re_lu_5 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# p_re_lu_6 (PReLU)            (None, 64)                64
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               8320
# _________________________________________________________________
# p_re_lu_7 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               33024
# _________________________________________________________________
# p_re_lu_8 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               131584
# _________________________________________________________________
# p_re_lu_9 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_10 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 2048)              2099200
# _________________________________________________________________
# p_re_lu_11 (PReLU)           (None, 2048)              2048
# _________________________________________________________________
# dense_12 (Dense)             (None, 2809)              5755641
# =================================================================
# Total params: 17,111,417
# Trainable params: 17,111,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_norm,
                X_train_norm,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 8243 samples, validate on 2748 samples
# Epoch 1/2048
# 10s - loss: 93.1682 - val_loss: 83.6115
# Epoch 2/2048
# 4s - loss: 76.1920 - val_loss: 68.3680
# Epoch 3/2048
# 5s - loss: 62.2371 - val_loss: 55.9050
# Epoch 4/2048
# 5s - loss: 50.9015 - val_loss: 45.7236
# Epoch 5/2048
# 6s - loss: 41.6396 - val_loss: 37.4043
# Epoch 6/2048
# 8s - loss: 34.0773 - val_loss: 30.6188
# Epoch 7/2048
# 6s - loss: 27.9135 - val_loss: 25.0945
# Epoch 8/2048
# 7s - loss: 22.8991 - val_loss: 20.6053
# Epoch 9/2048
# 4s - loss: 18.8259 - val_loss: 16.9637
# Epoch 10/2048
# 7s - loss: 15.5241 - val_loss: 14.0149
# Epoch 11/2048
# 6s - loss: 12.8524 - val_loss: 11.6312
# Epoch 12/2048
# 7s - loss: 10.6939 - val_loss: 9.7068
# Epoch 13/2048
# 6s - loss: 8.9524 - val_loss: 8.1554
# Epoch 14/2048
# 7s - loss: 7.5490 - val_loss: 6.9059
# Epoch 15/2048
# 7s - loss: 6.4191 - val_loss: 5.9003
# Epoch 16/2048
# 7s - loss: 5.5104 - val_loss: 5.0928
# Epoch 17/2048
# 7s - loss: 4.7805 - val_loss: 4.4429
# Epoch 18/2048
# 6s - loss: 4.1880 - val_loss: 3.9081
# Epoch 19/2048
# 6s - loss: 3.6963 - val_loss: 3.4622
# Epoch 20/2048
# 6s - loss: 3.2864 - val_loss: 3.0903
# Epoch 21/2048
# 7s - loss: 2.9444 - val_loss: 2.7804
# Epoch 22/2048
# 6s - loss: 2.6592 - val_loss: 2.5216
# Epoch 23/2048
# 7s - loss: 2.4191 - val_loss: 2.3001
# Epoch 24/2048
# 7s - loss: 2.2113 - val_loss: 2.1070
# Epoch 25/2048
# 3s - loss: 2.0297 - val_loss: 1.9381
# Epoch 26/2048
# 6s - loss: 1.8706 - val_loss: 1.7899
# Epoch 27/2048
# 6s - loss: 1.7313 - val_loss: 1.6602
# Epoch 28/2048
# 6s - loss: 1.6092 - val_loss: 1.5465
# Epoch 29/2048
# 6s - loss: 1.5022 - val_loss: 1.4469
# Epoch 30/2048
# 6s - loss: 1.4083 - val_loss: 1.3596
# Epoch 31/2048
# 7s - loss: 1.3260 - val_loss: 1.2829
# Epoch 32/2048
# 5s - loss: 1.2538 - val_loss: 1.2156
# Epoch 33/2048
# 4s - loss: 1.1904 - val_loss: 1.1566
# Epoch 34/2048
# 5s - loss: 1.1343 - val_loss: 1.1036
# Epoch 35/2048
# 6s - loss: 1.0838 - val_loss: 1.0559
# Epoch 36/2048
# 8s - loss: 1.0383 - val_loss: 1.0129
# Epoch 37/2048
# 6s - loss: 0.9973 - val_loss: 0.9741
# Epoch 38/2048
# 5s - loss: 0.9603 - val_loss: 0.9395
# Epoch 39/2048
# 4s - loss: 0.9270 - val_loss: 0.9077
# Epoch 40/2048
# 5s - loss: 0.8969 - val_loss: 0.8794
# Epoch 41/2048
# 9s - loss: 0.8698 - val_loss: 0.8538
# Epoch 42/2048
# 7s - loss: 0.8455 - val_loss: 0.8308
# Epoch 43/2048
# 6s - loss: 0.8235 - val_loss: 0.8101
# Epoch 44/2048
# 6s - loss: 0.8037 - val_loss: 0.7920
# Epoch 45/2048
# 7s - loss: 0.7860 - val_loss: 0.7751
# Epoch 46/2048
# 8s - loss: 0.7699 - val_loss: 0.7599
# Epoch 47/2048
# 7s - loss: 0.7556 - val_loss: 0.7465
# Epoch 48/2048
# 7s - loss: 0.7427 - val_loss: 0.7343
# Epoch 49/2048
# 7s - loss: 0.7311 - val_loss: 0.7233
# Epoch 50/2048
# 6s - loss: 0.7206 - val_loss: 0.7137
# Epoch 51/2048
# 3s - loss: 0.7110 - val_loss: 0.7042
# Epoch 52/2048
# 5s - loss: 0.7022 - val_loss: 0.6963
# Epoch 53/2048
# 7s - loss: 0.6941 - val_loss: 0.6883
# Epoch 54/2048
# 7s - loss: 0.6868 - val_loss: 0.6814
# Epoch 55/2048
# 5s - loss: 0.6801 - val_loss: 0.6750
# Epoch 56/2048
# 7s - loss: 0.6740 - val_loss: 0.6693
# Epoch 57/2048
# 4s - loss: 0.6685 - val_loss: 0.6646
# Epoch 58/2048
# 4s - loss: 0.6635 - val_loss: 0.6594
# Epoch 59/2048
# 6s - loss: 0.6587 - val_loss: 0.6550
# Epoch 60/2048
# 7s - loss: 0.6545 - val_loss: 0.6509
# Epoch 61/2048
# 5s - loss: 0.6507 - val_loss: 0.6475
# Epoch 62/2048
# 6s - loss: 0.6472 - val_loss: 0.6440
# Epoch 63/2048
# 7s - loss: 0.6441 - val_loss: 0.6412
# Epoch 64/2048
# 6s - loss: 0.6412 - val_loss: 0.6384
# Epoch 65/2048
# 5s - loss: 0.6386 - val_loss: 0.6360
# Epoch 66/2048
# 6s - loss: 0.6362 - val_loss: 0.6338
# Epoch 67/2048
# 7s - loss: 0.6340 - val_loss: 0.6318
# Epoch 68/2048
# 5s - loss: 0.6321 - val_loss: 0.6301
# Epoch 69/2048
# 6s - loss: 0.6303 - val_loss: 0.6288
# Epoch 70/2048
# 6s - loss: 0.6288 - val_loss: 0.6270
# Epoch 71/2048
# 7s - loss: 0.6272 - val_loss: 0.6257
# Epoch 72/2048
# 4s - loss: 0.6258 - val_loss: 0.6242
# Epoch 73/2048
# 4s - loss: 0.6246 - val_loss: 0.6233
# Epoch 74/2048
# 6s - loss: 0.6235 - val_loss: 0.6219
# Epoch 75/2048
# 6s - loss: 0.6224 - val_loss: 0.6209
# Epoch 76/2048
# 6s - loss: 0.6213 - val_loss: 0.6201
# Epoch 77/2048
# 6s - loss: 0.6204 - val_loss: 0.6192
# Epoch 78/2048
# 4s - loss: 0.6196 - val_loss: 0.6184
# Epoch 79/2048
# 7s - loss: 0.6188 - val_loss: 0.6177
# Epoch 80/2048
# 4s - loss: 0.6180 - val_loss: 0.6169
# Epoch 81/2048
# 6s - loss: 0.6174 - val_loss: 0.6164
# Epoch 82/2048
# 6s - loss: 0.6167 - val_loss: 0.6158
# Epoch 83/2048
# 4s - loss: 0.6161 - val_loss: 0.6154
# Epoch 84/2048
# 6s - loss: 0.6155 - val_loss: 0.6147
# Epoch 85/2048
# 1s - loss: 0.6150 - val_loss: 0.6148
# Epoch 86/2048
# 6s - loss: 0.6147 - val_loss: 0.6140
# Epoch 87/2048
# 6s - loss: 0.6141 - val_loss: 0.6136
# Epoch 88/2048
# 4s - loss: 0.6137 - val_loss: 0.6131
# Epoch 89/2048
# 5s - loss: 0.6133 - val_loss: 0.6127
# Epoch 90/2048
# 5s - loss: 0.6129 - val_loss: 0.6125
# Epoch 91/2048
# 8s - loss: 0.6125 - val_loss: 0.6121
# Epoch 92/2048
# 4s - loss: 0.6122 - val_loss: 0.6119
# Epoch 93/2048
# 5s - loss: 0.6119 - val_loss: 0.6115
# Epoch 94/2048
# 5s - loss: 0.6115 - val_loss: 0.6113
# Epoch 95/2048
# 5s - loss: 0.6113 - val_loss: 0.6110
# Epoch 96/2048
# 6s - loss: 0.6110 - val_loss: 0.6108
# Epoch 97/2048
# 1s - loss: 0.6108 - val_loss: 0.6109
# Epoch 98/2048
# 5s - loss: 0.6105 - val_loss: 0.6105
# Epoch 99/2048
# 5s - loss: 0.6103 - val_loss: 0.6103
# Epoch 100/2048
# 5s - loss: 0.6101 - val_loss: 0.6100
# Epoch 101/2048
# 7s - loss: 0.6098 - val_loss: 0.6099
# Epoch 102/2048
# 6s - loss: 0.6096 - val_loss: 0.6095
# Epoch 103/2048
# 6s - loss: 0.6094 - val_loss: 0.6095
# Epoch 104/2048
# 8s - loss: 0.6092 - val_loss: 0.6094
# Epoch 105/2048
# 8s - loss: 0.6090 - val_loss: 0.6093
# Epoch 106/2048
# 6s - loss: 0.6088 - val_loss: 0.6090
# Epoch 107/2048
# 7s - loss: 0.6086 - val_loss: 0.6090
# Epoch 108/2048
# 6s - loss: 0.6084 - val_loss: 0.6086
# Epoch 109/2048
# 1s - loss: 0.6082 - val_loss: 0.6086
# Epoch 110/2048
# 5s - loss: 0.6080 - val_loss: 0.6083
# Epoch 111/2048
# 5s - loss: 0.6078 - val_loss: 0.6082
# Epoch 112/2048
# 5s - loss: 0.6076 - val_loss: 0.6080
# Epoch 113/2048
# 4s - loss: 0.6074 - val_loss: 0.6080
# Epoch 114/2048
# 5s - loss: 0.6072 - val_loss: 0.6078
# Epoch 115/2048
# 5s - loss: 0.6070 - val_loss: 0.6076
# Epoch 116/2048
# 1s - loss: 0.6068 - val_loss: 0.6077
# Epoch 117/2048
# 4s - loss: 0.6068 - val_loss: 0.6074
# Epoch 118/2048
# 8s - loss: 0.6064 - val_loss: 0.6072
# Epoch 119/2048
# 1s - loss: 0.6063 - val_loss: 0.6072
# Epoch 120/2048
# 5s - loss: 0.6062 - val_loss: 0.6072
# Epoch 121/2048
# 4s - loss: 0.6059 - val_loss: 0.6069
# Epoch 122/2048
# 5s - loss: 0.6057 - val_loss: 0.6067
# Epoch 123/2048
# 6s - loss: 0.6055 - val_loss: 0.6065
# Epoch 124/2048
# 1s - loss: 0.6054 - val_loss: 0.6068
# Epoch 125/2048
# 6s - loss: 0.6053 - val_loss: 0.6065
# Epoch 126/2048
# 6s - loss: 0.6050 - val_loss: 0.6061
# Epoch 127/2048
# 6s - loss: 0.6049 - val_loss: 0.6060
# Epoch 128/2048
# 6s - loss: 0.6047 - val_loss: 0.6060
# Epoch 129/2048
# 6s - loss: 0.6046 - val_loss: 0.6058
# Epoch 130/2048
# 5s - loss: 0.6044 - val_loss: 0.6057
# Epoch 131/2048
# 5s - loss: 0.6042 - val_loss: 0.6056
# Epoch 132/2048
# 6s - loss: 0.6040 - val_loss: 0.6053
# Epoch 133/2048
# 6s - loss: 0.6039 - val_loss: 0.6052
# Epoch 134/2048
# 5s - loss: 0.6037 - val_loss: 0.6051
# Epoch 135/2048
# 5s - loss: 0.6036 - val_loss: 0.6050
# Epoch 136/2048
# 6s - loss: 0.6034 - val_loss: 0.6048
# Epoch 137/2048
# 6s - loss: 0.6033 - val_loss: 0.6048
# Epoch 138/2048
# 4s - loss: 0.6031 - val_loss: 0.6046
# Epoch 139/2048
# 4s - loss: 0.6029 - val_loss: 0.6044
# Epoch 140/2048
# 5s - loss: 0.6027 - val_loss: 0.6043
# Epoch 141/2048
# 8s - loss: 0.6026 - val_loss: 0.6042
# Epoch 142/2048
# 6s - loss: 0.6024 - val_loss: 0.6041
# Epoch 143/2048
# 4s - loss: 0.6023 - val_loss: 0.6040
# Epoch 144/2048
# 5s - loss: 0.6021 - val_loss: 0.6039
# Epoch 145/2048
# 5s - loss: 0.6020 - val_loss: 0.6038
# Epoch 146/2048
# 4s - loss: 0.6018 - val_loss: 0.6037
# Epoch 147/2048
# 5s - loss: 0.6017 - val_loss: 0.6037
# Epoch 148/2048
# 6s - loss: 0.6016 - val_loss: 0.6035
# Epoch 149/2048
# 4s - loss: 0.6014 - val_loss: 0.6033
# Epoch 150/2048
# 5s - loss: 0.6013 - val_loss: 0.6033
# Epoch 151/2048
# 4s - loss: 0.6011 - val_loss: 0.6031
# Epoch 152/2048
# 6s - loss: 0.6010 - val_loss: 0.6030
# Epoch 153/2048
# 3s - loss: 0.6008 - val_loss: 0.6029
# Epoch 154/2048
# 5s - loss: 0.6008 - val_loss: 0.6028
# Epoch 155/2048
# 4s - loss: 0.6006 - val_loss: 0.6025
# Epoch 156/2048
# 1s - loss: 0.6004 - val_loss: 0.6026
# Epoch 157/2048
# 5s - loss: 0.6003 - val_loss: 0.6025
# Epoch 158/2048
# 5s - loss: 0.6002 - val_loss: 0.6023
# Epoch 159/2048
# 6s - loss: 0.6000 - val_loss: 0.6023
# Epoch 160/2048
# 6s - loss: 0.5999 - val_loss: 0.6021
# Epoch 161/2048
# 7s - loss: 0.5997 - val_loss: 0.6020
# Epoch 162/2048
# 1s - loss: 0.5995 - val_loss: 0.6021
# Epoch 163/2048
# 6s - loss: 0.5995 - val_loss: 0.6019
# Epoch 164/2048
# 6s - loss: 0.5993 - val_loss: 0.6018
# Epoch 165/2048
# 6s - loss: 0.5992 - val_loss: 0.6017
# Epoch 166/2048
# 7s - loss: 0.5991 - val_loss: 0.6017
# Epoch 167/2048
# 3s - loss: 0.5989 - val_loss: 0.6016
# Epoch 168/2048
# 5s - loss: 0.5988 - val_loss: 0.6013
# Epoch 169/2048
# 1s - loss: 0.5986 - val_loss: 0.6014
# Epoch 170/2048
# 3s - loss: 0.5985 - val_loss: 0.6012
# Epoch 171/2048
# 5s - loss: 0.5984 - val_loss: 0.6011
# Epoch 172/2048
# 1s - loss: 0.5983 - val_loss: 0.6012
# Epoch 173/2048
# 4s - loss: 0.5982 - val_loss: 0.6010
# Epoch 174/2048
# 1s - loss: 0.5980 - val_loss: 0.6011
# Epoch 175/2048
# 4s - loss: 0.5979 - val_loss: 0.6009
# Epoch 176/2048
# 5s - loss: 0.5977 - val_loss: 0.6008
# Epoch 177/2048
# 6s - loss: 0.5975 - val_loss: 0.6007
# Epoch 178/2048
# 1s - loss: 0.5974 - val_loss: 0.6008
# Epoch 179/2048
# 3s - loss: 0.5973 - val_loss: 0.6003
# Epoch 180/2048
# 3s - loss: 0.5972 - val_loss: 0.6003
# Epoch 181/2048
# 5s - loss: 0.5970 - val_loss: 0.6001
# Epoch 182/2048
# 3s - loss: 0.5969 - val_loss: 0.6001
# Epoch 183/2048
# 3s - loss: 0.5968 - val_loss: 0.6001
# Epoch 184/2048
# 4s - loss: 0.5966 - val_loss: 0.5999
# Epoch 185/2048
# 1s - loss: 0.5965 - val_loss: 0.6000
# Epoch 186/2048
# 4s - loss: 0.5965 - val_loss: 0.5999
# Epoch 187/2048
# 5s - loss: 0.5962 - val_loss: 0.5997
# Epoch 188/2048
# 1s - loss: 0.5961 - val_loss: 0.6001
# Epoch 189/2048
# 5s - loss: 0.5961 - val_loss: 0.5995
# Epoch 190/2048
# 1s - loss: 0.5960 - val_loss: 0.5996
# Epoch 191/2048
# 5s - loss: 0.5958 - val_loss: 0.5994
# Epoch 192/2048
# 7s - loss: 0.5956 - val_loss: 0.5992
# Epoch 193/2048
# 1s - loss: 0.5955 - val_loss: 0.5992
# Epoch 194/2048
# 6s - loss: 0.5954 - val_loss: 0.5991
# Epoch 195/2048
# 1s - loss: 0.5952 - val_loss: 0.5991
# Epoch 196/2048
# 6s - loss: 0.5951 - val_loss: 0.5990
# Epoch 197/2048
# 6s - loss: 0.5950 - val_loss: 0.5987
# Epoch 198/2048
# 1s - loss: 0.5949 - val_loss: 0.5989
# Epoch 199/2048
# 4s - loss: 0.5948 - val_loss: 0.5986
# Epoch 200/2048
# 6s - loss: 0.5946 - val_loss: 0.5984
# Epoch 201/2048
# 1s - loss: 0.5945 - val_loss: 0.5985
# Epoch 202/2048
# 5s - loss: 0.5944 - val_loss: 0.5984
# Epoch 203/2048
# 1s - loss: 0.5943 - val_loss: 0.5984
# Epoch 204/2048
# 5s - loss: 0.5942 - val_loss: 0.5983
# Epoch 205/2048
# 4s - loss: 0.5941 - val_loss: 0.5982
# Epoch 206/2048
# 7s - loss: 0.5940 - val_loss: 0.5981
# Epoch 207/2048
# 7s - loss: 0.5938 - val_loss: 0.5979
# Epoch 208/2048
# 6s - loss: 0.5937 - val_loss: 0.5978
# Epoch 209/2048
# 1s - loss: 0.5936 - val_loss: 0.5978
# Epoch 210/2048
# 4s - loss: 0.5935 - val_loss: 0.5977
# Epoch 211/2048
# 6s - loss: 0.5934 - val_loss: 0.5975
# Epoch 212/2048
# 6s - loss: 0.5933 - val_loss: 0.5974
# Epoch 213/2048
# 7s - loss: 0.5931 - val_loss: 0.5973
# Epoch 214/2048
# 5s - loss: 0.5930 - val_loss: 0.5972
# Epoch 215/2048
# 1s - loss: 0.5930 - val_loss: 0.5973
# Epoch 216/2048
# 6s - loss: 0.5928 - val_loss: 0.5972
# Epoch 217/2048
# 1s - loss: 0.5927 - val_loss: 0.5973
# Epoch 218/2048
# 5s - loss: 0.5926 - val_loss: 0.5970
# Epoch 219/2048
# 1s - loss: 0.5925 - val_loss: 0.5971
# Epoch 220/2048
# 4s - loss: 0.5923 - val_loss: 0.5967
# Epoch 221/2048
# 1s - loss: 0.5922 - val_loss: 0.5968
# Epoch 222/2048
# 4s - loss: 0.5921 - val_loss: 0.5966
# Epoch 223/2048
# 1s - loss: 0.5920 - val_loss: 0.5967
# Epoch 224/2048
# 6s - loss: 0.5919 - val_loss: 0.5966
# Epoch 225/2048
# 6s - loss: 0.5918 - val_loss: 0.5965
# Epoch 226/2048
# 5s - loss: 0.5917 - val_loss: 0.5963
# Epoch 227/2048
# 1s - loss: 0.5916 - val_loss: 0.5963
# Epoch 228/2048
# 3s - loss: 0.5914 - val_loss: 0.5961
# Epoch 229/2048
# 1s - loss: 0.5914 - val_loss: 0.5961
# Epoch 230/2048
# 1s - loss: 0.5912 - val_loss: 0.5963
# Epoch 231/2048
# 4s - loss: 0.5911 - val_loss: 0.5960
# Epoch 232/2048
# 5s - loss: 0.5911 - val_loss: 0.5959
# Epoch 233/2048
# 1s - loss: 0.5909 - val_loss: 0.5959
# Epoch 234/2048
# 1s - loss: 0.5908 - val_loss: 0.5959
# Epoch 235/2048
# 3s - loss: 0.5908 - val_loss: 0.5958
# Epoch 236/2048
# 4s - loss: 0.5906 - val_loss: 0.5957
# Epoch 237/2048
# 6s - loss: 0.5905 - val_loss: 0.5956
# Epoch 238/2048
# 1s - loss: 0.5904 - val_loss: 0.5956
# Epoch 239/2048
# 4s - loss: 0.5903 - val_loss: 0.5954
# Epoch 240/2048
# 1s - loss: 0.5902 - val_loss: 0.5954
# Epoch 241/2048
# 1s - loss: 0.5901 - val_loss: 0.5954
# Epoch 242/2048
# 4s - loss: 0.5900 - val_loss: 0.5952
# Epoch 243/2048
# 5s - loss: 0.5898 - val_loss: 0.5951
# Epoch 244/2048
# 1s - loss: 0.5897 - val_loss: 0.5951
# Epoch 245/2048
# 3s - loss: 0.5897 - val_loss: 0.5951
# Epoch 246/2048
# 4s - loss: 0.5895 - val_loss: 0.5950
# Epoch 247/2048
# 4s - loss: 0.5894 - val_loss: 0.5948
# Epoch 248/2048
# 6s - loss: 0.5893 - val_loss: 0.5948
# Epoch 249/2048
# 4s - loss: 0.5892 - val_loss: 0.5948
# Epoch 250/2048
# 5s - loss: 0.5891 - val_loss: 0.5947
# Epoch 251/2048
# 5s - loss: 0.5890 - val_loss: 0.5946
# Epoch 252/2048
# 5s - loss: 0.5889 - val_loss: 0.5945
# Epoch 253/2048
# 6s - loss: 0.5888 - val_loss: 0.5943
# Epoch 254/2048
# 1s - loss: 0.5887 - val_loss: 0.5944
# Epoch 255/2048
# 1s - loss: 0.5886 - val_loss: 0.5944
# Epoch 256/2048
# 3s - loss: 0.5885 - val_loss: 0.5942
# Epoch 257/2048
# 1s - loss: 0.5884 - val_loss: 0.5943
# Epoch 258/2048
# 3s - loss: 0.5883 - val_loss: 0.5941
# Epoch 259/2048
# 3s - loss: 0.5882 - val_loss: 0.5940
# Epoch 260/2048
# 3s - loss: 0.5881 - val_loss: 0.5940
# Epoch 261/2048
# 6s - loss: 0.5880 - val_loss: 0.5938
# Epoch 262/2048
# 1s - loss: 0.5879 - val_loss: 0.5938
# Epoch 263/2048
# 1s - loss: 0.5878 - val_loss: 0.5939
# Epoch 264/2048
# 4s - loss: 0.5877 - val_loss: 0.5937
# Epoch 265/2048
# 5s - loss: 0.5876 - val_loss: 0.5936
# Epoch 266/2048
# 5s - loss: 0.5875 - val_loss: 0.5934
# Epoch 267/2048
# 1s - loss: 0.5874 - val_loss: 0.5937
# Epoch 268/2048
# 4s - loss: 0.5873 - val_loss: 0.5934
# Epoch 269/2048
# 1s - loss: 0.5872 - val_loss: 0.5934
# Epoch 270/2048
# 5s - loss: 0.5871 - val_loss: 0.5933
# Epoch 271/2048
# 1s - loss: 0.5870 - val_loss: 0.5933
# Epoch 272/2048
# 1s - loss: 0.5869 - val_loss: 0.5933
# Epoch 273/2048
# 1s - loss: 0.5869 - val_loss: 0.5934
# Epoch 274/2048
# 4s - loss: 0.5867 - val_loss: 0.5932
# Epoch 275/2048
# 2s - loss: 0.5866 - val_loss: 0.5930
# Epoch 276/2048
# 4s - loss: 0.5865 - val_loss: 0.5929
# Epoch 277/2048
# 4s - loss: 0.5864 - val_loss: 0.5928
# Epoch 278/2048
# 1s - loss: 0.5863 - val_loss: 0.5929
# Epoch 279/2048
# 1s - loss: 0.5862 - val_loss: 0.5928
# Epoch 280/2048
# 5s - loss: 0.5861 - val_loss: 0.5928
# Epoch 281/2048
# 7s - loss: 0.5860 - val_loss: 0.5927
# Epoch 282/2048
# 1s - loss: 0.5859 - val_loss: 0.5928
# Epoch 283/2048
# 6s - loss: 0.5858 - val_loss: 0.5927
# Epoch 284/2048
# 6s - loss: 0.5857 - val_loss: 0.5925
# Epoch 285/2048
# 4s - loss: 0.5856 - val_loss: 0.5923
# Epoch 286/2048
# 1s - loss: 0.5855 - val_loss: 0.5924
# Epoch 287/2048
# 1s - loss: 0.5854 - val_loss: 0.5924
# Epoch 288/2048
# 4s - loss: 0.5853 - val_loss: 0.5922
# Epoch 289/2048
# 6s - loss: 0.5852 - val_loss: 0.5922
# Epoch 290/2048
# 1s - loss: 0.5851 - val_loss: 0.5922
# Epoch 291/2048
# 4s - loss: 0.5850 - val_loss: 0.5921
# Epoch 292/2048
# 1s - loss: 0.5850 - val_loss: 0.5922
# Epoch 293/2048
# 4s - loss: 0.5849 - val_loss: 0.5920
# Epoch 294/2048
# 3s - loss: 0.5847 - val_loss: 0.5919
# Epoch 295/2048
# 1s - loss: 0.5847 - val_loss: 0.5919
# Epoch 296/2048
# 5s - loss: 0.5846 - val_loss: 0.5918
# Epoch 297/2048
# 5s - loss: 0.5845 - val_loss: 0.5917
# Epoch 298/2048
# 1s - loss: 0.5845 - val_loss: 0.5918
# Epoch 299/2048
# 5s - loss: 0.5844 - val_loss: 0.5917
# Epoch 300/2048
# 3s - loss: 0.5842 - val_loss: 0.5915
# Epoch 301/2048
# 5s - loss: 0.5841 - val_loss: 0.5914
# Epoch 302/2048
# 6s - loss: 0.5841 - val_loss: 0.5913
# Epoch 303/2048
# 1s - loss: 0.5840 - val_loss: 0.5913
# Epoch 304/2048
# 1s - loss: 0.5839 - val_loss: 0.5915
# Epoch 305/2048
# 4s - loss: 0.5838 - val_loss: 0.5913
# Epoch 306/2048
# 5s - loss: 0.5837 - val_loss: 0.5911
# Epoch 307/2048
# 1s - loss: 0.5836 - val_loss: 0.5913
# Epoch 308/2048
# 3s - loss: 0.5835 - val_loss: 0.5910
# Epoch 309/2048
# 6s - loss: 0.5835 - val_loss: 0.5910
# Epoch 310/2048
# 5s - loss: 0.5834 - val_loss: 0.5909
# Epoch 311/2048
# 3s - loss: 0.5832 - val_loss: 0.5908
# Epoch 312/2048
# 1s - loss: 0.5832 - val_loss: 0.5908
# Epoch 313/2048
# 1s - loss: 0.5831 - val_loss: 0.5908
# Epoch 314/2048
# 4s - loss: 0.5830 - val_loss: 0.5908
# Epoch 315/2048
# 3s - loss: 0.5829 - val_loss: 0.5907
# Epoch 316/2048
# 6s - loss: 0.5828 - val_loss: 0.5907
# Epoch 317/2048
# 5s - loss: 0.5827 - val_loss: 0.5905
# Epoch 318/2048
# 6s - loss: 0.5826 - val_loss: 0.5905
# Epoch 319/2048
# 5s - loss: 0.5825 - val_loss: 0.5904
# Epoch 320/2048
# 1s - loss: 0.5824 - val_loss: 0.5904
# Epoch 321/2048
# 1s - loss: 0.5823 - val_loss: 0.5905
# Epoch 322/2048
# 3s - loss: 0.5822 - val_loss: 0.5903
# Epoch 323/2048
# 1s - loss: 0.5821 - val_loss: 0.5904
# Epoch 324/2048
# 3s - loss: 0.5820 - val_loss: 0.5901
# Epoch 325/2048
# 5s - loss: 0.5819 - val_loss: 0.5900
# Epoch 326/2048
# 4s - loss: 0.5818 - val_loss: 0.5899
# Epoch 327/2048
# 1s - loss: 0.5817 - val_loss: 0.5901
# Epoch 328/2048
# 5s - loss: 0.5817 - val_loss: 0.5898
# Epoch 329/2048
# 5s - loss: 0.5815 - val_loss: 0.5897
# Epoch 330/2048
# 7s - loss: 0.5815 - val_loss: 0.5897
# Epoch 331/2048
# 3s - loss: 0.5813 - val_loss: 0.5896
# Epoch 332/2048
# 4s - loss: 0.5813 - val_loss: 0.5895
# Epoch 333/2048
# 1s - loss: 0.5811 - val_loss: 0.5895
# Epoch 334/2048
# 4s - loss: 0.5810 - val_loss: 0.5894
# Epoch 335/2048
# 4s - loss: 0.5809 - val_loss: 0.5892
# Epoch 336/2048
# 1s - loss: 0.5808 - val_loss: 0.5893
# Epoch 337/2048
# 5s - loss: 0.5807 - val_loss: 0.5892
# Epoch 338/2048
# 5s - loss: 0.5806 - val_loss: 0.5889
# Epoch 339/2048
# 1s - loss: 0.5805 - val_loss: 0.5890
# Epoch 340/2048
# 5s - loss: 0.5804 - val_loss: 0.5888
# Epoch 341/2048
# 5s - loss: 0.5803 - val_loss: 0.5888
# Epoch 342/2048
# 1s - loss: 0.5801 - val_loss: 0.5888
# Epoch 343/2048
# 4s - loss: 0.5800 - val_loss: 0.5884
# Epoch 344/2048
# 3s - loss: 0.5799 - val_loss: 0.5884
# Epoch 345/2048
# 3s - loss: 0.5798 - val_loss: 0.5882
# Epoch 346/2048
# 1s - loss: 0.5796 - val_loss: 0.5884
# Epoch 347/2048
# 3s - loss: 0.5795 - val_loss: 0.5881
# Epoch 348/2048
# 3s - loss: 0.5794 - val_loss: 0.5880
# Epoch 349/2048
# 3s - loss: 0.5792 - val_loss: 0.5880
# Epoch 350/2048
# 4s - loss: 0.5791 - val_loss: 0.5878
# Epoch 351/2048
# 1s - loss: 0.5790 - val_loss: 0.5878
# Epoch 352/2048
# 3s - loss: 0.5788 - val_loss: 0.5876
# Epoch 353/2048
# 4s - loss: 0.5787 - val_loss: 0.5876
# Epoch 354/2048
# 5s - loss: 0.5785 - val_loss: 0.5874
# Epoch 355/2048
# 6s - loss: 0.5784 - val_loss: 0.5872
# Epoch 356/2048
# 1s - loss: 0.5784 - val_loss: 0.5873
# Epoch 357/2048
# 4s - loss: 0.5782 - val_loss: 0.5872
# Epoch 358/2048
# 6s - loss: 0.5781 - val_loss: 0.5871
# Epoch 359/2048
# 5s - loss: 0.5780 - val_loss: 0.5871
# Epoch 360/2048
# 5s - loss: 0.5779 - val_loss: 0.5871
# Epoch 361/2048
# 6s - loss: 0.5778 - val_loss: 0.5869
# Epoch 362/2048
# 4s - loss: 0.5777 - val_loss: 0.5869
# Epoch 363/2048
# 4s - loss: 0.5776 - val_loss: 0.5868
# Epoch 364/2048
# 6s - loss: 0.5776 - val_loss: 0.5867
# Epoch 365/2048
# 1s - loss: 0.5774 - val_loss: 0.5868
# Epoch 366/2048
# 4s - loss: 0.5774 - val_loss: 0.5866
# Epoch 367/2048
# 1s - loss: 0.5773 - val_loss: 0.5866
# Epoch 368/2048
# 5s - loss: 0.5772 - val_loss: 0.5866
# Epoch 369/2048
# 5s - loss: 0.5771 - val_loss: 0.5865
# Epoch 370/2048
# 3s - loss: 0.5770 - val_loss: 0.5865
# Epoch 371/2048
# 5s - loss: 0.5769 - val_loss: 0.5863
# Epoch 372/2048
# 5s - loss: 0.5768 - val_loss: 0.5861
# Epoch 373/2048
# 1s - loss: 0.5768 - val_loss: 0.5862
# Epoch 374/2048
# 1s - loss: 0.5767 - val_loss: 0.5863
# Epoch 375/2048
# 1s - loss: 0.5766 - val_loss: 0.5862
# Epoch 376/2048
# 1s - loss: 0.5765 - val_loss: 0.5862
# Epoch 377/2048
# 3s - loss: 0.5764 - val_loss: 0.5859
# Epoch 378/2048
# 1s - loss: 0.5763 - val_loss: 0.5862
# Epoch 379/2048
# 6s - loss: 0.5762 - val_loss: 0.5857
# Epoch 380/2048
# 1s - loss: 0.5762 - val_loss: 0.5859
# Epoch 381/2048
# 4s - loss: 0.5761 - val_loss: 0.5857
# Epoch 382/2048
# 3s - loss: 0.5760 - val_loss: 0.5857
# Epoch 383/2048
# 5s - loss: 0.5759 - val_loss: 0.5855
# Epoch 384/2048
# 1s - loss: 0.5758 - val_loss: 0.5857
# Epoch 385/2048
# 4s - loss: 0.5757 - val_loss: 0.5855
# Epoch 386/2048
# 1s - loss: 0.5756 - val_loss: 0.5855
# Epoch 387/2048
# 10s - loss: 0.5756 - val_loss: 0.5853
# Epoch 388/2048
# 1s - loss: 0.5756 - val_loss: 0.5854
# Epoch 389/2048
# 4s - loss: 0.5755 - val_loss: 0.5853
# Epoch 390/2048
# 3s - loss: 0.5753 - val_loss: 0.5851
# Epoch 391/2048
# 1s - loss: 0.5753 - val_loss: 0.5852
# Epoch 392/2048
# 5s - loss: 0.5752 - val_loss: 0.5851
# Epoch 393/2048
# 3s - loss: 0.5751 - val_loss: 0.5851
# Epoch 394/2048
# 4s - loss: 0.5751 - val_loss: 0.5850
# Epoch 395/2048
# 5s - loss: 0.5750 - val_loss: 0.5850
# Epoch 396/2048
# 5s - loss: 0.5749 - val_loss: 0.5849
# Epoch 397/2048
# 4s - loss: 0.5748 - val_loss: 0.5848
# Epoch 398/2048
# 1s - loss: 0.5748 - val_loss: 0.5848
# Epoch 399/2048
# 1s - loss: 0.5747 - val_loss: 0.5849
# Epoch 400/2048
# 1s - loss: 0.5746 - val_loss: 0.5848
# Epoch 401/2048
# 4s - loss: 0.5745 - val_loss: 0.5847
# Epoch 402/2048
# 1s - loss: 0.5744 - val_loss: 0.5848
# Epoch 403/2048
# 3s - loss: 0.5744 - val_loss: 0.5846
# Epoch 404/2048
# 3s - loss: 0.5743 - val_loss: 0.5844
# Epoch 405/2048
# 1s - loss: 0.5742 - val_loss: 0.5846
# Epoch 406/2048
# 1s - loss: 0.5742 - val_loss: 0.5846
# Epoch 407/2048
# 1s - loss: 0.5741 - val_loss: 0.5846
# Epoch 408/2048
# 1s - loss: 0.5740 - val_loss: 0.5845
# Epoch 409/2048
# 1s - loss: 0.5739 - val_loss: 0.5845
# Epoch 410/2048
# 4s - loss: 0.5738 - val_loss: 0.5842
# Epoch 411/2048
# 1s - loss: 0.5738 - val_loss: 0.5843
# Epoch 412/2048
# 1s - loss: 0.5737 - val_loss: 0.5843
# Epoch 413/2048
# 1s - loss: 0.5736 - val_loss: 0.5842
# Epoch 414/2048
# 2s - loss: 0.5736 - val_loss: 0.5841
# Epoch 415/2048
# 4s - loss: 0.5735 - val_loss: 0.5841
# Epoch 416/2048
# 1s - loss: 0.5734 - val_loss: 0.5841
# Epoch 417/2048
# 7s - loss: 0.5733 - val_loss: 0.5839
# Epoch 418/2048
# 6s - loss: 0.5733 - val_loss: 0.5839
# Epoch 419/2048
# 1s - loss: 0.5732 - val_loss: 0.5839
# Epoch 420/2048
# 1s - loss: 0.5731 - val_loss: 0.5840
# Epoch 421/2048
# 3s - loss: 0.5730 - val_loss: 0.5837
# Epoch 422/2048
# 1s - loss: 0.5730 - val_loss: 0.5837
# Epoch 423/2048
# 4s - loss: 0.5729 - val_loss: 0.5836
# Epoch 424/2048
# 3s - loss: 0.5728 - val_loss: 0.5835
# Epoch 425/2048
# 1s - loss: 0.5728 - val_loss: 0.5835
# Epoch 426/2048
# 1s - loss: 0.5727 - val_loss: 0.5836
# Epoch 427/2048
# 4s - loss: 0.5726 - val_loss: 0.5834
# Epoch 428/2048
# 5s - loss: 0.5726 - val_loss: 0.5834
# Epoch 429/2048
# 4s - loss: 0.5725 - val_loss: 0.5833
# Epoch 430/2048
# 1s - loss: 0.5724 - val_loss: 0.5834
# Epoch 431/2048
# 6s - loss: 0.5724 - val_loss: 0.5832
# Epoch 432/2048
# 1s - loss: 0.5723 - val_loss: 0.5834
# Epoch 433/2048
# 1s - loss: 0.5722 - val_loss: 0.5834
# Epoch 434/2048
# 3s - loss: 0.5722 - val_loss: 0.5832
# Epoch 435/2048
# 3s - loss: 0.5721 - val_loss: 0.5831
# Epoch 436/2048
# 5s - loss: 0.5720 - val_loss: 0.5830
# Epoch 437/2048
# 1s - loss: 0.5719 - val_loss: 0.5831
# Epoch 438/2048
# 1s - loss: 0.5719 - val_loss: 0.5830
# Epoch 439/2048
# 5s - loss: 0.5718 - val_loss: 0.5829
# Epoch 440/2048
# 1s - loss: 0.5717 - val_loss: 0.5830
# Epoch 441/2048
# 1s - loss: 0.5717 - val_loss: 0.5830
# Epoch 442/2048
# 3s - loss: 0.5716 - val_loss: 0.5829
# Epoch 443/2048
# 4s - loss: 0.5715 - val_loss: 0.5829
# Epoch 444/2048
# 4s - loss: 0.5715 - val_loss: 0.5825
# Epoch 445/2048
# 1s - loss: 0.5714 - val_loss: 0.5827
# Epoch 446/2048
# 1s - loss: 0.5713 - val_loss: 0.5826
# Epoch 447/2048
# 5s - loss: 0.5713 - val_loss: 0.5825
# Epoch 448/2048
# 1s - loss: 0.5712 - val_loss: 0.5826
# Epoch 449/2048
# 1s - loss: 0.5711 - val_loss: 0.5825
# Epoch 450/2048
# 1s - loss: 0.5711 - val_loss: 0.5825
# Epoch 451/2048
# 2s - loss: 0.5710 - val_loss: 0.5824
# Epoch 452/2048
# 1s - loss: 0.5710 - val_loss: 0.5825
# Epoch 453/2048
# 3s - loss: 0.5709 - val_loss: 0.5823
# Epoch 454/2048
# 1s - loss: 0.5708 - val_loss: 0.5824
# Epoch 455/2048
# 4s - loss: 0.5707 - val_loss: 0.5822
# Epoch 456/2048
# 1s - loss: 0.5707 - val_loss: 0.5822
# Epoch 457/2048
# 4s - loss: 0.5706 - val_loss: 0.5822
# Epoch 458/2048
# 5s - loss: 0.5705 - val_loss: 0.5821
# Epoch 459/2048
# 1s - loss: 0.5705 - val_loss: 0.5822
# Epoch 460/2048
# 1s - loss: 0.5704 - val_loss: 0.5822
# Epoch 461/2048
# 3s - loss: 0.5704 - val_loss: 0.5821
# Epoch 462/2048
# 5s - loss: 0.5703 - val_loss: 0.5821
# Epoch 463/2048
# 5s - loss: 0.5702 - val_loss: 0.5818
# Epoch 464/2048
# 1s - loss: 0.5702 - val_loss: 0.5821
# Epoch 465/2048
# 1s - loss: 0.5701 - val_loss: 0.5821
# Epoch 466/2048
# 2s - loss: 0.5700 - val_loss: 0.5818
# Epoch 467/2048
# 1s - loss: 0.5699 - val_loss: 0.5819
# Epoch 468/2048
# 5s - loss: 0.5699 - val_loss: 0.5817
# Epoch 469/2048
# 1s - loss: 0.5698 - val_loss: 0.5817
# Epoch 470/2048
# 1s - loss: 0.5697 - val_loss: 0.5817
# Epoch 471/2048
# 4s - loss: 0.5697 - val_loss: 0.5815
# Epoch 472/2048
# 1s - loss: 0.5696 - val_loss: 0.5816
# Epoch 473/2048
# 1s - loss: 0.5696 - val_loss: 0.5816
# Epoch 474/2048
# 1s - loss: 0.5695 - val_loss: 0.5816
# Epoch 475/2048
# 3s - loss: 0.5694 - val_loss: 0.5815
# Epoch 476/2048
# 4s - loss: 0.5694 - val_loss: 0.5813
# Epoch 477/2048
# 1s - loss: 0.5693 - val_loss: 0.5815
# Epoch 478/2048
# 6s - loss: 0.5693 - val_loss: 0.5813
# Epoch 479/2048
# 5s - loss: 0.5692 - val_loss: 0.5813
# Epoch 480/2048
# 1s - loss: 0.5691 - val_loss: 0.5813
# Epoch 481/2048
# 4s - loss: 0.5691 - val_loss: 0.5811
# Epoch 482/2048
# 1s - loss: 0.5690 - val_loss: 0.5812
# Epoch 483/2048
# 5s - loss: 0.5690 - val_loss: 0.5811
# Epoch 484/2048
# 6s - loss: 0.5689 - val_loss: 0.5811
# Epoch 485/2048
# 3s - loss: 0.5688 - val_loss: 0.5810
# Epoch 486/2048
# 4s - loss: 0.5688 - val_loss: 0.5809
# Epoch 487/2048
# 1s - loss: 0.5687 - val_loss: 0.5811
# Epoch 488/2048
# 3s - loss: 0.5687 - val_loss: 0.5809
# Epoch 489/2048
# 1s - loss: 0.5686 - val_loss: 0.5810
# Epoch 490/2048
# 5s - loss: 0.5686 - val_loss: 0.5808
# Epoch 491/2048
# 1s - loss: 0.5685 - val_loss: 0.5810
# Epoch 492/2048
# 6s - loss: 0.5684 - val_loss: 0.5807
# Epoch 493/2048
# 1s - loss: 0.5683 - val_loss: 0.5808
# Epoch 494/2048
# 3s - loss: 0.5683 - val_loss: 0.5806
# Epoch 495/2048
# 5s - loss: 0.5682 - val_loss: 0.5806
# Epoch 496/2048
# 1s - loss: 0.5682 - val_loss: 0.5806
# Epoch 497/2048
# 1s - loss: 0.5681 - val_loss: 0.5806
# Epoch 498/2048
# 3s - loss: 0.5681 - val_loss: 0.5806
# Epoch 499/2048
# 6s - loss: 0.5680 - val_loss: 0.5805
# Epoch 500/2048
# 2s - loss: 0.5679 - val_loss: 0.5804
# Epoch 501/2048
# 1s - loss: 0.5679 - val_loss: 0.5806
# Epoch 502/2048
# 5s - loss: 0.5678 - val_loss: 0.5803
# Epoch 503/2048
# 4s - loss: 0.5678 - val_loss: 0.5803
# Epoch 504/2048
# 1s - loss: 0.5677 - val_loss: 0.5803
# Epoch 505/2048
# 3s - loss: 0.5677 - val_loss: 0.5801
# Epoch 506/2048
# 1s - loss: 0.5676 - val_loss: 0.5803
# Epoch 507/2048
# 1s - loss: 0.5676 - val_loss: 0.5802
# Epoch 508/2048
# 4s - loss: 0.5675 - val_loss: 0.5800
# Epoch 509/2048
# 1s - loss: 0.5675 - val_loss: 0.5802
# Epoch 510/2048
# 1s - loss: 0.5674 - val_loss: 0.5802
# Epoch 511/2048
# 4s - loss: 0.5673 - val_loss: 0.5800
# Epoch 512/2048
# 5s - loss: 0.5673 - val_loss: 0.5799
# Epoch 513/2048
# 6s - loss: 0.5672 - val_loss: 0.5799
# Epoch 514/2048
# 3s - loss: 0.5671 - val_loss: 0.5798
# Epoch 515/2048
# 2s - loss: 0.5671 - val_loss: 0.5797
# Epoch 516/2048
# 6s - loss: 0.5670 - val_loss: 0.5797
# Epoch 517/2048
# 1s - loss: 0.5670 - val_loss: 0.5798
# Epoch 518/2048
# 1s - loss: 0.5669 - val_loss: 0.5797
# Epoch 519/2048
# 3s - loss: 0.5669 - val_loss: 0.5795
# Epoch 520/2048
# 3s - loss: 0.5668 - val_loss: 0.5795
# Epoch 521/2048
# 1s - loss: 0.5667 - val_loss: 0.5796
# Epoch 522/2048
# 1s - loss: 0.5667 - val_loss: 0.5796
# Epoch 523/2048
# 1s - loss: 0.5666 - val_loss: 0.5798
# Epoch 524/2048
# 1s - loss: 0.5666 - val_loss: 0.5796
# Epoch 525/2048
# 3s - loss: 0.5665 - val_loss: 0.5793
# Epoch 526/2048
# 1s - loss: 0.5665 - val_loss: 0.5795
# Epoch 527/2048
# 1s - loss: 0.5664 - val_loss: 0.5794
# Epoch 528/2048
# 1s - loss: 0.5663 - val_loss: 0.5796
# Epoch 529/2048
# 1s - loss: 0.5663 - val_loss: 0.5795
# Epoch 530/2048
# 1s - loss: 0.5662 - val_loss: 0.5793
# Epoch 531/2048
# 1s - loss: 0.5662 - val_loss: 0.5793
# Epoch 532/2048
# 1s - loss: 0.5661 - val_loss: 0.5793
# Epoch 533/2048
# 3s - loss: 0.5661 - val_loss: 0.5792
# Epoch 534/2048
# 1s - loss: 0.5660 - val_loss: 0.5792
# Epoch 535/2048
# 3s - loss: 0.5660 - val_loss: 0.5791
# Epoch 536/2048
# 2s - loss: 0.5659 - val_loss: 0.5790
# Epoch 537/2048
# 3s - loss: 0.5659 - val_loss: 0.5790
# Epoch 538/2048
# 1s - loss: 0.5658 - val_loss: 0.5792
# Epoch 539/2048
# 5s - loss: 0.5658 - val_loss: 0.5788
# Epoch 540/2048
# 1s - loss: 0.5657 - val_loss: 0.5789
# Epoch 541/2048
# 1s - loss: 0.5656 - val_loss: 0.5789
# Epoch 542/2048
# 3s - loss: 0.5656 - val_loss: 0.5788
# Epoch 543/2048
# 1s - loss: 0.5655 - val_loss: 0.5788
# Epoch 544/2048
# 1s - loss: 0.5655 - val_loss: 0.5789
# Epoch 545/2048
# 1s - loss: 0.5654 - val_loss: 0.5790
# Epoch 546/2048
# 3s - loss: 0.5654 - val_loss: 0.5787
# Epoch 547/2048
# 4s - loss: 0.5653 - val_loss: 0.5785
# Epoch 548/2048
# 1s - loss: 0.5653 - val_loss: 0.5786
# Epoch 549/2048
# 5s - loss: 0.5652 - val_loss: 0.5785
# Epoch 550/2048
# 1s - loss: 0.5652 - val_loss: 0.5786
# Epoch 551/2048
# 1s - loss: 0.5651 - val_loss: 0.5787
# Epoch 552/2048
# 3s - loss: 0.5651 - val_loss: 0.5785
# Epoch 553/2048
# 1s - loss: 0.5650 - val_loss: 0.5787
# Epoch 554/2048
# 1s - loss: 0.5651 - val_loss: 0.5785
# Epoch 555/2048
# 4s - loss: 0.5649 - val_loss: 0.5784
# Epoch 556/2048
# 1s - loss: 0.5648 - val_loss: 0.5785
# Epoch 557/2048
# 5s - loss: 0.5648 - val_loss: 0.5783
# Epoch 558/2048
# 1s - loss: 0.5647 - val_loss: 0.5784
# Epoch 559/2048
# 2s - loss: 0.5648 - val_loss: 0.5782
# Epoch 560/2048
# 1s - loss: 0.5646 - val_loss: 0.5785
# Epoch 561/2048
# 3s - loss: 0.5646 - val_loss: 0.5782
# Epoch 562/2048
# 3s - loss: 0.5645 - val_loss: 0.5781
# Epoch 563/2048
# 1s - loss: 0.5645 - val_loss: 0.5781
# Epoch 564/2048
# 1s - loss: 0.5644 - val_loss: 0.5783
# Epoch 565/2048
# 5s - loss: 0.5644 - val_loss: 0.5779
# Epoch 566/2048
# 1s - loss: 0.5644 - val_loss: 0.5781
# Epoch 567/2048
# 1s - loss: 0.5643 - val_loss: 0.5782
# Epoch 568/2048
# 1s - loss: 0.5642 - val_loss: 0.5784
# Epoch 569/2048
# 3s - loss: 0.5642 - val_loss: 0.5779
# Epoch 570/2048
# 1s - loss: 0.5641 - val_loss: 0.5780
# Epoch 571/2048
# 1s - loss: 0.5641 - val_loss: 0.5780
# Epoch 572/2048
# 3s - loss: 0.5640 - val_loss: 0.5777
# Epoch 573/2048
# 1s - loss: 0.5640 - val_loss: 0.5778
# Epoch 574/2048
# 1s - loss: 0.5639 - val_loss: 0.5780
# Epoch 575/2048
# 3s - loss: 0.5639 - val_loss: 0.5776
# Epoch 576/2048
# 3s - loss: 0.5638 - val_loss: 0.5776
# Epoch 577/2048
# 1s - loss: 0.5638 - val_loss: 0.5776
# Epoch 578/2048
# 1s - loss: 0.5637 - val_loss: 0.5776
# Epoch 579/2048
# 1s - loss: 0.5637 - val_loss: 0.5776
# Epoch 580/2048
# 4s - loss: 0.5636 - val_loss: 0.5775
# Epoch 581/2048
# 1s - loss: 0.5635 - val_loss: 0.5776
# Epoch 582/2048
# 1s - loss: 0.5635 - val_loss: 0.5776
# Epoch 583/2048
# 4s - loss: 0.5635 - val_loss: 0.5773
# Epoch 584/2048
# 1s - loss: 0.5634 - val_loss: 0.5775
# Epoch 585/2048
# 1s - loss: 0.5634 - val_loss: 0.5775
# Epoch 586/2048
# 4s - loss: 0.5633 - val_loss: 0.5772
# Epoch 587/2048
# 1s - loss: 0.5633 - val_loss: 0.5773
# Epoch 588/2048
# 1s - loss: 0.5632 - val_loss: 0.5773
# Epoch 589/2048
# 1s - loss: 0.5632 - val_loss: 0.5774
# Epoch 590/2048
# 1s - loss: 0.5631 - val_loss: 0.5772
# Epoch 591/2048
# 3s - loss: 0.5631 - val_loss: 0.5772
# Epoch 592/2048
# 4s - loss: 0.5630 - val_loss: 0.5772
# Epoch 593/2048
# 3s - loss: 0.5630 - val_loss: 0.5771
# Epoch 594/2048
# 1s - loss: 0.5630 - val_loss: 0.5773
# Epoch 595/2048
# 6s - loss: 0.5629 - val_loss: 0.5770
# Epoch 596/2048
# 1s - loss: 0.5628 - val_loss: 0.5771
# Epoch 597/2048
# 4s - loss: 0.5628 - val_loss: 0.5768
# Epoch 598/2048
# 1s - loss: 0.5627 - val_loss: 0.5770
# Epoch 599/2048
# 1s - loss: 0.5627 - val_loss: 0.5769
# Epoch 600/2048
# 1s - loss: 0.5627 - val_loss: 0.5771
# Epoch 601/2048
# 1s - loss: 0.5627 - val_loss: 0.5769
# Epoch 602/2048
# 2s - loss: 0.5626 - val_loss: 0.5768
# Epoch 603/2048
# 5s - loss: 0.5625 - val_loss: 0.5767
# Epoch 604/2048
# 1s - loss: 0.5625 - val_loss: 0.5769
# Epoch 605/2048
# 3s - loss: 0.5625 - val_loss: 0.5766
# Epoch 606/2048
# 1s - loss: 0.5624 - val_loss: 0.5768
# Epoch 607/2048
# 1s - loss: 0.5624 - val_loss: 0.5766
# Epoch 608/2048
# 5s - loss: 0.5623 - val_loss: 0.5765
# Epoch 609/2048
# 1s - loss: 0.5622 - val_loss: 0.5767
# Epoch 610/2048
# 1s - loss: 0.5622 - val_loss: 0.5765
# Epoch 611/2048
# 1s - loss: 0.5622 - val_loss: 0.5768
# Epoch 612/2048
# 3s - loss: 0.5621 - val_loss: 0.5765
# Epoch 613/2048
# 5s - loss: 0.5621 - val_loss: 0.5764
# Epoch 614/2048
# 1s - loss: 0.5620 - val_loss: 0.5765
# Epoch 615/2048
# 1s - loss: 0.5620 - val_loss: 0.5765
# Epoch 616/2048
# 1s - loss: 0.5619 - val_loss: 0.5765
# Epoch 617/2048
# 3s - loss: 0.5619 - val_loss: 0.5763
# Epoch 618/2048
# 1s - loss: 0.5619 - val_loss: 0.5764
# Epoch 619/2048
# 6s - loss: 0.5618 - val_loss: 0.5763
# Epoch 620/2048
# 6s - loss: 0.5617 - val_loss: 0.5761
# Epoch 621/2048
# 1s - loss: 0.5617 - val_loss: 0.5763
# Epoch 622/2048
# 1s - loss: 0.5617 - val_loss: 0.5762
# Epoch 623/2048
# 1s - loss: 0.5616 - val_loss: 0.5761
# Epoch 624/2048
# 1s - loss: 0.5616 - val_loss: 0.5762
# Epoch 625/2048
# 1s - loss: 0.5616 - val_loss: 0.5763
# Epoch 626/2048
# 1s - loss: 0.5615 - val_loss: 0.5764
# Epoch 627/2048
# 3s - loss: 0.5615 - val_loss: 0.5761
# Epoch 628/2048
# 3s - loss: 0.5614 - val_loss: 0.5760
# Epoch 629/2048
# 4s - loss: 0.5613 - val_loss: 0.5760
# Epoch 630/2048
# 4s - loss: 0.5613 - val_loss: 0.5759
# Epoch 631/2048
# 4s - loss: 0.5613 - val_loss: 0.5759
# Epoch 632/2048
# 1s - loss: 0.5612 - val_loss: 0.5764
# Epoch 633/2048
# 3s - loss: 0.5613 - val_loss: 0.5758
# Epoch 634/2048
# 5s - loss: 0.5611 - val_loss: 0.5757
# Epoch 635/2048
# 1s - loss: 0.5611 - val_loss: 0.5758
# Epoch 636/2048
# 1s - loss: 0.5611 - val_loss: 0.5759
# Epoch 637/2048
# 1s - loss: 0.5610 - val_loss: 0.5758
# Epoch 638/2048
# 1s - loss: 0.5610 - val_loss: 0.5757
# Epoch 639/2048
# 1s - loss: 0.5609 - val_loss: 0.5757
# Epoch 640/2048
# 1s - loss: 0.5609 - val_loss: 0.5758
# Epoch 641/2048
# 1s - loss: 0.5609 - val_loss: 0.5759
# Epoch 642/2048
# 4s - loss: 0.5608 - val_loss: 0.5755
# Epoch 643/2048
# 3s - loss: 0.5608 - val_loss: 0.5753
# Epoch 644/2048
# 6s - loss: 0.5607 - val_loss: 0.5753
# Epoch 645/2048
# 1s - loss: 0.5607 - val_loss: 0.5756
# Epoch 646/2048
# 1s - loss: 0.5606 - val_loss: 0.5754
# Epoch 647/2048
# 1s - loss: 0.5606 - val_loss: 0.5754
# Epoch 648/2048
# 1s - loss: 0.5605 - val_loss: 0.5754
# Epoch 649/2048
# 1s - loss: 0.5605 - val_loss: 0.5753
# Epoch 650/2048
# 1s - loss: 0.5604 - val_loss: 0.5754
# Epoch 651/2048
# 1s - loss: 0.5604 - val_loss: 0.5753
# Epoch 652/2048
# 3s - loss: 0.5604 - val_loss: 0.5752
# Epoch 653/2048
# 1s - loss: 0.5603 - val_loss: 0.5754
# Epoch 654/2048
# 1s - loss: 0.5603 - val_loss: 0.5753
# Epoch 655/2048
# 4s - loss: 0.5603 - val_loss: 0.5752
# Epoch 656/2048
# 3s - loss: 0.5602 - val_loss: 0.5751
# Epoch 657/2048
# 4s - loss: 0.5602 - val_loss: 0.5751
# Epoch 658/2048
# 1s - loss: 0.5601 - val_loss: 0.5752
# Epoch 659/2048
# 5s - loss: 0.5601 - val_loss: 0.5751
# Epoch 660/2048
# 1s - loss: 0.5601 - val_loss: 0.5751
# Epoch 661/2048
# 1s - loss: 0.5600 - val_loss: 0.5753
# Epoch 662/2048
# 1s - loss: 0.5600 - val_loss: 0.5752
# Epoch 663/2048
# 4s - loss: 0.5599 - val_loss: 0.5750
# Epoch 664/2048
# 5s - loss: 0.5599 - val_loss: 0.5748
# Epoch 665/2048
# 1s - loss: 0.5598 - val_loss: 0.5749
# Epoch 666/2048
# 1s - loss: 0.5598 - val_loss: 0.5749
# Epoch 667/2048
# 1s - loss: 0.5598 - val_loss: 0.5750
# Epoch 668/2048
# 1s - loss: 0.5597 - val_loss: 0.5750
# Epoch 669/2048
# 4s - loss: 0.5597 - val_loss: 0.5747
# Epoch 670/2048
# 3s - loss: 0.5596 - val_loss: 0.5745
# Epoch 671/2048
# 1s - loss: 0.5596 - val_loss: 0.5748
# Epoch 672/2048
# 1s - loss: 0.5596 - val_loss: 0.5747
# Epoch 673/2048
# 1s - loss: 0.5595 - val_loss: 0.5745
# Epoch 674/2048
# 1s - loss: 0.5594 - val_loss: 0.5746
# Epoch 675/2048
# 1s - loss: 0.5594 - val_loss: 0.5746
# Epoch 676/2048
# 1s - loss: 0.5594 - val_loss: 0.5745
# Epoch 677/2048
# 2s - loss: 0.5594 - val_loss: 0.5745
# Epoch 678/2048
# 5s - loss: 0.5593 - val_loss: 0.5745
# Epoch 679/2048
# 2s - loss: 0.5593 - val_loss: 0.5744
# Epoch 680/2048
# 4s - loss: 0.5592 - val_loss: 0.5744
# Epoch 681/2048
# 1s - loss: 0.5591 - val_loss: 0.5745
# Epoch 682/2048
# 1s - loss: 0.5591 - val_loss: 0.5744
# Epoch 683/2048
# 3s - loss: 0.5590 - val_loss: 0.5744
# Epoch 684/2048
# 1s - loss: 0.5591 - val_loss: 0.5744
# Epoch 685/2048
# 4s - loss: 0.5590 - val_loss: 0.5743
# Epoch 686/2048
# 1s - loss: 0.5590 - val_loss: 0.5743
# Epoch 687/2048
# 4s - loss: 0.5590 - val_loss: 0.5741
# Epoch 688/2048
# 1s - loss: 0.5589 - val_loss: 0.5741
# Epoch 689/2048
# 1s - loss: 0.5588 - val_loss: 0.5743
# Epoch 690/2048
# 1s - loss: 0.5588 - val_loss: 0.5741
# Epoch 691/2048
# 1s - loss: 0.5588 - val_loss: 0.5741
# Epoch 692/2048
# 1s - loss: 0.5587 - val_loss: 0.5743
# Epoch 693/2048
# 2s - loss: 0.5587 - val_loss: 0.5741
# Epoch 694/2048
# 4s - loss: 0.5587 - val_loss: 0.5741
# Epoch 695/2048
# 2s - loss: 0.5586 - val_loss: 0.5739
# Epoch 696/2048
# 2s - loss: 0.5586 - val_loss: 0.5739
# Epoch 697/2048
# 1s - loss: 0.5586 - val_loss: 0.5741
# Epoch 698/2048
# 1s - loss: 0.5585 - val_loss: 0.5740
# Epoch 699/2048
# 4s - loss: 0.5585 - val_loss: 0.5737
# Epoch 700/2048
# 1s - loss: 0.5584 - val_loss: 0.5741
# Epoch 701/2048
# 3s - loss: 0.5583 - val_loss: 0.5737
# Epoch 702/2048
# 1s - loss: 0.5583 - val_loss: 0.5739
# Epoch 703/2048
# 1s - loss: 0.5583 - val_loss: 0.5739
# Epoch 704/2048
# 5s - loss: 0.5583 - val_loss: 0.5735
# Epoch 705/2048
# 1s - loss: 0.5582 - val_loss: 0.5738
# Epoch 706/2048
# 1s - loss: 0.5582 - val_loss: 0.5740
# Epoch 707/2048
# 1s - loss: 0.5581 - val_loss: 0.5737
# Epoch 708/2048
# 1s - loss: 0.5581 - val_loss: 0.5737
# Epoch 709/2048
# 1s - loss: 0.5580 - val_loss: 0.5735
# Epoch 710/2048
# 1s - loss: 0.5581 - val_loss: 0.5738
# Epoch 711/2048
# 1s - loss: 0.5579 - val_loss: 0.5735
# Epoch 712/2048
# 3s - loss: 0.5579 - val_loss: 0.5735
# Epoch 713/2048
# 3s - loss: 0.5579 - val_loss: 0.5734
# Epoch 714/2048
# 1s - loss: 0.5578 - val_loss: 0.5735
# Epoch 715/2048
# 1s - loss: 0.5578 - val_loss: 0.5737
# Epoch 716/2048
# 1s - loss: 0.5578 - val_loss: 0.5736
# Epoch 717/2048
# 1s - loss: 0.5577 - val_loss: 0.5735
# Epoch 718/2048
# 1s - loss: 0.5577 - val_loss: 0.5734
# Epoch 719/2048
# 1s - loss: 0.5576 - val_loss: 0.5734
# Epoch 720/2048
# 2s - loss: 0.5576 - val_loss: 0.5732
# Epoch 721/2048
# 1s - loss: 0.5576 - val_loss: 0.5734
# Epoch 722/2048
# 1s - loss: 0.5575 - val_loss: 0.5733
# Epoch 723/2048
# 3s - loss: 0.5575 - val_loss: 0.5732
# Epoch 724/2048
# 4s - loss: 0.5575 - val_loss: 0.5731
# Epoch 725/2048
# 1s - loss: 0.5574 - val_loss: 0.5732
# Epoch 726/2048
# 1s - loss: 0.5574 - val_loss: 0.5734
# Epoch 727/2048
# 4s - loss: 0.5574 - val_loss: 0.5730
# Epoch 728/2048
# 1s - loss: 0.5573 - val_loss: 0.5731
# Epoch 729/2048
# 1s - loss: 0.5573 - val_loss: 0.5733
# Epoch 730/2048
# 1s - loss: 0.5572 - val_loss: 0.5731
# Epoch 731/2048
# 1s - loss: 0.5572 - val_loss: 0.5732
# Epoch 732/2048
# 4s - loss: 0.5572 - val_loss: 0.5729
# Epoch 733/2048
# 1s - loss: 0.5572 - val_loss: 0.5731
# Epoch 734/2048
# 1s - loss: 0.5571 - val_loss: 0.5730
# Epoch 735/2048
# 1s - loss: 0.5570 - val_loss: 0.5730
# Epoch 736/2048
# 2s - loss: 0.5570 - val_loss: 0.5728
# Epoch 737/2048
# 1s - loss: 0.5570 - val_loss: 0.5728
# Epoch 738/2048
# 1s - loss: 0.5569 - val_loss: 0.5732
# Epoch 739/2048
# 4s - loss: 0.5569 - val_loss: 0.5728
# Epoch 740/2048
# 1s - loss: 0.5568 - val_loss: 0.5728
# Epoch 741/2048
# 5s - loss: 0.5568 - val_loss: 0.5727
# Epoch 742/2048
# 3s - loss: 0.5568 - val_loss: 0.5724
# Epoch 743/2048
# 1s - loss: 0.5567 - val_loss: 0.5726
# Epoch 744/2048
# 1s - loss: 0.5567 - val_loss: 0.5727
# Epoch 745/2048
# 1s - loss: 0.5566 - val_loss: 0.5726
# Epoch 746/2048
# 1s - loss: 0.5566 - val_loss: 0.5726
# Epoch 747/2048
# 1s - loss: 0.5566 - val_loss: 0.5724
# Epoch 748/2048
# 2s - loss: 0.5566 - val_loss: 0.5724
# Epoch 749/2048
# 1s - loss: 0.5565 - val_loss: 0.5724
# Epoch 750/2048
# 1s - loss: 0.5564 - val_loss: 0.5725
# Epoch 751/2048
# 5s - loss: 0.5564 - val_loss: 0.5723
# Epoch 752/2048
# 1s - loss: 0.5564 - val_loss: 0.5723
# Epoch 753/2048
# 1s - loss: 0.5563 - val_loss: 0.5724
# Epoch 754/2048
# 4s - loss: 0.5563 - val_loss: 0.5722
# Epoch 755/2048
# 1s - loss: 0.5562 - val_loss: 0.5726
# Epoch 756/2048
# 3s - loss: 0.5562 - val_loss: 0.5719
# Epoch 757/2048
# 1s - loss: 0.5562 - val_loss: 0.5723
# Epoch 758/2048
# 1s - loss: 0.5561 - val_loss: 0.5723
# Epoch 759/2048
# 1s - loss: 0.5561 - val_loss: 0.5724
# Epoch 760/2048
# 1s - loss: 0.5561 - val_loss: 0.5721
# Epoch 761/2048
# 1s - loss: 0.5560 - val_loss: 0.5720
# Epoch 762/2048
# 1s - loss: 0.5560 - val_loss: 0.5722
# Epoch 763/2048
# 1s - loss: 0.5559 - val_loss: 0.5722
# Epoch 764/2048
# 3s - loss: 0.5560 - val_loss: 0.5719
# Epoch 765/2048
# 1s - loss: 0.5559 - val_loss: 0.5722
# Epoch 766/2048
# 4s - loss: 0.5559 - val_loss: 0.5718
# Epoch 767/2048
# 1s - loss: 0.5558 - val_loss: 0.5718
# Epoch 768/2048
# 3s - loss: 0.5557 - val_loss: 0.5718
# Epoch 769/2048
# 1s - loss: 0.5557 - val_loss: 0.5719
# Epoch 770/2048
# 3s - loss: 0.5557 - val_loss: 0.5717
# Epoch 771/2048
# 1s - loss: 0.5556 - val_loss: 0.5718
# Epoch 772/2048
# 1s - loss: 0.5556 - val_loss: 0.5718
# Epoch 773/2048
# 1s - loss: 0.5555 - val_loss: 0.5719
# Epoch 774/2048
# 2s - loss: 0.5555 - val_loss: 0.5716
# Epoch 775/2048
# 3s - loss: 0.5555 - val_loss: 0.5715
# Epoch 776/2048
# 1s - loss: 0.5554 - val_loss: 0.5716
# Epoch 777/2048
# 1s - loss: 0.5554 - val_loss: 0.5717
# Epoch 778/2048
# 1s - loss: 0.5553 - val_loss: 0.5716
# Epoch 779/2048
# 1s - loss: 0.5553 - val_loss: 0.5715
# Epoch 780/2048
# 2s - loss: 0.5553 - val_loss: 0.5713
# Epoch 781/2048
# 1s - loss: 0.5552 - val_loss: 0.5713
# Epoch 782/2048
# 1s - loss: 0.5552 - val_loss: 0.5714
# Epoch 783/2048
# 3s - loss: 0.5552 - val_loss: 0.5713
# Epoch 784/2048
# 1s - loss: 0.5551 - val_loss: 0.5713
# Epoch 785/2048
# 1s - loss: 0.5550 - val_loss: 0.5713
# Epoch 786/2048
# 3s - loss: 0.5550 - val_loss: 0.5710
# Epoch 787/2048
# 1s - loss: 0.5549 - val_loss: 0.5714
# Epoch 788/2048
# 1s - loss: 0.5549 - val_loss: 0.5713
# Epoch 789/2048
# 1s - loss: 0.5548 - val_loss: 0.5711
# Epoch 790/2048
# 3s - loss: 0.5548 - val_loss: 0.5710
# Epoch 791/2048
# 3s - loss: 0.5548 - val_loss: 0.5709
# Epoch 792/2048
# 1s - loss: 0.5548 - val_loss: 0.5711
# Epoch 793/2048
# 1s - loss: 0.5547 - val_loss: 0.5711
# Epoch 794/2048
# 3s - loss: 0.5547 - val_loss: 0.5707
# Epoch 795/2048
# 1s - loss: 0.5547 - val_loss: 0.5708
# Epoch 796/2048
# 1s - loss: 0.5546 - val_loss: 0.5709
# Epoch 797/2048
# 1s - loss: 0.5545 - val_loss: 0.5711
# Epoch 798/2048
# 2s - loss: 0.5545 - val_loss: 0.5707
# Epoch 799/2048
# 1s - loss: 0.5545 - val_loss: 0.5708
# Epoch 800/2048
# 3s - loss: 0.5544 - val_loss: 0.5706
# Epoch 801/2048
# 1s - loss: 0.5544 - val_loss: 0.5707
# Epoch 802/2048
# 1s - loss: 0.5543 - val_loss: 0.5708
# Epoch 803/2048
# 1s - loss: 0.5543 - val_loss: 0.5709
# Epoch 804/2048
# 1s - loss: 0.5542 - val_loss: 0.5709
# Epoch 805/2048
# 3s - loss: 0.5543 - val_loss: 0.5705
# Epoch 806/2048
# 1s - loss: 0.5542 - val_loss: 0.5706
# Epoch 807/2048
# 1s - loss: 0.5541 - val_loss: 0.5706
# Epoch 808/2048
# 4s - loss: 0.5541 - val_loss: 0.5704
# Epoch 809/2048
# 1s - loss: 0.5541 - val_loss: 0.5706
# Epoch 810/2048
# 1s - loss: 0.5540 - val_loss: 0.5704
# Epoch 811/2048
# 1s - loss: 0.5539 - val_loss: 0.5706
# Epoch 812/2048
# 1s - loss: 0.5540 - val_loss: 0.5705
# Epoch 813/2048
# 1s - loss: 0.5539 - val_loss: 0.5704
# Epoch 814/2048
# 3s - loss: 0.5538 - val_loss: 0.5702
# Epoch 815/2048
# 1s - loss: 0.5538 - val_loss: 0.5703
# Epoch 816/2048
# 1s - loss: 0.5537 - val_loss: 0.5702
# Epoch 817/2048
# 3s - loss: 0.5537 - val_loss: 0.5699
# Epoch 818/2048
# 1s - loss: 0.5537 - val_loss: 0.5705
# Epoch 819/2048
# 1s - loss: 0.5536 - val_loss: 0.5701
# Epoch 820/2048
# 1s - loss: 0.5536 - val_loss: 0.5704
# Epoch 821/2048
# 1s - loss: 0.5536 - val_loss: 0.5700
# Epoch 822/2048
# 1s - loss: 0.5535 - val_loss: 0.5701
# Epoch 823/2048
# 3s - loss: 0.5535 - val_loss: 0.5698
# Epoch 824/2048
# 1s - loss: 0.5534 - val_loss: 0.5702
# Epoch 825/2048
# 1s - loss: 0.5535 - val_loss: 0.5702
# Epoch 826/2048
# 1s - loss: 0.5534 - val_loss: 0.5699
# Epoch 827/2048
# 1s - loss: 0.5533 - val_loss: 0.5699
# Epoch 828/2048
# 1s - loss: 0.5533 - val_loss: 0.5699
# Epoch 829/2048
# 2s - loss: 0.5532 - val_loss: 0.5696
# Epoch 830/2048
# 1s - loss: 0.5531 - val_loss: 0.5698
# Epoch 831/2048
# 1s - loss: 0.5532 - val_loss: 0.5697
# Epoch 832/2048
# 1s - loss: 0.5531 - val_loss: 0.5700
# Epoch 833/2048
# 1s - loss: 0.5530 - val_loss: 0.5698
# Epoch 834/2048
# 2s - loss: 0.5530 - val_loss: 0.5696
# Epoch 835/2048
# 2s - loss: 0.5529 - val_loss: 0.5694
# Epoch 836/2048
# 1s - loss: 0.5529 - val_loss: 0.5695
# Epoch 837/2048
# 1s - loss: 0.5528 - val_loss: 0.5696
# Epoch 838/2048
# 1s - loss: 0.5528 - val_loss: 0.5699
# Epoch 839/2048
# 1s - loss: 0.5528 - val_loss: 0.5696
# Epoch 840/2048
# 2s - loss: 0.5527 - val_loss: 0.5693
# Epoch 841/2048
# 1s - loss: 0.5527 - val_loss: 0.5696
# Epoch 842/2048
# 4s - loss: 0.5527 - val_loss: 0.5691
# Epoch 843/2048
# 1s - loss: 0.5527 - val_loss: 0.5693
# Epoch 844/2048
# 3s - loss: 0.5525 - val_loss: 0.5691
# Epoch 845/2048
# 1s - loss: 0.5525 - val_loss: 0.5692
# Epoch 846/2048
# 1s - loss: 0.5525 - val_loss: 0.5694
# Epoch 847/2048
# 4s - loss: 0.5525 - val_loss: 0.5691
# Epoch 848/2048
# 3s - loss: 0.5524 - val_loss: 0.5689
# Epoch 849/2048
# 1s - loss: 0.5524 - val_loss: 0.5693
# Epoch 850/2048
# 1s - loss: 0.5524 - val_loss: 0.5689
# Epoch 851/2048
# 1s - loss: 0.5523 - val_loss: 0.5692
# Epoch 852/2048
# 1s - loss: 0.5523 - val_loss: 0.5690
# Epoch 853/2048
# 1s - loss: 0.5522 - val_loss: 0.5690
# Epoch 854/2048
# 1s - loss: 0.5522 - val_loss: 0.5690
# Epoch 855/2048
# 1s - loss: 0.5522 - val_loss: 0.5690
# Epoch 856/2048
# 2s - loss: 0.5521 - val_loss: 0.5688
# Epoch 857/2048
# 1s - loss: 0.5521 - val_loss: 0.5690
# Epoch 858/2048
# 5s - loss: 0.5521 - val_loss: 0.5688
# Epoch 859/2048
# 4s - loss: 0.5520 - val_loss: 0.5687
# Epoch 860/2048
# 1s - loss: 0.5520 - val_loss: 0.5688
# Epoch 861/2048
# 1s - loss: 0.5519 - val_loss: 0.5688
# Epoch 862/2048
# 3s - loss: 0.5519 - val_loss: 0.5686
# Epoch 863/2048
# 1s - loss: 0.5519 - val_loss: 0.5687
# Epoch 864/2048
# 1s - loss: 0.5518 - val_loss: 0.5687
# Epoch 865/2048
# 2s - loss: 0.5518 - val_loss: 0.5685
# Epoch 866/2048
# 1s - loss: 0.5518 - val_loss: 0.5686
# Epoch 867/2048
# 5s - loss: 0.5517 - val_loss: 0.5685
# Epoch 868/2048
# 1s - loss: 0.5517 - val_loss: 0.5686
# Epoch 869/2048
# 3s - loss: 0.5516 - val_loss: 0.5685
# Epoch 870/2048
# 1s - loss: 0.5516 - val_loss: 0.5685
# Epoch 871/2048
# 4s - loss: 0.5516 - val_loss: 0.5683
# Epoch 872/2048
# 1s - loss: 0.5515 - val_loss: 0.5685
# Epoch 873/2048
# 4s - loss: 0.5515 - val_loss: 0.5681
# Epoch 874/2048
# 1s - loss: 0.5514 - val_loss: 0.5685
# Epoch 875/2048
# 1s - loss: 0.5514 - val_loss: 0.5684
# Epoch 876/2048
# 1s - loss: 0.5514 - val_loss: 0.5682
# Epoch 877/2048
# 1s - loss: 0.5513 - val_loss: 0.5685
# Epoch 878/2048
# 1s - loss: 0.5513 - val_loss: 0.5682
# Epoch 879/2048
# 1s - loss: 0.5513 - val_loss: 0.5684
# Epoch 880/2048
# 1s - loss: 0.5513 - val_loss: 0.5683
# Epoch 881/2048
# 1s - loss: 0.5512 - val_loss: 0.5684
# Epoch 882/2048
# 1s - loss: 0.5511 - val_loss: 0.5682
# Epoch 883/2048
# 3s - loss: 0.5512 - val_loss: 0.5681
# Epoch 884/2048
# 5s - loss: 0.5512 - val_loss: 0.5679
# Epoch 885/2048
# 1s - loss: 0.5511 - val_loss: 0.5681
# Epoch 886/2048
# 1s - loss: 0.5511 - val_loss: 0.5681
# Epoch 887/2048
# 2s - loss: 0.5510 - val_loss: 0.5679
# Epoch 888/2048
# 1s - loss: 0.5510 - val_loss: 0.5680
# Epoch 889/2048
# 1s - loss: 0.5510 - val_loss: 0.5683
# Epoch 890/2048
# 3s - loss: 0.5509 - val_loss: 0.5679
# Epoch 891/2048
# 1s - loss: 0.5508 - val_loss: 0.5681
# Epoch 892/2048
# 3s - loss: 0.5509 - val_loss: 0.5675
# Epoch 893/2048
# 1s - loss: 0.5508 - val_loss: 0.5677
# Epoch 894/2048
# 1s - loss: 0.5508 - val_loss: 0.5677
# Epoch 895/2048
# 1s - loss: 0.5507 - val_loss: 0.5677
# Epoch 896/2048
# 1s - loss: 0.5508 - val_loss: 0.5679
# Epoch 897/2048
# 1s - loss: 0.5507 - val_loss: 0.5679
# Epoch 898/2048
# 1s - loss: 0.5506 - val_loss: 0.5678
# Epoch 899/2048
# 1s - loss: 0.5506 - val_loss: 0.5680
# Epoch 900/2048
# 2s - loss: 0.5506 - val_loss: 0.5675
# Epoch 901/2048
# 1s - loss: 0.5505 - val_loss: 0.5676
# Epoch 902/2048
# 1s - loss: 0.5505 - val_loss: 0.5681
# Epoch 903/2048
# 1s - loss: 0.5506 - val_loss: 0.5675
# Epoch 904/2048
# 1s - loss: 0.5505 - val_loss: 0.5678
# Epoch 905/2048
# 1s - loss: 0.5504 - val_loss: 0.5677
# Epoch 906/2048
# 3s - loss: 0.5504 - val_loss: 0.5674
# Epoch 907/2048
# 1s - loss: 0.5503 - val_loss: 0.5675
# Epoch 908/2048
# 5s - loss: 0.5503 - val_loss: 0.5673
# Epoch 909/2048
# 1s - loss: 0.5503 - val_loss: 0.5676
# Epoch 910/2048
# 3s - loss: 0.5503 - val_loss: 0.5671
# Epoch 911/2048
# 1s - loss: 0.5502 - val_loss: 0.5674
# Epoch 912/2048
# 1s - loss: 0.5502 - val_loss: 0.5676
# Epoch 913/2048
# 1s - loss: 0.5502 - val_loss: 0.5674
# Epoch 914/2048
# 1s - loss: 0.5501 - val_loss: 0.5674
# Epoch 915/2048
# 1s - loss: 0.5501 - val_loss: 0.5675
# Epoch 916/2048
# 1s - loss: 0.5500 - val_loss: 0.5677
# Epoch 917/2048
# 1s - loss: 0.5501 - val_loss: 0.5671
# Epoch 918/2048
# 1s - loss: 0.5500 - val_loss: 0.5673
# Epoch 919/2048
# 1s - loss: 0.5499 - val_loss: 0.5673
# Epoch 920/2048
# 1s - loss: 0.5500 - val_loss: 0.5671
# Epoch 921/2048
# 1s - loss: 0.5499 - val_loss: 0.5672
# Epoch 922/2048
# 1s - loss: 0.5499 - val_loss: 0.5675
# Epoch 923/2048
# 1s - loss: 0.5499 - val_loss: 0.5673
# Epoch 924/2048
# ...
# 1s - loss: 0.5270 - val_loss: 0.5463
# Epoch 1748/2048
# 1s - loss: 0.5271 - val_loss: 0.5466
# Epoch 1749/2048
# 1s - loss: 0.5270 - val_loss: 0.5464
# Epoch 1750/2048
# 1s - loss: 0.5270 - val_loss: 0.5464
# Epoch 1751/2048
# 1s - loss: 0.5270 - val_loss: 0.5466
# Epoch 1752/2048
# 1s - loss: 0.5270 - val_loss: 0.5468
# Epoch 1753/2048
# 1s - loss: 0.5269 - val_loss: 0.5465
# Epoch 1754/2048
# 1s - loss: 0.5269 - val_loss: 0.5465
# Epoch 1755/2048
# 1s - loss: 0.5269 - val_loss: 0.5465
# Epoch 1756/2048
# 2s - loss: 0.5269 - val_loss: 0.5462
# Epoch 1757/2048
# 1s - loss: 0.5268 - val_loss: 0.5464
# Epoch 1758/2048
# 1s - loss: 0.5268 - val_loss: 0.5465
# Epoch 1759/2048
# 1s - loss: 0.5268 - val_loss: 0.5462
# Epoch 1760/2048
# 1s - loss: 0.5268 - val_loss: 0.5468
# Epoch 1761/2048
# 3s - loss: 0.5268 - val_loss: 0.5461
# Epoch 1762/2048
# 1s - loss: 0.5269 - val_loss: 0.5463
# Epoch 1763/2048
# 1s - loss: 0.5267 - val_loss: 0.5462
# Epoch 1764/2048
# 1s - loss: 0.5267 - val_loss: 0.5462
# Epoch 1765/2048
# 1s - loss: 0.5267 - val_loss: 0.5463
# Epoch 1766/2048
# 1s - loss: 0.5267 - val_loss: 0.5464
# Epoch 1767/2048
# 1s - loss: 0.5267 - val_loss: 0.5461
# Epoch 1768/2048
# 1s - loss: 0.5267 - val_loss: 0.5462
# Epoch 1769/2048
# 1s - loss: 0.5266 - val_loss: 0.5463
# Epoch 1770/2048
# 1s - loss: 0.5266 - val_loss: 0.5464
# Epoch 1771/2048
# 1s - loss: 0.5266 - val_loss: 0.5464
# Epoch 1772/2048
# 1s - loss: 0.5265 - val_loss: 0.5463
# Epoch 1773/2048
# 1s - loss: 0.5266 - val_loss: 0.5462
# Epoch 1774/2048
# 3s - loss: 0.5266 - val_loss: 0.5461
# Epoch 1775/2048
# 1s - loss: 0.5267 - val_loss: 0.5462
# Epoch 1776/2048
# 1s - loss: 0.5265 - val_loss: 0.5462
# Epoch 1777/2048
# 2s - loss: 0.5265 - val_loss: 0.5459
# Epoch 1778/2048
# 2s - loss: 0.5265 - val_loss: 0.5458
# Epoch 1779/2048
# 1s - loss: 0.5265 - val_loss: 0.5462
# Epoch 1780/2048
# 1s - loss: 0.5264 - val_loss: 0.5464
# Epoch 1781/2048
# 1s - loss: 0.5264 - val_loss: 0.5459
# Epoch 1782/2048
# 1s - loss: 0.5264 - val_loss: 0.5462
# Epoch 1783/2048
# 1s - loss: 0.5264 - val_loss: 0.5460
# Epoch 1784/2048
# 1s - loss: 0.5264 - val_loss: 0.5461
# Epoch 1785/2048
# 1s - loss: 0.5264 - val_loss: 0.5459
# Epoch 1786/2048
# 1s - loss: 0.5263 - val_loss: 0.5459
# Epoch 1787/2048
# 1s - loss: 0.5263 - val_loss: 0.5460
# Epoch 1788/2048
# 3s - loss: 0.5264 - val_loss: 0.5456
# Epoch 1789/2048
# 1s - loss: 0.5263 - val_loss: 0.5460
# Epoch 1790/2048
# 1s - loss: 0.5264 - val_loss: 0.5458
# Epoch 1791/2048
# 1s - loss: 0.5263 - val_loss: 0.5458
# Epoch 1792/2048
# 1s - loss: 0.5263 - val_loss: 0.5458
# Epoch 1793/2048
# 1s - loss: 0.5264 - val_loss: 0.5462
# Epoch 1794/2048
# 1s - loss: 0.5263 - val_loss: 0.5459
# Epoch 1795/2048
# 1s - loss: 0.5262 - val_loss: 0.5459
# Epoch 1796/2048
# 1s - loss: 0.5262 - val_loss: 0.5463
# Epoch 1797/2048
# 1s - loss: 0.5262 - val_loss: 0.5459
# Epoch 1798/2048
# 1s - loss: 0.5262 - val_loss: 0.5457
# Epoch 1799/2048
# 1s - loss: 0.5261 - val_loss: 0.5463
# Epoch 1800/2048
# 1s - loss: 0.5262 - val_loss: 0.5456
# Epoch 1801/2048
# 2s - loss: 0.5261 - val_loss: 0.5455
# Epoch 1802/2048
# 1s - loss: 0.5261 - val_loss: 0.5456
# Epoch 1803/2048
# 3s - loss: 0.5261 - val_loss: 0.5455
# Epoch 1804/2048
# 1s - loss: 0.5261 - val_loss: 0.5458
# Epoch 1805/2048
# 1s - loss: 0.5261 - val_loss: 0.5459
# Epoch 1806/2048
# 2s - loss: 0.5261 - val_loss: 0.5453
# Epoch 1807/2048
# 1s - loss: 0.5261 - val_loss: 0.5455
# Epoch 1808/2048
# 1s - loss: 0.5261 - val_loss: 0.5455
# Epoch 1809/2048
# 1s - loss: 0.5260 - val_loss: 0.5455
# Epoch 1810/2048
# 1s - loss: 0.5260 - val_loss: 0.5455
# Epoch 1811/2048
# 1s - loss: 0.5260 - val_loss: 0.5459
# Epoch 1812/2048
# 1s - loss: 0.5261 - val_loss: 0.5457
# Epoch 1813/2048
# 1s - loss: 0.5259 - val_loss: 0.5455
# Epoch 1814/2048
# 1s - loss: 0.5259 - val_loss: 0.5455
# Epoch 1815/2048
# 1s - loss: 0.5259 - val_loss: 0.5458
# Epoch 1816/2048
# 1s - loss: 0.5259 - val_loss: 0.5456
# Epoch 1817/2048
# 1s - loss: 0.5259 - val_loss: 0.5456
# Epoch 1818/2048
# 1s - loss: 0.5259 - val_loss: 0.5454
# Epoch 1819/2048
# 1s - loss: 0.5258 - val_loss: 0.5459
# Epoch 1820/2048
# 1s - loss: 0.5258 - val_loss: 0.5455
# Epoch 1821/2048
# 1s - loss: 0.5258 - val_loss: 0.5454
# Epoch 1822/2048
# 1s - loss: 0.5258 - val_loss: 0.5458
# Epoch 1823/2048
# 1s - loss: 0.5257 - val_loss: 0.5454
# Epoch 1824/2048
# 1s - loss: 0.5258 - val_loss: 0.5460
# Epoch 1825/2048
# 2s - loss: 0.5258 - val_loss: 0.5453
# Epoch 1826/2048
# 1s - loss: 0.5258 - val_loss: 0.5454
# Epoch 1827/2048
# 1s - loss: 0.5257 - val_loss: 0.5454
# Epoch 1828/2048
# 1s - loss: 0.5258 - val_loss: 0.5454
# Epoch 1829/2048
# 1s - loss: 0.5257 - val_loss: 0.5460
# Epoch 1830/2048
# 3s - loss: 0.5257 - val_loss: 0.5452
# Epoch 1831/2048
# 1s - loss: 0.5256 - val_loss: 0.5453
# Epoch 1832/2048
# 3s - loss: 0.5257 - val_loss: 0.5451
# Epoch 1833/2048
# 1s - loss: 0.5256 - val_loss: 0.5453
# Epoch 1834/2048
# 1s - loss: 0.5256 - val_loss: 0.5453
# Epoch 1835/2048
# 1s - loss: 0.5257 - val_loss: 0.5453
# Epoch 1836/2048
# 1s - loss: 0.5256 - val_loss: 0.5455
# Epoch 1837/2048
# 1s - loss: 0.5256 - val_loss: 0.5453
# Epoch 1838/2048
# 1s - loss: 0.5256 - val_loss: 0.5452
# Epoch 1839/2048
# 1s - loss: 0.5255 - val_loss: 0.5451
# Epoch 1840/2048
# 2s - loss: 0.5256 - val_loss: 0.5448
# Epoch 1841/2048
# 1s - loss: 0.5255 - val_loss: 0.5451
# Epoch 1842/2048
# 1s - loss: 0.5255 - val_loss: 0.5450
# Epoch 1843/2048
# 1s - loss: 0.5254 - val_loss: 0.5451
# Epoch 1844/2048
# 1s - loss: 0.5255 - val_loss: 0.5451
# Epoch 1845/2048
# 1s - loss: 0.5255 - val_loss: 0.5452
# Epoch 1846/2048
# 1s - loss: 0.5254 - val_loss: 0.5449
# Epoch 1847/2048
# 1s - loss: 0.5253 - val_loss: 0.5451
# Epoch 1848/2048
# 0s - loss: 0.5254 - val_loss: 0.5452
# Epoch 1849/2048
# 1s - loss: 0.5253 - val_loss: 0.5449
# Epoch 1850/2048
# 1s - loss: 0.5254 - val_loss: 0.5451
# Epoch 1851/2048
# 1s - loss: 0.5255 - val_loss: 0.5451
# Epoch 1852/2048
# 1s - loss: 0.5253 - val_loss: 0.5457
# Epoch 1853/2048
# 3s - loss: 0.5253 - val_loss: 0.5448
# Epoch 1854/2048
# 1s - loss: 0.5253 - val_loss: 0.5449
# Epoch 1855/2048
# 1s - loss: 0.5252 - val_loss: 0.5452
# Epoch 1856/2048
# 2s - loss: 0.5253 - val_loss: 0.5447
# Epoch 1857/2048
# 2s - loss: 0.5253 - val_loss: 0.5445
# Epoch 1858/2048
# 1s - loss: 0.5253 - val_loss: 0.5449
# Epoch 1859/2048
# 1s - loss: 0.5252 - val_loss: 0.5452
# Epoch 1860/2048
# 1s - loss: 0.5252 - val_loss: 0.5448
# Epoch 1861/2048
# 1s - loss: 0.5252 - val_loss: 0.5448
# Epoch 1862/2048
# 1s - loss: 0.5252 - val_loss: 0.5450
# Epoch 1863/2048
# 1s - loss: 0.5252 - val_loss: 0.5450
# Epoch 1864/2048
# 1s - loss: 0.5252 - val_loss: 0.5449
# Epoch 1865/2048
# 1s - loss: 0.5251 - val_loss: 0.5446
# Epoch 1866/2048
# 1s - loss: 0.5251 - val_loss: 0.5448
# Epoch 1867/2048
# 1s - loss: 0.5250 - val_loss: 0.5447
# Epoch 1868/2048
# 1s - loss: 0.5250 - val_loss: 0.5453
# Epoch 1869/2048
# 1s - loss: 0.5251 - val_loss: 0.5449
# Epoch 1870/2048
# 1s - loss: 0.5250 - val_loss: 0.5447
# Epoch 1871/2048
# 1s - loss: 0.5250 - val_loss: 0.5447
# Epoch 1872/2048
# 1s - loss: 0.5250 - val_loss: 0.5448
# Epoch 1873/2048
# 1s - loss: 0.5250 - val_loss: 0.5446
# Epoch 1874/2048
# 2s - loss: 0.5249 - val_loss: 0.5443
# Epoch 1875/2048
# 1s - loss: 0.5249 - val_loss: 0.5449
# Epoch 1876/2048
# 0s - loss: 0.5249 - val_loss: 0.5447
# Epoch 1877/2048
# 0s - loss: 0.5249 - val_loss: 0.5447
# Epoch 1878/2048
# 1s - loss: 0.5250 - val_loss: 0.5446
# Epoch 1879/2048
# 1s - loss: 0.5250 - val_loss: 0.5445
# Epoch 1880/2048
# 1s - loss: 0.5249 - val_loss: 0.5446
# Epoch 1881/2048
# 1s - loss: 0.5249 - val_loss: 0.5446
# Epoch 1882/2048
# 3s - loss: 0.5248 - val_loss: 0.5443
# Epoch 1883/2048
# 1s - loss: 0.5248 - val_loss: 0.5446
# Epoch 1884/2048
# 1s - loss: 0.5248 - val_loss: 0.5444
# Epoch 1885/2048
# 1s - loss: 0.5248 - val_loss: 0.5445
# Epoch 1886/2048
# 2s - loss: 0.5248 - val_loss: 0.5443
# Epoch 1887/2048
# 1s - loss: 0.5249 - val_loss: 0.5446
# Epoch 1888/2048
# 1s - loss: 0.5248 - val_loss: 0.5445
# Epoch 1889/2048
# 1s - loss: 0.5248 - val_loss: 0.5444
# Epoch 1890/2048
# 1s - loss: 0.5247 - val_loss: 0.5447
# Epoch 1891/2048
# 1s - loss: 0.5248 - val_loss: 0.5447
# Epoch 1892/2048
# 1s - loss: 0.5247 - val_loss: 0.5448
# Epoch 1893/2048
# 2s - loss: 0.5247 - val_loss: 0.5441
# Epoch 1894/2048
# 1s - loss: 0.5247 - val_loss: 0.5443
# Epoch 1895/2048
# 1s - loss: 0.5247 - val_loss: 0.5445
# Epoch 1896/2048
# 1s - loss: 0.5246 - val_loss: 0.5445
# Epoch 1897/2048
# 1s - loss: 0.5247 - val_loss: 0.5442
# Epoch 1898/2048
# 1s - loss: 0.5246 - val_loss: 0.5444
# Epoch 1899/2048
# 1s - loss: 0.5246 - val_loss: 0.5445
# Epoch 1900/2048
# 1s - loss: 0.5246 - val_loss: 0.5443
# Epoch 1901/2048
# 1s - loss: 0.5246 - val_loss: 0.5446
# Epoch 1902/2048
# 1s - loss: 0.5246 - val_loss: 0.5444
# Epoch 1903/2048
# 1s - loss: 0.5245 - val_loss: 0.5444
# Epoch 1904/2048
# 1s - loss: 0.5245 - val_loss: 0.5444
# Epoch 1905/2048
# 1s - loss: 0.5246 - val_loss: 0.5443
# Epoch 1906/2048
# 2s - loss: 0.5245 - val_loss: 0.5440
# Epoch 1907/2048
# 1s - loss: 0.5245 - val_loss: 0.5448
# Epoch 1908/2048
# 1s - loss: 0.5244 - val_loss: 0.5443
# Epoch 1909/2048
# 1s - loss: 0.5245 - val_loss: 0.5444
# Epoch 1910/2048
# 1s - loss: 0.5244 - val_loss: 0.5447
# Epoch 1911/2048
# 1s - loss: 0.5244 - val_loss: 0.5440
# Epoch 1912/2048
# 1s - loss: 0.5244 - val_loss: 0.5445
# Epoch 1913/2048
# 1s - loss: 0.5244 - val_loss: 0.5445
# Epoch 1914/2048
# 1s - loss: 0.5244 - val_loss: 0.5442
# Epoch 1915/2048
# 1s - loss: 0.5243 - val_loss: 0.5443
# Epoch 1916/2048
# 1s - loss: 0.5243 - val_loss: 0.5440
# Epoch 1917/2048
# 2s - loss: 0.5243 - val_loss: 0.5438
# Epoch 1918/2048
# 1s - loss: 0.5243 - val_loss: 0.5441
# Epoch 1919/2048
# 1s - loss: 0.5243 - val_loss: 0.5441
# Epoch 1920/2048
# 1s - loss: 0.5243 - val_loss: 0.5439
# Epoch 1921/2048
# 1s - loss: 0.5243 - val_loss: 0.5438
# Epoch 1922/2048
# 1s - loss: 0.5242 - val_loss: 0.5440
# Epoch 1923/2048
# 1s - loss: 0.5242 - val_loss: 0.5444
# Epoch 1924/2048
# 1s - loss: 0.5243 - val_loss: 0.5441
# Epoch 1925/2048
# 1s - loss: 0.5243 - val_loss: 0.5441
# Epoch 1926/2048
# 1s - loss: 0.5242 - val_loss: 0.5440
# Epoch 1927/2048
# 1s - loss: 0.5242 - val_loss: 0.5441
# Epoch 1928/2048
# 1s - loss: 0.5242 - val_loss: 0.5441
# Epoch 1929/2048
# 3s - loss: 0.5242 - val_loss: 0.5437
# Epoch 1930/2048
# 1s - loss: 0.5242 - val_loss: 0.5440
# Epoch 1931/2048
# 1s - loss: 0.5241 - val_loss: 0.5441
# Epoch 1932/2048
# 1s - loss: 0.5242 - val_loss: 0.5440
# Epoch 1933/2048
# 1s - loss: 0.5241 - val_loss: 0.5441
# Epoch 1934/2048
# 2s - loss: 0.5241 - val_loss: 0.5435
# Epoch 1935/2048
# 1s - loss: 0.5241 - val_loss: 0.5441
# Epoch 1936/2048
# 1s - loss: 0.5240 - val_loss: 0.5440
# Epoch 1937/2048
# 1s - loss: 0.5240 - val_loss: 0.5437
# Epoch 1938/2048
# 1s - loss: 0.5240 - val_loss: 0.5440
# Epoch 1939/2048
# 1s - loss: 0.5240 - val_loss: 0.5440
# Epoch 1940/2048
# 0s - loss: 0.5240 - val_loss: 0.5439
# Epoch 1941/2048
# 1s - loss: 0.5240 - val_loss: 0.5439
# Epoch 1942/2048
# 2s - loss: 0.5241 - val_loss: 0.5435
# Epoch 1943/2048
# 1s - loss: 0.5239 - val_loss: 0.5437
# Epoch 1944/2048
# 1s - loss: 0.5239 - val_loss: 0.5437
# Epoch 1945/2048
# 2s - loss: 0.5239 - val_loss: 0.5432
# Epoch 1946/2048
# 1s - loss: 0.5239 - val_loss: 0.5437
# Epoch 1947/2048
# 0s - loss: 0.5239 - val_loss: 0.5437
# Epoch 1948/2048
# 1s - loss: 0.5240 - val_loss: 0.5436
# Epoch 1949/2048
# 1s - loss: 0.5239 - val_loss: 0.5437
# Epoch 1950/2048
# 1s - loss: 0.5238 - val_loss: 0.5436
# Epoch 1951/2048
# 1s - loss: 0.5238 - val_loss: 0.5436
# Epoch 1952/2048
# 1s - loss: 0.5238 - val_loss: 0.5435
# Epoch 1953/2048
# 1s - loss: 0.5238 - val_loss: 0.5438
# Epoch 1954/2048
# 1s - loss: 0.5238 - val_loss: 0.5437
# Epoch 1955/2048
# 1s - loss: 0.5239 - val_loss: 0.5438
# Epoch 1956/2048
# 1s - loss: 0.5238 - val_loss: 0.5436
# Epoch 1957/2048
# 1s - loss: 0.5237 - val_loss: 0.5436
# Epoch 1958/2048
# 1s - loss: 0.5237 - val_loss: 0.5436
# Epoch 1959/2048
# 1s - loss: 0.5237 - val_loss: 0.5437
# Epoch 1960/2048
# 1s - loss: 0.5237 - val_loss: 0.5437
# Epoch 1961/2048
# 1s - loss: 0.5237 - val_loss: 0.5435
# Epoch 1962/2048
# 1s - loss: 0.5237 - val_loss: 0.5435
# Epoch 1963/2048
# 1s - loss: 0.5236 - val_loss: 0.5436
# Epoch 1964/2048
# 1s - loss: 0.5237 - val_loss: 0.5439
# Epoch 1965/2048
# 1s - loss: 0.5237 - val_loss: 0.5435
# Epoch 1966/2048
# 1s - loss: 0.5236 - val_loss: 0.5435
# Epoch 1967/2048
# 1s - loss: 0.5236 - val_loss: 0.5434
# Epoch 1968/2048
# 2s - loss: 0.5236 - val_loss: 0.5432
# Epoch 1969/2048
# 2s - loss: 0.5236 - val_loss: 0.5431
# Epoch 1970/2048
# 1s - loss: 0.5235 - val_loss: 0.5433
# Epoch 1971/2048
# 1s - loss: 0.5236 - val_loss: 0.5435
# Epoch 1972/2048
# 1s - loss: 0.5235 - val_loss: 0.5435
# Epoch 1973/2048
# 1s - loss: 0.5236 - val_loss: 0.5434
# Epoch 1974/2048
# 1s - loss: 0.5235 - val_loss: 0.5436
# Epoch 1975/2048
# 1s - loss: 0.5234 - val_loss: 0.5433
# Epoch 1976/2048
# 1s - loss: 0.5236 - val_loss: 0.5432
# Epoch 1977/2048
# 2s - loss: 0.5234 - val_loss: 0.5430
# Epoch 1978/2048
# 1s - loss: 0.5235 - val_loss: 0.5432
# Epoch 1979/2048
# 1s - loss: 0.5234 - val_loss: 0.5431
# Epoch 1980/2048
# 1s - loss: 0.5234 - val_loss: 0.5432
# Epoch 1981/2048
# 1s - loss: 0.5235 - val_loss: 0.5431
# Epoch 1982/2048
# 0s - loss: 0.5234 - val_loss: 0.5433
# Epoch 1983/2048
# 1s - loss: 0.5234 - val_loss: 0.5433
# Epoch 1984/2048
# 1s - loss: 0.5233 - val_loss: 0.5433
# Epoch 1985/2048
# 1s - loss: 0.5234 - val_loss: 0.5435
# Epoch 1986/2048
# 1s - loss: 0.5233 - val_loss: 0.5434
# Epoch 1987/2048
# 1s - loss: 0.5233 - val_loss: 0.5434
# Epoch 1988/2048
# 3s - loss: 0.5233 - val_loss: 0.5430
# Epoch 1989/2048
# 1s - loss: 0.5233 - val_loss: 0.5431
# Epoch 1990/2048
# 1s - loss: 0.5233 - val_loss: 0.5431
# Epoch 1991/2048
# 3s - loss: 0.5233 - val_loss: 0.5429
# Epoch 1992/2048
# 2s - loss: 0.5233 - val_loss: 0.5427
# Epoch 1993/2048
# 1s - loss: 0.5233 - val_loss: 0.5431
# Epoch 1994/2048
# 1s - loss: 0.5233 - val_loss: 0.5432
# Epoch 1995/2048
# 1s - loss: 0.5232 - val_loss: 0.5429
# Epoch 1996/2048
# 1s - loss: 0.5233 - val_loss: 0.5429
# Epoch 1997/2048
# 1s - loss: 0.5232 - val_loss: 0.5427
# Epoch 1998/2048
# 1s - loss: 0.5231 - val_loss: 0.5428
# Epoch 1999/2048
# 1s - loss: 0.5232 - val_loss: 0.5432
# Epoch 2000/2048
# 1s - loss: 0.5231 - val_loss: 0.5429
# Epoch 2001/2048
# 1s - loss: 0.5231 - val_loss: 0.5430
# Epoch 2002/2048
# 1s - loss: 0.5231 - val_loss: 0.5429
# Epoch 2003/2048
# 1s - loss: 0.5231 - val_loss: 0.5430
# Epoch 2004/2048
# 1s - loss: 0.5231 - val_loss: 0.5428
# Epoch 2005/2048
# 1s - loss: 0.5231 - val_loss: 0.5429
# Epoch 2006/2048
# 2s - loss: 0.5230 - val_loss: 0.5427
# Epoch 2007/2048
# 1s - loss: 0.5230 - val_loss: 0.5429
# Epoch 2008/2048
# 1s - loss: 0.5231 - val_loss: 0.5430
# Epoch 2009/2048
# 1s - loss: 0.5231 - val_loss: 0.5429
# Epoch 2010/2048
# 1s - loss: 0.5230 - val_loss: 0.5429
# Epoch 2011/2048
# 1s - loss: 0.5231 - val_loss: 0.5429
# Epoch 2012/2048
# 1s - loss: 0.5229 - val_loss: 0.5432
# Epoch 2013/2048
# 2s - loss: 0.5229 - val_loss: 0.5426
# Epoch 2014/2048
# 1s - loss: 0.5229 - val_loss: 0.5428
# Epoch 2015/2048
# 3s - loss: 0.5230 - val_loss: 0.5426
# Epoch 2016/2048
# 1s - loss: 0.5229 - val_loss: 0.5431
# Epoch 2017/2048
# 1s - loss: 0.5230 - val_loss: 0.5427
# Epoch 2018/2048
# 1s - loss: 0.5229 - val_loss: 0.5426
# Epoch 2019/2048
# 1s - loss: 0.5229 - val_loss: 0.5430
# Epoch 2020/2048
# 1s - loss: 0.5229 - val_loss: 0.5426
# Epoch 2021/2048
# 1s - loss: 0.5229 - val_loss: 0.5429
# Epoch 2022/2048
# 1s - loss: 0.5228 - val_loss: 0.5429
# Epoch 2023/2048
# 1s - loss: 0.5228 - val_loss: 0.5429
# Epoch 2024/2048
# 2s - loss: 0.5228 - val_loss: 0.5424
# Epoch 2025/2048
# 1s - loss: 0.5228 - val_loss: 0.5431
# Epoch 2026/2048
# 1s - loss: 0.5228 - val_loss: 0.5427
# Epoch 2027/2048
# 2s - loss: 0.5227 - val_loss: 0.5424
# Epoch 2028/2048
# 2s - loss: 0.5227 - val_loss: 0.5423
# Epoch 2029/2048
# 1s - loss: 0.5228 - val_loss: 0.5428
# Epoch 2030/2048
# 1s - loss: 0.5227 - val_loss: 0.5425
# Epoch 2031/2048
# 1s - loss: 0.5227 - val_loss: 0.5426
# Epoch 2032/2048
# 1s - loss: 0.5227 - val_loss: 0.5424
# Epoch 2033/2048
# 1s - loss: 0.5227 - val_loss: 0.5424
# Epoch 2034/2048
# 1s - loss: 0.5227 - val_loss: 0.5428
# Epoch 2035/2048
# 1s - loss: 0.5227 - val_loss: 0.5426
# Epoch 2036/2048
# 1s - loss: 0.5227 - val_loss: 0.5426
# Epoch 2037/2048
# 1s - loss: 0.5226 - val_loss: 0.5424
# Epoch 2038/2048
# 1s - loss: 0.5226 - val_loss: 0.5424
# Epoch 2039/2048
# 1s - loss: 0.5226 - val_loss: 0.5425
# Epoch 2040/2048
# 1s - loss: 0.5226 - val_loss: 0.5425
# Epoch 2041/2048
# 1s - loss: 0.5225 - val_loss: 0.5426
# Epoch 2042/2048
# 1s - loss: 0.5225 - val_loss: 0.5428
# Epoch 2043/2048
# 1s - loss: 0.5226 - val_loss: 0.5429
# Epoch 2044/2048
# 1s - loss: 0.5227 - val_loss: 0.5427
# Epoch 2045/2048
# 2s - loss: 0.5226 - val_loss: 0.5423
# Epoch 2046/2048
# 1s - loss: 0.5225 - val_loss: 0.5423
# Epoch 2047/2048
# 3s - loss: 0.5225 - val_loss: 0.5422
# Epoch 2048/2048
# 2s - loss: 0.5225 - val_loss: 0.5422

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name))

# %%
# Run predictions
ae_pred = autoencoder.predict(X_test_norm)
ae_pred_train = autoencoder.predict(X_train_norm)

# %%
# Exclude validation set
ae_pred_train = ae_pred_train[:int(0.75 * len(ae_pred_train)), :]

# %%
pickle.dump(ae_pred, open(model_directory + "ae_pred.p", "wb"))
pickle.dump(ae_pred_train, open(model_directory + "ae_pred_train.p", "wb"))

# %%
ae_pred = pickle.load(open(model_directory + "ae_pred.p", "rb"))
ae_pred_train = pickle.load(open(model_directory + "ae_pred_train.p", "rb"))

# %%
# Exclude validation set
X_train_wo_valid = X_train_norm[:int(0.75 * len(X_train_norm)), :]

# %%
def get_error_df(X_test, predictions, mode="allmean", n_highest = 100):
    
    if mode == "allmean":
        return np.mean(np.power(X_test - predictions, 2), axis=1)
    
    elif mode == "topn":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.mean(result, axis=1)
    
    elif mode == "topn_median":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.median(result, axis=1)
    
    elif mode == "perobj":
        mses = []
        for l in legend:
            mse = np.mean(
                np.power(X_test[:,l["start"]:l["end"]] - predictions[:,l["start"]:l["end"]], 2),
                axis=1)
            mses.append(mse)
     
        return np.maximum.reduce(mses)
    
    elif mode == "bottomn":
        temp = np.partition(np.power(X_test - predictions, 2), n_highest)
        result = temp[:,:n_highest]
        return np.mean(result, axis=1)

# %%
ae_pred.shape
# Out:
# (12035, 2809)

# %%
ae_error = get_error_df(X_test_norm, ae_pred, mode="topn", n_highest=100)
ae_error_train = get_error_df(X_train_wo_valid, ae_pred_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error, open(model_directory + "ae_error.p", "wb"))
pickle.dump(ae_error_train, open(model_directory + "ae_error_train.p", "wb"))

# %%
# Plot lumi vs error
def plot_lumi_error(pred, X_test, threshold=None, title=None):
    scores = get_error_df(X_test, pred, mode='topn')
    
    fig, ax = plt.subplots()

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 0],
             scores[y_test == 0],
             linestyle='',
             ms=2,
             marker='o',
             label="Outlier")

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 1],
             scores[y_test == 1],
             linestyle='',
             ms=2,
             marker='o',
             label="Inlier")

    ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
    
    ax.set_yscale("log")
    plt.ylabel("Score")
    plt.xlabel("Lumisection #")
    if title:
        plt.title(title)
    plt.show();

# %%
start_legend = 1414
var_legend = [{'start': start_legend, 'end': start_legend, 'name': 'mean'},
              {'start': start_legend+1, 'end': start_legend+1, 'name': 'RMS'},
              {'start': start_legend+2, 'end': start_legend+2, 'name': 'Q1'},
              {'start': start_legend+3, 'end': start_legend+3, 'name': 'Q2'},
              {'start': start_legend+4, 'end': start_legend+4, 'name': 'Q3'},
              {'start': start_legend+5, 'end': start_legend+5, 'name': 'Q4'},
              {'start': start_legend+6, 'end': start_legend+6, 'name': 'Q5'}]

# %%
corr = [pearsonr(X_train_wo_valid[:, i].reshape(-1), ae_pred_train[:, i].reshape(-1)) for i in range(INPUT_DIM)]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
corr = np.array(corr)[:, 0]

# %%
corr[np.isnan(corr)] = 0

# %%
plt.hist(corr, bins=100)
plt.title('Histogram of correlation coefficients for 2809 features')
plt.show()

# %%
corr_filter = corr > 0.5

# %%
variance = np.var(data.iloc[:, 0:INPUT_DIM])

# %%
var_filter = variance != 0

# %%
feature_filter = corr_filter & var_filter

# %%
X_train_filtered = X_train_norm[:, feature_filter]
X_train_filtered.shape
# Out:
# (10991, 1152)

# %%
X_train_filtered_wo_valid = X_train.iloc[:round(0.75*len(X_train)), :]
X_train_filtered_wo_valid = np.array(X_train_filtered_wo_valid)[:, feature_filter]

# %%
corr_names = []
for i in tnrange(2809):
    v, r = divmod(i, 7)
    corr_names.append([feature_names[v],
                      var_legend[r]['name'],
                      corr[i]])

# %%
corr_names_pd = pd.DataFrame(corr_names, columns=['name', 'group',
                                                  'corr_coeff'])

# %%
corr_groups = corr_names_pd.groupby('group')

# %%
plt.rcParams['figure.figsize'] = [6, 3]
for n in corr_groups.groups.keys():
    coeffs = corr_groups.get_group(n).corr_coeff
    used = len(coeffs[coeffs > 0.5])/len(coeffs)
    plt.hist(corr_groups.get_group(n).corr_coeff, bins=10)
    plt.title(n + ' ' + str(round(used, 2)))
    plt.xlim([0, 1])
    plt.show()

# %%
corr_groups.aggregate(np.mean)
# Out:
#        corr_coeff
# group
# Q1       0.287405
# Q2       0.459075
# Q3       0.352997
# Q4       0.530945
# Q5       0.296341
# RMS      0.646571
# mean     0.477696

# %%
corr_groups.aggregate(np.median)
# Out:
#        corr_coeff
# group
# Q1       0.302295
# Q2       0.417831
# Q3       0.099886
# Q4       0.685171
# Q5       0.272196
# RMS      0.765844
# mean     0.344423

# %%
corr_groups.aggregate(np.std)
# Out:
#        corr_coeff
# group
# Q1       0.235231
# Q2       0.424318
# Q3       0.415136
# Q4       0.424578
# Q5       0.184986
# RMS      0.334522
# mean     0.388119

# %%
csv_dir = model_directory
corr_names_pd.to_csv(csv_dir + 'correlation_coeff_feature_names.csv', index=False)

# %%
input_dim = X_train_filtered.shape[1]
input_layer = Input(shape=(input_dim, ))

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(32, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(input_dim)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1152)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              1180672
# _________________________________________________________________
# p_re_lu_12 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# p_re_lu_13 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               131328
# _________________________________________________________________
# p_re_lu_14 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# p_re_lu_15 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# p_re_lu_16 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# p_re_lu_17 (PReLU)           (None, 32)                32
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                2112
# _________________________________________________________________
# p_re_lu_18 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               8320
# _________________________________________________________________
# p_re_lu_19 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               33024
# _________________________________________________________________
# p_re_lu_20 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# p_re_lu_21 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_23 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_22 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_24 (Dense)             (None, 1152)              1180800
# =================================================================
# Total params: 3,765,184
# Trainable params: 3,765,184
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name2 = 'ae2'

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name2)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_filtered,
                X_train_filtered,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 8243 samples, validate on 2748 samples
# Epoch 1/2048
# 2s - loss: 43.7373 - val_loss: 40.4318
# Epoch 2/2048
# 1s - loss: 37.9361 - val_loss: 35.3083
# Epoch 3/2048
# 1s - loss: 33.0819 - val_loss: 30.8265
# Epoch 4/2048
# 1s - loss: 28.8798 - val_loss: 26.8950
# Epoch 5/2048
# 1s - loss: 25.1960 - val_loss: 23.4329
# Epoch 6/2048
# 1s - loss: 21.9400 - val_loss: 20.3556
# Epoch 7/2048
# 1s - loss: 19.1155 - val_loss: 17.7684
# Epoch 8/2048
# 1s - loss: 16.6975 - val_loss: 15.5294
# Epoch 9/2048
# 1s - loss: 14.5999 - val_loss: 13.5853
# Epoch 10/2048
# 1s - loss: 12.7755 - val_loss: 11.8946
# Epoch 11/2048
# 1s - loss: 11.1907 - val_loss: 10.4266
# Epoch 12/2048
# 1s - loss: 9.8154 - val_loss: 9.1542
# Epoch 13/2048
# 1s - loss: 8.6223 - val_loss: 8.0513
# Epoch 14/2048
# 1s - loss: 7.5897 - val_loss: 7.0963
# Epoch 15/2048
# 1s - loss: 6.6961 - val_loss: 6.2712
# Epoch 16/2048
# 1s - loss: 5.9233 - val_loss: 5.5567
# Epoch 17/2048
# 1s - loss: 5.2553 - val_loss: 4.9395
# Epoch 18/2048
# 1s - loss: 4.6775 - val_loss: 4.4054
# Epoch 19/2048
# 1s - loss: 4.1784 - val_loss: 3.9439
# Epoch 20/2048
# 1s - loss: 3.7465 - val_loss: 3.5445
# Epoch 21/2048
# 1s - loss: 3.3728 - val_loss: 3.2000
# Epoch 22/2048
# 1s - loss: 3.0496 - val_loss: 2.8998
# Epoch 23/2048
# 1s - loss: 2.7689 - val_loss: 2.6405
# Epoch 24/2048
# 1s - loss: 2.5254 - val_loss: 2.4159
# Epoch 25/2048
# 1s - loss: 2.3144 - val_loss: 2.2199
# Epoch 26/2048
# 1s - loss: 2.1308 - val_loss: 2.0496
# Epoch 27/2048
# 1s - loss: 1.9705 - val_loss: 1.9016
# Epoch 28/2048
# 1s - loss: 1.8308 - val_loss: 1.7698
# Epoch 29/2048
# 1s - loss: 1.7072 - val_loss: 1.6552
# Epoch 30/2048
# 1s - loss: 1.5979 - val_loss: 1.5524
# Epoch 31/2048
# 1s - loss: 1.4996 - val_loss: 1.4601
# Epoch 32/2048
# 1s - loss: 1.4125 - val_loss: 1.3785
# Epoch 33/2048
# 1s - loss: 1.3348 - val_loss: 1.3064
# Epoch 34/2048
# 1s - loss: 1.2648 - val_loss: 1.2396
# Epoch 35/2048
# 1s - loss: 1.2016 - val_loss: 1.1797
# Epoch 36/2048
# 1s - loss: 1.1438 - val_loss: 1.1246
# Epoch 37/2048
# 1s - loss: 1.0913 - val_loss: 1.0754
# Epoch 38/2048
# 1s - loss: 1.0430 - val_loss: 1.0290
# Epoch 39/2048
# 1s - loss: 0.9987 - val_loss: 0.9874
# Epoch 40/2048
# 1s - loss: 0.9584 - val_loss: 0.9487
# Epoch 41/2048
# 1s - loss: 0.9214 - val_loss: 0.9137
# Epoch 42/2048
# 1s - loss: 0.8875 - val_loss: 0.8816
# Epoch 43/2048
# 1s - loss: 0.8567 - val_loss: 0.8539
# Epoch 44/2048
# 1s - loss: 0.8297 - val_loss: 0.8260
# Epoch 45/2048
# 1s - loss: 0.8026 - val_loss: 0.8012
# Epoch 46/2048
# 1s - loss: 0.7787 - val_loss: 0.7780
# Epoch 47/2048
# 1s - loss: 0.7570 - val_loss: 0.7576
# Epoch 48/2048
# 1s - loss: 0.7369 - val_loss: 0.7389
# Epoch 49/2048
# 1s - loss: 0.7186 - val_loss: 0.7211
# Epoch 50/2048
# 1s - loss: 0.7020 - val_loss: 0.7048
# Epoch 51/2048
# 1s - loss: 0.6855 - val_loss: 0.6890
# Epoch 52/2048
# 1s - loss: 0.6707 - val_loss: 0.6750
# Epoch 53/2048
# 1s - loss: 0.6571 - val_loss: 0.6621
# Epoch 54/2048
# 1s - loss: 0.6444 - val_loss: 0.6502
# Epoch 55/2048
# 1s - loss: 0.6323 - val_loss: 0.6379
# Epoch 56/2048
# 1s - loss: 0.6211 - val_loss: 0.6279
# Epoch 57/2048
# 1s - loss: 0.6109 - val_loss: 0.6174
# Epoch 58/2048
# 1s - loss: 0.6011 - val_loss: 0.6082
# Epoch 59/2048
# 1s - loss: 0.5921 - val_loss: 0.6005
# Epoch 60/2048
# 1s - loss: 0.5837 - val_loss: 0.5911
# Epoch 61/2048
# 1s - loss: 0.5758 - val_loss: 0.5835
# Epoch 62/2048
# 1s - loss: 0.5686 - val_loss: 0.5768
# Epoch 63/2048
# 1s - loss: 0.5616 - val_loss: 0.5702
# Epoch 64/2048
# 1s - loss: 0.5552 - val_loss: 0.5636
# Epoch 65/2048
# 1s - loss: 0.5495 - val_loss: 0.5587
# Epoch 66/2048
# 1s - loss: 0.5437 - val_loss: 0.5527
# Epoch 67/2048
# 1s - loss: 0.5384 - val_loss: 0.5482
# Epoch 68/2048
# 1s - loss: 0.5335 - val_loss: 0.5436
# Epoch 69/2048
# 1s - loss: 0.5289 - val_loss: 0.5390
# Epoch 70/2048
# 1s - loss: 0.5251 - val_loss: 0.5351
# Epoch 71/2048
# 1s - loss: 0.5208 - val_loss: 0.5313
# Epoch 72/2048
# 1s - loss: 0.5171 - val_loss: 0.5277
# Epoch 73/2048
# 1s - loss: 0.5137 - val_loss: 0.5247
# Epoch 74/2048
# 1s - loss: 0.5103 - val_loss: 0.5215
# Epoch 75/2048
# 1s - loss: 0.5073 - val_loss: 0.5182
# Epoch 76/2048
# 1s - loss: 0.5042 - val_loss: 0.5157
# Epoch 77/2048
# 1s - loss: 0.5016 - val_loss: 0.5139
# Epoch 78/2048
# 1s - loss: 0.4990 - val_loss: 0.5108
# Epoch 79/2048
# 1s - loss: 0.4964 - val_loss: 0.5080
# Epoch 80/2048
# 1s - loss: 0.4940 - val_loss: 0.5060
# Epoch 81/2048
# 1s - loss: 0.4917 - val_loss: 0.5043
# Epoch 82/2048
# 1s - loss: 0.4898 - val_loss: 0.5020
# Epoch 83/2048
# 1s - loss: 0.4879 - val_loss: 0.4997
# Epoch 84/2048
# 1s - loss: 0.4860 - val_loss: 0.4983
# Epoch 85/2048
# 1s - loss: 0.4842 - val_loss: 0.4966
# Epoch 86/2048
# 1s - loss: 0.4828 - val_loss: 0.4946
# Epoch 87/2048
# 1s - loss: 0.4811 - val_loss: 0.4938
# Epoch 88/2048
# 1s - loss: 0.4795 - val_loss: 0.4926
# Epoch 89/2048
# 1s - loss: 0.4780 - val_loss: 0.4918
# Epoch 90/2048
# 1s - loss: 0.4780 - val_loss: 0.4907
# Epoch 91/2048
# 1s - loss: 0.4756 - val_loss: 0.4887
# Epoch 92/2048
# 1s - loss: 0.4743 - val_loss: 0.4875
# Epoch 93/2048
# 1s - loss: 0.4734 - val_loss: 0.4878
# Epoch 94/2048
# 1s - loss: 0.4722 - val_loss: 0.4861
# Epoch 95/2048
# 1s - loss: 0.4716 - val_loss: 0.4850
# Epoch 96/2048
# 1s - loss: 0.4701 - val_loss: 0.4842
# Epoch 97/2048
# 1s - loss: 0.4691 - val_loss: 0.4837
# Epoch 98/2048
# 1s - loss: 0.4683 - val_loss: 0.4824
# Epoch 99/2048
# 1s - loss: 0.4673 - val_loss: 0.4817
# Epoch 100/2048
# 1s - loss: 0.4665 - val_loss: 0.4813
# Epoch 101/2048
# 1s - loss: 0.4657 - val_loss: 0.4804
# Epoch 102/2048
# 1s - loss: 0.4650 - val_loss: 0.4790
# Epoch 103/2048
# 1s - loss: 0.4643 - val_loss: 0.4787
# Epoch 104/2048
# 1s - loss: 0.4635 - val_loss: 0.4781
# Epoch 105/2048
# 1s - loss: 0.4634 - val_loss: 0.4782
# Epoch 106/2048
# 1s - loss: 0.4627 - val_loss: 0.4770
# Epoch 107/2048
# 1s - loss: 0.4616 - val_loss: 0.4764
# Epoch 108/2048
# 1s - loss: 0.4610 - val_loss: 0.4762
# Epoch 109/2048
# 1s - loss: 0.4603 - val_loss: 0.4755
# Epoch 110/2048
# 1s - loss: 0.4597 - val_loss: 0.4749
# Epoch 111/2048
# 1s - loss: 0.4590 - val_loss: 0.4744
# Epoch 112/2048
# 1s - loss: 0.4585 - val_loss: 0.4737
# Epoch 113/2048
# 1s - loss: 0.4579 - val_loss: 0.4734
# Epoch 114/2048
# 1s - loss: 0.4574 - val_loss: 0.4728
# Epoch 115/2048
# 1s - loss: 0.4570 - val_loss: 0.4727
# Epoch 116/2048
# 1s - loss: 0.4565 - val_loss: 0.4718
# Epoch 117/2048
# 1s - loss: 0.4563 - val_loss: 0.4716
# Epoch 118/2048
# 1s - loss: 0.4555 - val_loss: 0.4714
# Epoch 119/2048
# 1s - loss: 0.4551 - val_loss: 0.4714
# Epoch 120/2048
# 1s - loss: 0.4547 - val_loss: 0.4704
# Epoch 121/2048
# 1s - loss: 0.4544 - val_loss: 0.4700
# Epoch 122/2048
# 1s - loss: 0.4538 - val_loss: 0.4697
# Epoch 123/2048
# 1s - loss: 0.4535 - val_loss: 0.4694
# Epoch 124/2048
# 1s - loss: 0.4529 - val_loss: 0.4692
# Epoch 125/2048
# 1s - loss: 0.4528 - val_loss: 0.4686
# Epoch 126/2048
# 1s - loss: 0.4522 - val_loss: 0.4681
# Epoch 127/2048
# 1s - loss: 0.4518 - val_loss: 0.4682
# Epoch 128/2048
# 1s - loss: 0.4516 - val_loss: 0.4680
# Epoch 129/2048
# 1s - loss: 0.4511 - val_loss: 0.4673
# Epoch 130/2048
# 1s - loss: 0.4508 - val_loss: 0.4670
# Epoch 131/2048
# 0s - loss: 0.4504 - val_loss: 0.4671
# Epoch 132/2048
# 0s - loss: 0.4502 - val_loss: 0.4671
# Epoch 133/2048
# 1s - loss: 0.4497 - val_loss: 0.4667
# Epoch 134/2048
# 1s - loss: 0.4495 - val_loss: 0.4660
# Epoch 135/2048
# 0s - loss: 0.4491 - val_loss: 0.4661
# Epoch 136/2048
# 1s - loss: 0.4488 - val_loss: 0.4655
# Epoch 137/2048
# 1s - loss: 0.4485 - val_loss: 0.4655
# Epoch 138/2048
# 1s - loss: 0.4483 - val_loss: 0.4648
# Epoch 139/2048
# 1s - loss: 0.4479 - val_loss: 0.4646
# Epoch 140/2048
# 1s - loss: 0.4478 - val_loss: 0.4647
# Epoch 141/2048
# 1s - loss: 0.4474 - val_loss: 0.4639
# Epoch 142/2048
# 1s - loss: 0.4472 - val_loss: 0.4643
# Epoch 143/2048
# 1s - loss: 0.4467 - val_loss: 0.4636
# Epoch 144/2048
# 1s - loss: 0.4465 - val_loss: 0.4633
# Epoch 145/2048
# 1s - loss: 0.4463 - val_loss: 0.4634
# Epoch 146/2048
# 1s - loss: 0.4460 - val_loss: 0.4631
# Epoch 147/2048
# 1s - loss: 0.4458 - val_loss: 0.4625
# Epoch 148/2048
# 0s - loss: 0.4456 - val_loss: 0.4631
# Epoch 149/2048
# 1s - loss: 0.4453 - val_loss: 0.4618
# Epoch 150/2048
# 1s - loss: 0.4450 - val_loss: 0.4620
# Epoch 151/2048
# 0s - loss: 0.4445 - val_loss: 0.4621
# Epoch 152/2048
# 1s - loss: 0.4443 - val_loss: 0.4617
# Epoch 153/2048
# 1s - loss: 0.4441 - val_loss: 0.4612
# Epoch 154/2048
# 0s - loss: 0.4439 - val_loss: 0.4614
# Epoch 155/2048
# 0s - loss: 0.4436 - val_loss: 0.4613
# Epoch 156/2048
# 1s - loss: 0.4434 - val_loss: 0.4606
# Epoch 157/2048
# 1s - loss: 0.4430 - val_loss: 0.4606
# Epoch 158/2048
# 1s - loss: 0.4429 - val_loss: 0.4606
# Epoch 159/2048
# 1s - loss: 0.4426 - val_loss: 0.4602
# Epoch 160/2048
# 1s - loss: 0.4423 - val_loss: 0.4596
# Epoch 161/2048
# 0s - loss: 0.4421 - val_loss: 0.4596
# Epoch 162/2048
# 1s - loss: 0.4419 - val_loss: 0.4598
# Epoch 163/2048
# 1s - loss: 0.4416 - val_loss: 0.4590
# Epoch 164/2048
# 0s - loss: 0.4414 - val_loss: 0.4590
# Epoch 165/2048
# 1s - loss: 0.4411 - val_loss: 0.4585
# Epoch 166/2048
# 1s - loss: 0.4408 - val_loss: 0.4584
# Epoch 167/2048
# 1s - loss: 0.4405 - val_loss: 0.4577
# Epoch 168/2048
# 0s - loss: 0.4404 - val_loss: 0.4579
# Epoch 169/2048
# 1s - loss: 0.4400 - val_loss: 0.4579
# Epoch 170/2048
# 1s - loss: 0.4399 - val_loss: 0.4577
# Epoch 171/2048
# 1s - loss: 0.4397 - val_loss: 0.4578
# Epoch 172/2048
# 1s - loss: 0.4394 - val_loss: 0.4577
# Epoch 173/2048
# 1s - loss: 0.4392 - val_loss: 0.4572
# Epoch 174/2048
# 1s - loss: 0.4389 - val_loss: 0.4569
# Epoch 175/2048
# 1s - loss: 0.4386 - val_loss: 0.4564
# Epoch 176/2048
# 0s - loss: 0.4384 - val_loss: 0.4564
# Epoch 177/2048
# 0s - loss: 0.4383 - val_loss: 0.4567
# Epoch 178/2048
# 1s - loss: 0.4380 - val_loss: 0.4560
# Epoch 179/2048
# 0s - loss: 0.4377 - val_loss: 0.4562
# Epoch 180/2048
# 1s - loss: 0.4376 - val_loss: 0.4563
# Epoch 181/2048
# 1s - loss: 0.4373 - val_loss: 0.4554
# Epoch 182/2048
# 1s - loss: 0.4371 - val_loss: 0.4556
# Epoch 183/2048
# 1s - loss: 0.4369 - val_loss: 0.4550
# Epoch 184/2048
# 1s - loss: 0.4367 - val_loss: 0.4546
# Epoch 185/2048
# 0s - loss: 0.4365 - val_loss: 0.4550
# Epoch 186/2048
# 1s - loss: 0.4363 - val_loss: 0.4544
# Epoch 187/2048
# 1s - loss: 0.4361 - val_loss: 0.4543
# Epoch 188/2048
# 1s - loss: 0.4359 - val_loss: 0.4536
# Epoch 189/2048
# 0s - loss: 0.4356 - val_loss: 0.4540
# Epoch 190/2048
# 0s - loss: 0.4354 - val_loss: 0.4539
# Epoch 191/2048
# 1s - loss: 0.4353 - val_loss: 0.4535
# Epoch 192/2048
# 1s - loss: 0.4351 - val_loss: 0.4537
# Epoch 193/2048
# 1s - loss: 0.4348 - val_loss: 0.4533
# Epoch 194/2048
# 1s - loss: 0.4353 - val_loss: 0.4539
# Epoch 195/2048
# 1s - loss: 0.4344 - val_loss: 0.4531
# Epoch 196/2048
# 1s - loss: 0.4344 - val_loss: 0.4530
# Epoch 197/2048
# 1s - loss: 0.4340 - val_loss: 0.4525
# Epoch 198/2048
# 1s - loss: 0.4338 - val_loss: 0.4523
# Epoch 199/2048
# 0s - loss: 0.4340 - val_loss: 0.4523
# Epoch 200/2048
# 1s - loss: 0.4336 - val_loss: 0.4518
# Epoch 201/2048
# 1s - loss: 0.4334 - val_loss: 0.4523
# Epoch 202/2048
# 1s - loss: 0.4330 - val_loss: 0.4518
# Epoch 203/2048
# 1s - loss: 0.4328 - val_loss: 0.4515
# Epoch 204/2048
# 0s - loss: 0.4327 - val_loss: 0.4520
# Epoch 205/2048
# 1s - loss: 0.4325 - val_loss: 0.4510
# Epoch 206/2048
# 0s - loss: 0.4324 - val_loss: 0.4515
# Epoch 207/2048
# 0s - loss: 0.4321 - val_loss: 0.4511
# Epoch 208/2048
# 1s - loss: 0.4319 - val_loss: 0.4509
# Epoch 209/2048
# 1s - loss: 0.4318 - val_loss: 0.4509
# Epoch 210/2048
# 1s - loss: 0.4317 - val_loss: 0.4505
# Epoch 211/2048
# 1s - loss: 0.4314 - val_loss: 0.4500
# Epoch 212/2048
# 1s - loss: 0.4312 - val_loss: 0.4497
# Epoch 213/2048
# 0s - loss: 0.4310 - val_loss: 0.4503
# Epoch 214/2048
# 1s - loss: 0.4310 - val_loss: 0.4495
# Epoch 215/2048
# 1s - loss: 0.4308 - val_loss: 0.4495
# Epoch 216/2048
# 1s - loss: 0.4306 - val_loss: 0.4491
# Epoch 217/2048
# 0s - loss: 0.4305 - val_loss: 0.4494
# Epoch 218/2048
# 0s - loss: 0.4303 - val_loss: 0.4500
# Epoch 219/2048
# 1s - loss: 0.4303 - val_loss: 0.4489
# Epoch 220/2048
# 0s - loss: 0.4301 - val_loss: 0.4493
# Epoch 221/2048
# 0s - loss: 0.4300 - val_loss: 0.4490
# Epoch 222/2048
# 0s - loss: 0.4296 - val_loss: 0.4489
# Epoch 223/2048
# 1s - loss: 0.4295 - val_loss: 0.4482
# Epoch 224/2048
# 1s - loss: 0.4294 - val_loss: 0.4482
# Epoch 225/2048
# 0s - loss: 0.4292 - val_loss: 0.4483
# Epoch 226/2048
# 1s - loss: 0.4291 - val_loss: 0.4482
# Epoch 227/2048
# 1s - loss: 0.4289 - val_loss: 0.4478
# Epoch 228/2048
# 1s - loss: 0.4287 - val_loss: 0.4478
# Epoch 229/2048
# 1s - loss: 0.4286 - val_loss: 0.4476
# Epoch 230/2048
# 1s - loss: 0.4285 - val_loss: 0.4475
# Epoch 231/2048
# 0s - loss: 0.4282 - val_loss: 0.4476
# Epoch 232/2048
# 1s - loss: 0.4280 - val_loss: 0.4471
# Epoch 233/2048
# 1s - loss: 0.4281 - val_loss: 0.4468
# Epoch 234/2048
# 0s - loss: 0.4279 - val_loss: 0.4469
# Epoch 235/2048
# 1s - loss: 0.4277 - val_loss: 0.4467
# Epoch 236/2048
# 0s - loss: 0.4275 - val_loss: 0.4468
# Epoch 237/2048
# 1s - loss: 0.4273 - val_loss: 0.4464
# Epoch 238/2048
# 1s - loss: 0.4270 - val_loss: 0.4463
# Epoch 239/2048
# 0s - loss: 0.4269 - val_loss: 0.4463
# Epoch 240/2048
# 1s - loss: 0.4268 - val_loss: 0.4460
# Epoch 241/2048
# 0s - loss: 0.4268 - val_loss: 0.4464
# Epoch 242/2048
# 1s - loss: 0.4265 - val_loss: 0.4457
# Epoch 243/2048
# 0s - loss: 0.4264 - val_loss: 0.4457
# Epoch 244/2048
# 1s - loss: 0.4261 - val_loss: 0.4455
# Epoch 245/2048
# 1s - loss: 0.4261 - val_loss: 0.4455
# Epoch 246/2048
# 1s - loss: 0.4259 - val_loss: 0.4451
# Epoch 247/2048
# 1s - loss: 0.4258 - val_loss: 0.4449
# Epoch 248/2048
# 0s - loss: 0.4257 - val_loss: 0.4453
# Epoch 249/2048
# 0s - loss: 0.4254 - val_loss: 0.4452
# Epoch 250/2048
# 1s - loss: 0.4254 - val_loss: 0.4443
# Epoch 251/2048
# 0s - loss: 0.4251 - val_loss: 0.4444
# Epoch 252/2048
# 1s - loss: 0.4249 - val_loss: 0.4453
# Epoch 253/2048
# 1s - loss: 0.4248 - val_loss: 0.4441
# Epoch 254/2048
# 1s - loss: 0.4247 - val_loss: 0.4441
# Epoch 255/2048
# 1s - loss: 0.4245 - val_loss: 0.4440
# Epoch 256/2048
# 1s - loss: 0.4243 - val_loss: 0.4432
# Epoch 257/2048
# 1s - loss: 0.4242 - val_loss: 0.4431
# Epoch 258/2048
# 0s - loss: 0.4241 - val_loss: 0.4434
# Epoch 259/2048
# 0s - loss: 0.4239 - val_loss: 0.4435
# Epoch 260/2048
# 0s - loss: 0.4237 - val_loss: 0.4433
# Epoch 261/2048
# 1s - loss: 0.4236 - val_loss: 0.4430
# Epoch 262/2048
# 0s - loss: 0.4235 - val_loss: 0.4433
# Epoch 263/2048
# 1s - loss: 0.4235 - val_loss: 0.4428
# Epoch 264/2048
# 0s - loss: 0.4232 - val_loss: 0.4430
# Epoch 265/2048
# 1s - loss: 0.4232 - val_loss: 0.4425
# Epoch 266/2048
# 0s - loss: 0.4230 - val_loss: 0.4428
# Epoch 267/2048
# 1s - loss: 0.4228 - val_loss: 0.4423
# Epoch 268/2048
# 1s - loss: 0.4226 - val_loss: 0.4420
# Epoch 269/2048
# 0s - loss: 0.4224 - val_loss: 0.4426
# Epoch 270/2048
# 0s - loss: 0.4225 - val_loss: 0.4422
# Epoch 271/2048
# 0s - loss: 0.4223 - val_loss: 0.4421
# Epoch 272/2048
# 1s - loss: 0.4223 - val_loss: 0.4415
# Epoch 273/2048
# 0s - loss: 0.4220 - val_loss: 0.4417
# Epoch 274/2048
# 0s - loss: 0.4218 - val_loss: 0.4423
# Epoch 275/2048
# 0s - loss: 0.4218 - val_loss: 0.4416
# Epoch 276/2048
# 1s - loss: 0.4216 - val_loss: 0.4414
# Epoch 277/2048
# 1s - loss: 0.4215 - val_loss: 0.4410
# Epoch 278/2048
# 1s - loss: 0.4214 - val_loss: 0.4409
# Epoch 279/2048
# 0s - loss: 0.4213 - val_loss: 0.4411
# Epoch 280/2048
# 0s - loss: 0.4218 - val_loss: 0.4416
# Epoch 281/2048
# 1s - loss: 0.4213 - val_loss: 0.4406
# Epoch 282/2048
# 0s - loss: 0.4210 - val_loss: 0.4413
# Epoch 283/2048
# 0s - loss: 0.4212 - val_loss: 0.4409
# Epoch 284/2048
# 1s - loss: 0.4208 - val_loss: 0.4401
# Epoch 285/2048
# 0s - loss: 0.4206 - val_loss: 0.4401
# Epoch 286/2048
# 0s - loss: 0.4204 - val_loss: 0.4407
# Epoch 287/2048
# 0s - loss: 0.4204 - val_loss: 0.4401
# Epoch 288/2048
# 0s - loss: 0.4202 - val_loss: 0.4402
# Epoch 289/2048
# 1s - loss: 0.4201 - val_loss: 0.4400
# Epoch 290/2048
# 1s - loss: 0.4200 - val_loss: 0.4395
# Epoch 291/2048
# 0s - loss: 0.4200 - val_loss: 0.4401
# Epoch 292/2048
# 0s - loss: 0.4199 - val_loss: 0.4398
# Epoch 293/2048
# 0s - loss: 0.4197 - val_loss: 0.4396
# Epoch 294/2048
# 0s - loss: 0.4195 - val_loss: 0.4397
# Epoch 295/2048
# 1s - loss: 0.4195 - val_loss: 0.4393
# Epoch 296/2048
# 1s - loss: 0.4194 - val_loss: 0.4391
# Epoch 297/2048
# 0s - loss: 0.4192 - val_loss: 0.4396
# Epoch 298/2048
# 0s - loss: 0.4192 - val_loss: 0.4391
# Epoch 299/2048
# 1s - loss: 0.4190 - val_loss: 0.4385
# Epoch 300/2048
# 0s - loss: 0.4189 - val_loss: 0.4393
# Epoch 301/2048
# 1s - loss: 0.4188 - val_loss: 0.4385
# Epoch 302/2048
# 0s - loss: 0.4187 - val_loss: 0.4388
# Epoch 303/2048
# 1s - loss: 0.4185 - val_loss: 0.4385
# Epoch 304/2048
# 0s - loss: 0.4184 - val_loss: 0.4389
# Epoch 305/2048
# 1s - loss: 0.4183 - val_loss: 0.4385
# Epoch 306/2048
# 0s - loss: 0.4183 - val_loss: 0.4387
# Epoch 307/2048
# 1s - loss: 0.4181 - val_loss: 0.4381
# Epoch 308/2048
# 0s - loss: 0.4180 - val_loss: 0.4383
# Epoch 309/2048
# 1s - loss: 0.4180 - val_loss: 0.4381
# Epoch 310/2048
# 1s - loss: 0.4178 - val_loss: 0.4378
# Epoch 311/2048
# 1s - loss: 0.4177 - val_loss: 0.4377
# Epoch 312/2048
# 1s - loss: 0.4176 - val_loss: 0.4375
# Epoch 313/2048
# 1s - loss: 0.4176 - val_loss: 0.4384
# Epoch 314/2048
# 1s - loss: 0.4175 - val_loss: 0.4378
# Epoch 315/2048
# 0s - loss: 0.4173 - val_loss: 0.4376
# Epoch 316/2048
# 1s - loss: 0.4172 - val_loss: 0.4376
# Epoch 317/2048
# 1s - loss: 0.4170 - val_loss: 0.4372
# Epoch 318/2048
# 0s - loss: 0.4170 - val_loss: 0.4375
# Epoch 319/2048
# 1s - loss: 0.4168 - val_loss: 0.4369
# Epoch 320/2048
# 1s - loss: 0.4167 - val_loss: 0.4369
# Epoch 321/2048
# 1s - loss: 0.4167 - val_loss: 0.4368
# Epoch 322/2048
# 1s - loss: 0.4165 - val_loss: 0.4365
# Epoch 323/2048
# 1s - loss: 0.4165 - val_loss: 0.4370
# Epoch 324/2048
# 1s - loss: 0.4165 - val_loss: 0.4364
# Epoch 325/2048
# 0s - loss: 0.4162 - val_loss: 0.4367
# Epoch 326/2048
# 0s - loss: 0.4161 - val_loss: 0.4365
# Epoch 327/2048
# 1s - loss: 0.4160 - val_loss: 0.4358
# Epoch 328/2048
# 0s - loss: 0.4158 - val_loss: 0.4364
# Epoch 329/2048
# 0s - loss: 0.4157 - val_loss: 0.4363
# Epoch 330/2048
# 0s - loss: 0.4157 - val_loss: 0.4360
# Epoch 331/2048
# 0s - loss: 0.4156 - val_loss: 0.4363
# Epoch 332/2048
# 0s - loss: 0.4154 - val_loss: 0.4363
# Epoch 333/2048
# 0s - loss: 0.4153 - val_loss: 0.4359
# Epoch 334/2048
# 1s - loss: 0.4152 - val_loss: 0.4355
# Epoch 335/2048
# 0s - loss: 0.4150 - val_loss: 0.4360
# Epoch 336/2048
# 0s - loss: 0.4150 - val_loss: 0.4360
# Epoch 337/2048
# 1s - loss: 0.4148 - val_loss: 0.4353
# Epoch 338/2048
# 1s - loss: 0.4146 - val_loss: 0.4350
# Epoch 339/2048
# 0s - loss: 0.4146 - val_loss: 0.4353
# Epoch 340/2048
# 1s - loss: 0.4145 - val_loss: 0.4348
# Epoch 341/2048
# 1s - loss: 0.4144 - val_loss: 0.4348
# Epoch 342/2048
# 0s - loss: 0.4143 - val_loss: 0.4348
# Epoch 343/2048
# 1s - loss: 0.4141 - val_loss: 0.4345
# Epoch 344/2048
# 1s - loss: 0.4139 - val_loss: 0.4343
# Epoch 345/2048
# 0s - loss: 0.4138 - val_loss: 0.4344
# Epoch 346/2048
# 0s - loss: 0.4137 - val_loss: 0.4344
# Epoch 347/2048
# 0s - loss: 0.4136 - val_loss: 0.4346
# Epoch 348/2048
# 1s - loss: 0.4135 - val_loss: 0.4337
# Epoch 349/2048
# 1s - loss: 0.4133 - val_loss: 0.4339
# Epoch 350/2048
# 1s - loss: 0.4133 - val_loss: 0.4335
# Epoch 351/2048
# 0s - loss: 0.4132 - val_loss: 0.4339
# Epoch 352/2048
# 1s - loss: 0.4130 - val_loss: 0.4334
# Epoch 353/2048
# 1s - loss: 0.4128 - val_loss: 0.4335
# Epoch 354/2048
# 1s - loss: 0.4128 - val_loss: 0.4334
# Epoch 355/2048
# 1s - loss: 0.4126 - val_loss: 0.4332
# Epoch 356/2048
# 0s - loss: 0.4125 - val_loss: 0.4337
# Epoch 357/2048
# 1s - loss: 0.4124 - val_loss: 0.4331
# Epoch 358/2048
# 1s - loss: 0.4123 - val_loss: 0.4331
# Epoch 359/2048
# 1s - loss: 0.4122 - val_loss: 0.4333
# Epoch 360/2048
# 1s - loss: 0.4121 - val_loss: 0.4331
# Epoch 361/2048
# 1s - loss: 0.4119 - val_loss: 0.4330
# Epoch 362/2048
# 1s - loss: 0.4119 - val_loss: 0.4329
# Epoch 363/2048
# 1s - loss: 0.4117 - val_loss: 0.4320
# Epoch 364/2048
# 0s - loss: 0.4116 - val_loss: 0.4323
# Epoch 365/2048
# 1s - loss: 0.4115 - val_loss: 0.4324
# Epoch 366/2048
# 0s - loss: 0.4114 - val_loss: 0.4323
# Epoch 367/2048
# 0s - loss: 0.4113 - val_loss: 0.4322
# Epoch 368/2048
# 1s - loss: 0.4112 - val_loss: 0.4319
# Epoch 369/2048
# 0s - loss: 0.4111 - val_loss: 0.4326
# Epoch 370/2048
# 0s - loss: 0.4109 - val_loss: 0.4321
# Epoch 371/2048
# 0s - loss: 0.4108 - val_loss: 0.4320
# Epoch 372/2048
# 0s - loss: 0.4108 - val_loss: 0.4321
# Epoch 373/2048
# 1s - loss: 0.4108 - val_loss: 0.4314
# Epoch 374/2048
# 0s - loss: 0.4105 - val_loss: 0.4317
# Epoch 375/2048
# 0s - loss: 0.4104 - val_loss: 0.4314
# Epoch 376/2048
# 1s - loss: 0.4104 - val_loss: 0.4310
# Epoch 377/2048
# 0s - loss: 0.4102 - val_loss: 0.4316
# Epoch 378/2048
# 1s - loss: 0.4102 - val_loss: 0.4315
# Epoch 379/2048
# 0s - loss: 0.4100 - val_loss: 0.4314
# Epoch 380/2048
# 1s - loss: 0.4099 - val_loss: 0.4307
# Epoch 381/2048
# 0s - loss: 0.4098 - val_loss: 0.4310
# Epoch 382/2048
# 0s - loss: 0.4097 - val_loss: 0.4309
# Epoch 383/2048
# 0s - loss: 0.4096 - val_loss: 0.4309
# Epoch 384/2048
# 1s - loss: 0.4094 - val_loss: 0.4305
# Epoch 385/2048
# 1s - loss: 0.4094 - val_loss: 0.4305
# Epoch 386/2048
# 1s - loss: 0.4093 - val_loss: 0.4303
# Epoch 387/2048
# 1s - loss: 0.4092 - val_loss: 0.4307
# Epoch 388/2048
# 1s - loss: 0.4091 - val_loss: 0.4304
# Epoch 389/2048
# 0s - loss: 0.4090 - val_loss: 0.4305
# Epoch 390/2048
# 1s - loss: 0.4093 - val_loss: 0.4305
# Epoch 391/2048
# 0s - loss: 0.4087 - val_loss: 0.4304
# Epoch 392/2048
# 1s - loss: 0.4086 - val_loss: 0.4301
# Epoch 393/2048
# 1s - loss: 0.4088 - val_loss: 0.4299
# Epoch 394/2048
# 1s - loss: 0.4085 - val_loss: 0.4297
# Epoch 395/2048
# 1s - loss: 0.4083 - val_loss: 0.4296
# Epoch 396/2048
# 1s - loss: 0.4083 - val_loss: 0.4302
# Epoch 397/2048
# 1s - loss: 0.4082 - val_loss: 0.4292
# Epoch 398/2048
# 1s - loss: 0.4081 - val_loss: 0.4297
# Epoch 399/2048
# 1s - loss: 0.4079 - val_loss: 0.4292
# Epoch 400/2048
# 1s - loss: 0.4079 - val_loss: 0.4293
# Epoch 401/2048
# 0s - loss: 0.4078 - val_loss: 0.4293
# Epoch 402/2048
# 1s - loss: 0.4077 - val_loss: 0.4291
# Epoch 403/2048
# 0s - loss: 0.4077 - val_loss: 0.4295
# Epoch 404/2048
# 0s - loss: 0.4076 - val_loss: 0.4293
# Epoch 405/2048
# 1s - loss: 0.4074 - val_loss: 0.4288
# Epoch 406/2048
# 1s - loss: 0.4073 - val_loss: 0.4287
# Epoch 407/2048
# 0s - loss: 0.4072 - val_loss: 0.4289
# Epoch 408/2048
# 0s - loss: 0.4072 - val_loss: 0.4294
# Epoch 409/2048
# 1s - loss: 0.4070 - val_loss: 0.4288
# Epoch 410/2048
# 0s - loss: 0.4069 - val_loss: 0.4287
# Epoch 411/2048
# 1s - loss: 0.4068 - val_loss: 0.4285
# Epoch 412/2048
# 1s - loss: 0.4068 - val_loss: 0.4284
# Epoch 413/2048
# 1s - loss: 0.4066 - val_loss: 0.4282
# Epoch 414/2048
# 1s - loss: 0.4066 - val_loss: 0.4282
# Epoch 415/2048
# 1s - loss: 0.4064 - val_loss: 0.4282
# Epoch 416/2048
# 1s - loss: 0.4063 - val_loss: 0.4277
# Epoch 417/2048
# 1s - loss: 0.4062 - val_loss: 0.4276
# Epoch 418/2048
# 0s - loss: 0.4061 - val_loss: 0.4276
# Epoch 419/2048
# 0s - loss: 0.4061 - val_loss: 0.4280
# Epoch 420/2048
# 0s - loss: 0.4059 - val_loss: 0.4285
# Epoch 421/2048
# 0s - loss: 0.4059 - val_loss: 0.4280
# Epoch 422/2048
# 1s - loss: 0.4057 - val_loss: 0.4272
# Epoch 423/2048
# 0s - loss: 0.4057 - val_loss: 0.4279
# Epoch 424/2048
# 0s - loss: 0.4056 - val_loss: 0.4273
# Epoch 425/2048
# 0s - loss: 0.4055 - val_loss: 0.4276
# Epoch 426/2048
# 0s - loss: 0.4053 - val_loss: 0.4277
# Epoch 427/2048
# 0s - loss: 0.4053 - val_loss: 0.4276
# Epoch 428/2048
# 1s - loss: 0.4052 - val_loss: 0.4272
# Epoch 429/2048
# 1s - loss: 0.4051 - val_loss: 0.4269
# Epoch 430/2048
# 1s - loss: 0.4049 - val_loss: 0.4269
# Epoch 431/2048
# 1s - loss: 0.4048 - val_loss: 0.4269
# Epoch 432/2048
# 1s - loss: 0.4048 - val_loss: 0.4267
# Epoch 433/2048
# 1s - loss: 0.4047 - val_loss: 0.4268
# Epoch 434/2048
# 1s - loss: 0.4046 - val_loss: 0.4263
# Epoch 435/2048
# 1s - loss: 0.4045 - val_loss: 0.4270
# Epoch 436/2048
# 0s - loss: 0.4045 - val_loss: 0.4266
# Epoch 437/2048
# 0s - loss: 0.4043 - val_loss: 0.4269
# Epoch 438/2048
# 0s - loss: 0.4042 - val_loss: 0.4263
# Epoch 439/2048
# 1s - loss: 0.4042 - val_loss: 0.4268
# Epoch 440/2048
# 1s - loss: 0.4041 - val_loss: 0.4262
# Epoch 441/2048
# 1s - loss: 0.4040 - val_loss: 0.4261
# Epoch 442/2048
# 1s - loss: 0.4039 - val_loss: 0.4258
# Epoch 443/2048
# 1s - loss: 0.4038 - val_loss: 0.4261
# Epoch 444/2048
# 0s - loss: 0.4036 - val_loss: 0.4261
# Epoch 445/2048
# 0s - loss: 0.4035 - val_loss: 0.4260
# Epoch 446/2048
# 0s - loss: 0.4035 - val_loss: 0.4260
# Epoch 447/2048
# 0s - loss: 0.4033 - val_loss: 0.4259
# Epoch 448/2048
# 1s - loss: 0.4033 - val_loss: 0.4256
# Epoch 449/2048
# 0s - loss: 0.4032 - val_loss: 0.4257
# Epoch 450/2048
# 1s - loss: 0.4032 - val_loss: 0.4257
# Epoch 451/2048
# 1s - loss: 0.4031 - val_loss: 0.4254
# Epoch 452/2048
# 0s - loss: 0.4029 - val_loss: 0.4255
# Epoch 453/2048
# 1s - loss: 0.4029 - val_loss: 0.4253
# Epoch 454/2048
# 1s - loss: 0.4028 - val_loss: 0.4250
# Epoch 455/2048
# 0s - loss: 0.4027 - val_loss: 0.4253
# Epoch 456/2048
# 0s - loss: 0.4025 - val_loss: 0.4252
# Epoch 457/2048
# 1s - loss: 0.4024 - val_loss: 0.4246
# Epoch 458/2048
# 0s - loss: 0.4024 - val_loss: 0.4252
# Epoch 459/2048
# 1s - loss: 0.4023 - val_loss: 0.4250
# Epoch 460/2048
# 1s - loss: 0.4022 - val_loss: 0.4242
# Epoch 461/2048
# 1s - loss: 0.4020 - val_loss: 0.4247
# Epoch 462/2048
# 0s - loss: 0.4020 - val_loss: 0.4245
# Epoch 463/2048
# 0s - loss: 0.4019 - val_loss: 0.4247
# Epoch 464/2048
# 0s - loss: 0.4020 - val_loss: 0.4247
# Epoch 465/2048
# 0s - loss: 0.4017 - val_loss: 0.4246
# Epoch 466/2048
# 1s - loss: 0.4017 - val_loss: 0.4242
# Epoch 467/2048
# 1s - loss: 0.4014 - val_loss: 0.4242
# Epoch 468/2048
# 1s - loss: 0.4015 - val_loss: 0.4241
# Epoch 469/2048
# 1s - loss: 0.4013 - val_loss: 0.4241
# Epoch 470/2048
# 0s - loss: 0.4013 - val_loss: 0.4243
# Epoch 471/2048
# 1s - loss: 0.4012 - val_loss: 0.4234
# Epoch 472/2048
# 1s - loss: 0.4010 - val_loss: 0.4233
# Epoch 473/2048
# 0s - loss: 0.4010 - val_loss: 0.4238
# Epoch 474/2048
# 1s - loss: 0.4009 - val_loss: 0.4233
# Epoch 475/2048
# 0s - loss: 0.4008 - val_loss: 0.4237
# Epoch 476/2048
# 1s - loss: 0.4007 - val_loss: 0.4235
# Epoch 477/2048
# 1s - loss: 0.4005 - val_loss: 0.4235
# Epoch 478/2048
# 1s - loss: 0.4005 - val_loss: 0.4235
# Epoch 479/2048
# 0s - loss: 0.4004 - val_loss: 0.4234
# Epoch 480/2048
# 1s - loss: 0.4004 - val_loss: 0.4234
# Epoch 481/2048
# 1s - loss: 0.4002 - val_loss: 0.4230
# Epoch 482/2048
# 0s - loss: 0.4001 - val_loss: 0.4233
# Epoch 483/2048
# 1s - loss: 0.3999 - val_loss: 0.4229
# Epoch 484/2048
# 1s - loss: 0.3999 - val_loss: 0.4229
# Epoch 485/2048
# 1s - loss: 0.3998 - val_loss: 0.4227
# Epoch 486/2048
# 1s - loss: 0.3997 - val_loss: 0.4228
# Epoch 487/2048
# 1s - loss: 0.3996 - val_loss: 0.4230
# Epoch 488/2048
# 0s - loss: 0.3996 - val_loss: 0.4229
# Epoch 489/2048
# 1s - loss: 0.3995 - val_loss: 0.4229
# Epoch 490/2048
# 0s - loss: 0.3994 - val_loss: 0.4228
# Epoch 491/2048
# 1s - loss: 0.3993 - val_loss: 0.4222
# Epoch 492/2048
# 1s - loss: 0.3992 - val_loss: 0.4224
# Epoch 493/2048
# 0s - loss: 0.3991 - val_loss: 0.4225
# Epoch 494/2048
# 1s - loss: 0.3994 - val_loss: 0.4220
# Epoch 495/2048
# 0s - loss: 0.3990 - val_loss: 0.4222
# Epoch 496/2048
# 0s - loss: 0.3988 - val_loss: 0.4226
# Epoch 497/2048
# 0s - loss: 0.3987 - val_loss: 0.4221
# Epoch 498/2048
# 0s - loss: 0.3987 - val_loss: 0.4222
# Epoch 499/2048
# 0s - loss: 0.3986 - val_loss: 0.4222
# Epoch 500/2048
# 1s - loss: 0.3985 - val_loss: 0.4219
# Epoch 501/2048
# 0s - loss: 0.3984 - val_loss: 0.4219
# Epoch 502/2048
# 1s - loss: 0.3983 - val_loss: 0.4215
# Epoch 503/2048
# 0s - loss: 0.3982 - val_loss: 0.4217
# Epoch 504/2048
# 0s - loss: 0.3984 - val_loss: 0.4216
# Epoch 505/2048
# 1s - loss: 0.3981 - val_loss: 0.4212
# Epoch 506/2048
# 0s - loss: 0.3981 - val_loss: 0.4214
# Epoch 507/2048
# 0s - loss: 0.3978 - val_loss: 0.4216
# Epoch 508/2048
# 0s - loss: 0.3978 - val_loss: 0.4213
# Epoch 509/2048
# 0s - loss: 0.3977 - val_loss: 0.4214
# Epoch 510/2048
# 0s - loss: 0.3976 - val_loss: 0.4214
# Epoch 511/2048
# 1s - loss: 0.3976 - val_loss: 0.4210
# Epoch 512/2048
# 1s - loss: 0.3975 - val_loss: 0.4209
# Epoch 513/2048
# 1s - loss: 0.3974 - val_loss: 0.4206
# Epoch 514/2048
# 0s - loss: 0.3973 - val_loss: 0.4207
# Epoch 515/2048
# 1s - loss: 0.3972 - val_loss: 0.4204
# Epoch 516/2048
# 0s - loss: 0.3972 - val_loss: 0.4208
# Epoch 517/2048
# 0s - loss: 0.3971 - val_loss: 0.4211
# Epoch 518/2048
# 1s - loss: 0.3971 - val_loss: 0.4203
# Epoch 519/2048
# 0s - loss: 0.3969 - val_loss: 0.4204
# Epoch 520/2048
# 1s - loss: 0.3967 - val_loss: 0.4198
# Epoch 521/2048
# 0s - loss: 0.3967 - val_loss: 0.4199
# Epoch 522/2048
# 0s - loss: 0.3967 - val_loss: 0.4208
# Epoch 523/2048
# 0s - loss: 0.3965 - val_loss: 0.4199
# Epoch 524/2048
# 0s - loss: 0.3963 - val_loss: 0.4204
# Epoch 525/2048
# 1s - loss: 0.3963 - val_loss: 0.4196
# Epoch 526/2048
# 0s - loss: 0.3962 - val_loss: 0.4197
# Epoch 527/2048
# 0s - loss: 0.3961 - val_loss: 0.4197
# Epoch 528/2048
# 0s - loss: 0.3961 - val_loss: 0.4196
# Epoch 529/2048
# 1s - loss: 0.3960 - val_loss: 0.4195
# Epoch 530/2048
# 1s - loss: 0.3959 - val_loss: 0.4191
# Epoch 531/2048
# 0s - loss: 0.3958 - val_loss: 0.4197
# Epoch 532/2048
# 1s - loss: 0.3957 - val_loss: 0.4191
# Epoch 533/2048
# 0s - loss: 0.3957 - val_loss: 0.4192
# Epoch 534/2048
# 0s - loss: 0.3956 - val_loss: 0.4193
# Epoch 535/2048
# 0s - loss: 0.3954 - val_loss: 0.4192
# Epoch 536/2048
# 0s - loss: 0.3954 - val_loss: 0.4192
# Epoch 537/2048
# 1s - loss: 0.3953 - val_loss: 0.4190
# Epoch 538/2048
# 1s - loss: 0.3953 - val_loss: 0.4189
# Epoch 539/2048
# 0s - loss: 0.3954 - val_loss: 0.4194
# Epoch 540/2048
# 1s - loss: 0.3951 - val_loss: 0.4185
# Epoch 541/2048
# 1s - loss: 0.3950 - val_loss: 0.4184
# Epoch 542/2048
# 0s - loss: 0.3949 - val_loss: 0.4190
# Epoch 543/2048
# 0s - loss: 0.3947 - val_loss: 0.4187
# Epoch 544/2048
# 0s - loss: 0.3947 - val_loss: 0.4186
# Epoch 545/2048
# 0s - loss: 0.3946 - val_loss: 0.4186
# Epoch 546/2048
# 0s - loss: 0.3945 - val_loss: 0.4188
# Epoch 547/2048
# 0s - loss: 0.3944 - val_loss: 0.4184
# Epoch 548/2048
# 1s - loss: 0.3942 - val_loss: 0.4183
# Epoch 549/2048
# 1s - loss: 0.3942 - val_loss: 0.4180
# Epoch 550/2048
# 1s - loss: 0.3941 - val_loss: 0.4180
# Epoch 551/2048
# 1s - loss: 0.3941 - val_loss: 0.4180
# Epoch 552/2048
# 0s - loss: 0.3939 - val_loss: 0.4180
# Epoch 553/2048
# 1s - loss: 0.3938 - val_loss: 0.4175
# Epoch 554/2048
# 1s - loss: 0.3937 - val_loss: 0.4177
# Epoch 555/2048
# 1s - loss: 0.3935 - val_loss: 0.4171
# Epoch 556/2048
# 1s - loss: 0.3934 - val_loss: 0.4170
# Epoch 557/2048
# 0s - loss: 0.3934 - val_loss: 0.4175
# Epoch 558/2048
# 1s - loss: 0.3932 - val_loss: 0.4164
# Epoch 559/2048
# 0s - loss: 0.3930 - val_loss: 0.4164
# Epoch 560/2048
# 1s - loss: 0.3929 - val_loss: 0.4159
# Epoch 561/2048
# 0s - loss: 0.3927 - val_loss: 0.4160
# Epoch 562/2048
# 0s - loss: 0.3926 - val_loss: 0.4164
# Epoch 563/2048
# 0s - loss: 0.3929 - val_loss: 0.4159
# Epoch 564/2048
# 0s - loss: 0.3923 - val_loss: 0.4159
# Epoch 565/2048
# 1s - loss: 0.3921 - val_loss: 0.4152
# Epoch 566/2048
# 0s - loss: 0.3920 - val_loss: 0.4153
# Epoch 567/2048
# 0s - loss: 0.3918 - val_loss: 0.4159
# Epoch 568/2048
# 1s - loss: 0.3919 - val_loss: 0.4150
# Epoch 569/2048
# 0s - loss: 0.3917 - val_loss: 0.4158
# Epoch 570/2048
# 1s - loss: 0.3918 - val_loss: 0.4147
# Epoch 571/2048
# 1s - loss: 0.3914 - val_loss: 0.4146
# Epoch 572/2048
# 0s - loss: 0.3913 - val_loss: 0.4151
# Epoch 573/2048
# 1s - loss: 0.3912 - val_loss: 0.4143
# Epoch 574/2048
# 0s - loss: 0.3910 - val_loss: 0.4144
# Epoch 575/2048
# 1s - loss: 0.3909 - val_loss: 0.4139
# Epoch 576/2048
# 1s - loss: 0.3908 - val_loss: 0.4139
# Epoch 577/2048
# 1s - loss: 0.3906 - val_loss: 0.4137
# Epoch 578/2048
# 1s - loss: 0.3905 - val_loss: 0.4135
# Epoch 579/2048
# 0s - loss: 0.3904 - val_loss: 0.4136
# Epoch 580/2048
# 0s - loss: 0.3903 - val_loss: 0.4136
# Epoch 581/2048
# 1s - loss: 0.3902 - val_loss: 0.4131
# Epoch 582/2048
# 1s - loss: 0.3902 - val_loss: 0.4129
# Epoch 583/2048
# 0s - loss: 0.3901 - val_loss: 0.4129
# Epoch 584/2048
# 1s - loss: 0.3898 - val_loss: 0.4128
# Epoch 585/2048
# 1s - loss: 0.3897 - val_loss: 0.4123
# Epoch 586/2048
# 0s - loss: 0.3897 - val_loss: 0.4127
# Epoch 587/2048
# 0s - loss: 0.3895 - val_loss: 0.4129
# Epoch 588/2048
# 1s - loss: 0.3894 - val_loss: 0.4119
# Epoch 589/2048
# 0s - loss: 0.3893 - val_loss: 0.4123
# Epoch 590/2048
# 0s - loss: 0.3891 - val_loss: 0.4121
# Epoch 591/2048
# 0s - loss: 0.3891 - val_loss: 0.4122
# Epoch 592/2048
# 0s - loss: 0.3890 - val_loss: 0.4120
# Epoch 593/2048
# 1s - loss: 0.3888 - val_loss: 0.4118
# Epoch 594/2048
# 1s - loss: 0.3887 - val_loss: 0.4115
# Epoch 595/2048
# 1s - loss: 0.3887 - val_loss: 0.4114
# Epoch 596/2048
# 1s - loss: 0.3885 - val_loss: 0.4110
# Epoch 597/2048
# 0s - loss: 0.3884 - val_loss: 0.4111
# Epoch 598/2048
# 0s - loss: 0.3883 - val_loss: 0.4112
# Epoch 599/2048
# 1s - loss: 0.3882 - val_loss: 0.4108
# Epoch 600/2048
# 1s - loss: 0.3881 - val_loss: 0.4108
# Epoch 601/2048
# 1s - loss: 0.3880 - val_loss: 0.4106
# Epoch 602/2048
# 0s - loss: 0.3880 - val_loss: 0.4107
# Epoch 603/2048
# 0s - loss: 0.3878 - val_loss: 0.4107
# Epoch 604/2048
# 1s - loss: 0.3878 - val_loss: 0.4104
# Epoch 605/2048
# 0s - loss: 0.3877 - val_loss: 0.4108
# Epoch 606/2048
# 0s - loss: 0.3875 - val_loss: 0.4104
# Epoch 607/2048
# 1s - loss: 0.3874 - val_loss: 0.4098
# Epoch 608/2048
# 0s - loss: 0.3873 - val_loss: 0.4107
# Epoch 609/2048
# 0s - loss: 0.3875 - val_loss: 0.4102
# Epoch 610/2048
# 0s - loss: 0.3871 - val_loss: 0.4105
# Epoch 611/2048
# 1s - loss: 0.3871 - val_loss: 0.4093
# Epoch 612/2048
# 1s - loss: 0.3869 - val_loss: 0.4093
# Epoch 613/2048
# 0s - loss: 0.3868 - val_loss: 0.4096
# Epoch 614/2048
# 0s - loss: 0.3867 - val_loss: 0.4094
# Epoch 615/2048
# 1s - loss: 0.3866 - val_loss: 0.4091
# Epoch 616/2048
# 0s - loss: 0.3865 - val_loss: 0.4093
# Epoch 617/2048
# 0s - loss: 0.3864 - val_loss: 0.4092
# Epoch 618/2048
# 1s - loss: 0.3864 - val_loss: 0.4089
# Epoch 619/2048
# 0s - loss: 0.3863 - val_loss: 0.4091
# Epoch 620/2048
# 0s - loss: 0.3862 - val_loss: 0.4090
# Epoch 621/2048
# 0s - loss: 0.3865 - val_loss: 0.4090
# Epoch 622/2048
# 0s - loss: 0.3861 - val_loss: 0.4089
# Epoch 623/2048
# 1s - loss: 0.3860 - val_loss: 0.4085
# Epoch 624/2048
# 1s - loss: 0.3858 - val_loss: 0.4085
# Epoch 625/2048
# 1s - loss: 0.3857 - val_loss: 0.4081
# Epoch 626/2048
# 0s - loss: 0.3856 - val_loss: 0.4083
# Epoch 627/2048
# 0s - loss: 0.3855 - val_loss: 0.4086
# Epoch 628/2048
# 0s - loss: 0.3854 - val_loss: 0.4082
# Epoch 629/2048
# 0s - loss: 0.3854 - val_loss: 0.4084
# Epoch 630/2048
# 1s - loss: 0.3853 - val_loss: 0.4077
# Epoch 631/2048
# 0s - loss: 0.3851 - val_loss: 0.4078
# Epoch 632/2048
# 0s - loss: 0.3851 - val_loss: 0.4081
# Epoch 633/2048
# 1s - loss: 0.3850 - val_loss: 0.4076
# Epoch 634/2048
# 0s - loss: 0.3850 - val_loss: 0.4078
# Epoch 635/2048
# 1s - loss: 0.3849 - val_loss: 0.4075
# Epoch 636/2048
# 1s - loss: 0.3849 - val_loss: 0.4077
# Epoch 637/2048
# 1s - loss: 0.3846 - val_loss: 0.4070
# Epoch 638/2048
# 1s - loss: 0.3845 - val_loss: 0.4070
# Epoch 639/2048
# 1s - loss: 0.3844 - val_loss: 0.4069
# Epoch 640/2048
# 1s - loss: 0.3844 - val_loss: 0.4067
# Epoch 641/2048
# 0s - loss: 0.3844 - val_loss: 0.4069
# Epoch 642/2048
# 0s - loss: 0.3842 - val_loss: 0.4082
# Epoch 643/2048
# 0s - loss: 0.3845 - val_loss: 0.4076
# Epoch 644/2048
# 0s - loss: 0.3840 - val_loss: 0.4070
# Epoch 645/2048
# 0s - loss: 0.3840 - val_loss: 0.4069
# Epoch 646/2048
# 0s - loss: 0.3839 - val_loss: 0.4068
# Epoch 647/2048
# 0s - loss: 0.3838 - val_loss: 0.4069
# Epoch 648/2048
# 1s - loss: 0.3840 - val_loss: 0.4062
# Epoch 649/2048
# 0s - loss: 0.3837 - val_loss: 0.4066
# Epoch 650/2048
# 1s - loss: 0.3836 - val_loss: 0.4061
# Epoch 651/2048
# 0s - loss: 0.3835 - val_loss: 0.4069
# Epoch 652/2048
# 0s - loss: 0.3834 - val_loss: 0.4063
# Epoch 653/2048
# 1s - loss: 0.3833 - val_loss: 0.4060
# Epoch 654/2048
# 0s - loss: 0.3832 - val_loss: 0.4061
# Epoch 655/2048
# 0s - loss: 0.3832 - val_loss: 0.4060
# Epoch 656/2048
# 1s - loss: 0.3831 - val_loss: 0.4057
# Epoch 657/2048
# 1s - loss: 0.3830 - val_loss: 0.4054
# Epoch 658/2048
# 0s - loss: 0.3829 - val_loss: 0.4054
# Epoch 659/2048
# 1s - loss: 0.3827 - val_loss: 0.4051
# Epoch 660/2048
# 0s - loss: 0.3826 - val_loss: 0.4054
# Epoch 661/2048
# 1s - loss: 0.3826 - val_loss: 0.4051
# Epoch 662/2048
# 0s - loss: 0.3825 - val_loss: 0.4059
# Epoch 663/2048
# 0s - loss: 0.3828 - val_loss: 0.4062
# Epoch 664/2048
# 0s - loss: 0.3826 - val_loss: 0.4053
# Epoch 665/2048
# 1s - loss: 0.3823 - val_loss: 0.4050
# Epoch 666/2048
# 1s - loss: 0.3822 - val_loss: 0.4047
# Epoch 667/2048
# 0s - loss: 0.3821 - val_loss: 0.4049
# Epoch 668/2048
# 0s - loss: 0.3820 - val_loss: 0.4049
# Epoch 669/2048
# 1s - loss: 0.3820 - val_loss: 0.4045
# Epoch 670/2048
# 0s - loss: 0.3819 - val_loss: 0.4049
# Epoch 671/2048
# 1s - loss: 0.3818 - val_loss: 0.4044
# Epoch 672/2048
# 0s - loss: 0.3818 - val_loss: 0.4046
# Epoch 673/2048
# 0s - loss: 0.3816 - val_loss: 0.4047
# Epoch 674/2048
# 1s - loss: 0.3816 - val_loss: 0.4040
# Epoch 675/2048
# 0s - loss: 0.3815 - val_loss: 0.4044
# Epoch 676/2048
# 0s - loss: 0.3814 - val_loss: 0.4043
# Epoch 677/2048
# 0s - loss: 0.3813 - val_loss: 0.4041
# Epoch 678/2048
# 1s - loss: 0.3813 - val_loss: 0.4039
# Epoch 679/2048
# 0s - loss: 0.3812 - val_loss: 0.4040
# Epoch 680/2048
# 0s - loss: 0.3811 - val_loss: 0.4039
# Epoch 681/2048
# 1s - loss: 0.3809 - val_loss: 0.4034
# Epoch 682/2048
# 1s - loss: 0.3809 - val_loss: 0.4034
# Epoch 683/2048
# 0s - loss: 0.3808 - val_loss: 0.4036
# Epoch 684/2048
# 1s - loss: 0.3807 - val_loss: 0.4034
# Epoch 685/2048
# 1s - loss: 0.3807 - val_loss: 0.4031
# Epoch 686/2048
# 1s - loss: 0.3805 - val_loss: 0.4031
# Epoch 687/2048
# 0s - loss: 0.3805 - val_loss: 0.4032
# Epoch 688/2048
# 1s - loss: 0.3804 - val_loss: 0.4029
# Epoch 689/2048
# 1s - loss: 0.3804 - val_loss: 0.4027
# Epoch 690/2048
# 0s - loss: 0.3803 - val_loss: 0.4029
# Epoch 691/2048
# 0s - loss: 0.3802 - val_loss: 0.4028
# Epoch 692/2048
# 0s - loss: 0.3801 - val_loss: 0.4028
# Epoch 693/2048
# 0s - loss: 0.3801 - val_loss: 0.4044
# Epoch 694/2048
# 0s - loss: 0.3805 - val_loss: 0.4027
# Epoch 695/2048
# 0s - loss: 0.3799 - val_loss: 0.4027
# Epoch 696/2048
# 0s - loss: 0.3798 - val_loss: 0.4028
# Epoch 697/2048
# 1s - loss: 0.3797 - val_loss: 0.4026
# Epoch 698/2048
# 1s - loss: 0.3797 - val_loss: 0.4023
# Epoch 699/2048
# 1s - loss: 0.3796 - val_loss: 0.4021
# Epoch 700/2048
# 1s - loss: 0.3794 - val_loss: 0.4020
# Epoch 701/2048
# 1s - loss: 0.3794 - val_loss: 0.4022
# Epoch 702/2048
# 1s - loss: 0.3793 - val_loss: 0.4016
# Epoch 703/2048
# 0s - loss: 0.3792 - val_loss: 0.4020
# Epoch 704/2048
# 0s - loss: 0.3792 - val_loss: 0.4018
# Epoch 705/2048
# 1s - loss: 0.3790 - val_loss: 0.4015
# Epoch 706/2048
# 1s - loss: 0.3790 - val_loss: 0.4014
# Epoch 707/2048
# 1s - loss: 0.3789 - val_loss: 0.4011
# Epoch 708/2048
# 0s - loss: 0.3788 - val_loss: 0.4013
# Epoch 709/2048
# 0s - loss: 0.3788 - val_loss: 0.4013
# Epoch 710/2048
# 0s - loss: 0.3787 - val_loss: 0.4011
# Epoch 711/2048
# 1s - loss: 0.3786 - val_loss: 0.4010
# Epoch 712/2048
# 0s - loss: 0.3785 - val_loss: 0.4013
# Epoch 713/2048
# 0s - loss: 0.3784 - val_loss: 0.4015
# Epoch 714/2048
# 1s - loss: 0.3784 - val_loss: 0.4009
# Epoch 715/2048
# 0s - loss: 0.3782 - val_loss: 0.4012
# Epoch 716/2048
# 1s - loss: 0.3782 - val_loss: 0.4006
# Epoch 717/2048
# 0s - loss: 0.3781 - val_loss: 0.4010
# Epoch 718/2048
# 0s - loss: 0.3780 - val_loss: 0.4027
# Epoch 719/2048
# 1s - loss: 0.3789 - val_loss: 0.4011
# Epoch 720/2048
# 0s - loss: 0.3779 - val_loss: 0.4007
# Epoch 721/2048
# 1s - loss: 0.3778 - val_loss: 0.4000
# Epoch 722/2048
# 0s - loss: 0.3778 - val_loss: 0.4001
# Epoch 723/2048
# 0s - loss: 0.3776 - val_loss: 0.4002
# Epoch 724/2048
# 0s - loss: 0.3775 - val_loss: 0.4005
# Epoch 725/2048
# 0s - loss: 0.3775 - val_loss: 0.4003
# Epoch 726/2048
# 1s - loss: 0.3774 - val_loss: 0.3997
# Epoch 727/2048
# 0s - loss: 0.3773 - val_loss: 0.3999
# Epoch 728/2048
# 0s - loss: 0.3772 - val_loss: 0.4000
# Epoch 729/2048
# 0s - loss: 0.3772 - val_loss: 0.4001
# Epoch 730/2048
# 0s - loss: 0.3771 - val_loss: 0.3997
# Epoch 731/2048
# 1s - loss: 0.3770 - val_loss: 0.3996
# Epoch 732/2048
# 0s - loss: 0.3770 - val_loss: 0.3998
# Epoch 733/2048
# 1s - loss: 0.3769 - val_loss: 0.3995
# Epoch 734/2048
# 1s - loss: 0.3768 - val_loss: 0.3995
# Epoch 735/2048
# 1s - loss: 0.3767 - val_loss: 0.3993
# Epoch 736/2048
# 1s - loss: 0.3766 - val_loss: 0.3992
# Epoch 737/2048
# 1s - loss: 0.3765 - val_loss: 0.3990
# Epoch 738/2048
# 1s - loss: 0.3764 - val_loss: 0.3987
# Epoch 739/2048
# 0s - loss: 0.3764 - val_loss: 0.3990
# Epoch 740/2048
# 1s - loss: 0.3763 - val_loss: 0.3985
# Epoch 741/2048
# 0s - loss: 0.3762 - val_loss: 0.3990
# Epoch 742/2048
# 0s - loss: 0.3761 - val_loss: 0.3990
# Epoch 743/2048
# 0s - loss: 0.3760 - val_loss: 0.3988
# Epoch 744/2048
# 0s - loss: 0.3761 - val_loss: 0.3990
# Epoch 745/2048
# 0s - loss: 0.3759 - val_loss: 0.3987
# Epoch 746/2048
# 0s - loss: 0.3759 - val_loss: 0.3987
# Epoch 747/2048
# 1s - loss: 0.3757 - val_loss: 0.3983
# Epoch 748/2048
# 0s - loss: 0.3756 - val_loss: 0.3984
# Epoch 749/2048
# 0s - loss: 0.3756 - val_loss: 0.3989
# Epoch 750/2048
# 1s - loss: 0.3755 - val_loss: 0.3980
# Epoch 751/2048
# 1s - loss: 0.3754 - val_loss: 0.3980
# Epoch 752/2048
# 0s - loss: 0.3753 - val_loss: 0.3982
# Epoch 753/2048
# 1s - loss: 0.3752 - val_loss: 0.3978
# Epoch 754/2048
# 1s - loss: 0.3752 - val_loss: 0.3980
# Epoch 755/2048
# 1s - loss: 0.3750 - val_loss: 0.3975
# Epoch 756/2048
# 0s - loss: 0.3750 - val_loss: 0.3980
# Epoch 757/2048
# 1s - loss: 0.3749 - val_loss: 0.3974
# Epoch 758/2048
# 1s - loss: 0.3748 - val_loss: 0.3973
# Epoch 759/2048
# 0s - loss: 0.3747 - val_loss: 0.3976
# Epoch 760/2048
# 0s - loss: 0.3746 - val_loss: 0.3974
# Epoch 761/2048
# 0s - loss: 0.3747 - val_loss: 0.3974
# Epoch 762/2048
# 1s - loss: 0.3746 - val_loss: 0.3968
# Epoch 763/2048
# 1s - loss: 0.3744 - val_loss: 0.3967
# Epoch 764/2048
# 0s - loss: 0.3743 - val_loss: 0.3970
# Epoch 765/2048
# 1s - loss: 0.3742 - val_loss: 0.3969
# Epoch 766/2048
# 0s - loss: 0.3741 - val_loss: 0.3970
# Epoch 767/2048
# 1s - loss: 0.3740 - val_loss: 0.3966
# Epoch 768/2048
# 0s - loss: 0.3739 - val_loss: 0.3970
# Epoch 769/2048
# 0s - loss: 0.3739 - val_loss: 0.3966
# Epoch 770/2048
# 1s - loss: 0.3737 - val_loss: 0.3962
# Epoch 771/2048
# 1s - loss: 0.3737 - val_loss: 0.3961
# Epoch 772/2048
# 1s - loss: 0.3736 - val_loss: 0.3963
# Epoch 773/2048
# 0s - loss: 0.3735 - val_loss: 0.3962
# Epoch 774/2048
# 1s - loss: 0.3734 - val_loss: 0.3961
# Epoch 775/2048
# 0s - loss: 0.3733 - val_loss: 0.3961
# Epoch 776/2048
# 0s - loss: 0.3732 - val_loss: 0.3961
# Epoch 777/2048
# 0s - loss: 0.3731 - val_loss: 0.3962
# Epoch 778/2048
# 1s - loss: 0.3730 - val_loss: 0.3957
# Epoch 779/2048
# 1s - loss: 0.3729 - val_loss: 0.3952
# Epoch 780/2048
# 0s - loss: 0.3728 - val_loss: 0.3960
# Epoch 781/2048
# 1s - loss: 0.3728 - val_loss: 0.3958
# Epoch 782/2048
# 1s - loss: 0.3728 - val_loss: 0.3950
# Epoch 783/2048
# 1s - loss: 0.3726 - val_loss: 0.3952
# Epoch 784/2048
# 0s - loss: 0.3725 - val_loss: 0.3954
# Epoch 785/2048
# 1s - loss: 0.3725 - val_loss: 0.3950
# Epoch 786/2048
# 1s - loss: 0.3724 - val_loss: 0.3947
# Epoch 787/2048
# 1s - loss: 0.3723 - val_loss: 0.3949
# Epoch 788/2048
# 0s - loss: 0.3722 - val_loss: 0.3948
# Epoch 789/2048
# 0s - loss: 0.3721 - val_loss: 0.3950
# Epoch 790/2048
# 0s - loss: 0.3720 - val_loss: 0.3948
# Epoch 791/2048
# 1s - loss: 0.3719 - val_loss: 0.3943
# Epoch 792/2048
# 0s - loss: 0.3718 - val_loss: 0.3947
# Epoch 793/2048
# 0s - loss: 0.3717 - val_loss: 0.3943
# Epoch 794/2048
# 1s - loss: 0.3716 - val_loss: 0.3941
# Epoch 795/2048
# 1s - loss: 0.3715 - val_loss: 0.3941
# Epoch 796/2048
# 0s - loss: 0.3714 - val_loss: 0.3943
# Epoch 797/2048
# 0s - loss: 0.3714 - val_loss: 0.3943
# Epoch 798/2048
# 1s - loss: 0.3713 - val_loss: 0.3937
# Epoch 799/2048
# 1s - loss: 0.3711 - val_loss: 0.3937
# Epoch 800/2048
# 1s - loss: 0.3711 - val_loss: 0.3935
# Epoch 801/2048
# 1s - loss: 0.3710 - val_loss: 0.3932
# Epoch 802/2048
# 0s - loss: 0.3709 - val_loss: 0.3938
# Epoch 803/2048
# 0s - loss: 0.3708 - val_loss: 0.3933
# Epoch 804/2048
# 1s - loss: 0.3706 - val_loss: 0.3930
# Epoch 805/2048
# 0s - loss: 0.3706 - val_loss: 0.3937
# Epoch 806/2048
# 1s - loss: 0.3705 - val_loss: 0.3928
# Epoch 807/2048
# 0s - loss: 0.3704 - val_loss: 0.3929
# Epoch 808/2048
# 1s - loss: 0.3703 - val_loss: 0.3930
# Epoch 809/2048
# 0s - loss: 0.3703 - val_loss: 0.3936
# Epoch 810/2048
# 1s - loss: 0.3702 - val_loss: 0.3927
# Epoch 811/2048
# 0s - loss: 0.3701 - val_loss: 0.3929
# Epoch 812/2048
# 1s - loss: 0.3699 - val_loss: 0.3925
# Epoch 813/2048
# 0s - loss: 0.3699 - val_loss: 0.3928
# Epoch 814/2048
# 1s - loss: 0.3698 - val_loss: 0.3929
# Epoch 815/2048
# 1s - loss: 0.3697 - val_loss: 0.3923
# Epoch 816/2048
# 1s - loss: 0.3696 - val_loss: 0.3921
# Epoch 817/2048
# 1s - loss: 0.3695 - val_loss: 0.3921
# Epoch 818/2048
# 0s - loss: 0.3694 - val_loss: 0.3921
# Epoch 819/2048
# 1s - loss: 0.3693 - val_loss: 0.3924
# Epoch 820/2048
# 0s - loss: 0.3692 - val_loss: 0.3925
# Epoch 821/2048
# 1s - loss: 0.3691 - val_loss: 0.3918
# Epoch 822/2048
# 1s - loss: 0.3691 - val_loss: 0.3916
# Epoch 823/2048
# 0s - loss: 0.3689 - val_loss: 0.3918
# Epoch 824/2048
# 1s - loss: 0.3690 - val_loss: 0.3915
# Epoch 825/2048
# 0s - loss: 0.3688 - val_loss: 0.3922
# Epoch 826/2048
# 1s - loss: 0.3686 - val_loss: 0.3915
# Epoch 827/2048
# 1s - loss: 0.3685 - val_loss: 0.3914
# Epoch 828/2048
# 1s - loss: 0.3685 - val_loss: 0.3916
# Epoch 829/2048
# 0s - loss: 0.3684 - val_loss: 0.3916
# Epoch 830/2048
# 1s - loss: 0.3683 - val_loss: 0.3914
# Epoch 831/2048
# 1s - loss: 0.3682 - val_loss: 0.3913
# Epoch 832/2048
# 1s - loss: 0.3681 - val_loss: 0.3910
# Epoch 833/2048
# 1s - loss: 0.3680 - val_loss: 0.3910
# Epoch 834/2048
# 1s - loss: 0.3679 - val_loss: 0.3909
# Epoch 835/2048
# 0s - loss: 0.3678 - val_loss: 0.3909
# Epoch 836/2048
# 1s - loss: 0.3677 - val_loss: 0.3905
# Epoch 837/2048
# 0s - loss: 0.3676 - val_loss: 0.3907
# Epoch 838/2048
# 1s - loss: 0.3675 - val_loss: 0.3903
# Epoch 839/2048
# 0s - loss: 0.3675 - val_loss: 0.3904
# Epoch 840/2048
# 0s - loss: 0.3674 - val_loss: 0.3904
# Epoch 841/2048
# 0s - loss: 0.3673 - val_loss: 0.3909
# Epoch 842/2048
# 1s - loss: 0.3672 - val_loss: 0.3902
# Epoch 843/2048
# 1s - loss: 0.3671 - val_loss: 0.3893
# Epoch 844/2048
# 0s - loss: 0.3671 - val_loss: 0.3896
# Epoch 845/2048
# 0s - loss: 0.3669 - val_loss: 0.3896
# Epoch 846/2048
# 0s - loss: 0.3668 - val_loss: 0.3894
# Epoch 847/2048
# 1s - loss: 0.3669 - val_loss: 0.3893
# Epoch 848/2048
# 0s - loss: 0.3666 - val_loss: 0.3896
# Epoch 849/2048
# 1s - loss: 0.3666 - val_loss: 0.3891
# Epoch 850/2048
# 0s - loss: 0.3665 - val_loss: 0.3893
# Epoch 851/2048
# 0s - loss: 0.3664 - val_loss: 0.3897
# Epoch 852/2048
# 0s - loss: 0.3663 - val_loss: 0.3892
# Epoch 853/2048
# 1s - loss: 0.3662 - val_loss: 0.3890
# Epoch 854/2048
# 1s - loss: 0.3661 - val_loss: 0.3887
# Epoch 855/2048
# 0s - loss: 0.3661 - val_loss: 0.3898
# Epoch 856/2048
# 0s - loss: 0.3660 - val_loss: 0.3894
# Epoch 857/2048
# 1s - loss: 0.3658 - val_loss: 0.3886
# Epoch 858/2048
# 1s - loss: 0.3656 - val_loss: 0.3886
# Epoch 859/2048
# 0s - loss: 0.3655 - val_loss: 0.3887
# Epoch 860/2048
# 1s - loss: 0.3655 - val_loss: 0.3883
# Epoch 861/2048
# 1s - loss: 0.3654 - val_loss: 0.3880
# Epoch 862/2048
# 0s - loss: 0.3653 - val_loss: 0.3880
# Epoch 863/2048
# 0s - loss: 0.3652 - val_loss: 0.3883
# Epoch 864/2048
# 1s - loss: 0.3651 - val_loss: 0.3879
# Epoch 865/2048
# 1s - loss: 0.3651 - val_loss: 0.3877
# Epoch 866/2048
# 1s - loss: 0.3649 - val_loss: 0.3881
# Epoch 867/2048
# 0s - loss: 0.3648 - val_loss: 0.3877
# Epoch 868/2048
# 1s - loss: 0.3647 - val_loss: 0.3886
# Epoch 869/2048
# 0s - loss: 0.3648 - val_loss: 0.3878
# Epoch 870/2048
# 1s - loss: 0.3645 - val_loss: 0.3873
# Epoch 871/2048
# 1s - loss: 0.3644 - val_loss: 0.3869
# Epoch 872/2048
# 0s - loss: 0.3643 - val_loss: 0.3872
# Epoch 873/2048
# 0s - loss: 0.3642 - val_loss: 0.3874
# Epoch 874/2048
# 0s - loss: 0.3641 - val_loss: 0.3870
# Epoch 875/2048
# 0s - loss: 0.3640 - val_loss: 0.3869
# Epoch 876/2048
# 1s - loss: 0.3639 - val_loss: 0.3874
# Epoch 877/2048
# 1s - loss: 0.3639 - val_loss: 0.3872
# Epoch 878/2048
# 1s - loss: 0.3638 - val_loss: 0.3872
# Epoch 879/2048
# 1s - loss: 0.3637 - val_loss: 0.3866
# Epoch 880/2048
# 1s - loss: 0.3635 - val_loss: 0.3865
# Epoch 881/2048
# 0s - loss: 0.3634 - val_loss: 0.3865
# Epoch 882/2048
# 1s - loss: 0.3635 - val_loss: 0.3864
# Epoch 883/2048
# 1s - loss: 0.3633 - val_loss: 0.3862
# Epoch 884/2048
# 1s - loss: 0.3632 - val_loss: 0.3861
# Epoch 885/2048
# 1s - loss: 0.3630 - val_loss: 0.3859
# Epoch 886/2048
# 1s - loss: 0.3630 - val_loss: 0.3860
# Epoch 887/2048
# 0s - loss: 0.3628 - val_loss: 0.3861
# Epoch 888/2048
# 1s - loss: 0.3627 - val_loss: 0.3860
# Epoch 889/2048
# 1s - loss: 0.3626 - val_loss: 0.3858
# Epoch 890/2048
# 1s - loss: 0.3625 - val_loss: 0.3856
# Epoch 891/2048
# 1s - loss: 0.3624 - val_loss: 0.3852
# Epoch 892/2048
# 0s - loss: 0.3623 - val_loss: 0.3855
# Epoch 893/2048
# 0s - loss: 0.3622 - val_loss: 0.3853
# Epoch 894/2048
# 0s - loss: 0.3622 - val_loss: 0.3857
# Epoch 895/2048
# 0s - loss: 0.3620 - val_loss: 0.3853
# Epoch 896/2048
# 1s - loss: 0.3620 - val_loss: 0.3850
# Epoch 897/2048
# 1s - loss: 0.3619 - val_loss: 0.3848
# Epoch 898/2048
# 0s - loss: 0.3617 - val_loss: 0.3849
# Epoch 899/2048
# 0s - loss: 0.3617 - val_loss: 0.3860
# Epoch 900/2048
# 0s - loss: 0.3620 - val_loss: 0.3849
# Epoch 901/2048
# 1s - loss: 0.3615 - val_loss: 0.3842
# Epoch 902/2048
# 0s - loss: 0.3613 - val_loss: 0.3844
# Epoch 903/2048
# 0s - loss: 0.3613 - val_loss: 0.3847
# Epoch 904/2048
# 1s - loss: 0.3612 - val_loss: 0.3839
# Epoch 905/2048
# 1s - loss: 0.3611 - val_loss: 0.3837
# Epoch 906/2048
# 1s - loss: 0.3609 - val_loss: 0.3841
# Epoch 907/2048
# 0s - loss: 0.3609 - val_loss: 0.3843
# Epoch 908/2048
# 1s - loss: 0.3608 - val_loss: 0.3841
# Epoch 909/2048
# 0s - loss: 0.3607 - val_loss: 0.3840
# Epoch 910/2048
# 1s - loss: 0.3606 - val_loss: 0.3837
# Epoch 911/2048
# 0s - loss: 0.3605 - val_loss: 0.3837
# Epoch 912/2048
# 0s - loss: 0.3605 - val_loss: 0.3852
# Epoch 913/2048
# 0s - loss: 0.3612 - val_loss: 0.3837
# Epoch 914/2048
# 1s - loss: 0.3604 - val_loss: 0.3834
# Epoch 915/2048
# 1s - loss: 0.3601 - val_loss: 0.3833
# Epoch 916/2048
# 0s - loss: 0.3600 - val_loss: 0.3834
# Epoch 917/2048
# 1s - loss: 0.3600 - val_loss: 0.3832
# Epoch 918/2048
# 1s - loss: 0.3598 - val_loss: 0.3826
# Epoch 919/2048
# 1s - loss: 0.3597 - val_loss: 0.3831
# Epoch 920/2048
# 1s - loss: 0.3596 - val_loss: 0.3826
# Epoch 921/2048
# 1s - loss: 0.3595 - val_loss: 0.3826
# Epoch 922/2048
# 1s - loss: 0.3595 - val_loss: 0.3825
# Epoch 923/2048
# 1s - loss: 0.3594 - val_loss: 0.3826
# Epoch 924/2048
# ...
# 1s - loss: 0.3047 - val_loss: 0.3323
# Epoch 1748/2048
# 0s - loss: 0.3047 - val_loss: 0.3324
# Epoch 1749/2048
# 1s - loss: 0.3047 - val_loss: 0.3323
# Epoch 1750/2048
# 0s - loss: 0.3046 - val_loss: 0.3327
# Epoch 1751/2048
# 1s - loss: 0.3046 - val_loss: 0.3319
# Epoch 1752/2048
# 0s - loss: 0.3046 - val_loss: 0.3324
# Epoch 1753/2048
# 0s - loss: 0.3045 - val_loss: 0.3323
# Epoch 1754/2048
# 0s - loss: 0.3045 - val_loss: 0.3330
# Epoch 1755/2048
# 0s - loss: 0.3045 - val_loss: 0.3323
# Epoch 1756/2048
# 0s - loss: 0.3044 - val_loss: 0.3321
# Epoch 1757/2048
# 0s - loss: 0.3044 - val_loss: 0.3321
# Epoch 1758/2048
# 0s - loss: 0.3044 - val_loss: 0.3323
# Epoch 1759/2048
# 0s - loss: 0.3043 - val_loss: 0.3320
# Epoch 1760/2048
# 0s - loss: 0.3043 - val_loss: 0.3320
# Epoch 1761/2048
# 0s - loss: 0.3042 - val_loss: 0.3326
# Epoch 1762/2048
# 0s - loss: 0.3043 - val_loss: 0.3321
# Epoch 1763/2048
# 0s - loss: 0.3042 - val_loss: 0.3320
# Epoch 1764/2048
# 0s - loss: 0.3041 - val_loss: 0.3324
# Epoch 1765/2048
# 1s - loss: 0.3041 - val_loss: 0.3319
# Epoch 1766/2048
# 0s - loss: 0.3041 - val_loss: 0.3323
# Epoch 1767/2048
# 1s - loss: 0.3040 - val_loss: 0.3318
# Epoch 1768/2048
# 0s - loss: 0.3040 - val_loss: 0.3321
# Epoch 1769/2048
# 1s - loss: 0.3040 - val_loss: 0.3314
# Epoch 1770/2048
# 0s - loss: 0.3039 - val_loss: 0.3317
# Epoch 1771/2048
# 0s - loss: 0.3039 - val_loss: 0.3317
# Epoch 1772/2048
# 0s - loss: 0.3039 - val_loss: 0.3320
# Epoch 1773/2048
# 0s - loss: 0.3043 - val_loss: 0.3319
# Epoch 1774/2048
# 0s - loss: 0.3038 - val_loss: 0.3322
# Epoch 1775/2048
# 0s - loss: 0.3038 - val_loss: 0.3317
# Epoch 1776/2048
# 0s - loss: 0.3037 - val_loss: 0.3315
# Epoch 1777/2048
# 0s - loss: 0.3037 - val_loss: 0.3317
# Epoch 1778/2048
# 0s - loss: 0.3036 - val_loss: 0.3316
# Epoch 1779/2048
# 0s - loss: 0.3036 - val_loss: 0.3316
# Epoch 1780/2048
# 0s - loss: 0.3036 - val_loss: 0.3318
# Epoch 1781/2048
# 0s - loss: 0.3035 - val_loss: 0.3314
# Epoch 1782/2048
# 1s - loss: 0.3035 - val_loss: 0.3316
# Epoch 1783/2048
# 1s - loss: 0.3035 - val_loss: 0.3312
# Epoch 1784/2048
# 0s - loss: 0.3034 - val_loss: 0.3316
# Epoch 1785/2048
# 0s - loss: 0.3034 - val_loss: 0.3312
# Epoch 1786/2048
# 1s - loss: 0.3035 - val_loss: 0.3310
# Epoch 1787/2048
# 0s - loss: 0.3034 - val_loss: 0.3313
# Epoch 1788/2048
# 0s - loss: 0.3033 - val_loss: 0.3314
# Epoch 1789/2048
# 0s - loss: 0.3033 - val_loss: 0.3313
# Epoch 1790/2048
# 0s - loss: 0.3033 - val_loss: 0.3311
# Epoch 1791/2048
# 1s - loss: 0.3035 - val_loss: 0.3309
# Epoch 1792/2048
# 0s - loss: 0.3033 - val_loss: 0.3314
# Epoch 1793/2048
# 0s - loss: 0.3032 - val_loss: 0.3314
# Epoch 1794/2048
# 0s - loss: 0.3031 - val_loss: 0.3314
# Epoch 1795/2048
# 0s - loss: 0.3031 - val_loss: 0.3312
# Epoch 1796/2048
# 1s - loss: 0.3032 - val_loss: 0.3309
# Epoch 1797/2048
# 1s - loss: 0.3031 - val_loss: 0.3307
# Epoch 1798/2048
# 0s - loss: 0.3030 - val_loss: 0.3311
# Epoch 1799/2048
# 0s - loss: 0.3030 - val_loss: 0.3309
# Epoch 1800/2048
# 0s - loss: 0.3029 - val_loss: 0.3313
# Epoch 1801/2048
# 0s - loss: 0.3029 - val_loss: 0.3307
# Epoch 1802/2048
# 0s - loss: 0.3029 - val_loss: 0.3311
# Epoch 1803/2048
# 0s - loss: 0.3029 - val_loss: 0.3310
# Epoch 1804/2048
# 0s - loss: 0.3028 - val_loss: 0.3310
# Epoch 1805/2048
# 0s - loss: 0.3028 - val_loss: 0.3311
# Epoch 1806/2048
# 0s - loss: 0.3028 - val_loss: 0.3311
# Epoch 1807/2048
# 1s - loss: 0.3027 - val_loss: 0.3307
# Epoch 1808/2048
# 0s - loss: 0.3027 - val_loss: 0.3308
# Epoch 1809/2048
# 0s - loss: 0.3026 - val_loss: 0.3307
# Epoch 1810/2048
# 1s - loss: 0.3026 - val_loss: 0.3305
# Epoch 1811/2048
# 0s - loss: 0.3026 - val_loss: 0.3306
# Epoch 1812/2048
# 0s - loss: 0.3026 - val_loss: 0.3311
# Epoch 1813/2048
# 1s - loss: 0.3025 - val_loss: 0.3304
# Epoch 1814/2048
# 1s - loss: 0.3026 - val_loss: 0.3312
# Epoch 1815/2048
# 0s - loss: 0.3025 - val_loss: 0.3307
# Epoch 1816/2048
# 1s - loss: 0.3025 - val_loss: 0.3305
# Epoch 1817/2048
# 0s - loss: 0.3024 - val_loss: 0.3306
# Epoch 1818/2048
# 1s - loss: 0.3024 - val_loss: 0.3304
# Epoch 1819/2048
# 0s - loss: 0.3023 - val_loss: 0.3306
# Epoch 1820/2048
# 0s - loss: 0.3023 - val_loss: 0.3307
# Epoch 1821/2048
# 0s - loss: 0.3024 - val_loss: 0.3307
# Epoch 1822/2048
# 0s - loss: 0.3023 - val_loss: 0.3304
# Epoch 1823/2048
# 1s - loss: 0.3022 - val_loss: 0.3308
# Epoch 1824/2048
# 1s - loss: 0.3022 - val_loss: 0.3304
# Epoch 1825/2048
# 1s - loss: 0.3021 - val_loss: 0.3302
# Epoch 1826/2048
# 1s - loss: 0.3021 - val_loss: 0.3301
# Epoch 1827/2048
# 1s - loss: 0.3022 - val_loss: 0.3300
# Epoch 1828/2048
# 0s - loss: 0.3021 - val_loss: 0.3305
# Epoch 1829/2048
# 0s - loss: 0.3021 - val_loss: 0.3303
# Epoch 1830/2048
# 0s - loss: 0.3020 - val_loss: 0.3303
# Epoch 1831/2048
# 1s - loss: 0.3020 - val_loss: 0.3298
# Epoch 1832/2048
# 0s - loss: 0.3020 - val_loss: 0.3301
# Epoch 1833/2048
# 0s - loss: 0.3019 - val_loss: 0.3299
# Epoch 1834/2048
# 0s - loss: 0.3019 - val_loss: 0.3302
# Epoch 1835/2048
# 0s - loss: 0.3019 - val_loss: 0.3303
# Epoch 1836/2048
# 0s - loss: 0.3019 - val_loss: 0.3300
# Epoch 1837/2048
# 0s - loss: 0.3018 - val_loss: 0.3299
# Epoch 1838/2048
# 1s - loss: 0.3018 - val_loss: 0.3296
# Epoch 1839/2048
# 0s - loss: 0.3017 - val_loss: 0.3297
# Epoch 1840/2048
# 0s - loss: 0.3017 - val_loss: 0.3299
# Epoch 1841/2048
# 1s - loss: 0.3017 - val_loss: 0.3295
# Epoch 1842/2048
# 0s - loss: 0.3017 - val_loss: 0.3297
# Epoch 1843/2048
# 0s - loss: 0.3016 - val_loss: 0.3301
# Epoch 1844/2048
# 0s - loss: 0.3016 - val_loss: 0.3300
# Epoch 1845/2048
# 0s - loss: 0.3016 - val_loss: 0.3298
# Epoch 1846/2048
# 0s - loss: 0.3016 - val_loss: 0.3300
# Epoch 1847/2048
# 0s - loss: 0.3015 - val_loss: 0.3300
# Epoch 1848/2048
# 0s - loss: 0.3015 - val_loss: 0.3299
# Epoch 1849/2048
# 1s - loss: 0.3014 - val_loss: 0.3294
# Epoch 1850/2048
# 0s - loss: 0.3014 - val_loss: 0.3298
# Epoch 1851/2048
# 0s - loss: 0.3014 - val_loss: 0.3297
# Epoch 1852/2048
# 1s - loss: 0.3014 - val_loss: 0.3293
# Epoch 1853/2048
# 0s - loss: 0.3013 - val_loss: 0.3298
# Epoch 1854/2048
# 0s - loss: 0.3013 - val_loss: 0.3296
# Epoch 1855/2048
# 0s - loss: 0.3013 - val_loss: 0.3296
# Epoch 1856/2048
# 0s - loss: 0.3013 - val_loss: 0.3294
# Epoch 1857/2048
# 0s - loss: 0.3012 - val_loss: 0.3295
# Epoch 1858/2048
# 1s - loss: 0.3012 - val_loss: 0.3292
# Epoch 1859/2048
# 0s - loss: 0.3013 - val_loss: 0.3294
# Epoch 1860/2048
# 0s - loss: 0.3012 - val_loss: 0.3299
# Epoch 1861/2048
# 0s - loss: 0.3012 - val_loss: 0.3297
# Epoch 1862/2048
# 0s - loss: 0.3010 - val_loss: 0.3294
# Epoch 1863/2048
# 0s - loss: 0.3011 - val_loss: 0.3294
# Epoch 1864/2048
# 0s - loss: 0.3010 - val_loss: 0.3292
# Epoch 1865/2048
# 0s - loss: 0.3010 - val_loss: 0.3297
# Epoch 1866/2048
# 1s - loss: 0.3010 - val_loss: 0.3291
# Epoch 1867/2048
# 0s - loss: 0.3009 - val_loss: 0.3292
# Epoch 1868/2048
# 0s - loss: 0.3009 - val_loss: 0.3293
# Epoch 1869/2048
# 1s - loss: 0.3008 - val_loss: 0.3290
# Epoch 1870/2048
# 1s - loss: 0.3008 - val_loss: 0.3292
# Epoch 1871/2048
# 0s - loss: 0.3008 - val_loss: 0.3292
# Epoch 1872/2048
# 0s - loss: 0.3008 - val_loss: 0.3292
# Epoch 1873/2048
# 1s - loss: 0.3008 - val_loss: 0.3294
# Epoch 1874/2048
# 1s - loss: 0.3008 - val_loss: 0.3287
# Epoch 1875/2048
# 0s - loss: 0.3009 - val_loss: 0.3293
# Epoch 1876/2048
# 0s - loss: 0.3007 - val_loss: 0.3288
# Epoch 1877/2048
# 0s - loss: 0.3006 - val_loss: 0.3291
# Epoch 1878/2048
# 0s - loss: 0.3006 - val_loss: 0.3292
# Epoch 1879/2048
# 0s - loss: 0.3006 - val_loss: 0.3291
# Epoch 1880/2048
# 0s - loss: 0.3007 - val_loss: 0.3295
# Epoch 1881/2048
# 0s - loss: 0.3006 - val_loss: 0.3290
# Epoch 1882/2048
# 0s - loss: 0.3005 - val_loss: 0.3288
# Epoch 1883/2048
# 0s - loss: 0.3005 - val_loss: 0.3291
# Epoch 1884/2048
# 1s - loss: 0.3005 - val_loss: 0.3286
# Epoch 1885/2048
# 0s - loss: 0.3004 - val_loss: 0.3287
# Epoch 1886/2048
# 0s - loss: 0.3004 - val_loss: 0.3288
# Epoch 1887/2048
# 0s - loss: 0.3004 - val_loss: 0.3288
# Epoch 1888/2048
# 0s - loss: 0.3004 - val_loss: 0.3287
# Epoch 1889/2048
# 1s - loss: 0.3003 - val_loss: 0.3285
# Epoch 1890/2048
# 1s - loss: 0.3003 - val_loss: 0.3284
# Epoch 1891/2048
# 0s - loss: 0.3003 - val_loss: 0.3286
# Epoch 1892/2048
# 0s - loss: 0.3003 - val_loss: 0.3289
# Epoch 1893/2048
# 0s - loss: 0.3003 - val_loss: 0.3285
# Epoch 1894/2048
# 1s - loss: 0.3002 - val_loss: 0.3283
# Epoch 1895/2048
# 0s - loss: 0.3001 - val_loss: 0.3289
# Epoch 1896/2048
# 0s - loss: 0.3001 - val_loss: 0.3284
# Epoch 1897/2048
# 0s - loss: 0.3001 - val_loss: 0.3290
# Epoch 1898/2048
# 0s - loss: 0.3001 - val_loss: 0.3288
# Epoch 1899/2048
# 0s - loss: 0.3000 - val_loss: 0.3284
# Epoch 1900/2048
# 0s - loss: 0.3000 - val_loss: 0.3284
# Epoch 1901/2048
# 0s - loss: 0.3000 - val_loss: 0.3287
# Epoch 1902/2048
# 0s - loss: 0.3000 - val_loss: 0.3285
# Epoch 1903/2048
# 0s - loss: 0.3000 - val_loss: 0.3283
# Epoch 1904/2048
# 0s - loss: 0.3000 - val_loss: 0.3285
# Epoch 1905/2048
# 0s - loss: 0.2999 - val_loss: 0.3288
# Epoch 1906/2048
# 0s - loss: 0.2999 - val_loss: 0.3288
# Epoch 1907/2048
# 0s - loss: 0.2999 - val_loss: 0.3286
# Epoch 1908/2048
# 1s - loss: 0.2998 - val_loss: 0.3282
# Epoch 1909/2048
# 0s - loss: 0.2999 - val_loss: 0.3283
# Epoch 1910/2048
# 0s - loss: 0.2998 - val_loss: 0.3282
# Epoch 1911/2048
# 1s - loss: 0.2997 - val_loss: 0.3281
# Epoch 1912/2048
# 0s - loss: 0.2997 - val_loss: 0.3283
# Epoch 1913/2048
# 0s - loss: 0.2997 - val_loss: 0.3282
# Epoch 1914/2048
# 1s - loss: 0.2997 - val_loss: 0.3278
# Epoch 1915/2048
# 0s - loss: 0.2996 - val_loss: 0.3287
# Epoch 1916/2048
# 0s - loss: 0.2996 - val_loss: 0.3283
# Epoch 1917/2048
# 0s - loss: 0.2996 - val_loss: 0.3283
# Epoch 1918/2048
# 1s - loss: 0.2996 - val_loss: 0.3277
# Epoch 1919/2048
# 0s - loss: 0.2995 - val_loss: 0.3284
# Epoch 1920/2048
# 0s - loss: 0.2995 - val_loss: 0.3284
# Epoch 1921/2048
# 0s - loss: 0.2995 - val_loss: 0.3279
# Epoch 1922/2048
# 0s - loss: 0.2994 - val_loss: 0.3281
# Epoch 1923/2048
# 0s - loss: 0.2995 - val_loss: 0.3282
# Epoch 1924/2048
# 1s - loss: 0.2995 - val_loss: 0.3275
# Epoch 1925/2048
# 0s - loss: 0.2994 - val_loss: 0.3281
# Epoch 1926/2048
# 0s - loss: 0.2994 - val_loss: 0.3278
# Epoch 1927/2048
# 0s - loss: 0.2993 - val_loss: 0.3282
# Epoch 1928/2048
# 0s - loss: 0.2993 - val_loss: 0.3280
# Epoch 1929/2048
# 0s - loss: 0.2993 - val_loss: 0.3278
# Epoch 1930/2048
# 0s - loss: 0.2993 - val_loss: 0.3278
# Epoch 1931/2048
# 0s - loss: 0.2992 - val_loss: 0.3280
# Epoch 1932/2048
# 0s - loss: 0.2992 - val_loss: 0.3281
# Epoch 1933/2048
# 0s - loss: 0.2992 - val_loss: 0.3280
# Epoch 1934/2048
# 0s - loss: 0.2991 - val_loss: 0.3279
# Epoch 1935/2048
# 0s - loss: 0.2992 - val_loss: 0.3280
# Epoch 1936/2048
# 0s - loss: 0.2991 - val_loss: 0.3277
# Epoch 1937/2048
# 0s - loss: 0.2990 - val_loss: 0.3280
# Epoch 1938/2048
# 0s - loss: 0.2990 - val_loss: 0.3279
# Epoch 1939/2048
# 0s - loss: 0.2990 - val_loss: 0.3278
# Epoch 1940/2048
# 0s - loss: 0.2989 - val_loss: 0.3277
# Epoch 1941/2048
# 0s - loss: 0.2989 - val_loss: 0.3278
# Epoch 1942/2048
# 0s - loss: 0.2990 - val_loss: 0.3280
# Epoch 1943/2048
# 1s - loss: 0.2990 - val_loss: 0.3274
# Epoch 1944/2048
# 0s - loss: 0.2989 - val_loss: 0.3275
# Epoch 1945/2048
# 0s - loss: 0.2989 - val_loss: 0.3276
# Epoch 1946/2048
# 1s - loss: 0.2988 - val_loss: 0.3273
# Epoch 1947/2048
# 0s - loss: 0.2988 - val_loss: 0.3275
# Epoch 1948/2048
# 0s - loss: 0.2988 - val_loss: 0.3275
# Epoch 1949/2048
# 0s - loss: 0.2988 - val_loss: 0.3275
# Epoch 1950/2048
# 0s - loss: 0.2987 - val_loss: 0.3275
# Epoch 1951/2048
# 1s - loss: 0.2986 - val_loss: 0.3272
# Epoch 1952/2048
# 1s - loss: 0.2987 - val_loss: 0.3271
# Epoch 1953/2048
# 0s - loss: 0.2986 - val_loss: 0.3276
# Epoch 1954/2048
# 0s - loss: 0.2985 - val_loss: 0.3282
# Epoch 1955/2048
# 0s - loss: 0.2992 - val_loss: 0.3274
# Epoch 1956/2048
# 0s - loss: 0.2985 - val_loss: 0.3272
# Epoch 1957/2048
# 0s - loss: 0.2985 - val_loss: 0.3272
# Epoch 1958/2048
# 1s - loss: 0.2985 - val_loss: 0.3270
# Epoch 1959/2048
# 0s - loss: 0.2985 - val_loss: 0.3275
# Epoch 1960/2048
# 0s - loss: 0.2984 - val_loss: 0.3272
# Epoch 1961/2048
# 0s - loss: 0.2984 - val_loss: 0.3271
# Epoch 1962/2048
# 0s - loss: 0.2984 - val_loss: 0.3274
# Epoch 1963/2048
# 0s - loss: 0.2983 - val_loss: 0.3275
# Epoch 1964/2048
# 1s - loss: 0.2983 - val_loss: 0.3269
# Epoch 1965/2048
# 0s - loss: 0.2983 - val_loss: 0.3271
# Epoch 1966/2048
# 0s - loss: 0.2984 - val_loss: 0.3273
# Epoch 1967/2048
# 0s - loss: 0.2982 - val_loss: 0.3271
# Epoch 1968/2048
# 1s - loss: 0.2982 - val_loss: 0.3268
# Epoch 1969/2048
# 0s - loss: 0.2982 - val_loss: 0.3277
# Epoch 1970/2048
# 0s - loss: 0.2982 - val_loss: 0.3269
# Epoch 1971/2048
# 0s - loss: 0.2981 - val_loss: 0.3270
# Epoch 1972/2048
# 0s - loss: 0.2981 - val_loss: 0.3273
# Epoch 1973/2048
# 0s - loss: 0.2981 - val_loss: 0.3272
# Epoch 1974/2048
# 0s - loss: 0.2981 - val_loss: 0.3269
# Epoch 1975/2048
# 0s - loss: 0.2980 - val_loss: 0.3271
# Epoch 1976/2048
# 0s - loss: 0.2980 - val_loss: 0.3273
# Epoch 1977/2048
# 0s - loss: 0.2981 - val_loss: 0.3272
# Epoch 1978/2048
# 1s - loss: 0.2979 - val_loss: 0.3271
# Epoch 1979/2048
# 0s - loss: 0.2979 - val_loss: 0.3270
# Epoch 1980/2048
# 0s - loss: 0.2979 - val_loss: 0.3270
# Epoch 1981/2048
# 0s - loss: 0.2978 - val_loss: 0.3276
# Epoch 1982/2048
# 1s - loss: 0.2979 - val_loss: 0.3265
# Epoch 1983/2048
# 0s - loss: 0.2978 - val_loss: 0.3268
# Epoch 1984/2048
# 0s - loss: 0.2978 - val_loss: 0.3268
# Epoch 1985/2048
# 0s - loss: 0.2977 - val_loss: 0.3268
# Epoch 1986/2048
# 0s - loss: 0.2977 - val_loss: 0.3270
# Epoch 1987/2048
# 0s - loss: 0.2977 - val_loss: 0.3268
# Epoch 1988/2048
# 0s - loss: 0.2976 - val_loss: 0.3270
# Epoch 1989/2048
# 0s - loss: 0.2976 - val_loss: 0.3270
# Epoch 1990/2048
# 0s - loss: 0.2976 - val_loss: 0.3271
# Epoch 1991/2048
# 0s - loss: 0.2976 - val_loss: 0.3269
# Epoch 1992/2048
# 0s - loss: 0.2977 - val_loss: 0.3270
# Epoch 1993/2048
# 0s - loss: 0.2975 - val_loss: 0.3267
# Epoch 1994/2048
# 1s - loss: 0.2975 - val_loss: 0.3264
# Epoch 1995/2048
# 0s - loss: 0.2975 - val_loss: 0.3268
# Epoch 1996/2048
# 0s - loss: 0.2974 - val_loss: 0.3266
# Epoch 1997/2048
# 0s - loss: 0.2974 - val_loss: 0.3264
# Epoch 1998/2048
# 1s - loss: 0.2974 - val_loss: 0.3263
# Epoch 1999/2048
# 0s - loss: 0.2974 - val_loss: 0.3264
# Epoch 2000/2048
# 1s - loss: 0.2974 - val_loss: 0.3259
# Epoch 2001/2048
# 0s - loss: 0.2973 - val_loss: 0.3263
# Epoch 2002/2048
# 0s - loss: 0.2973 - val_loss: 0.3262
# Epoch 2003/2048
# 0s - loss: 0.2972 - val_loss: 0.3267
# Epoch 2004/2048
# 0s - loss: 0.2972 - val_loss: 0.3263
# Epoch 2005/2048
# 0s - loss: 0.2972 - val_loss: 0.3267
# Epoch 2006/2048
# 0s - loss: 0.2972 - val_loss: 0.3259
# Epoch 2007/2048
# 0s - loss: 0.2972 - val_loss: 0.3266
# Epoch 2008/2048
# 0s - loss: 0.2971 - val_loss: 0.3262
# Epoch 2009/2048
# 0s - loss: 0.2971 - val_loss: 0.3260
# Epoch 2010/2048
# 1s - loss: 0.2971 - val_loss: 0.3259
# Epoch 2011/2048
# 0s - loss: 0.2970 - val_loss: 0.3264
# Epoch 2012/2048
# 1s - loss: 0.2972 - val_loss: 0.3267
# Epoch 2013/2048
# 0s - loss: 0.2970 - val_loss: 0.3260
# Epoch 2014/2048
# 0s - loss: 0.2970 - val_loss: 0.3262
# Epoch 2015/2048
# 0s - loss: 0.2970 - val_loss: 0.3260
# Epoch 2016/2048
# 0s - loss: 0.2969 - val_loss: 0.3261
# Epoch 2017/2048
# 0s - loss: 0.2969 - val_loss: 0.3265
# Epoch 2018/2048
# 0s - loss: 0.2969 - val_loss: 0.3262
# Epoch 2019/2048
# 0s - loss: 0.2969 - val_loss: 0.3259
# Epoch 2020/2048
# 1s - loss: 0.2968 - val_loss: 0.3259
# Epoch 2021/2048
# 1s - loss: 0.2968 - val_loss: 0.3258
# Epoch 2022/2048
# 0s - loss: 0.2968 - val_loss: 0.3259
# Epoch 2023/2048
# 0s - loss: 0.2968 - val_loss: 0.3260
# Epoch 2024/2048
# 0s - loss: 0.2967 - val_loss: 0.3260
# Epoch 2025/2048
# 0s - loss: 0.2967 - val_loss: 0.3261
# Epoch 2026/2048
# 0s - loss: 0.2967 - val_loss: 0.3261
# Epoch 2027/2048
# 0s - loss: 0.2968 - val_loss: 0.3259
# Epoch 2028/2048
# 0s - loss: 0.2967 - val_loss: 0.3261
# Epoch 2029/2048
# 0s - loss: 0.2967 - val_loss: 0.3261
# Epoch 2030/2048
# 1s - loss: 0.2966 - val_loss: 0.3257
# Epoch 2031/2048
# 1s - loss: 0.2965 - val_loss: 0.3256
# Epoch 2032/2048
# 0s - loss: 0.2965 - val_loss: 0.3257
# Epoch 2033/2048
# 0s - loss: 0.2966 - val_loss: 0.3257
# Epoch 2034/2048
# 0s - loss: 0.2965 - val_loss: 0.3257
# Epoch 2035/2048
# 0s - loss: 0.2964 - val_loss: 0.3260
# Epoch 2036/2048
# 0s - loss: 0.2965 - val_loss: 0.3257
# Epoch 2037/2048
# 1s - loss: 0.2965 - val_loss: 0.3255
# Epoch 2038/2048
# 0s - loss: 0.2964 - val_loss: 0.3261
# Epoch 2039/2048
# 1s - loss: 0.2964 - val_loss: 0.3251
# Epoch 2040/2048
# 0s - loss: 0.2964 - val_loss: 0.3255
# Epoch 2041/2048
# 0s - loss: 0.2964 - val_loss: 0.3259
# Epoch 2042/2048
# 0s - loss: 0.2963 - val_loss: 0.3256
# Epoch 2043/2048
# 0s - loss: 0.2963 - val_loss: 0.3259
# Epoch 2044/2048
# 0s - loss: 0.2963 - val_loss: 0.3253
# Epoch 2045/2048
# 0s - loss: 0.2964 - val_loss: 0.3258
# Epoch 2046/2048
# 0s - loss: 0.2967 - val_loss: 0.3254
# Epoch 2047/2048
# 0s - loss: 0.2962 - val_loss: 0.3257
# Epoch 2048/2048
# 0s - loss: 0.2961 - val_loss: 0.3256

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name2))

# %%
X_test_filtered = X_test_norm[:, feature_filter]

# %%
# Exclude validation set
X_train_wo_valid_filtered = X_train_wo_valid[:, feature_filter]

# %%
X_test_filtered.shape
# Out:
# (12035, 1152)

# %%
# Run predictions
ae_pred_filtered = autoencoder.predict(X_test_filtered)
ae_pred_filtered_train = autoencoder.predict(X_train_wo_valid_filtered)

# %%
pickle.dump(ae_pred_filtered, open(model_directory + "ae_pred_filtered.p", "wb"))
pickle.dump(ae_pred_filtered_train, open(model_directory + "ae_pred_filtered_train.p", "wb"))

# %%
ae_pred_filtered = pickle.load(open(model_directory + "ae_pred_filtered.p", "rb"))
ae_pred_filtered_train = pickle.load(open(model_directory + "ae_pred_filtered_train.p", "rb"))

# %%
ae_error_filtered = get_error_df(X_test_filtered, ae_pred_filtered, mode="topn", n_highest=100)
ae_error_filtered_train = get_error_df(X_train_wo_valid_filtered, ae_pred_filtered_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error_filtered, open(model_directory + "ae_error_filtered.p", "wb"))
pickle.dump(ae_error_filtered_train, open(model_directory + "ae_error_filtered_train.p", "wb"))

# %%
plt.rcParams['figure.figsize'] = [30, 30]
plt_dir = '/afs/cern.ch/user/t/tkrzyzek/Documents/Data-Certification/visualization/plots_train_reduced_features/'
bins = np.linspace(-50, 50, 50)
overlap = []
for i in tnrange(X_test_filtered.shape[1]):
    v, r = divmod(i, 7)
    
    # Train set
    good_input_train = X_train_wo_valid_filtered[:, i].reshape(-1)
    good_output_train = ae_pred_filtered_train[:, i].reshape(-1)
    filter_fraction = 1 # in %
    filtered_idx = (good_input_train < np.percentile(good_input_train, 100-filter_fraction))
    filtered_idx &= (good_input_train > np.percentile(good_input_train, filter_fraction))
    filtered_idx &= (good_output_train < np.percentile(good_output_train, 100-filter_fraction))
    filtered_idx &= (good_output_train > np.percentile(good_output_train, filter_fraction))
    good_input_filtered_train = good_input_train[filtered_idx]
    good_output_filtered_train = good_output_train[filtered_idx]
    
    good_input_orig = X_train_filtered_wo_valid[:, i].reshape(-1)
    filtered_orig_idx = (good_input_orig < np.percentile(good_input_orig, 100-filter_fraction))
    filtered_orig_idx &= (good_input_orig > np.percentile(good_input_orig, filter_fraction))
    good_input_orig_filtered_train = good_input_orig[filtered_orig_idx]
    
    # Test set
    good_input_test = X_test_filtered[y_test == 0][:, i].reshape(-1)
    good_output_test = ae_pred_filtered[y_test == 0][:, i].reshape(-1)
    filter_fraction = 1
    filtered_idx = (good_input_test < np.percentile(good_input_test, 100-filter_fraction))
    filtered_idx &= (good_input_test > np.percentile(good_input_test, filter_fraction))
    filtered_idx &= (good_output_test < np.percentile(good_output_test, 100-filter_fraction))
    filtered_idx &= (good_output_test > np.percentile(good_output_test, filter_fraction))
    good_input_filtered_test = good_input_test[filtered_idx]
    good_output_filtered_test = good_output_test[filtered_idx]
    
    bad_input_test = X_test_filtered[y_test == 1][:, i].reshape(-1)
    bad_output_test = ae_pred_filtered[y_test == 1][:, i].reshape(-1)
    filter_fraction = 1
    filtered_idx = (bad_input_test < np.percentile(bad_input_test, 100-filter_fraction))
    filtered_idx &= (bad_input_test > np.percentile(bad_input_test, filter_fraction))
    filtered_idx &= (bad_output_test < np.percentile(bad_output_test, 100-filter_fraction))
    filtered_idx &= (bad_output_test > np.percentile(bad_output_test, filter_fraction))
    bad_input_filtered_test = bad_input_test[filtered_idx]
    bad_output_filtered_test = bad_output_test[filtered_idx]
    
    good_input_orig = X_test_filtered[:, i][y_test == 0].reshape(-1)
    filtered_orig_idx = (good_input_orig < np.percentile(good_input_orig, 100-filter_fraction))
    filtered_orig_idx &= (good_input_orig > np.percentile(good_input_orig, filter_fraction))
    good_input_orig_filtered_test = good_input_orig[filtered_orig_idx]
    
    bad_input_orig = X_test_filtered[:, i][y_test == 1].reshape(-1)
    filtered_orig_idx = (bad_input_orig < np.percentile(bad_input_orig, 100-filter_fraction))
    filtered_orig_idx &= (bad_input_orig > np.percentile(bad_input_orig, filter_fraction))
    bad_input_orig_filtered_test = bad_input_orig[filtered_orig_idx]
    
#     print(len(good_input_filtered))
#     print(len(good_input))
#     cut = 100 * (1 - len(good_input_filtered) / len(good_input))
#     print(cut)
#     overlap_frac = 100 * (4-cut)/2
#     print(overlap_frac)
#     overlap.append(overlap_frac)
    
    fig, axes = plt.subplots(3, 3)
    
    axes[(0, 0)].hist(good_input_orig_filtered_train, 100, histtype='step', linewidth=2, label="Raw input")
    axes[(0, 0)].set_title(feature_names[v] + ' ' + var_legend[r]['name'] + ' GOOD TRAIN raw input')
    axes[(0, 0)].set_xlabel('Values')
    axes[(0, 0)].set_ylabel('Number of lumisections')
    axes[(0, 0)].legend()
    
    axes[(0, 1)].hist(good_input_orig_filtered_test, 100, histtype='step', linewidth=2, label="Raw input")
    axes[(0, 1)].set_title(feature_names[v] + ' ' + var_legend[r]['name'] + ' GOOD TEST raw input')
    axes[(0, 1)].set_xlabel('Values')
    axes[(0, 1)].set_ylabel('Number of lumisections')
    axes[(0, 1)].legend()
    
    axes[(0, 2)].hist(bad_input_orig_filtered_test, 100, histtype='step', linewidth=2, label="Raw input")
    axes[(0, 2)].set_title(feature_names[v] + ' ' + var_legend[r]['name'] + ' BAD raw input')
    axes[(0, 2)].set_xlabel('Values')
    axes[(0, 2)].set_ylabel('Number of lumisections')
    axes[(0, 2)].legend()
    
    axes[(1, 0)].hist(good_input_filtered_train, alpha=0.5, histtype='step', linewidth=2, color='b', 
          label="Normalized input")
    axes[(1, 0)].hist(good_output_filtered_train, alpha=0.5, histtype='step', linewidth=2, color='r', 
          label="AE output")
    axes[(1, 0)].set_xlabel('Values')
    axes[(1, 0)].set_ylabel('Number of lumisections')
    axes[(1, 0)].legend()
    axes[(1, 0)].set_title(feature_names[v] + ' ' + var_legend[r]['name'] + ' I/O histogram')
    
    axes[1][1].hist(good_input_filtered_test, alpha=0.5, histtype='step', linewidth=2, color='b', 
          label="Normalized input")
    axes[1][1].hist(good_output_filtered_test, alpha=0.5, histtype='step', linewidth=2, color='r', 
          label="AE output")
    axes[1][1].set_xlabel('Values')
    axes[1][1].set_ylabel('Number of lumisections')
    axes[1][1].legend()
    axes[1][1].set_title(feature_names[v] + ' ' + var_legend[r]['name'] + ' I/O histogram')
    
    axes[1][2].hist(bad_input_filtered_test, alpha=0.5, histtype='step', linewidth=2, color='b', 
          label="Normalized input")
    axes[1][2].hist(bad_output_filtered_test, alpha=0.5, histtype='step', linewidth=2, color='r', 
          label="AE output")
    axes[1][2].set_xlabel('Values')
    axes[1][2].set_ylabel('Number of lumisections')
    axes[1][2].legend()
    axes[1][2].set_title(feature_names[v] + ' ' + var_legend[r]['name'] + ' I/O histogram')
    
    axes[2][0].hist2d(good_input_filtered_train, good_output_filtered_train, norm=LogNorm(),
                      bins=200)
    axes[2][0].set_title('corr. coeff.:' 
                         + str(round(pearsonr(good_input_train, good_output_train)[0], 2)))
    axes[2][0].set_xlabel('Input values')
    axes[2][0].set_ylabel('Output values')
    axes[2][0].axis('equal')
    
    axes[2][1].hist2d(good_input_filtered_test, good_output_filtered_test, norm=LogNorm(),
                      bins=200)
    axes[2][1].set_title('corr. coeff.:' 
                         + str(round(pearsonr(good_input_test, good_output_test)[0], 2)))
    axes[2][1].set_xlabel('Input values')
    axes[2][1].set_ylabel('Output values')
    axes[2][1].axis('equal')
    
    axes[2][2].hist2d(bad_input_filtered_test, bad_output_filtered_test, norm=LogNorm(), 
                      bins=200)
    axes[2][2].set_title('corr. coeff.:' 
                         + str(round(pearsonr(bad_input_test, bad_output_test)[0], 2)))
    axes[2][2].set_xlabel('Input values')
    axes[2][2].set_ylabel('Output values')
    axes[2][2].axis('equal')
    
#     plt.savefig(plt_dir + str(i) + '_' + feature_names[v] + '_' + var_legend[r]['name'])
    plt.show()
    plt.close()
    print('####################################################################################')

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plot_lumi_error(np.zeros(ae_pred.shape), X_test_norm, title='Mean square score across lumisections')
plot_lumi_error(ae_pred, X_test_norm, title='AE reco errror across lumisections')
plot_lumi_error(ae_pred_filtered, X_test_filtered, 
                title='AE filtered reco errror across lumisections')

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve(label, pred, X_tests, names):
    """Generates ROC Curves for a given array"""
    scores = [get_error_df(X_tests[i], pred[i], mode='topn') for i in range(len(pred))]
    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve_error(label, scores, names):
    """Generates ROC Curves for a given array"""    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()
    return plt

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [ae_error,
                     get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)], 
                    ['AE',
                     'Mean square'])

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error, 
                     get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)], 
                    ['Squeezed AE w/o pileup',
                     'Squeezed AE with pileup',
                     'Standard AE with pileup',
                     'Standard AE w/o pileup',
                     'Mean square'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-0de51066cff7> in <module>()
#       1 plt.rcParams['figure.figsize'] = [20, 10]
#       2 fig = get_roc_curve_error(y_test,
# ----> 3                     [np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error,
#       4                      get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)],
#       5                     ['Squeezed AE w/o pileup',
#
# NameError: name 'np_b_ae_error' is not defined

# %%
fig.savefig(csv_dir + 'roc_auc_filtered_ae.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-a37dea40acb0> in <module>()
# ----> 1 fig.savefig(csv_dir + 'roc_auc_filtered_ae.png')
#
# NameError: name 'csv_dir' is not defined

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered,
                     get_error_df(X_test_filtered, np.zeros(X_test_filtered.shape), mode="topn", n_highest=100)], 
                    ['Squeezed AE w/o pileup',
                     'Squeezed AE with pileup',
                     'Standard AE with pileup',
                     'Standard AE w/o pileup',
                     'Mean square'])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

LABELS = ["Normal", "Anomalous"]

def conf_matrix(scores, y_true, threshold, title):
    y_pred = [1 if e > threshold else 0 for e in scores]
    conf_matrix = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(12, 12))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.title(title)
    plt.show()

    acc = accuracy_score(y_true, y_pred)
    class_imbal = np.mean(1 - y_true)
    adj_acc = (acc - class_imbal) / (1 - class_imbal)

    print("Threshold:", threshold)
    print("Adjusted accuracy:", adj_acc)
    return threshold

# %%
conf_matrix(ae_error_filtered, y_test, 1.5e0, '')
# Out:
# Threshold: 1.5
# Adjusted accuracy: -9.19813953488
# 1.5

# %%
def pred_vs_feature(y_val, x_val, y_class, y_name="", x_name="", selected=[], linear=False,
                    limit=False):
    '''
    Plots two arbitrary values agains each other.
    '''
    df = pd.DataFrame({'y_val': y_val,
                       'x_val': x_val,
                       'y_class': y_class})

    groups = df.groupby('y_class')
    fig, ax = plt.subplots()

    for name, group in groups:
        ax.plot(group.x_val, 
                group.y_val,
                color="red" if name == 1 else "blue",
                marker='o',
                ms=2,
                linestyle='',
                label= "Anomaly" if name == 1 else "Normal")

    for i in selected:
        ax.plot(x_val[i],
                y_val[i],
                color="green",
                marker='o',
                ms=4,
                linestyle='')
                 
    ax.legend()
    if not linear:
        ax.set_yscale('log')
    if limit:
        plt.xlim([limit[0], limit[1]])
    plt.grid()
    plt.ylabel(y_name)
    plt.xlabel(x_name)
    plt.show()

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error_filtered, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
model_directory_np_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_bottleneck/"
model_directory_p_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup/"
model_directory_p_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup_no_bottleneck/"
model_directory_np_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_no_pileup_no_bottleneck/"

# %%
np_b_ae_error = pickle.load(open(model_directory_np_b + "ae_error.p", "rb"))
np_b_ae_error_filtered = pickle.load(open(model_directory_np_b + "ae_error_filtered.p", "rb"))

p_b_ae_error = pickle.load(open(model_directory_p_b + "ae_error.p", "rb"))
p_b_ae_error_filtered = pickle.load(open(model_directory_p_b + "ae_error_filtered.p", "rb"))


p_nb_ae_error = pickle.load(open(model_directory_p_nb + "ae_error.p", "rb"))
p_nb_ae_error_filtered = pickle.load(open(model_directory_p_nb + "ae_error_filtered.p", "rb"))


np_nb_ae_error = pickle.load(open(model_directory_np_nb + "ae_error.p", "rb"))
np_nb_ae_error_filtered = pickle.load(open(model_directory_np_nb + "ae_error_filtered.p", "rb"))

# %%
def pred_vs_feature4(y_vals, x_val, y_class, titles, y_name="", x_name="", linear=False, 
                     limit=False, name_plt=''):
    '''
    Plots two arbitrary values agains each other.
    '''
    fig, axes = plt.subplots(2, 2)
    
    for i in range(4):
        df = pd.DataFrame({'y_val': y_vals[i],
                           'x_val': x_val,
                           'y_class': y_class})

        groups = df.groupby('y_class')
        if i < 2:
            ax = axes[0, i%2]
        else:
            ax = axes[1, i%2]
        
        for name, group in groups:
            ax.plot(group.x_val, 
                    group.y_val,
                    color="red" if name == 1 else "blue",
                    marker='o',
                    ms=2,
                    linestyle='',
                    label= "Anomaly" if name == 1 else "Normal")

        ax.legend()
        if not linear:
            ax.set_yscale('log')
        if limit:
            plt.xlim([limit[0], limit[1]])
        ax.set_ylabel(y_name)
        ax.set_xlabel(x_name)
        ax.set_title(titles[i])
        plt.grid()
    plt.show()
    plt.savefig(csv_dir + name_plt)

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2807], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2807], y_test,
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                 'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='filtered_ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2808], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='ae_vs_pileup.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2808], y_test, 
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='filtered_ae_vs_pileup.png')
