# %%
# Running on GPU?
import setGPU

import getpass
import h5py
import pickle
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.colors import LogNorm

from tqdm import tnrange, tqdm_notebook
# Out:
# setGPU: Setting GPU to: 2

# %%
import os
import getpass
# Get permission to access EOS (Insert your NICE password)
os.system("echo %s | kinit" % getpass.getpass())
# Out:
# ········
# 0

# %%
import json
import numpy as np
import pandas as pd
from pprint import pprint

import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Dense, Lambda, BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.activations import sigmoid, linear, relu
from keras.models import Model, load_model
from keras.regularizers import l1, l2, l1_l2

from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import class_weight
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from scipy.stats import pearsonr

import xgboost as xgb
from xgboost import XGBClassifier
# Out:
# Using TensorFlow backend.

# %%
plt.rcParams.update({'font.size': 22})

# %%
PDs  = {1: 'BTagCSV',
        2: 'BTagMu',
        3: 'Charmonium',
        4: 'DisplacedJet',
        5: 'DoubleEG',
        6: 'DoubleMuon',
        7: 'DoubleMuonLowMass',
        8: 'FSQJets',
        9: 'HighMultiplicityEOF',
        10: 'HTMHT',
        11: 'JetHT',
        12: 'MET',
        13: 'MinimumBias',
        14: 'MuonEG',
        15: 'MuOnia',
        16: 'NoBPTX',
        17: 'SingleElectron',
        18: 'SingleMuon',
        19: 'SinglePhoton',
        20: 'Tau',
        21: 'ZeroBias'}

# Select PD
nPD = 11

# %%
legend = [{"name": 'pf_jets', "start": 0, "end": 776},
          {"name": 'cal_jet_mets', "start": 777, "end": 944},
          {"name": 'pho', "start": 945, "end": 1280},
          {"name": 'muons', "start": 1281, "end": 1784},
          {"name": 'pf_jets2', "start": 1785, "end": 1889},
          {"name": 'pf_mets', "start": 1890, "end": 1917},
          {"name": 'nvtx', "start": 1918, "end": 1924},
          {"name": 'cal_jet_mets2', "start": 1925},
          {"name": 'sc', "start": 2037, "end": 2127},
          {"name": 'cc', "start": 2128, "end": 2169},
          {"name": 'pho2', "start": 2170, "end": 2365},
          {"name": 'muons2', "start": 2366, "end": 2491},
          {"name": 'ebs', "start": 2492, "end": 2701},
          {"name": 'hbhef', "start": 2702, "end": 2764},
          {"name": 'presh', "start": 2765, "end": 2806},
          {"name": 'inst_lumi', "start": 2807, "end": 2808}]

# %%
# Feature description
feature_names = ['qPFJetPt', 'qPFJetEta', 'qPFJetPhi', 'qPFJet0Pt', 'qPFJet1Pt', 'qPFJet2Pt', 'qPFJet3Pt', 'qPFJet4Pt', 'qPFJet5Pt', 'qPFJet0Eta', 'qPFJet1Eta', 'qPFJet2Eta', 'qPFJet3Eta', 'qPFJet4Eta', 'qPFJet5Eta', 'qPFJet0Phi', 'qPFJet1Phi', 'qPFJet2Phi', 'qPFJet3Phi', 'qPFJet4Phi', 'qPFJet5Phi', 'qPFJet4CHS0Pt', 'qPFJet4CHS1Pt', 'qPFJet4CHS2Pt', 'qPFJet4CHS3Pt', 'qPFJet4CHS4Pt', 'qPFJet4CHS5Pt', 'qPFJet4CHS0Eta', 'qPFJet4CHS1Eta', 'qPFJet4CHS2Eta', 'qPFJet4CHS3Eta', 'qPFJet4CHS4Eta', 'qPFJet4CHS5Eta', 'qPFJet4CHS0Phi', 'qPFJet4CHS1Phi', 'qPFJet4CHS2Phi', 'qPFJet4CHS3Phi', 'qPFJet4CHS4Phi', 'qPFJet4CHS5Phi', 'qPFJet8CHS0Pt', 'qPFJet8CHS1Pt', 'qPFJet8CHS2Pt', 'qPFJet8CHS3Pt', 'qPFJet8CHS4Pt', 'qPFJet8CHS5Pt', 'qPFJet8CHS0Eta', 'qPFJet8CHS1Eta', 'qPFJet8CHS2Eta', 'qPFJet8CHS3Eta', 'qPFJet8CHS4Eta', 'qPFJet8CHS5Eta', 'qPFJet8CHS0Phi', 'qPFJet8CHS1Phi', 'qPFJet8CHS2Phi', 'qPFJet8CHS3Phi', 'qPFJet8CHS4Phi', 'qPFJet8CHS5Phi', 'qPFJetEI0Pt', 'qPFJetEI1Pt', 'qPFJetEI2Pt', 'qPFJetEI3Pt', 'qPFJetEI4Pt', 'qPFJetEI5Pt', 'qPFJetEI0Eta', 'qPFJetEI1Eta', 'qPFJetEI2Eta', 'qPFJetEI3Eta', 'qPFJetEI4Eta', 'qPFJetEI5Eta', 'qPFJetEI0Phi', 'qPFJetEI1Phi', 'qPFJetEI2Phi', 'qPFJetEI3Phi', 'qPFJetEI4Phi', 'qPFJetEI5Phi', 'qPFJet8CHSSD0Pt', 'qPFJet8CHSSD1Pt', 'qPFJet8CHSSD2Pt', 'qPFJet8CHSSD3Pt', 'qPFJet8CHSSD4Pt', 'qPFJet8CHSSD5Pt', 'qPFJet8CHSSD0Eta', 'qPFJet8CHSSD1Eta', 'qPFJet8CHSSD2Eta', 'qPFJet8CHSSD3Eta', 'qPFJet8CHSSD4Eta', 'qPFJet8CHSSD5Eta', 'qPFJet8CHSSD0Phi', 'qPFJet8CHSSD1Phi', 'qPFJet8CHSSD2Phi', 'qPFJet8CHSSD3Phi', 'qPFJet8CHSSD4Phi', 'qPFJet8CHSSD5Phi', 'qPFJetTopCHS0Pt', 'qPFJetTopCHS1Pt', 'qPFJetTopCHS2Pt', 'qPFJetTopCHS3Pt', 'qPFJetTopCHS4Pt', 'qPFJetTopCHS5Pt', 'qPFJetTopCHS0Eta', 'qPFJetTopCHS1Eta', 'qPFJetTopCHS2Eta', 'qPFJetTopCHS3Eta', 'qPFJetTopCHS4Eta', 'qPFJetTopCHS5Eta', 'qPFJetTopCHS0Phi', 'qPFJetTopCHS1Phi', 'qPFJetTopCHS2Phi', 'qPFJetTopCHS3Phi', 'qPFJetTopCHS4Phi', 'qPFJetTopCHS5Phi', 'qCalJet0Pt', 'qCalJet1Pt', 'qCalJet2Pt', 'qCalJet3Pt', 'qCalJet4Pt', 'qCalJet5Pt', 'qCalJet0Eta', 'qCalJet1Eta', 'qCalJet2Eta', 'qCalJet3Eta', 'qCalJet4Eta', 'qCalJet5Eta', 'qCalJet0Phi', 'qCalJet1Phi', 'qCalJet2Phi', 'qCalJet3Phi', 'qCalJet4Phi', 'qCalJet5Phi', 'qCalJet0En', 'qCalJet1En', 'qCalJet2En', 'qCalJet3En', 'qCalJet4En', 'qCalJet5En', 'qPho0Pt', 'qPho1Pt', 'qPho2Pt', 'qPho3Pt', 'qPho4Pt', 'qPho5Pt', 'qPho0Eta', 'qPho1Eta', 'qPho2Eta', 'qPho3Eta', 'qPho4Eta', 'qPho5Eta', 'qPho0Phi', 'qPho1Phi', 'qPho2Phi', 'qPho3Phi', 'qPho4Phi', 'qPho5Phi', 'qPho0En', 'qPho1En', 'qPho2En', 'qPho3En', 'qPho4En', 'qPho5En', 'qgedPho0Pt', 'qgedPho1Pt', 'qgedPho2Pt', 'qgedPho3Pt', 'qgedPho4Pt', 'qgedPho5Pt', 'qgedPho0Eta', 'qgedPho1Eta', 'qgedPho2Eta', 'qgedPho3Eta', 'qgedPho4Eta', 'qgedPho5Eta', 'qgedPho0Phi', 'qgedPho1Phi', 'qgedPho2Phi', 'qgedPho3Phi', 'qgedPho4Phi', 'qgedPho5Phi', 'qgedPho0En', 'qgedPho1En', 'qgedPho2En', 'qgedPho3En', 'qgedPho4En', 'qgedPho5En', 'qMu0Pt', 'qMu1Pt', 'qMu2Pt', 'qMu3Pt', 'qMu4Pt', 'qMu5Pt', 'qMu0Eta', 'qMu1Eta', 'qMu2Eta', 'qMu3Eta', 'qMu4Eta', 'qMu5Eta', 'qMu0Phi', 'qMu1Phi', 'qMu2Phi', 'qMu3Phi', 'qMu4Phi', 'qMu5Phi', 'qMu0En', 'qMu1En', 'qMu2En', 'qMu3En', 'qMu4En', 'qMu5En', 'qMuCosm0Pt', 'qMuCosm1Pt', 'qMuCosm2Pt', 'qMuCosm3Pt', 'qMuCosm4Pt', 'qMuCosm5Pt', 'qMuCosm0Eta', 'qMuCosm1Eta', 'qMuCosm2Eta', 'qMuCosm3Eta', 'qMuCosm4Eta', 'qMuCosm5Eta', 'qMuCosm0Phi', 'qMuCosm1Phi', 'qMuCosm2Phi', 'qMuCosm3Phi', 'qMuCosm4Phi', 'qMuCosm5Phi', 'qMuCosm0En', 'qMuCosm1En', 'qMuCosm2En', 'qMuCosm3En', 'qMuCosm4En', 'qMuCosm5En', 'qMuCosmLeg0Pt', 'qMuCosmLeg1Pt', 'qMuCosmLeg2Pt', 'qMuCosmLeg3Pt', 'qMuCosmLeg4Pt', 'qMuCosmLeg5Pt', 'qMuCosmLeg0Eta', 'qMuCosmLeg1Eta', 'qMuCosmLeg2Eta', 'qMuCosmLeg3Eta', 'qMuCosmLeg4Eta', 'qMuCosmLeg5Eta', 'qMuCosmLeg0Phi', 'qMuCosmLeg1Phi', 'qMuCosmLeg2Phi', 'qMuCosmLeg3Phi', 'qMuCosmLeg4Phi', 'qMuCosmLeg5Phi', 'qMuCosmLeg0En', 'qMuCosmLeg1En', 'qMuCosmLeg2En', 'qMuCosmLeg3En', 'qMuCosmLeg4En', 'qMuCosmLeg5En', 'qPFJet4CHSPt', 'qPFJet4CHSEta', 'qPFJet4CHSPhi', 'qPFJet8CHSPt', 'qPFJet8CHSEta', 'qPFJet8CHSPhi', 'qPFJetEIPt', 'qPFJetEIEta', 'qPFJetEIPhi', 'qPFJet8CHSSDPt', 'qPFJet8CHSSDEta', 'qPFJet8CHSSDPhi', 'qPFJetTopCHSPt', 'qPFJetTopCHSEta', 'qPFJetTopCHSPhi', 'qPFChMetPt', 'qPFChMetPhi', 'qPFMetPt', 'qPFMetPhi', 'qNVtx', 'qCalJetPt', 'qCalJetEta', 'qCalJetPhi', 'qCalJetEn', 'qCalMETPt', 'qCalMETPhi', 'qCalMETEn', 'qCalMETBEPt', 'qCalMETBEPhi', 'qCalMETBEEn', 'qCalMETBEFOPt', 'qCalMETBEFOPhi', 'qCalMETBEFOEn', 'qCalMETMPt', 'qCalMETMPhi', 'qCalMETMEn', 'qSCEn', 'qSCEta', 'qSCPhi', 'qSCEtaWidth', 'qSCPhiWidth', 'qSCEnhfEM', 'qSCEtahfEM', 'qSCPhihfEM', 'qSCEn5x5', 'qSCEta5x5', 'qSCPhi5x5', 'qSCEtaWidth5x5', 'qSCPhiWidth5x5', 'qCCEn', 'qCCEta', 'qCCPhi', 'qCCEn5x5', 'qCCEta5x5', 'qCCPhi5x5', 'qPhoPt', 'qPhoEta', 'qPhoPhi', 'qPhoEn_', 'qPhoe1x5_', 'qPhoe2x5_', 'qPhoe3x3_', 'qPhoe5x5_', 'qPhomaxenxtal_', 'qPhosigmaeta_', 'qPhosigmaIeta_', 'qPhor1x5_', 'qPhor2x5_', 'qPhor9_', 'qgedPhoPt', 'qgedPhoEta', 'qgedPhoPhi', 'qgedPhoEn_', 'qgedPhoe1x5_', 'qgedPhoe2x5_', 'qgedPhoe3x3_', 'qgedPhoe5x5_', 'qgedPhomaxenxtal_', 'qgedPhosigmaeta_', 'qgedPhosigmaIeta_', 'qgedPhor1x5_', 'qgedPhor2x5_', 'qgedPhor9_', 'qMuPt', 'qMuEta', 'qMuPhi', 'qMuEn_', 'qMuCh_', 'qMuChi2_', 'qMuCosmPt', 'qMuCosmEta', 'qMuCosmPhi', 'qMuCosmEn_', 'qMuCosmCh_', 'qMuCosmChi2_', 'qMuCosmLegPt', 'qMuCosmLegEta', 'qMuCosmLegPhi', 'qMuCosmLegEn_', 'qMuCosmLegCh_', 'qMuCosmLegChi2_', 'qSigmaIEta', 'qSigmaIPhi', 'qr9', 'qHadOEm', 'qdrSumPt', 'qdrSumEt', 'qeSCOP', 'qecEn', 'qUNSigmaIEta', 'qUNSigmaIPhi', 'qUNr9', 'qUNHadOEm', 'qUNdrSumPt', 'qUNdrSumEt', 'qUNeSCOP', 'qUNecEn', 'qEBenergy', 'qEBtime', 'qEBchi2', 'qEBiEta', 'qEBiPhi', 'qEEenergy', 'qEEtime', 'qEEchi2', 'qEEix', 'qEEiy', 'qESenergy', 'qEStime', 'qESix', 'qESiy', 'qHBHEenergy', 'qHBHEtime', 'qHBHEauxe', 'qHBHEieta', 'qHBHEiphi', 'qHFenergy', 'qHFtime', 'qHFieta', 'qHFiphi', 'qPreShEn', 'qPreShEta', 'qPreShPhi', 'qPreShYEn', 'qPreShYEta', 'qPreShYPhi', 'inst_luminosity']

# %%
data_directory = "/eos/cms/store/user/fsiroky/consistentlumih5/"
label_file = "/afs/cern.ch/user/t/tkrzyzek/Documents/Data-Certification/jsons-generated/JetHT.json"
pileup_file = "/afs/cern.ch/cms/CAF/CMSCOMM/COMM_DQM/certification/Collisions16/13TeV/PileUp/pileup_latest.txt"
model_directory = "/eos/user/t/tkrzyzek/autoencoder/JetHT-80-20-adj-feats/"
model_name = "model"

# %%
def get_file_list(directory, pds, npd, typeof, extension):
    files = []
    parts = ["C", "D", "E", "F", "G", "H"]
    for p in parts:
        files.append("%s%s_%s_%s%s" % (directory, pds[npd], p, typeof, extension))
    return files

files = get_file_list(data_directory, PDs, nPD, "background", ".h5")
files = files + get_file_list(data_directory, PDs, nPD, "signal", ".h5")

# %%
# Load good and bad jets
def get_data(files):
    readout = np.empty([0,2813])
    
    for file in files:
        jet = file.split("/")[-1][:-3]
        print("Reading: %s" % jet)
        try:
            h5file = h5py.File(file, "r")
            readout = np.concatenate((readout, h5file[jet][:]), axis=0)
        except OSError as error:
            print("This Primary Dataset doesn't have %s. %s" % (jet, error))
            continue

    return readout

data = pd.DataFrame(get_data(files))
# Out:
# Reading: JetHT_C_background
# Reading: JetHT_D_background
# Reading: JetHT_E_background
# Reading: JetHT_F_background
# Reading: JetHT_G_background
# Reading: JetHT_H_background
# Reading: JetHT_C_signal
# Reading: JetHT_D_signal
# Reading: JetHT_E_signal
# Reading: JetHT_F_signal
# Reading: JetHT_G_signal
# Reading: JetHT_H_signal

# %%
data["run"] = data[2807].astype(int)
data["lumi"] = data[2808].astype(int)
data["inst_lumi"] = data[2809].astype(float)

# Drop unnecessary meta data
data.drop([2808, 2809, 2810, 2811, 2812], axis=1, inplace=True)

# Append inst. luminosity at the end as well
data[2807] = data["inst_lumi"]

# Sort by runID and then by lumiID
data = data.sort_values(["run", "lumi"], ascending=[True,True])

# Reset index
data = data.reset_index(drop=True)  

runIDs  = data["run"].astype(int)
lumiIDs = data["lumi"].astype(int)
luminosity = data["inst_lumi"].astype(float)

# %%
# Apply labels
output_json = json.load(open(label_file))

def json_checker(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid >= i[0] and orig_lumid <= i[1]:
                return 0
    except KeyError:
        pass
    return 1

def add_flags(sample):
    return json_checker(output_json, sample["run"], sample["lumi"])

data["label"] = data.apply(add_flags, axis=1)

# %%
with open(pileup_file) as f:
    pileup = json.load(f)

def pileup_from_json(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid == i[0]:
                return i[3]
    except KeyError:
        print('key error')
    return 1

def add_pileup(sample):
    return pileup_from_json(pileup, sample["run"], sample["lumi"])

data["pileup"] = data.apply(add_pileup, axis=1)

# %%
data[2808] = data["pileup"]

# %%
RUN_FROM = 278769

# Take only continous data
data = data[data['run'] >= RUN_FROM]

# Split the data
TRAIN_FROM = round(0*len(data))
TRAIN_TO = round(0.8*len(data))
TEST_FROM = round(0.8*len(data))
TEST_TO = round(1*len(data))

train = data.iloc[TRAIN_FROM:TRAIN_TO]
X_train = pd.concat([train.iloc[:, :2808], train[2808]], axis=1)
y_train = train["label"]

# Adding bad data to test set
test = pd.concat([data.iloc[TEST_FROM:TEST_TO], data[:TEST_FROM][data['label'] == 1],
                 data[TEST_TO:][data['label'] == 1]]) 
X_test = pd.concat([test.iloc[:, :2808], test[2808]], axis=1)
y_test = test["label"]

normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# Train only on good
X_train = X_train[y_train == 0]
X_train_norm = X_train_norm[y_train == 0]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
INPUT_DIM = 2809

# %%
X_test_norm.shape
# Out:
# (19086, 2809)

# %%
input_layer = Input(shape=(INPUT_DIM, ))

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(INPUT_DIM)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2809)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              5754880
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 2048)              2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 1024)              1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# p_re_lu_3 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# p_re_lu_4 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# p_re_lu_5 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# p_re_lu_6 (PReLU)            (None, 64)                64
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               8320
# _________________________________________________________________
# p_re_lu_7 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               33024
# _________________________________________________________________
# p_re_lu_8 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               131584
# _________________________________________________________________
# p_re_lu_9 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_10 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 2048)              2099200
# _________________________________________________________________
# p_re_lu_11 (PReLU)           (None, 2048)              2048
# _________________________________________________________________
# dense_12 (Dense)             (None, 2809)              5755641
# =================================================================
# Total params: 17,111,417
# Trainable params: 17,111,417
# Non-trainable params: 0
# _________________________________________________________________

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_norm,
                X_train_norm,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 51739 samples, validate on 17247 samples
# Epoch 1/2048
# 13s - loss: 58.8903 - val_loss: 29.6389
# Epoch 2/2048
# 9s - loss: 17.3407 - val_loss: 9.1733
# Epoch 3/2048
# 10s - loss: 5.8545 - val_loss: 3.6643
# Epoch 4/2048
# 8s - loss: 2.6815 - val_loss: 1.9684
# Epoch 5/2048
# 8s - loss: 1.5718 - val_loss: 1.2631
# Epoch 6/2048
# 8s - loss: 1.0852 - val_loss: 0.9395
# Epoch 7/2048
# 8s - loss: 0.8476 - val_loss: 0.7710
# Epoch 8/2048
# 8s - loss: 0.7226 - val_loss: 0.6818
# Epoch 9/2048
# 8s - loss: 0.6559 - val_loss: 0.6319
# Epoch 10/2048
# 8s - loss: 0.6180 - val_loss: 0.6043
# Epoch 11/2048
# 8s - loss: 0.5965 - val_loss: 0.5884
# Epoch 12/2048
# 8s - loss: 0.5843 - val_loss: 0.5789
# Epoch 13/2048
# 10s - loss: 0.5767 - val_loss: 0.5725
# Epoch 14/2048
# 9s - loss: 0.5718 - val_loss: 0.5684
# Epoch 15/2048
# 9s - loss: 0.5683 - val_loss: 0.5655
# Epoch 16/2048
# 8s - loss: 0.5657 - val_loss: 0.5632
# Epoch 17/2048
# 8s - loss: 0.5635 - val_loss: 0.5606
# Epoch 18/2048
# 8s - loss: 0.5614 - val_loss: 0.5585
# Epoch 19/2048
# 9s - loss: 0.5595 - val_loss: 0.5565
# Epoch 20/2048
# 9s - loss: 0.5579 - val_loss: 0.5555
# Epoch 21/2048
# 8s - loss: 0.5564 - val_loss: 0.5539
# Epoch 22/2048
# 8s - loss: 0.5550 - val_loss: 0.5530
# Epoch 23/2048
# 8s - loss: 0.5537 - val_loss: 0.5513
# Epoch 24/2048
# 8s - loss: 0.5526 - val_loss: 0.5499
# Epoch 25/2048
# 8s - loss: 0.5515 - val_loss: 0.5495
# Epoch 26/2048
# 8s - loss: 0.5504 - val_loss: 0.5481
# Epoch 27/2048
# 8s - loss: 0.5494 - val_loss: 0.5471
# Epoch 28/2048
# 8s - loss: 0.5484 - val_loss: 0.5461
# Epoch 29/2048
# 8s - loss: 0.5475 - val_loss: 0.5444
# Epoch 30/2048
# 8s - loss: 0.5465 - val_loss: 0.5438
# Epoch 31/2048
# 8s - loss: 0.5456 - val_loss: 0.5430
# Epoch 32/2048
# 8s - loss: 0.5448 - val_loss: 0.5429
# Epoch 33/2048
# 8s - loss: 0.5440 - val_loss: 0.5413
# Epoch 34/2048
# 8s - loss: 0.5431 - val_loss: 0.5412
# Epoch 35/2048
# 8s - loss: 0.5423 - val_loss: 0.5393
# Epoch 36/2048
# 8s - loss: 0.5415 - val_loss: 0.5392
# Epoch 37/2048
# 8s - loss: 0.5407 - val_loss: 0.5381
# Epoch 38/2048
# 8s - loss: 0.5399 - val_loss: 0.5375
# Epoch 39/2048
# 8s - loss: 0.5392 - val_loss: 0.5365
# Epoch 40/2048
# 8s - loss: 0.5384 - val_loss: 0.5361
# Epoch 41/2048
# 9s - loss: 0.5376 - val_loss: 0.5351
# Epoch 42/2048
# 8s - loss: 0.5367 - val_loss: 0.5342
# Epoch 43/2048
# 8s - loss: 0.5359 - val_loss: 0.5337
# Epoch 44/2048
# 8s - loss: 0.5350 - val_loss: 0.5326
# Epoch 45/2048
# 8s - loss: 0.5341 - val_loss: 0.5314
# Epoch 46/2048
# 6s - loss: 0.5333 - val_loss: 0.5314
# Epoch 47/2048
# 8s - loss: 0.5325 - val_loss: 0.5302
# Epoch 48/2048
# 8s - loss: 0.5317 - val_loss: 0.5296
# Epoch 49/2048
# 8s - loss: 0.5310 - val_loss: 0.5289
# Epoch 50/2048
# 8s - loss: 0.5302 - val_loss: 0.5285
# Epoch 51/2048
# 9s - loss: 0.5295 - val_loss: 0.5274
# Epoch 52/2048
# 7s - loss: 0.5288 - val_loss: 0.5269
# Epoch 53/2048
# 6s - loss: 0.5281 - val_loss: 0.5269
# Epoch 54/2048
# 8s - loss: 0.5274 - val_loss: 0.5260
# Epoch 55/2048
# 8s - loss: 0.5267 - val_loss: 0.5252
# Epoch 56/2048
# 8s - loss: 0.5260 - val_loss: 0.5250
# Epoch 57/2048
# 8s - loss: 0.5253 - val_loss: 0.5243
# Epoch 58/2048
# 8s - loss: 0.5246 - val_loss: 0.5238
# Epoch 59/2048
# 8s - loss: 0.5239 - val_loss: 0.5232
# Epoch 60/2048
# 10s - loss: 0.5233 - val_loss: 0.5224
# Epoch 61/2048
# 6s - loss: 0.5225 - val_loss: 0.5227
# Epoch 62/2048
# 9s - loss: 0.5219 - val_loss: 0.5220
# Epoch 63/2048
# 8s - loss: 0.5212 - val_loss: 0.5207
# Epoch 64/2048
# 6s - loss: 0.5205 - val_loss: 0.5209
# Epoch 65/2048
# 8s - loss: 0.5199 - val_loss: 0.5202
# Epoch 66/2048
# 8s - loss: 0.5193 - val_loss: 0.5198
# Epoch 67/2048
# 8s - loss: 0.5186 - val_loss: 0.5191
# Epoch 68/2048
# 8s - loss: 0.5180 - val_loss: 0.5186
# Epoch 69/2048
# 8s - loss: 0.5174 - val_loss: 0.5180
# Epoch 70/2048
# 8s - loss: 0.5167 - val_loss: 0.5179
# Epoch 71/2048
# 6s - loss: 0.5160 - val_loss: 0.5180
# Epoch 72/2048
# 7s - loss: 0.5153 - val_loss: 0.5169
# Epoch 73/2048
# 7s - loss: 0.5146 - val_loss: 0.5168
# Epoch 74/2048
# 8s - loss: 0.5138 - val_loss: 0.5164
# Epoch 75/2048
# 8s - loss: 0.5130 - val_loss: 0.5164
# Epoch 76/2048
# 8s - loss: 0.5122 - val_loss: 0.5160
# Epoch 77/2048
# 8s - loss: 0.5113 - val_loss: 0.5154
# Epoch 78/2048
# 8s - loss: 0.5104 - val_loss: 0.5154
# Epoch 79/2048
# 6s - loss: 0.5094 - val_loss: 0.5160
# Epoch 80/2048
# 8s - loss: 0.5083 - val_loss: 0.5151
# Epoch 81/2048
# 6s - loss: 0.5072 - val_loss: 0.5155
# Epoch 82/2048
# 6s - loss: 0.5060 - val_loss: 0.5158
# Epoch 83/2048
# 7s - loss: 0.5047 - val_loss: 0.5149
# Epoch 84/2048
# 6s - loss: 0.5034 - val_loss: 0.5149
# Epoch 85/2048
# 6s - loss: 0.5021 - val_loss: 0.5154
# Epoch 86/2048
# 6s - loss: 0.5008 - val_loss: 0.5150
# Epoch 87/2048
# 6s - loss: 0.4995 - val_loss: 0.5152
# Epoch 88/2048
# 6s - loss: 0.4982 - val_loss: 0.5156
# Epoch 89/2048
# 8s - loss: 0.4970 - val_loss: 0.5138
# Epoch 90/2048
# 6s - loss: 0.4957 - val_loss: 0.5149
# Epoch 91/2048
# 6s - loss: 0.4946 - val_loss: 0.5149
# Epoch 92/2048
# 6s - loss: 0.4935 - val_loss: 0.5139
# Epoch 93/2048
# 6s - loss: 0.4925 - val_loss: 0.5144
# Epoch 94/2048
# 6s - loss: 0.4915 - val_loss: 0.5148
# Epoch 95/2048
# 9s - loss: 0.4907 - val_loss: 0.5136
# Epoch 96/2048
# 6s - loss: 0.4899 - val_loss: 0.5138
# Epoch 97/2048
# 6s - loss: 0.4891 - val_loss: 0.5139
# Epoch 98/2048
# 9s - loss: 0.4884 - val_loss: 0.5132
# Epoch 99/2048
# 6s - loss: 0.4878 - val_loss: 0.5133
# Epoch 100/2048
# 9s - loss: 0.4872 - val_loss: 0.5117
# Epoch 101/2048
# 6s - loss: 0.4866 - val_loss: 0.5123
# Epoch 102/2048
# 7s - loss: 0.4860 - val_loss: 0.5117
# Epoch 103/2048
# 6s - loss: 0.4856 - val_loss: 0.5119
# Epoch 104/2048
# 6s - loss: 0.4851 - val_loss: 0.5121
# Epoch 105/2048
# 6s - loss: 0.4846 - val_loss: 0.5122
# Epoch 106/2048
# 9s - loss: 0.4841 - val_loss: 0.5106
# Epoch 107/2048
# 6s - loss: 0.4837 - val_loss: 0.5109
# Epoch 108/2048
# 8s - loss: 0.4833 - val_loss: 0.5100
# Epoch 109/2048
# 8s - loss: 0.4828 - val_loss: 0.5094
# Epoch 110/2048
# 8s - loss: 0.4824 - val_loss: 0.5092
# Epoch 111/2048
# 6s - loss: 0.4820 - val_loss: 0.5093
# Epoch 112/2048
# 8s - loss: 0.4816 - val_loss: 0.5085
# Epoch 113/2048
# 9s - loss: 0.4812 - val_loss: 0.5084
# Epoch 114/2048
# 9s - loss: 0.4808 - val_loss: 0.5083
# Epoch 115/2048
# 8s - loss: 0.4804 - val_loss: 0.5069
# Epoch 116/2048
# 6s - loss: 0.4800 - val_loss: 0.5069
# Epoch 117/2048
# 10s - loss: 0.4796 - val_loss: 0.5068
# Epoch 118/2048
# 10s - loss: 0.4792 - val_loss: 0.5067
# Epoch 119/2048
# 8s - loss: 0.4787 - val_loss: 0.5062
# Epoch 120/2048
# 9s - loss: 0.4783 - val_loss: 0.5052
# Epoch 121/2048
# 6s - loss: 0.4778 - val_loss: 0.5054
# Epoch 122/2048
# 8s - loss: 0.4774 - val_loss: 0.5047
# Epoch 123/2048
# 6s - loss: 0.4769 - val_loss: 0.5048
# Epoch 124/2048
# 9s - loss: 0.4763 - val_loss: 0.5036
# Epoch 125/2048
# 9s - loss: 0.4758 - val_loss: 0.5029
# Epoch 126/2048
# 6s - loss: 0.4752 - val_loss: 0.5035
# Epoch 127/2048
# 9s - loss: 0.4746 - val_loss: 0.5027
# Epoch 128/2048
# 9s - loss: 0.4740 - val_loss: 0.5024
# Epoch 129/2048
# 8s - loss: 0.4734 - val_loss: 0.5020
# Epoch 130/2048
# 9s - loss: 0.4728 - val_loss: 0.5005
# Epoch 131/2048
# 10s - loss: 0.4721 - val_loss: 0.4993
# Epoch 132/2048
# 6s - loss: 0.4715 - val_loss: 0.4994
# Epoch 133/2048
# 9s - loss: 0.4709 - val_loss: 0.4985
# Epoch 134/2048
# 9s - loss: 0.4703 - val_loss: 0.4978
# Epoch 135/2048
# 9s - loss: 0.4697 - val_loss: 0.4976
# Epoch 136/2048
# 8s - loss: 0.4692 - val_loss: 0.4967
# Epoch 137/2048
# 8s - loss: 0.4687 - val_loss: 0.4957
# Epoch 138/2048
# 8s - loss: 0.4682 - val_loss: 0.4951
# Epoch 139/2048
# 6s - loss: 0.4677 - val_loss: 0.4957
# Epoch 140/2048
# 9s - loss: 0.4673 - val_loss: 0.4946
# Epoch 141/2048
# 6s - loss: 0.4668 - val_loss: 0.4948
# Epoch 142/2048
# 10s - loss: 0.4664 - val_loss: 0.4939
# Epoch 143/2048
# 8s - loss: 0.4659 - val_loss: 0.4936
# Epoch 144/2048
# 8s - loss: 0.4655 - val_loss: 0.4932
# Epoch 145/2048
# 10s - loss: 0.4651 - val_loss: 0.4926
# Epoch 146/2048
# 8s - loss: 0.4646 - val_loss: 0.4919
# Epoch 147/2048
# 8s - loss: 0.4642 - val_loss: 0.4917
# Epoch 148/2048
# 6s - loss: 0.4638 - val_loss: 0.4920
# Epoch 149/2048
# 8s - loss: 0.4634 - val_loss: 0.4906
# Epoch 150/2048
# 6s - loss: 0.4630 - val_loss: 0.4909
# Epoch 151/2048
# 8s - loss: 0.4626 - val_loss: 0.4899
# Epoch 152/2048
# 6s - loss: 0.4622 - val_loss: 0.4902
# Epoch 153/2048
# 6s - loss: 0.4619 - val_loss: 0.4899
# Epoch 154/2048
# 8s - loss: 0.4615 - val_loss: 0.4887
# Epoch 155/2048
# 6s - loss: 0.4611 - val_loss: 0.4887
# Epoch 156/2048
# 8s - loss: 0.4607 - val_loss: 0.4885
# Epoch 157/2048
# 8s - loss: 0.4603 - val_loss: 0.4878
# Epoch 158/2048
# 9s - loss: 0.4600 - val_loss: 0.4877
# Epoch 159/2048
# 9s - loss: 0.4596 - val_loss: 0.4875
# Epoch 160/2048
# 8s - loss: 0.4592 - val_loss: 0.4867
# Epoch 161/2048
# 8s - loss: 0.4588 - val_loss: 0.4859
# Epoch 162/2048
# 8s - loss: 0.4584 - val_loss: 0.4857
# Epoch 163/2048
# 6s - loss: 0.4581 - val_loss: 0.4859
# Epoch 164/2048
# 11s - loss: 0.4577 - val_loss: 0.4848
# Epoch 165/2048
# 6s - loss: 0.4574 - val_loss: 0.4851
# Epoch 166/2048
# 6s - loss: 0.4570 - val_loss: 0.4855
# Epoch 167/2048
# 6s - loss: 0.4567 - val_loss: 0.4850
# Epoch 168/2048
# 8s - loss: 0.4563 - val_loss: 0.4840
# Epoch 169/2048
# 8s - loss: 0.4559 - val_loss: 0.4839
# Epoch 170/2048
# 9s - loss: 0.4554 - val_loss: 0.4830
# Epoch 171/2048
# 6s - loss: 0.4550 - val_loss: 0.4834
# Epoch 172/2048
# 6s - loss: 0.4546 - val_loss: 0.4834
# Epoch 173/2048
# 8s - loss: 0.4542 - val_loss: 0.4825
# Epoch 174/2048
# 9s - loss: 0.4538 - val_loss: 0.4823
# Epoch 175/2048
# 8s - loss: 0.4533 - val_loss: 0.4807
# Epoch 176/2048
# 9s - loss: 0.4529 - val_loss: 0.4805
# Epoch 177/2048
# 8s - loss: 0.4525 - val_loss: 0.4804
# Epoch 178/2048
# 8s - loss: 0.4520 - val_loss: 0.4802
# Epoch 179/2048
# 8s - loss: 0.4516 - val_loss: 0.4799
# Epoch 180/2048
# 9s - loss: 0.4512 - val_loss: 0.4790
# Epoch 181/2048
# 9s - loss: 0.4508 - val_loss: 0.4785
# Epoch 182/2048
# 8s - loss: 0.4503 - val_loss: 0.4783
# Epoch 183/2048
# 6s - loss: 0.4500 - val_loss: 0.4784
# Epoch 184/2048
# 10s - loss: 0.4496 - val_loss: 0.4782
# Epoch 185/2048
# 9s - loss: 0.4493 - val_loss: 0.4772
# Epoch 186/2048
# 6s - loss: 0.4489 - val_loss: 0.4786
# Epoch 187/2048
# 9s - loss: 0.4486 - val_loss: 0.4764
# Epoch 188/2048
# 8s - loss: 0.4482 - val_loss: 0.4763
# Epoch 189/2048
# 8s - loss: 0.4479 - val_loss: 0.4760
# Epoch 190/2048
# 8s - loss: 0.4476 - val_loss: 0.4754
# Epoch 191/2048
# 8s - loss: 0.4472 - val_loss: 0.4749
# Epoch 192/2048
# 8s - loss: 0.4469 - val_loss: 0.4748
# Epoch 193/2048
# 8s - loss: 0.4465 - val_loss: 0.4745
# Epoch 194/2048
# 8s - loss: 0.4461 - val_loss: 0.4740
# Epoch 195/2048
# 9s - loss: 0.4458 - val_loss: 0.4739
# Epoch 196/2048
# 9s - loss: 0.4453 - val_loss: 0.4729
# Epoch 197/2048
# 6s - loss: 0.4449 - val_loss: 0.4732
# Epoch 198/2048
# 8s - loss: 0.4446 - val_loss: 0.4726
# Epoch 199/2048
# 8s - loss: 0.4442 - val_loss: 0.4717
# Epoch 200/2048
# 8s - loss: 0.4439 - val_loss: 0.4714
# Epoch 201/2048
# 6s - loss: 0.4435 - val_loss: 0.4719
# Epoch 202/2048
# 8s - loss: 0.4431 - val_loss: 0.4712
# Epoch 203/2048
# 9s - loss: 0.4427 - val_loss: 0.4711
# Epoch 204/2048
# 8s - loss: 0.4424 - val_loss: 0.4706
# Epoch 205/2048
# 9s - loss: 0.4420 - val_loss: 0.4703
# Epoch 206/2048
# 9s - loss: 0.4416 - val_loss: 0.4695
# Epoch 207/2048
# 8s - loss: 0.4413 - val_loss: 0.4694
# Epoch 208/2048
# 10s - loss: 0.4409 - val_loss: 0.4685
# Epoch 209/2048
# 8s - loss: 0.4405 - val_loss: 0.4685
# Epoch 210/2048
# 6s - loss: 0.4401 - val_loss: 0.4686
# Epoch 211/2048
# 6s - loss: 0.4397 - val_loss: 0.4688
# Epoch 212/2048
# 8s - loss: 0.4393 - val_loss: 0.4669
# Epoch 213/2048
# 8s - loss: 0.4390 - val_loss: 0.4663
# Epoch 214/2048
# 6s - loss: 0.4386 - val_loss: 0.4666
# Epoch 215/2048
# 8s - loss: 0.4382 - val_loss: 0.4658
# Epoch 216/2048
# 9s - loss: 0.4379 - val_loss: 0.4655
# Epoch 217/2048
# 8s - loss: 0.4376 - val_loss: 0.4653
# Epoch 218/2048
# 8s - loss: 0.4373 - val_loss: 0.4646
# Epoch 219/2048
# 6s - loss: 0.4370 - val_loss: 0.4654
# Epoch 220/2048
# 8s - loss: 0.4367 - val_loss: 0.4637
# Epoch 221/2048
# 6s - loss: 0.4365 - val_loss: 0.4646
# Epoch 222/2048
# 6s - loss: 0.4362 - val_loss: 0.4649
# Epoch 223/2048
# 6s - loss: 0.4359 - val_loss: 0.4638
# Epoch 224/2048
# 8s - loss: 0.4356 - val_loss: 0.4636
# Epoch 225/2048
# 8s - loss: 0.4354 - val_loss: 0.4636
# Epoch 226/2048
# 8s - loss: 0.4351 - val_loss: 0.4631
# Epoch 227/2048
# 6s - loss: 0.4348 - val_loss: 0.4633
# Epoch 228/2048
# 8s - loss: 0.4346 - val_loss: 0.4628
# Epoch 229/2048
# 8s - loss: 0.4343 - val_loss: 0.4620
# Epoch 230/2048
# 8s - loss: 0.4341 - val_loss: 0.4619
# Epoch 231/2048
# 6s - loss: 0.4338 - val_loss: 0.4624
# Epoch 232/2048
# 8s - loss: 0.4336 - val_loss: 0.4615
# Epoch 233/2048
# 6s - loss: 0.4333 - val_loss: 0.4619
# Epoch 234/2048
# 6s - loss: 0.4331 - val_loss: 0.4616
# Epoch 235/2048
# 9s - loss: 0.4328 - val_loss: 0.4612
# Epoch 236/2048
# 10s - loss: 0.4326 - val_loss: 0.4606
# Epoch 237/2048
# 8s - loss: 0.4324 - val_loss: 0.4599
# Epoch 238/2048
# 6s - loss: 0.4322 - val_loss: 0.4613
# Epoch 239/2048
# 6s - loss: 0.4319 - val_loss: 0.4604
# Epoch 240/2048
# 8s - loss: 0.4317 - val_loss: 0.4596
# Epoch 241/2048
# 6s - loss: 0.4315 - val_loss: 0.4598
# Epoch 242/2048
# 8s - loss: 0.4313 - val_loss: 0.4594
# Epoch 243/2048
# 6s - loss: 0.4311 - val_loss: 0.4599
# Epoch 244/2048
# 8s - loss: 0.4309 - val_loss: 0.4591
# Epoch 245/2048
# 8s - loss: 0.4307 - val_loss: 0.4586
# Epoch 246/2048
# 6s - loss: 0.4306 - val_loss: 0.4588
# Epoch 247/2048
# 9s - loss: 0.4303 - val_loss: 0.4584
# Epoch 248/2048
# 8s - loss: 0.4301 - val_loss: 0.4582
# Epoch 249/2048
# 9s - loss: 0.4300 - val_loss: 0.4577
# Epoch 250/2048
# 6s - loss: 0.4298 - val_loss: 0.4582
# Epoch 251/2048
# 6s - loss: 0.4296 - val_loss: 0.4585
# Epoch 252/2048
# 6s - loss: 0.4295 - val_loss: 0.4577
# Epoch 253/2048
# 8s - loss: 0.4293 - val_loss: 0.4572
# Epoch 254/2048
# 6s - loss: 0.4291 - val_loss: 0.4576
# Epoch 255/2048
# 6s - loss: 0.4289 - val_loss: 0.4574
# Epoch 256/2048
# 6s - loss: 0.4288 - val_loss: 0.4575
# Epoch 257/2048
# 8s - loss: 0.4286 - val_loss: 0.4560
# Epoch 258/2048
# 6s - loss: 0.4284 - val_loss: 0.4569
# Epoch 259/2048
# 8s - loss: 0.4283 - val_loss: 0.4557
# Epoch 260/2048
# 6s - loss: 0.4281 - val_loss: 0.4564
# Epoch 261/2048
# 6s - loss: 0.4279 - val_loss: 0.4562
# Epoch 262/2048
# 8s - loss: 0.4278 - val_loss: 0.4557
# Epoch 263/2048
# 9s - loss: 0.4276 - val_loss: 0.4556
# Epoch 264/2048
# 6s - loss: 0.4274 - val_loss: 0.4563
# Epoch 265/2048
# 9s - loss: 0.4273 - val_loss: 0.4550
# Epoch 266/2048
# 9s - loss: 0.4271 - val_loss: 0.4549
# Epoch 267/2048
# 8s - loss: 0.4270 - val_loss: 0.4549
# Epoch 268/2048
# 8s - loss: 0.4268 - val_loss: 0.4545
# Epoch 269/2048
# 6s - loss: 0.4266 - val_loss: 0.4547
# Epoch 270/2048
# 8s - loss: 0.4264 - val_loss: 0.4541
# Epoch 271/2048
# 6s - loss: 0.4263 - val_loss: 0.4544
# Epoch 272/2048
# 6s - loss: 0.4261 - val_loss: 0.4549
# Epoch 273/2048
# 9s - loss: 0.4259 - val_loss: 0.4540
# Epoch 274/2048
# 8s - loss: 0.4257 - val_loss: 0.4534
# Epoch 275/2048
# 6s - loss: 0.4254 - val_loss: 0.4541
# Epoch 276/2048
# 6s - loss: 0.4252 - val_loss: 0.4535
# Epoch 277/2048
# 8s - loss: 0.4250 - val_loss: 0.4533
# Epoch 278/2048
# 6s - loss: 0.4248 - val_loss: 0.4539
# Epoch 279/2048
# 8s - loss: 0.4246 - val_loss: 0.4531
# Epoch 280/2048
# 9s - loss: 0.4245 - val_loss: 0.4531
# Epoch 281/2048
# 6s - loss: 0.4243 - val_loss: 0.4532
# Epoch 282/2048
# 8s - loss: 0.4241 - val_loss: 0.4526
# Epoch 283/2048
# 6s - loss: 0.4239 - val_loss: 0.4526
# Epoch 284/2048
# 6s - loss: 0.4237 - val_loss: 0.4526
# Epoch 285/2048
# 8s - loss: 0.4235 - val_loss: 0.4522
# Epoch 286/2048
# 10s - loss: 0.4234 - val_loss: 0.4518
# Epoch 287/2048
# 6s - loss: 0.4232 - val_loss: 0.4518
# Epoch 288/2048
# 6s - loss: 0.4230 - val_loss: 0.4522
# Epoch 289/2048
# 8s - loss: 0.4228 - val_loss: 0.4509
# Epoch 290/2048
# 6s - loss: 0.4226 - val_loss: 0.4510
# Epoch 291/2048
# 9s - loss: 0.4224 - val_loss: 0.4509
# Epoch 292/2048
# 6s - loss: 0.4222 - val_loss: 0.4510
# Epoch 293/2048
# 9s - loss: 0.4220 - val_loss: 0.4505
# Epoch 294/2048
# 6s - loss: 0.4218 - val_loss: 0.4506
# Epoch 295/2048
# 8s - loss: 0.4216 - val_loss: 0.4501
# Epoch 296/2048
# 6s - loss: 0.4215 - val_loss: 0.4504
# Epoch 297/2048
# 9s - loss: 0.4213 - val_loss: 0.4493
# Epoch 298/2048
# 8s - loss: 0.4211 - val_loss: 0.4493
# Epoch 299/2048
# 6s - loss: 0.4209 - val_loss: 0.4496
# Epoch 300/2048
# 8s - loss: 0.4208 - val_loss: 0.4492
# Epoch 301/2048
# 6s - loss: 0.4206 - val_loss: 0.4493
# Epoch 302/2048
# 8s - loss: 0.4205 - val_loss: 0.4488
# Epoch 303/2048
# 6s - loss: 0.4203 - val_loss: 0.4490
# Epoch 304/2048
# 8s - loss: 0.4202 - val_loss: 0.4486
# Epoch 305/2048
# 8s - loss: 0.4200 - val_loss: 0.4484
# Epoch 306/2048
# 6s - loss: 0.4199 - val_loss: 0.4488
# Epoch 307/2048
# 6s - loss: 0.4197 - val_loss: 0.4488
# Epoch 308/2048
# 8s - loss: 0.4196 - val_loss: 0.4479
# Epoch 309/2048
# 6s - loss: 0.4195 - val_loss: 0.4482
# Epoch 310/2048
# 6s - loss: 0.4193 - val_loss: 0.4480
# Epoch 311/2048
# 8s - loss: 0.4192 - val_loss: 0.4476
# Epoch 312/2048
# 6s - loss: 0.4191 - val_loss: 0.4478
# Epoch 313/2048
# 6s - loss: 0.4189 - val_loss: 0.4479
# Epoch 314/2048
# 6s - loss: 0.4187 - val_loss: 0.4478
# Epoch 315/2048
# 8s - loss: 0.4186 - val_loss: 0.4472
# Epoch 316/2048
# 8s - loss: 0.4184 - val_loss: 0.4470
# Epoch 317/2048
# 8s - loss: 0.4182 - val_loss: 0.4470
# Epoch 318/2048
# 6s - loss: 0.4180 - val_loss: 0.4470
# Epoch 319/2048
# 8s - loss: 0.4178 - val_loss: 0.4464
# Epoch 320/2048
# 6s - loss: 0.4175 - val_loss: 0.4467
# Epoch 321/2048
# 8s - loss: 0.4173 - val_loss: 0.4459
# Epoch 322/2048
# 8s - loss: 0.4170 - val_loss: 0.4455
# Epoch 323/2048
# 6s - loss: 0.4168 - val_loss: 0.4455
# Epoch 324/2048
# 10s - loss: 0.4165 - val_loss: 0.4446
# Epoch 325/2048
# 6s - loss: 0.4163 - val_loss: 0.4447
# Epoch 326/2048
# 8s - loss: 0.4161 - val_loss: 0.4444
# Epoch 327/2048
# 8s - loss: 0.4159 - val_loss: 0.4442
# Epoch 328/2048
# 8s - loss: 0.4157 - val_loss: 0.4441
# Epoch 329/2048
# 9s - loss: 0.4155 - val_loss: 0.4439
# Epoch 330/2048
# 8s - loss: 0.4152 - val_loss: 0.4439
# Epoch 331/2048
# 9s - loss: 0.4148 - val_loss: 0.4435
# Epoch 332/2048
# 8s - loss: 0.4145 - val_loss: 0.4430
# Epoch 333/2048
# 8s - loss: 0.4144 - val_loss: 0.4424
# Epoch 334/2048
# 8s - loss: 0.4142 - val_loss: 0.4422
# Epoch 335/2048
# 8s - loss: 0.4140 - val_loss: 0.4418
# Epoch 336/2048
# 8s - loss: 0.4139 - val_loss: 0.4418
# Epoch 337/2048
# 6s - loss: 0.4137 - val_loss: 0.4424
# Epoch 338/2048
# 6s - loss: 0.4136 - val_loss: 0.4420
# Epoch 339/2048
# 8s - loss: 0.4134 - val_loss: 0.4415
# Epoch 340/2048
# 8s - loss: 0.4133 - val_loss: 0.4411
# Epoch 341/2048
# 8s - loss: 0.4132 - val_loss: 0.4407
# Epoch 342/2048
# 6s - loss: 0.4130 - val_loss: 0.4409
# Epoch 343/2048
# 6s - loss: 0.4129 - val_loss: 0.4435
# Epoch 344/2048
# 6s - loss: 0.4129 - val_loss: 0.4410
# Epoch 345/2048
# 6s - loss: 0.4127 - val_loss: 0.4412
# Epoch 346/2048
# 6s - loss: 0.4125 - val_loss: 0.4412
# Epoch 347/2048
# 6s - loss: 0.4124 - val_loss: 0.4410
# Epoch 348/2048
# 6s - loss: 0.4123 - val_loss: 0.4410
# Epoch 349/2048
# 8s - loss: 0.4122 - val_loss: 0.4407
# Epoch 350/2048
# 6s - loss: 0.4121 - val_loss: 0.4408
# Epoch 351/2048
# 8s - loss: 0.4119 - val_loss: 0.4401
# Epoch 352/2048
# 8s - loss: 0.4118 - val_loss: 0.4400
# Epoch 353/2048
# 8s - loss: 0.4118 - val_loss: 0.4399
# Epoch 354/2048
# 8s - loss: 0.4116 - val_loss: 0.4396
# Epoch 355/2048
# 9s - loss: 0.4115 - val_loss: 0.4396
# Epoch 356/2048
# 6s - loss: 0.4114 - val_loss: 0.4399
# Epoch 357/2048
# 6s - loss: 0.4113 - val_loss: 0.4399
# Epoch 358/2048
# 6s - loss: 0.4112 - val_loss: 0.4399
# Epoch 359/2048
# 8s - loss: 0.4111 - val_loss: 0.4392
# Epoch 360/2048
# 6s - loss: 0.4111 - val_loss: 0.4397
# Epoch 361/2048
# 6s - loss: 0.4110 - val_loss: 0.4392
# Epoch 362/2048
# 6s - loss: 0.4109 - val_loss: 0.4392
# Epoch 363/2048
# 8s - loss: 0.4108 - val_loss: 0.4387
# Epoch 364/2048
# 6s - loss: 0.4107 - val_loss: 0.4390
# Epoch 365/2048
# 6s - loss: 0.4106 - val_loss: 0.4389
# Epoch 366/2048
# 6s - loss: 0.4105 - val_loss: 0.4395
# Epoch 367/2048
# 6s - loss: 0.4104 - val_loss: 0.4390
# Epoch 368/2048
# 8s - loss: 0.4103 - val_loss: 0.4386
# Epoch 369/2048
# 8s - loss: 0.4102 - val_loss: 0.4383
# Epoch 370/2048
# 6s - loss: 0.4101 - val_loss: 0.4388
# Epoch 371/2048
# 8s - loss: 0.4100 - val_loss: 0.4379
# Epoch 372/2048
# 6s - loss: 0.4100 - val_loss: 0.4380
# Epoch 373/2048
# 6s - loss: 0.4098 - val_loss: 0.4383
# Epoch 374/2048
# 6s - loss: 0.4098 - val_loss: 0.4385
# Epoch 375/2048
# 7s - loss: 0.4097 - val_loss: 0.4378
# Epoch 376/2048
# 7s - loss: 0.4096 - val_loss: 0.4377
# Epoch 377/2048
# 6s - loss: 0.4095 - val_loss: 0.4383
# Epoch 378/2048
# 9s - loss: 0.4094 - val_loss: 0.4376
# Epoch 379/2048
# 6s - loss: 0.4093 - val_loss: 0.4376
# Epoch 380/2048
# 9s - loss: 0.4093 - val_loss: 0.4374
# Epoch 381/2048
# 8s - loss: 0.4092 - val_loss: 0.4373
# Epoch 382/2048
# 6s - loss: 0.4091 - val_loss: 0.4374
# Epoch 383/2048
# 8s - loss: 0.4090 - val_loss: 0.4371
# Epoch 384/2048
# 8s - loss: 0.4089 - val_loss: 0.4370
# Epoch 385/2048
# 8s - loss: 0.4089 - val_loss: 0.4369
# Epoch 386/2048
# 6s - loss: 0.4088 - val_loss: 0.4369
# Epoch 387/2048
# 6s - loss: 0.4087 - val_loss: 0.4374
# Epoch 388/2048
# 6s - loss: 0.4086 - val_loss: 0.4369
# Epoch 389/2048
# 6s - loss: 0.4086 - val_loss: 0.4374
# Epoch 390/2048
# 9s - loss: 0.4085 - val_loss: 0.4365
# Epoch 391/2048
# 8s - loss: 0.4084 - val_loss: 0.4362
# Epoch 392/2048
# 6s - loss: 0.4084 - val_loss: 0.4373
# Epoch 393/2048
# 6s - loss: 0.4083 - val_loss: 0.4373
# Epoch 394/2048
# 8s - loss: 0.4082 - val_loss: 0.4362
# Epoch 395/2048
# 6s - loss: 0.4081 - val_loss: 0.4364
# Epoch 396/2048
# 8s - loss: 0.4080 - val_loss: 0.4360
# Epoch 397/2048
# 6s - loss: 0.4080 - val_loss: 0.4365
# Epoch 398/2048
# 9s - loss: 0.4079 - val_loss: 0.4360
# Epoch 399/2048
# 6s - loss: 0.4078 - val_loss: 0.4366
# Epoch 400/2048
# 6s - loss: 0.4078 - val_loss: 0.4367
# Epoch 401/2048
# 6s - loss: 0.4078 - val_loss: 0.4361
# Epoch 402/2048
# 8s - loss: 0.4076 - val_loss: 0.4358
# Epoch 403/2048
# 7s - loss: 0.4076 - val_loss: 0.4357
# Epoch 404/2048
# 6s - loss: 0.4075 - val_loss: 0.4361
# Epoch 405/2048
# 6s - loss: 0.4075 - val_loss: 0.4363
# Epoch 406/2048
# 6s - loss: 0.4074 - val_loss: 0.4357
# Epoch 407/2048
# 9s - loss: 0.4074 - val_loss: 0.4354
# Epoch 408/2048
# 6s - loss: 0.4073 - val_loss: 0.4360
# Epoch 409/2048
# 6s - loss: 0.4073 - val_loss: 0.4356
# Epoch 410/2048
# 6s - loss: 0.4072 - val_loss: 0.4358
# Epoch 411/2048
# 6s - loss: 0.4071 - val_loss: 0.4358
# Epoch 412/2048
# 6s - loss: 0.4071 - val_loss: 0.4360
# Epoch 413/2048
# 8s - loss: 0.4070 - val_loss: 0.4346
# Epoch 414/2048
# 6s - loss: 0.4070 - val_loss: 0.4354
# Epoch 415/2048
# 6s - loss: 0.4069 - val_loss: 0.4350
# Epoch 416/2048
# 6s - loss: 0.4069 - val_loss: 0.4350
# Epoch 417/2048
# 6s - loss: 0.4068 - val_loss: 0.4352
# Epoch 418/2048
# 6s - loss: 0.4067 - val_loss: 0.4350
# Epoch 419/2048
# 6s - loss: 0.4066 - val_loss: 0.4354
# Epoch 420/2048
# 6s - loss: 0.4066 - val_loss: 0.4351
# Epoch 421/2048
# 6s - loss: 0.4066 - val_loss: 0.4348
# Epoch 422/2048
# 6s - loss: 0.4065 - val_loss: 0.4354
# Epoch 423/2048
# 8s - loss: 0.4065 - val_loss: 0.4346
# Epoch 424/2048
# 6s - loss: 0.4064 - val_loss: 0.4347
# Epoch 425/2048
# 6s - loss: 0.4063 - val_loss: 0.4347
# Epoch 426/2048
# 8s - loss: 0.4063 - val_loss: 0.4346
# Epoch 427/2048
# 8s - loss: 0.4062 - val_loss: 0.4343
# Epoch 428/2048
# 6s - loss: 0.4062 - val_loss: 0.4350
# Epoch 429/2048
# 6s - loss: 0.4062 - val_loss: 0.4349
# Epoch 430/2048
# 7s - loss: 0.4061 - val_loss: 0.4340
# Epoch 431/2048
# 6s - loss: 0.4060 - val_loss: 0.4341
# Epoch 432/2048
# 6s - loss: 0.4059 - val_loss: 0.4345
# Epoch 433/2048
# 6s - loss: 0.4059 - val_loss: 0.4344
# Epoch 434/2048
# 6s - loss: 0.4059 - val_loss: 0.4350
# Epoch 435/2048
# 9s - loss: 0.4058 - val_loss: 0.4335
# Epoch 436/2048
# 6s - loss: 0.4058 - val_loss: 0.4340
# Epoch 437/2048
# 6s - loss: 0.4057 - val_loss: 0.4343
# Epoch 438/2048
# 6s - loss: 0.4056 - val_loss: 0.4339
# Epoch 439/2048
# 6s - loss: 0.4056 - val_loss: 0.4337
# Epoch 440/2048
# 6s - loss: 0.4055 - val_loss: 0.4341
# Epoch 441/2048
# 6s - loss: 0.4055 - val_loss: 0.4340
# Epoch 442/2048
# 8s - loss: 0.4054 - val_loss: 0.4331
# Epoch 443/2048
# 6s - loss: 0.4054 - val_loss: 0.4342
# Epoch 444/2048
# 6s - loss: 0.4053 - val_loss: 0.4335
# Epoch 445/2048
# 6s - loss: 0.4053 - val_loss: 0.4338
# Epoch 446/2048
# 6s - loss: 0.4052 - val_loss: 0.4333
# Epoch 447/2048
# 6s - loss: 0.4052 - val_loss: 0.4340
# Epoch 448/2048
# 7s - loss: 0.4051 - val_loss: 0.4329
# Epoch 449/2048
# 6s - loss: 0.4051 - val_loss: 0.4335
# Epoch 450/2048
# 6s - loss: 0.4050 - val_loss: 0.4335
# Epoch 451/2048
# 6s - loss: 0.4050 - val_loss: 0.4340
# Epoch 452/2048
# 6s - loss: 0.4050 - val_loss: 0.4337
# Epoch 453/2048
# 6s - loss: 0.4049 - val_loss: 0.4335
# Epoch 454/2048
# 6s - loss: 0.4048 - val_loss: 0.4330
# Epoch 455/2048
# 6s - loss: 0.4048 - val_loss: 0.4339
# Epoch 456/2048
# 6s - loss: 0.4048 - val_loss: 0.4330
# Epoch 457/2048
# 6s - loss: 0.4047 - val_loss: 0.4330
# Epoch 458/2048
# 6s - loss: 0.4047 - val_loss: 0.4335
# Epoch 459/2048
# 6s - loss: 0.4047 - val_loss: 0.4334
# Epoch 460/2048
# 6s - loss: 0.4046 - val_loss: 0.4330
# Epoch 461/2048
# 6s - loss: 0.4046 - val_loss: 0.4330
# Epoch 462/2048
# 8s - loss: 0.4045 - val_loss: 0.4327
# Epoch 463/2048
# 6s - loss: 0.4045 - val_loss: 0.4330
# Epoch 464/2048
# 6s - loss: 0.4044 - val_loss: 0.4334
# Epoch 465/2048
# 6s - loss: 0.4044 - val_loss: 0.4329
# Epoch 466/2048
# 9s - loss: 0.4043 - val_loss: 0.4325
# Epoch 467/2048
# 6s - loss: 0.4043 - val_loss: 0.4363
# Epoch 468/2048
# 7s - loss: 0.4044 - val_loss: 0.4321
# Epoch 469/2048
# 6s - loss: 0.4042 - val_loss: 0.4328
# Epoch 470/2048
# 6s - loss: 0.4042 - val_loss: 0.4328
# Epoch 471/2048
# 6s - loss: 0.4041 - val_loss: 0.4321
# Epoch 472/2048
# 6s - loss: 0.4041 - val_loss: 0.4328
# Epoch 473/2048
# 6s - loss: 0.4041 - val_loss: 0.4324
# Epoch 474/2048
# 6s - loss: 0.4040 - val_loss: 0.4326
# Epoch 475/2048
# 6s - loss: 0.4039 - val_loss: 0.4324
# Epoch 476/2048
# 6s - loss: 0.4039 - val_loss: 0.4323
# Epoch 477/2048
# 6s - loss: 0.4039 - val_loss: 0.4325
# Epoch 478/2048
# 6s - loss: 0.4038 - val_loss: 0.4344
# Epoch 479/2048
# 6s - loss: 0.4040 - val_loss: 0.4327
# Epoch 480/2048
# 7s - loss: 0.4037 - val_loss: 0.4321
# Epoch 481/2048
# 7s - loss: 0.4037 - val_loss: 0.4318
# Epoch 482/2048
# 6s - loss: 0.4037 - val_loss: 0.4326
# Epoch 483/2048
# 6s - loss: 0.4037 - val_loss: 0.4325
# Epoch 484/2048
# 6s - loss: 0.4036 - val_loss: 0.4326
# Epoch 485/2048
# 6s - loss: 0.4036 - val_loss: 0.4323
# Epoch 486/2048
# 6s - loss: 0.4035 - val_loss: 0.4320
# Epoch 487/2048
# 6s - loss: 0.4035 - val_loss: 0.4321
# Epoch 488/2048
# 6s - loss: 0.4035 - val_loss: 0.4323
# Epoch 489/2048
# 6s - loss: 0.4034 - val_loss: 0.4320
# Epoch 490/2048
# 9s - loss: 0.4033 - val_loss: 0.4316
# Epoch 491/2048
# 6s - loss: 0.4033 - val_loss: 0.4320
# Epoch 492/2048
# 6s - loss: 0.4033 - val_loss: 0.4322
# Epoch 493/2048
# 6s - loss: 0.4033 - val_loss: 0.4317
# Epoch 494/2048
# 8s - loss: 0.4032 - val_loss: 0.4315
# Epoch 495/2048
# 6s - loss: 0.4032 - val_loss: 0.4321
# Epoch 496/2048
# 6s - loss: 0.4032 - val_loss: 0.4315
# Epoch 497/2048
# 6s - loss: 0.4031 - val_loss: 0.4316
# Epoch 498/2048
# 6s - loss: 0.4031 - val_loss: 0.4316
# Epoch 499/2048
# 6s - loss: 0.4031 - val_loss: 0.4330
# Epoch 500/2048
# 6s - loss: 0.4030 - val_loss: 0.4316
# Epoch 501/2048
# 6s - loss: 0.4030 - val_loss: 0.4320
# Epoch 502/2048
# 6s - loss: 0.4029 - val_loss: 0.4316
# Epoch 503/2048
# 6s - loss: 0.4029 - val_loss: 0.4321
# Epoch 504/2048
# 6s - loss: 0.4029 - val_loss: 0.4317
# Epoch 505/2048
# 8s - loss: 0.4028 - val_loss: 0.4314
# Epoch 506/2048
# 6s - loss: 0.4028 - val_loss: 0.4316
# Epoch 507/2048
# 6s - loss: 0.4028 - val_loss: 0.4319
# Epoch 508/2048
# 8s - loss: 0.4027 - val_loss: 0.4312
# Epoch 509/2048
# 6s - loss: 0.4027 - val_loss: 0.4321
# Epoch 510/2048
# 9s - loss: 0.4026 - val_loss: 0.4311
# Epoch 511/2048
# 6s - loss: 0.4026 - val_loss: 0.4315
# Epoch 512/2048
# 6s - loss: 0.4025 - val_loss: 0.4314
# Epoch 513/2048
# 6s - loss: 0.4025 - val_loss: 0.4316
# Epoch 514/2048
# 8s - loss: 0.4024 - val_loss: 0.4306
# Epoch 515/2048
# 6s - loss: 0.4025 - val_loss: 0.4312
# Epoch 516/2048
# 8s - loss: 0.4024 - val_loss: 0.4306
# Epoch 517/2048
# 6s - loss: 0.4024 - val_loss: 0.4311
# Epoch 518/2048
# 6s - loss: 0.4024 - val_loss: 0.4308
# Epoch 519/2048
# 6s - loss: 0.4023 - val_loss: 0.4310
# Epoch 520/2048
# 6s - loss: 0.4023 - val_loss: 0.4313
# Epoch 521/2048
# 6s - loss: 0.4022 - val_loss: 0.4311
# Epoch 522/2048
# 6s - loss: 0.4022 - val_loss: 0.4316
# Epoch 523/2048
# 6s - loss: 0.4022 - val_loss: 0.4310
# Epoch 524/2048
# 6s - loss: 0.4021 - val_loss: 0.4311
# Epoch 525/2048
# 8s - loss: 0.4021 - val_loss: 0.4304
# Epoch 526/2048
# 6s - loss: 0.4021 - val_loss: 0.4309
# Epoch 527/2048
# 6s - loss: 0.4020 - val_loss: 0.4310
# Epoch 528/2048
# 6s - loss: 0.4021 - val_loss: 0.4311
# Epoch 529/2048
# 6s - loss: 0.4020 - val_loss: 0.4308
# Epoch 530/2048
# 6s - loss: 0.4019 - val_loss: 0.4306
# Epoch 531/2048
# 6s - loss: 0.4019 - val_loss: 0.4307
# Epoch 532/2048
# 6s - loss: 0.4019 - val_loss: 0.4304
# Epoch 533/2048
# 6s - loss: 0.4018 - val_loss: 0.4308
# Epoch 534/2048
# 6s - loss: 0.4018 - val_loss: 0.4307
# Epoch 535/2048
# 8s - loss: 0.4018 - val_loss: 0.4302
# Epoch 536/2048
# 6s - loss: 0.4017 - val_loss: 0.4314
# Epoch 537/2048
# 6s - loss: 0.4017 - val_loss: 0.4310
# Epoch 538/2048
# 6s - loss: 0.4017 - val_loss: 0.4304
# Epoch 539/2048
# 6s - loss: 0.4017 - val_loss: 0.4310
# Epoch 540/2048
# 6s - loss: 0.4016 - val_loss: 0.4309
# Epoch 541/2048
# 6s - loss: 0.4016 - val_loss: 0.4311
# Epoch 542/2048
# 6s - loss: 0.4015 - val_loss: 0.4308
# Epoch 543/2048
# 6s - loss: 0.4015 - val_loss: 0.4303
# Epoch 544/2048
# 8s - loss: 0.4015 - val_loss: 0.4301
# Epoch 545/2048
# 6s - loss: 0.4015 - val_loss: 0.4304
# Epoch 546/2048
# 6s - loss: 0.4014 - val_loss: 0.4308
# Epoch 547/2048
# 6s - loss: 0.4014 - val_loss: 0.4309
# Epoch 548/2048
# 6s - loss: 0.4014 - val_loss: 0.4306
# Epoch 549/2048
# 8s - loss: 0.4013 - val_loss: 0.4298
# Epoch 550/2048
# 6s - loss: 0.4012 - val_loss: 0.4307
# Epoch 551/2048
# 6s - loss: 0.4013 - val_loss: 0.4301
# Epoch 552/2048
# 6s - loss: 0.4012 - val_loss: 0.4305
# Epoch 553/2048
# 6s - loss: 0.4012 - val_loss: 0.4307
# Epoch 554/2048
# 8s - loss: 0.4012 - val_loss: 0.4295
# Epoch 555/2048
# 6s - loss: 0.4011 - val_loss: 0.4307
# Epoch 556/2048
# 6s - loss: 0.4011 - val_loss: 0.4297
# Epoch 557/2048
# 6s - loss: 0.4011 - val_loss: 0.4304
# Epoch 558/2048
# 6s - loss: 0.4010 - val_loss: 0.4304
# Epoch 559/2048
# 6s - loss: 0.4010 - val_loss: 0.4299
# Epoch 560/2048
# 6s - loss: 0.4010 - val_loss: 0.4307
# Epoch 561/2048
# 6s - loss: 0.4009 - val_loss: 0.4298
# Epoch 562/2048
# 6s - loss: 0.4009 - val_loss: 0.4299
# Epoch 563/2048
# 6s - loss: 0.4009 - val_loss: 0.4297
# Epoch 564/2048
# 6s - loss: 0.4009 - val_loss: 0.4299
# Epoch 565/2048
# 6s - loss: 0.4008 - val_loss: 0.4305
# Epoch 566/2048
# 8s - loss: 0.4008 - val_loss: 0.4292
# Epoch 567/2048
# 6s - loss: 0.4008 - val_loss: 0.4299
# Epoch 568/2048
# 6s - loss: 0.4007 - val_loss: 0.4304
# Epoch 569/2048
# 6s - loss: 0.4008 - val_loss: 0.4294
# Epoch 570/2048
# 6s - loss: 0.4007 - val_loss: 0.4293
# Epoch 571/2048
# 6s - loss: 0.4006 - val_loss: 0.4299
# Epoch 572/2048
# 8s - loss: 0.4007 - val_loss: 0.4291
# Epoch 573/2048
# 6s - loss: 0.4006 - val_loss: 0.4295
# Epoch 574/2048
# 6s - loss: 0.4006 - val_loss: 0.4304
# Epoch 575/2048
# 6s - loss: 0.4005 - val_loss: 0.4299
# Epoch 576/2048
# 6s - loss: 0.4005 - val_loss: 0.4299
# Epoch 577/2048
# 6s - loss: 0.4005 - val_loss: 0.4298
# Epoch 578/2048
# 6s - loss: 0.4005 - val_loss: 0.4296
# Epoch 579/2048
# 6s - loss: 0.4004 - val_loss: 0.4296
# Epoch 580/2048
# 6s - loss: 0.4004 - val_loss: 0.4295
# Epoch 581/2048
# 6s - loss: 0.4003 - val_loss: 0.4299
# Epoch 582/2048
# 6s - loss: 0.4003 - val_loss: 0.4296
# Epoch 583/2048
# 6s - loss: 0.4003 - val_loss: 0.4302
# Epoch 584/2048
# 6s - loss: 0.4003 - val_loss: 0.4294
# Epoch 585/2048
# 6s - loss: 0.4002 - val_loss: 0.4295
# Epoch 586/2048
# 6s - loss: 0.4003 - val_loss: 0.4295
# Epoch 587/2048
# 6s - loss: 0.4002 - val_loss: 0.4300
# Epoch 588/2048
# 8s - loss: 0.4002 - val_loss: 0.4290
# Epoch 589/2048
# 8s - loss: 0.4001 - val_loss: 0.4290
# Epoch 590/2048
# 8s - loss: 0.4001 - val_loss: 0.4290
# Epoch 591/2048
# 6s - loss: 0.4000 - val_loss: 0.4290
# Epoch 592/2048
# 6s - loss: 0.4000 - val_loss: 0.4294
# Epoch 593/2048
# 10s - loss: 0.4000 - val_loss: 0.4288
# Epoch 594/2048
# 6s - loss: 0.4000 - val_loss: 0.4297
# Epoch 595/2048
# 6s - loss: 0.4000 - val_loss: 0.4295
# Epoch 596/2048
# 8s - loss: 0.3999 - val_loss: 0.4287
# Epoch 597/2048
# 6s - loss: 0.3999 - val_loss: 0.4296
# Epoch 598/2048
# 6s - loss: 0.4000 - val_loss: 0.4292
# Epoch 599/2048
# 6s - loss: 0.3999 - val_loss: 0.4298
# Epoch 600/2048
# 6s - loss: 0.3998 - val_loss: 0.4290
# Epoch 601/2048
# 6s - loss: 0.3998 - val_loss: 0.4291
# Epoch 602/2048
# 8s - loss: 0.3998 - val_loss: 0.4287
# Epoch 603/2048
# 6s - loss: 0.3998 - val_loss: 0.4289
# Epoch 604/2048
# 6s - loss: 0.3997 - val_loss: 0.4290
# Epoch 605/2048
# 8s - loss: 0.3997 - val_loss: 0.4286
# Epoch 606/2048
# 6s - loss: 0.3998 - val_loss: 0.4295
# Epoch 607/2048
# 6s - loss: 0.3997 - val_loss: 0.4290
# Epoch 608/2048
# 6s - loss: 0.3996 - val_loss: 0.4293
# Epoch 609/2048
# 6s - loss: 0.3997 - val_loss: 0.4290
# Epoch 610/2048
# 6s - loss: 0.3996 - val_loss: 0.4293
# Epoch 611/2048
# 6s - loss: 0.3995 - val_loss: 0.4287
# Epoch 612/2048
# 6s - loss: 0.3995 - val_loss: 0.4291
# Epoch 613/2048
# 6s - loss: 0.3995 - val_loss: 0.4290
# Epoch 614/2048
# 6s - loss: 0.3994 - val_loss: 0.4290
# Epoch 615/2048
# 6s - loss: 0.3994 - val_loss: 0.4289
# Epoch 616/2048
# 8s - loss: 0.3994 - val_loss: 0.4280
# Epoch 617/2048
# 6s - loss: 0.3994 - val_loss: 0.4292
# Epoch 618/2048
# 6s - loss: 0.3994 - val_loss: 0.4290
# Epoch 619/2048
# 6s - loss: 0.3993 - val_loss: 0.4295
# Epoch 620/2048
# 6s - loss: 0.3993 - val_loss: 0.4285
# Epoch 621/2048
# 6s - loss: 0.3993 - val_loss: 0.4283
# Epoch 622/2048
# 6s - loss: 0.3993 - val_loss: 0.4286
# Epoch 623/2048
# 6s - loss: 0.3992 - val_loss: 0.4283
# Epoch 624/2048
# 6s - loss: 0.3992 - val_loss: 0.4293
# Epoch 625/2048
# 6s - loss: 0.3993 - val_loss: 0.4288
# Epoch 626/2048
# 6s - loss: 0.3992 - val_loss: 0.4289
# Epoch 627/2048
# 6s - loss: 0.3991 - val_loss: 0.4285
# Epoch 628/2048
# 6s - loss: 0.3991 - val_loss: 0.4286
# Epoch 629/2048
# 6s - loss: 0.3991 - val_loss: 0.4285
# Epoch 630/2048
# 6s - loss: 0.3990 - val_loss: 0.4286
# Epoch 631/2048
# 6s - loss: 0.3991 - val_loss: 0.4288
# Epoch 632/2048
# 6s - loss: 0.3990 - val_loss: 0.4287
# Epoch 633/2048
# 6s - loss: 0.3990 - val_loss: 0.4288
# Epoch 634/2048
# 6s - loss: 0.3989 - val_loss: 0.4286
# Epoch 635/2048
# 6s - loss: 0.3989 - val_loss: 0.4287
# Epoch 636/2048
# 6s - loss: 0.3989 - val_loss: 0.4285
# Epoch 637/2048
# 6s - loss: 0.3989 - val_loss: 0.4291
# Epoch 638/2048
# 6s - loss: 0.3990 - val_loss: 0.4280
# Epoch 639/2048
# 6s - loss: 0.3988 - val_loss: 0.4287
# Epoch 640/2048
# 8s - loss: 0.3988 - val_loss: 0.4278
# Epoch 641/2048
# 6s - loss: 0.3989 - val_loss: 0.4287
# Epoch 642/2048
# 6s - loss: 0.3988 - val_loss: 0.4279
# Epoch 643/2048
# 6s - loss: 0.3987 - val_loss: 0.4280
# Epoch 644/2048
# 6s - loss: 0.3987 - val_loss: 0.4286
# Epoch 645/2048
# 6s - loss: 0.3987 - val_loss: 0.4280
# Epoch 646/2048
# 6s - loss: 0.3987 - val_loss: 0.4281
# Epoch 647/2048
# 6s - loss: 0.3987 - val_loss: 0.4284
# Epoch 648/2048
# 9s - loss: 0.3987 - val_loss: 0.4277
# Epoch 649/2048
# 6s - loss: 0.3986 - val_loss: 0.4282
# Epoch 650/2048
# 6s - loss: 0.3986 - val_loss: 0.4282
# Epoch 651/2048
# 6s - loss: 0.3985 - val_loss: 0.4280
# Epoch 652/2048
# 6s - loss: 0.3985 - val_loss: 0.4282
# Epoch 653/2048
# 9s - loss: 0.3985 - val_loss: 0.4275
# Epoch 654/2048
# 6s - loss: 0.3984 - val_loss: 0.4277
# Epoch 655/2048
# 6s - loss: 0.3984 - val_loss: 0.4278
# Epoch 656/2048
# 6s - loss: 0.3983 - val_loss: 0.4282
# Epoch 657/2048
# 9s - loss: 0.3983 - val_loss: 0.4274
# Epoch 658/2048
# 6s - loss: 0.3982 - val_loss: 0.4282
# Epoch 659/2048
# 6s - loss: 0.3983 - val_loss: 0.4284
# Epoch 660/2048
# 6s - loss: 0.3982 - val_loss: 0.4275
# Epoch 661/2048
# 6s - loss: 0.3982 - val_loss: 0.4304
# Epoch 662/2048
# 6s - loss: 0.3983 - val_loss: 0.4277
# Epoch 663/2048
# 6s - loss: 0.3981 - val_loss: 0.4278
# Epoch 664/2048
# 6s - loss: 0.3981 - val_loss: 0.4277
# Epoch 665/2048
# 6s - loss: 0.3980 - val_loss: 0.4275
# Epoch 666/2048
# 6s - loss: 0.3980 - val_loss: 0.4280
# Epoch 667/2048
# 8s - loss: 0.3980 - val_loss: 0.4271
# Epoch 668/2048
# 6s - loss: 0.3980 - val_loss: 0.4272
# Epoch 669/2048
# 6s - loss: 0.3979 - val_loss: 0.4275
# Epoch 670/2048
# 6s - loss: 0.3980 - val_loss: 0.4273
# Epoch 671/2048
# 9s - loss: 0.3979 - val_loss: 0.4270
# Epoch 672/2048
# 6s - loss: 0.3978 - val_loss: 0.4280
# Epoch 673/2048
# 6s - loss: 0.3978 - val_loss: 0.4271
# Epoch 674/2048
# 8s - loss: 0.3978 - val_loss: 0.4269
# Epoch 675/2048
# 6s - loss: 0.3978 - val_loss: 0.4270
# Epoch 676/2048
# 6s - loss: 0.3977 - val_loss: 0.4276
# Epoch 677/2048
# 6s - loss: 0.3977 - val_loss: 0.4280
# Epoch 678/2048
# 6s - loss: 0.3977 - val_loss: 0.4276
# Epoch 679/2048
# 6s - loss: 0.3977 - val_loss: 0.4271
# Epoch 680/2048
# 6s - loss: 0.3978 - val_loss: 0.4273
# Epoch 681/2048
# 9s - loss: 0.3977 - val_loss: 0.4266
# Epoch 682/2048
# 6s - loss: 0.3976 - val_loss: 0.4272
# Epoch 683/2048
# 6s - loss: 0.3976 - val_loss: 0.4277
# Epoch 684/2048
# 6s - loss: 0.3976 - val_loss: 0.4270
# Epoch 685/2048
# 6s - loss: 0.3976 - val_loss: 0.4274
# Epoch 686/2048
# 6s - loss: 0.3975 - val_loss: 0.4270
# Epoch 687/2048
# 8s - loss: 0.3975 - val_loss: 0.4266
# Epoch 688/2048
# 6s - loss: 0.3974 - val_loss: 0.4270
# Epoch 689/2048
# 6s - loss: 0.3975 - val_loss: 0.4269
# Epoch 690/2048
# 6s - loss: 0.3974 - val_loss: 0.4269
# Epoch 691/2048
# 6s - loss: 0.3974 - val_loss: 0.4273
# Epoch 692/2048
# 6s - loss: 0.3974 - val_loss: 0.4274
# Epoch 693/2048
# 6s - loss: 0.3974 - val_loss: 0.4266
# Epoch 694/2048
# 6s - loss: 0.3974 - val_loss: 0.4270
# Epoch 695/2048
# 8s - loss: 0.3973 - val_loss: 0.4260
# Epoch 696/2048
# 6s - loss: 0.3973 - val_loss: 0.4271
# Epoch 697/2048
# 6s - loss: 0.3972 - val_loss: 0.4270
# Epoch 698/2048
# 6s - loss: 0.3972 - val_loss: 0.4268
# Epoch 699/2048
# 6s - loss: 0.3972 - val_loss: 0.4267
# Epoch 700/2048
# 6s - loss: 0.3972 - val_loss: 0.4271
# Epoch 701/2048
# 6s - loss: 0.3972 - val_loss: 0.4267
# Epoch 702/2048
# 6s - loss: 0.3972 - val_loss: 0.4263
# Epoch 703/2048
# 6s - loss: 0.3971 - val_loss: 0.4271
# Epoch 704/2048
# 6s - loss: 0.3972 - val_loss: 0.4272
# Epoch 705/2048
# 6s - loss: 0.3971 - val_loss: 0.4271
# Epoch 706/2048
# 6s - loss: 0.3971 - val_loss: 0.4271
# Epoch 707/2048
# 6s - loss: 0.3971 - val_loss: 0.4268
# Epoch 708/2048
# 6s - loss: 0.3970 - val_loss: 0.4268
# Epoch 709/2048
# 6s - loss: 0.3970 - val_loss: 0.4271
# Epoch 710/2048
# 6s - loss: 0.3970 - val_loss: 0.4263
# Epoch 711/2048
# 6s - loss: 0.3970 - val_loss: 0.4262
# Epoch 712/2048
# 6s - loss: 0.3970 - val_loss: 0.4266
# Epoch 713/2048
# 8s - loss: 0.3970 - val_loss: 0.4260
# Epoch 714/2048
# 6s - loss: 0.3969 - val_loss: 0.4264
# Epoch 715/2048
# 6s - loss: 0.3969 - val_loss: 0.4268
# Epoch 716/2048
# 6s - loss: 0.3968 - val_loss: 0.4267
# Epoch 717/2048
# 6s - loss: 0.3969 - val_loss: 0.4264
# Epoch 718/2048
# 6s - loss: 0.3969 - val_loss: 0.4261
# Epoch 719/2048
# 8s - loss: 0.3968 - val_loss: 0.4258
# Epoch 720/2048
# 6s - loss: 0.3968 - val_loss: 0.4266
# Epoch 721/2048
# 6s - loss: 0.3967 - val_loss: 0.4261
# Epoch 722/2048
# 6s - loss: 0.3967 - val_loss: 0.4268
# Epoch 723/2048
# 6s - loss: 0.3968 - val_loss: 0.4260
# Epoch 724/2048
# 6s - loss: 0.3967 - val_loss: 0.4266
# Epoch 725/2048
# 6s - loss: 0.3967 - val_loss: 0.4259
# Epoch 726/2048
# 6s - loss: 0.3966 - val_loss: 0.4259
# Epoch 727/2048
# 6s - loss: 0.3967 - val_loss: 0.4269
# Epoch 728/2048
# 6s - loss: 0.3967 - val_loss: 0.4263
# Epoch 729/2048
# 6s - loss: 0.3966 - val_loss: 0.4263
# Epoch 730/2048
# 6s - loss: 0.3966 - val_loss: 0.4270
# Epoch 731/2048
# 6s - loss: 0.3966 - val_loss: 0.4262
# Epoch 732/2048
# 8s - loss: 0.3965 - val_loss: 0.4255
# Epoch 733/2048
# 8s - loss: 0.3966 - val_loss: 0.4252
# Epoch 734/2048
# 6s - loss: 0.3965 - val_loss: 0.4262
# Epoch 735/2048
# 6s - loss: 0.3965 - val_loss: 0.4266
# Epoch 736/2048
# 6s - loss: 0.3965 - val_loss: 0.4277
# Epoch 737/2048
# 6s - loss: 0.3965 - val_loss: 0.4259
# Epoch 738/2048
# 6s - loss: 0.3964 - val_loss: 0.4262
# Epoch 739/2048
# 6s - loss: 0.3964 - val_loss: 0.4260
# Epoch 740/2048
# 6s - loss: 0.3965 - val_loss: 0.4254
# Epoch 741/2048
# 6s - loss: 0.3964 - val_loss: 0.4262
# Epoch 742/2048
# 6s - loss: 0.3964 - val_loss: 0.4258
# Epoch 743/2048
# 6s - loss: 0.3963 - val_loss: 0.4254
# Epoch 744/2048
# 6s - loss: 0.3964 - val_loss: 0.4263
# Epoch 745/2048
# 8s - loss: 0.3963 - val_loss: 0.4250
# Epoch 746/2048
# 6s - loss: 0.3964 - val_loss: 0.4263
# Epoch 747/2048
# 6s - loss: 0.3963 - val_loss: 0.4257
# Epoch 748/2048
# 6s - loss: 0.3962 - val_loss: 0.4263
# Epoch 749/2048
# 6s - loss: 0.3963 - val_loss: 0.4258
# Epoch 750/2048
# 8s - loss: 0.3962 - val_loss: 0.4250
# Epoch 751/2048
# 6s - loss: 0.3962 - val_loss: 0.4255
# Epoch 752/2048
# 6s - loss: 0.3962 - val_loss: 0.4261
# Epoch 753/2048
# 6s - loss: 0.3962 - val_loss: 0.4259
# Epoch 754/2048
# 6s - loss: 0.3961 - val_loss: 0.4261
# Epoch 755/2048
# 6s - loss: 0.3961 - val_loss: 0.4260
# Epoch 756/2048
# 6s - loss: 0.3961 - val_loss: 0.4254
# Epoch 757/2048
# 6s - loss: 0.3961 - val_loss: 0.4257
# Epoch 758/2048
# 6s - loss: 0.3962 - val_loss: 0.4254
# Epoch 759/2048
# 6s - loss: 0.3961 - val_loss: 0.4259
# Epoch 760/2048
# 6s - loss: 0.3961 - val_loss: 0.4264
# Epoch 761/2048
# 6s - loss: 0.3960 - val_loss: 0.4255
# Epoch 762/2048
# 6s - loss: 0.3960 - val_loss: 0.4257
# Epoch 763/2048
# 6s - loss: 0.3960 - val_loss: 0.4259
# Epoch 764/2048
# 6s - loss: 0.3960 - val_loss: 0.4253
# Epoch 765/2048
# 6s - loss: 0.3959 - val_loss: 0.4253
# Epoch 766/2048
# 6s - loss: 0.3960 - val_loss: 0.4259
# Epoch 767/2048
# 6s - loss: 0.3960 - val_loss: 0.4261
# Epoch 768/2048
# 6s - loss: 0.3959 - val_loss: 0.4261
# Epoch 769/2048
# 6s - loss: 0.3959 - val_loss: 0.4254
# Epoch 770/2048
# 6s - loss: 0.3959 - val_loss: 0.4260
# Epoch 771/2048
# 6s - loss: 0.3959 - val_loss: 0.4259
# Epoch 772/2048
# 6s - loss: 0.3958 - val_loss: 0.4253
# Epoch 773/2048
# 6s - loss: 0.3958 - val_loss: 0.4255
# Epoch 774/2048
# 6s - loss: 0.3958 - val_loss: 0.4259
# Epoch 775/2048
# 6s - loss: 0.3958 - val_loss: 0.4254
# Epoch 776/2048
# 6s - loss: 0.3958 - val_loss: 0.4254
# Epoch 777/2048
# 6s - loss: 0.3958 - val_loss: 0.4253
# Epoch 778/2048
# 6s - loss: 0.3957 - val_loss: 0.4260
# Epoch 779/2048
# 6s - loss: 0.3957 - val_loss: 0.4259
# Epoch 780/2048
# 8s - loss: 0.3957 - val_loss: 0.4246
# Epoch 781/2048
# 8s - loss: 0.3957 - val_loss: 0.4245
# Epoch 782/2048
# 6s - loss: 0.3956 - val_loss: 0.4255
# Epoch 783/2048
# 6s - loss: 0.3957 - val_loss: 0.4274
# Epoch 784/2048
# 6s - loss: 0.3957 - val_loss: 0.4250
# Epoch 785/2048
# 6s - loss: 0.3956 - val_loss: 0.4252
# Epoch 786/2048
# 6s - loss: 0.3955 - val_loss: 0.4246
# Epoch 787/2048
# 6s - loss: 0.3955 - val_loss: 0.4256
# Epoch 788/2048
# 6s - loss: 0.3955 - val_loss: 0.4247
# Epoch 789/2048
# 6s - loss: 0.3956 - val_loss: 0.4248
# Epoch 790/2048
# 6s - loss: 0.3955 - val_loss: 0.4249
# Epoch 791/2048
# 6s - loss: 0.3956 - val_loss: 0.4256
# Epoch 792/2048
# 6s - loss: 0.3955 - val_loss: 0.4253
# Epoch 793/2048
# 6s - loss: 0.3955 - val_loss: 0.4253
# Epoch 794/2048
# 6s - loss: 0.3954 - val_loss: 0.4269
# Epoch 795/2048
# 6s - loss: 0.3956 - val_loss: 0.4251
# Epoch 796/2048
# 6s - loss: 0.3955 - val_loss: 0.4246
# Epoch 797/2048
# 6s - loss: 0.3954 - val_loss: 0.4253
# Epoch 798/2048
# 6s - loss: 0.3955 - val_loss: 0.4250
# Epoch 799/2048
# 6s - loss: 0.3954 - val_loss: 0.4255
# Epoch 800/2048
# 6s - loss: 0.3954 - val_loss: 0.4252
# Epoch 801/2048
# 6s - loss: 0.3953 - val_loss: 0.4255
# Epoch 802/2048
# 6s - loss: 0.3953 - val_loss: 0.4251
# Epoch 803/2048
# 6s - loss: 0.3954 - val_loss: 0.4253
# Epoch 804/2048
# 6s - loss: 0.3953 - val_loss: 0.4253
# Epoch 805/2048
# 6s - loss: 0.3953 - val_loss: 0.4251
# Epoch 806/2048
# 6s - loss: 0.3952 - val_loss: 0.4246
# Epoch 807/2048
# 8s - loss: 0.3953 - val_loss: 0.4244
# Epoch 808/2048
# 6s - loss: 0.3953 - val_loss: 0.4248
# Epoch 809/2048
# 6s - loss: 0.3952 - val_loss: 0.4251
# Epoch 810/2048
# 6s - loss: 0.3952 - val_loss: 0.4250
# Epoch 811/2048
# 8s - loss: 0.3952 - val_loss: 0.4244
# Epoch 812/2048
# 6s - loss: 0.3952 - val_loss: 0.4256
# Epoch 813/2048
# 6s - loss: 0.3952 - val_loss: 0.4255
# Epoch 814/2048
# 9s - loss: 0.3952 - val_loss: 0.4242
# Epoch 815/2048
# 6s - loss: 0.3951 - val_loss: 0.4244
# Epoch 816/2048
# 6s - loss: 0.3951 - val_loss: 0.4251
# Epoch 817/2048
# 6s - loss: 0.3951 - val_loss: 0.4248
# Epoch 818/2048
# 6s - loss: 0.3951 - val_loss: 0.4245
# Epoch 819/2048
# 6s - loss: 0.3950 - val_loss: 0.4247
# Epoch 820/2048
# 6s - loss: 0.3950 - val_loss: 0.4250
# Epoch 821/2048
# 6s - loss: 0.3950 - val_loss: 0.4242
# Epoch 822/2048
# 6s - loss: 0.3950 - val_loss: 0.4253
# Epoch 823/2048
# 6s - loss: 0.3951 - val_loss: 0.4242
# Epoch 824/2048
# 6s - loss: 0.3950 - val_loss: 0.4244
# Epoch 825/2048
# 6s - loss: 0.3950 - val_loss: 0.4245
# Epoch 826/2048
# 6s - loss: 0.3949 - val_loss: 0.4251
# Epoch 827/2048
# 6s - loss: 0.3949 - val_loss: 0.4242
# Epoch 828/2048
# 6s - loss: 0.3949 - val_loss: 0.4244
# Epoch 829/2048
# 8s - loss: 0.3949 - val_loss: 0.4241
# Epoch 830/2048
# 6s - loss: 0.3949 - val_loss: 0.4244
# Epoch 831/2048
# 6s - loss: 0.3949 - val_loss: 0.4242
# Epoch 832/2048
# 8s - loss: 0.3949 - val_loss: 0.4239
# Epoch 833/2048
# 6s - loss: 0.3948 - val_loss: 0.4241
# Epoch 834/2048
# 6s - loss: 0.3949 - val_loss: 0.4244
# Epoch 835/2048
# 6s - loss: 0.3949 - val_loss: 0.4248
# Epoch 836/2048
# 6s - loss: 0.3948 - val_loss: 0.4243
# Epoch 837/2048
# 6s - loss: 0.3948 - val_loss: 0.4254
# Epoch 838/2048
# 6s - loss: 0.3948 - val_loss: 0.4241
# Epoch 839/2048
# 6s - loss: 0.3948 - val_loss: 0.4244
# Epoch 840/2048
# 6s - loss: 0.3947 - val_loss: 0.4247
# Epoch 841/2048
# 6s - loss: 0.3947 - val_loss: 0.4242
# Epoch 842/2048
# 6s - loss: 0.3947 - val_loss: 0.4243
# Epoch 843/2048
# 6s - loss: 0.3947 - val_loss: 0.4249
# Epoch 844/2048
# 6s - loss: 0.3947 - val_loss: 0.4242
# Epoch 845/2048
# 6s - loss: 0.3946 - val_loss: 0.4248
# Epoch 846/2048
# 6s - loss: 0.3946 - val_loss: 0.4244
# Epoch 847/2048
# 6s - loss: 0.3946 - val_loss: 0.4242
# Epoch 848/2048
# 6s - loss: 0.3946 - val_loss: 0.4246
# Epoch 849/2048
# 6s - loss: 0.3946 - val_loss: 0.4279
# Epoch 850/2048
# 6s - loss: 0.3948 - val_loss: 0.4241
# Epoch 851/2048
# 6s - loss: 0.3946 - val_loss: 0.4245
# Epoch 852/2048
# 7s - loss: 0.3945 - val_loss: 0.4234
# Epoch 853/2048
# 6s - loss: 0.3946 - val_loss: 0.4237
# Epoch 854/2048
# 6s - loss: 0.3945 - val_loss: 0.4240
# Epoch 855/2048
# 6s - loss: 0.3945 - val_loss: 0.4241
# Epoch 856/2048
# 6s - loss: 0.3946 - val_loss: 0.4249
# Epoch 857/2048
# 6s - loss: 0.3945 - val_loss: 0.4242
# Epoch 858/2048
# 6s - loss: 0.3945 - val_loss: 0.4239
# Epoch 859/2048
# 6s - loss: 0.3944 - val_loss: 0.4235
# Epoch 860/2048
# 6s - loss: 0.3945 - val_loss: 0.4243
# Epoch 861/2048
# 6s - loss: 0.3945 - val_loss: 0.4244
# Epoch 862/2048
# 6s - loss: 0.3945 - val_loss: 0.4237
# Epoch 863/2048
# 6s - loss: 0.3944 - val_loss: 0.4238
# Epoch 864/2048
# 6s - loss: 0.3944 - val_loss: 0.4247
# Epoch 865/2048
# 6s - loss: 0.3943 - val_loss: 0.4241
# Epoch 866/2048
# 6s - loss: 0.3943 - val_loss: 0.4244
# Epoch 867/2048
# 7s - loss: 0.3944 - val_loss: 0.4234
# Epoch 868/2048
# 6s - loss: 0.3943 - val_loss: 0.4250
# Epoch 869/2048
# 6s - loss: 0.3944 - val_loss: 0.4243
# Epoch 870/2048
# 6s - loss: 0.3944 - val_loss: 0.4244
# Epoch 871/2048
# 6s - loss: 0.3943 - val_loss: 0.4242
# Epoch 872/2048
# 6s - loss: 0.3943 - val_loss: 0.4238
# Epoch 873/2048
# 6s - loss: 0.3943 - val_loss: 0.4235
# Epoch 874/2048
# 6s - loss: 0.3942 - val_loss: 0.4248
# Epoch 875/2048
# 6s - loss: 0.3942 - val_loss: 0.4244
# Epoch 876/2048
# 6s - loss: 0.3944 - val_loss: 0.4239
# Epoch 877/2048
# 6s - loss: 0.3943 - val_loss: 0.4239
# Epoch 878/2048
# 6s - loss: 0.3942 - val_loss: 0.4243
# Epoch 879/2048
# 6s - loss: 0.3942 - val_loss: 0.4245
# Epoch 880/2048
# 6s - loss: 0.3947 - val_loss: 0.4243
# Epoch 881/2048
# 6s - loss: 0.3942 - val_loss: 0.4235
# Epoch 882/2048
# 6s - loss: 0.3941 - val_loss: 0.4244
# Epoch 883/2048
# 6s - loss: 0.3941 - val_loss: 0.4242
# Epoch 884/2048
# 6s - loss: 0.3941 - val_loss: 0.4238
# Epoch 885/2048
# 6s - loss: 0.3942 - val_loss: 0.4236
# Epoch 886/2048
# 6s - loss: 0.3941 - val_loss: 0.4244
# Epoch 887/2048
# 6s - loss: 0.3940 - val_loss: 0.4240
# Epoch 888/2048
# 6s - loss: 0.3940 - val_loss: 0.4286
# Epoch 889/2048
# 6s - loss: 0.3945 - val_loss: 0.4235
# Epoch 890/2048
# 6s - loss: 0.3940 - val_loss: 0.4254
# Epoch 891/2048
# 6s - loss: 0.3940 - val_loss: 0.4243
# Epoch 892/2048
# 7s - loss: 0.3941 - val_loss: 0.4231
# Epoch 893/2048
# 6s - loss: 0.3940 - val_loss: 0.4238
# Epoch 894/2048
# 6s - loss: 0.3939 - val_loss: 0.4233
# Epoch 895/2048
# 6s - loss: 0.3940 - val_loss: 0.4243
# Epoch 896/2048
# 6s - loss: 0.3939 - val_loss: 0.4239
# Epoch 897/2048
# 6s - loss: 0.3940 - val_loss: 0.4238
# Epoch 898/2048
# 6s - loss: 0.3939 - val_loss: 0.4248
# Epoch 899/2048
# 6s - loss: 0.3939 - val_loss: 0.4236
# Epoch 900/2048
# 6s - loss: 0.3939 - val_loss: 0.4236
# Epoch 901/2048
# 6s - loss: 0.3939 - val_loss: 0.4241
# Epoch 902/2048
# 6s - loss: 0.3938 - val_loss: 0.4241
# Epoch 903/2048
# 6s - loss: 0.3939 - val_loss: 0.4233
# Epoch 904/2048
# 6s - loss: 0.3940 - val_loss: 0.4237
# Epoch 905/2048
# 6s - loss: 0.3938 - val_loss: 0.4242
# Epoch 906/2048
# 6s - loss: 0.3938 - val_loss: 0.4241
# Epoch 907/2048
# 6s - loss: 0.3938 - val_loss: 0.4235
# Epoch 908/2048
# 6s - loss: 0.3938 - val_loss: 0.4238
# Epoch 909/2048
# 6s - loss: 0.3938 - val_loss: 0.4238
# Epoch 910/2048
# 6s - loss: 0.3938 - val_loss: 0.4237
# Epoch 911/2048
# 6s - loss: 0.3938 - val_loss: 0.4237
# Epoch 912/2048
# 6s - loss: 0.3938 - val_loss: 0.4236
# Epoch 913/2048
# 6s - loss: 0.3944 - val_loss: 0.4238
# Epoch 914/2048
# 6s - loss: 0.3938 - val_loss: 0.4232
# Epoch 915/2048
# 6s - loss: 0.3937 - val_loss: 0.4237
# Epoch 916/2048
# 6s - loss: 0.3937 - val_loss: 0.4233
# Epoch 917/2048
# 7s - loss: 0.3937 - val_loss: 0.4231
# Epoch 918/2048
# 6s - loss: 0.3937 - val_loss: 0.4236
# Epoch 919/2048
# 6s - loss: 0.3936 - val_loss: 0.4236
# Epoch 920/2048
# 6s - loss: 0.3936 - val_loss: 0.4232
# Epoch 921/2048
# 6s - loss: 0.3936 - val_loss: 0.4234
# Epoch 922/2048
# 6s - loss: 0.3936 - val_loss: 0.4237
# Epoch 923/2048
# 6s - loss: 0.3937 - val_loss: 0.4243
# Epoch 924/2048
# 6s - loss: 0.3937 - val_loss: 0.4236
# Epoch 925/2048
# 6s - loss: 0.3936 - val_loss: 0.4234
# Epoch 926/2048
# 6s - loss: 0.3936 - val_loss: 0.4231
# Epoch 927/2048
# 8s - loss: 0.3936 - val_loss: 0.4227
# Epoch 928/2048
# 6s - loss: 0.3935 - val_loss: 0.4237
# Epoch 929/2048
# 6s - loss: 0.3936 - val_loss: 0.4231
# Epoch 930/2048
# 6s - loss: 0.3935 - val_loss: 0.4247
# Epoch 931/2048
# 6s - loss: 0.3934 - val_loss: 0.4240
# Epoch 932/2048
# 6s - loss: 0.3935 - val_loss: 0.4234
# Epoch 933/2048
# 6s - loss: 0.3934 - val_loss: 0.4238
# Epoch 934/2048
# 6s - loss: 0.3935 - val_loss: 0.4235
# Epoch 935/2048
# 6s - loss: 0.3934 - val_loss: 0.4232
# Epoch 936/2048
# 6s - loss: 0.3934 - val_loss: 0.4229
# Epoch 937/2048
# 6s - loss: 0.3934 - val_loss: 0.4233
# Epoch 938/2048
# 6s - loss: 0.3934 - val_loss: 0.4233
# Epoch 939/2048
# 6s - loss: 0.3934 - val_loss: 0.4239
# Epoch 940/2048
# 6s - loss: 0.3933 - val_loss: 0.4230
# Epoch 941/2048
# 6s - loss: 0.3934 - val_loss: 0.4244
# Epoch 942/2048
# 6s - loss: 0.3933 - val_loss: 0.4229
# Epoch 943/2048
# 6s - loss: 0.3933 - val_loss: 0.4235
# Epoch 944/2048
# 8s - loss: 0.3933 - val_loss: 0.4227
# Epoch 945/2048
# 8s - loss: 0.3933 - val_loss: 0.4227
# Epoch 946/2048
# 6s - loss: 0.3932 - val_loss: 0.4228
# Epoch 947/2048
# 6s - loss: 0.3932 - val_loss: 0.4252
# Epoch 948/2048
# 6s - loss: 0.3935 - val_loss: 0.4236
# Epoch 949/2048
# 6s - loss: 0.3932 - val_loss: 0.4242
# Epoch 950/2048
# 6s - loss: 0.3931 - val_loss: 0.4235
# Epoch 951/2048
# 6s - loss: 0.3931 - val_loss: 0.4233
# Epoch 952/2048
# 6s - loss: 0.3932 - val_loss: 0.4233
# Epoch 953/2048
# 7s - loss: 0.3931 - val_loss: 0.4226
# Epoch 954/2048
# 6s - loss: 0.3932 - val_loss: 0.4231
# Epoch 955/2048
# 6s - loss: 0.3931 - val_loss: 0.4236
# Epoch 956/2048
# 6s - loss: 0.3931 - val_loss: 0.4229
# Epoch 957/2048
# 6s - loss: 0.3931 - val_loss: 0.4238
# Epoch 958/2048
# 6s - loss: 0.3931 - val_loss: 0.4233
# Epoch 959/2048
# 6s - loss: 0.3931 - val_loss: 0.4236
# Epoch 960/2048
# 6s - loss: 0.3930 - val_loss: 0.4230
# Epoch 961/2048
# 6s - loss: 0.3930 - val_loss: 0.4228
# Epoch 962/2048
# 6s - loss: 0.3930 - val_loss: 0.4227
# Epoch 963/2048
# 6s - loss: 0.3931 - val_loss: 0.4228
# Epoch 964/2048
# 7s - loss: 0.3930 - val_loss: 0.4222
# Epoch 965/2048
# 6s - loss: 0.3930 - val_loss: 0.4236
# Epoch 966/2048
# 6s - loss: 0.3930 - val_loss: 0.4231
# Epoch 967/2048
# 6s - loss: 0.3929 - val_loss: 0.4225
# Epoch 968/2048
# 6s - loss: 0.3929 - val_loss: 0.4232
# Epoch 969/2048
# 6s - loss: 0.3930 - val_loss: 0.4231
# Epoch 970/2048
# 6s - loss: 0.3929 - val_loss: 0.4225
# Epoch 971/2048
# 6s - loss: 0.3929 - val_loss: 0.4228
# Epoch 972/2048
# 6s - loss: 0.3930 - val_loss: 0.4228
# Epoch 973/2048
# 6s - loss: 0.3929 - val_loss: 0.4234
# Epoch 974/2048
# 6s - loss: 0.3928 - val_loss: 0.4225
# Epoch 975/2048
# 6s - loss: 0.3928 - val_loss: 0.4227
# Epoch 976/2048
# 6s - loss: 0.3928 - val_loss: 0.4230
# Epoch 977/2048
# 6s - loss: 0.3928 - val_loss: 0.4231
# Epoch 978/2048
# 6s - loss: 0.3928 - val_loss: 0.4232
# Epoch 979/2048
# 6s - loss: 0.3927 - val_loss: 0.4236
# Epoch 980/2048
# 6s - loss: 0.3928 - val_loss: 0.4231
# Epoch 981/2048
# 6s - loss: 0.3927 - val_loss: 0.4224
# Epoch 982/2048
# 6s - loss: 0.3927 - val_loss: 0.4230
# Epoch 983/2048
# 6s - loss: 0.3928 - val_loss: 0.4230
# Epoch 984/2048
# 6s - loss: 0.3927 - val_loss: 0.4227
# Epoch 985/2048
# 6s - loss: 0.3927 - val_loss: 0.4231
# Epoch 986/2048
# 6s - loss: 0.3927 - val_loss: 0.4231
# Epoch 987/2048
# 6s - loss: 0.3926 - val_loss: 0.4231
# Epoch 988/2048
# 6s - loss: 0.3926 - val_loss: 0.4227
# Epoch 989/2048
# 6s - loss: 0.3926 - val_loss: 0.4228
# Epoch 990/2048
# 6s - loss: 0.3926 - val_loss: 0.4231
# Epoch 991/2048
# 6s - loss: 0.3925 - val_loss: 0.4233
# Epoch 992/2048
# 6s - loss: 0.3925 - val_loss: 0.4226
# Epoch 993/2048
# 6s - loss: 0.3925 - val_loss: 0.4227
# Epoch 994/2048
# 6s - loss: 0.3926 - val_loss: 0.4225
# Epoch 995/2048
# 6s - loss: 0.3925 - val_loss: 0.4228
# Epoch 996/2048
# 6s - loss: 0.3924 - val_loss: 0.4231
# Epoch 997/2048
# 6s - loss: 0.3925 - val_loss: 0.4232
# Epoch 00996: early stopping

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name))

# %%
# Run predictions
ae_pred = autoencoder.predict(X_test_norm)
ae_pred_train = autoencoder.predict(X_train_norm)

# %%
# Exclude validation set
ae_pred_train = ae_pred_train[:int(0.75 * len(ae_pred_train)), :]

# %%
pickle.dump(ae_pred, open(model_directory + "ae_pred.p", "wb"))
pickle.dump(ae_pred_train, open(model_directory + "ae_pred_train.p", "wb"))

# %%
ae_pred = pickle.load(open(model_directory + "ae_pred.p", "rb"))
ae_pred_train = pickle.load(open(model_directory + "ae_pred_train.p", "rb"))

# %%
# Exclude validation set
X_train_wo_valid = X_train_norm[:int(0.75 * len(X_train_norm)), :]

# %%
def get_error_df(X_test, predictions, mode="allmean", n_highest = 100):
    
    if mode == "allmean":
        return np.mean(np.power(X_test - predictions, 2), axis=1)
    
    elif mode == "topn":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.mean(result, axis=1)
    
    elif mode == "topn_median":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.median(result, axis=1)
    
    elif mode == "perobj":
        mses = []
        for l in legend:
            mse = np.mean(
                np.power(X_test[:,l["start"]:l["end"]] - predictions[:,l["start"]:l["end"]], 2),
                axis=1)
            mses.append(mse)
     
        return np.maximum.reduce(mses)
    
    elif mode == "bottomn":
        temp = np.partition(np.power(X_test - predictions, 2), n_highest)
        result = temp[:,:n_highest]
        return np.mean(result, axis=1)

# %%
ae_pred.shape
# Out:
# (19086, 2809)

# %%
ae_error = get_error_df(X_test_norm, ae_pred, mode="topn", n_highest=100)
ae_error_train = get_error_df(X_train_wo_valid, ae_pred_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error, open(model_directory + "ae_error.p", "wb"))
pickle.dump(ae_error_train, open(model_directory + "ae_error_train.p", "wb"))

# %%
# Plot lumi vs error
def plot_lumi_error(pred, X_test, threshold=None, title=None):
    scores = get_error_df(X_test, pred, mode='topn')
    
    fig, ax = plt.subplots()

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 0],
             scores[y_test == 0],
             linestyle='',
             ms=2,
             marker='o',
             label="Outlier")

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 1],
             scores[y_test == 1],
             linestyle='',
             ms=2,
             marker='o',
             label="Inlier")

    ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
    
    ax.set_yscale("log")
    plt.ylabel("Score")
    plt.xlabel("Lumisection #")
    if title:
        plt.title(title)
    plt.show();

# %%
start_legend = 1414
var_legend = [{'start': start_legend, 'end': start_legend, 'name': 'mean'},
              {'start': start_legend+1, 'end': start_legend+1, 'name': 'RMS'},
              {'start': start_legend+2, 'end': start_legend+2, 'name': 'Q1'},
              {'start': start_legend+3, 'end': start_legend+3, 'name': 'Q2'},
              {'start': start_legend+4, 'end': start_legend+4, 'name': 'Q3'},
              {'start': start_legend+5, 'end': start_legend+5, 'name': 'Q4'},
              {'start': start_legend+6, 'end': start_legend+6, 'name': 'Q5'}]

# %%
corr = [pearsonr(X_train_wo_valid[:, i].reshape(-1), ae_pred_train[:, i].reshape(-1)) for i in range(INPUT_DIM)]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
corr = np.array(corr)[:, 0]

# %%
corr[np.isnan(corr)] = 0

# %%
plt.hist(corr, bins=100)
plt.title('Histogram of correlation coefficients for 2809 features')
plt.show()

# %%
corr_filter = corr > 0.5

# %%
variance = np.var(data.iloc[:, 0:INPUT_DIM])

# %%
var_filter = variance != 0

# %%
feature_filter = corr_filter & var_filter

# %%
X_train_filtered = X_train_norm[:, feature_filter]
X_train_filtered.shape
# Out:
# (68986, 1272)

# %%
X_train_filtered_wo_valid = X_train.iloc[:round(0.75*len(X_train)), :]
X_train_filtered_wo_valid = np.array(X_train_filtered_wo_valid)[:, feature_filter]

# %%
input_dim = X_train_filtered.shape[1]
input_layer = Input(shape=(input_dim, ))

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(32, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(input_dim)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1272)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              1303552
# _________________________________________________________________
# p_re_lu_12 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# p_re_lu_13 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               131328
# _________________________________________________________________
# p_re_lu_14 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# p_re_lu_15 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# p_re_lu_16 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# p_re_lu_17 (PReLU)           (None, 32)                32
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                2112
# _________________________________________________________________
# p_re_lu_18 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               8320
# _________________________________________________________________
# p_re_lu_19 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               33024
# _________________________________________________________________
# p_re_lu_20 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# p_re_lu_21 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_23 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_22 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_24 (Dense)             (None, 1272)              1303800
# =================================================================
# Total params: 4,011,064
# Trainable params: 4,011,064
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name2 = 'ae2'

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name2)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_filtered,
                X_train_filtered,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 51739 samples, validate on 17247 samples
# Epoch 1/2048
# 7s - loss: 31.6650 - val_loss: 19.7415
# Epoch 2/2048
# 6s - loss: 13.4568 - val_loss: 8.5630
# Epoch 3/2048
# 6s - loss: 5.9876 - val_loss: 3.9873
# Epoch 4/2048
# 6s - loss: 2.9688 - val_loss: 2.1348
# Epoch 5/2048
# 6s - loss: 1.7299 - val_loss: 1.3447
# Epoch 6/2048
# 6s - loss: 1.1681 - val_loss: 0.9537
# Epoch 7/2048
# 6s - loss: 0.8708 - val_loss: 0.7322
# Epoch 8/2048
# 6s - loss: 0.6990 - val_loss: 0.6020
# Epoch 9/2048
# 6s - loss: 0.5960 - val_loss: 0.5208
# Epoch 10/2048
# 6s - loss: 0.5303 - val_loss: 0.4688
# Epoch 11/2048
# 6s - loss: 0.4877 - val_loss: 0.4358
# Epoch 12/2048
# 6s - loss: 0.4598 - val_loss: 0.4144
# Epoch 13/2048
# 6s - loss: 0.4405 - val_loss: 0.3997
# Epoch 14/2048
# 6s - loss: 0.4264 - val_loss: 0.3909
# Epoch 15/2048
# 6s - loss: 0.4153 - val_loss: 0.3872
# Epoch 16/2048
# 6s - loss: 0.4051 - val_loss: 0.3857
# Epoch 17/2048
# 6s - loss: 0.3919 - val_loss: 0.3936
# Epoch 18/2048
# 6s - loss: 0.3726 - val_loss: 0.3967
# Epoch 19/2048
# 6s - loss: 0.3589 - val_loss: 0.3917
# Epoch 20/2048
# 6s - loss: 0.3527 - val_loss: 0.3828
# Epoch 21/2048
# 6s - loss: 0.3490 - val_loss: 0.3791
# Epoch 22/2048
# 6s - loss: 0.3461 - val_loss: 0.3762
# Epoch 23/2048
# 6s - loss: 0.3438 - val_loss: 0.3730
# Epoch 24/2048
# 6s - loss: 0.3417 - val_loss: 0.3706
# Epoch 25/2048
# 6s - loss: 0.3400 - val_loss: 0.3683
# Epoch 26/2048
# 6s - loss: 0.3383 - val_loss: 0.3661
# Epoch 27/2048
# 6s - loss: 0.3368 - val_loss: 0.3646
# Epoch 28/2048
# 6s - loss: 0.3353 - val_loss: 0.3633
# Epoch 29/2048
# 6s - loss: 0.3339 - val_loss: 0.3615
# Epoch 30/2048
# 6s - loss: 0.3326 - val_loss: 0.3607
# Epoch 31/2048
# 6s - loss: 0.3313 - val_loss: 0.3591
# Epoch 32/2048
# 6s - loss: 0.3301 - val_loss: 0.3569
# Epoch 33/2048
# 6s - loss: 0.3289 - val_loss: 0.3588
# Epoch 34/2048
# 6s - loss: 0.3278 - val_loss: 0.3544
# Epoch 35/2048
# 6s - loss: 0.3267 - val_loss: 0.3533
# Epoch 36/2048
# 6s - loss: 0.3257 - val_loss: 0.3528
# Epoch 37/2048
# 6s - loss: 0.3246 - val_loss: 0.3515
# Epoch 38/2048
# 6s - loss: 0.3237 - val_loss: 0.3505
# Epoch 39/2048
# 6s - loss: 0.3228 - val_loss: 0.3495
# Epoch 40/2048
# 6s - loss: 0.3218 - val_loss: 0.3485
# Epoch 41/2048
# 6s - loss: 0.3209 - val_loss: 0.3471
# Epoch 42/2048
# 6s - loss: 0.3200 - val_loss: 0.3463
# Epoch 43/2048
# 6s - loss: 0.3192 - val_loss: 0.3456
# Epoch 44/2048
# 6s - loss: 0.3183 - val_loss: 0.3454
# Epoch 45/2048
# 6s - loss: 0.3174 - val_loss: 0.3437
# Epoch 46/2048
# 6s - loss: 0.3166 - val_loss: 0.3439
# Epoch 47/2048
# 6s - loss: 0.3159 - val_loss: 0.3432
# Epoch 48/2048
# 6s - loss: 0.3152 - val_loss: 0.3413
# Epoch 49/2048
# 6s - loss: 0.3144 - val_loss: 0.3403
# Epoch 50/2048
# 6s - loss: 0.3136 - val_loss: 0.3409
# Epoch 51/2048
# 6s - loss: 0.3129 - val_loss: 0.3397
# Epoch 52/2048
# 6s - loss: 0.3122 - val_loss: 0.3384
# Epoch 53/2048
# 6s - loss: 0.3114 - val_loss: 0.3375
# Epoch 54/2048
# 6s - loss: 0.3107 - val_loss: 0.3377
# Epoch 55/2048
# 6s - loss: 0.3102 - val_loss: 0.3370
# Epoch 56/2048
# 6s - loss: 0.3095 - val_loss: 0.3359
# Epoch 57/2048
# 7s - loss: 0.3089 - val_loss: 0.3345
# Epoch 58/2048
# 6s - loss: 0.3083 - val_loss: 0.3343
# Epoch 59/2048
# 5s - loss: 0.3077 - val_loss: 0.3348
# Epoch 60/2048
# 6s - loss: 0.3071 - val_loss: 0.3340
# Epoch 61/2048
# 6s - loss: 0.3066 - val_loss: 0.3325
# Epoch 62/2048
# 6s - loss: 0.3059 - val_loss: 0.3316
# Epoch 63/2048
# 6s - loss: 0.3053 - val_loss: 0.3325
# Epoch 64/2048
# 6s - loss: 0.3048 - val_loss: 0.3306
# Epoch 65/2048
# 6s - loss: 0.3043 - val_loss: 0.3311
# Epoch 66/2048
# 6s - loss: 0.3038 - val_loss: 0.3297
# Epoch 67/2048
# 6s - loss: 0.3033 - val_loss: 0.3310
# Epoch 68/2048
# 6s - loss: 0.3028 - val_loss: 0.3290
# Epoch 69/2048
# 6s - loss: 0.3023 - val_loss: 0.3300
# Epoch 70/2048
# 6s - loss: 0.3019 - val_loss: 0.3287
# Epoch 71/2048
# 6s - loss: 0.3014 - val_loss: 0.3280
# Epoch 72/2048
# 6s - loss: 0.3008 - val_loss: 0.3270
# Epoch 73/2048
# 6s - loss: 0.3004 - val_loss: 0.3271
# Epoch 74/2048
# 6s - loss: 0.3000 - val_loss: 0.3266
# Epoch 75/2048
# 6s - loss: 0.2995 - val_loss: 0.3263
# Epoch 76/2048
# 6s - loss: 0.2990 - val_loss: 0.3252
# Epoch 77/2048
# 6s - loss: 0.2985 - val_loss: 0.3248
# Epoch 78/2048
# 6s - loss: 0.2980 - val_loss: 0.3249
# Epoch 79/2048
# 6s - loss: 0.2976 - val_loss: 0.3236
# Epoch 80/2048
# 6s - loss: 0.2971 - val_loss: 0.3233
# Epoch 81/2048
# 6s - loss: 0.2967 - val_loss: 0.3235
# Epoch 82/2048
# 6s - loss: 0.2962 - val_loss: 0.3230
# Epoch 83/2048
# 6s - loss: 0.2958 - val_loss: 0.3218
# Epoch 84/2048
# 5s - loss: 0.2954 - val_loss: 0.3230
# Epoch 85/2048
# 6s - loss: 0.2949 - val_loss: 0.3212
# Epoch 86/2048
# 6s - loss: 0.2945 - val_loss: 0.3216
# Epoch 87/2048
# 6s - loss: 0.2941 - val_loss: 0.3195
# Epoch 88/2048
# 6s - loss: 0.2937 - val_loss: 0.3194
# Epoch 89/2048
# 6s - loss: 0.2934 - val_loss: 0.3201
# Epoch 90/2048
# 6s - loss: 0.2930 - val_loss: 0.3197
# Epoch 91/2048
# 6s - loss: 0.2927 - val_loss: 0.3187
# Epoch 92/2048
# 6s - loss: 0.2923 - val_loss: 0.3178
# Epoch 93/2048
# 6s - loss: 0.2920 - val_loss: 0.3188
# Epoch 94/2048
# 5s - loss: 0.2917 - val_loss: 0.3191
# Epoch 95/2048
# 5s - loss: 0.2914 - val_loss: 0.3184
# Epoch 96/2048
# 6s - loss: 0.2911 - val_loss: 0.3179
# Epoch 97/2048
# 6s - loss: 0.2908 - val_loss: 0.3169
# Epoch 98/2048
# 6s - loss: 0.2905 - val_loss: 0.3162
# Epoch 99/2048
# 6s - loss: 0.2902 - val_loss: 0.3175
# Epoch 100/2048
# 6s - loss: 0.2898 - val_loss: 0.3167
# Epoch 101/2048
# 6s - loss: 0.2896 - val_loss: 0.3160
# Epoch 102/2048
# 6s - loss: 0.2893 - val_loss: 0.3168
# Epoch 103/2048
# 6s - loss: 0.2890 - val_loss: 0.3163
# Epoch 104/2048
# 6s - loss: 0.2887 - val_loss: 0.3150
# Epoch 105/2048
# 6s - loss: 0.2884 - val_loss: 0.3150
# Epoch 106/2048
# 6s - loss: 0.2882 - val_loss: 0.3158
# Epoch 107/2048
# 6s - loss: 0.2879 - val_loss: 0.3142
# Epoch 108/2048
# 6s - loss: 0.2876 - val_loss: 0.3147
# Epoch 109/2048
# 6s - loss: 0.2873 - val_loss: 0.3137
# Epoch 110/2048
# 6s - loss: 0.2870 - val_loss: 0.3140
# Epoch 111/2048
# 6s - loss: 0.2868 - val_loss: 0.3138
# Epoch 112/2048
# 6s - loss: 0.2865 - val_loss: 0.3131
# Epoch 113/2048
# 6s - loss: 0.2862 - val_loss: 0.3135
# Epoch 114/2048
# 6s - loss: 0.2860 - val_loss: 0.3125
# Epoch 115/2048
# 5s - loss: 0.2858 - val_loss: 0.3125
# Epoch 116/2048
# 5s - loss: 0.2854 - val_loss: 0.3125
# Epoch 117/2048
# 6s - loss: 0.2852 - val_loss: 0.3120
# Epoch 118/2048
# 6s - loss: 0.2849 - val_loss: 0.3115
# Epoch 119/2048
# 6s - loss: 0.2847 - val_loss: 0.3122
# Epoch 120/2048
# 6s - loss: 0.2844 - val_loss: 0.3108
# Epoch 121/2048
# 6s - loss: 0.2841 - val_loss: 0.3113
# Epoch 122/2048
# 6s - loss: 0.2838 - val_loss: 0.3106
# Epoch 123/2048
# 6s - loss: 0.2836 - val_loss: 0.3100
# Epoch 124/2048
# 6s - loss: 0.2833 - val_loss: 0.3103
# Epoch 125/2048
# 6s - loss: 0.2830 - val_loss: 0.3096
# Epoch 126/2048
# 6s - loss: 0.2827 - val_loss: 0.3105
# Epoch 127/2048
# 6s - loss: 0.2826 - val_loss: 0.3095
# Epoch 128/2048
# 6s - loss: 0.2821 - val_loss: 0.3093
# Epoch 129/2048
# 6s - loss: 0.2819 - val_loss: 0.3082
# Epoch 130/2048
# 6s - loss: 0.2815 - val_loss: 0.3087
# Epoch 131/2048
# 6s - loss: 0.2812 - val_loss: 0.3084
# Epoch 132/2048
# 6s - loss: 0.2809 - val_loss: 0.3071
# Epoch 133/2048
# 6s - loss: 0.2805 - val_loss: 0.3068
# Epoch 134/2048
# 6s - loss: 0.2801 - val_loss: 0.3064
# Epoch 135/2048
# 6s - loss: 0.2796 - val_loss: 0.3060
# Epoch 136/2048
# 6s - loss: 0.2792 - val_loss: 0.3055
# Epoch 137/2048
# 6s - loss: 0.2787 - val_loss: 0.3048
# Epoch 138/2048
# 6s - loss: 0.2783 - val_loss: 0.3053
# Epoch 139/2048
# 6s - loss: 0.2777 - val_loss: 0.3036
# Epoch 140/2048
# 6s - loss: 0.2772 - val_loss: 0.3045
# Epoch 141/2048
# 6s - loss: 0.2767 - val_loss: 0.3026
# Epoch 142/2048
# 6s - loss: 0.2762 - val_loss: 0.3022
# Epoch 143/2048
# 6s - loss: 0.2757 - val_loss: 0.3025
# Epoch 144/2048
# 6s - loss: 0.2753 - val_loss: 0.3022
# Epoch 145/2048
# 6s - loss: 0.2748 - val_loss: 0.3015
# Epoch 146/2048
# 6s - loss: 0.2743 - val_loss: 0.3011
# Epoch 147/2048
# 7s - loss: 0.2739 - val_loss: 0.3004
# Epoch 148/2048
# 6s - loss: 0.2735 - val_loss: 0.3006
# Epoch 149/2048
# 6s - loss: 0.2731 - val_loss: 0.3003
# Epoch 150/2048
# 6s - loss: 0.2728 - val_loss: 0.2994
# Epoch 151/2048
# 6s - loss: 0.2724 - val_loss: 0.2999
# Epoch 152/2048
# 6s - loss: 0.2722 - val_loss: 0.2992
# Epoch 153/2048
# 6s - loss: 0.2719 - val_loss: 0.2994
# Epoch 154/2048
# 6s - loss: 0.2716 - val_loss: 0.2977
# Epoch 155/2048
# 6s - loss: 0.2713 - val_loss: 0.2978
# Epoch 156/2048
# 6s - loss: 0.2710 - val_loss: 0.2969
# Epoch 157/2048
# 6s - loss: 0.2707 - val_loss: 0.2984
# Epoch 158/2048
# 6s - loss: 0.2705 - val_loss: 0.2968
# Epoch 159/2048
# 6s - loss: 0.2702 - val_loss: 0.2964
# Epoch 160/2048
# 6s - loss: 0.2699 - val_loss: 0.2965
# Epoch 161/2048
# 6s - loss: 0.2696 - val_loss: 0.2961
# Epoch 162/2048
# 6s - loss: 0.2694 - val_loss: 0.2961
# Epoch 163/2048
# 6s - loss: 0.2691 - val_loss: 0.2958
# Epoch 164/2048
# 6s - loss: 0.2688 - val_loss: 0.2956
# Epoch 165/2048
# 6s - loss: 0.2685 - val_loss: 0.2957
# Epoch 166/2048
# 6s - loss: 0.2683 - val_loss: 0.2949
# Epoch 167/2048
# 6s - loss: 0.2680 - val_loss: 0.2942
# Epoch 168/2048
# 6s - loss: 0.2678 - val_loss: 0.2938
# Epoch 169/2048
# 6s - loss: 0.2675 - val_loss: 0.2938
# Epoch 170/2048
# 6s - loss: 0.2673 - val_loss: 0.2938
# Epoch 171/2048
# 6s - loss: 0.2671 - val_loss: 0.2936
# Epoch 172/2048
# 6s - loss: 0.2668 - val_loss: 0.2938
# Epoch 173/2048
# 6s - loss: 0.2666 - val_loss: 0.2934
# Epoch 174/2048
# 6s - loss: 0.2663 - val_loss: 0.2932
# Epoch 175/2048
# 6s - loss: 0.2661 - val_loss: 0.2931
# Epoch 176/2048
# 6s - loss: 0.2659 - val_loss: 0.2928
# Epoch 177/2048
# 6s - loss: 0.2657 - val_loss: 0.2919
# Epoch 178/2048
# 6s - loss: 0.2654 - val_loss: 0.2920
# Epoch 179/2048
# 6s - loss: 0.2652 - val_loss: 0.2912
# Epoch 180/2048
# 6s - loss: 0.2650 - val_loss: 0.2914
# Epoch 181/2048
# 6s - loss: 0.2647 - val_loss: 0.2913
# Epoch 182/2048
# 5s - loss: 0.2645 - val_loss: 0.2917
# Epoch 183/2048
# 6s - loss: 0.2643 - val_loss: 0.2908
# Epoch 184/2048
# 6s - loss: 0.2641 - val_loss: 0.2904
# Epoch 185/2048
# 6s - loss: 0.2639 - val_loss: 0.2911
# Epoch 186/2048
# 6s - loss: 0.2637 - val_loss: 0.2907
# Epoch 187/2048
# 6s - loss: 0.2634 - val_loss: 0.2905
# Epoch 188/2048
# 6s - loss: 0.2632 - val_loss: 0.2898
# Epoch 189/2048
# 6s - loss: 0.2631 - val_loss: 0.2900
# Epoch 190/2048
# 6s - loss: 0.2627 - val_loss: 0.2890
# Epoch 191/2048
# 6s - loss: 0.2625 - val_loss: 0.2892
# Epoch 192/2048
# 6s - loss: 0.2623 - val_loss: 0.2886
# Epoch 193/2048
# 6s - loss: 0.2622 - val_loss: 0.2878
# Epoch 194/2048
# 5s - loss: 0.2619 - val_loss: 0.2886
# Epoch 195/2048
# 6s - loss: 0.2617 - val_loss: 0.2884
# Epoch 196/2048
# 6s - loss: 0.2615 - val_loss: 0.2882
# Epoch 197/2048
# 6s - loss: 0.2613 - val_loss: 0.2879
# Epoch 198/2048
# 6s - loss: 0.2611 - val_loss: 0.2878
# Epoch 199/2048
# 6s - loss: 0.2609 - val_loss: 0.2871
# Epoch 200/2048
# 6s - loss: 0.2606 - val_loss: 0.2873
# Epoch 201/2048
# 6s - loss: 0.2604 - val_loss: 0.2864
# Epoch 202/2048
# 6s - loss: 0.2602 - val_loss: 0.2865
# Epoch 203/2048
# 6s - loss: 0.2600 - val_loss: 0.2856
# Epoch 204/2048
# 6s - loss: 0.2598 - val_loss: 0.2859
# Epoch 205/2048
# 6s - loss: 0.2596 - val_loss: 0.2862
# Epoch 206/2048
# 6s - loss: 0.2593 - val_loss: 0.2860
# Epoch 207/2048
# 6s - loss: 0.2591 - val_loss: 0.2853
# Epoch 208/2048
# 6s - loss: 0.2589 - val_loss: 0.2862
# Epoch 209/2048
# 6s - loss: 0.2586 - val_loss: 0.2845
# Epoch 210/2048
# 6s - loss: 0.2584 - val_loss: 0.2841
# Epoch 211/2048
# 6s - loss: 0.2582 - val_loss: 0.2844
# Epoch 212/2048
# 6s - loss: 0.2579 - val_loss: 0.2845
# Epoch 213/2048
# 6s - loss: 0.2577 - val_loss: 0.2833
# Epoch 214/2048
# 6s - loss: 0.2574 - val_loss: 0.2840
# Epoch 215/2048
# 6s - loss: 0.2572 - val_loss: 0.2832
# Epoch 216/2048
# 6s - loss: 0.2570 - val_loss: 0.2834
# Epoch 217/2048
# 6s - loss: 0.2568 - val_loss: 0.2822
# Epoch 218/2048
# 6s - loss: 0.2565 - val_loss: 0.2824
# Epoch 219/2048
# 6s - loss: 0.2563 - val_loss: 0.2821
# Epoch 220/2048
# 6s - loss: 0.2561 - val_loss: 0.2823
# Epoch 221/2048
# 6s - loss: 0.2558 - val_loss: 0.2822
# Epoch 222/2048
# 6s - loss: 0.2556 - val_loss: 0.2812
# Epoch 223/2048
# 6s - loss: 0.2554 - val_loss: 0.2817
# Epoch 224/2048
# 6s - loss: 0.2551 - val_loss: 0.2809
# Epoch 225/2048
# 6s - loss: 0.2549 - val_loss: 0.2810
# Epoch 226/2048
# 6s - loss: 0.2547 - val_loss: 0.2812
# Epoch 227/2048
# 6s - loss: 0.2544 - val_loss: 0.2812
# Epoch 228/2048
# 6s - loss: 0.2542 - val_loss: 0.2809
# Epoch 229/2048
# 6s - loss: 0.2540 - val_loss: 0.2809
# Epoch 230/2048
# 6s - loss: 0.2538 - val_loss: 0.2804
# Epoch 231/2048
# 6s - loss: 0.2535 - val_loss: 0.2800
# Epoch 232/2048
# 6s - loss: 0.2533 - val_loss: 0.2798
# Epoch 233/2048
# 6s - loss: 0.2531 - val_loss: 0.2801
# Epoch 234/2048
# 6s - loss: 0.2529 - val_loss: 0.2786
# Epoch 235/2048
# 6s - loss: 0.2527 - val_loss: 0.2783
# Epoch 236/2048
# 6s - loss: 0.2525 - val_loss: 0.2780
# Epoch 237/2048
# 6s - loss: 0.2522 - val_loss: 0.2788
# Epoch 238/2048
# 6s - loss: 0.2520 - val_loss: 0.2802
# Epoch 239/2048
# 6s - loss: 0.2518 - val_loss: 0.2783
# Epoch 240/2048
# 6s - loss: 0.2516 - val_loss: 0.2790
# Epoch 241/2048
# 6s - loss: 0.2515 - val_loss: 0.2772
# Epoch 242/2048
# 6s - loss: 0.2512 - val_loss: 0.2775
# Epoch 243/2048
# 6s - loss: 0.2510 - val_loss: 0.2764
# Epoch 244/2048
# 6s - loss: 0.2508 - val_loss: 0.2773
# Epoch 245/2048
# 6s - loss: 0.2506 - val_loss: 0.2776
# Epoch 246/2048
# 6s - loss: 0.2504 - val_loss: 0.2766
# Epoch 247/2048
# 6s - loss: 0.2502 - val_loss: 0.2766
# Epoch 248/2048
# 6s - loss: 0.2500 - val_loss: 0.2766
# Epoch 249/2048
# 6s - loss: 0.2498 - val_loss: 0.2765
# Epoch 250/2048
# 6s - loss: 0.2495 - val_loss: 0.2760
# Epoch 251/2048
# 6s - loss: 0.2494 - val_loss: 0.2750
# Epoch 252/2048
# 6s - loss: 0.2491 - val_loss: 0.2755
# Epoch 253/2048
# 5s - loss: 0.2489 - val_loss: 0.2759
# Epoch 254/2048
# 5s - loss: 0.2487 - val_loss: 0.2751
# Epoch 255/2048
# 6s - loss: 0.2484 - val_loss: 0.2754
# Epoch 256/2048
# 6s - loss: 0.2482 - val_loss: 0.2743
# Epoch 257/2048
# 6s - loss: 0.2480 - val_loss: 0.2751
# Epoch 258/2048
# 6s - loss: 0.2478 - val_loss: 0.2753
# Epoch 259/2048
# 6s - loss: 0.2476 - val_loss: 0.2742
# Epoch 260/2048
# 6s - loss: 0.2474 - val_loss: 0.2738
# Epoch 261/2048
# 6s - loss: 0.2471 - val_loss: 0.2741
# Epoch 262/2048
# 6s - loss: 0.2469 - val_loss: 0.2740
# Epoch 263/2048
# 6s - loss: 0.2467 - val_loss: 0.2726
# Epoch 264/2048
# 6s - loss: 0.2464 - val_loss: 0.2728
# Epoch 265/2048
# 6s - loss: 0.2462 - val_loss: 0.2723
# Epoch 266/2048
# 7s - loss: 0.2459 - val_loss: 0.2716
# Epoch 267/2048
# 6s - loss: 0.2457 - val_loss: 0.2720
# Epoch 268/2048
# 6s - loss: 0.2455 - val_loss: 0.2721
# Epoch 269/2048
# 6s - loss: 0.2453 - val_loss: 0.2718
# Epoch 270/2048
# 5s - loss: 0.2451 - val_loss: 0.2724
# Epoch 271/2048
# 6s - loss: 0.2448 - val_loss: 0.2715
# Epoch 272/2048
# 6s - loss: 0.2445 - val_loss: 0.2703
# Epoch 273/2048
# 6s - loss: 0.2443 - val_loss: 0.2710
# Epoch 274/2048
# 6s - loss: 0.2441 - val_loss: 0.2708
# Epoch 275/2048
# 6s - loss: 0.2439 - val_loss: 0.2709
# Epoch 276/2048
# 6s - loss: 0.2437 - val_loss: 0.2698
# Epoch 277/2048
# 6s - loss: 0.2434 - val_loss: 0.2695
# Epoch 278/2048
# 6s - loss: 0.2432 - val_loss: 0.2703
# Epoch 279/2048
# 6s - loss: 0.2430 - val_loss: 0.2696
# Epoch 280/2048
# 6s - loss: 0.2428 - val_loss: 0.2688
# Epoch 281/2048
# 6s - loss: 0.2425 - val_loss: 0.2693
# Epoch 282/2048
# 6s - loss: 0.2423 - val_loss: 0.2691
# Epoch 283/2048
# 6s - loss: 0.2421 - val_loss: 0.2690
# Epoch 284/2048
# 6s - loss: 0.2419 - val_loss: 0.2688
# Epoch 285/2048
# 6s - loss: 0.2416 - val_loss: 0.2689
# Epoch 286/2048
# 6s - loss: 0.2414 - val_loss: 0.2684
# Epoch 287/2048
# 6s - loss: 0.2412 - val_loss: 0.2679
# Epoch 288/2048
# 6s - loss: 0.2409 - val_loss: 0.2673
# Epoch 289/2048
# 6s - loss: 0.2407 - val_loss: 0.2665
# Epoch 290/2048
# 6s - loss: 0.2406 - val_loss: 0.2671
# Epoch 291/2048
# 6s - loss: 0.2403 - val_loss: 0.2671
# Epoch 292/2048
# 6s - loss: 0.2401 - val_loss: 0.2672
# Epoch 293/2048
# 6s - loss: 0.2399 - val_loss: 0.2671
# Epoch 294/2048
# 6s - loss: 0.2397 - val_loss: 0.2666
# Epoch 295/2048
# 6s - loss: 0.2394 - val_loss: 0.2661
# Epoch 296/2048
# 6s - loss: 0.2393 - val_loss: 0.2665
# Epoch 297/2048
# 6s - loss: 0.2391 - val_loss: 0.2667
# Epoch 298/2048
# 6s - loss: 0.2390 - val_loss: 0.2658
# Epoch 299/2048
# 6s - loss: 0.2386 - val_loss: 0.2658
# Epoch 300/2048
# 6s - loss: 0.2384 - val_loss: 0.2657
# Epoch 301/2048
# 6s - loss: 0.2382 - val_loss: 0.2662
# Epoch 302/2048
# 6s - loss: 0.2380 - val_loss: 0.2643
# Epoch 303/2048
# 6s - loss: 0.2378 - val_loss: 0.2651
# Epoch 304/2048
# 6s - loss: 0.2376 - val_loss: 0.2641
# Epoch 305/2048
# 6s - loss: 0.2374 - val_loss: 0.2641
# Epoch 306/2048
# 6s - loss: 0.2371 - val_loss: 0.2637
# Epoch 307/2048
# 6s - loss: 0.2370 - val_loss: 0.2653
# Epoch 308/2048
# 6s - loss: 0.2367 - val_loss: 0.2630
# Epoch 309/2048
# 6s - loss: 0.2365 - val_loss: 0.2643
# Epoch 310/2048
# 6s - loss: 0.2363 - val_loss: 0.2636
# Epoch 311/2048
# 6s - loss: 0.2360 - val_loss: 0.2630
# Epoch 312/2048
# 6s - loss: 0.2358 - val_loss: 0.2627
# Epoch 313/2048
# 6s - loss: 0.2357 - val_loss: 0.2629
# Epoch 314/2048
# 6s - loss: 0.2354 - val_loss: 0.2617
# Epoch 315/2048
# 6s - loss: 0.2351 - val_loss: 0.2619
# Epoch 316/2048
# 6s - loss: 0.2349 - val_loss: 0.2610
# Epoch 317/2048
# 6s - loss: 0.2347 - val_loss: 0.2616
# Epoch 318/2048
# 6s - loss: 0.2345 - val_loss: 0.2614
# Epoch 319/2048
# 6s - loss: 0.2343 - val_loss: 0.2623
# Epoch 320/2048
# 6s - loss: 0.2340 - val_loss: 0.2611
# Epoch 321/2048
# 6s - loss: 0.2339 - val_loss: 0.2607
# Epoch 322/2048
# 6s - loss: 0.2337 - val_loss: 0.2603
# Epoch 323/2048
# 6s - loss: 0.2335 - val_loss: 0.2609
# Epoch 324/2048
# 6s - loss: 0.2333 - val_loss: 0.2607
# Epoch 325/2048
# 6s - loss: 0.2330 - val_loss: 0.2600
# Epoch 326/2048
# 6s - loss: 0.2328 - val_loss: 0.2595
# Epoch 327/2048
# 6s - loss: 0.2326 - val_loss: 0.2598
# Epoch 328/2048
# 6s - loss: 0.2324 - val_loss: 0.2594
# Epoch 329/2048
# 6s - loss: 0.2322 - val_loss: 0.2581
# Epoch 330/2048
# 6s - loss: 0.2320 - val_loss: 0.2596
# Epoch 331/2048
# 6s - loss: 0.2318 - val_loss: 0.2588
# Epoch 332/2048
# 6s - loss: 0.2315 - val_loss: 0.2582
# Epoch 333/2048
# 6s - loss: 0.2313 - val_loss: 0.2578
# Epoch 334/2048
# 6s - loss: 0.2310 - val_loss: 0.2572
# Epoch 335/2048
# 6s - loss: 0.2308 - val_loss: 0.2576
# Epoch 336/2048
# 6s - loss: 0.2306 - val_loss: 0.2573
# Epoch 337/2048
# 6s - loss: 0.2303 - val_loss: 0.2562
# Epoch 338/2048
# 6s - loss: 0.2300 - val_loss: 0.2564
# Epoch 339/2048
# 6s - loss: 0.2297 - val_loss: 0.2572
# Epoch 340/2048
# 6s - loss: 0.2295 - val_loss: 0.2569
# Epoch 341/2048
# 6s - loss: 0.2292 - val_loss: 0.2551
# Epoch 342/2048
# 6s - loss: 0.2289 - val_loss: 0.2559
# Epoch 343/2048
# 6s - loss: 0.2286 - val_loss: 0.2549
# Epoch 344/2048
# 6s - loss: 0.2285 - val_loss: 0.2562
# Epoch 345/2048
# 6s - loss: 0.2282 - val_loss: 0.2557
# Epoch 346/2048
# 6s - loss: 0.2279 - val_loss: 0.2545
# Epoch 347/2048
# 6s - loss: 0.2277 - val_loss: 0.2530
# Epoch 348/2048
# 6s - loss: 0.2274 - val_loss: 0.2543
# Epoch 349/2048
# 6s - loss: 0.2270 - val_loss: 0.2529
# Epoch 350/2048
# 6s - loss: 0.2269 - val_loss: 0.2540
# Epoch 351/2048
# 6s - loss: 0.2266 - val_loss: 0.2529
# Epoch 352/2048
# 5s - loss: 0.2264 - val_loss: 0.2536
# Epoch 353/2048
# 6s - loss: 0.2260 - val_loss: 0.2532
# Epoch 354/2048
# 6s - loss: 0.2258 - val_loss: 0.2521
# Epoch 355/2048
# 6s - loss: 0.2255 - val_loss: 0.2520
# Epoch 356/2048
# 6s - loss: 0.2253 - val_loss: 0.2517
# Epoch 357/2048
# 6s - loss: 0.2250 - val_loss: 0.2520
# Epoch 358/2048
# 6s - loss: 0.2247 - val_loss: 0.2513
# Epoch 359/2048
# 6s - loss: 0.2244 - val_loss: 0.2511
# Epoch 360/2048
# 6s - loss: 0.2241 - val_loss: 0.2505
# Epoch 361/2048
# 6s - loss: 0.2239 - val_loss: 0.2500
# Epoch 362/2048
# 6s - loss: 0.2236 - val_loss: 0.2504
# Epoch 363/2048
# 6s - loss: 0.2233 - val_loss: 0.2499
# Epoch 364/2048
# 6s - loss: 0.2230 - val_loss: 0.2502
# Epoch 365/2048
# 6s - loss: 0.2227 - val_loss: 0.2497
# Epoch 366/2048
# 6s - loss: 0.2223 - val_loss: 0.2490
# Epoch 367/2048
# 6s - loss: 0.2221 - val_loss: 0.2486
# Epoch 368/2048
# 6s - loss: 0.2218 - val_loss: 0.2478
# Epoch 369/2048
# 6s - loss: 0.2215 - val_loss: 0.2470
# Epoch 370/2048
# 6s - loss: 0.2212 - val_loss: 0.2469
# Epoch 371/2048
# 6s - loss: 0.2208 - val_loss: 0.2472
# Epoch 372/2048
# 6s - loss: 0.2205 - val_loss: 0.2476
# Epoch 373/2048
# 6s - loss: 0.2203 - val_loss: 0.2467
# Epoch 374/2048
# 6s - loss: 0.2199 - val_loss: 0.2457
# Epoch 375/2048
# 6s - loss: 0.2196 - val_loss: 0.2464
# Epoch 376/2048
# 6s - loss: 0.2193 - val_loss: 0.2455
# Epoch 377/2048
# 6s - loss: 0.2190 - val_loss: 0.2454
# Epoch 378/2048
# 6s - loss: 0.2187 - val_loss: 0.2460
# Epoch 379/2048
# 6s - loss: 0.2184 - val_loss: 0.2450
# Epoch 380/2048
# 6s - loss: 0.2181 - val_loss: 0.2441
# Epoch 381/2048
# 6s - loss: 0.2178 - val_loss: 0.2440
# Epoch 382/2048
# 6s - loss: 0.2175 - val_loss: 0.2441
# Epoch 383/2048
# 6s - loss: 0.2172 - val_loss: 0.2439
# Epoch 384/2048
# 6s - loss: 0.2170 - val_loss: 0.2432
# Epoch 385/2048
# 6s - loss: 0.2167 - val_loss: 0.2441
# Epoch 386/2048
# 6s - loss: 0.2164 - val_loss: 0.2428
# Epoch 387/2048
# 6s - loss: 0.2164 - val_loss: 0.2427
# Epoch 388/2048
# 6s - loss: 0.2159 - val_loss: 0.2425
# Epoch 389/2048
# 6s - loss: 0.2157 - val_loss: 0.2420
# Epoch 390/2048
# 6s - loss: 0.2154 - val_loss: 0.2421
# Epoch 391/2048
# 6s - loss: 0.2152 - val_loss: 0.2417
# Epoch 392/2048
# 6s - loss: 0.2149 - val_loss: 0.2417
# Epoch 393/2048
# 6s - loss: 0.2145 - val_loss: 0.2410
# Epoch 394/2048
# 6s - loss: 0.2142 - val_loss: 0.2405
# Epoch 395/2048
# 6s - loss: 0.2139 - val_loss: 0.2389
# Epoch 396/2048
# 6s - loss: 0.2136 - val_loss: 0.2403
# Epoch 397/2048
# 6s - loss: 0.2133 - val_loss: 0.2403
# Epoch 398/2048
# 6s - loss: 0.2131 - val_loss: 0.2400
# Epoch 399/2048
# 6s - loss: 0.2128 - val_loss: 0.2400
# Epoch 400/2048
# 6s - loss: 0.2125 - val_loss: 0.2386
# Epoch 401/2048
# 6s - loss: 0.2123 - val_loss: 0.2389
# Epoch 402/2048
# 6s - loss: 0.2120 - val_loss: 0.2379
# Epoch 403/2048
# 6s - loss: 0.2117 - val_loss: 0.2385
# Epoch 404/2048
# 6s - loss: 0.2115 - val_loss: 0.2378
# Epoch 405/2048
# 6s - loss: 0.2112 - val_loss: 0.2375
# Epoch 406/2048
# 6s - loss: 0.2109 - val_loss: 0.2374
# Epoch 407/2048
# 6s - loss: 0.2107 - val_loss: 0.2370
# Epoch 408/2048
# 6s - loss: 0.2105 - val_loss: 0.2374
# Epoch 409/2048
# 6s - loss: 0.2102 - val_loss: 0.2362
# Epoch 410/2048
# 6s - loss: 0.2100 - val_loss: 0.2374
# Epoch 411/2048
# 6s - loss: 0.2098 - val_loss: 0.2361
# Epoch 412/2048
# 6s - loss: 0.2095 - val_loss: 0.2357
# Epoch 413/2048
# 6s - loss: 0.2094 - val_loss: 0.2365
# Epoch 414/2048
# 6s - loss: 0.2091 - val_loss: 0.2357
# Epoch 415/2048
# 6s - loss: 0.2090 - val_loss: 0.2356
# Epoch 416/2048
# 6s - loss: 0.2087 - val_loss: 0.2352
# Epoch 417/2048
# 6s - loss: 0.2085 - val_loss: 0.2345
# Epoch 418/2048
# 6s - loss: 0.2083 - val_loss: 0.2352
# Epoch 419/2048
# 6s - loss: 0.2081 - val_loss: 0.2353
# Epoch 420/2048
# 6s - loss: 0.2079 - val_loss: 0.2341
# Epoch 421/2048
# 6s - loss: 0.2076 - val_loss: 0.2339
# Epoch 422/2048
# 6s - loss: 0.2075 - val_loss: 0.2346
# Epoch 423/2048
# 6s - loss: 0.2072 - val_loss: 0.2338
# Epoch 424/2048
# 6s - loss: 0.2071 - val_loss: 0.2326
# Epoch 425/2048
# 6s - loss: 0.2070 - val_loss: 0.2336
# Epoch 426/2048
# 6s - loss: 0.2067 - val_loss: 0.2331
# Epoch 427/2048
# 6s - loss: 0.2065 - val_loss: 0.2325
# Epoch 428/2048
# 6s - loss: 0.2064 - val_loss: 0.2328
# Epoch 429/2048
# 6s - loss: 0.2061 - val_loss: 0.2326
# Epoch 430/2048
# 6s - loss: 0.2059 - val_loss: 0.2324
# Epoch 431/2048
# 6s - loss: 0.2057 - val_loss: 0.2319
# Epoch 432/2048
# 6s - loss: 0.2056 - val_loss: 0.2319
# Epoch 433/2048
# 6s - loss: 0.2054 - val_loss: 0.2323
# Epoch 434/2048
# 6s - loss: 0.2053 - val_loss: 0.2318
# Epoch 435/2048
# 6s - loss: 0.2050 - val_loss: 0.2306
# Epoch 436/2048
# 6s - loss: 0.2049 - val_loss: 0.2317
# Epoch 437/2048
# 6s - loss: 0.2047 - val_loss: 0.2326
# Epoch 438/2048
# 6s - loss: 0.2046 - val_loss: 0.2311
# Epoch 439/2048
# 6s - loss: 0.2043 - val_loss: 0.2305
# Epoch 440/2048
# 6s - loss: 0.2042 - val_loss: 0.2305
# Epoch 441/2048
# 6s - loss: 0.2041 - val_loss: 0.2311
# Epoch 442/2048
# 6s - loss: 0.2039 - val_loss: 0.2309
# Epoch 443/2048
# 6s - loss: 0.2037 - val_loss: 0.2302
# Epoch 444/2048
# 6s - loss: 0.2036 - val_loss: 0.2292
# Epoch 445/2048
# 5s - loss: 0.2035 - val_loss: 0.2305
# Epoch 446/2048
# 5s - loss: 0.2032 - val_loss: 0.2297
# Epoch 447/2048
# 5s - loss: 0.2031 - val_loss: 0.2296
# Epoch 448/2048
# 6s - loss: 0.2030 - val_loss: 0.2296
# Epoch 449/2048
# 6s - loss: 0.2028 - val_loss: 0.2299
# Epoch 450/2048
# 6s - loss: 0.2027 - val_loss: 0.2294
# Epoch 451/2048
# 6s - loss: 0.2025 - val_loss: 0.2293
# Epoch 452/2048
# 6s - loss: 0.2024 - val_loss: 0.2294
# Epoch 453/2048
# 6s - loss: 0.2023 - val_loss: 0.2286
# Epoch 454/2048
# 6s - loss: 0.2021 - val_loss: 0.2275
# Epoch 455/2048
# 6s - loss: 0.2019 - val_loss: 0.2281
# Epoch 456/2048
# 6s - loss: 0.2018 - val_loss: 0.2277
# Epoch 457/2048
# 6s - loss: 0.2017 - val_loss: 0.2273
# Epoch 458/2048
# 6s - loss: 0.2016 - val_loss: 0.2280
# Epoch 459/2048
# 6s - loss: 0.2014 - val_loss: 0.2283
# Epoch 460/2048
# 6s - loss: 0.2013 - val_loss: 0.2280
# Epoch 461/2048
# 6s - loss: 0.2011 - val_loss: 0.2283
# Epoch 462/2048
# 6s - loss: 0.2009 - val_loss: 0.2278
# Epoch 463/2048
# 6s - loss: 0.2008 - val_loss: 0.2279
# Epoch 464/2048
# 6s - loss: 0.2006 - val_loss: 0.2273
# Epoch 465/2048
# 6s - loss: 0.2005 - val_loss: 0.2273
# Epoch 466/2048
# 6s - loss: 0.2004 - val_loss: 0.2269
# Epoch 467/2048
# 6s - loss: 0.2002 - val_loss: 0.2261
# Epoch 468/2048
# 6s - loss: 0.2001 - val_loss: 0.2276
# Epoch 469/2048
# 6s - loss: 0.2000 - val_loss: 0.2259
# Epoch 470/2048
# 6s - loss: 0.1998 - val_loss: 0.2264
# Epoch 471/2048
# 6s - loss: 0.1997 - val_loss: 0.2263
# Epoch 472/2048
# 6s - loss: 0.1995 - val_loss: 0.2259
# Epoch 473/2048
# 5s - loss: 0.1994 - val_loss: 0.2266
# Epoch 474/2048
# 6s - loss: 0.1993 - val_loss: 0.2254
# Epoch 475/2048
# 6s - loss: 0.1992 - val_loss: 0.2266
# Epoch 476/2048
# 6s - loss: 0.1990 - val_loss: 0.2263
# Epoch 477/2048
# 6s - loss: 0.1989 - val_loss: 0.2259
# Epoch 478/2048
# 6s - loss: 0.1988 - val_loss: 0.2250
# Epoch 479/2048
# 6s - loss: 0.1987 - val_loss: 0.2247
# Epoch 480/2048
# 6s - loss: 0.1986 - val_loss: 0.2259
# Epoch 481/2048
# 6s - loss: 0.1984 - val_loss: 0.2252
# Epoch 482/2048
# 6s - loss: 0.1983 - val_loss: 0.2249
# Epoch 483/2048
# 6s - loss: 0.1982 - val_loss: 0.2242
# Epoch 484/2048
# 6s - loss: 0.1981 - val_loss: 0.2245
# Epoch 485/2048
# 6s - loss: 0.1979 - val_loss: 0.2256
# Epoch 486/2048
# 6s - loss: 0.1978 - val_loss: 0.2239
# Epoch 487/2048
# 6s - loss: 0.1976 - val_loss: 0.2249
# Epoch 488/2048
# 6s - loss: 0.1975 - val_loss: 0.2251
# Epoch 489/2048
# 6s - loss: 0.1973 - val_loss: 0.2241
# Epoch 490/2048
# 6s - loss: 0.1972 - val_loss: 0.2242
# Epoch 491/2048
# 6s - loss: 0.1971 - val_loss: 0.2242
# Epoch 492/2048
# 7s - loss: 0.1970 - val_loss: 0.2235
# Epoch 493/2048
# 6s - loss: 0.1969 - val_loss: 0.2236
# Epoch 494/2048
# 6s - loss: 0.1966 - val_loss: 0.2238
# Epoch 495/2048
# 6s - loss: 0.1965 - val_loss: 0.2239
# Epoch 496/2048
# 6s - loss: 0.1964 - val_loss: 0.2225
# Epoch 497/2048
# 6s - loss: 0.1962 - val_loss: 0.2238
# Epoch 498/2048
# 6s - loss: 0.1960 - val_loss: 0.2230
# Epoch 499/2048
# 6s - loss: 0.1958 - val_loss: 0.2239
# Epoch 500/2048
# 6s - loss: 0.1957 - val_loss: 0.2225
# Epoch 501/2048
# 6s - loss: 0.1956 - val_loss: 0.2218
# Epoch 502/2048
# 6s - loss: 0.1954 - val_loss: 0.2223
# Epoch 503/2048
# 6s - loss: 0.1954 - val_loss: 0.2204
# Epoch 504/2048
# 6s - loss: 0.1951 - val_loss: 0.2216
# Epoch 505/2048
# 6s - loss: 0.1950 - val_loss: 0.2220
# Epoch 506/2048
# 6s - loss: 0.1949 - val_loss: 0.2215
# Epoch 507/2048
# 6s - loss: 0.1948 - val_loss: 0.2219
# Epoch 508/2048
# 6s - loss: 0.1946 - val_loss: 0.2221
# Epoch 509/2048
# 6s - loss: 0.1946 - val_loss: 0.2224
# Epoch 510/2048
# 6s - loss: 0.1945 - val_loss: 0.2208
# Epoch 511/2048
# 6s - loss: 0.1943 - val_loss: 0.2217
# Epoch 512/2048
# 6s - loss: 0.1942 - val_loss: 0.2219
# Epoch 513/2048
# 6s - loss: 0.1940 - val_loss: 0.2221
# Epoch 514/2048
# 6s - loss: 0.1940 - val_loss: 0.2210
# Epoch 515/2048
# 6s - loss: 0.1938 - val_loss: 0.2206
# Epoch 516/2048
# 6s - loss: 0.1937 - val_loss: 0.2204
# Epoch 517/2048
# 6s - loss: 0.1935 - val_loss: 0.2210
# Epoch 518/2048
# 6s - loss: 0.1934 - val_loss: 0.2209
# Epoch 519/2048
# 6s - loss: 0.1933 - val_loss: 0.2205
# Epoch 520/2048
# 6s - loss: 0.1931 - val_loss: 0.2202
# Epoch 521/2048
# 6s - loss: 0.1929 - val_loss: 0.2194
# Epoch 522/2048
# 6s - loss: 0.1929 - val_loss: 0.2210
# Epoch 523/2048
# 6s - loss: 0.1927 - val_loss: 0.2204
# Epoch 524/2048
# 6s - loss: 0.1927 - val_loss: 0.2197
# Epoch 525/2048
# 6s - loss: 0.1926 - val_loss: 0.2201
# Epoch 526/2048
# 6s - loss: 0.1923 - val_loss: 0.2195
# Epoch 527/2048
# 6s - loss: 0.1923 - val_loss: 0.2196
# Epoch 528/2048
# 6s - loss: 0.1922 - val_loss: 0.2191
# Epoch 529/2048
# 6s - loss: 0.1921 - val_loss: 0.2200
# Epoch 530/2048
# 6s - loss: 0.1919 - val_loss: 0.2188
# Epoch 531/2048
# 6s - loss: 0.1918 - val_loss: 0.2177
# Epoch 532/2048
# 6s - loss: 0.1918 - val_loss: 0.2186
# Epoch 533/2048
# 6s - loss: 0.1916 - val_loss: 0.2186
# Epoch 534/2048
# 6s - loss: 0.1915 - val_loss: 0.2192
# Epoch 535/2048
# 6s - loss: 0.1914 - val_loss: 0.2191
# Epoch 536/2048
# 6s - loss: 0.1913 - val_loss: 0.2184
# Epoch 537/2048
# 6s - loss: 0.1912 - val_loss: 0.2187
# Epoch 538/2048
# 6s - loss: 0.1911 - val_loss: 0.2182
# Epoch 539/2048
# 6s - loss: 0.1910 - val_loss: 0.2174
# Epoch 540/2048
# 5s - loss: 0.1909 - val_loss: 0.2182
# Epoch 541/2048
# 6s - loss: 0.1908 - val_loss: 0.2184
# Epoch 542/2048
# 6s - loss: 0.1907 - val_loss: 0.2176
# Epoch 543/2048
# 5s - loss: 0.1906 - val_loss: 0.2181
# Epoch 544/2048
# 6s - loss: 0.1905 - val_loss: 0.2174
# Epoch 545/2048
# 6s - loss: 0.1905 - val_loss: 0.2176
# Epoch 546/2048
# 6s - loss: 0.1903 - val_loss: 0.2170
# Epoch 547/2048
# 6s - loss: 0.1903 - val_loss: 0.2173
# Epoch 548/2048
# 6s - loss: 0.1902 - val_loss: 0.2169
# Epoch 549/2048
# 6s - loss: 0.1901 - val_loss: 0.2177
# Epoch 550/2048
# 6s - loss: 0.1901 - val_loss: 0.2166
# Epoch 551/2048
# 6s - loss: 0.1899 - val_loss: 0.2167
# Epoch 552/2048
# 6s - loss: 0.1899 - val_loss: 0.2162
# Epoch 553/2048
# 6s - loss: 0.1898 - val_loss: 0.2184
# Epoch 554/2048
# 5s - loss: 0.1897 - val_loss: 0.2167
# Epoch 555/2048
# 6s - loss: 0.1896 - val_loss: 0.2162
# Epoch 556/2048
# 6s - loss: 0.1895 - val_loss: 0.2180
# Epoch 557/2048
# 6s - loss: 0.1894 - val_loss: 0.2174
# Epoch 558/2048
# 6s - loss: 0.1893 - val_loss: 0.2163
# Epoch 559/2048
# 6s - loss: 0.1892 - val_loss: 0.2160
# Epoch 560/2048
# 6s - loss: 0.1892 - val_loss: 0.2164
# Epoch 561/2048
# 6s - loss: 0.1891 - val_loss: 0.2166
# Epoch 562/2048
# 6s - loss: 0.1891 - val_loss: 0.2164
# Epoch 563/2048
# 5s - loss: 0.1889 - val_loss: 0.2170
# Epoch 564/2048
# 6s - loss: 0.1888 - val_loss: 0.2167
# Epoch 565/2048
# 6s - loss: 0.1888 - val_loss: 0.2160
# Epoch 566/2048
# 6s - loss: 0.1887 - val_loss: 0.2157
# Epoch 567/2048
# 6s - loss: 0.1886 - val_loss: 0.2169
# Epoch 568/2048
# 6s - loss: 0.1886 - val_loss: 0.2152
# Epoch 569/2048
# 6s - loss: 0.1885 - val_loss: 0.2146
# Epoch 570/2048
# 6s - loss: 0.1885 - val_loss: 0.2146
# Epoch 571/2048
# 6s - loss: 0.1883 - val_loss: 0.2153
# Epoch 572/2048
# 6s - loss: 0.1882 - val_loss: 0.2151
# Epoch 573/2048
# 6s - loss: 0.1882 - val_loss: 0.2154
# Epoch 574/2048
# 6s - loss: 0.1881 - val_loss: 0.2165
# Epoch 575/2048
# 6s - loss: 0.1881 - val_loss: 0.2151
# Epoch 576/2048
# 6s - loss: 0.1880 - val_loss: 0.2153
# Epoch 577/2048
# 6s - loss: 0.1879 - val_loss: 0.2147
# Epoch 578/2048
# 6s - loss: 0.1879 - val_loss: 0.2145
# Epoch 579/2048
# 6s - loss: 0.1878 - val_loss: 0.2158
# Epoch 580/2048
# 6s - loss: 0.1877 - val_loss: 0.2146
# Epoch 581/2048
# 6s - loss: 0.1877 - val_loss: 0.2150
# Epoch 582/2048
# 6s - loss: 0.1876 - val_loss: 0.2138
# Epoch 583/2048
# 6s - loss: 0.1875 - val_loss: 0.2151
# Epoch 584/2048
# 6s - loss: 0.1874 - val_loss: 0.2149
# Epoch 585/2048
# 6s - loss: 0.1875 - val_loss: 0.2145
# Epoch 586/2048
# 6s - loss: 0.1873 - val_loss: 0.2155
# Epoch 587/2048
# 5s - loss: 0.1872 - val_loss: 0.2145
# Epoch 588/2048
# 6s - loss: 0.1872 - val_loss: 0.2136
# Epoch 589/2048
# 6s - loss: 0.1871 - val_loss: 0.2138
# Epoch 590/2048
# 6s - loss: 0.1870 - val_loss: 0.2144
# Epoch 591/2048
# 6s - loss: 0.1869 - val_loss: 0.2145
# Epoch 592/2048
# 6s - loss: 0.1869 - val_loss: 0.2137
# Epoch 593/2048
# 5s - loss: 0.1867 - val_loss: 0.2145
# Epoch 594/2048
# 6s - loss: 0.1868 - val_loss: 0.2134
# Epoch 595/2048
# 6s - loss: 0.1866 - val_loss: 0.2144
# Epoch 596/2048
# 5s - loss: 0.1865 - val_loss: 0.2153
# Epoch 597/2048
# 6s - loss: 0.1865 - val_loss: 0.2143
# Epoch 598/2048
# 6s - loss: 0.1864 - val_loss: 0.2135
# Epoch 599/2048
# 6s - loss: 0.1863 - val_loss: 0.2141
# Epoch 600/2048
# 6s - loss: 0.1863 - val_loss: 0.2129
# Epoch 601/2048
# 6s - loss: 0.1861 - val_loss: 0.2131
# Epoch 602/2048
# 6s - loss: 0.1861 - val_loss: 0.2130
# Epoch 603/2048
# 6s - loss: 0.1860 - val_loss: 0.2133
# Epoch 604/2048
# 6s - loss: 0.1860 - val_loss: 0.2128
# Epoch 605/2048
# 6s - loss: 0.1859 - val_loss: 0.2133
# Epoch 606/2048
# 6s - loss: 0.1859 - val_loss: 0.2128
# Epoch 607/2048
# 6s - loss: 0.1858 - val_loss: 0.2129
# Epoch 608/2048
# 6s - loss: 0.1857 - val_loss: 0.2124
# Epoch 609/2048
# 6s - loss: 0.1857 - val_loss: 0.2126
# Epoch 610/2048
# 6s - loss: 0.1856 - val_loss: 0.2128
# Epoch 611/2048
# 6s - loss: 0.1855 - val_loss: 0.2139
# Epoch 612/2048
# 6s - loss: 0.1855 - val_loss: 0.2143
# Epoch 613/2048
# 6s - loss: 0.1857 - val_loss: 0.2131
# Epoch 614/2048
# 6s - loss: 0.1853 - val_loss: 0.2121
# Epoch 615/2048
# 6s - loss: 0.1853 - val_loss: 0.2128
# Epoch 616/2048
# 6s - loss: 0.1852 - val_loss: 0.2119
# Epoch 617/2048
# 6s - loss: 0.1852 - val_loss: 0.2125
# Epoch 618/2048
# 6s - loss: 0.1851 - val_loss: 0.2132
# Epoch 619/2048
# 6s - loss: 0.1851 - val_loss: 0.2123
# Epoch 620/2048
# 6s - loss: 0.1850 - val_loss: 0.2122
# Epoch 621/2048
# 6s - loss: 0.1849 - val_loss: 0.2118
# Epoch 622/2048
# 6s - loss: 0.1848 - val_loss: 0.2118
# Epoch 623/2048
# 6s - loss: 0.1848 - val_loss: 0.2120
# Epoch 624/2048
# 6s - loss: 0.1847 - val_loss: 0.2122
# Epoch 625/2048
# 6s - loss: 0.1848 - val_loss: 0.2116
# Epoch 626/2048
# 6s - loss: 0.1846 - val_loss: 0.2120
# Epoch 627/2048
# 6s - loss: 0.1845 - val_loss: 0.2106
# Epoch 628/2048
# 6s - loss: 0.1845 - val_loss: 0.2115
# Epoch 629/2048
# 6s - loss: 0.1844 - val_loss: 0.2116
# Epoch 630/2048
# 6s - loss: 0.1844 - val_loss: 0.2110
# Epoch 631/2048
# 6s - loss: 0.1843 - val_loss: 0.2112
# Epoch 632/2048
# 6s - loss: 0.1843 - val_loss: 0.2113
# Epoch 633/2048
# 6s - loss: 0.1842 - val_loss: 0.2106
# Epoch 634/2048
# 6s - loss: 0.1841 - val_loss: 0.2119
# Epoch 635/2048
# 6s - loss: 0.1841 - val_loss: 0.2109
# Epoch 636/2048
# 6s - loss: 0.1840 - val_loss: 0.2110
# Epoch 637/2048
# 6s - loss: 0.1839 - val_loss: 0.2113
# Epoch 638/2048
# 6s - loss: 0.1840 - val_loss: 0.2109
# Epoch 639/2048
# 6s - loss: 0.1838 - val_loss: 0.2104
# Epoch 640/2048
# 6s - loss: 0.1837 - val_loss: 0.2107
# Epoch 641/2048
# 6s - loss: 0.1837 - val_loss: 0.2100
# Epoch 642/2048
# 6s - loss: 0.1836 - val_loss: 0.2111
# Epoch 643/2048
# 6s - loss: 0.1835 - val_loss: 0.2109
# Epoch 644/2048
# 6s - loss: 0.1836 - val_loss: 0.2117
# Epoch 645/2048
# 6s - loss: 0.1835 - val_loss: 0.2107
# Epoch 646/2048
# 5s - loss: 0.1834 - val_loss: 0.2101
# Epoch 647/2048
# 6s - loss: 0.1834 - val_loss: 0.2112
# Epoch 648/2048
# 6s - loss: 0.1833 - val_loss: 0.2108
# Epoch 649/2048
# 6s - loss: 0.1833 - val_loss: 0.2099
# Epoch 650/2048
# 6s - loss: 0.1832 - val_loss: 0.2106
# Epoch 651/2048
# 6s - loss: 0.1831 - val_loss: 0.2095
# Epoch 652/2048
# 6s - loss: 0.1830 - val_loss: 0.2106
# Epoch 653/2048
# 6s - loss: 0.1830 - val_loss: 0.2102
# Epoch 654/2048
# 6s - loss: 0.1831 - val_loss: 0.2101
# Epoch 655/2048
# 6s - loss: 0.1830 - val_loss: 0.2098
# Epoch 656/2048
# 6s - loss: 0.1829 - val_loss: 0.2102
# Epoch 657/2048
# 6s - loss: 0.1829 - val_loss: 0.2099
# Epoch 658/2048
# 6s - loss: 0.1828 - val_loss: 0.2102
# Epoch 659/2048
# 6s - loss: 0.1827 - val_loss: 0.2102
# Epoch 660/2048
# 6s - loss: 0.1827 - val_loss: 0.2096
# Epoch 661/2048
# 6s - loss: 0.1829 - val_loss: 0.2103
# Epoch 662/2048
# 6s - loss: 0.1826 - val_loss: 0.2095
# Epoch 663/2048
# 6s - loss: 0.1825 - val_loss: 0.2103
# Epoch 664/2048
# 6s - loss: 0.1825 - val_loss: 0.2099
# Epoch 665/2048
# 6s - loss: 0.1825 - val_loss: 0.2101
# Epoch 666/2048
# 6s - loss: 0.1824 - val_loss: 0.2096
# Epoch 667/2048
# 6s - loss: 0.1824 - val_loss: 0.2095
# Epoch 668/2048
# 7s - loss: 0.1824 - val_loss: 0.2086
# Epoch 669/2048
# 6s - loss: 0.1823 - val_loss: 0.2099
# Epoch 670/2048
# 6s - loss: 0.1822 - val_loss: 0.2092
# Epoch 671/2048
# 6s - loss: 0.1822 - val_loss: 0.2096
# Epoch 672/2048
# 6s - loss: 0.1821 - val_loss: 0.2093
# Epoch 673/2048
# 6s - loss: 0.1821 - val_loss: 0.2094
# Epoch 674/2048
# 5s - loss: 0.1821 - val_loss: 0.2102
# Epoch 675/2048
# 6s - loss: 0.1820 - val_loss: 0.2090
# Epoch 676/2048
# 6s - loss: 0.1820 - val_loss: 0.2087
# Epoch 677/2048
# 6s - loss: 0.1818 - val_loss: 0.2084
# Epoch 678/2048
# 6s - loss: 0.1818 - val_loss: 0.2092
# Epoch 679/2048
# 6s - loss: 0.1819 - val_loss: 0.2086
# Epoch 680/2048
# 6s - loss: 0.1818 - val_loss: 0.2086
# Epoch 681/2048
# 6s - loss: 0.1817 - val_loss: 0.2082
# Epoch 682/2048
# 6s - loss: 0.1817 - val_loss: 0.2088
# Epoch 683/2048
# 6s - loss: 0.1817 - val_loss: 0.2097
# Epoch 684/2048
# 6s - loss: 0.1816 - val_loss: 0.2088
# Epoch 685/2048
# 6s - loss: 0.1816 - val_loss: 0.2089
# Epoch 686/2048
# 5s - loss: 0.1815 - val_loss: 0.2087
# Epoch 687/2048
# 6s - loss: 0.1815 - val_loss: 0.2082
# Epoch 688/2048
# 6s - loss: 0.1814 - val_loss: 0.2086
# Epoch 689/2048
# 6s - loss: 0.1814 - val_loss: 0.2079
# Epoch 690/2048
# 6s - loss: 0.1813 - val_loss: 0.2077
# Epoch 691/2048
# 5s - loss: 0.1813 - val_loss: 0.2083
# Epoch 692/2048
# 5s - loss: 0.1813 - val_loss: 0.2087
# Epoch 693/2048
# 6s - loss: 0.1812 - val_loss: 0.2089
# Epoch 694/2048
# 6s - loss: 0.1812 - val_loss: 0.2088
# Epoch 695/2048
# 5s - loss: 0.1811 - val_loss: 0.2074
# Epoch 696/2048
# 5s - loss: 0.1811 - val_loss: 0.2081
# Epoch 697/2048
# 6s - loss: 0.1810 - val_loss: 0.2089
# Epoch 698/2048
# 6s - loss: 0.1810 - val_loss: 0.2083
# Epoch 699/2048
# 6s - loss: 0.1810 - val_loss: 0.2086
# Epoch 700/2048
# 5s - loss: 0.1810 - val_loss: 0.2080
# Epoch 701/2048
# 5s - loss: 0.1809 - val_loss: 0.2086
# Epoch 702/2048
# 5s - loss: 0.1809 - val_loss: 0.2088
# Epoch 703/2048
# 6s - loss: 0.1808 - val_loss: 0.2073
# Epoch 704/2048
# 6s - loss: 0.1807 - val_loss: 0.2086
# Epoch 705/2048
# 5s - loss: 0.1807 - val_loss: 0.2081
# Epoch 706/2048
# 6s - loss: 0.1807 - val_loss: 0.2083
# Epoch 707/2048
# 7s - loss: 0.1807 - val_loss: 0.2079
# Epoch 708/2048
# 7s - loss: 0.1805 - val_loss: 0.2074
# Epoch 709/2048
# 7s - loss: 0.1806 - val_loss: 0.2075
# Epoch 710/2048
# 7s - loss: 0.1805 - val_loss: 0.2084
# Epoch 711/2048
# 8s - loss: 0.1805 - val_loss: 0.2070
# Epoch 712/2048
# 7s - loss: 0.1805 - val_loss: 0.2073
# Epoch 713/2048
# 7s - loss: 0.1804 - val_loss: 0.2073
# Epoch 714/2048
# 7s - loss: 0.1804 - val_loss: 0.2072
# Epoch 715/2048
# 7s - loss: 0.1804 - val_loss: 0.2063
# Epoch 716/2048
# 7s - loss: 0.1803 - val_loss: 0.2071
# Epoch 717/2048
# 7s - loss: 0.1802 - val_loss: 0.2073
# Epoch 718/2048
# 7s - loss: 0.1802 - val_loss: 0.2080
# Epoch 719/2048
# 6s - loss: 0.1803 - val_loss: 0.2069
# Epoch 720/2048
# 7s - loss: 0.1801 - val_loss: 0.2070
# Epoch 721/2048
# 8s - loss: 0.1801 - val_loss: 0.2067
# Epoch 722/2048
# 6s - loss: 0.1800 - val_loss: 0.2081
# Epoch 723/2048
# 7s - loss: 0.1800 - val_loss: 0.2072
# Epoch 724/2048
# 7s - loss: 0.1800 - val_loss: 0.2080
# Epoch 725/2048
# 7s - loss: 0.1799 - val_loss: 0.2068
# Epoch 726/2048
# 7s - loss: 0.1799 - val_loss: 0.2067
# Epoch 727/2048
# 7s - loss: 0.1799 - val_loss: 0.2070
# Epoch 728/2048
# 7s - loss: 0.1799 - val_loss: 0.2064
# Epoch 729/2048
# 7s - loss: 0.1798 - val_loss: 0.2069
# Epoch 730/2048
# 7s - loss: 0.1797 - val_loss: 0.2068
# Epoch 731/2048
# 7s - loss: 0.1797 - val_loss: 0.2066
# Epoch 732/2048
# 7s - loss: 0.1796 - val_loss: 0.2053
# Epoch 733/2048
# 7s - loss: 0.1797 - val_loss: 0.2070
# Epoch 734/2048
# 7s - loss: 0.1796 - val_loss: 0.2076
# Epoch 735/2048
# 7s - loss: 0.1795 - val_loss: 0.2071
# Epoch 736/2048
# 7s - loss: 0.1795 - val_loss: 0.2068
# Epoch 737/2048
# 7s - loss: 0.1795 - val_loss: 0.2062
# Epoch 738/2048
# 6s - loss: 0.1794 - val_loss: 0.2060
# Epoch 739/2048
# 6s - loss: 0.1795 - val_loss: 0.2066
# Epoch 740/2048
# 6s - loss: 0.1793 - val_loss: 0.2057
# Epoch 741/2048
# 5s - loss: 0.1794 - val_loss: 0.2061
# Epoch 742/2048
# 5s - loss: 0.1793 - val_loss: 0.2064
# Epoch 743/2048
# 5s - loss: 0.1793 - val_loss: 0.2066
# Epoch 744/2048
# 5s - loss: 0.1793 - val_loss: 0.2069
# Epoch 745/2048
# 5s - loss: 0.1793 - val_loss: 0.2060
# Epoch 746/2048
# 5s - loss: 0.1791 - val_loss: 0.2059
# Epoch 747/2048
# 5s - loss: 0.1791 - val_loss: 0.2068
# Epoch 748/2048
# 5s - loss: 0.1790 - val_loss: 0.2068
# Epoch 749/2048
# 5s - loss: 0.1790 - val_loss: 0.2066
# Epoch 750/2048
# 5s - loss: 0.1789 - val_loss: 0.2067
# Epoch 751/2048
# 5s - loss: 0.1788 - val_loss: 0.2058
# Epoch 752/2048
# 5s - loss: 0.1788 - val_loss: 0.2061
# Epoch 753/2048
# 5s - loss: 0.1788 - val_loss: 0.2055
# Epoch 754/2048
# 5s - loss: 0.1788 - val_loss: 0.2056
# Epoch 755/2048
# 5s - loss: 0.1787 - val_loss: 0.2056
# Epoch 756/2048
# 5s - loss: 0.1787 - val_loss: 0.2070
# Epoch 757/2048
# 5s - loss: 0.1788 - val_loss: 0.2066
# Epoch 758/2048
# 5s - loss: 0.1787 - val_loss: 0.2059
# Epoch 759/2048
# 5s - loss: 0.1786 - val_loss: 0.2055
# Epoch 760/2048
# 5s - loss: 0.1786 - val_loss: 0.2053
# Epoch 761/2048
# 5s - loss: 0.1786 - val_loss: 0.2063
# Epoch 762/2048
# 5s - loss: 0.1785 - val_loss: 0.2065
# Epoch 763/2048
# 5s - loss: 0.1785 - val_loss: 0.2062
# Epoch 764/2048
# 6s - loss: 0.1784 - val_loss: 0.2048
# Epoch 765/2048
# 5s - loss: 0.1784 - val_loss: 0.2057
# Epoch 766/2048
# 5s - loss: 0.1784 - val_loss: 0.2060
# Epoch 767/2048
# 5s - loss: 0.1784 - val_loss: 0.2056
# Epoch 768/2048
# 5s - loss: 0.1783 - val_loss: 0.2054
# Epoch 769/2048
# 5s - loss: 0.1782 - val_loss: 0.2051
# Epoch 770/2048
# 5s - loss: 0.1782 - val_loss: 0.2052
# Epoch 771/2048
# 5s - loss: 0.1782 - val_loss: 0.2056
# Epoch 772/2048
# 5s - loss: 0.1781 - val_loss: 0.2055
# Epoch 773/2048
# 5s - loss: 0.1782 - val_loss: 0.2057
# Epoch 774/2048
# 5s - loss: 0.1780 - val_loss: 0.2057
# Epoch 775/2048
# 5s - loss: 0.1780 - val_loss: 0.2051
# Epoch 776/2048
# 5s - loss: 0.1781 - val_loss: 0.2057
# Epoch 777/2048
# 5s - loss: 0.1780 - val_loss: 0.2061
# Epoch 778/2048
# 6s - loss: 0.1780 - val_loss: 0.2046
# Epoch 779/2048
# 5s - loss: 0.1779 - val_loss: 0.2056
# Epoch 780/2048
# 5s - loss: 0.1779 - val_loss: 0.2050
# Epoch 781/2048
# 5s - loss: 0.1778 - val_loss: 0.2053
# Epoch 782/2048
# 5s - loss: 0.1779 - val_loss: 0.2051
# Epoch 783/2048
# 6s - loss: 0.1778 - val_loss: 0.2046
# Epoch 784/2048
# 5s - loss: 0.1777 - val_loss: 0.2046
# Epoch 785/2048
# 5s - loss: 0.1777 - val_loss: 0.2055
# Epoch 786/2048
# 6s - loss: 0.1777 - val_loss: 0.2044
# Epoch 787/2048
# 5s - loss: 0.1777 - val_loss: 0.2049
# Epoch 788/2048
# 5s - loss: 0.1775 - val_loss: 0.2052
# Epoch 789/2048
# 5s - loss: 0.1776 - val_loss: 0.2056
# Epoch 790/2048
# 5s - loss: 0.1775 - val_loss: 0.2046
# Epoch 791/2048
# 5s - loss: 0.1775 - val_loss: 0.2064
# Epoch 792/2048
# 5s - loss: 0.1775 - val_loss: 0.2049
# Epoch 793/2048
# 5s - loss: 0.1774 - val_loss: 0.2048
# Epoch 794/2048
# 5s - loss: 0.1774 - val_loss: 0.2045
# Epoch 795/2048
# 5s - loss: 0.1774 - val_loss: 0.2045
# Epoch 796/2048
# 5s - loss: 0.1772 - val_loss: 0.2053
# Epoch 797/2048
# 5s - loss: 0.1773 - val_loss: 0.2047
# Epoch 798/2048
# 5s - loss: 0.1773 - val_loss: 0.2057
# Epoch 799/2048
# 6s - loss: 0.1772 - val_loss: 0.2035
# Epoch 800/2048
# 5s - loss: 0.1772 - val_loss: 0.2046
# Epoch 801/2048
# 5s - loss: 0.1772 - val_loss: 0.2037
# Epoch 802/2048
# 5s - loss: 0.1771 - val_loss: 0.2047
# Epoch 803/2048
# 5s - loss: 0.1770 - val_loss: 0.2041
# Epoch 804/2048
# 5s - loss: 0.1771 - val_loss: 0.2052
# Epoch 805/2048
# 5s - loss: 0.1771 - val_loss: 0.2048
# Epoch 806/2048
# 5s - loss: 0.1770 - val_loss: 0.2046
# Epoch 807/2048
# 5s - loss: 0.1769 - val_loss: 0.2035
# Epoch 808/2048
# 6s - loss: 0.1769 - val_loss: 0.2034
# Epoch 809/2048
# 5s - loss: 0.1770 - val_loss: 0.2045
# Epoch 810/2048
# 5s - loss: 0.1769 - val_loss: 0.2060
# Epoch 811/2048
# 5s - loss: 0.1770 - val_loss: 0.2048
# Epoch 812/2048
# 5s - loss: 0.1768 - val_loss: 0.2046
# Epoch 813/2048
# 5s - loss: 0.1767 - val_loss: 0.2035
# Epoch 814/2048
# 5s - loss: 0.1767 - val_loss: 0.2042
# Epoch 815/2048
# 5s - loss: 0.1767 - val_loss: 0.2039
# Epoch 816/2048
# 5s - loss: 0.1767 - val_loss: 0.2045
# Epoch 817/2048
# 5s - loss: 0.1767 - val_loss: 0.2038
# Epoch 818/2048
# 5s - loss: 0.1766 - val_loss: 0.2039
# Epoch 819/2048
# 5s - loss: 0.1765 - val_loss: 0.2034
# Epoch 820/2048
# 6s - loss: 0.1766 - val_loss: 0.2029
# Epoch 821/2048
# 5s - loss: 0.1765 - val_loss: 0.2036
# Epoch 822/2048
# 5s - loss: 0.1765 - val_loss: 0.2036
# Epoch 823/2048
# 5s - loss: 0.1765 - val_loss: 0.2039
# Epoch 824/2048
# 5s - loss: 0.1764 - val_loss: 0.2044
# Epoch 825/2048
# 5s - loss: 0.1764 - val_loss: 0.2049
# Epoch 826/2048
# 5s - loss: 0.1764 - val_loss: 0.2042
# Epoch 827/2048
# 5s - loss: 0.1763 - val_loss: 0.2045
# Epoch 828/2048
# 5s - loss: 0.1763 - val_loss: 0.2038
# Epoch 829/2048
# 6s - loss: 0.1763 - val_loss: 0.2028
# Epoch 830/2048
# 5s - loss: 0.1762 - val_loss: 0.2045
# Epoch 831/2048
# 5s - loss: 0.1763 - val_loss: 0.2040
# Epoch 832/2048
# 5s - loss: 0.1761 - val_loss: 0.2030
# Epoch 833/2048
# 5s - loss: 0.1761 - val_loss: 0.2036
# Epoch 834/2048
# 5s - loss: 0.1761 - val_loss: 0.2042
# Epoch 835/2048
# 5s - loss: 0.1760 - val_loss: 0.2035
# Epoch 836/2048
# 5s - loss: 0.1760 - val_loss: 0.2039
# Epoch 837/2048
# 5s - loss: 0.1761 - val_loss: 0.2040
# Epoch 838/2048
# 5s - loss: 0.1760 - val_loss: 0.2037
# Epoch 839/2048
# 5s - loss: 0.1760 - val_loss: 0.2036
# Epoch 840/2048
# 5s - loss: 0.1759 - val_loss: 0.2032
# Epoch 841/2048
# 5s - loss: 0.1759 - val_loss: 0.2044
# Epoch 842/2048
# 5s - loss: 0.1759 - val_loss: 0.2040
# Epoch 843/2048
# 5s - loss: 0.1759 - val_loss: 0.2031
# Epoch 844/2048
# 5s - loss: 0.1758 - val_loss: 0.2029
# Epoch 845/2048
# 5s - loss: 0.1757 - val_loss: 0.2033
# Epoch 846/2048
# 5s - loss: 0.1758 - val_loss: 0.2034
# Epoch 847/2048
# 6s - loss: 0.1757 - val_loss: 0.2035
# Epoch 848/2048
# 5s - loss: 0.1757 - val_loss: 0.2033
# Epoch 849/2048
# 6s - loss: 0.1757 - val_loss: 0.2026
# Epoch 850/2048
# 5s - loss: 0.1756 - val_loss: 0.2027
# Epoch 851/2048
# 5s - loss: 0.1756 - val_loss: 0.2034
# Epoch 852/2048
# 5s - loss: 0.1756 - val_loss: 0.2032
# Epoch 853/2048
# 5s - loss: 0.1755 - val_loss: 0.2024
# Epoch 854/2048
# 5s - loss: 0.1756 - val_loss: 0.2032
# Epoch 855/2048
# 6s - loss: 0.1757 - val_loss: 0.2031
# Epoch 856/2048
# 5s - loss: 0.1754 - val_loss: 0.2030
# Epoch 857/2048
# 5s - loss: 0.1754 - val_loss: 0.2027
# Epoch 858/2048
# 5s - loss: 0.1754 - val_loss: 0.2030
# Epoch 859/2048
# 6s - loss: 0.1754 - val_loss: 0.2022
# Epoch 860/2048
# 5s - loss: 0.1754 - val_loss: 0.2028
# Epoch 861/2048
# 5s - loss: 0.1754 - val_loss: 0.2023
# Epoch 862/2048
# 5s - loss: 0.1753 - val_loss: 0.2026
# Epoch 863/2048
# 5s - loss: 0.1753 - val_loss: 0.2025
# Epoch 864/2048
# 5s - loss: 0.1753 - val_loss: 0.2036
# Epoch 865/2048
# 5s - loss: 0.1759 - val_loss: 0.2025
# Epoch 866/2048
# 5s - loss: 0.1751 - val_loss: 0.2026
# Epoch 867/2048
# 6s - loss: 0.1751 - val_loss: 0.2022
# Epoch 868/2048
# 5s - loss: 0.1752 - val_loss: 0.2030
# Epoch 869/2048
# 5s - loss: 0.1751 - val_loss: 0.2030
# Epoch 870/2048
# 5s - loss: 0.1751 - val_loss: 0.2022
# Epoch 871/2048
# 5s - loss: 0.1752 - val_loss: 0.2034
# Epoch 872/2048
# 5s - loss: 0.1751 - val_loss: 0.2024
# Epoch 873/2048
# 6s - loss: 0.1750 - val_loss: 0.2018
# Epoch 874/2048
# 5s - loss: 0.1750 - val_loss: 0.2027
# Epoch 875/2048
# 5s - loss: 0.1749 - val_loss: 0.2024
# Epoch 876/2048
# 5s - loss: 0.1750 - val_loss: 0.2021
# Epoch 877/2048
# 5s - loss: 0.1749 - val_loss: 0.2027
# Epoch 878/2048
# 5s - loss: 0.1749 - val_loss: 0.2022
# Epoch 879/2048
# 6s - loss: 0.1749 - val_loss: 0.2024
# Epoch 880/2048
# 5s - loss: 0.1749 - val_loss: 0.2020
# Epoch 881/2048
# 5s - loss: 0.1748 - val_loss: 0.2024
# Epoch 882/2048
# 5s - loss: 0.1747 - val_loss: 0.2030
# Epoch 883/2048
# 6s - loss: 0.1748 - val_loss: 0.2017
# Epoch 884/2048
# 5s - loss: 0.1748 - val_loss: 0.2020
# Epoch 885/2048
# 5s - loss: 0.1747 - val_loss: 0.2020
# Epoch 886/2048
# 5s - loss: 0.1747 - val_loss: 0.2018
# Epoch 887/2048
# 6s - loss: 0.1747 - val_loss: 0.2012
# Epoch 888/2048
# 5s - loss: 0.1747 - val_loss: 0.2016
# Epoch 889/2048
# 5s - loss: 0.1746 - val_loss: 0.2012
# Epoch 890/2048
# 5s - loss: 0.1746 - val_loss: 0.2017
# Epoch 891/2048
# 5s - loss: 0.1745 - val_loss: 0.2029
# Epoch 892/2048
# 5s - loss: 0.1745 - val_loss: 0.2018
# Epoch 893/2048
# 5s - loss: 0.1745 - val_loss: 0.2016
# Epoch 894/2048
# 5s - loss: 0.1745 - val_loss: 0.2014
# Epoch 895/2048
# 5s - loss: 0.1745 - val_loss: 0.2017
# Epoch 896/2048
# 5s - loss: 0.1744 - val_loss: 0.2014
# Epoch 897/2048
# 5s - loss: 0.1744 - val_loss: 0.2020
# Epoch 898/2048
# 5s - loss: 0.1744 - val_loss: 0.2016
# Epoch 899/2048
# 5s - loss: 0.1743 - val_loss: 0.2017
# Epoch 900/2048
# 5s - loss: 0.1743 - val_loss: 0.2013
# Epoch 901/2048
# 5s - loss: 0.1744 - val_loss: 0.2015
# Epoch 902/2048
# 5s - loss: 0.1743 - val_loss: 0.2021
# Epoch 903/2048
# 5s - loss: 0.1742 - val_loss: 0.2012
# Epoch 904/2048
# 5s - loss: 0.1742 - val_loss: 0.2030
# Epoch 905/2048
# 5s - loss: 0.1742 - val_loss: 0.2019
# Epoch 906/2048
# 5s - loss: 0.1742 - val_loss: 0.2019
# Epoch 907/2048
# 6s - loss: 0.1742 - val_loss: 0.2011
# Epoch 908/2048
# 6s - loss: 0.1742 - val_loss: 0.2009
# Epoch 909/2048
# 5s - loss: 0.1740 - val_loss: 0.2010
# Epoch 910/2048
# 5s - loss: 0.1740 - val_loss: 0.2017
# Epoch 911/2048
# 6s - loss: 0.1740 - val_loss: 0.2031
# Epoch 912/2048
# 5s - loss: 0.1741 - val_loss: 0.2019
# Epoch 913/2048
# 5s - loss: 0.1739 - val_loss: 0.2014
# Epoch 914/2048
# 5s - loss: 0.1740 - val_loss: 0.2020
# Epoch 915/2048
# 6s - loss: 0.1740 - val_loss: 0.2006
# Epoch 916/2048
# 5s - loss: 0.1739 - val_loss: 0.2017
# Epoch 917/2048
# 5s - loss: 0.1740 - val_loss: 0.2013
# Epoch 918/2048
# 5s - loss: 0.1738 - val_loss: 0.2015
# Epoch 919/2048
# 5s - loss: 0.1738 - val_loss: 0.2011
# Epoch 920/2048
# 5s - loss: 0.1738 - val_loss: 0.2012
# Epoch 921/2048
# 5s - loss: 0.1737 - val_loss: 0.2009
# Epoch 922/2048
# 5s - loss: 0.1738 - val_loss: 0.2013
# Epoch 923/2048
# 5s - loss: 0.1737 - val_loss: 0.2003
# Epoch 924/2048
# 5s - loss: 0.1737 - val_loss: 0.2014
# ...
# 5s - loss: 0.1737 - val_loss: 0.2018
# Epoch 926/2048
# 5s - loss: 0.1737 - val_loss: 0.2015
# Epoch 927/2048
# 5s - loss: 0.1736 - val_loss: 0.2004
# Epoch 928/2048
# 6s - loss: 0.1737 - val_loss: 0.2003
# Epoch 929/2048
# 6s - loss: 0.1737 - val_loss: 0.2002
# Epoch 930/2048
# 5s - loss: 0.1736 - val_loss: 0.2008
# Epoch 931/2048
# 5s - loss: 0.1736 - val_loss: 0.2008
# Epoch 932/2048
# 5s - loss: 0.1736 - val_loss: 0.2007
# Epoch 933/2048
# 6s - loss: 0.1735 - val_loss: 0.2011
# Epoch 934/2048
# 5s - loss: 0.1736 - val_loss: 0.2008
# Epoch 935/2048
# 5s - loss: 0.1735 - val_loss: 0.2004
# Epoch 936/2048
# 5s - loss: 0.1734 - val_loss: 0.2008
# Epoch 937/2048
# 5s - loss: 0.1734 - val_loss: 0.2031
# Epoch 938/2048
# 5s - loss: 0.1735 - val_loss: 0.2008
# Epoch 939/2048
# 5s - loss: 0.1734 - val_loss: 0.2005
# Epoch 940/2048
# 5s - loss: 0.1733 - val_loss: 0.2005
# Epoch 941/2048
# 6s - loss: 0.1733 - val_loss: 0.2001
# Epoch 942/2048
# 5s - loss: 0.1733 - val_loss: 0.2011
# Epoch 943/2048
# 5s - loss: 0.1733 - val_loss: 0.2010
# Epoch 944/2048
# 5s - loss: 0.1733 - val_loss: 0.2012
# Epoch 945/2048
# 5s - loss: 0.1732 - val_loss: 0.2006
# Epoch 946/2048
# 5s - loss: 0.1732 - val_loss: 0.2014
# Epoch 947/2048
# 5s - loss: 0.1731 - val_loss: 0.2011
# Epoch 948/2048
# 6s - loss: 0.1732 - val_loss: 0.2000
# Epoch 949/2048
# 5s - loss: 0.1731 - val_loss: 0.2003
# Epoch 950/2048
# 5s - loss: 0.1731 - val_loss: 0.2009
# Epoch 951/2048
# 5s - loss: 0.1731 - val_loss: 0.2005
# Epoch 952/2048
# 5s - loss: 0.1731 - val_loss: 0.2005
# Epoch 953/2048
# 6s - loss: 0.1730 - val_loss: 0.1997
# Epoch 954/2048
# 5s - loss: 0.1730 - val_loss: 0.2008
# Epoch 955/2048
# 5s - loss: 0.1730 - val_loss: 0.2009
# Epoch 956/2048
# 5s - loss: 0.1730 - val_loss: 0.2000
# Epoch 957/2048
# 5s - loss: 0.1730 - val_loss: 0.2005
# Epoch 958/2048
# 5s - loss: 0.1729 - val_loss: 0.1997
# Epoch 959/2048
# 6s - loss: 0.1728 - val_loss: 0.1995
# Epoch 960/2048
# 6s - loss: 0.1729 - val_loss: 0.2002
# Epoch 961/2048
# 5s - loss: 0.1728 - val_loss: 0.2002
# Epoch 962/2048
# 5s - loss: 0.1728 - val_loss: 0.2007
# Epoch 963/2048
# 5s - loss: 0.1728 - val_loss: 0.2002
# Epoch 964/2048
# 5s - loss: 0.1728 - val_loss: 0.2002
# Epoch 965/2048
# 5s - loss: 0.1727 - val_loss: 0.2005
# Epoch 966/2048
# 5s - loss: 0.1727 - val_loss: 0.2000
# Epoch 967/2048
# 5s - loss: 0.1727 - val_loss: 0.2027
# Epoch 968/2048
# 5s - loss: 0.1731 - val_loss: 0.2011
# Epoch 969/2048
# 5s - loss: 0.1726 - val_loss: 0.2000
# Epoch 970/2048
# 5s - loss: 0.1727 - val_loss: 0.1997
# Epoch 971/2048
# 5s - loss: 0.1728 - val_loss: 0.1998
# Epoch 972/2048
# 5s - loss: 0.1726 - val_loss: 0.1997
# Epoch 973/2048
# 5s - loss: 0.1726 - val_loss: 0.2003
# Epoch 974/2048
# 5s - loss: 0.1726 - val_loss: 0.2004
# Epoch 975/2048
# 5s - loss: 0.1726 - val_loss: 0.1996
# Epoch 976/2048
# 5s - loss: 0.1725 - val_loss: 0.1995
# Epoch 977/2048
# 5s - loss: 0.1725 - val_loss: 0.1997
# Epoch 978/2048
# 5s - loss: 0.1725 - val_loss: 0.1999
# Epoch 979/2048
# 5s - loss: 0.1725 - val_loss: 0.1996
# Epoch 980/2048
# 5s - loss: 0.1724 - val_loss: 0.2005
# Epoch 981/2048
# 5s - loss: 0.1724 - val_loss: 0.1998
# Epoch 982/2048
# 5s - loss: 0.1725 - val_loss: 0.1995
# Epoch 983/2048
# 6s - loss: 0.1723 - val_loss: 0.1989
# Epoch 984/2048
# 5s - loss: 0.1724 - val_loss: 0.1991
# Epoch 985/2048
# 5s - loss: 0.1724 - val_loss: 0.2002
# Epoch 986/2048
# 5s - loss: 0.1724 - val_loss: 0.1990
# Epoch 987/2048
# 5s - loss: 0.1723 - val_loss: 0.1995
# Epoch 988/2048
# 5s - loss: 0.1723 - val_loss: 0.2004
# Epoch 989/2048
# 5s - loss: 0.1723 - val_loss: 0.1988
# Epoch 990/2048
# 5s - loss: 0.1722 - val_loss: 0.2002
# Epoch 991/2048
# 5s - loss: 0.1722 - val_loss: 0.2003
# Epoch 992/2048
# 5s - loss: 0.1722 - val_loss: 0.1994
# Epoch 993/2048
# 5s - loss: 0.1722 - val_loss: 0.2006
# Epoch 994/2048
# 5s - loss: 0.1722 - val_loss: 0.1994
# Epoch 995/2048
# 5s - loss: 0.1723 - val_loss: 0.2003
# Epoch 996/2048
# 5s - loss: 0.1721 - val_loss: 0.1996
# Epoch 997/2048
# 5s - loss: 0.1720 - val_loss: 0.1995
# Epoch 998/2048
# 5s - loss: 0.1721 - val_loss: 0.1996
# Epoch 999/2048
# 5s - loss: 0.1721 - val_loss: 0.2005
# Epoch 1000/2048
# 5s - loss: 0.1720 - val_loss: 0.1997
# Epoch 1001/2048
# 5s - loss: 0.1720 - val_loss: 0.1994
# Epoch 1002/2048
# 5s - loss: 0.1720 - val_loss: 0.2002
# Epoch 1003/2048
# 5s - loss: 0.1719 - val_loss: 0.1997
# Epoch 1004/2048
# 5s - loss: 0.1722 - val_loss: 0.2007
# Epoch 1005/2048
# 5s - loss: 0.1720 - val_loss: 0.1998
# Epoch 1006/2048
# 5s - loss: 0.1718 - val_loss: 0.1993
# Epoch 1007/2048
# 6s - loss: 0.1719 - val_loss: 0.1987
# Epoch 1008/2048
# 5s - loss: 0.1719 - val_loss: 0.1990
# Epoch 1009/2048
# 5s - loss: 0.1718 - val_loss: 0.1989
# Epoch 1010/2048
# 5s - loss: 0.1718 - val_loss: 0.1988
# Epoch 1011/2048
# 5s - loss: 0.1718 - val_loss: 0.2003
# Epoch 1012/2048
# 5s - loss: 0.1718 - val_loss: 0.1993
# Epoch 1013/2048
# 5s - loss: 0.1718 - val_loss: 0.2000
# Epoch 1014/2048
# 5s - loss: 0.1717 - val_loss: 0.1991
# Epoch 1015/2048
# 5s - loss: 0.1718 - val_loss: 0.1990
# Epoch 1016/2048
# 5s - loss: 0.1718 - val_loss: 0.1992
# Epoch 1017/2048
# 5s - loss: 0.1717 - val_loss: 0.1988
# Epoch 1018/2048
# 5s - loss: 0.1717 - val_loss: 0.1988
# Epoch 1019/2048
# 5s - loss: 0.1717 - val_loss: 0.1994
# Epoch 1020/2048
# 5s - loss: 0.1717 - val_loss: 0.1988
# Epoch 1021/2048
# 5s - loss: 0.1716 - val_loss: 0.2001
# Epoch 1022/2048
# 5s - loss: 0.1716 - val_loss: 0.2000
# Epoch 1023/2048
# 5s - loss: 0.1716 - val_loss: 0.1997
# Epoch 1024/2048
# 6s - loss: 0.1716 - val_loss: 0.1986
# Epoch 1025/2048
# 5s - loss: 0.1716 - val_loss: 0.1994
# Epoch 1026/2048
# 5s - loss: 0.1715 - val_loss: 0.1991
# Epoch 1027/2048
# 5s - loss: 0.1715 - val_loss: 0.1987
# Epoch 1028/2048
# 5s - loss: 0.1714 - val_loss: 0.1992
# Epoch 1029/2048
# 5s - loss: 0.1715 - val_loss: 0.1989
# Epoch 1030/2048
# 5s - loss: 0.1714 - val_loss: 0.1986
# Epoch 1031/2048
# 5s - loss: 0.1715 - val_loss: 0.1991
# Epoch 1032/2048
# 6s - loss: 0.1714 - val_loss: 0.1979
# Epoch 1033/2048
# 5s - loss: 0.1714 - val_loss: 0.1989
# Epoch 1034/2048
# 5s - loss: 0.1713 - val_loss: 0.1989
# Epoch 1035/2048
# 5s - loss: 0.1714 - val_loss: 0.1992
# Epoch 1036/2048
# 5s - loss: 0.1713 - val_loss: 0.1986
# Epoch 1037/2048
# 6s - loss: 0.1713 - val_loss: 0.1987
# Epoch 1038/2048
# 5s - loss: 0.1713 - val_loss: 0.1982
# Epoch 1039/2048
# 5s - loss: 0.1713 - val_loss: 0.1989
# Epoch 1040/2048
# 5s - loss: 0.1713 - val_loss: 0.1983
# Epoch 1041/2048
# 5s - loss: 0.1712 - val_loss: 0.1983
# Epoch 1042/2048
# 5s - loss: 0.1712 - val_loss: 0.1993
# Epoch 1043/2048
# 5s - loss: 0.1712 - val_loss: 0.1990
# Epoch 1044/2048
# 5s - loss: 0.1712 - val_loss: 0.1992
# Epoch 1045/2048
# 5s - loss: 0.1711 - val_loss: 0.1997
# Epoch 1046/2048
# 5s - loss: 0.1712 - val_loss: 0.1989
# Epoch 1047/2048
# 5s - loss: 0.1711 - val_loss: 0.1982
# Epoch 1048/2048
# 5s - loss: 0.1711 - val_loss: 0.1990
# Epoch 1049/2048
# 5s - loss: 0.1711 - val_loss: 0.1982
# Epoch 1050/2048
# 6s - loss: 0.1710 - val_loss: 0.1979
# Epoch 1051/2048
# 5s - loss: 0.1711 - val_loss: 0.1980
# Epoch 1052/2048
# 5s - loss: 0.1710 - val_loss: 0.1990
# Epoch 1053/2048
# 6s - loss: 0.1711 - val_loss: 0.1978
# Epoch 1054/2048
# 5s - loss: 0.1710 - val_loss: 0.1992
# Epoch 1055/2048
# 5s - loss: 0.1709 - val_loss: 0.1981
# Epoch 1056/2048
# 5s - loss: 0.1710 - val_loss: 0.1984
# Epoch 1057/2048
# 5s - loss: 0.1709 - val_loss: 0.1982
# Epoch 1058/2048
# 5s - loss: 0.1709 - val_loss: 0.1984
# Epoch 1059/2048
# 5s - loss: 0.1709 - val_loss: 0.1983
# Epoch 1060/2048
# 6s - loss: 0.1709 - val_loss: 0.1978
# Epoch 1061/2048
# 5s - loss: 0.1708 - val_loss: 0.1989
# Epoch 1062/2048
# 5s - loss: 0.1709 - val_loss: 0.1980
# Epoch 1063/2048
# 5s - loss: 0.1708 - val_loss: 0.1992
# Epoch 1064/2048
# 5s - loss: 0.1708 - val_loss: 0.1979
# Epoch 1065/2048
# 5s - loss: 0.1709 - val_loss: 0.1985
# Epoch 1066/2048
# 5s - loss: 0.1708 - val_loss: 0.1980
# Epoch 1067/2048
# 5s - loss: 0.1708 - val_loss: 0.1974
# Epoch 1068/2048
# 5s - loss: 0.1707 - val_loss: 0.1981
# Epoch 1069/2048
# 5s - loss: 0.1707 - val_loss: 0.1980
# Epoch 1070/2048
# 5s - loss: 0.1707 - val_loss: 0.1978
# Epoch 1071/2048
# 5s - loss: 0.1707 - val_loss: 0.1991
# Epoch 1072/2048
# 5s - loss: 0.1707 - val_loss: 0.1982
# Epoch 1073/2048
# 5s - loss: 0.1706 - val_loss: 0.1990
# Epoch 1074/2048
# 5s - loss: 0.1707 - val_loss: 0.1983
# Epoch 1075/2048
# 5s - loss: 0.1706 - val_loss: 0.1974
# Epoch 1076/2048
# 5s - loss: 0.1706 - val_loss: 0.1978
# Epoch 1077/2048
# 5s - loss: 0.1706 - val_loss: 0.1988
# Epoch 1078/2048
# 5s - loss: 0.1705 - val_loss: 0.1981
# Epoch 1079/2048
# 5s - loss: 0.1705 - val_loss: 0.1979
# Epoch 1080/2048
# 5s - loss: 0.1705 - val_loss: 0.1987
# Epoch 1081/2048
# 5s - loss: 0.1705 - val_loss: 0.1975
# Epoch 1082/2048
# 5s - loss: 0.1705 - val_loss: 0.1981
# Epoch 1083/2048
# 5s - loss: 0.1704 - val_loss: 0.1977
# Epoch 1084/2048
# 5s - loss: 0.1705 - val_loss: 0.1981
# Epoch 1085/2048
# 5s - loss: 0.1705 - val_loss: 0.1981
# Epoch 1086/2048
# 6s - loss: 0.1704 - val_loss: 0.1974
# Epoch 1087/2048
# 6s - loss: 0.1704 - val_loss: 0.1973
# Epoch 1088/2048
# 5s - loss: 0.1705 - val_loss: 0.1979
# Epoch 1089/2048
# 5s - loss: 0.1703 - val_loss: 0.1981
# Epoch 1090/2048
# 6s - loss: 0.1704 - val_loss: 0.1978
# Epoch 1091/2048
# 5s - loss: 0.1704 - val_loss: 0.1975
# Epoch 1092/2048
# 5s - loss: 0.1703 - val_loss: 0.1975
# Epoch 1093/2048
# 5s - loss: 0.1703 - val_loss: 0.1973
# Epoch 1094/2048
# 5s - loss: 0.1703 - val_loss: 0.1974
# Epoch 1095/2048
# 5s - loss: 0.1703 - val_loss: 0.1985
# Epoch 1096/2048
# 5s - loss: 0.1703 - val_loss: 0.1982
# Epoch 1097/2048
# 5s - loss: 0.1703 - val_loss: 0.1974
# Epoch 1098/2048
# 6s - loss: 0.1702 - val_loss: 0.1987
# Epoch 1099/2048
# 6s - loss: 0.1704 - val_loss: 0.1972
# Epoch 1100/2048
# 5s - loss: 0.1701 - val_loss: 0.1984
# Epoch 1101/2048
# 5s - loss: 0.1701 - val_loss: 0.1987
# Epoch 1102/2048
# 5s - loss: 0.1701 - val_loss: 0.1975
# Epoch 1103/2048
# 5s - loss: 0.1702 - val_loss: 0.1972
# Epoch 1104/2048
# 5s - loss: 0.1701 - val_loss: 0.1976
# Epoch 1105/2048
# 5s - loss: 0.1701 - val_loss: 0.1972
# Epoch 1106/2048
# 5s - loss: 0.1701 - val_loss: 0.1978
# Epoch 1107/2048
# 6s - loss: 0.1701 - val_loss: 0.1968
# Epoch 1108/2048
# 5s - loss: 0.1701 - val_loss: 0.1977
# Epoch 1109/2048
# 5s - loss: 0.1700 - val_loss: 0.1982
# Epoch 1110/2048
# 5s - loss: 0.1701 - val_loss: 0.1973
# Epoch 1111/2048
# 5s - loss: 0.1700 - val_loss: 0.1975
# Epoch 1112/2048
# 5s - loss: 0.1700 - val_loss: 0.1986
# Epoch 1113/2048
# 5s - loss: 0.1700 - val_loss: 0.1970
# Epoch 1114/2048
# 5s - loss: 0.1699 - val_loss: 0.1973
# Epoch 1115/2048
# 5s - loss: 0.1699 - val_loss: 0.1970
# Epoch 1116/2048
# 5s - loss: 0.1699 - val_loss: 0.1975
# Epoch 1117/2048
# 5s - loss: 0.1700 - val_loss: 0.1973
# Epoch 1118/2048
# 6s - loss: 0.1700 - val_loss: 0.1966
# Epoch 1119/2048
# 5s - loss: 0.1699 - val_loss: 0.1974
# Epoch 1120/2048
# 5s - loss: 0.1699 - val_loss: 0.1972
# Epoch 1121/2048
# 5s - loss: 0.1699 - val_loss: 0.1974
# Epoch 1122/2048
# 5s - loss: 0.1699 - val_loss: 0.1967
# Epoch 1123/2048
# 5s - loss: 0.1698 - val_loss: 0.1976
# Epoch 1124/2048
# 5s - loss: 0.1699 - val_loss: 0.1969
# Epoch 1125/2048
# 5s - loss: 0.1699 - val_loss: 0.1972
# Epoch 1126/2048
# 5s - loss: 0.1698 - val_loss: 0.1968
# Epoch 1127/2048
# 5s - loss: 0.1698 - val_loss: 0.1971
# Epoch 1128/2048
# 5s - loss: 0.1697 - val_loss: 0.1971
# Epoch 1129/2048
# 5s - loss: 0.1697 - val_loss: 0.1972
# Epoch 1130/2048
# 5s - loss: 0.1697 - val_loss: 0.1967
# Epoch 1131/2048
# 5s - loss: 0.1697 - val_loss: 0.1973
# Epoch 1132/2048
# 5s - loss: 0.1697 - val_loss: 0.1971
# Epoch 1133/2048
# 5s - loss: 0.1696 - val_loss: 0.1968
# Epoch 1134/2048
# 6s - loss: 0.1697 - val_loss: 0.1958
# Epoch 1135/2048
# 5s - loss: 0.1696 - val_loss: 0.1981
# Epoch 1136/2048
# 5s - loss: 0.1697 - val_loss: 0.1971
# Epoch 1137/2048
# 5s - loss: 0.1696 - val_loss: 0.1976
# Epoch 1138/2048
# 5s - loss: 0.1696 - val_loss: 0.1969
# Epoch 1139/2048
# 5s - loss: 0.1696 - val_loss: 0.1971
# Epoch 1140/2048
# 5s - loss: 0.1696 - val_loss: 0.1980
# Epoch 1141/2048
# 5s - loss: 0.1695 - val_loss: 0.1972
# Epoch 1142/2048
# 5s - loss: 0.1697 - val_loss: 0.1972
# Epoch 1143/2048
# 5s - loss: 0.1696 - val_loss: 0.1968
# Epoch 1144/2048
# 5s - loss: 0.1695 - val_loss: 0.1968
# Epoch 1145/2048
# 5s - loss: 0.1695 - val_loss: 0.1965
# Epoch 1146/2048
# 5s - loss: 0.1694 - val_loss: 0.1967
# Epoch 1147/2048
# 5s - loss: 0.1694 - val_loss: 0.1963
# Epoch 1148/2048
# 5s - loss: 0.1694 - val_loss: 0.1987
# Epoch 1149/2048
# 5s - loss: 0.1695 - val_loss: 0.1975
# Epoch 1150/2048
# 5s - loss: 0.1694 - val_loss: 0.1968
# Epoch 1151/2048
# 5s - loss: 0.1694 - val_loss: 0.1965
# Epoch 1152/2048
# 6s - loss: 0.1693 - val_loss: 0.1972
# Epoch 1153/2048
# 5s - loss: 0.1694 - val_loss: 0.1974
# Epoch 1154/2048
# 5s - loss: 0.1694 - val_loss: 0.1971
# Epoch 1155/2048
# 5s - loss: 0.1693 - val_loss: 0.1972
# Epoch 1156/2048
# 5s - loss: 0.1693 - val_loss: 0.1972
# Epoch 1157/2048
# 6s - loss: 0.1693 - val_loss: 0.1967
# Epoch 1158/2048
# 5s - loss: 0.1693 - val_loss: 0.1970
# Epoch 1159/2048
# 5s - loss: 0.1693 - val_loss: 0.1960
# Epoch 1160/2048
# 5s - loss: 0.1696 - val_loss: 0.1979
# Epoch 1161/2048
# 5s - loss: 0.1693 - val_loss: 0.1966
# Epoch 1162/2048
# 5s - loss: 0.1693 - val_loss: 0.1972
# Epoch 1163/2048
# 5s - loss: 0.1692 - val_loss: 0.1966
# Epoch 1164/2048
# 5s - loss: 0.1692 - val_loss: 0.1966
# Epoch 1165/2048
# 5s - loss: 0.1692 - val_loss: 0.1966
# Epoch 1166/2048
# 5s - loss: 0.1692 - val_loss: 0.1969
# Epoch 1167/2048
# 6s - loss: 0.1692 - val_loss: 0.1958
# Epoch 1168/2048
# 6s - loss: 0.1691 - val_loss: 0.1955
# Epoch 1169/2048
# 5s - loss: 0.1691 - val_loss: 0.1963
# Epoch 1170/2048
# 5s - loss: 0.1691 - val_loss: 0.1968
# Epoch 1171/2048
# 5s - loss: 0.1691 - val_loss: 0.1960
# Epoch 1172/2048
# 5s - loss: 0.1691 - val_loss: 0.1967
# Epoch 1173/2048
# 5s - loss: 0.1691 - val_loss: 0.1972
# Epoch 1174/2048
# 5s - loss: 0.1691 - val_loss: 0.1960
# Epoch 1175/2048
# 5s - loss: 0.1690 - val_loss: 0.1973
# Epoch 1176/2048
# 5s - loss: 0.1691 - val_loss: 0.1967
# Epoch 1177/2048
# 5s - loss: 0.1690 - val_loss: 0.1966
# Epoch 1178/2048
# 5s - loss: 0.1691 - val_loss: 0.1973
# Epoch 1179/2048
# 5s - loss: 0.1690 - val_loss: 0.1964
# Epoch 1180/2048
# 5s - loss: 0.1690 - val_loss: 0.1960
# Epoch 1181/2048
# 5s - loss: 0.1690 - val_loss: 0.1968
# Epoch 1182/2048
# 5s - loss: 0.1690 - val_loss: 0.1968
# Epoch 1183/2048
# 5s - loss: 0.1689 - val_loss: 0.1957
# Epoch 1184/2048
# 5s - loss: 0.1690 - val_loss: 0.1964
# Epoch 1185/2048
# 5s - loss: 0.1689 - val_loss: 0.1962
# Epoch 1186/2048
# 5s - loss: 0.1690 - val_loss: 0.1970
# Epoch 1187/2048
# 5s - loss: 0.1689 - val_loss: 0.1974
# Epoch 1188/2048
# 5s - loss: 0.1689 - val_loss: 0.1967
# Epoch 1189/2048
# 5s - loss: 0.1689 - val_loss: 0.1958
# Epoch 1190/2048
# 5s - loss: 0.1688 - val_loss: 0.1970
# Epoch 1191/2048
# 5s - loss: 0.1690 - val_loss: 0.1957
# Epoch 1192/2048
# 5s - loss: 0.1688 - val_loss: 0.1958
# Epoch 1193/2048
# 5s - loss: 0.1689 - val_loss: 0.1962
# Epoch 1194/2048
# 6s - loss: 0.1689 - val_loss: 0.1954
# Epoch 1195/2048
# 5s - loss: 0.1688 - val_loss: 0.1958
# Epoch 1196/2048
# 5s - loss: 0.1689 - val_loss: 0.1961
# Epoch 1197/2048
# 5s - loss: 0.1688 - val_loss: 0.1972
# Epoch 1198/2048
# 5s - loss: 0.1688 - val_loss: 0.1971
# Epoch 1199/2048
# 5s - loss: 0.1688 - val_loss: 0.1960
# Epoch 1200/2048
# 5s - loss: 0.1687 - val_loss: 0.1972
# Epoch 1201/2048
# 5s - loss: 0.1688 - val_loss: 0.1962
# Epoch 1202/2048
# 5s - loss: 0.1687 - val_loss: 0.1962
# Epoch 1203/2048
# 5s - loss: 0.1688 - val_loss: 0.1964
# Epoch 1204/2048
# 5s - loss: 0.1687 - val_loss: 0.1962
# Epoch 1205/2048
# 5s - loss: 0.1687 - val_loss: 0.1967
# Epoch 1206/2048
# 5s - loss: 0.1687 - val_loss: 0.1964
# Epoch 1207/2048
# 6s - loss: 0.1686 - val_loss: 0.1966
# Epoch 1208/2048
# 5s - loss: 0.1686 - val_loss: 0.1969
# Epoch 1209/2048
# 5s - loss: 0.1686 - val_loss: 0.1958
# Epoch 1210/2048
# 5s - loss: 0.1686 - val_loss: 0.1957
# Epoch 1211/2048
# 5s - loss: 0.1685 - val_loss: 0.1956
# Epoch 1212/2048
# 5s - loss: 0.1686 - val_loss: 0.1966
# Epoch 1213/2048
# 5s - loss: 0.1686 - val_loss: 0.1958
# Epoch 1214/2048
# 5s - loss: 0.1685 - val_loss: 0.1955
# Epoch 1215/2048
# 5s - loss: 0.1686 - val_loss: 0.1966
# Epoch 1216/2048
# 5s - loss: 0.1685 - val_loss: 0.1961
# Epoch 1217/2048
# 5s - loss: 0.1685 - val_loss: 0.1979
# Epoch 1218/2048
# 5s - loss: 0.1685 - val_loss: 0.1961
# Epoch 1219/2048
# 5s - loss: 0.1686 - val_loss: 0.1954
# Epoch 1220/2048
# 5s - loss: 0.1685 - val_loss: 0.1979
# Epoch 1221/2048
# 5s - loss: 0.1685 - val_loss: 0.1966
# Epoch 1222/2048
# 5s - loss: 0.1684 - val_loss: 0.1956
# Epoch 1223/2048
# 5s - loss: 0.1684 - val_loss: 0.1960
# Epoch 1224/2048
# 5s - loss: 0.1685 - val_loss: 0.1961
# Epoch 1225/2048
# 5s - loss: 0.1684 - val_loss: 0.1958
# Epoch 1226/2048
# 5s - loss: 0.1684 - val_loss: 0.1975
# Epoch 1227/2048
# 5s - loss: 0.1684 - val_loss: 0.1960
# Epoch 01226: early stopping

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name2))

# %%
X_test_filtered = X_test_norm[:, feature_filter]

# %%
# Exclude validation set
X_train_wo_valid_filtered = X_train_wo_valid[:, feature_filter]

# %%
X_test_filtered.shape
# Out:
# (19086, 1272)

# %%
# Run predictions
ae_pred_filtered = autoencoder.predict(X_test_filtered)
ae_pred_filtered_train = autoencoder.predict(X_train_wo_valid_filtered)

# %%
ae_pred_filtered_train.shape
# Out:
# (51739, 1272)

# %%
pickle.dump(ae_pred_filtered, open(model_directory + "ae_pred_filtered.p", "wb"))
pickle.dump(ae_pred_filtered_train, open(model_directory + "ae_pred_filtered_train.p", "wb"))

# %%
ae_pred_filtered = pickle.load(open(model_directory + "ae_pred_filtered.p", "rb"))
ae_pred_filtered_train = pickle.load(open(model_directory + "ae_pred_filtered_train.p", "rb"))

# %%
# Here magic happens
bias = np.mean(np.abs(ae_pred_filtered_train - X_train_wo_valid_filtered), axis=0)
bias_rms = np.std(np.abs(ae_pred_filtered_train - X_train_wo_valid_filtered), axis=0)

# %%
adjusted_pred = np.abs(ae_pred_filtered - X_test_filtered - bias) / bias_rms
ae_error_filtered_adjusted = get_error_df(X_test_filtered, adjusted_pred, mode='allmean')

# %%
ae_error_filtered = get_error_df(X_test_filtered, ae_pred_filtered, mode="topn", n_highest=100)
ae_error_filtered_train = get_error_df(X_train_wo_valid_filtered, ae_pred_filtered_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error_filtered, open(model_directory + "ae_error_filtered.p", "wb"))
pickle.dump(ae_error_filtered_train, open(model_directory + "ae_error_filtered_train.p", "wb"))

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plot_lumi_error(np.zeros(ae_pred.shape), X_test_norm, title='Mean square score across lumisections')
plot_lumi_error(ae_pred, X_test_norm, title='AE reco errror across lumisections')
plot_lumi_error(ae_pred_filtered, X_test_filtered, 
                title='AE filtered reco errror across lumisections')
plot_lumi_error(adjusted_pred, X_test_filtered, 
                title='AE filtered & adjusted reco errror across lumisections')

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve(label, pred, X_tests, names):
    """Generates ROC Curves for a given array"""
    scores = [get_error_df(X_tests[i], pred[i], mode='topn') for i in range(len(pred))]
    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve_error(label, scores, names):
    """Generates ROC Curves for a given array"""    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()
    return plt

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [ae_error, ae_error_filtered, ae_error_filtered_adjusted,
                     get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)], 
                    ['AE',
                     'AE filtered',
                     'AE filtered & adjusted',
                     'Mean square'])

# %%
fig.savefig(csv_dir + 'roc_auc_filtered_ae.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-a37dea40acb0> in <module>()
# ----> 1 fig.savefig(csv_dir + 'roc_auc_filtered_ae.png')
#
# NameError: name 'csv_dir' is not defined

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered,
                     get_error_df(X_test_filtered, np.zeros(X_test_filtered.shape), mode="topn", n_highest=100)], 
                    ['Squeezed AE w/o pileup',
                     'Squeezed AE with pileup',
                     'Standard AE with pileup',
                     'Standard AE w/o pileup',
                     'Mean square'])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

LABELS = ["Normal", "Anomalous"]

def conf_matrix(scores, y_true, threshold, title):
    y_pred = [1 if e > threshold else 0 for e in scores]
    conf_matrix = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(12, 12))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.title(title)
    plt.show()

    acc = accuracy_score(y_true, y_pred)
    class_imbal = np.mean(1 - y_true)
    adj_acc = (acc - class_imbal) / (1 - class_imbal)

    print("Threshold:", threshold)
    print("Adjusted accuracy:", adj_acc)
    return threshold

# %%
conf_matrix(ae_error_filtered, y_test, 1.5e0, '')

# %%
def pred_vs_feature(y_val, x_val, y_class, y_name="", x_name="", selected=[], linear=False,
                    limit=False):
    '''
    Plots two arbitrary values agains each other.
    '''
    df = pd.DataFrame({'y_val': y_val,
                       'x_val': x_val,
                       'y_class': y_class})

    groups = df.groupby('y_class')
    fig, ax = plt.subplots()

    for name, group in groups:
        ax.plot(group.x_val, 
                group.y_val,
                color="red" if name == 1 else "blue",
                marker='o',
                ms=2,
                linestyle='',
                label= "Anomaly" if name == 1 else "Normal")

    for i in selected:
        ax.plot(x_val[i],
                y_val[i],
                color="green",
                marker='o',
                ms=4,
                linestyle='')
                 
    ax.legend()
    if not linear:
        ax.set_yscale('log')
    if limit:
        plt.xlim([limit[0], limit[1]])
    plt.grid()
    plt.ylabel(y_name)
    plt.xlabel(x_name)
    plt.show()

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error_filtered, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
model_directory_np_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_bottleneck/"
model_directory_p_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup/"
model_directory_p_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup_no_bottleneck/"
model_directory_np_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_no_pileup_no_bottleneck/"

# %%
np_b_ae_error = pickle.load(open(model_directory_np_b + "ae_error.p", "rb"))
np_b_ae_error_filtered = pickle.load(open(model_directory_np_b + "ae_error_filtered.p", "rb"))

p_b_ae_error = pickle.load(open(model_directory_p_b + "ae_error.p", "rb"))
p_b_ae_error_filtered = pickle.load(open(model_directory_p_b + "ae_error_filtered.p", "rb"))


p_nb_ae_error = pickle.load(open(model_directory_p_nb + "ae_error.p", "rb"))
p_nb_ae_error_filtered = pickle.load(open(model_directory_p_nb + "ae_error_filtered.p", "rb"))


np_nb_ae_error = pickle.load(open(model_directory_np_nb + "ae_error.p", "rb"))
np_nb_ae_error_filtered = pickle.load(open(model_directory_np_nb + "ae_error_filtered.p", "rb"))

# %%
def pred_vs_feature4(y_vals, x_val, y_class, titles, y_name="", x_name="", linear=False, 
                     limit=False, name_plt=''):
    '''
    Plots two arbitrary values agains each other.
    '''
    fig, axes = plt.subplots(2, 2)
    
    for i in range(4):
        df = pd.DataFrame({'y_val': y_vals[i],
                           'x_val': x_val,
                           'y_class': y_class})

        groups = df.groupby('y_class')
        if i < 2:
            ax = axes[0, i%2]
        else:
            ax = axes[1, i%2]
        
        for name, group in groups:
            ax.plot(group.x_val, 
                    group.y_val,
                    color="red" if name == 1 else "blue",
                    marker='o',
                    ms=2,
                    linestyle='',
                    label= "Anomaly" if name == 1 else "Normal")

        ax.legend()
        if not linear:
            ax.set_yscale('log')
        if limit:
            plt.xlim([limit[0], limit[1]])
        ax.set_ylabel(y_name)
        ax.set_xlabel(x_name)
        ax.set_title(titles[i])
        plt.grid()
    plt.show()
    plt.savefig(csv_dir + name_plt)

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2807], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2807], y_test,
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                 'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='filtered_ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2808], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='ae_vs_pileup.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2808], y_test, 
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='filtered_ae_vs_pileup.png')
