# %%
# Running on GPU?
import setGPU

import getpass
import h5py
import pickle
import matplotlib.pyplot as plt
import matplotlib
from matplotlib.colors import LogNorm

from tqdm import tnrange, tqdm_notebook
# Out:
# setGPU: Setting GPU to: 3

# %%
import os
import getpass
# Get permission to access EOS (Insert your NICE password)
os.system("echo %s | kinit" % getpass.getpass())
# Out:
# ········
# 0

# %%
import json
import numpy as np
import pandas as pd
from pprint import pprint

import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Dense, Lambda, BatchNormalization
from keras.layers.advanced_activations import PReLU
from keras.activations import sigmoid, linear, relu
from keras.models import Model, load_model
from keras.regularizers import l1, l2, l1_l2

from sklearn.model_selection import TimeSeriesSplit
from sklearn.model_selection import StratifiedKFold
from sklearn.utils import class_weight
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

from scipy.stats import pearsonr
# Out:
# Using TensorFlow backend.

# %%
plt.rcParams.update({'font.size': 22})

# %%
PDs  = {1: 'BTagCSV',
        2: 'BTagMu',
        3: 'Charmonium',
        4: 'DisplacedJet',
        5: 'DoubleEG',
        6: 'DoubleMuon',
        7: 'DoubleMuonLowMass',
        8: 'FSQJets',
        9: 'HighMultiplicityEOF',
        10: 'HTMHT',
        11: 'JetHT',
        12: 'MET',
        13: 'MinimumBias',
        14: 'MuonEG',
        15: 'MuOnia',
        16: 'NoBPTX',
        17: 'SingleElectron',
        18: 'SingleMuon',
        19: 'SinglePhoton',
        20: 'Tau',
        21: 'ZeroBias'}

# Select PD
nPD = 11

# %%
legend = [{"name": 'pf_jets', "start": 0, "end": 776},
          {"name": 'cal_jet_mets', "start": 777, "end": 944},
          {"name": 'pho', "start": 945, "end": 1280},
          {"name": 'muons', "start": 1281, "end": 1784},
          {"name": 'pf_jets2', "start": 1785, "end": 1889},
          {"name": 'pf_mets', "start": 1890, "end": 1917},
          {"name": 'nvtx', "start": 1918, "end": 1924},
          {"name": 'cal_jet_mets2', "start": 1925},
          {"name": 'sc', "start": 2037, "end": 2127},
          {"name": 'cc', "start": 2128, "end": 2169},
          {"name": 'pho2', "start": 2170, "end": 2365},
          {"name": 'muons2', "start": 2366, "end": 2491},
          {"name": 'ebs', "start": 2492, "end": 2701},
          {"name": 'hbhef', "start": 2702, "end": 2764},
          {"name": 'presh', "start": 2765, "end": 2806},
          {"name": 'inst_lumi', "start": 2807, "end": 2808}]

# %%
# Feature description
feature_names = ['qPFJetPt', 'qPFJetEta', 'qPFJetPhi', 'qPFJet0Pt', 'qPFJet1Pt', 'qPFJet2Pt', 'qPFJet3Pt', 'qPFJet4Pt', 'qPFJet5Pt', 'qPFJet0Eta', 'qPFJet1Eta', 'qPFJet2Eta', 'qPFJet3Eta', 'qPFJet4Eta', 'qPFJet5Eta', 'qPFJet0Phi', 'qPFJet1Phi', 'qPFJet2Phi', 'qPFJet3Phi', 'qPFJet4Phi', 'qPFJet5Phi', 'qPFJet4CHS0Pt', 'qPFJet4CHS1Pt', 'qPFJet4CHS2Pt', 'qPFJet4CHS3Pt', 'qPFJet4CHS4Pt', 'qPFJet4CHS5Pt', 'qPFJet4CHS0Eta', 'qPFJet4CHS1Eta', 'qPFJet4CHS2Eta', 'qPFJet4CHS3Eta', 'qPFJet4CHS4Eta', 'qPFJet4CHS5Eta', 'qPFJet4CHS0Phi', 'qPFJet4CHS1Phi', 'qPFJet4CHS2Phi', 'qPFJet4CHS3Phi', 'qPFJet4CHS4Phi', 'qPFJet4CHS5Phi', 'qPFJet8CHS0Pt', 'qPFJet8CHS1Pt', 'qPFJet8CHS2Pt', 'qPFJet8CHS3Pt', 'qPFJet8CHS4Pt', 'qPFJet8CHS5Pt', 'qPFJet8CHS0Eta', 'qPFJet8CHS1Eta', 'qPFJet8CHS2Eta', 'qPFJet8CHS3Eta', 'qPFJet8CHS4Eta', 'qPFJet8CHS5Eta', 'qPFJet8CHS0Phi', 'qPFJet8CHS1Phi', 'qPFJet8CHS2Phi', 'qPFJet8CHS3Phi', 'qPFJet8CHS4Phi', 'qPFJet8CHS5Phi', 'qPFJetEI0Pt', 'qPFJetEI1Pt', 'qPFJetEI2Pt', 'qPFJetEI3Pt', 'qPFJetEI4Pt', 'qPFJetEI5Pt', 'qPFJetEI0Eta', 'qPFJetEI1Eta', 'qPFJetEI2Eta', 'qPFJetEI3Eta', 'qPFJetEI4Eta', 'qPFJetEI5Eta', 'qPFJetEI0Phi', 'qPFJetEI1Phi', 'qPFJetEI2Phi', 'qPFJetEI3Phi', 'qPFJetEI4Phi', 'qPFJetEI5Phi', 'qPFJet8CHSSD0Pt', 'qPFJet8CHSSD1Pt', 'qPFJet8CHSSD2Pt', 'qPFJet8CHSSD3Pt', 'qPFJet8CHSSD4Pt', 'qPFJet8CHSSD5Pt', 'qPFJet8CHSSD0Eta', 'qPFJet8CHSSD1Eta', 'qPFJet8CHSSD2Eta', 'qPFJet8CHSSD3Eta', 'qPFJet8CHSSD4Eta', 'qPFJet8CHSSD5Eta', 'qPFJet8CHSSD0Phi', 'qPFJet8CHSSD1Phi', 'qPFJet8CHSSD2Phi', 'qPFJet8CHSSD3Phi', 'qPFJet8CHSSD4Phi', 'qPFJet8CHSSD5Phi', 'qPFJetTopCHS0Pt', 'qPFJetTopCHS1Pt', 'qPFJetTopCHS2Pt', 'qPFJetTopCHS3Pt', 'qPFJetTopCHS4Pt', 'qPFJetTopCHS5Pt', 'qPFJetTopCHS0Eta', 'qPFJetTopCHS1Eta', 'qPFJetTopCHS2Eta', 'qPFJetTopCHS3Eta', 'qPFJetTopCHS4Eta', 'qPFJetTopCHS5Eta', 'qPFJetTopCHS0Phi', 'qPFJetTopCHS1Phi', 'qPFJetTopCHS2Phi', 'qPFJetTopCHS3Phi', 'qPFJetTopCHS4Phi', 'qPFJetTopCHS5Phi', 'qCalJet0Pt', 'qCalJet1Pt', 'qCalJet2Pt', 'qCalJet3Pt', 'qCalJet4Pt', 'qCalJet5Pt', 'qCalJet0Eta', 'qCalJet1Eta', 'qCalJet2Eta', 'qCalJet3Eta', 'qCalJet4Eta', 'qCalJet5Eta', 'qCalJet0Phi', 'qCalJet1Phi', 'qCalJet2Phi', 'qCalJet3Phi', 'qCalJet4Phi', 'qCalJet5Phi', 'qCalJet0En', 'qCalJet1En', 'qCalJet2En', 'qCalJet3En', 'qCalJet4En', 'qCalJet5En', 'qPho0Pt', 'qPho1Pt', 'qPho2Pt', 'qPho3Pt', 'qPho4Pt', 'qPho5Pt', 'qPho0Eta', 'qPho1Eta', 'qPho2Eta', 'qPho3Eta', 'qPho4Eta', 'qPho5Eta', 'qPho0Phi', 'qPho1Phi', 'qPho2Phi', 'qPho3Phi', 'qPho4Phi', 'qPho5Phi', 'qPho0En', 'qPho1En', 'qPho2En', 'qPho3En', 'qPho4En', 'qPho5En', 'qgedPho0Pt', 'qgedPho1Pt', 'qgedPho2Pt', 'qgedPho3Pt', 'qgedPho4Pt', 'qgedPho5Pt', 'qgedPho0Eta', 'qgedPho1Eta', 'qgedPho2Eta', 'qgedPho3Eta', 'qgedPho4Eta', 'qgedPho5Eta', 'qgedPho0Phi', 'qgedPho1Phi', 'qgedPho2Phi', 'qgedPho3Phi', 'qgedPho4Phi', 'qgedPho5Phi', 'qgedPho0En', 'qgedPho1En', 'qgedPho2En', 'qgedPho3En', 'qgedPho4En', 'qgedPho5En', 'qMu0Pt', 'qMu1Pt', 'qMu2Pt', 'qMu3Pt', 'qMu4Pt', 'qMu5Pt', 'qMu0Eta', 'qMu1Eta', 'qMu2Eta', 'qMu3Eta', 'qMu4Eta', 'qMu5Eta', 'qMu0Phi', 'qMu1Phi', 'qMu2Phi', 'qMu3Phi', 'qMu4Phi', 'qMu5Phi', 'qMu0En', 'qMu1En', 'qMu2En', 'qMu3En', 'qMu4En', 'qMu5En', 'qMuCosm0Pt', 'qMuCosm1Pt', 'qMuCosm2Pt', 'qMuCosm3Pt', 'qMuCosm4Pt', 'qMuCosm5Pt', 'qMuCosm0Eta', 'qMuCosm1Eta', 'qMuCosm2Eta', 'qMuCosm3Eta', 'qMuCosm4Eta', 'qMuCosm5Eta', 'qMuCosm0Phi', 'qMuCosm1Phi', 'qMuCosm2Phi', 'qMuCosm3Phi', 'qMuCosm4Phi', 'qMuCosm5Phi', 'qMuCosm0En', 'qMuCosm1En', 'qMuCosm2En', 'qMuCosm3En', 'qMuCosm4En', 'qMuCosm5En', 'qMuCosmLeg0Pt', 'qMuCosmLeg1Pt', 'qMuCosmLeg2Pt', 'qMuCosmLeg3Pt', 'qMuCosmLeg4Pt', 'qMuCosmLeg5Pt', 'qMuCosmLeg0Eta', 'qMuCosmLeg1Eta', 'qMuCosmLeg2Eta', 'qMuCosmLeg3Eta', 'qMuCosmLeg4Eta', 'qMuCosmLeg5Eta', 'qMuCosmLeg0Phi', 'qMuCosmLeg1Phi', 'qMuCosmLeg2Phi', 'qMuCosmLeg3Phi', 'qMuCosmLeg4Phi', 'qMuCosmLeg5Phi', 'qMuCosmLeg0En', 'qMuCosmLeg1En', 'qMuCosmLeg2En', 'qMuCosmLeg3En', 'qMuCosmLeg4En', 'qMuCosmLeg5En', 'qPFJet4CHSPt', 'qPFJet4CHSEta', 'qPFJet4CHSPhi', 'qPFJet8CHSPt', 'qPFJet8CHSEta', 'qPFJet8CHSPhi', 'qPFJetEIPt', 'qPFJetEIEta', 'qPFJetEIPhi', 'qPFJet8CHSSDPt', 'qPFJet8CHSSDEta', 'qPFJet8CHSSDPhi', 'qPFJetTopCHSPt', 'qPFJetTopCHSEta', 'qPFJetTopCHSPhi', 'qPFChMetPt', 'qPFChMetPhi', 'qPFMetPt', 'qPFMetPhi', 'qNVtx', 'qCalJetPt', 'qCalJetEta', 'qCalJetPhi', 'qCalJetEn', 'qCalMETPt', 'qCalMETPhi', 'qCalMETEn', 'qCalMETBEPt', 'qCalMETBEPhi', 'qCalMETBEEn', 'qCalMETBEFOPt', 'qCalMETBEFOPhi', 'qCalMETBEFOEn', 'qCalMETMPt', 'qCalMETMPhi', 'qCalMETMEn', 'qSCEn', 'qSCEta', 'qSCPhi', 'qSCEtaWidth', 'qSCPhiWidth', 'qSCEnhfEM', 'qSCEtahfEM', 'qSCPhihfEM', 'qSCEn5x5', 'qSCEta5x5', 'qSCPhi5x5', 'qSCEtaWidth5x5', 'qSCPhiWidth5x5', 'qCCEn', 'qCCEta', 'qCCPhi', 'qCCEn5x5', 'qCCEta5x5', 'qCCPhi5x5', 'qPhoPt', 'qPhoEta', 'qPhoPhi', 'qPhoEn_', 'qPhoe1x5_', 'qPhoe2x5_', 'qPhoe3x3_', 'qPhoe5x5_', 'qPhomaxenxtal_', 'qPhosigmaeta_', 'qPhosigmaIeta_', 'qPhor1x5_', 'qPhor2x5_', 'qPhor9_', 'qgedPhoPt', 'qgedPhoEta', 'qgedPhoPhi', 'qgedPhoEn_', 'qgedPhoe1x5_', 'qgedPhoe2x5_', 'qgedPhoe3x3_', 'qgedPhoe5x5_', 'qgedPhomaxenxtal_', 'qgedPhosigmaeta_', 'qgedPhosigmaIeta_', 'qgedPhor1x5_', 'qgedPhor2x5_', 'qgedPhor9_', 'qMuPt', 'qMuEta', 'qMuPhi', 'qMuEn_', 'qMuCh_', 'qMuChi2_', 'qMuCosmPt', 'qMuCosmEta', 'qMuCosmPhi', 'qMuCosmEn_', 'qMuCosmCh_', 'qMuCosmChi2_', 'qMuCosmLegPt', 'qMuCosmLegEta', 'qMuCosmLegPhi', 'qMuCosmLegEn_', 'qMuCosmLegCh_', 'qMuCosmLegChi2_', 'qSigmaIEta', 'qSigmaIPhi', 'qr9', 'qHadOEm', 'qdrSumPt', 'qdrSumEt', 'qeSCOP', 'qecEn', 'qUNSigmaIEta', 'qUNSigmaIPhi', 'qUNr9', 'qUNHadOEm', 'qUNdrSumPt', 'qUNdrSumEt', 'qUNeSCOP', 'qUNecEn', 'qEBenergy', 'qEBtime', 'qEBchi2', 'qEBiEta', 'qEBiPhi', 'qEEenergy', 'qEEtime', 'qEEchi2', 'qEEix', 'qEEiy', 'qESenergy', 'qEStime', 'qESix', 'qESiy', 'qHBHEenergy', 'qHBHEtime', 'qHBHEauxe', 'qHBHEieta', 'qHBHEiphi', 'qHFenergy', 'qHFtime', 'qHFieta', 'qHFiphi', 'qPreShEn', 'qPreShEta', 'qPreShPhi', 'qPreShYEn', 'qPreShYEta', 'qPreShYPhi', 'inst_luminosity']

# %%
data_directory = "/eos/cms/store/user/fsiroky/consistentlumih5/"
label_file = "/afs/cern.ch/user/t/tkrzyzek/Documents/Data-Certification/JetHT.json"
pileup_file = "/afs/cern.ch/cms/CAF/CMSCOMM/COMM_DQM/certification/Collisions16/13TeV/PileUp/pileup_latest.txt"
model_directory = "/eos/user/t/tkrzyzek/autoencoder/30-40-JetHT/np_b/"
model_name = "model"

# %%
def get_file_list(directory, pds, npd, typeof, extension):
    files = []
    parts = ["C", "D", "E", "F", "G", "H"]
    for p in parts:
        files.append("%s%s_%s_%s%s" % (directory, pds[npd], p, typeof, extension))
    return files

files = get_file_list(data_directory, PDs, nPD, "background", ".h5")
files = files + get_file_list(data_directory, PDs, nPD, "signal", ".h5")

# %%
# Load good and bad jets
def get_data(files):
    readout = np.empty([0,2813])
    
    for file in files:
        jet = file.split("/")[-1][:-3]
        print("Reading: %s" % jet)
        try:
            h5file = h5py.File(file, "r")
            readout = np.concatenate((readout, h5file[jet][:]), axis=0)
        except OSError as error:
            print("This Primary Dataset doesn't have %s. %s" % (jet, error))
            continue

    return readout

data = pd.DataFrame(get_data(files))
# Out:
# Reading: JetHT_C_background
# Reading: JetHT_D_background
# Reading: JetHT_E_background
# Reading: JetHT_F_background
# Reading: JetHT_G_background
# Reading: JetHT_H_background
# Reading: JetHT_C_signal
# Reading: JetHT_D_signal
# Reading: JetHT_E_signal
# Reading: JetHT_F_signal
# Reading: JetHT_G_signal
# Reading: JetHT_H_signal

# %%
data["run"] = data[2807].astype(int)
data["lumi"] = data[2808].astype(int)
data["inst_lumi"] = data[2809].astype(float)

# Drop unnecessary meta data
data.drop([2808, 2809, 2810, 2811, 2812], axis=1, inplace=True)

# Append inst. luminosity at the end as well
data[2807] = data["inst_lumi"]

# Sort by runID and then by lumiID
data = data.sort_values(["run", "lumi"], ascending=[True,True])

# Reset index
data = data.reset_index(drop=True)  

runIDs  = data["run"].astype(int)
lumiIDs = data["lumi"].astype(int)
luminosity = data["inst_lumi"].astype(float)

# %%
# Apply labels
output_json = json.load(open(label_file))

def json_checker(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid >= i[0] and orig_lumid <= i[1]:
                return 0
    except KeyError:
        pass
    return 1

def add_flags(sample):
    return json_checker(output_json, sample["run"], sample["lumi"])

data["label"] = data.apply(add_flags, axis=1)

# %%
# with open(pileup_file) as f:
#     pileup = json.load(f)

# def pileup_from_json(json_file, orig_runid, orig_lumid):
#     try:
#         for i in json_file[str(int(orig_runid))]:
#             if orig_lumid == i[0]:
#                 return i[3]
#     except KeyError:
#         print('key error')
#     return 1

# def add_pileup(sample):
#     return pileup_from_json(pileup, sample["run"], sample["lumi"])

# data["pileup"] = data.apply(add_pileup, axis=1)

# %%
# data[2808] = data["pileup"]

# %%
# Split the data
TRAIN_FROM = round(0.3*len(data))
TRAIN_TO = round(0.4*len(data))
TEST_FROM = round(0.4*len(data))
TEST_TO = round(0.5*len(data))

train = data.iloc[TRAIN_FROM:TRAIN_TO]
X_train = train.iloc[:, :2808]
y_train = train["label"]

# Adding bad data to test set
test = pd.concat([data.iloc[TEST_FROM:TEST_TO], data[:TEST_FROM][data['label'] == 1],
                 data[TEST_TO:][data['label'] == 1]]) 
X_test = test.iloc[:, :2808]
y_test = test["label"]

normalizer = StandardScaler()
X_train_norm = normalizer.fit_transform(X_train)
X_test_norm = normalizer.transform(X_test)

# Train only on good
X_train = X_train[y_train == 0]
X_train_norm = X_train_norm[y_train == 0]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:12: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /opt/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:13: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
INPUT_DIM = 2808

# %%
X_train_norm.shape
# Out:
# (16294, 2808)

# %%
input_layer = Input(shape=(INPUT_DIM, ))

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(2048, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(INPUT_DIM)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 2808)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2048)              5752832
# _________________________________________________________________
# p_re_lu_1 (PReLU)            (None, 2048)              2048
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# p_re_lu_2 (PReLU)            (None, 1024)              1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# p_re_lu_3 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               131328
# _________________________________________________________________
# p_re_lu_4 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               32896
# _________________________________________________________________
# p_re_lu_5 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_6 (Dense)              (None, 64)                8256
# _________________________________________________________________
# p_re_lu_6 (PReLU)            (None, 64)                64
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               8320
# _________________________________________________________________
# p_re_lu_7 (PReLU)            (None, 128)               128
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               33024
# _________________________________________________________________
# p_re_lu_8 (PReLU)            (None, 256)               256
# _________________________________________________________________
# dense_9 (Dense)              (None, 512)               131584
# _________________________________________________________________
# p_re_lu_9 (PReLU)            (None, 512)               512
# _________________________________________________________________
# dense_10 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_10 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_11 (Dense)             (None, 2048)              2099200
# _________________________________________________________________
# p_re_lu_11 (PReLU)           (None, 2048)              2048
# _________________________________________________________________
# dense_12 (Dense)             (None, 2808)              5753592
# =================================================================
# Total params: 17,107,320
# Trainable params: 17,107,320
# Non-trainable params: 0
# _________________________________________________________________

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_norm,
                X_train_norm,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 12220 samples, validate on 4074 samples
# Epoch 1/2048
# 7s - loss: 89.1485 - val_loss: 76.3027
# Epoch 2/2048
# 4s - loss: 66.5070 - val_loss: 56.9129
# Epoch 3/2048
# 4s - loss: 49.6550 - val_loss: 42.4861
# Epoch 4/2048
# 4s - loss: 37.1047 - val_loss: 31.7407
# Epoch 5/2048
# 4s - loss: 27.7721 - val_loss: 23.7661
# Epoch 6/2048
# 4s - loss: 20.8592 - val_loss: 17.8703
# Epoch 7/2048
# 5s - loss: 15.7575 - val_loss: 13.5282
# Epoch 8/2048
# 4s - loss: 12.0062 - val_loss: 10.3423
# Epoch 9/2048
# 4s - loss: 9.2567 - val_loss: 8.0111
# Epoch 10/2048
# 4s - loss: 7.2465 - val_loss: 6.3080
# Epoch 11/2048
# 4s - loss: 5.7796 - val_loss: 5.0672
# Epoch 12/2048
# 4s - loss: 4.7111 - val_loss: 4.1604
# Epoch 13/2048
# 5s - loss: 3.9162 - val_loss: 3.4717
# Epoch 14/2048
# 5s - loss: 3.3083 - val_loss: 2.9435
# Epoch 15/2048
# 4s - loss: 2.8420 - val_loss: 2.5380
# Epoch 16/2048
# 4s - loss: 2.4811 - val_loss: 2.2178
# Epoch 17/2048
# 4s - loss: 2.1895 - val_loss: 1.9544
# Epoch 18/2048
# 4s - loss: 1.9491 - val_loss: 1.7373
# Epoch 19/2048
# 4s - loss: 1.7506 - val_loss: 1.5575
# Epoch 20/2048
# 4s - loss: 1.5865 - val_loss: 1.4093
# Epoch 21/2048
# 5s - loss: 1.4508 - val_loss: 1.2862
# Epoch 22/2048
# 5s - loss: 1.3383 - val_loss: 1.1835
# Epoch 23/2048
# 4s - loss: 1.2450 - val_loss: 1.0993
# Epoch 24/2048
# 4s - loss: 1.1663 - val_loss: 1.0264
# Epoch 25/2048
# 4s - loss: 1.0986 - val_loss: 0.9640
# Epoch 26/2048
# 4s - loss: 1.0403 - val_loss: 0.9099
# Epoch 27/2048
# 4s - loss: 0.9901 - val_loss: 0.8640
# Epoch 28/2048
# 4s - loss: 0.9467 - val_loss: 0.8238
# Epoch 29/2048
# 4s - loss: 0.9094 - val_loss: 0.7892
# Epoch 30/2048
# 4s - loss: 0.8773 - val_loss: 0.7595
# Epoch 31/2048
# 5s - loss: 0.8498 - val_loss: 0.7347
# Epoch 32/2048
# 6s - loss: 0.8261 - val_loss: 0.7123
# Epoch 33/2048
# 4s - loss: 0.8058 - val_loss: 0.6934
# Epoch 34/2048
# 4s - loss: 0.7883 - val_loss: 0.6776
# Epoch 35/2048
# 3s - loss: 0.7730 - val_loss: 0.6639
# Epoch 36/2048
# 3s - loss: 0.7597 - val_loss: 0.6508
# Epoch 37/2048
# 4s - loss: 0.7478 - val_loss: 0.6400
# Epoch 38/2048
# 4s - loss: 0.7373 - val_loss: 0.6317
# Epoch 39/2048
# 4s - loss: 0.7282 - val_loss: 0.6225
# Epoch 40/2048
# 4s - loss: 0.7202 - val_loss: 0.6154
# Epoch 41/2048
# 4s - loss: 0.7132 - val_loss: 0.6078
# Epoch 42/2048
# 4s - loss: 0.7069 - val_loss: 0.6019
# Epoch 43/2048
# 5s - loss: 0.7015 - val_loss: 0.5974
# Epoch 44/2048
# 4s - loss: 0.6969 - val_loss: 0.5941
# Epoch 45/2048
# 4s - loss: 0.6929 - val_loss: 0.5900
# Epoch 46/2048
# 5s - loss: 0.6894 - val_loss: 0.5873
# Epoch 47/2048
# 4s - loss: 0.6864 - val_loss: 0.5845
# Epoch 48/2048
# 4s - loss: 0.6836 - val_loss: 0.5817
# Epoch 49/2048
# 5s - loss: 0.6813 - val_loss: 0.5796
# Epoch 50/2048
# 4s - loss: 0.6792 - val_loss: 0.5774
# Epoch 51/2048
# 4s - loss: 0.6774 - val_loss: 0.5769
# Epoch 52/2048
# 6s - loss: 0.6756 - val_loss: 0.5752
# Epoch 53/2048
# 4s - loss: 0.6741 - val_loss: 0.5738
# Epoch 54/2048
# 3s - loss: 0.6728 - val_loss: 0.5730
# Epoch 55/2048
# 6s - loss: 0.6716 - val_loss: 0.5719
# Epoch 56/2048
# 4s - loss: 0.6705 - val_loss: 0.5704
# Epoch 57/2048
# 5s - loss: 0.6695 - val_loss: 0.5693
# Epoch 58/2048
# 6s - loss: 0.6686 - val_loss: 0.5692
# Epoch 59/2048
# 4s - loss: 0.6678 - val_loss: 0.5683
# Epoch 60/2048
# 4s - loss: 0.6671 - val_loss: 0.5679
# Epoch 61/2048
# 4s - loss: 0.6665 - val_loss: 0.5678
# Epoch 62/2048
# 4s - loss: 0.6659 - val_loss: 0.5670
# Epoch 63/2048
# 1s - loss: 0.6653 - val_loss: 0.5676
# Epoch 64/2048
# 3s - loss: 0.6648 - val_loss: 0.5662
# Epoch 65/2048
# 1s - loss: 0.6644 - val_loss: 0.5662
# Epoch 66/2048
# 5s - loss: 0.6640 - val_loss: 0.5651
# Epoch 67/2048
# 1s - loss: 0.6637 - val_loss: 0.5658
# Epoch 68/2048
# 4s - loss: 0.6633 - val_loss: 0.5647
# Epoch 69/2048
# 1s - loss: 0.6629 - val_loss: 0.5654
# Epoch 70/2048
# 1s - loss: 0.6626 - val_loss: 0.5647
# Epoch 71/2048
# 1s - loss: 0.6623 - val_loss: 0.5648
# Epoch 72/2048
# 3s - loss: 0.6619 - val_loss: 0.5642
# Epoch 73/2048
# 1s - loss: 0.6616 - val_loss: 0.5644
# Epoch 74/2048
# 1s - loss: 0.6614 - val_loss: 0.5644
# Epoch 75/2048
# 3s - loss: 0.6610 - val_loss: 0.5639
# Epoch 76/2048
# 3s - loss: 0.6608 - val_loss: 0.5630
# Epoch 77/2048
# 1s - loss: 0.6605 - val_loss: 0.5638
# Epoch 78/2048
# 1s - loss: 0.6602 - val_loss: 0.5633
# Epoch 79/2048
# 3s - loss: 0.6600 - val_loss: 0.5627
# Epoch 80/2048
# 1s - loss: 0.6597 - val_loss: 0.5630
# Epoch 81/2048
# 1s - loss: 0.6594 - val_loss: 0.5633
# Epoch 82/2048
# 1s - loss: 0.6592 - val_loss: 0.5631
# Epoch 83/2048
# 4s - loss: 0.6589 - val_loss: 0.5622
# Epoch 84/2048
# 1s - loss: 0.6588 - val_loss: 0.5623
# Epoch 85/2048
# 1s - loss: 0.6584 - val_loss: 0.5626
# Epoch 86/2048
# 1s - loss: 0.6583 - val_loss: 0.5622
# Epoch 87/2048
# 3s - loss: 0.6580 - val_loss: 0.5616
# Epoch 88/2048
# 1s - loss: 0.6578 - val_loss: 0.5618
# Epoch 89/2048
# 5s - loss: 0.6575 - val_loss: 0.5612
# Epoch 90/2048
# 1s - loss: 0.6573 - val_loss: 0.5613
# Epoch 91/2048
# 1s - loss: 0.6572 - val_loss: 0.5613
# Epoch 92/2048
# 3s - loss: 0.6570 - val_loss: 0.5610
# Epoch 93/2048
# 1s - loss: 0.6568 - val_loss: 0.5611
# Epoch 94/2048
# 1s - loss: 0.6567 - val_loss: 0.5611
# Epoch 95/2048
# 4s - loss: 0.6564 - val_loss: 0.5608
# Epoch 96/2048
# 5s - loss: 0.6563 - val_loss: 0.5605
# Epoch 97/2048
# 1s - loss: 0.6560 - val_loss: 0.5606
# Epoch 98/2048
# 5s - loss: 0.6557 - val_loss: 0.5603
# Epoch 99/2048
# 1s - loss: 0.6555 - val_loss: 0.5603
# Epoch 100/2048
# 4s - loss: 0.6554 - val_loss: 0.5601
# Epoch 101/2048
# 4s - loss: 0.6553 - val_loss: 0.5596
# Epoch 102/2048
# 1s - loss: 0.6550 - val_loss: 0.5604
# Epoch 103/2048
# 1s - loss: 0.6548 - val_loss: 0.5597
# Epoch 104/2048
# 3s - loss: 0.6547 - val_loss: 0.5591
# Epoch 105/2048
# 1s - loss: 0.6545 - val_loss: 0.5596
# Epoch 106/2048
# 1s - loss: 0.6543 - val_loss: 0.5593
# Epoch 107/2048
# 3s - loss: 0.6542 - val_loss: 0.5587
# Epoch 108/2048
# 4s - loss: 0.6539 - val_loss: 0.5581
# Epoch 109/2048
# 1s - loss: 0.6538 - val_loss: 0.5581
# Epoch 110/2048
# 1s - loss: 0.6536 - val_loss: 0.5588
# Epoch 111/2048
# 1s - loss: 0.6535 - val_loss: 0.5589
# Epoch 112/2048
# 1s - loss: 0.6532 - val_loss: 0.5582
# Epoch 113/2048
# 1s - loss: 0.6530 - val_loss: 0.5583
# Epoch 114/2048
# 3s - loss: 0.6529 - val_loss: 0.5576
# Epoch 115/2048
# 5s - loss: 0.6528 - val_loss: 0.5575
# Epoch 116/2048
# 1s - loss: 0.6527 - val_loss: 0.5576
# Epoch 117/2048
# 5s - loss: 0.6525 - val_loss: 0.5570
# Epoch 118/2048
# 1s - loss: 0.6524 - val_loss: 0.5576
# Epoch 119/2048
# 1s - loss: 0.6523 - val_loss: 0.5574
# Epoch 120/2048
# 1s - loss: 0.6520 - val_loss: 0.5574
# Epoch 121/2048
# 4s - loss: 0.6519 - val_loss: 0.5569
# Epoch 122/2048
# 1s - loss: 0.6518 - val_loss: 0.5573
# Epoch 123/2048
# 4s - loss: 0.6517 - val_loss: 0.5565
# Epoch 124/2048
# 1s - loss: 0.6516 - val_loss: 0.5572
# Epoch 125/2048
# 1s - loss: 0.6513 - val_loss: 0.5571
# Epoch 126/2048
# 1s - loss: 0.6512 - val_loss: 0.5565
# Epoch 127/2048
# 1s - loss: 0.6512 - val_loss: 0.5569
# Epoch 128/2048
# 4s - loss: 0.6511 - val_loss: 0.5560
# Epoch 129/2048
# 1s - loss: 0.6509 - val_loss: 0.5567
# Epoch 130/2048
# 1s - loss: 0.6508 - val_loss: 0.5563
# Epoch 131/2048
# 1s - loss: 0.6507 - val_loss: 0.5563
# Epoch 132/2048
# 4s - loss: 0.6507 - val_loss: 0.5556
# Epoch 133/2048
# 1s - loss: 0.6504 - val_loss: 0.5571
# Epoch 134/2048
# 4s - loss: 0.6504 - val_loss: 0.5555
# Epoch 135/2048
# 1s - loss: 0.6503 - val_loss: 0.5560
# Epoch 136/2048
# 1s - loss: 0.6501 - val_loss: 0.5557
# Epoch 137/2048
# 1s - loss: 0.6500 - val_loss: 0.5562
# Epoch 138/2048
# 4s - loss: 0.6500 - val_loss: 0.5554
# Epoch 139/2048
# 1s - loss: 0.6498 - val_loss: 0.5554
# Epoch 140/2048
# 1s - loss: 0.6496 - val_loss: 0.5554
# Epoch 141/2048
# 3s - loss: 0.6496 - val_loss: 0.5551
# Epoch 142/2048
# 4s - loss: 0.6495 - val_loss: 0.5547
# Epoch 143/2048
# 1s - loss: 0.6494 - val_loss: 0.5552
# Epoch 144/2048
# 1s - loss: 0.6493 - val_loss: 0.5550
# Epoch 145/2048
# 1s - loss: 0.6492 - val_loss: 0.5559
# Epoch 146/2048
# 1s - loss: 0.6492 - val_loss: 0.5548
# Epoch 147/2048
# 4s - loss: 0.6489 - val_loss: 0.5543
# Epoch 148/2048
# 1s - loss: 0.6489 - val_loss: 0.5544
# Epoch 149/2048
# 5s - loss: 0.6487 - val_loss: 0.5543
# Epoch 150/2048
# 1s - loss: 0.6487 - val_loss: 0.5544
# Epoch 151/2048
# 6s - loss: 0.6486 - val_loss: 0.5540
# Epoch 152/2048
# 1s - loss: 0.6486 - val_loss: 0.5544
# Epoch 153/2048
# 4s - loss: 0.6483 - val_loss: 0.5540
# Epoch 154/2048
# 1s - loss: 0.6482 - val_loss: 0.5540
# Epoch 155/2048
# 4s - loss: 0.6482 - val_loss: 0.5537
# Epoch 156/2048
# 1s - loss: 0.6481 - val_loss: 0.5537
# Epoch 157/2048
# 1s - loss: 0.6479 - val_loss: 0.5537
# Epoch 158/2048
# 1s - loss: 0.6479 - val_loss: 0.5539
# Epoch 159/2048
# 1s - loss: 0.6478 - val_loss: 0.5540
# Epoch 160/2048
# 3s - loss: 0.6477 - val_loss: 0.5534
# Epoch 161/2048
# 1s - loss: 0.6476 - val_loss: 0.5535
# Epoch 162/2048
# 5s - loss: 0.6475 - val_loss: 0.5534
# Epoch 163/2048
# 3s - loss: 0.6475 - val_loss: 0.5530
# Epoch 164/2048
# 1s - loss: 0.6473 - val_loss: 0.5531
# Epoch 165/2048
# 5s - loss: 0.6472 - val_loss: 0.5530
# Epoch 166/2048
# 4s - loss: 0.6471 - val_loss: 0.5527
# Epoch 167/2048
# 1s - loss: 0.6471 - val_loss: 0.5532
# Epoch 168/2048
# 1s - loss: 0.6470 - val_loss: 0.5535
# Epoch 169/2048
# 1s - loss: 0.6469 - val_loss: 0.5535
# Epoch 170/2048
# 1s - loss: 0.6467 - val_loss: 0.5530
# Epoch 171/2048
# 4s - loss: 0.6467 - val_loss: 0.5523
# Epoch 172/2048
# 4s - loss: 0.6467 - val_loss: 0.5523
# Epoch 173/2048
# 1s - loss: 0.6465 - val_loss: 0.5531
# Epoch 174/2048
# 1s - loss: 0.6465 - val_loss: 0.5536
# Epoch 175/2048
# 3s - loss: 0.6464 - val_loss: 0.5520
# Epoch 176/2048
# 4s - loss: 0.6464 - val_loss: 0.5518
# Epoch 177/2048
# 1s - loss: 0.6463 - val_loss: 0.5523
# Epoch 178/2048
# 1s - loss: 0.6461 - val_loss: 0.5519
# Epoch 179/2048
# 4s - loss: 0.6460 - val_loss: 0.5514
# Epoch 180/2048
# 1s - loss: 0.6459 - val_loss: 0.5517
# Epoch 181/2048
# 1s - loss: 0.6458 - val_loss: 0.5520
# Epoch 182/2048
# 1s - loss: 0.6458 - val_loss: 0.5520
# Epoch 183/2048
# 1s - loss: 0.6457 - val_loss: 0.5517
# Epoch 184/2048
# 4s - loss: 0.6455 - val_loss: 0.5513
# Epoch 185/2048
# 1s - loss: 0.6455 - val_loss: 0.5518
# Epoch 186/2048
# 5s - loss: 0.6455 - val_loss: 0.5512
# Epoch 187/2048
# 5s - loss: 0.6454 - val_loss: 0.5510
# Epoch 188/2048
# 1s - loss: 0.6452 - val_loss: 0.5517
# Epoch 189/2048
# 1s - loss: 0.6452 - val_loss: 0.5514
# Epoch 190/2048
# 3s - loss: 0.6451 - val_loss: 0.5507
# Epoch 191/2048
# 1s - loss: 0.6450 - val_loss: 0.5515
# Epoch 192/2048
# 1s - loss: 0.6450 - val_loss: 0.5514
# Epoch 193/2048
# 3s - loss: 0.6448 - val_loss: 0.5507
# Epoch 194/2048
# 1s - loss: 0.6448 - val_loss: 0.5512
# Epoch 195/2048
# 5s - loss: 0.6447 - val_loss: 0.5506
# Epoch 196/2048
# 4s - loss: 0.6446 - val_loss: 0.5503
# Epoch 197/2048
# 6s - loss: 0.6446 - val_loss: 0.5502
# Epoch 198/2048
# 1s - loss: 0.6444 - val_loss: 0.5508
# Epoch 199/2048
# 1s - loss: 0.6443 - val_loss: 0.5503
# Epoch 200/2048
# 1s - loss: 0.6443 - val_loss: 0.5504
# Epoch 201/2048
# 3s - loss: 0.6442 - val_loss: 0.5501
# Epoch 202/2048
# 1s - loss: 0.6441 - val_loss: 0.5505
# Epoch 203/2048
# 1s - loss: 0.6440 - val_loss: 0.5503
# Epoch 204/2048
# 3s - loss: 0.6440 - val_loss: 0.5492
# Epoch 205/2048
# 1s - loss: 0.6439 - val_loss: 0.5496
# Epoch 206/2048
# 1s - loss: 0.6439 - val_loss: 0.5497
# Epoch 207/2048
# 1s - loss: 0.6437 - val_loss: 0.5498
# Epoch 208/2048
# 1s - loss: 0.6438 - val_loss: 0.5498
# Epoch 209/2048
# 1s - loss: 0.6436 - val_loss: 0.5500
# Epoch 210/2048
# 3s - loss: 0.6435 - val_loss: 0.5492
# Epoch 211/2048
# 1s - loss: 0.6434 - val_loss: 0.5494
# Epoch 212/2048
# 6s - loss: 0.6434 - val_loss: 0.5490
# Epoch 213/2048
# 1s - loss: 0.6433 - val_loss: 0.5500
# Epoch 214/2048
# 1s - loss: 0.6432 - val_loss: 0.5494
# Epoch 215/2048
# 1s - loss: 0.6433 - val_loss: 0.5495
# Epoch 216/2048
# 1s - loss: 0.6430 - val_loss: 0.5494
# Epoch 217/2048
# 1s - loss: 0.6431 - val_loss: 0.5490
# Epoch 218/2048
# 4s - loss: 0.6429 - val_loss: 0.5487
# Epoch 219/2048
# 1s - loss: 0.6429 - val_loss: 0.5490
# Epoch 220/2048
# 1s - loss: 0.6427 - val_loss: 0.5491
# Epoch 221/2048
# 1s - loss: 0.6428 - val_loss: 0.5487
# Epoch 222/2048
# 4s - loss: 0.6426 - val_loss: 0.5482
# Epoch 223/2048
# 1s - loss: 0.6426 - val_loss: 0.5488
# Epoch 224/2048
# 4s - loss: 0.6425 - val_loss: 0.5481
# Epoch 225/2048
# 1s - loss: 0.6425 - val_loss: 0.5482
# Epoch 226/2048
# 1s - loss: 0.6424 - val_loss: 0.5483
# Epoch 227/2048
# 4s - loss: 0.6423 - val_loss: 0.5481
# Epoch 228/2048
# 4s - loss: 0.6423 - val_loss: 0.5476
# Epoch 229/2048
# 1s - loss: 0.6421 - val_loss: 0.5478
# Epoch 230/2048
# 1s - loss: 0.6421 - val_loss: 0.5482
# Epoch 231/2048
# 1s - loss: 0.6420 - val_loss: 0.5482
# Epoch 232/2048
# 1s - loss: 0.6419 - val_loss: 0.5482
# Epoch 233/2048
# 1s - loss: 0.6418 - val_loss: 0.5480
# Epoch 234/2048
# 1s - loss: 0.6418 - val_loss: 0.5479
# Epoch 235/2048
# 4s - loss: 0.6417 - val_loss: 0.5474
# Epoch 236/2048
# 1s - loss: 0.6416 - val_loss: 0.5478
# Epoch 237/2048
# 1s - loss: 0.6415 - val_loss: 0.5474
# Epoch 238/2048
# 1s - loss: 0.6414 - val_loss: 0.5478
# Epoch 239/2048
# 1s - loss: 0.6414 - val_loss: 0.5475
# Epoch 240/2048
# 3s - loss: 0.6413 - val_loss: 0.5473
# Epoch 241/2048
# 4s - loss: 0.6412 - val_loss: 0.5472
# Epoch 242/2048
# 1s - loss: 0.6412 - val_loss: 0.5474
# Epoch 243/2048
# 5s - loss: 0.6412 - val_loss: 0.5469
# Epoch 244/2048
# 1s - loss: 0.6410 - val_loss: 0.5471
# Epoch 245/2048
# 1s - loss: 0.6410 - val_loss: 0.5472
# Epoch 246/2048
# 1s - loss: 0.6409 - val_loss: 0.5476
# Epoch 247/2048
# 1s - loss: 0.6409 - val_loss: 0.5476
# Epoch 248/2048
# 3s - loss: 0.6407 - val_loss: 0.5465
# Epoch 249/2048
# 4s - loss: 0.6407 - val_loss: 0.5463
# Epoch 250/2048
# 1s - loss: 0.6405 - val_loss: 0.5463
# Epoch 251/2048
# 1s - loss: 0.6404 - val_loss: 0.5467
# Epoch 252/2048
# 1s - loss: 0.6404 - val_loss: 0.5463
# Epoch 253/2048
# 3s - loss: 0.6403 - val_loss: 0.5459
# Epoch 254/2048
# 1s - loss: 0.6402 - val_loss: 0.5466
# Epoch 255/2048
# 1s - loss: 0.6402 - val_loss: 0.5463
# Epoch 256/2048
# 4s - loss: 0.6400 - val_loss: 0.5459
# Epoch 257/2048
# 1s - loss: 0.6400 - val_loss: 0.5460
# Epoch 258/2048
# 1s - loss: 0.6397 - val_loss: 0.5460
# Epoch 259/2048
# 1s - loss: 0.6397 - val_loss: 0.5459
# Epoch 260/2048
# 1s - loss: 0.6396 - val_loss: 0.5461
# Epoch 261/2048
# 4s - loss: 0.6395 - val_loss: 0.5456
# Epoch 262/2048
# 1s - loss: 0.6395 - val_loss: 0.5462
# Epoch 263/2048
# 1s - loss: 0.6395 - val_loss: 0.5457
# Epoch 264/2048
# 1s - loss: 0.6393 - val_loss: 0.5458
# Epoch 265/2048
# 1s - loss: 0.6395 - val_loss: 0.5456
# Epoch 266/2048
# 3s - loss: 0.6393 - val_loss: 0.5455
# Epoch 267/2048
# 1s - loss: 0.6392 - val_loss: 0.5455
# Epoch 268/2048
# 4s - loss: 0.6392 - val_loss: 0.5452
# Epoch 269/2048
# 4s - loss: 0.6391 - val_loss: 0.5451
# Epoch 270/2048
# 1s - loss: 0.6390 - val_loss: 0.5453
# Epoch 271/2048
# 1s - loss: 0.6389 - val_loss: 0.5458
# Epoch 272/2048
# 4s - loss: 0.6389 - val_loss: 0.5450
# Epoch 273/2048
# 1s - loss: 0.6389 - val_loss: 0.5451
# Epoch 274/2048
# 1s - loss: 0.6388 - val_loss: 0.5451
# Epoch 275/2048
# 4s - loss: 0.6387 - val_loss: 0.5447
# Epoch 276/2048
# 1s - loss: 0.6386 - val_loss: 0.5448
# Epoch 277/2048
# 5s - loss: 0.6385 - val_loss: 0.5444
# Epoch 278/2048
# 1s - loss: 0.6385 - val_loss: 0.5448
# Epoch 279/2048
# 5s - loss: 0.6384 - val_loss: 0.5443
# Epoch 280/2048
# 1s - loss: 0.6384 - val_loss: 0.5452
# Epoch 281/2048
# 1s - loss: 0.6384 - val_loss: 0.5445
# Epoch 282/2048
# 1s - loss: 0.6383 - val_loss: 0.5445
# Epoch 283/2048
# 1s - loss: 0.6383 - val_loss: 0.5444
# Epoch 284/2048
# 1s - loss: 0.6381 - val_loss: 0.5444
# Epoch 285/2048
# 3s - loss: 0.6381 - val_loss: 0.5441
# Epoch 286/2048
# 1s - loss: 0.6381 - val_loss: 0.5445
# Epoch 287/2048
# 6s - loss: 0.6381 - val_loss: 0.5439
# Epoch 288/2048
# 1s - loss: 0.6379 - val_loss: 0.5446
# Epoch 289/2048
# 5s - loss: 0.6378 - val_loss: 0.5438
# Epoch 290/2048
# 1s - loss: 0.6378 - val_loss: 0.5445
# Epoch 291/2048
# 1s - loss: 0.6378 - val_loss: 0.5442
# Epoch 292/2048
# 1s - loss: 0.6377 - val_loss: 0.5439
# Epoch 293/2048
# 4s - loss: 0.6377 - val_loss: 0.5437
# Epoch 294/2048
# 1s - loss: 0.6376 - val_loss: 0.5440
# Epoch 295/2048
# 1s - loss: 0.6376 - val_loss: 0.5441
# Epoch 296/2048
# 4s - loss: 0.6375 - val_loss: 0.5435
# Epoch 297/2048
# 1s - loss: 0.6374 - val_loss: 0.5437
# Epoch 298/2048
# 1s - loss: 0.6373 - val_loss: 0.5442
# Epoch 299/2048
# 1s - loss: 0.6374 - val_loss: 0.5439
# Epoch 300/2048
# 1s - loss: 0.6373 - val_loss: 0.5439
# Epoch 301/2048
# 4s - loss: 0.6372 - val_loss: 0.5432
# Epoch 302/2048
# 1s - loss: 0.6372 - val_loss: 0.5435
# Epoch 303/2048
# 4s - loss: 0.6371 - val_loss: 0.5430
# Epoch 304/2048
# 1s - loss: 0.6370 - val_loss: 0.5438
# Epoch 305/2048
# 1s - loss: 0.6370 - val_loss: 0.5433
# Epoch 306/2048
# 1s - loss: 0.6370 - val_loss: 0.5431
# Epoch 307/2048
# 1s - loss: 0.6370 - val_loss: 0.5432
# Epoch 308/2048
# 1s - loss: 0.6369 - val_loss: 0.5439
# Epoch 309/2048
# 1s - loss: 0.6367 - val_loss: 0.5432
# Epoch 310/2048
# 1s - loss: 0.6367 - val_loss: 0.5441
# Epoch 311/2048
# 1s - loss: 0.6367 - val_loss: 0.5431
# Epoch 312/2048
# 1s - loss: 0.6366 - val_loss: 0.5436
# Epoch 313/2048
# 1s - loss: 0.6366 - val_loss: 0.5435
# Epoch 314/2048
# 4s - loss: 0.6365 - val_loss: 0.5428
# Epoch 315/2048
# 1s - loss: 0.6365 - val_loss: 0.5434
# Epoch 316/2048
# 1s - loss: 0.6365 - val_loss: 0.5432
# Epoch 317/2048
# 1s - loss: 0.6363 - val_loss: 0.5430
# Epoch 318/2048
# 3s - loss: 0.6364 - val_loss: 0.5426
# Epoch 319/2048
# 1s - loss: 0.6362 - val_loss: 0.5428
# Epoch 320/2048
# 1s - loss: 0.6363 - val_loss: 0.5428
# Epoch 321/2048
# 3s - loss: 0.6361 - val_loss: 0.5425
# Epoch 322/2048
# 1s - loss: 0.6360 - val_loss: 0.5428
# Epoch 323/2048
# 1s - loss: 0.6361 - val_loss: 0.5429
# Epoch 324/2048
# 4s - loss: 0.6360 - val_loss: 0.5425
# Epoch 325/2048
# 5s - loss: 0.6359 - val_loss: 0.5420
# Epoch 326/2048
# 1s - loss: 0.6359 - val_loss: 0.5429
# Epoch 327/2048
# 1s - loss: 0.6358 - val_loss: 0.5429
# Epoch 328/2048
# 1s - loss: 0.6358 - val_loss: 0.5428
# Epoch 329/2048
# 1s - loss: 0.6358 - val_loss: 0.5423
# Epoch 330/2048
# 1s - loss: 0.6357 - val_loss: 0.5423
# Epoch 331/2048
# 1s - loss: 0.6356 - val_loss: 0.5423
# Epoch 332/2048
# 1s - loss: 0.6355 - val_loss: 0.5423
# Epoch 333/2048
# 1s - loss: 0.6355 - val_loss: 0.5424
# Epoch 334/2048
# 1s - loss: 0.6355 - val_loss: 0.5421
# Epoch 335/2048
# 1s - loss: 0.6355 - val_loss: 0.5423
# Epoch 336/2048
# 1s - loss: 0.6354 - val_loss: 0.5424
# Epoch 337/2048
# 1s - loss: 0.6354 - val_loss: 0.5426
# Epoch 338/2048
# 1s - loss: 0.6353 - val_loss: 0.5422
# Epoch 339/2048
# 1s - loss: 0.6352 - val_loss: 0.5421
# Epoch 340/2048
# 4s - loss: 0.6353 - val_loss: 0.5420
# Epoch 341/2048
# 1s - loss: 0.6352 - val_loss: 0.5430
# Epoch 342/2048
# 1s - loss: 0.6352 - val_loss: 0.5424
# Epoch 343/2048
# 3s - loss: 0.6351 - val_loss: 0.5416
# Epoch 344/2048
# 1s - loss: 0.6350 - val_loss: 0.5421
# Epoch 345/2048
# 1s - loss: 0.6350 - val_loss: 0.5419
# Epoch 346/2048
# 1s - loss: 0.6349 - val_loss: 0.5418
# Epoch 347/2048
# 3s - loss: 0.6349 - val_loss: 0.5415
# Epoch 348/2048
# 1s - loss: 0.6348 - val_loss: 0.5422
# Epoch 349/2048
# 1s - loss: 0.6347 - val_loss: 0.5419
# Epoch 350/2048
# 1s - loss: 0.6347 - val_loss: 0.5417
# Epoch 351/2048
# 1s - loss: 0.6346 - val_loss: 0.5423
# Epoch 352/2048
# 3s - loss: 0.6347 - val_loss: 0.5413
# Epoch 353/2048
# 1s - loss: 0.6346 - val_loss: 0.5418
# Epoch 354/2048
# 3s - loss: 0.6345 - val_loss: 0.5412
# Epoch 355/2048
# 1s - loss: 0.6344 - val_loss: 0.5418
# Epoch 356/2048
# 1s - loss: 0.6345 - val_loss: 0.5419
# Epoch 357/2048
# 1s - loss: 0.6344 - val_loss: 0.5423
# Epoch 358/2048
# 1s - loss: 0.6343 - val_loss: 0.5419
# Epoch 359/2048
# 1s - loss: 0.6343 - val_loss: 0.5415
# Epoch 360/2048
# 1s - loss: 0.6343 - val_loss: 0.5422
# Epoch 361/2048
# 1s - loss: 0.6344 - val_loss: 0.5412
# Epoch 362/2048
# 3s - loss: 0.6342 - val_loss: 0.5410
# Epoch 363/2048
# 1s - loss: 0.6341 - val_loss: 0.5419
# Epoch 364/2048
# 1s - loss: 0.6341 - val_loss: 0.5412
# Epoch 365/2048
# 1s - loss: 0.6340 - val_loss: 0.5411
# Epoch 366/2048
# 1s - loss: 0.6339 - val_loss: 0.5423
# Epoch 367/2048
# 1s - loss: 0.6340 - val_loss: 0.5413
# Epoch 368/2048
# 1s - loss: 0.6339 - val_loss: 0.5413
# Epoch 369/2048
# 1s - loss: 0.6339 - val_loss: 0.5418
# Epoch 370/2048
# 1s - loss: 0.6337 - val_loss: 0.5414
# Epoch 371/2048
# 3s - loss: 0.6337 - val_loss: 0.5409
# Epoch 372/2048
# 1s - loss: 0.6337 - val_loss: 0.5412
# Epoch 373/2048
# 1s - loss: 0.6336 - val_loss: 0.5413
# Epoch 374/2048
# 1s - loss: 0.6336 - val_loss: 0.5413
# Epoch 375/2048
# 3s - loss: 0.6336 - val_loss: 0.5409
# Epoch 376/2048
# 1s - loss: 0.6335 - val_loss: 0.5410
# Epoch 377/2048
# 1s - loss: 0.6335 - val_loss: 0.5416
# Epoch 378/2048
# 1s - loss: 0.6335 - val_loss: 0.5412
# Epoch 379/2048
# 1s - loss: 0.6334 - val_loss: 0.5415
# Epoch 380/2048
# 1s - loss: 0.6333 - val_loss: 0.5410
# Epoch 381/2048
# 1s - loss: 0.6332 - val_loss: 0.5412
# Epoch 382/2048
# 1s - loss: 0.6332 - val_loss: 0.5411
# Epoch 383/2048
# 1s - loss: 0.6331 - val_loss: 0.5409
# Epoch 384/2048
# 1s - loss: 0.6331 - val_loss: 0.5411
# Epoch 385/2048
# 4s - loss: 0.6330 - val_loss: 0.5409
# Epoch 386/2048
# 1s - loss: 0.6330 - val_loss: 0.5409
# Epoch 387/2048
# 1s - loss: 0.6330 - val_loss: 0.5411
# Epoch 388/2048
# 1s - loss: 0.6330 - val_loss: 0.5411
# Epoch 389/2048
# 3s - loss: 0.6329 - val_loss: 0.5401
# Epoch 390/2048
# 1s - loss: 0.6329 - val_loss: 0.5407
# Epoch 391/2048
# 1s - loss: 0.6328 - val_loss: 0.5410
# Epoch 392/2048
# 1s - loss: 0.6327 - val_loss: 0.5412
# Epoch 393/2048
# 1s - loss: 0.6328 - val_loss: 0.5403
# Epoch 394/2048
# 1s - loss: 0.6328 - val_loss: 0.5416
# Epoch 395/2048
# 1s - loss: 0.6327 - val_loss: 0.5406
# Epoch 396/2048
# 1s - loss: 0.6326 - val_loss: 0.5405
# Epoch 397/2048
# 1s - loss: 0.6325 - val_loss: 0.5409
# Epoch 398/2048
# 1s - loss: 0.6325 - val_loss: 0.5413
# Epoch 399/2048
# 1s - loss: 0.6324 - val_loss: 0.5411
# Epoch 400/2048
# 1s - loss: 0.6324 - val_loss: 0.5407
# Epoch 401/2048
# 1s - loss: 0.6324 - val_loss: 0.5411
# Epoch 402/2048
# 1s - loss: 0.6323 - val_loss: 0.5402
# Epoch 403/2048
# 1s - loss: 0.6324 - val_loss: 0.5406
# Epoch 404/2048
# 1s - loss: 0.6323 - val_loss: 0.5407
# Epoch 405/2048
# 1s - loss: 0.6322 - val_loss: 0.5402
# Epoch 406/2048
# 1s - loss: 0.6323 - val_loss: 0.5409
# Epoch 407/2048
# 1s - loss: 0.6321 - val_loss: 0.5407
# Epoch 408/2048
# 1s - loss: 0.6320 - val_loss: 0.5407
# Epoch 409/2048
# 4s - loss: 0.6320 - val_loss: 0.5400
# Epoch 410/2048
# 1s - loss: 0.6319 - val_loss: 0.5404
# Epoch 411/2048
# 1s - loss: 0.6319 - val_loss: 0.5403
# Epoch 412/2048
# 1s - loss: 0.6318 - val_loss: 0.5405
# Epoch 413/2048
# 1s - loss: 0.6318 - val_loss: 0.5408
# Epoch 414/2048
# 1s - loss: 0.6317 - val_loss: 0.5405
# Epoch 415/2048
# 1s - loss: 0.6317 - val_loss: 0.5404
# Epoch 416/2048
# 1s - loss: 0.6317 - val_loss: 0.5403
# Epoch 417/2048
# 1s - loss: 0.6316 - val_loss: 0.5407
# Epoch 418/2048
# 1s - loss: 0.6316 - val_loss: 0.5400
# Epoch 419/2048
# 1s - loss: 0.6316 - val_loss: 0.5403
# Epoch 420/2048
# 1s - loss: 0.6316 - val_loss: 0.5400
# Epoch 421/2048
# 1s - loss: 0.6315 - val_loss: 0.5406
# Epoch 422/2048
# 1s - loss: 0.6314 - val_loss: 0.5403
# Epoch 423/2048
# 3s - loss: 0.6313 - val_loss: 0.5396
# Epoch 424/2048
# 1s - loss: 0.6313 - val_loss: 0.5403
# Epoch 425/2048
# 1s - loss: 0.6312 - val_loss: 0.5402
# Epoch 426/2048
# 1s - loss: 0.6313 - val_loss: 0.5400
# Epoch 427/2048
# 1s - loss: 0.6314 - val_loss: 0.5397
# Epoch 428/2048
# 1s - loss: 0.6313 - val_loss: 0.5402
# Epoch 429/2048
# 1s - loss: 0.6313 - val_loss: 0.5402
# Epoch 430/2048
# 1s - loss: 0.6310 - val_loss: 0.5403
# Epoch 431/2048
# 1s - loss: 0.6310 - val_loss: 0.5403
# Epoch 432/2048
# 1s - loss: 0.6310 - val_loss: 0.5400
# Epoch 433/2048
# 1s - loss: 0.6309 - val_loss: 0.5402
# Epoch 434/2048
# 1s - loss: 0.6308 - val_loss: 0.5399
# Epoch 435/2048
# 1s - loss: 0.6309 - val_loss: 0.5402
# Epoch 436/2048
# 1s - loss: 0.6309 - val_loss: 0.5400
# Epoch 437/2048
# 1s - loss: 0.6307 - val_loss: 0.5402
# Epoch 438/2048
# 1s - loss: 0.6308 - val_loss: 0.5400
# Epoch 439/2048
# 3s - loss: 0.6306 - val_loss: 0.5395
# Epoch 440/2048
# 1s - loss: 0.6306 - val_loss: 0.5399
# Epoch 441/2048
# 1s - loss: 0.6306 - val_loss: 0.5400
# Epoch 442/2048
# 1s - loss: 0.6306 - val_loss: 0.5408
# Epoch 443/2048
# 1s - loss: 0.6306 - val_loss: 0.5404
# Epoch 444/2048
# 1s - loss: 0.6305 - val_loss: 0.5405
# Epoch 445/2048
# 1s - loss: 0.6305 - val_loss: 0.5396
# Epoch 446/2048
# 1s - loss: 0.6305 - val_loss: 0.5405
# Epoch 447/2048
# 1s - loss: 0.6303 - val_loss: 0.5407
# Epoch 448/2048
# 1s - loss: 0.6303 - val_loss: 0.5404
# Epoch 449/2048
# 1s - loss: 0.6303 - val_loss: 0.5402
# Epoch 450/2048
# 1s - loss: 0.6302 - val_loss: 0.5395
# Epoch 451/2048
# 1s - loss: 0.6301 - val_loss: 0.5399
# Epoch 452/2048
# 1s - loss: 0.6300 - val_loss: 0.5402
# Epoch 453/2048
# 1s - loss: 0.6300 - val_loss: 0.5405
# Epoch 454/2048
# 1s - loss: 0.6301 - val_loss: 0.5406
# Epoch 455/2048
# 1s - loss: 0.6301 - val_loss: 0.5405
# Epoch 456/2048
# 1s - loss: 0.6299 - val_loss: 0.5402
# Epoch 457/2048
# 3s - loss: 0.6299 - val_loss: 0.5393
# Epoch 458/2048
# 1s - loss: 0.6299 - val_loss: 0.5398
# Epoch 459/2048
# 1s - loss: 0.6298 - val_loss: 0.5398
# Epoch 460/2048
# 1s - loss: 0.6297 - val_loss: 0.5400
# Epoch 461/2048
# 1s - loss: 0.6297 - val_loss: 0.5396
# Epoch 462/2048
# 1s - loss: 0.6297 - val_loss: 0.5408
# Epoch 463/2048
# 1s - loss: 0.6296 - val_loss: 0.5402
# Epoch 464/2048
# 1s - loss: 0.6295 - val_loss: 0.5393
# Epoch 465/2048
# 1s - loss: 0.6296 - val_loss: 0.5400
# Epoch 466/2048
# 1s - loss: 0.6295 - val_loss: 0.5402
# Epoch 467/2048
# 1s - loss: 0.6295 - val_loss: 0.5398
# Epoch 468/2048
# 1s - loss: 0.6295 - val_loss: 0.5404
# Epoch 469/2048
# 1s - loss: 0.6294 - val_loss: 0.5401
# Epoch 470/2048
# 1s - loss: 0.6294 - val_loss: 0.5401
# Epoch 471/2048
# 1s - loss: 0.6293 - val_loss: 0.5402
# Epoch 472/2048
# 1s - loss: 0.6292 - val_loss: 0.5400
# Epoch 473/2048
# 1s - loss: 0.6291 - val_loss: 0.5397
# Epoch 474/2048
# 1s - loss: 0.6293 - val_loss: 0.5401
# Epoch 475/2048
# 1s - loss: 0.6291 - val_loss: 0.5400
# Epoch 476/2048
# 1s - loss: 0.6290 - val_loss: 0.5398
# Epoch 477/2048
# 1s - loss: 0.6290 - val_loss: 0.5404
# Epoch 478/2048
# 1s - loss: 0.6290 - val_loss: 0.5398
# Epoch 479/2048
# 1s - loss: 0.6289 - val_loss: 0.5404
# Epoch 480/2048
# 1s - loss: 0.6289 - val_loss: 0.5401
# Epoch 481/2048
# 1s - loss: 0.6289 - val_loss: 0.5396
# Epoch 482/2048
# 1s - loss: 0.6289 - val_loss: 0.5401
# Epoch 483/2048
# 1s - loss: 0.6289 - val_loss: 0.5407
# Epoch 484/2048
# 1s - loss: 0.6287 - val_loss: 0.5400
# Epoch 485/2048
# 1s - loss: 0.6288 - val_loss: 0.5406
# Epoch 486/2048
# 1s - loss: 0.6287 - val_loss: 0.5404
# Epoch 487/2048
# 1s - loss: 0.6286 - val_loss: 0.5404
# Epoch 488/2048
# 1s - loss: 0.6286 - val_loss: 0.5400
# Epoch 489/2048
# 1s - loss: 0.6285 - val_loss: 0.5407
# Epoch 490/2048
# 1s - loss: 0.6284 - val_loss: 0.5404
# Epoch 00489: early stopping

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name))

# %%
# Run predictions
ae_pred = autoencoder.predict(X_test_norm)
ae_pred_train = autoencoder.predict(X_train_norm)

# %%
# Exclude validation set
ae_pred_train = ae_pred_train[:int(0.75 * len(ae_pred_train)), :]

# %%
pickle.dump(ae_pred, open(model_directory + "ae_pred.p", "wb"))
pickle.dump(ae_pred_train, open(model_directory + "ae_pred_train.p", "wb"))

# %%
ae_pred = pickle.load(open(model_directory + "ae_pred.p", "rb"))
ae_pred_train = pickle.load(open(model_directory + "ae_pred_train.p", "rb"))

# %%
# Exclude validation set
X_train_wo_valid = X_train_norm[:int(0.75 * len(X_train_norm)), :]

# %%
def get_error_df(X_test, predictions, mode="allmean", n_highest = 100):
    
    if mode == "allmean":
        return np.mean(np.power(X_test - predictions, 2), axis=1)
    
    elif mode == "topn":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.mean(result, axis=1)
    
    elif mode == "topn_median":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.median(result, axis=1)
    
    elif mode == "perobj":
        mses = []
        for l in legend:
            mse = np.mean(
                np.power(X_test[:,l["start"]:l["end"]] - predictions[:,l["start"]:l["end"]], 2),
                axis=1)
            mses.append(mse)
     
        return np.maximum.reduce(mses)
    
    elif mode == "bottomn":
        temp = np.partition(np.power(X_test - predictions, 2), n_highest)
        result = temp[:,:n_highest]
        return np.mean(result, axis=1)

# %%
ae_pred.shape
# Out:
# (18628, 2808)

# %%
ae_error = get_error_df(X_test_norm, ae_pred, mode="topn", n_highest=100)
ae_error_train = get_error_df(X_train_wo_valid, ae_pred_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error, open(model_directory + "ae_error.p", "wb"))
pickle.dump(ae_error_train, open(model_directory + "ae_error_train.p", "wb"))

# %%
# Plot lumi vs error
def plot_lumi_error(pred, X_test, threshold=None, title=None):
    scores = get_error_df(X_test, pred, mode='topn')
    
    fig, ax = plt.subplots()

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 0],
             scores[y_test == 0],
             linestyle='',
             ms=2,
             marker='o',
             label="Outlier")

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 1],
             scores[y_test == 1],
             linestyle='',
             ms=2,
             marker='o',
             label="Inlier")

    ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
    
    ax.set_yscale("log")
    plt.ylabel("Score")
    plt.xlabel("Lumisection #")
    if title:
        plt.title(title)
    plt.show();

# %%
start_legend = 1414
var_legend = [{'start': start_legend, 'end': start_legend, 'name': 'mean'},
              {'start': start_legend+1, 'end': start_legend+1, 'name': 'RMS'},
              {'start': start_legend+2, 'end': start_legend+2, 'name': 'Q1'},
              {'start': start_legend+3, 'end': start_legend+3, 'name': 'Q2'},
              {'start': start_legend+4, 'end': start_legend+4, 'name': 'Q3'},
              {'start': start_legend+5, 'end': start_legend+5, 'name': 'Q4'},
              {'start': start_legend+6, 'end': start_legend+6, 'name': 'Q5'}]

# %%
corr = [pearsonr(X_train_wo_valid[:, i].reshape(-1), ae_pred_train[:, i].reshape(-1)) for i in range(INPUT_DIM)]
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:3021: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den

# %%
corr = np.array(corr)[:, 0]

# %%
corr[np.isnan(corr)] = 0

# %%
plt.hist(corr, bins=100)
plt.title('Histogram of correlation coefficients for 2809 features')
plt.show()

# %%
corr_filter = corr > 0.5

# %%
variance = np.var(data.iloc[:, 0:INPUT_DIM])

# %%
var_filter = variance != 0

# %%
feature_filter = corr_filter & var_filter

# %%
X_train_filtered = X_train_norm[:, feature_filter]
X_train_filtered.shape
# Out:
# (16294, 1170)

# %%
X_train_filtered_wo_valid = X_train.iloc[:round(0.75*len(X_train)), :]
X_train_filtered_wo_valid = np.array(X_train_filtered_wo_valid)[:, feature_filter]

# %%
corr_names = []
for i in tnrange(2808):
    v, r = divmod(i, 7)
    corr_names.append([feature_names[v],
                      var_legend[r]['name'],
                      corr[i]])

# %%
corr_names_pd = pd.DataFrame(corr_names, columns=['name', 'group',
                                                  'corr_coeff'])

# %%
corr_groups = corr_names_pd.groupby('group')

# %%
plt.rcParams['figure.figsize'] = [6, 3]
for n in corr_groups.groups.keys():
    coeffs = corr_groups.get_group(n).corr_coeff
    used = len(coeffs[coeffs > 0.5])/len(coeffs)
    plt.hist(corr_groups.get_group(n).corr_coeff, bins=10)
    plt.title(n + ' ' + str(round(used, 2)))
    plt.xlim([0, 1])
    plt.show()

# %%
corr_groups.aggregate(np.mean)
# Out:
#        corr_coeff
# group
# Q1       0.240629
# Q2       0.531084
# Q3       0.371853
# Q4       0.572851
# Q5       0.274348
# RMS      0.593304
# mean     0.424852

# %%
corr_groups.aggregate(np.median)
# Out:
#        corr_coeff
# group
# Q1       0.234014
# Q2       0.641915
# Q3       0.101435
# Q4       0.721690
# Q5       0.244286
# RMS      0.676668
# mean     0.247901

# %%
corr_groups.aggregate(np.std)
# Out:
#        corr_coeff
# group
# Q1       0.198089
# Q2       0.395393
# Q3       0.405507
# Q4       0.379859
# Q5       0.180980
# RMS      0.325722
# mean     0.372079

# %%
csv_dir = model_directory
corr_names_pd.to_csv(csv_dir + 'correlation_coeff_feature_names.csv', index=False)

# %%
input_dim = X_train_filtered.shape[1]
input_layer = Input(shape=(input_dim, ))

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(input_layer)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(32, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(64, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(128, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(256, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(512, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(1024, kernel_regularizer=l1_l2(10e-5))(x)
x = PReLU()(x)

x = Dense(input_dim)(x)

autoencoder = Model(inputs=input_layer, outputs=x)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 1170)              0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1024)              1199104
# _________________________________________________________________
# p_re_lu_12 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_14 (Dense)             (None, 512)               524800
# _________________________________________________________________
# p_re_lu_13 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_15 (Dense)             (None, 256)               131328
# _________________________________________________________________
# p_re_lu_14 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               32896
# _________________________________________________________________
# p_re_lu_15 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_17 (Dense)             (None, 64)                8256
# _________________________________________________________________
# p_re_lu_16 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_18 (Dense)             (None, 32)                2080
# _________________________________________________________________
# p_re_lu_17 (PReLU)           (None, 32)                32
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                2112
# _________________________________________________________________
# p_re_lu_18 (PReLU)           (None, 64)                64
# _________________________________________________________________
# dense_20 (Dense)             (None, 128)               8320
# _________________________________________________________________
# p_re_lu_19 (PReLU)           (None, 128)               128
# _________________________________________________________________
# dense_21 (Dense)             (None, 256)               33024
# _________________________________________________________________
# p_re_lu_20 (PReLU)           (None, 256)               256
# _________________________________________________________________
# dense_22 (Dense)             (None, 512)               131584
# _________________________________________________________________
# p_re_lu_21 (PReLU)           (None, 512)               512
# _________________________________________________________________
# dense_23 (Dense)             (None, 1024)              525312
# _________________________________________________________________
# p_re_lu_22 (PReLU)           (None, 1024)              1024
# _________________________________________________________________
# dense_24 (Dense)             (None, 1170)              1199250
# =================================================================
# Total params: 3,802,066
# Trainable params: 3,802,066
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_name2 = 'ae2'

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name2)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

# %%
autoencoder.fit(X_train_filtered,
                X_train_filtered,
                epochs=2048,
                batch_size=256,
                validation_split=0.25,
                verbose=2,
                callbacks=[early_stopper, checkpoint_callback])
# Out:
# Train on 12220 samples, validate on 4074 samples
# Epoch 1/2048
# 2s - loss: 42.4704 - val_loss: 37.9508
# Epoch 2/2048
# 1s - loss: 34.6104 - val_loss: 31.0248
# Epoch 3/2048
# 1s - loss: 28.3534 - val_loss: 25.4060
# Epoch 4/2048
# 1s - loss: 23.2042 - val_loss: 20.7328
# Epoch 5/2048
# 1s - loss: 18.9812 - val_loss: 16.9933
# Epoch 6/2048
# 1s - loss: 15.5854 - val_loss: 13.9828
# Epoch 7/2048
# 1s - loss: 12.7707 - val_loss: 11.5095
# Epoch 8/2048
# 2s - loss: 10.5207 - val_loss: 9.4962
# Epoch 9/2048
# 2s - loss: 8.6978 - val_loss: 7.8639
# Epoch 10/2048
# 2s - loss: 7.2199 - val_loss: 6.5401
# Epoch 11/2048
# 2s - loss: 6.0228 - val_loss: 5.4701
# Epoch 12/2048
# 1s - loss: 5.0548 - val_loss: 4.6051
# Epoch 13/2048
# 1s - loss: 4.2725 - val_loss: 3.9053
# Epoch 14/2048
# 1s - loss: 3.6393 - val_loss: 3.3408
# Epoch 15/2048
# 1s - loss: 3.1265 - val_loss: 2.8805
# Epoch 16/2048
# 1s - loss: 2.7101 - val_loss: 2.5076
# Epoch 17/2048
# 1s - loss: 2.3717 - val_loss: 2.2042
# Epoch 18/2048
# 2s - loss: 2.0956 - val_loss: 1.9554
# Epoch 19/2048
# 1s - loss: 1.8692 - val_loss: 1.7510
# Epoch 20/2048
# 1s - loss: 1.6810 - val_loss: 1.5796
# Epoch 21/2048
# 1s - loss: 1.5223 - val_loss: 1.4347
# Epoch 22/2048
# 1s - loss: 1.3886 - val_loss: 1.3119
# Epoch 23/2048
# 2s - loss: 1.2748 - val_loss: 1.2075
# Epoch 24/2048
# 2s - loss: 1.1772 - val_loss: 1.1167
# Epoch 25/2048
# 1s - loss: 1.0917 - val_loss: 1.0376
# Epoch 26/2048
# 1s - loss: 1.0170 - val_loss: 0.9676
# Epoch 27/2048
# 2s - loss: 0.9515 - val_loss: 0.9066
# Epoch 28/2048
# 1s - loss: 0.8945 - val_loss: 0.8534
# Epoch 29/2048
# 1s - loss: 0.8434 - val_loss: 0.8057
# Epoch 30/2048
# 1s - loss: 0.7989 - val_loss: 0.7641
# Epoch 31/2048
# 1s - loss: 0.7597 - val_loss: 0.7276
# Epoch 32/2048
# 1s - loss: 0.7252 - val_loss: 0.6958
# Epoch 33/2048
# 1s - loss: 0.6949 - val_loss: 0.6671
# Epoch 34/2048
# 1s - loss: 0.6676 - val_loss: 0.6416
# Epoch 35/2048
# 1s - loss: 0.6432 - val_loss: 0.6187
# Epoch 36/2048
# 1s - loss: 0.6215 - val_loss: 0.5979
# Epoch 37/2048
# 1s - loss: 0.6017 - val_loss: 0.5794
# Epoch 38/2048
# 1s - loss: 0.5839 - val_loss: 0.5628
# Epoch 39/2048
# 1s - loss: 0.5678 - val_loss: 0.5476
# Epoch 40/2048
# 1s - loss: 0.5533 - val_loss: 0.5340
# Epoch 41/2048
# 1s - loss: 0.5401 - val_loss: 0.5218
# Epoch 42/2048
# 2s - loss: 0.5282 - val_loss: 0.5104
# Epoch 43/2048
# 1s - loss: 0.5174 - val_loss: 0.5000
# Epoch 44/2048
# 1s - loss: 0.5077 - val_loss: 0.4911
# Epoch 45/2048
# 2s - loss: 0.4988 - val_loss: 0.4826
# Epoch 46/2048
# 2s - loss: 0.4907 - val_loss: 0.4755
# Epoch 47/2048
# 1s - loss: 0.4834 - val_loss: 0.4681
# Epoch 48/2048
# 2s - loss: 0.4767 - val_loss: 0.4620
# Epoch 49/2048
# 2s - loss: 0.4705 - val_loss: 0.4565
# Epoch 50/2048
# 2s - loss: 0.4649 - val_loss: 0.4507
# Epoch 51/2048
# 1s - loss: 0.4598 - val_loss: 0.4460
# Epoch 52/2048
# 1s - loss: 0.4550 - val_loss: 0.4417
# Epoch 53/2048
# 1s - loss: 0.4506 - val_loss: 0.4378
# Epoch 54/2048
# 2s - loss: 0.4467 - val_loss: 0.4338
# Epoch 55/2048
# 1s - loss: 0.4429 - val_loss: 0.4302
# Epoch 56/2048
# 1s - loss: 0.4394 - val_loss: 0.4266
# Epoch 57/2048
# 2s - loss: 0.4362 - val_loss: 0.4238
# Epoch 58/2048
# 1s - loss: 0.4333 - val_loss: 0.4213
# Epoch 59/2048
# 1s - loss: 0.4306 - val_loss: 0.4188
# Epoch 60/2048
# 3s - loss: 0.4280 - val_loss: 0.4162
# Epoch 61/2048
# 1s - loss: 0.4258 - val_loss: 0.4140
# Epoch 62/2048
# 1s - loss: 0.4235 - val_loss: 0.4119
# Epoch 63/2048
# 1s - loss: 0.4214 - val_loss: 0.4102
# Epoch 64/2048
# 1s - loss: 0.4196 - val_loss: 0.4081
# Epoch 65/2048
# 1s - loss: 0.4179 - val_loss: 0.4066
# Epoch 66/2048
# 1s - loss: 0.4162 - val_loss: 0.4052
# Epoch 67/2048
# 2s - loss: 0.4147 - val_loss: 0.4039
# Epoch 68/2048
# 1s - loss: 0.4132 - val_loss: 0.4027
# Epoch 69/2048
# 1s - loss: 0.4119 - val_loss: 0.4013
# Epoch 70/2048
# 1s - loss: 0.4106 - val_loss: 0.4000
# Epoch 71/2048
# 1s - loss: 0.4094 - val_loss: 0.3990
# Epoch 72/2048
# 1s - loss: 0.4084 - val_loss: 0.3975
# Epoch 73/2048
# 2s - loss: 0.4073 - val_loss: 0.3969
# Epoch 74/2048
# 1s - loss: 0.4063 - val_loss: 0.3961
# Epoch 75/2048
# 1s - loss: 0.4054 - val_loss: 0.3950
# Epoch 76/2048
# 1s - loss: 0.4044 - val_loss: 0.3944
# Epoch 77/2048
# 1s - loss: 0.4034 - val_loss: 0.3934
# Epoch 78/2048
# 1s - loss: 0.4027 - val_loss: 0.3922
# Epoch 79/2048
# 1s - loss: 0.4019 - val_loss: 0.3921
# Epoch 80/2048
# 1s - loss: 0.4011 - val_loss: 0.3910
# Epoch 81/2048
# 1s - loss: 0.4004 - val_loss: 0.3904
# Epoch 82/2048
# 1s - loss: 0.3997 - val_loss: 0.3899
# Epoch 83/2048
# 2s - loss: 0.3989 - val_loss: 0.3892
# Epoch 84/2048
# 1s - loss: 0.3983 - val_loss: 0.3886
# Epoch 85/2048
# 1s - loss: 0.3977 - val_loss: 0.3882
# Epoch 86/2048
# 2s - loss: 0.3973 - val_loss: 0.3875
# Epoch 87/2048
# 1s - loss: 0.3966 - val_loss: 0.3869
# Epoch 88/2048
# 1s - loss: 0.3960 - val_loss: 0.3859
# Epoch 89/2048
# 1s - loss: 0.3955 - val_loss: 0.3861
# Epoch 90/2048
# 1s - loss: 0.3951 - val_loss: 0.3856
# Epoch 91/2048
# 2s - loss: 0.3945 - val_loss: 0.3849
# Epoch 92/2048
# 1s - loss: 0.3940 - val_loss: 0.3845
# Epoch 93/2048
# 1s - loss: 0.3935 - val_loss: 0.3840
# Epoch 94/2048
# 1s - loss: 0.3931 - val_loss: 0.3837
# Epoch 95/2048
# 1s - loss: 0.3925 - val_loss: 0.3829
# Epoch 96/2048
# 1s - loss: 0.3922 - val_loss: 0.3826
# Epoch 97/2048
# 1s - loss: 0.3918 - val_loss: 0.3822
# Epoch 98/2048
# 1s - loss: 0.3912 - val_loss: 0.3817
# Epoch 99/2048
# 1s - loss: 0.3907 - val_loss: 0.3817
# Epoch 100/2048
# 1s - loss: 0.3904 - val_loss: 0.3810
# Epoch 101/2048
# 1s - loss: 0.3899 - val_loss: 0.3803
# Epoch 102/2048
# 1s - loss: 0.3895 - val_loss: 0.3800
# Epoch 103/2048
# 1s - loss: 0.3890 - val_loss: 0.3797
# Epoch 104/2048
# 2s - loss: 0.3886 - val_loss: 0.3789
# Epoch 105/2048
# 1s - loss: 0.3882 - val_loss: 0.3791
# Epoch 106/2048
# 1s - loss: 0.3878 - val_loss: 0.3785
# Epoch 107/2048
# 1s - loss: 0.3874 - val_loss: 0.3780
# Epoch 108/2048
# 1s - loss: 0.3870 - val_loss: 0.3777
# Epoch 109/2048
# 1s - loss: 0.3867 - val_loss: 0.3777
# Epoch 110/2048
# 1s - loss: 0.3864 - val_loss: 0.3766
# Epoch 111/2048
# 1s - loss: 0.3859 - val_loss: 0.3769
# Epoch 112/2048
# 1s - loss: 0.3855 - val_loss: 0.3763
# Epoch 113/2048
# 1s - loss: 0.3852 - val_loss: 0.3763
# Epoch 114/2048
# 1s - loss: 0.3848 - val_loss: 0.3759
# Epoch 115/2048
# 1s - loss: 0.3845 - val_loss: 0.3750
# Epoch 116/2048
# 1s - loss: 0.3841 - val_loss: 0.3750
# Epoch 117/2048
# 1s - loss: 0.3837 - val_loss: 0.3745
# Epoch 118/2048
# 1s - loss: 0.3834 - val_loss: 0.3741
# Epoch 119/2048
# 1s - loss: 0.3831 - val_loss: 0.3738
# Epoch 120/2048
# 1s - loss: 0.3827 - val_loss: 0.3732
# Epoch 121/2048
# 1s - loss: 0.3823 - val_loss: 0.3733
# Epoch 122/2048
# 1s - loss: 0.3820 - val_loss: 0.3729
# Epoch 123/2048
# 1s - loss: 0.3817 - val_loss: 0.3732
# Epoch 124/2048
# 1s - loss: 0.3814 - val_loss: 0.3725
# Epoch 125/2048
# 1s - loss: 0.3811 - val_loss: 0.3719
# Epoch 126/2048
# 1s - loss: 0.3806 - val_loss: 0.3714
# Epoch 127/2048
# 1s - loss: 0.3804 - val_loss: 0.3713
# Epoch 128/2048
# 1s - loss: 0.3800 - val_loss: 0.3708
# Epoch 129/2048
# 1s - loss: 0.3797 - val_loss: 0.3708
# Epoch 130/2048
# 1s - loss: 0.3794 - val_loss: 0.3702
# Epoch 131/2048
# 1s - loss: 0.3791 - val_loss: 0.3702
# Epoch 132/2048
# 1s - loss: 0.3788 - val_loss: 0.3696
# Epoch 133/2048
# 2s - loss: 0.3785 - val_loss: 0.3695
# Epoch 134/2048
# 1s - loss: 0.3781 - val_loss: 0.3692
# Epoch 135/2048
# 1s - loss: 0.3778 - val_loss: 0.3689
# Epoch 136/2048
# 1s - loss: 0.3775 - val_loss: 0.3686
# Epoch 137/2048
# 1s - loss: 0.3772 - val_loss: 0.3686
# Epoch 138/2048
# 1s - loss: 0.3770 - val_loss: 0.3677
# Epoch 139/2048
# 1s - loss: 0.3767 - val_loss: 0.3678
# Epoch 140/2048
# 1s - loss: 0.3765 - val_loss: 0.3678
# Epoch 141/2048
# 1s - loss: 0.3761 - val_loss: 0.3671
# Epoch 142/2048
# 1s - loss: 0.3759 - val_loss: 0.3669
# Epoch 143/2048
# 1s - loss: 0.3756 - val_loss: 0.3668
# Epoch 144/2048
# 2s - loss: 0.3753 - val_loss: 0.3665
# Epoch 145/2048
# 1s - loss: 0.3750 - val_loss: 0.3663
# Epoch 146/2048
# 1s - loss: 0.3747 - val_loss: 0.3658
# Epoch 147/2048
# 1s - loss: 0.3744 - val_loss: 0.3654
# Epoch 148/2048
# 1s - loss: 0.3741 - val_loss: 0.3655
# Epoch 149/2048
# 1s - loss: 0.3739 - val_loss: 0.3652
# Epoch 150/2048
# 2s - loss: 0.3738 - val_loss: 0.3649
# Epoch 151/2048
# 1s - loss: 0.3734 - val_loss: 0.3645
# Epoch 152/2048
# 1s - loss: 0.3732 - val_loss: 0.3642
# Epoch 153/2048
# 1s - loss: 0.3729 - val_loss: 0.3636
# Epoch 154/2048
# 1s - loss: 0.3728 - val_loss: 0.3639
# Epoch 155/2048
# 1s - loss: 0.3724 - val_loss: 0.3632
# Epoch 156/2048
# 1s - loss: 0.3721 - val_loss: 0.3632
# Epoch 157/2048
# 1s - loss: 0.3718 - val_loss: 0.3629
# Epoch 158/2048
# 2s - loss: 0.3716 - val_loss: 0.3627
# Epoch 159/2048
# 1s - loss: 0.3713 - val_loss: 0.3629
# Epoch 160/2048
# 1s - loss: 0.3710 - val_loss: 0.3621
# Epoch 161/2048
# 1s - loss: 0.3708 - val_loss: 0.3622
# Epoch 162/2048
# 1s - loss: 0.3705 - val_loss: 0.3619
# Epoch 163/2048
# 1s - loss: 0.3702 - val_loss: 0.3613
# Epoch 164/2048
# 1s - loss: 0.3700 - val_loss: 0.3612
# Epoch 165/2048
# 1s - loss: 0.3698 - val_loss: 0.3610
# Epoch 166/2048
# 1s - loss: 0.3695 - val_loss: 0.3607
# Epoch 167/2048
# 1s - loss: 0.3692 - val_loss: 0.3606
# Epoch 168/2048
# 1s - loss: 0.3689 - val_loss: 0.3604
# Epoch 169/2048
# 1s - loss: 0.3686 - val_loss: 0.3598
# Epoch 170/2048
# 1s - loss: 0.3684 - val_loss: 0.3601
# Epoch 171/2048
# 1s - loss: 0.3682 - val_loss: 0.3595
# Epoch 172/2048
# 1s - loss: 0.3678 - val_loss: 0.3590
# Epoch 173/2048
# 1s - loss: 0.3675 - val_loss: 0.3589
# Epoch 174/2048
# 1s - loss: 0.3673 - val_loss: 0.3583
# Epoch 175/2048
# 1s - loss: 0.3670 - val_loss: 0.3585
# Epoch 176/2048
# 1s - loss: 0.3666 - val_loss: 0.3579
# Epoch 177/2048
# 1s - loss: 0.3664 - val_loss: 0.3578
# Epoch 178/2048
# 1s - loss: 0.3661 - val_loss: 0.3575
# Epoch 179/2048
# 1s - loss: 0.3659 - val_loss: 0.3573
# Epoch 180/2048
# 1s - loss: 0.3657 - val_loss: 0.3572
# Epoch 181/2048
# 1s - loss: 0.3654 - val_loss: 0.3567
# Epoch 182/2048
# 1s - loss: 0.3651 - val_loss: 0.3563
# Epoch 183/2048
# 1s - loss: 0.3649 - val_loss: 0.3566
# Epoch 184/2048
# 1s - loss: 0.3646 - val_loss: 0.3561
# Epoch 185/2048
# 1s - loss: 0.3644 - val_loss: 0.3561
# Epoch 186/2048
# 1s - loss: 0.3642 - val_loss: 0.3558
# Epoch 187/2048
# 2s - loss: 0.3639 - val_loss: 0.3557
# Epoch 188/2048
# 1s - loss: 0.3637 - val_loss: 0.3552
# Epoch 189/2048
# 1s - loss: 0.3635 - val_loss: 0.3552
# Epoch 190/2048
# 1s - loss: 0.3632 - val_loss: 0.3547
# Epoch 191/2048
# 1s - loss: 0.3630 - val_loss: 0.3547
# Epoch 192/2048
# 1s - loss: 0.3627 - val_loss: 0.3542
# Epoch 193/2048
# 1s - loss: 0.3625 - val_loss: 0.3541
# Epoch 194/2048
# 2s - loss: 0.3624 - val_loss: 0.3539
# Epoch 195/2048
# 2s - loss: 0.3621 - val_loss: 0.3537
# Epoch 196/2048
# 1s - loss: 0.3619 - val_loss: 0.3536
# Epoch 197/2048
# 1s - loss: 0.3617 - val_loss: 0.3531
# Epoch 198/2048
# 1s - loss: 0.3615 - val_loss: 0.3530
# Epoch 199/2048
# 1s - loss: 0.3613 - val_loss: 0.3528
# Epoch 200/2048
# 2s - loss: 0.3611 - val_loss: 0.3526
# Epoch 201/2048
# 2s - loss: 0.3608 - val_loss: 0.3524
# Epoch 202/2048
# 1s - loss: 0.3606 - val_loss: 0.3524
# Epoch 203/2048
# 1s - loss: 0.3605 - val_loss: 0.3520
# Epoch 204/2048
# 1s - loss: 0.3602 - val_loss: 0.3518
# Epoch 205/2048
# 1s - loss: 0.3600 - val_loss: 0.3517
# Epoch 206/2048
# 1s - loss: 0.3597 - val_loss: 0.3517
# Epoch 207/2048
# 1s - loss: 0.3596 - val_loss: 0.3513
# Epoch 208/2048
# 1s - loss: 0.3594 - val_loss: 0.3512
# Epoch 209/2048
# 2s - loss: 0.3592 - val_loss: 0.3508
# Epoch 210/2048
# 2s - loss: 0.3589 - val_loss: 0.3507
# Epoch 211/2048
# 2s - loss: 0.3587 - val_loss: 0.3504
# Epoch 212/2048
# 1s - loss: 0.3586 - val_loss: 0.3501
# Epoch 213/2048
# 1s - loss: 0.3584 - val_loss: 0.3501
# Epoch 214/2048
# 1s - loss: 0.3582 - val_loss: 0.3498
# Epoch 215/2048
# 1s - loss: 0.3580 - val_loss: 0.3497
# Epoch 216/2048
# 1s - loss: 0.3578 - val_loss: 0.3496
# Epoch 217/2048
# 2s - loss: 0.3576 - val_loss: 0.3495
# Epoch 218/2048
# 1s - loss: 0.3575 - val_loss: 0.3495
# Epoch 219/2048
# 1s - loss: 0.3572 - val_loss: 0.3489
# Epoch 220/2048
# 1s - loss: 0.3570 - val_loss: 0.3491
# Epoch 221/2048
# 1s - loss: 0.3568 - val_loss: 0.3488
# Epoch 222/2048
# 1s - loss: 0.3567 - val_loss: 0.3484
# Epoch 223/2048
# 1s - loss: 0.3564 - val_loss: 0.3482
# Epoch 224/2048
# 1s - loss: 0.3562 - val_loss: 0.3483
# Epoch 225/2048
# 1s - loss: 0.3561 - val_loss: 0.3484
# Epoch 226/2048
# 1s - loss: 0.3560 - val_loss: 0.3473
# Epoch 227/2048
# 1s - loss: 0.3557 - val_loss: 0.3477
# Epoch 228/2048
# 1s - loss: 0.3555 - val_loss: 0.3475
# Epoch 229/2048
# 1s - loss: 0.3554 - val_loss: 0.3472
# Epoch 230/2048
# 1s - loss: 0.3552 - val_loss: 0.3473
# Epoch 231/2048
# 1s - loss: 0.3550 - val_loss: 0.3468
# Epoch 232/2048
# 1s - loss: 0.3548 - val_loss: 0.3468
# Epoch 233/2048
# 1s - loss: 0.3547 - val_loss: 0.3467
# Epoch 234/2048
# 1s - loss: 0.3545 - val_loss: 0.3466
# Epoch 235/2048
# 1s - loss: 0.3543 - val_loss: 0.3464
# Epoch 236/2048
# 1s - loss: 0.3542 - val_loss: 0.3460
# Epoch 237/2048
# 1s - loss: 0.3540 - val_loss: 0.3457
# Epoch 238/2048
# 1s - loss: 0.3538 - val_loss: 0.3458
# Epoch 239/2048
# 1s - loss: 0.3536 - val_loss: 0.3455
# Epoch 240/2048
# 1s - loss: 0.3534 - val_loss: 0.3453
# Epoch 241/2048
# 1s - loss: 0.3533 - val_loss: 0.3453
# Epoch 242/2048
# 1s - loss: 0.3531 - val_loss: 0.3455
# Epoch 243/2048
# 1s - loss: 0.3529 - val_loss: 0.3451
# Epoch 244/2048
# 1s - loss: 0.3528 - val_loss: 0.3448
# Epoch 245/2048
# 1s - loss: 0.3526 - val_loss: 0.3446
# Epoch 246/2048
# 1s - loss: 0.3524 - val_loss: 0.3445
# Epoch 247/2048
# 1s - loss: 0.3523 - val_loss: 0.3445
# Epoch 248/2048
# 1s - loss: 0.3521 - val_loss: 0.3441
# Epoch 249/2048
# 1s - loss: 0.3519 - val_loss: 0.3441
# Epoch 250/2048
# 1s - loss: 0.3517 - val_loss: 0.3436
# Epoch 251/2048
# 1s - loss: 0.3516 - val_loss: 0.3437
# Epoch 252/2048
# 1s - loss: 0.3514 - val_loss: 0.3435
# Epoch 253/2048
# 1s - loss: 0.3512 - val_loss: 0.3432
# Epoch 254/2048
# 1s - loss: 0.3510 - val_loss: 0.3433
# Epoch 255/2048
# 1s - loss: 0.3509 - val_loss: 0.3429
# Epoch 256/2048
# 2s - loss: 0.3507 - val_loss: 0.3427
# Epoch 257/2048
# 1s - loss: 0.3505 - val_loss: 0.3426
# Epoch 258/2048
# 2s - loss: 0.3503 - val_loss: 0.3425
# Epoch 259/2048
# 2s - loss: 0.3502 - val_loss: 0.3424
# Epoch 260/2048
# 1s - loss: 0.3500 - val_loss: 0.3422
# Epoch 261/2048
# 1s - loss: 0.3498 - val_loss: 0.3421
# Epoch 262/2048
# 1s - loss: 0.3497 - val_loss: 0.3417
# Epoch 263/2048
# 1s - loss: 0.3495 - val_loss: 0.3416
# Epoch 264/2048
# 1s - loss: 0.3493 - val_loss: 0.3416
# Epoch 265/2048
# 1s - loss: 0.3491 - val_loss: 0.3414
# Epoch 266/2048
# 1s - loss: 0.3490 - val_loss: 0.3411
# Epoch 267/2048
# 1s - loss: 0.3488 - val_loss: 0.3409
# Epoch 268/2048
# 1s - loss: 0.3486 - val_loss: 0.3409
# Epoch 269/2048
# 1s - loss: 0.3484 - val_loss: 0.3408
# Epoch 270/2048
# 1s - loss: 0.3483 - val_loss: 0.3405
# Epoch 271/2048
# 1s - loss: 0.3481 - val_loss: 0.3404
# Epoch 272/2048
# 1s - loss: 0.3479 - val_loss: 0.3403
# Epoch 273/2048
# 2s - loss: 0.3477 - val_loss: 0.3400
# Epoch 274/2048
# 1s - loss: 0.3475 - val_loss: 0.3398
# Epoch 275/2048
# 1s - loss: 0.3474 - val_loss: 0.3398
# Epoch 276/2048
# 1s - loss: 0.3472 - val_loss: 0.3396
# Epoch 277/2048
# 1s - loss: 0.3470 - val_loss: 0.3394
# Epoch 278/2048
# 1s - loss: 0.3468 - val_loss: 0.3390
# Epoch 279/2048
# 1s - loss: 0.3467 - val_loss: 0.3392
# Epoch 280/2048
# 1s - loss: 0.3465 - val_loss: 0.3390
# Epoch 281/2048
# 1s - loss: 0.3463 - val_loss: 0.3385
# Epoch 282/2048
# 1s - loss: 0.3461 - val_loss: 0.3384
# Epoch 283/2048
# 1s - loss: 0.3460 - val_loss: 0.3381
# Epoch 284/2048
# 1s - loss: 0.3458 - val_loss: 0.3383
# Epoch 285/2048
# 1s - loss: 0.3456 - val_loss: 0.3381
# Epoch 286/2048
# 1s - loss: 0.3454 - val_loss: 0.3380
# Epoch 287/2048
# 2s - loss: 0.3452 - val_loss: 0.3375
# Epoch 288/2048
# 1s - loss: 0.3451 - val_loss: 0.3376
# Epoch 289/2048
# 1s - loss: 0.3449 - val_loss: 0.3372
# Epoch 290/2048
# 1s - loss: 0.3448 - val_loss: 0.3370
# Epoch 291/2048
# 2s - loss: 0.3445 - val_loss: 0.3367
# Epoch 292/2048
# 1s - loss: 0.3444 - val_loss: 0.3367
# Epoch 293/2048
# 1s - loss: 0.3442 - val_loss: 0.3365
# Epoch 294/2048
# 1s - loss: 0.3440 - val_loss: 0.3365
# Epoch 295/2048
# 2s - loss: 0.3439 - val_loss: 0.3359
# Epoch 296/2048
# 1s - loss: 0.3437 - val_loss: 0.3361
# Epoch 297/2048
# 1s - loss: 0.3435 - val_loss: 0.3360
# Epoch 298/2048
# 1s - loss: 0.3434 - val_loss: 0.3356
# Epoch 299/2048
# 1s - loss: 0.3431 - val_loss: 0.3352
# Epoch 300/2048
# 2s - loss: 0.3430 - val_loss: 0.3351
# Epoch 301/2048
# 1s - loss: 0.3428 - val_loss: 0.3355
# Epoch 302/2048
# 1s - loss: 0.3427 - val_loss: 0.3351
# Epoch 303/2048
# 1s - loss: 0.3425 - val_loss: 0.3347
# Epoch 304/2048
# 1s - loss: 0.3423 - val_loss: 0.3350
# Epoch 305/2048
# 1s - loss: 0.3422 - val_loss: 0.3347
# Epoch 306/2048
# 1s - loss: 0.3420 - val_loss: 0.3343
# Epoch 307/2048
# 2s - loss: 0.3418 - val_loss: 0.3343
# Epoch 308/2048
# 1s - loss: 0.3417 - val_loss: 0.3342
# Epoch 309/2048
# 1s - loss: 0.3415 - val_loss: 0.3343
# Epoch 310/2048
# 1s - loss: 0.3414 - val_loss: 0.3340
# Epoch 311/2048
# 1s - loss: 0.3412 - val_loss: 0.3336
# Epoch 312/2048
# 1s - loss: 0.3410 - val_loss: 0.3333
# Epoch 313/2048
# 1s - loss: 0.3409 - val_loss: 0.3335
# Epoch 314/2048
# 1s - loss: 0.3408 - val_loss: 0.3330
# Epoch 315/2048
# 1s - loss: 0.3406 - val_loss: 0.3332
# Epoch 316/2048
# 1s - loss: 0.3404 - val_loss: 0.3328
# Epoch 317/2048
# 1s - loss: 0.3403 - val_loss: 0.3329
# Epoch 318/2048
# 1s - loss: 0.3401 - val_loss: 0.3325
# Epoch 319/2048
# 1s - loss: 0.3400 - val_loss: 0.3327
# Epoch 320/2048
# 1s - loss: 0.3398 - val_loss: 0.3323
# Epoch 321/2048
# 1s - loss: 0.3397 - val_loss: 0.3323
# Epoch 322/2048
# 1s - loss: 0.3396 - val_loss: 0.3321
# Epoch 323/2048
# 1s - loss: 0.3394 - val_loss: 0.3320
# Epoch 324/2048
# 1s - loss: 0.3392 - val_loss: 0.3318
# Epoch 325/2048
# 1s - loss: 0.3391 - val_loss: 0.3315
# Epoch 326/2048
# 1s - loss: 0.3389 - val_loss: 0.3314
# Epoch 327/2048
# 1s - loss: 0.3388 - val_loss: 0.3312
# Epoch 328/2048
# 1s - loss: 0.3386 - val_loss: 0.3312
# Epoch 329/2048
# 1s - loss: 0.3385 - val_loss: 0.3311
# Epoch 330/2048
# 1s - loss: 0.3383 - val_loss: 0.3310
# Epoch 331/2048
# 1s - loss: 0.3382 - val_loss: 0.3306
# Epoch 332/2048
# 1s - loss: 0.3381 - val_loss: 0.3304
# Epoch 333/2048
# 1s - loss: 0.3379 - val_loss: 0.3306
# Epoch 334/2048
# 1s - loss: 0.3378 - val_loss: 0.3303
# Epoch 335/2048
# 1s - loss: 0.3376 - val_loss: 0.3299
# Epoch 336/2048
# 1s - loss: 0.3375 - val_loss: 0.3299
# Epoch 337/2048
# 1s - loss: 0.3373 - val_loss: 0.3298
# Epoch 338/2048
# 1s - loss: 0.3372 - val_loss: 0.3297
# Epoch 339/2048
# 1s - loss: 0.3370 - val_loss: 0.3295
# Epoch 340/2048
# 1s - loss: 0.3369 - val_loss: 0.3296
# Epoch 341/2048
# 1s - loss: 0.3368 - val_loss: 0.3293
# Epoch 342/2048
# 1s - loss: 0.3366 - val_loss: 0.3290
# Epoch 343/2048
# 1s - loss: 0.3365 - val_loss: 0.3292
# Epoch 344/2048
# 1s - loss: 0.3363 - val_loss: 0.3290
# Epoch 345/2048
# 1s - loss: 0.3363 - val_loss: 0.3290
# Epoch 346/2048
# 1s - loss: 0.3361 - val_loss: 0.3288
# Epoch 347/2048
# 1s - loss: 0.3359 - val_loss: 0.3285
# Epoch 348/2048
# 1s - loss: 0.3358 - val_loss: 0.3285
# Epoch 349/2048
# 1s - loss: 0.3356 - val_loss: 0.3281
# Epoch 350/2048
# 1s - loss: 0.3355 - val_loss: 0.3280
# Epoch 351/2048
# 1s - loss: 0.3353 - val_loss: 0.3281
# Epoch 352/2048
# 1s - loss: 0.3352 - val_loss: 0.3277
# Epoch 353/2048
# 1s - loss: 0.3350 - val_loss: 0.3275
# Epoch 354/2048
# 2s - loss: 0.3349 - val_loss: 0.3273
# Epoch 355/2048
# 1s - loss: 0.3347 - val_loss: 0.3276
# Epoch 356/2048
# 1s - loss: 0.3346 - val_loss: 0.3272
# Epoch 357/2048
# 1s - loss: 0.3345 - val_loss: 0.3272
# Epoch 358/2048
# 1s - loss: 0.3344 - val_loss: 0.3267
# Epoch 359/2048
# 1s - loss: 0.3342 - val_loss: 0.3268
# Epoch 360/2048
# 1s - loss: 0.3340 - val_loss: 0.3267
# Epoch 361/2048
# 1s - loss: 0.3339 - val_loss: 0.3266
# Epoch 362/2048
# 1s - loss: 0.3337 - val_loss: 0.3262
# Epoch 363/2048
# 1s - loss: 0.3336 - val_loss: 0.3264
# Epoch 364/2048
# 1s - loss: 0.3335 - val_loss: 0.3261
# Epoch 365/2048
# 1s - loss: 0.3333 - val_loss: 0.3262
# Epoch 366/2048
# 1s - loss: 0.3331 - val_loss: 0.3260
# Epoch 367/2048
# 2s - loss: 0.3330 - val_loss: 0.3254
# Epoch 368/2048
# 2s - loss: 0.3328 - val_loss: 0.3254
# Epoch 369/2048
# 1s - loss: 0.3327 - val_loss: 0.3252
# Epoch 370/2048
# 1s - loss: 0.3326 - val_loss: 0.3258
# Epoch 371/2048
# 1s - loss: 0.3324 - val_loss: 0.3250
# Epoch 372/2048
# 1s - loss: 0.3322 - val_loss: 0.3249
# Epoch 373/2048
# 1s - loss: 0.3321 - val_loss: 0.3247
# Epoch 374/2048
# 1s - loss: 0.3319 - val_loss: 0.3248
# Epoch 375/2048
# 1s - loss: 0.3318 - val_loss: 0.3244
# Epoch 376/2048
# 1s - loss: 0.3316 - val_loss: 0.3243
# Epoch 377/2048
# 1s - loss: 0.3314 - val_loss: 0.3241
# Epoch 378/2048
# 1s - loss: 0.3312 - val_loss: 0.3238
# Epoch 379/2048
# 1s - loss: 0.3311 - val_loss: 0.3237
# Epoch 380/2048
# 2s - loss: 0.3309 - val_loss: 0.3234
# Epoch 381/2048
# 1s - loss: 0.3307 - val_loss: 0.3236
# Epoch 382/2048
# 1s - loss: 0.3306 - val_loss: 0.3231
# Epoch 383/2048
# 1s - loss: 0.3304 - val_loss: 0.3227
# Epoch 384/2048
# 1s - loss: 0.3302 - val_loss: 0.3231
# Epoch 385/2048
# 1s - loss: 0.3301 - val_loss: 0.3229
# Epoch 386/2048
# 1s - loss: 0.3298 - val_loss: 0.3225
# Epoch 387/2048
# 1s - loss: 0.3297 - val_loss: 0.3223
# Epoch 388/2048
# 1s - loss: 0.3294 - val_loss: 0.3221
# Epoch 389/2048
# 1s - loss: 0.3293 - val_loss: 0.3221
# Epoch 390/2048
# 1s - loss: 0.3291 - val_loss: 0.3216
# Epoch 391/2048
# 1s - loss: 0.3289 - val_loss: 0.3215
# Epoch 392/2048
# 1s - loss: 0.3287 - val_loss: 0.3213
# Epoch 393/2048
# 1s - loss: 0.3285 - val_loss: 0.3213
# Epoch 394/2048
# 1s - loss: 0.3283 - val_loss: 0.3212
# Epoch 395/2048
# 1s - loss: 0.3280 - val_loss: 0.3204
# Epoch 396/2048
# 1s - loss: 0.3279 - val_loss: 0.3205
# Epoch 397/2048
# 1s - loss: 0.3277 - val_loss: 0.3203
# Epoch 398/2048
# 1s - loss: 0.3274 - val_loss: 0.3202
# Epoch 399/2048
# 2s - loss: 0.3272 - val_loss: 0.3199
# Epoch 400/2048
# 1s - loss: 0.3270 - val_loss: 0.3199
# Epoch 401/2048
# 1s - loss: 0.3268 - val_loss: 0.3194
# Epoch 402/2048
# 1s - loss: 0.3265 - val_loss: 0.3193
# Epoch 403/2048
# 2s - loss: 0.3262 - val_loss: 0.3190
# Epoch 404/2048
# 1s - loss: 0.3260 - val_loss: 0.3186
# Epoch 405/2048
# 1s - loss: 0.3257 - val_loss: 0.3185
# Epoch 406/2048
# 1s - loss: 0.3255 - val_loss: 0.3180
# Epoch 407/2048
# 1s - loss: 0.3252 - val_loss: 0.3182
# Epoch 408/2048
# 1s - loss: 0.3250 - val_loss: 0.3174
# Epoch 409/2048
# 1s - loss: 0.3247 - val_loss: 0.3172
# Epoch 410/2048
# 1s - loss: 0.3245 - val_loss: 0.3173
# Epoch 411/2048
# 1s - loss: 0.3242 - val_loss: 0.3171
# Epoch 412/2048
# 1s - loss: 0.3240 - val_loss: 0.3164
# Epoch 413/2048
# 1s - loss: 0.3237 - val_loss: 0.3162
# Epoch 414/2048
# 1s - loss: 0.3235 - val_loss: 0.3161
# Epoch 415/2048
# 1s - loss: 0.3233 - val_loss: 0.3160
# Epoch 416/2048
# 1s - loss: 0.3230 - val_loss: 0.3158
# Epoch 417/2048
# 1s - loss: 0.3228 - val_loss: 0.3153
# Epoch 418/2048
# 1s - loss: 0.3226 - val_loss: 0.3150
# Epoch 419/2048
# 1s - loss: 0.3224 - val_loss: 0.3151
# Epoch 420/2048
# 1s - loss: 0.3222 - val_loss: 0.3147
# Epoch 421/2048
# 1s - loss: 0.3219 - val_loss: 0.3146
# Epoch 422/2048
# 2s - loss: 0.3217 - val_loss: 0.3141
# Epoch 423/2048
# 1s - loss: 0.3215 - val_loss: 0.3141
# Epoch 424/2048
# 1s - loss: 0.3212 - val_loss: 0.3141
# Epoch 425/2048
# 1s - loss: 0.3210 - val_loss: 0.3139
# Epoch 426/2048
# 1s - loss: 0.3209 - val_loss: 0.3137
# Epoch 427/2048
# 1s - loss: 0.3206 - val_loss: 0.3131
# Epoch 428/2048
# 1s - loss: 0.3204 - val_loss: 0.3130
# Epoch 429/2048
# 2s - loss: 0.3202 - val_loss: 0.3128
# Epoch 430/2048
# 2s - loss: 0.3200 - val_loss: 0.3125
# Epoch 431/2048
# 2s - loss: 0.3198 - val_loss: 0.3122
# Epoch 432/2048
# 1s - loss: 0.3196 - val_loss: 0.3123
# Epoch 433/2048
# 1s - loss: 0.3195 - val_loss: 0.3122
# Epoch 434/2048
# 1s - loss: 0.3193 - val_loss: 0.3117
# Epoch 435/2048
# 1s - loss: 0.3190 - val_loss: 0.3115
# Epoch 436/2048
# 1s - loss: 0.3189 - val_loss: 0.3115
# Epoch 437/2048
# 1s - loss: 0.3187 - val_loss: 0.3113
# Epoch 438/2048
# 1s - loss: 0.3185 - val_loss: 0.3113
# Epoch 439/2048
# 1s - loss: 0.3183 - val_loss: 0.3110
# Epoch 440/2048
# 1s - loss: 0.3181 - val_loss: 0.3106
# Epoch 441/2048
# 1s - loss: 0.3180 - val_loss: 0.3107
# Epoch 442/2048
# 1s - loss: 0.3178 - val_loss: 0.3100
# Epoch 443/2048
# 1s - loss: 0.3176 - val_loss: 0.3103
# Epoch 444/2048
# 1s - loss: 0.3174 - val_loss: 0.3102
# Epoch 445/2048
# 1s - loss: 0.3173 - val_loss: 0.3102
# Epoch 446/2048
# 1s - loss: 0.3171 - val_loss: 0.3096
# Epoch 447/2048
# 1s - loss: 0.3169 - val_loss: 0.3096
# Epoch 448/2048
# 1s - loss: 0.3168 - val_loss: 0.3092
# Epoch 449/2048
# 1s - loss: 0.3166 - val_loss: 0.3092
# Epoch 450/2048
# 1s - loss: 0.3164 - val_loss: 0.3092
# Epoch 451/2048
# 1s - loss: 0.3163 - val_loss: 0.3091
# Epoch 452/2048
# 1s - loss: 0.3161 - val_loss: 0.3085
# Epoch 453/2048
# 1s - loss: 0.3160 - val_loss: 0.3088
# Epoch 454/2048
# 1s - loss: 0.3158 - val_loss: 0.3086
# Epoch 455/2048
# 1s - loss: 0.3156 - val_loss: 0.3082
# Epoch 456/2048
# 1s - loss: 0.3155 - val_loss: 0.3082
# Epoch 457/2048
# 1s - loss: 0.3153 - val_loss: 0.3079
# Epoch 458/2048
# 1s - loss: 0.3152 - val_loss: 0.3077
# Epoch 459/2048
# 1s - loss: 0.3150 - val_loss: 0.3075
# Epoch 460/2048
# 1s - loss: 0.3148 - val_loss: 0.3076
# Epoch 461/2048
# 1s - loss: 0.3147 - val_loss: 0.3077
# Epoch 462/2048
# 1s - loss: 0.3146 - val_loss: 0.3074
# Epoch 463/2048
# 1s - loss: 0.3144 - val_loss: 0.3073
# Epoch 464/2048
# 2s - loss: 0.3143 - val_loss: 0.3070
# Epoch 465/2048
# 1s - loss: 0.3141 - val_loss: 0.3067
# Epoch 466/2048
# 1s - loss: 0.3140 - val_loss: 0.3067
# Epoch 467/2048
# 1s - loss: 0.3138 - val_loss: 0.3068
# Epoch 468/2048
# 1s - loss: 0.3137 - val_loss: 0.3064
# Epoch 469/2048
# 2s - loss: 0.3136 - val_loss: 0.3063
# Epoch 470/2048
# 1s - loss: 0.3134 - val_loss: 0.3062
# Epoch 471/2048
# 2s - loss: 0.3132 - val_loss: 0.3061
# Epoch 472/2048
# 1s - loss: 0.3131 - val_loss: 0.3061
# Epoch 473/2048
# 1s - loss: 0.3129 - val_loss: 0.3055
# Epoch 474/2048
# 1s - loss: 0.3128 - val_loss: 0.3060
# Epoch 475/2048
# 1s - loss: 0.3126 - val_loss: 0.3055
# Epoch 476/2048
# 1s - loss: 0.3125 - val_loss: 0.3053
# Epoch 477/2048
# 1s - loss: 0.3124 - val_loss: 0.3053
# Epoch 478/2048
# 2s - loss: 0.3122 - val_loss: 0.3047
# Epoch 479/2048
# 1s - loss: 0.3121 - val_loss: 0.3048
# Epoch 480/2048
# 1s - loss: 0.3120 - val_loss: 0.3050
# Epoch 481/2048
# 1s - loss: 0.3118 - val_loss: 0.3046
# Epoch 482/2048
# 1s - loss: 0.3117 - val_loss: 0.3038
# Epoch 483/2048
# 1s - loss: 0.3115 - val_loss: 0.3042
# Epoch 484/2048
# 1s - loss: 0.3114 - val_loss: 0.3042
# Epoch 485/2048
# 1s - loss: 0.3113 - val_loss: 0.3040
# Epoch 486/2048
# 1s - loss: 0.3112 - val_loss: 0.3037
# Epoch 487/2048
# 1s - loss: 0.3110 - val_loss: 0.3038
# Epoch 488/2048
# 1s - loss: 0.3109 - val_loss: 0.3040
# Epoch 489/2048
# 1s - loss: 0.3107 - val_loss: 0.3037
# Epoch 490/2048
# 1s - loss: 0.3106 - val_loss: 0.3033
# Epoch 491/2048
# 1s - loss: 0.3105 - val_loss: 0.3032
# Epoch 492/2048
# 1s - loss: 0.3103 - val_loss: 0.3033
# Epoch 493/2048
# 1s - loss: 0.3102 - val_loss: 0.3028
# Epoch 494/2048
# 1s - loss: 0.3100 - val_loss: 0.3028
# Epoch 495/2048
# 1s - loss: 0.3099 - val_loss: 0.3030
# Epoch 496/2048
# 1s - loss: 0.3098 - val_loss: 0.3026
# Epoch 497/2048
# 1s - loss: 0.3097 - val_loss: 0.3028
# Epoch 498/2048
# 1s - loss: 0.3096 - val_loss: 0.3021
# Epoch 499/2048
# 1s - loss: 0.3094 - val_loss: 0.3021
# Epoch 500/2048
# 1s - loss: 0.3093 - val_loss: 0.3020
# Epoch 501/2048
# 2s - loss: 0.3092 - val_loss: 0.3018
# Epoch 502/2048
# 1s - loss: 0.3091 - val_loss: 0.3021
# Epoch 503/2048
# 1s - loss: 0.3089 - val_loss: 0.3018
# Epoch 504/2048
# 1s - loss: 0.3088 - val_loss: 0.3015
# Epoch 505/2048
# 1s - loss: 0.3087 - val_loss: 0.3016
# Epoch 506/2048
# 1s - loss: 0.3085 - val_loss: 0.3011
# Epoch 507/2048
# 1s - loss: 0.3084 - val_loss: 0.3011
# Epoch 508/2048
# 1s - loss: 0.3082 - val_loss: 0.3011
# Epoch 509/2048
# 1s - loss: 0.3082 - val_loss: 0.3011
# Epoch 510/2048
# 1s - loss: 0.3080 - val_loss: 0.3008
# Epoch 511/2048
# 1s - loss: 0.3079 - val_loss: 0.3009
# Epoch 512/2048
# 1s - loss: 0.3078 - val_loss: 0.3005
# Epoch 513/2048
# 1s - loss: 0.3076 - val_loss: 0.3006
# Epoch 514/2048
# 1s - loss: 0.3075 - val_loss: 0.3004
# Epoch 515/2048
# 1s - loss: 0.3074 - val_loss: 0.3002
# Epoch 516/2048
# 1s - loss: 0.3072 - val_loss: 0.3006
# Epoch 517/2048
# 1s - loss: 0.3072 - val_loss: 0.2999
# Epoch 518/2048
# 1s - loss: 0.3071 - val_loss: 0.2999
# Epoch 519/2048
# 1s - loss: 0.3069 - val_loss: 0.2997
# Epoch 520/2048
# 1s - loss: 0.3068 - val_loss: 0.2997
# Epoch 521/2048
# 1s - loss: 0.3067 - val_loss: 0.2995
# Epoch 522/2048
# 1s - loss: 0.3066 - val_loss: 0.2996
# Epoch 523/2048
# 1s - loss: 0.3064 - val_loss: 0.2992
# Epoch 524/2048
# 1s - loss: 0.3063 - val_loss: 0.2990
# Epoch 525/2048
# 2s - loss: 0.3062 - val_loss: 0.2989
# Epoch 526/2048
# 1s - loss: 0.3061 - val_loss: 0.2987
# Epoch 527/2048
# 1s - loss: 0.3060 - val_loss: 0.2987
# Epoch 528/2048
# 1s - loss: 0.3058 - val_loss: 0.2990
# Epoch 529/2048
# 1s - loss: 0.3057 - val_loss: 0.2988
# Epoch 530/2048
# 1s - loss: 0.3056 - val_loss: 0.2984
# Epoch 531/2048
# 1s - loss: 0.3055 - val_loss: 0.2985
# Epoch 532/2048
# 1s - loss: 0.3054 - val_loss: 0.2980
# Epoch 533/2048
# 1s - loss: 0.3053 - val_loss: 0.2980
# Epoch 534/2048
# 1s - loss: 0.3052 - val_loss: 0.2979
# Epoch 535/2048
# 1s - loss: 0.3050 - val_loss: 0.2980
# Epoch 536/2048
# 1s - loss: 0.3050 - val_loss: 0.2977
# Epoch 537/2048
# 1s - loss: 0.3049 - val_loss: 0.2977
# Epoch 538/2048
# 1s - loss: 0.3047 - val_loss: 0.2972
# Epoch 539/2048
# 1s - loss: 0.3046 - val_loss: 0.2974
# Epoch 540/2048
# 1s - loss: 0.3045 - val_loss: 0.2975
# Epoch 541/2048
# 1s - loss: 0.3044 - val_loss: 0.2973
# Epoch 542/2048
# 1s - loss: 0.3043 - val_loss: 0.2969
# Epoch 543/2048
# 1s - loss: 0.3042 - val_loss: 0.2967
# Epoch 544/2048
# 1s - loss: 0.3041 - val_loss: 0.2969
# Epoch 545/2048
# 1s - loss: 0.3039 - val_loss: 0.2968
# Epoch 546/2048
# 1s - loss: 0.3039 - val_loss: 0.2966
# Epoch 547/2048
# 1s - loss: 0.3038 - val_loss: 0.2965
# Epoch 548/2048
# 1s - loss: 0.3037 - val_loss: 0.2964
# Epoch 549/2048
# 1s - loss: 0.3036 - val_loss: 0.2963
# Epoch 550/2048
# 1s - loss: 0.3035 - val_loss: 0.2961
# Epoch 551/2048
# 1s - loss: 0.3033 - val_loss: 0.2959
# Epoch 552/2048
# 1s - loss: 0.3032 - val_loss: 0.2957
# Epoch 553/2048
# 1s - loss: 0.3031 - val_loss: 0.2958
# Epoch 554/2048
# 1s - loss: 0.3030 - val_loss: 0.2955
# Epoch 555/2048
# 1s - loss: 0.3029 - val_loss: 0.2957
# Epoch 556/2048
# 1s - loss: 0.3028 - val_loss: 0.2953
# Epoch 557/2048
# 1s - loss: 0.3027 - val_loss: 0.2955
# Epoch 558/2048
# 1s - loss: 0.3026 - val_loss: 0.2950
# Epoch 559/2048
# 1s - loss: 0.3025 - val_loss: 0.2952
# Epoch 560/2048
# 1s - loss: 0.3024 - val_loss: 0.2951
# Epoch 561/2048
# 1s - loss: 0.3023 - val_loss: 0.2950
# Epoch 562/2048
# 1s - loss: 0.3022 - val_loss: 0.2945
# Epoch 563/2048
# 1s - loss: 0.3021 - val_loss: 0.2948
# Epoch 564/2048
# 1s - loss: 0.3020 - val_loss: 0.2943
# Epoch 565/2048
# 1s - loss: 0.3019 - val_loss: 0.2945
# Epoch 566/2048
# 1s - loss: 0.3018 - val_loss: 0.2945
# Epoch 567/2048
# 1s - loss: 0.3018 - val_loss: 0.2945
# Epoch 568/2048
# 1s - loss: 0.3016 - val_loss: 0.2944
# Epoch 569/2048
# 1s - loss: 0.3015 - val_loss: 0.2941
# Epoch 570/2048
# 1s - loss: 0.3014 - val_loss: 0.2943
# Epoch 571/2048
# 1s - loss: 0.3013 - val_loss: 0.2939
# Epoch 572/2048
# 1s - loss: 0.3012 - val_loss: 0.2940
# Epoch 573/2048
# 1s - loss: 0.3011 - val_loss: 0.2938
# Epoch 574/2048
# 1s - loss: 0.3010 - val_loss: 0.2938
# Epoch 575/2048
# 1s - loss: 0.3010 - val_loss: 0.2934
# Epoch 576/2048
# 1s - loss: 0.3009 - val_loss: 0.2935
# Epoch 577/2048
# 1s - loss: 0.3008 - val_loss: 0.2933
# Epoch 578/2048
# 2s - loss: 0.3006 - val_loss: 0.2932
# Epoch 579/2048
# 1s - loss: 0.3006 - val_loss: 0.2932
# Epoch 580/2048
# 1s - loss: 0.3004 - val_loss: 0.2930
# Epoch 581/2048
# 1s - loss: 0.3004 - val_loss: 0.2930
# Epoch 582/2048
# 1s - loss: 0.3003 - val_loss: 0.2928
# Epoch 583/2048
# 1s - loss: 0.3002 - val_loss: 0.2931
# Epoch 584/2048
# 1s - loss: 0.3001 - val_loss: 0.2925
# Epoch 585/2048
# 1s - loss: 0.3000 - val_loss: 0.2926
# Epoch 586/2048
# 1s - loss: 0.2999 - val_loss: 0.2925
# Epoch 587/2048
# 1s - loss: 0.2998 - val_loss: 0.2920
# Epoch 588/2048
# 1s - loss: 0.2997 - val_loss: 0.2923
# Epoch 589/2048
# 1s - loss: 0.2996 - val_loss: 0.2921
# Epoch 590/2048
# 1s - loss: 0.2995 - val_loss: 0.2923
# Epoch 591/2048
# 1s - loss: 0.2994 - val_loss: 0.2920
# Epoch 592/2048
# 1s - loss: 0.2993 - val_loss: 0.2921
# Epoch 593/2048
# 1s - loss: 0.2992 - val_loss: 0.2920
# Epoch 594/2048
# 1s - loss: 0.2991 - val_loss: 0.2918
# Epoch 595/2048
# 1s - loss: 0.2990 - val_loss: 0.2913
# Epoch 596/2048
# 1s - loss: 0.2989 - val_loss: 0.2916
# Epoch 597/2048
# 1s - loss: 0.2988 - val_loss: 0.2914
# Epoch 598/2048
# 1s - loss: 0.2987 - val_loss: 0.2915
# Epoch 599/2048
# 1s - loss: 0.2986 - val_loss: 0.2914
# Epoch 600/2048
# 1s - loss: 0.2985 - val_loss: 0.2912
# Epoch 601/2048
# 1s - loss: 0.2985 - val_loss: 0.2909
# Epoch 602/2048
# 1s - loss: 0.2983 - val_loss: 0.2912
# Epoch 603/2048
# 1s - loss: 0.2982 - val_loss: 0.2908
# Epoch 604/2048
# 1s - loss: 0.2981 - val_loss: 0.2906
# Epoch 605/2048
# 1s - loss: 0.2980 - val_loss: 0.2908
# Epoch 606/2048
# 1s - loss: 0.2979 - val_loss: 0.2905
# Epoch 607/2048
# 1s - loss: 0.2978 - val_loss: 0.2905
# Epoch 608/2048
# 1s - loss: 0.2977 - val_loss: 0.2904
# Epoch 609/2048
# 1s - loss: 0.2976 - val_loss: 0.2903
# Epoch 610/2048
# 1s - loss: 0.2976 - val_loss: 0.2901
# Epoch 611/2048
# 1s - loss: 0.2974 - val_loss: 0.2902
# Epoch 612/2048
# 1s - loss: 0.2974 - val_loss: 0.2901
# Epoch 613/2048
# 1s - loss: 0.2972 - val_loss: 0.2896
# Epoch 614/2048
# 1s - loss: 0.2971 - val_loss: 0.2900
# Epoch 615/2048
# 1s - loss: 0.2970 - val_loss: 0.2895
# Epoch 616/2048
# 1s - loss: 0.2969 - val_loss: 0.2893
# Epoch 617/2048
# 1s - loss: 0.2969 - val_loss: 0.2895
# Epoch 618/2048
# 1s - loss: 0.2967 - val_loss: 0.2895
# Epoch 619/2048
# 1s - loss: 0.2966 - val_loss: 0.2890
# Epoch 620/2048
# 1s - loss: 0.2965 - val_loss: 0.2892
# Epoch 621/2048
# 1s - loss: 0.2964 - val_loss: 0.2891
# Epoch 622/2048
# 1s - loss: 0.2963 - val_loss: 0.2889
# Epoch 623/2048
# 1s - loss: 0.2962 - val_loss: 0.2888
# Epoch 624/2048
# 1s - loss: 0.2961 - val_loss: 0.2889
# Epoch 625/2048
# 1s - loss: 0.2961 - val_loss: 0.2889
# Epoch 626/2048
# 1s - loss: 0.2960 - val_loss: 0.2885
# Epoch 627/2048
# 1s - loss: 0.2959 - val_loss: 0.2883
# Epoch 628/2048
# 2s - loss: 0.2957 - val_loss: 0.2882
# Epoch 629/2048
# 2s - loss: 0.2956 - val_loss: 0.2879
# Epoch 630/2048
# 1s - loss: 0.2955 - val_loss: 0.2883
# Epoch 631/2048
# 1s - loss: 0.2954 - val_loss: 0.2883
# Epoch 632/2048
# 1s - loss: 0.2953 - val_loss: 0.2880
# Epoch 633/2048
# 1s - loss: 0.2952 - val_loss: 0.2880
# Epoch 634/2048
# 1s - loss: 0.2952 - val_loss: 0.2878
# Epoch 635/2048
# 2s - loss: 0.2950 - val_loss: 0.2877
# Epoch 636/2048
# 1s - loss: 0.2949 - val_loss: 0.2873
# Epoch 637/2048
# 1s - loss: 0.2948 - val_loss: 0.2874
# Epoch 638/2048
# 1s - loss: 0.2947 - val_loss: 0.2875
# Epoch 639/2048
# 1s - loss: 0.2946 - val_loss: 0.2873
# Epoch 640/2048
# 1s - loss: 0.2945 - val_loss: 0.2868
# Epoch 641/2048
# 1s - loss: 0.2944 - val_loss: 0.2872
# Epoch 642/2048
# 1s - loss: 0.2943 - val_loss: 0.2867
# Epoch 643/2048
# 1s - loss: 0.2942 - val_loss: 0.2867
# Epoch 644/2048
# 1s - loss: 0.2941 - val_loss: 0.2867
# Epoch 645/2048
# 1s - loss: 0.2940 - val_loss: 0.2867
# Epoch 646/2048
# 1s - loss: 0.2939 - val_loss: 0.2865
# Epoch 647/2048
# 1s - loss: 0.2938 - val_loss: 0.2869
# Epoch 648/2048
# 1s - loss: 0.2937 - val_loss: 0.2864
# Epoch 649/2048
# 1s - loss: 0.2936 - val_loss: 0.2862
# Epoch 650/2048
# 1s - loss: 0.2935 - val_loss: 0.2861
# Epoch 651/2048
# 1s - loss: 0.2934 - val_loss: 0.2857
# Epoch 652/2048
# 1s - loss: 0.2933 - val_loss: 0.2860
# Epoch 653/2048
# 1s - loss: 0.2932 - val_loss: 0.2860
# Epoch 654/2048
# 1s - loss: 0.2931 - val_loss: 0.2857
# Epoch 655/2048
# 1s - loss: 0.2930 - val_loss: 0.2856
# Epoch 656/2048
# 1s - loss: 0.2929 - val_loss: 0.2856
# Epoch 657/2048
# 1s - loss: 0.2928 - val_loss: 0.2852
# Epoch 658/2048
# 1s - loss: 0.2927 - val_loss: 0.2852
# Epoch 659/2048
# 1s - loss: 0.2926 - val_loss: 0.2854
# Epoch 660/2048
# 1s - loss: 0.2925 - val_loss: 0.2851
# Epoch 661/2048
# 1s - loss: 0.2924 - val_loss: 0.2854
# Epoch 662/2048
# 1s - loss: 0.2923 - val_loss: 0.2850
# Epoch 663/2048
# 2s - loss: 0.2922 - val_loss: 0.2848
# Epoch 664/2048
# 1s - loss: 0.2921 - val_loss: 0.2847
# Epoch 665/2048
# 1s - loss: 0.2920 - val_loss: 0.2847
# Epoch 666/2048
# 1s - loss: 0.2919 - val_loss: 0.2845
# Epoch 667/2048
# 1s - loss: 0.2918 - val_loss: 0.2847
# Epoch 668/2048
# 1s - loss: 0.2917 - val_loss: 0.2843
# Epoch 669/2048
# 2s - loss: 0.2916 - val_loss: 0.2841
# Epoch 670/2048
# 1s - loss: 0.2914 - val_loss: 0.2844
# Epoch 671/2048
# 1s - loss: 0.2914 - val_loss: 0.2837
# Epoch 672/2048
# 1s - loss: 0.2913 - val_loss: 0.2840
# Epoch 673/2048
# 1s - loss: 0.2912 - val_loss: 0.2840
# Epoch 674/2048
# 1s - loss: 0.2911 - val_loss: 0.2837
# Epoch 675/2048
# 1s - loss: 0.2909 - val_loss: 0.2836
# Epoch 676/2048
# 1s - loss: 0.2908 - val_loss: 0.2837
# Epoch 677/2048
# 1s - loss: 0.2908 - val_loss: 0.2833
# Epoch 678/2048
# 1s - loss: 0.2907 - val_loss: 0.2833
# Epoch 679/2048
# 1s - loss: 0.2905 - val_loss: 0.2830
# Epoch 680/2048
# 1s - loss: 0.2905 - val_loss: 0.2832
# Epoch 681/2048
# 1s - loss: 0.2903 - val_loss: 0.2829
# Epoch 682/2048
# 1s - loss: 0.2902 - val_loss: 0.2829
# Epoch 683/2048
# 1s - loss: 0.2901 - val_loss: 0.2830
# Epoch 684/2048
# 1s - loss: 0.2901 - val_loss: 0.2829
# Epoch 685/2048
# 1s - loss: 0.2899 - val_loss: 0.2824
# Epoch 686/2048
# 1s - loss: 0.2898 - val_loss: 0.2824
# Epoch 687/2048
# 1s - loss: 0.2897 - val_loss: 0.2827
# Epoch 688/2048
# 1s - loss: 0.2896 - val_loss: 0.2824
# Epoch 689/2048
# 2s - loss: 0.2895 - val_loss: 0.2821
# Epoch 690/2048
# 1s - loss: 0.2894 - val_loss: 0.2820
# Epoch 691/2048
# 2s - loss: 0.2893 - val_loss: 0.2819
# Epoch 692/2048
# 1s - loss: 0.2892 - val_loss: 0.2818
# Epoch 693/2048
# 1s - loss: 0.2891 - val_loss: 0.2816
# Epoch 694/2048
# 1s - loss: 0.2890 - val_loss: 0.2816
# Epoch 695/2048
# 1s - loss: 0.2888 - val_loss: 0.2814
# Epoch 696/2048
# 1s - loss: 0.2888 - val_loss: 0.2815
# Epoch 697/2048
# 1s - loss: 0.2886 - val_loss: 0.2812
# Epoch 698/2048
# 1s - loss: 0.2885 - val_loss: 0.2813
# Epoch 699/2048
# 1s - loss: 0.2884 - val_loss: 0.2814
# Epoch 700/2048
# 1s - loss: 0.2883 - val_loss: 0.2809
# Epoch 701/2048
# 1s - loss: 0.2882 - val_loss: 0.2810
# Epoch 702/2048
# 1s - loss: 0.2881 - val_loss: 0.2807
# Epoch 703/2048
# 1s - loss: 0.2880 - val_loss: 0.2809
# Epoch 704/2048
# 1s - loss: 0.2879 - val_loss: 0.2805
# Epoch 705/2048
# 1s - loss: 0.2877 - val_loss: 0.2808
# Epoch 706/2048
# 1s - loss: 0.2877 - val_loss: 0.2805
# Epoch 707/2048
# 1s - loss: 0.2875 - val_loss: 0.2806
# Epoch 708/2048
# 1s - loss: 0.2874 - val_loss: 0.2800
# Epoch 709/2048
# 2s - loss: 0.2873 - val_loss: 0.2798
# Epoch 710/2048
# 1s - loss: 0.2872 - val_loss: 0.2798
# Epoch 711/2048
# 1s - loss: 0.2871 - val_loss: 0.2798
# Epoch 712/2048
# 1s - loss: 0.2870 - val_loss: 0.2798
# Epoch 713/2048
# 1s - loss: 0.2869 - val_loss: 0.2796
# Epoch 714/2048
# 1s - loss: 0.2868 - val_loss: 0.2794
# Epoch 715/2048
# 1s - loss: 0.2866 - val_loss: 0.2795
# Epoch 716/2048
# 1s - loss: 0.2865 - val_loss: 0.2795
# Epoch 717/2048
# 1s - loss: 0.2864 - val_loss: 0.2788
# Epoch 718/2048
# 1s - loss: 0.2863 - val_loss: 0.2791
# Epoch 719/2048
# 1s - loss: 0.2862 - val_loss: 0.2791
# Epoch 720/2048
# 1s - loss: 0.2861 - val_loss: 0.2792
# Epoch 721/2048
# 1s - loss: 0.2860 - val_loss: 0.2786
# Epoch 722/2048
# 1s - loss: 0.2859 - val_loss: 0.2788
# Epoch 723/2048
# 1s - loss: 0.2858 - val_loss: 0.2787
# Epoch 724/2048
# 1s - loss: 0.2856 - val_loss: 0.2785
# Epoch 725/2048
# 1s - loss: 0.2855 - val_loss: 0.2786
# Epoch 726/2048
# 1s - loss: 0.2854 - val_loss: 0.2781
# Epoch 727/2048
# 2s - loss: 0.2853 - val_loss: 0.2780
# Epoch 728/2048
# 1s - loss: 0.2852 - val_loss: 0.2780
# Epoch 729/2048
# 1s - loss: 0.2851 - val_loss: 0.2778
# Epoch 730/2048
# 1s - loss: 0.2850 - val_loss: 0.2778
# Epoch 731/2048
# 1s - loss: 0.2849 - val_loss: 0.2777
# Epoch 732/2048
# 1s - loss: 0.2848 - val_loss: 0.2775
# Epoch 733/2048
# 1s - loss: 0.2846 - val_loss: 0.2774
# Epoch 734/2048
# 1s - loss: 0.2845 - val_loss: 0.2775
# Epoch 735/2048
# 1s - loss: 0.2844 - val_loss: 0.2773
# Epoch 736/2048
# 1s - loss: 0.2843 - val_loss: 0.2769
# Epoch 737/2048
# 1s - loss: 0.2842 - val_loss: 0.2770
# Epoch 738/2048
# 1s - loss: 0.2841 - val_loss: 0.2771
# Epoch 739/2048
# 1s - loss: 0.2840 - val_loss: 0.2769
# Epoch 740/2048
# 1s - loss: 0.2839 - val_loss: 0.2766
# Epoch 741/2048
# 1s - loss: 0.2838 - val_loss: 0.2762
# Epoch 742/2048
# 1s - loss: 0.2837 - val_loss: 0.2765
# Epoch 743/2048
# 1s - loss: 0.2836 - val_loss: 0.2762
# Epoch 744/2048
# 1s - loss: 0.2834 - val_loss: 0.2762
# Epoch 745/2048
# 1s - loss: 0.2834 - val_loss: 0.2761
# Epoch 746/2048
# 1s - loss: 0.2833 - val_loss: 0.2764
# Epoch 747/2048
# 1s - loss: 0.2831 - val_loss: 0.2759
# Epoch 748/2048
# 2s - loss: 0.2830 - val_loss: 0.2757
# Epoch 749/2048
# 1s - loss: 0.2829 - val_loss: 0.2756
# Epoch 750/2048
# 1s - loss: 0.2828 - val_loss: 0.2756
# Epoch 751/2048
# 1s - loss: 0.2827 - val_loss: 0.2753
# Epoch 752/2048
# 1s - loss: 0.2826 - val_loss: 0.2752
# Epoch 753/2048
# 1s - loss: 0.2825 - val_loss: 0.2752
# Epoch 754/2048
# 1s - loss: 0.2824 - val_loss: 0.2750
# Epoch 755/2048
# 1s - loss: 0.2822 - val_loss: 0.2750
# Epoch 756/2048
# 1s - loss: 0.2821 - val_loss: 0.2748
# Epoch 757/2048
# 1s - loss: 0.2820 - val_loss: 0.2747
# Epoch 758/2048
# 1s - loss: 0.2820 - val_loss: 0.2750
# Epoch 759/2048
# 1s - loss: 0.2818 - val_loss: 0.2745
# Epoch 760/2048
# 1s - loss: 0.2817 - val_loss: 0.2743
# Epoch 761/2048
# 1s - loss: 0.2816 - val_loss: 0.2746
# Epoch 762/2048
# 1s - loss: 0.2815 - val_loss: 0.2742
# Epoch 763/2048
# 1s - loss: 0.2814 - val_loss: 0.2740
# Epoch 764/2048
# 1s - loss: 0.2813 - val_loss: 0.2743
# Epoch 765/2048
# 1s - loss: 0.2812 - val_loss: 0.2742
# Epoch 766/2048
# 1s - loss: 0.2811 - val_loss: 0.2740
# Epoch 767/2048
# 2s - loss: 0.2810 - val_loss: 0.2738
# Epoch 768/2048
# 2s - loss: 0.2809 - val_loss: 0.2737
# Epoch 769/2048
# 1s - loss: 0.2808 - val_loss: 0.2736
# Epoch 770/2048
# 1s - loss: 0.2807 - val_loss: 0.2735
# Epoch 771/2048
# 2s - loss: 0.2806 - val_loss: 0.2733
# Epoch 772/2048
# 1s - loss: 0.2805 - val_loss: 0.2735
# Epoch 773/2048
# 1s - loss: 0.2804 - val_loss: 0.2731
# Epoch 774/2048
# 1s - loss: 0.2803 - val_loss: 0.2731
# Epoch 775/2048
# 1s - loss: 0.2802 - val_loss: 0.2731
# Epoch 776/2048
# 1s - loss: 0.2801 - val_loss: 0.2730
# Epoch 777/2048
# 1s - loss: 0.2800 - val_loss: 0.2728
# Epoch 778/2048
# 1s - loss: 0.2799 - val_loss: 0.2728
# Epoch 779/2048
# 1s - loss: 0.2798 - val_loss: 0.2725
# Epoch 780/2048
# 1s - loss: 0.2798 - val_loss: 0.2727
# Epoch 781/2048
# 1s - loss: 0.2796 - val_loss: 0.2727
# Epoch 782/2048
# 1s - loss: 0.2796 - val_loss: 0.2723
# Epoch 783/2048
# 1s - loss: 0.2795 - val_loss: 0.2723
# Epoch 784/2048
# 1s - loss: 0.2794 - val_loss: 0.2722
# Epoch 785/2048
# 1s - loss: 0.2793 - val_loss: 0.2722
# Epoch 786/2048
# 1s - loss: 0.2792 - val_loss: 0.2720
# Epoch 787/2048
# 1s - loss: 0.2791 - val_loss: 0.2721
# Epoch 788/2048
# 1s - loss: 0.2790 - val_loss: 0.2718
# Epoch 789/2048
# 1s - loss: 0.2789 - val_loss: 0.2717
# Epoch 790/2048
# 1s - loss: 0.2789 - val_loss: 0.2717
# Epoch 791/2048
# 1s - loss: 0.2787 - val_loss: 0.2719
# Epoch 792/2048
# 1s - loss: 0.2787 - val_loss: 0.2715
# Epoch 793/2048
# 1s - loss: 0.2786 - val_loss: 0.2717
# Epoch 794/2048
# 1s - loss: 0.2785 - val_loss: 0.2715
# Epoch 795/2048
# 1s - loss: 0.2784 - val_loss: 0.2715
# Epoch 796/2048
# 1s - loss: 0.2783 - val_loss: 0.2712
# Epoch 797/2048
# 1s - loss: 0.2782 - val_loss: 0.2712
# Epoch 798/2048
# 1s - loss: 0.2782 - val_loss: 0.2713
# Epoch 799/2048
# 1s - loss: 0.2781 - val_loss: 0.2708
# Epoch 800/2048
# 1s - loss: 0.2780 - val_loss: 0.2710
# Epoch 801/2048
# 1s - loss: 0.2779 - val_loss: 0.2710
# Epoch 802/2048
# 1s - loss: 0.2779 - val_loss: 0.2711
# Epoch 803/2048
# 1s - loss: 0.2778 - val_loss: 0.2706
# Epoch 804/2048
# 1s - loss: 0.2776 - val_loss: 0.2706
# Epoch 805/2048
# 1s - loss: 0.2776 - val_loss: 0.2708
# Epoch 806/2048
# 1s - loss: 0.2775 - val_loss: 0.2703
# Epoch 807/2048
# 1s - loss: 0.2774 - val_loss: 0.2704
# Epoch 808/2048
# 1s - loss: 0.2773 - val_loss: 0.2706
# Epoch 809/2048
# 1s - loss: 0.2772 - val_loss: 0.2700
# Epoch 810/2048
# 1s - loss: 0.2772 - val_loss: 0.2701
# Epoch 811/2048
# 1s - loss: 0.2771 - val_loss: 0.2698
# Epoch 812/2048
# 1s - loss: 0.2770 - val_loss: 0.2696
# Epoch 813/2048
# 1s - loss: 0.2769 - val_loss: 0.2698
# Epoch 814/2048
# 1s - loss: 0.2768 - val_loss: 0.2697
# Epoch 815/2048
# 1s - loss: 0.2768 - val_loss: 0.2698
# Epoch 816/2048
# 1s - loss: 0.2767 - val_loss: 0.2697
# Epoch 817/2048
# 1s - loss: 0.2766 - val_loss: 0.2695
# Epoch 818/2048
# 1s - loss: 0.2765 - val_loss: 0.2692
# Epoch 819/2048
# 1s - loss: 0.2765 - val_loss: 0.2694
# Epoch 820/2048
# 1s - loss: 0.2764 - val_loss: 0.2694
# Epoch 821/2048
# 1s - loss: 0.2763 - val_loss: 0.2692
# Epoch 822/2048
# 1s - loss: 0.2762 - val_loss: 0.2691
# Epoch 823/2048
# 1s - loss: 0.2761 - val_loss: 0.2691
# Epoch 824/2048
# 1s - loss: 0.2761 - val_loss: 0.2689
# Epoch 825/2048
# 1s - loss: 0.2760 - val_loss: 0.2690
# Epoch 826/2048
# 1s - loss: 0.2759 - val_loss: 0.2687
# Epoch 827/2048
# 1s - loss: 0.2758 - val_loss: 0.2690
# Epoch 828/2048
# 1s - loss: 0.2757 - val_loss: 0.2688
# Epoch 829/2048
# 1s - loss: 0.2757 - val_loss: 0.2687
# Epoch 830/2048
# 1s - loss: 0.2756 - val_loss: 0.2689
# Epoch 831/2048
# 1s - loss: 0.2756 - val_loss: 0.2688
# Epoch 832/2048
# 1s - loss: 0.2755 - val_loss: 0.2685
# Epoch 833/2048
# 1s - loss: 0.2754 - val_loss: 0.2682
# Epoch 834/2048
# 1s - loss: 0.2753 - val_loss: 0.2685
# Epoch 835/2048
# 1s - loss: 0.2752 - val_loss: 0.2680
# Epoch 836/2048
# 1s - loss: 0.2751 - val_loss: 0.2681
# Epoch 837/2048
# 1s - loss: 0.2751 - val_loss: 0.2680
# Epoch 838/2048
# 1s - loss: 0.2750 - val_loss: 0.2681
# Epoch 839/2048
# 1s - loss: 0.2749 - val_loss: 0.2681
# Epoch 840/2048
# 1s - loss: 0.2748 - val_loss: 0.2680
# Epoch 841/2048
# 1s - loss: 0.2748 - val_loss: 0.2680
# Epoch 842/2048
# 1s - loss: 0.2747 - val_loss: 0.2674
# Epoch 843/2048
# 1s - loss: 0.2746 - val_loss: 0.2675
# Epoch 844/2048
# 1s - loss: 0.2745 - val_loss: 0.2677
# Epoch 845/2048
# 1s - loss: 0.2744 - val_loss: 0.2674
# Epoch 846/2048
# 1s - loss: 0.2744 - val_loss: 0.2676
# Epoch 847/2048
# 1s - loss: 0.2744 - val_loss: 0.2672
# Epoch 848/2048
# 1s - loss: 0.2742 - val_loss: 0.2671
# Epoch 849/2048
# 1s - loss: 0.2742 - val_loss: 0.2674
# Epoch 850/2048
# 1s - loss: 0.2741 - val_loss: 0.2672
# Epoch 851/2048
# 1s - loss: 0.2741 - val_loss: 0.2674
# Epoch 852/2048
# 1s - loss: 0.2740 - val_loss: 0.2673
# Epoch 853/2048
# 1s - loss: 0.2739 - val_loss: 0.2673
# Epoch 854/2048
# 1s - loss: 0.2738 - val_loss: 0.2667
# Epoch 855/2048
# 1s - loss: 0.2737 - val_loss: 0.2669
# Epoch 856/2048
# 1s - loss: 0.2736 - val_loss: 0.2667
# Epoch 857/2048
# 1s - loss: 0.2736 - val_loss: 0.2668
# Epoch 858/2048
# 1s - loss: 0.2735 - val_loss: 0.2665
# Epoch 859/2048
# 1s - loss: 0.2734 - val_loss: 0.2664
# Epoch 860/2048
# 1s - loss: 0.2733 - val_loss: 0.2664
# Epoch 861/2048
# 1s - loss: 0.2732 - val_loss: 0.2664
# Epoch 862/2048
# 1s - loss: 0.2733 - val_loss: 0.2663
# Epoch 863/2048
# 1s - loss: 0.2731 - val_loss: 0.2661
# Epoch 864/2048
# 1s - loss: 0.2730 - val_loss: 0.2661
# Epoch 865/2048
# 1s - loss: 0.2729 - val_loss: 0.2661
# Epoch 866/2048
# 1s - loss: 0.2729 - val_loss: 0.2661
# Epoch 867/2048
# 1s - loss: 0.2728 - val_loss: 0.2659
# Epoch 868/2048
# 1s - loss: 0.2727 - val_loss: 0.2657
# Epoch 869/2048
# 1s - loss: 0.2726 - val_loss: 0.2658
# Epoch 870/2048
# 1s - loss: 0.2725 - val_loss: 0.2655
# Epoch 871/2048
# 1s - loss: 0.2724 - val_loss: 0.2658
# Epoch 872/2048
# 1s - loss: 0.2724 - val_loss: 0.2657
# Epoch 873/2048
# 1s - loss: 0.2723 - val_loss: 0.2654
# Epoch 874/2048
# 1s - loss: 0.2723 - val_loss: 0.2656
# Epoch 875/2048
# 1s - loss: 0.2722 - val_loss: 0.2655
# Epoch 876/2048
# 1s - loss: 0.2721 - val_loss: 0.2655
# Epoch 877/2048
# 1s - loss: 0.2720 - val_loss: 0.2651
# Epoch 878/2048
# 1s - loss: 0.2719 - val_loss: 0.2649
# Epoch 879/2048
# 1s - loss: 0.2719 - val_loss: 0.2651
# Epoch 880/2048
# 1s - loss: 0.2718 - val_loss: 0.2649
# Epoch 881/2048
# 1s - loss: 0.2717 - val_loss: 0.2648
# Epoch 882/2048
# 1s - loss: 0.2716 - val_loss: 0.2645
# Epoch 883/2048
# 1s - loss: 0.2715 - val_loss: 0.2650
# Epoch 884/2048
# 1s - loss: 0.2715 - val_loss: 0.2647
# Epoch 885/2048
# 1s - loss: 0.2714 - val_loss: 0.2644
# Epoch 886/2048
# 1s - loss: 0.2713 - val_loss: 0.2646
# Epoch 887/2048
# 1s - loss: 0.2712 - val_loss: 0.2643
# Epoch 888/2048
# 1s - loss: 0.2712 - val_loss: 0.2642
# Epoch 889/2048
# 1s - loss: 0.2711 - val_loss: 0.2643
# Epoch 890/2048
# 1s - loss: 0.2710 - val_loss: 0.2642
# Epoch 891/2048
# 1s - loss: 0.2709 - val_loss: 0.2641
# Epoch 892/2048
# 1s - loss: 0.2708 - val_loss: 0.2639
# Epoch 893/2048
# 1s - loss: 0.2708 - val_loss: 0.2641
# Epoch 894/2048
# 1s - loss: 0.2707 - val_loss: 0.2636
# Epoch 895/2048
# 1s - loss: 0.2706 - val_loss: 0.2639
# Epoch 896/2048
# 1s - loss: 0.2705 - val_loss: 0.2636
# Epoch 897/2048
# 1s - loss: 0.2704 - val_loss: 0.2636
# Epoch 898/2048
# 1s - loss: 0.2703 - val_loss: 0.2634
# Epoch 899/2048
# 1s - loss: 0.2703 - val_loss: 0.2632
# Epoch 900/2048
# 1s - loss: 0.2702 - val_loss: 0.2634
# Epoch 901/2048
# 1s - loss: 0.2701 - val_loss: 0.2634
# Epoch 902/2048
# 1s - loss: 0.2700 - val_loss: 0.2630
# Epoch 903/2048
# 1s - loss: 0.2699 - val_loss: 0.2633
# Epoch 904/2048
# 1s - loss: 0.2699 - val_loss: 0.2632
# Epoch 905/2048
# 1s - loss: 0.2698 - val_loss: 0.2628
# Epoch 906/2048
# 1s - loss: 0.2697 - val_loss: 0.2632
# Epoch 907/2048
# 1s - loss: 0.2696 - val_loss: 0.2630
# Epoch 908/2048
# 1s - loss: 0.2695 - val_loss: 0.2626
# Epoch 909/2048
# 1s - loss: 0.2694 - val_loss: 0.2624
# Epoch 910/2048
# 1s - loss: 0.2694 - val_loss: 0.2625
# Epoch 911/2048
# 1s - loss: 0.2693 - val_loss: 0.2624
# Epoch 912/2048
# 1s - loss: 0.2692 - val_loss: 0.2624
# Epoch 913/2048
# 2s - loss: 0.2691 - val_loss: 0.2624
# Epoch 914/2048
# 2s - loss: 0.2690 - val_loss: 0.2621
# Epoch 915/2048
# 2s - loss: 0.2689 - val_loss: 0.2621
# Epoch 916/2048
# 2s - loss: 0.2689 - val_loss: 0.2619
# Epoch 917/2048
# 1s - loss: 0.2688 - val_loss: 0.2621
# Epoch 918/2048
# 1s - loss: 0.2687 - val_loss: 0.2620
# Epoch 919/2048
# 1s - loss: 0.2686 - val_loss: 0.2618
# Epoch 920/2048
# 1s - loss: 0.2685 - val_loss: 0.2617
# Epoch 921/2048
# 1s - loss: 0.2684 - val_loss: 0.2618
# Epoch 922/2048
# 2s - loss: 0.2683 - val_loss: 0.2616
# Epoch 923/2048
# 1s - loss: 0.2683 - val_loss: 0.2614
# Epoch 924/2048
# ...
# 1s - loss: 0.2365 - val_loss: 0.2307
# Epoch 1748/2048
# 1s - loss: 0.2365 - val_loss: 0.2308
# Epoch 1749/2048
# 1s - loss: 0.2365 - val_loss: 0.2306
# Epoch 1750/2048
# 1s - loss: 0.2365 - val_loss: 0.2309
# Epoch 1751/2048
# 1s - loss: 0.2365 - val_loss: 0.2306
# Epoch 1752/2048
# 1s - loss: 0.2365 - val_loss: 0.2311
# Epoch 1753/2048
# 1s - loss: 0.2364 - val_loss: 0.2309
# Epoch 1754/2048
# 1s - loss: 0.2364 - val_loss: 0.2309
# Epoch 1755/2048
# 1s - loss: 0.2364 - val_loss: 0.2307
# Epoch 1756/2048
# 1s - loss: 0.2364 - val_loss: 0.2307
# Epoch 1757/2048
# 1s - loss: 0.2363 - val_loss: 0.2308
# Epoch 1758/2048
# 1s - loss: 0.2363 - val_loss: 0.2308
# Epoch 1759/2048
# 1s - loss: 0.2363 - val_loss: 0.2306
# Epoch 1760/2048
# 1s - loss: 0.2363 - val_loss: 0.2307
# Epoch 1761/2048
# 1s - loss: 0.2363 - val_loss: 0.2305
# Epoch 1762/2048
# 1s - loss: 0.2363 - val_loss: 0.2304
# Epoch 1763/2048
# 1s - loss: 0.2362 - val_loss: 0.2304
# Epoch 1764/2048
# 1s - loss: 0.2362 - val_loss: 0.2305
# Epoch 1765/2048
# 1s - loss: 0.2362 - val_loss: 0.2302
# Epoch 1766/2048
# 1s - loss: 0.2362 - val_loss: 0.2307
# Epoch 1767/2048
# 1s - loss: 0.2362 - val_loss: 0.2307
# Epoch 1768/2048
# 1s - loss: 0.2362 - val_loss: 0.2303
# Epoch 1769/2048
# 1s - loss: 0.2361 - val_loss: 0.2305
# Epoch 1770/2048
# 1s - loss: 0.2361 - val_loss: 0.2304
# Epoch 1771/2048
# 1s - loss: 0.2361 - val_loss: 0.2304
# Epoch 1772/2048
# 1s - loss: 0.2361 - val_loss: 0.2305
# Epoch 1773/2048
# 1s - loss: 0.2361 - val_loss: 0.2307
# Epoch 1774/2048
# 1s - loss: 0.2360 - val_loss: 0.2308
# Epoch 1775/2048
# 1s - loss: 0.2360 - val_loss: 0.2304
# Epoch 1776/2048
# 1s - loss: 0.2360 - val_loss: 0.2304
# Epoch 1777/2048
# 1s - loss: 0.2360 - val_loss: 0.2302
# Epoch 1778/2048
# 1s - loss: 0.2360 - val_loss: 0.2305
# Epoch 1779/2048
# 1s - loss: 0.2360 - val_loss: 0.2302
# Epoch 1780/2048
# 1s - loss: 0.2359 - val_loss: 0.2309
# Epoch 1781/2048
# 1s - loss: 0.2359 - val_loss: 0.2302
# Epoch 1782/2048
# 1s - loss: 0.2359 - val_loss: 0.2303
# Epoch 1783/2048
# 1s - loss: 0.2359 - val_loss: 0.2302
# Epoch 1784/2048
# 1s - loss: 0.2359 - val_loss: 0.2305
# Epoch 1785/2048
# 1s - loss: 0.2359 - val_loss: 0.2303
# Epoch 1786/2048
# 1s - loss: 0.2358 - val_loss: 0.2301
# Epoch 1787/2048
# 1s - loss: 0.2359 - val_loss: 0.2300
# Epoch 1788/2048
# 1s - loss: 0.2358 - val_loss: 0.2305
# Epoch 1789/2048
# 1s - loss: 0.2358 - val_loss: 0.2299
# Epoch 1790/2048
# 1s - loss: 0.2358 - val_loss: 0.2304
# Epoch 1791/2048
# 1s - loss: 0.2358 - val_loss: 0.2302
# Epoch 1792/2048
# 1s - loss: 0.2357 - val_loss: 0.2300
# Epoch 1793/2048
# 1s - loss: 0.2357 - val_loss: 0.2303
# Epoch 1794/2048
# 1s - loss: 0.2357 - val_loss: 0.2303
# Epoch 1795/2048
# 1s - loss: 0.2357 - val_loss: 0.2300
# Epoch 1796/2048
# 1s - loss: 0.2357 - val_loss: 0.2301
# Epoch 1797/2048
# 1s - loss: 0.2357 - val_loss: 0.2300
# Epoch 1798/2048
# 1s - loss: 0.2356 - val_loss: 0.2300
# Epoch 1799/2048
# 1s - loss: 0.2356 - val_loss: 0.2302
# Epoch 1800/2048
# 1s - loss: 0.2356 - val_loss: 0.2300
# Epoch 1801/2048
# 1s - loss: 0.2355 - val_loss: 0.2302
# Epoch 1802/2048
# 1s - loss: 0.2355 - val_loss: 0.2300
# Epoch 1803/2048
# 1s - loss: 0.2355 - val_loss: 0.2300
# Epoch 1804/2048
# 1s - loss: 0.2355 - val_loss: 0.2303
# Epoch 1805/2048
# 1s - loss: 0.2355 - val_loss: 0.2300
# Epoch 1806/2048
# 1s - loss: 0.2355 - val_loss: 0.2299
# Epoch 1807/2048
# 1s - loss: 0.2355 - val_loss: 0.2301
# Epoch 1808/2048
# 1s - loss: 0.2354 - val_loss: 0.2299
# Epoch 1809/2048
# 1s - loss: 0.2355 - val_loss: 0.2298
# Epoch 1810/2048
# 1s - loss: 0.2355 - val_loss: 0.2298
# Epoch 1811/2048
# 1s - loss: 0.2354 - val_loss: 0.2300
# Epoch 1812/2048
# 1s - loss: 0.2354 - val_loss: 0.2299
# Epoch 1813/2048
# 1s - loss: 0.2354 - val_loss: 0.2296
# Epoch 1814/2048
# 1s - loss: 0.2353 - val_loss: 0.2297
# Epoch 1815/2048
# 1s - loss: 0.2353 - val_loss: 0.2297
# Epoch 1816/2048
# 1s - loss: 0.2353 - val_loss: 0.2296
# Epoch 1817/2048
# 1s - loss: 0.2353 - val_loss: 0.2299
# Epoch 1818/2048
# 1s - loss: 0.2353 - val_loss: 0.2299
# Epoch 1819/2048
# 1s - loss: 0.2353 - val_loss: 0.2298
# Epoch 1820/2048
# 1s - loss: 0.2353 - val_loss: 0.2297
# Epoch 1821/2048
# 1s - loss: 0.2353 - val_loss: 0.2297
# Epoch 1822/2048
# 1s - loss: 0.2352 - val_loss: 0.2295
# Epoch 1823/2048
# 1s - loss: 0.2352 - val_loss: 0.2299
# Epoch 1824/2048
# 1s - loss: 0.2352 - val_loss: 0.2296
# Epoch 1825/2048
# 1s - loss: 0.2352 - val_loss: 0.2298
# Epoch 1826/2048
# 1s - loss: 0.2352 - val_loss: 0.2297
# Epoch 1827/2048
# 1s - loss: 0.2352 - val_loss: 0.2295
# Epoch 1828/2048
# 1s - loss: 0.2352 - val_loss: 0.2296
# Epoch 1829/2048
# 1s - loss: 0.2352 - val_loss: 0.2297
# Epoch 1830/2048
# 1s - loss: 0.2351 - val_loss: 0.2299
# Epoch 1831/2048
# 1s - loss: 0.2351 - val_loss: 0.2294
# Epoch 1832/2048
# 1s - loss: 0.2351 - val_loss: 0.2294
# Epoch 1833/2048
# 1s - loss: 0.2351 - val_loss: 0.2295
# Epoch 1834/2048
# 1s - loss: 0.2351 - val_loss: 0.2297
# Epoch 1835/2048
# 1s - loss: 0.2350 - val_loss: 0.2294
# Epoch 1836/2048
# 1s - loss: 0.2350 - val_loss: 0.2298
# Epoch 1837/2048
# 1s - loss: 0.2350 - val_loss: 0.2296
# Epoch 1838/2048
# 1s - loss: 0.2350 - val_loss: 0.2295
# Epoch 1839/2048
# 1s - loss: 0.2349 - val_loss: 0.2294
# Epoch 1840/2048
# 1s - loss: 0.2350 - val_loss: 0.2292
# Epoch 1841/2048
# 1s - loss: 0.2350 - val_loss: 0.2292
# Epoch 1842/2048
# 1s - loss: 0.2350 - val_loss: 0.2296
# Epoch 1843/2048
# 1s - loss: 0.2349 - val_loss: 0.2293
# Epoch 1844/2048
# 1s - loss: 0.2349 - val_loss: 0.2293
# Epoch 1845/2048
# 1s - loss: 0.2349 - val_loss: 0.2296
# Epoch 1846/2048
# 1s - loss: 0.2348 - val_loss: 0.2293
# Epoch 1847/2048
# 1s - loss: 0.2348 - val_loss: 0.2292
# Epoch 1848/2048
# 1s - loss: 0.2348 - val_loss: 0.2294
# Epoch 1849/2048
# 1s - loss: 0.2348 - val_loss: 0.2291
# Epoch 1850/2048
# 1s - loss: 0.2348 - val_loss: 0.2295
# Epoch 1851/2048
# 1s - loss: 0.2348 - val_loss: 0.2293
# Epoch 1852/2048
# 1s - loss: 0.2348 - val_loss: 0.2294
# Epoch 1853/2048
# 1s - loss: 0.2348 - val_loss: 0.2298
# Epoch 1854/2048
# 1s - loss: 0.2348 - val_loss: 0.2293
# Epoch 1855/2048
# 1s - loss: 0.2347 - val_loss: 0.2297
# Epoch 1856/2048
# 1s - loss: 0.2347 - val_loss: 0.2291
# Epoch 1857/2048
# 1s - loss: 0.2347 - val_loss: 0.2292
# Epoch 1858/2048
# 1s - loss: 0.2347 - val_loss: 0.2291
# Epoch 1859/2048
# 1s - loss: 0.2347 - val_loss: 0.2291
# Epoch 1860/2048
# 1s - loss: 0.2347 - val_loss: 0.2288
# Epoch 1861/2048
# 1s - loss: 0.2346 - val_loss: 0.2290
# Epoch 1862/2048
# 1s - loss: 0.2346 - val_loss: 0.2292
# Epoch 1863/2048
# 1s - loss: 0.2346 - val_loss: 0.2292
# Epoch 1864/2048
# 1s - loss: 0.2346 - val_loss: 0.2289
# Epoch 1865/2048
# 1s - loss: 0.2346 - val_loss: 0.2289
# Epoch 1866/2048
# 1s - loss: 0.2346 - val_loss: 0.2293
# Epoch 1867/2048
# 1s - loss: 0.2346 - val_loss: 0.2294
# Epoch 1868/2048
# 1s - loss: 0.2345 - val_loss: 0.2292
# Epoch 1869/2048
# 1s - loss: 0.2346 - val_loss: 0.2289
# Epoch 1870/2048
# 1s - loss: 0.2346 - val_loss: 0.2293
# Epoch 1871/2048
# 1s - loss: 0.2345 - val_loss: 0.2291
# Epoch 1872/2048
# 1s - loss: 0.2345 - val_loss: 0.2289
# Epoch 1873/2048
# 1s - loss: 0.2345 - val_loss: 0.2290
# Epoch 1874/2048
# 1s - loss: 0.2345 - val_loss: 0.2288
# Epoch 1875/2048
# 1s - loss: 0.2344 - val_loss: 0.2290
# Epoch 1876/2048
# 1s - loss: 0.2344 - val_loss: 0.2288
# Epoch 1877/2048
# 1s - loss: 0.2344 - val_loss: 0.2289
# Epoch 1878/2048
# 1s - loss: 0.2344 - val_loss: 0.2287
# Epoch 1879/2048
# 1s - loss: 0.2344 - val_loss: 0.2289
# Epoch 1880/2048
# 1s - loss: 0.2344 - val_loss: 0.2288
# Epoch 1881/2048
# 1s - loss: 0.2344 - val_loss: 0.2287
# Epoch 1882/2048
# 1s - loss: 0.2343 - val_loss: 0.2287
# Epoch 1883/2048
# 1s - loss: 0.2343 - val_loss: 0.2288
# Epoch 1884/2048
# 1s - loss: 0.2343 - val_loss: 0.2285
# Epoch 1885/2048
# 1s - loss: 0.2343 - val_loss: 0.2289
# Epoch 1886/2048
# 1s - loss: 0.2343 - val_loss: 0.2288
# Epoch 1887/2048
# 1s - loss: 0.2343 - val_loss: 0.2287
# Epoch 1888/2048
# 1s - loss: 0.2342 - val_loss: 0.2285
# Epoch 1889/2048
# 1s - loss: 0.2342 - val_loss: 0.2287
# Epoch 1890/2048
# 1s - loss: 0.2342 - val_loss: 0.2285
# Epoch 1891/2048
# 1s - loss: 0.2342 - val_loss: 0.2288
# Epoch 1892/2048
# 1s - loss: 0.2342 - val_loss: 0.2287
# Epoch 1893/2048
# 1s - loss: 0.2342 - val_loss: 0.2290
# Epoch 1894/2048
# 1s - loss: 0.2342 - val_loss: 0.2285
# Epoch 1895/2048
# 1s - loss: 0.2342 - val_loss: 0.2291
# Epoch 1896/2048
# 1s - loss: 0.2342 - val_loss: 0.2286
# Epoch 1897/2048
# 1s - loss: 0.2341 - val_loss: 0.2287
# Epoch 1898/2048
# 1s - loss: 0.2341 - val_loss: 0.2287
# Epoch 1899/2048
# 1s - loss: 0.2341 - val_loss: 0.2285
# Epoch 1900/2048
# 1s - loss: 0.2341 - val_loss: 0.2286
# Epoch 1901/2048
# 1s - loss: 0.2341 - val_loss: 0.2289
# Epoch 1902/2048
# 1s - loss: 0.2341 - val_loss: 0.2286
# Epoch 1903/2048
# 1s - loss: 0.2340 - val_loss: 0.2286
# Epoch 1904/2048
# 1s - loss: 0.2340 - val_loss: 0.2286
# Epoch 1905/2048
# 1s - loss: 0.2340 - val_loss: 0.2288
# Epoch 1906/2048
# 1s - loss: 0.2340 - val_loss: 0.2287
# Epoch 1907/2048
# 1s - loss: 0.2340 - val_loss: 0.2286
# Epoch 1908/2048
# 1s - loss: 0.2340 - val_loss: 0.2285
# Epoch 1909/2048
# 1s - loss: 0.2340 - val_loss: 0.2288
# Epoch 1910/2048
# 1s - loss: 0.2339 - val_loss: 0.2288
# Epoch 1911/2048
# 1s - loss: 0.2339 - val_loss: 0.2283
# Epoch 1912/2048
# 1s - loss: 0.2339 - val_loss: 0.2281
# Epoch 1913/2048
# 1s - loss: 0.2339 - val_loss: 0.2285
# Epoch 1914/2048
# 1s - loss: 0.2339 - val_loss: 0.2291
# Epoch 1915/2048
# 1s - loss: 0.2339 - val_loss: 0.2286
# Epoch 1916/2048
# 1s - loss: 0.2339 - val_loss: 0.2282
# Epoch 1917/2048
# 1s - loss: 0.2338 - val_loss: 0.2286
# Epoch 1918/2048
# 1s - loss: 0.2338 - val_loss: 0.2285
# Epoch 1919/2048
# 1s - loss: 0.2338 - val_loss: 0.2283
# Epoch 1920/2048
# 1s - loss: 0.2338 - val_loss: 0.2285
# Epoch 1921/2048
# 1s - loss: 0.2338 - val_loss: 0.2285
# Epoch 1922/2048
# 1s - loss: 0.2338 - val_loss: 0.2282
# Epoch 1923/2048
# 1s - loss: 0.2338 - val_loss: 0.2284
# Epoch 1924/2048
# 1s - loss: 0.2338 - val_loss: 0.2284
# Epoch 1925/2048
# 1s - loss: 0.2337 - val_loss: 0.2283
# Epoch 1926/2048
# 1s - loss: 0.2337 - val_loss: 0.2285
# Epoch 1927/2048
# 1s - loss: 0.2337 - val_loss: 0.2285
# Epoch 1928/2048
# 1s - loss: 0.2337 - val_loss: 0.2282
# Epoch 1929/2048
# 1s - loss: 0.2337 - val_loss: 0.2281
# Epoch 1930/2048
# 1s - loss: 0.2337 - val_loss: 0.2286
# Epoch 1931/2048
# 1s - loss: 0.2337 - val_loss: 0.2282
# Epoch 1932/2048
# 1s - loss: 0.2336 - val_loss: 0.2280
# Epoch 1933/2048
# 1s - loss: 0.2336 - val_loss: 0.2280
# Epoch 1934/2048
# 1s - loss: 0.2337 - val_loss: 0.2281
# Epoch 1935/2048
# 1s - loss: 0.2336 - val_loss: 0.2283
# Epoch 1936/2048
# 1s - loss: 0.2336 - val_loss: 0.2282
# Epoch 1937/2048
# 1s - loss: 0.2336 - val_loss: 0.2282
# Epoch 1938/2048
# 1s - loss: 0.2336 - val_loss: 0.2282
# Epoch 1939/2048
# 1s - loss: 0.2336 - val_loss: 0.2281
# Epoch 1940/2048
# 1s - loss: 0.2335 - val_loss: 0.2279
# Epoch 1941/2048
# 1s - loss: 0.2335 - val_loss: 0.2284
# Epoch 1942/2048
# 1s - loss: 0.2336 - val_loss: 0.2280
# Epoch 1943/2048
# 1s - loss: 0.2335 - val_loss: 0.2279
# Epoch 1944/2048
# 1s - loss: 0.2335 - val_loss: 0.2281
# Epoch 1945/2048
# 1s - loss: 0.2335 - val_loss: 0.2280
# Epoch 1946/2048
# 1s - loss: 0.2335 - val_loss: 0.2284
# Epoch 1947/2048
# 1s - loss: 0.2334 - val_loss: 0.2280
# Epoch 1948/2048
# 1s - loss: 0.2334 - val_loss: 0.2283
# Epoch 1949/2048
# 1s - loss: 0.2334 - val_loss: 0.2280
# Epoch 1950/2048
# 1s - loss: 0.2334 - val_loss: 0.2277
# Epoch 1951/2048
# 1s - loss: 0.2334 - val_loss: 0.2283
# Epoch 1952/2048
# 1s - loss: 0.2334 - val_loss: 0.2279
# Epoch 1953/2048
# 1s - loss: 0.2334 - val_loss: 0.2282
# Epoch 1954/2048
# 1s - loss: 0.2334 - val_loss: 0.2278
# Epoch 1955/2048
# 1s - loss: 0.2333 - val_loss: 0.2278
# Epoch 1956/2048
# 1s - loss: 0.2333 - val_loss: 0.2281
# Epoch 1957/2048
# 1s - loss: 0.2333 - val_loss: 0.2279
# Epoch 1958/2048
# 1s - loss: 0.2333 - val_loss: 0.2274
# Epoch 1959/2048
# 1s - loss: 0.2333 - val_loss: 0.2279
# Epoch 1960/2048
# 1s - loss: 0.2333 - val_loss: 0.2280
# Epoch 1961/2048
# 1s - loss: 0.2332 - val_loss: 0.2278
# Epoch 1962/2048
# 1s - loss: 0.2333 - val_loss: 0.2276
# Epoch 1963/2048
# 1s - loss: 0.2332 - val_loss: 0.2279
# Epoch 1964/2048
# 1s - loss: 0.2332 - val_loss: 0.2279
# Epoch 1965/2048
# 1s - loss: 0.2332 - val_loss: 0.2279
# Epoch 1966/2048
# 1s - loss: 0.2332 - val_loss: 0.2277
# Epoch 1967/2048
# 1s - loss: 0.2332 - val_loss: 0.2276
# Epoch 1968/2048
# 1s - loss: 0.2332 - val_loss: 0.2277
# Epoch 1969/2048
# 1s - loss: 0.2331 - val_loss: 0.2278
# Epoch 1970/2048
# 1s - loss: 0.2332 - val_loss: 0.2280
# Epoch 1971/2048
# 1s - loss: 0.2331 - val_loss: 0.2277
# Epoch 1972/2048
# 1s - loss: 0.2331 - val_loss: 0.2277
# Epoch 1973/2048
# 1s - loss: 0.2331 - val_loss: 0.2279
# Epoch 1974/2048
# 1s - loss: 0.2331 - val_loss: 0.2276
# Epoch 1975/2048
# 1s - loss: 0.2331 - val_loss: 0.2278
# Epoch 1976/2048
# 1s - loss: 0.2331 - val_loss: 0.2278
# Epoch 1977/2048
# 1s - loss: 0.2331 - val_loss: 0.2277
# Epoch 1978/2048
# 1s - loss: 0.2331 - val_loss: 0.2280
# Epoch 1979/2048
# 1s - loss: 0.2330 - val_loss: 0.2278
# Epoch 1980/2048
# 1s - loss: 0.2330 - val_loss: 0.2276
# Epoch 1981/2048
# 1s - loss: 0.2330 - val_loss: 0.2277
# Epoch 1982/2048
# 1s - loss: 0.2330 - val_loss: 0.2275
# Epoch 1983/2048
# 1s - loss: 0.2330 - val_loss: 0.2281
# Epoch 1984/2048
# 1s - loss: 0.2330 - val_loss: 0.2276
# Epoch 1985/2048
# 1s - loss: 0.2330 - val_loss: 0.2273
# Epoch 1986/2048
# 1s - loss: 0.2329 - val_loss: 0.2275
# Epoch 1987/2048
# 1s - loss: 0.2330 - val_loss: 0.2273
# Epoch 1988/2048
# 1s - loss: 0.2330 - val_loss: 0.2276
# Epoch 1989/2048
# 1s - loss: 0.2329 - val_loss: 0.2276
# Epoch 1990/2048
# 1s - loss: 0.2329 - val_loss: 0.2276
# Epoch 1991/2048
# 1s - loss: 0.2329 - val_loss: 0.2278
# Epoch 1992/2048
# 1s - loss: 0.2329 - val_loss: 0.2276
# Epoch 1993/2048
# 1s - loss: 0.2328 - val_loss: 0.2277
# Epoch 1994/2048
# 1s - loss: 0.2328 - val_loss: 0.2275
# Epoch 1995/2048
# 1s - loss: 0.2328 - val_loss: 0.2274
# Epoch 1996/2048
# 1s - loss: 0.2328 - val_loss: 0.2277
# Epoch 1997/2048
# 1s - loss: 0.2328 - val_loss: 0.2275
# Epoch 1998/2048
# 1s - loss: 0.2328 - val_loss: 0.2275
# Epoch 1999/2048
# 1s - loss: 0.2328 - val_loss: 0.2274
# Epoch 2000/2048
# 1s - loss: 0.2328 - val_loss: 0.2274
# Epoch 2001/2048
# 1s - loss: 0.2327 - val_loss: 0.2271
# Epoch 2002/2048
# 1s - loss: 0.2327 - val_loss: 0.2275
# Epoch 2003/2048
# 1s - loss: 0.2327 - val_loss: 0.2275
# Epoch 2004/2048
# 1s - loss: 0.2327 - val_loss: 0.2273
# Epoch 2005/2048
# 1s - loss: 0.2327 - val_loss: 0.2276
# Epoch 2006/2048
# 1s - loss: 0.2327 - val_loss: 0.2272
# Epoch 2007/2048
# 1s - loss: 0.2327 - val_loss: 0.2273
# Epoch 2008/2048
# 1s - loss: 0.2327 - val_loss: 0.2277
# Epoch 2009/2048
# 1s - loss: 0.2328 - val_loss: 0.2274
# Epoch 2010/2048
# 1s - loss: 0.2327 - val_loss: 0.2273
# Epoch 2011/2048
# 1s - loss: 0.2326 - val_loss: 0.2275
# Epoch 2012/2048
# 1s - loss: 0.2326 - val_loss: 0.2270
# Epoch 2013/2048
# 1s - loss: 0.2326 - val_loss: 0.2273
# Epoch 2014/2048
# 1s - loss: 0.2326 - val_loss: 0.2272
# Epoch 2015/2048
# 1s - loss: 0.2326 - val_loss: 0.2269
# Epoch 2016/2048
# 1s - loss: 0.2326 - val_loss: 0.2272
# Epoch 2017/2048
# 1s - loss: 0.2325 - val_loss: 0.2272
# Epoch 2018/2048
# 1s - loss: 0.2326 - val_loss: 0.2275
# Epoch 2019/2048
# 1s - loss: 0.2325 - val_loss: 0.2269
# Epoch 2020/2048
# 1s - loss: 0.2325 - val_loss: 0.2272
# Epoch 2021/2048
# 1s - loss: 0.2325 - val_loss: 0.2271
# Epoch 2022/2048
# 1s - loss: 0.2325 - val_loss: 0.2272
# Epoch 2023/2048
# 1s - loss: 0.2325 - val_loss: 0.2272
# Epoch 2024/2048
# 1s - loss: 0.2325 - val_loss: 0.2269
# Epoch 2025/2048
# 1s - loss: 0.2324 - val_loss: 0.2272
# Epoch 2026/2048
# 1s - loss: 0.2325 - val_loss: 0.2270
# Epoch 2027/2048
# 1s - loss: 0.2324 - val_loss: 0.2272
# Epoch 2028/2048
# 1s - loss: 0.2325 - val_loss: 0.2272
# Epoch 2029/2048
# 1s - loss: 0.2324 - val_loss: 0.2268
# Epoch 2030/2048
# 1s - loss: 0.2324 - val_loss: 0.2270
# Epoch 2031/2048
# 1s - loss: 0.2324 - val_loss: 0.2269
# Epoch 2032/2048
# 1s - loss: 0.2324 - val_loss: 0.2270
# Epoch 2033/2048
# 1s - loss: 0.2324 - val_loss: 0.2272
# Epoch 2034/2048
# 1s - loss: 0.2324 - val_loss: 0.2269
# Epoch 2035/2048
# 1s - loss: 0.2323 - val_loss: 0.2271
# Epoch 2036/2048
# 1s - loss: 0.2324 - val_loss: 0.2272
# Epoch 2037/2048
# 1s - loss: 0.2324 - val_loss: 0.2271
# Epoch 2038/2048
# 1s - loss: 0.2324 - val_loss: 0.2271
# Epoch 2039/2048
# 1s - loss: 0.2323 - val_loss: 0.2273
# Epoch 2040/2048
# 1s - loss: 0.2323 - val_loss: 0.2273
# Epoch 2041/2048
# 1s - loss: 0.2323 - val_loss: 0.2272
# Epoch 2042/2048
# 1s - loss: 0.2323 - val_loss: 0.2270
# Epoch 2043/2048
# 1s - loss: 0.2323 - val_loss: 0.2270
# Epoch 2044/2048
# 1s - loss: 0.2323 - val_loss: 0.2270
# Epoch 2045/2048
# 1s - loss: 0.2322 - val_loss: 0.2270
# Epoch 2046/2048
# 1s - loss: 0.2322 - val_loss: 0.2275
# Epoch 2047/2048
# 1s - loss: 0.2322 - val_loss: 0.2267
# Epoch 2048/2048
# 1s - loss: 0.2322 - val_loss: 0.2270

# %%
# Reload saved model
autoencoder = load_model("%s%s.h5" % (model_directory, model_name2))

# %%
X_test_filtered = X_test_norm[:, feature_filter]

# %%
# Exclude validation set
X_train_wo_valid_filtered = X_train_wo_valid[:, feature_filter]

# %%
X_test_filtered.shape
# Out:
# (18628, 1170)

# %%
# Run predictions
ae_pred_filtered = autoencoder.predict(X_test_filtered)
ae_pred_filtered_train = autoencoder.predict(X_train_wo_valid_filtered)

# %%
pickle.dump(ae_pred_filtered, open(model_directory + "ae_pred_filtered.p", "wb"))
pickle.dump(ae_pred_filtered_train, open(model_directory + "ae_pred_filtered_train.p", "wb"))

# %%
ae_pred_filtered = pickle.load(open(model_directory + "ae_pred_filtered.p", "rb"))
ae_pred_filtered_train = pickle.load(open(model_directory + "ae_pred_filtered_train.p", "rb"))

# %%
ae_error_filtered = get_error_df(X_test_filtered, ae_pred_filtered, mode="topn", n_highest=100)
ae_error_filtered_train = get_error_df(X_train_wo_valid_filtered, ae_pred_filtered_train, mode="topn", n_highest=100)

# %%
pickle.dump(ae_error_filtered, open(model_directory + "ae_error_filtered.p", "wb"))
pickle.dump(ae_error_filtered_train, open(model_directory + "ae_error_filtered_train.p", "wb"))

# %%
plt.rcParams['figure.figsize'] = [20, 10]
plot_lumi_error(np.zeros(ae_pred.shape), X_test_norm, title='Mean square score across lumisections')
plot_lumi_error(ae_pred, X_test_norm, title='AE reco errror across lumisections')
plot_lumi_error(ae_pred_filtered, X_test_filtered, 
                title='AE filtered reco errror across lumisections')

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve(label, pred, X_tests, names):
    """Generates ROC Curves for a given array"""
    scores = [get_error_df(X_tests[i], pred[i], mode='topn') for i in range(len(pred))]
    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve_error(label, scores, names):
    """Generates ROC Curves for a given array"""    
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.show()
    return plt

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test,
                    [ae_error,
                     get_error_df(X_test_filtered, ae_pred_filtered, mode="topn"), 
                     get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn")], 
                    ['AE',
                     'AE filtered',
                     'Mean square'])

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error, 
                     get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)], 
                    ['Squeezed AE w/o pileup',
                     'Squeezed AE with pileup',
                     'Standard AE with pileup',
                     'Standard AE w/o pileup',
                     'Mean square'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-0de51066cff7> in <module>()
#       1 plt.rcParams['figure.figsize'] = [20, 10]
#       2 fig = get_roc_curve_error(y_test,
# ----> 3                     [np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error,
#       4                      get_error_df(X_test_norm, np.zeros(X_test_norm.shape), mode="topn", n_highest=100)],
#       5                     ['Squeezed AE w/o pileup',
#
# NameError: name 'np_b_ae_error' is not defined

# %%
fig.savefig(csv_dir + 'roc_auc_filtered_ae.png')

# %%
plt.rcParams['figure.figsize'] = [20, 10]
fig = get_roc_curve_error(y_test, 
                    [np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered,
                     get_error_df(X_test_filtered, np.zeros(X_test_filtered.shape), mode="topn", n_highest=100)], 
                    ['Squeezed AE w/o pileup',
                     'Squeezed AE with pileup',
                     'Standard AE with pileup',
                     'Standard AE w/o pileup',
                     'Mean square'])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

LABELS = ["Normal", "Anomalous"]

def conf_matrix(scores, y_true, threshold, title):
    y_pred = [1 if e > threshold else 0 for e in scores]
    conf_matrix = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(12, 12))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.title(title)
    plt.show()

    acc = accuracy_score(y_true, y_pred)
    class_imbal = np.mean(1 - y_true)
    adj_acc = (acc - class_imbal) / (1 - class_imbal)

    print("Threshold:", threshold)
    print("Adjusted accuracy:", adj_acc)
    return threshold

# %%
conf_matrix(ae_error_filtered, y_test, 1.5e0, '')

# %%
def pred_vs_feature(y_val, x_val, y_class, y_name="", x_name="", selected=[], linear=False,
                    limit=False):
    '''
    Plots two arbitrary values agains each other.
    '''
    df = pd.DataFrame({'y_val': y_val,
                       'x_val': x_val,
                       'y_class': y_class})

    groups = df.groupby('y_class')
    fig, ax = plt.subplots()

    for name, group in groups:
        ax.plot(group.x_val, 
                group.y_val,
                color="red" if name == 1 else "blue",
                marker='o',
                ms=2,
                linestyle='',
                label= "Anomaly" if name == 1 else "Normal")

    for i in selected:
        ax.plot(x_val[i],
                y_val[i],
                color="green",
                marker='o',
                ms=4,
                linestyle='')
                 
    ax.legend()
    if not linear:
        ax.set_yscale('log')
    if limit:
        plt.xlim([limit[0], limit[1]])
    plt.grid()
    plt.ylabel(y_name)
    plt.xlabel(x_name)
    plt.show()

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
plt.rcParams['figure.figsize'] = [20, 10]
pred_vs_feature(ae_error_filtered, X_test[2807], y_test, "AE reco error", "Luminosity")

# %%
model_directory_np_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_bottleneck/"
model_directory_p_b = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup/"
model_directory_p_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_w_pileup_no_bottleneck/"
model_directory_np_nb = "/eos/user/t/tkrzyzek/autoencoder/plots_train_no_pileup_no_bottleneck/"

# %%
np_b_ae_error = pickle.load(open(model_directory_np_b + "ae_error.p", "rb"))
np_b_ae_error_filtered = pickle.load(open(model_directory_np_b + "ae_error_filtered.p", "rb"))

p_b_ae_error = pickle.load(open(model_directory_p_b + "ae_error.p", "rb"))
p_b_ae_error_filtered = pickle.load(open(model_directory_p_b + "ae_error_filtered.p", "rb"))


p_nb_ae_error = pickle.load(open(model_directory_p_nb + "ae_error.p", "rb"))
p_nb_ae_error_filtered = pickle.load(open(model_directory_p_nb + "ae_error_filtered.p", "rb"))


np_nb_ae_error = pickle.load(open(model_directory_np_nb + "ae_error.p", "rb"))
np_nb_ae_error_filtered = pickle.load(open(model_directory_np_nb + "ae_error_filtered.p", "rb"))

# %%
def pred_vs_feature4(y_vals, x_val, y_class, titles, y_name="", x_name="", linear=False, 
                     limit=False, name_plt=''):
    '''
    Plots two arbitrary values agains each other.
    '''
    fig, axes = plt.subplots(2, 2)
    
    for i in range(4):
        df = pd.DataFrame({'y_val': y_vals[i],
                           'x_val': x_val,
                           'y_class': y_class})

        groups = df.groupby('y_class')
        if i < 2:
            ax = axes[0, i%2]
        else:
            ax = axes[1, i%2]
        
        for name, group in groups:
            ax.plot(group.x_val, 
                    group.y_val,
                    color="red" if name == 1 else "blue",
                    marker='o',
                    ms=2,
                    linestyle='',
                    label= "Anomaly" if name == 1 else "Normal")

        ax.legend()
        if not linear:
            ax.set_yscale('log')
        if limit:
            plt.xlim([limit[0], limit[1]])
        ax.set_ylabel(y_name)
        ax.set_xlabel(x_name)
        ax.set_title(titles[i])
        plt.grid()
    plt.show()
    plt.savefig(csv_dir + name_plt)

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2807], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2807], y_test,
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                 'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Luminosity", name_plt='filtered_ae_vs_luminosity.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error, p_b_ae_error, p_nb_ae_error, np_nb_ae_error],
                X_test[2808], y_test, ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='ae_vs_pileup.png')

# %%
plt.rcParams['figure.figsize'] = [40, 20]
pred_vs_feature4([np_b_ae_error_filtered, p_b_ae_error_filtered, p_nb_ae_error_filtered,
                  np_nb_ae_error_filtered], X_test[2808], y_test, 
                 ['Squeezed AE w/o pileup', 'Squeezed AE with pileup',
                                      'Normal AE with pileup', 'Normal AE w/o pileup'],
                 "AE reco error", "Pileup", name_plt='filtered_ae_vs_pileup.png')
