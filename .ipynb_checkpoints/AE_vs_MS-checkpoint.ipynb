# %%
# Running on GPU?

import setGPU
# Out:
# setGPU: Setting GPU to: 0

# %% [markdown]
# # Autoencoder vs Mean Square for Data Certification

# %%
# Imports...

import getpass
import h5py
import matplotlib
import matplotlib.pyplot as plt
import os

from tqdm import tqdm

# Size of plots
plt.rcParams['figure.figsize'] = [20, 10]

# %%
# Get permission to access EOS (Insert your NICE password)

os.system("echo %s | kinit" % getpass.getpass())
# Out:
# ········
# 0

# %%
# Change presentation settings

# %matplotlib inline

matplotlib.rcParams["figure.figsize"] = (8.0, 5.0)
matplotlib.rcParams["xtick.labelsize"] = 12
matplotlib.rcParams["ytick.labelsize"] = 12
matplotlib.rcParams["axes.spines.left"] = True
matplotlib.rcParams["axes.spines.bottom"] = True
matplotlib.rcParams["axes.spines.right"] = False
matplotlib.rcParams["axes.spines.top"] = False
matplotlib.rcParams["axes.labelsize"] = 14
matplotlib.rcParams["legend.fontsize"] = 14
matplotlib.rcParams["axes.titlesize"] = 14

color_palette = {"Indigo": {
                    50: "#E8EAF6",
                    100: "#C5CAE9",
                    200: "#9FA8DA",
                    300: "#7986CB",
                    400: "#5C6BC0",
                    500: "#3F51B5",
                    600: "#3949AB",
                    700: "#303F9F",
                    800: "#283593",
                    900: "#1A237E"},
                 "Teal": {      
                    50: "#E0F2F1",
                    100: "#B2DFDB",
                    200: "#80CBC4",
                    300: "#4DB6AC",
                    400: "#26A69A",
                    500: "#009688",
                    600: "#00897B",
                    700: "#00796B",
                    800: "#00695C",
                    900: "#004D40"}
                }

line_styles = [(0, ()), (0, (1, 3)), (0, (3, 2))]

# %% [markdown]
# ## Load data, and labels

# %%
import json
import numpy as np
import pandas as pd

# %%
PDs  = {1: 'BTagCSV',
        2: 'BTagMu',
        3: 'Charmonium',
        4: 'DisplacedJet',
        5: 'DoubleEG',
        6: 'DoubleMuon',
        7: 'DoubleMuonLowMass',
        8: 'FSQJets',
        9: 'HighMultiplicityEOF',
        10: 'HTMHT',
        11: 'JetHT',
        12: 'MET',
        13: 'MinimumBias',
        14: 'MuonEG',
        15: 'MuOnia',
        16: 'NoBPTX',
        17: 'SingleElectron',
        18: 'SingleMuon',
        19: 'SinglePhoton',
        20: 'Tau',
        21: 'ZeroBias'}

# Select PD
nPD = 11

# %%
data_directory = "/eos/cms/store/user/fsiroky/consistentlumih5/"
label_file = "./JetHT.json"
model_directory = "./"
model_name = "model_ae_vs_ms"

# %%
def get_file_list(directory, pds, npd, typeof, extension):
    files = []
    parts = ["C", "D", "E", "F", "G", "H"]
    for p in parts:
        files.append("%s%s_%s_%s%s" % (directory, pds[npd], p, typeof, extension))
    return files

files = get_file_list(data_directory, PDs, nPD, "background", ".h5")
files = files + get_file_list(data_directory, PDs, nPD, "signal", ".h5")

# %%
# Load good and bad jets

def get_data(files):
    readout = np.empty([0,2813])
    
    for file in files:
        jet = file.split("/")[-1][:-3]
        print("Reading: %s" % jet)
        try:
            h5file = h5py.File(file, "r")
            readout = np.concatenate((readout, h5file[jet][:]), axis=0)
        except OSError as error:
            print("This Primary Dataset doesn't have %s. %s" % (jet, error))
            continue

    return readout

data = pd.DataFrame(get_data(files))
# Out:
# Reading: JetHT_C_background
# Reading: JetHT_D_background
# Reading: JetHT_E_background
# Reading: JetHT_F_background
# Reading: JetHT_G_background
# Reading: JetHT_H_background
# Reading: JetHT_C_signal
# Reading: JetHT_D_signal
# Reading: JetHT_E_signal
# Reading: JetHT_F_signal
# Reading: JetHT_G_signal
# Reading: JetHT_H_signal

# %%
data["run"] = data[2807].astype(int)
data["lumi"] = data[2808].astype(int)
data["inst_lumi"] = data[2809].astype(float)

# Drop unnecessary meta data
data.drop([2807, 2808, 2809, 2810, 2811, 2812], axis=1, inplace=True)

# Sort by runID and then by lumiID
data = data.sort_values(["run", "lumi"], ascending=[True,True])

# Reset index
data = data.reset_index(drop=True)

# %%
# Apply labels
output_json = json.load(open(label_file))

def json_checker(json_file, orig_runid, orig_lumid):
    try:
        for i in json_file[str(int(orig_runid))]:
            if orig_lumid >= i[0] and orig_lumid <= i[1]:
                return 0
    except KeyError:
        pass
    return 1

def add_flags(sample):
    return json_checker(output_json, sample["run"], sample["lumi"])

data["label"] = data.apply(add_flags, axis=1)

# %%
print("Number of anomalies: ", len(data[data["label"] == 1]))
print("Number of inliers: ", len(data[data["label"] == 0]))
# Out:
# Number of anomalies:  2377
# Number of inliers:  161307

# %% [markdown]
# ## Preprocess the data

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Normalize the data

# Before
data[0].plot.hist(bins=50, logy=True);

data.iloc[:, 0:2806] = StandardScaler().fit_transform(data.iloc[:, 0:2806].values)

# After
data[0].plot.hist(bins=50, logy=True);

# %%
# Split the data

# This will work in scikit v19
# X_train, X_test, y_train, y_test = train_test_split(data.iloc[:, 0:2806], data["label"], shuffle=False)

# This will work in scikit v<19

split_factor = 0.1

split = round(split_factor*len(data))

train = data.iloc[:split]
X_train = train.iloc[:, 0:2806]
y_train = train["label"]

test = data.iloc[split:]
X_test = test.iloc[:, 0:2806]
y_test = test["label"]

print("Number of inliers in test set: %s" % sum((y_test == 0).values))
print("Number of anomalies in the test set: %s" % sum((y_test == 1).values))
# Out:
# Number of inliers in test set: 145494
# Number of anomalies in the test set: 1822

# %% [markdown]
# # Training the autoencoder

# %%
import keras
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.layers import Input, Dense
from keras.layers.advanced_activations import PReLU
from keras.models import Model, load_model

# %%
# Train only on good

X_train = X_train[y_train == 0]
X_train = X_train.values
X_test = X_test.values

# %%
input_dim = X_train.shape[1]

# %%
# Define the model

input_layer = Input(shape=(input_dim, ))
prellll = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=None)
encoded = Dense(2000, kernel_regularizer=keras.regularizers.l1(10e-5))(input_layer)
encoded = prellll(encoded)

prellll = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=None)
encoded = Dense(1000, kernel_regularizer=keras.regularizers.l1(10e-5))(encoded)
encoded = prellll(encoded)

prellll = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=None)
encoded = Dense(500, kernel_regularizer=keras.regularizers.l1(10e-5))(encoded)
encoded = prellll(encoded)

prellll = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=None)
encoded = Dense(1000, kernel_regularizer=keras.regularizers.l1(10e-5))(encoded)
encoded = prellll(encoded)

prellll = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=None)
encoded = Dense(2000, kernel_regularizer=keras.regularizers.l1(10e-5))(encoded)
encoded = prellll(encoded)

prellll = PReLU(alpha_initializer='zeros', alpha_regularizer=None, alpha_constraint=None, shared_axes=None)
decoder = Dense(input_dim)(encoded)
decoder = prellll(decoder)
autoencoder = Model(inputs=input_layer, outputs=decoder)

autoencoder.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 2806)              0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2000)              5614000
# _________________________________________________________________
# p_re_lu_19 (PReLU)           (None, 2000)              2000
# _________________________________________________________________
# dense_20 (Dense)             (None, 1000)              2001000
# _________________________________________________________________
# p_re_lu_20 (PReLU)           (None, 1000)              1000
# _________________________________________________________________
# dense_21 (Dense)             (None, 2000)              2002000
# _________________________________________________________________
# p_re_lu_21 (PReLU)           (None, 2000)              2000
# _________________________________________________________________
# dense_22 (Dense)             (None, 2806)              5614806
# _________________________________________________________________
# p_re_lu_22 (PReLU)           (None, 2806)              2806
# =================================================================
# Total params: 15,239,612
# Trainable params: 15,239,612
# Non-trainable params: 0
# _________________________________________________________________

# %%
adamm = keras.optimizers.Adam(lr=0.0001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

early_stopper = EarlyStopping(monitor="val_loss",
                              patience=32,
                              verbose=True,
                              mode="auto")

autoencoder.compile(optimizer=adamm, loss='mean_squared_error')

checkpoint_callback = ModelCheckpoint(("%s%s.h5" % (model_directory, model_name)),
                                      monitor="val_loss",
                                      verbose=False,
                                      save_best_only=True,
                                      mode="min")

history = autoencoder.fit(X_train,
                          X_train,
                          epochs=8192,
                          batch_size=256,
                          shuffle=True,
                          validation_split=0.25,
                          verbose=2,
                          callbacks=[early_stopper, checkpoint_callback]).history
# Out:
# Train on 11859 samples, validate on 3954 samples
# Epoch 1/8192
# 6s - loss: 0.3906 - val_loss: 0.4721
# Epoch 2/8192
# 2s - loss: 0.3841 - val_loss: 0.4758
# Epoch 3/8192
# 2s - loss: 0.3841 - val_loss: 0.4745
# Epoch 4/8192
# 5s - loss: 0.3838 - val_loss: 0.4717
# Epoch 5/8192
# 5s - loss: 0.3835 - val_loss: 0.4698
# Epoch 6/8192
# 2s - loss: 0.3834 - val_loss: 0.4752
# Epoch 7/8192
# 2s - loss: 0.3830 - val_loss: 0.4758
# Epoch 8/8192
# 2s - loss: 0.3832 - val_loss: 0.4722
# Epoch 9/8192
# 5s - loss: 0.3829 - val_loss: 0.4681
# Epoch 10/8192
# 2s - loss: 0.3828 - val_loss: 0.4720
# Epoch 11/8192
# 2s - loss: 0.3825 - val_loss: 0.4730
# Epoch 12/8192
# 2s - loss: 0.3824 - val_loss: 0.4704
# Epoch 13/8192
# 2s - loss: 0.3823 - val_loss: 0.4696
# Epoch 14/8192
# 2s - loss: 0.3819 - val_loss: 0.4741
# Epoch 15/8192
# 2s - loss: 0.3819 - val_loss: 0.4723
# Epoch 16/8192
# 2s - loss: 0.3816 - val_loss: 0.4710
# Epoch 17/8192
# 5s - loss: 0.3816 - val_loss: 0.4670
# Epoch 18/8192
# 2s - loss: 0.3812 - val_loss: 0.4725
# Epoch 19/8192
# 2s - loss: 0.3811 - val_loss: 0.4720
# Epoch 20/8192
# 2s - loss: 0.3810 - val_loss: 0.4711
# Epoch 21/8192
# 2s - loss: 0.3807 - val_loss: 0.4681
# Epoch 22/8192
# 2s - loss: 0.3806 - val_loss: 0.4713
# Epoch 23/8192
# 2s - loss: 0.3802 - val_loss: 0.4723
# Epoch 24/8192
# 2s - loss: 0.3803 - val_loss: 0.4690
# Epoch 25/8192
# 4s - loss: 0.3800 - val_loss: 0.4662
# Epoch 26/8192
# 2s - loss: 0.3798 - val_loss: 0.4689
# Epoch 27/8192
# 2s - loss: 0.3796 - val_loss: 0.4717
# Epoch 28/8192
# 5s - loss: 0.3794 - val_loss: 0.4661
# Epoch 29/8192
# 2s - loss: 0.3793 - val_loss: 0.4661
# Epoch 30/8192
# 2s - loss: 0.3788 - val_loss: 0.4695
# Epoch 31/8192
# 2s - loss: 0.3788 - val_loss: 0.4712
# Epoch 32/8192
# 2s - loss: 0.3786 - val_loss: 0.4671
# Epoch 33/8192
# 5s - loss: 0.3786 - val_loss: 0.4628
# Epoch 34/8192
# 2s - loss: 0.3782 - val_loss: 0.4674
# Epoch 35/8192
# 2s - loss: 0.3780 - val_loss: 0.4664
# Epoch 36/8192
# 2s - loss: 0.3780 - val_loss: 0.4639
# Epoch 37/8192
# 2s - loss: 0.3776 - val_loss: 0.4632
# Epoch 38/8192
# 2s - loss: 0.3775 - val_loss: 0.4670
# Epoch 39/8192
# 2s - loss: 0.3772 - val_loss: 0.4672
# Epoch 40/8192
# 2s - loss: 0.3772 - val_loss: 0.4631
# Epoch 41/8192
# 5s - loss: 0.3769 - val_loss: 0.4597
# Epoch 42/8192
# 2s - loss: 0.3767 - val_loss: 0.4645
# Epoch 43/8192
# 2s - loss: 0.3766 - val_loss: 0.4667
# Epoch 44/8192
# 2s - loss: 0.3763 - val_loss: 0.4629
# Epoch 45/8192
# 2s - loss: 0.3763 - val_loss: 0.4597
# Epoch 46/8192
# 2s - loss: 0.3759 - val_loss: 0.4651
# Epoch 47/8192
# 2s - loss: 0.3759 - val_loss: 0.4654
# Epoch 48/8192
# 2s - loss: 0.3757 - val_loss: 0.4626
# Epoch 49/8192
# 5s - loss: 0.3755 - val_loss: 0.4583
# Epoch 50/8192
# 2s - loss: 0.3753 - val_loss: 0.4645
# Epoch 51/8192
# 2s - loss: 0.3751 - val_loss: 0.4635
# Epoch 52/8192
# 2s - loss: 0.3751 - val_loss: 0.4596
# Epoch 53/8192
# 2s - loss: 0.3748 - val_loss: 0.4595
# Epoch 54/8192
# 2s - loss: 0.3746 - val_loss: 0.4636
# Epoch 55/8192
# 2s - loss: 0.3744 - val_loss: 0.4642
# Epoch 56/8192
# 2s - loss: 0.3744 - val_loss: 0.4598
# Epoch 57/8192
# 4s - loss: 0.3742 - val_loss: 0.4577
# Epoch 58/8192
# 2s - loss: 0.3739 - val_loss: 0.4603
# Epoch 59/8192
# 2s - loss: 0.3739 - val_loss: 0.4616
# Epoch 60/8192
# 2s - loss: 0.3737 - val_loss: 0.4581
# Epoch 61/8192
# 2s - loss: 0.3736 - val_loss: 0.4578
# Epoch 62/8192
# 2s - loss: 0.3733 - val_loss: 0.4620
# Epoch 63/8192
# 2s - loss: 0.3733 - val_loss: 0.4612
# Epoch 64/8192
# 2s - loss: 0.3732 - val_loss: 0.4587
# Epoch 65/8192
# 5s - loss: 0.3730 - val_loss: 0.4539
# Epoch 66/8192
# 2s - loss: 0.3729 - val_loss: 0.4584
# Epoch 67/8192
# 2s - loss: 0.3726 - val_loss: 0.4592
# Epoch 68/8192
# 2s - loss: 0.3727 - val_loss: 0.4564
# Epoch 69/8192
# 2s - loss: 0.3725 - val_loss: 0.4553
# Epoch 70/8192
# 2s - loss: 0.3723 - val_loss: 0.4583
# Epoch 71/8192
# 2s - loss: 0.3722 - val_loss: 0.4594
# Epoch 72/8192
# 2s - loss: 0.3721 - val_loss: 0.4565
# Epoch 73/8192
# 2s - loss: 0.3721 - val_loss: 0.4539
# Epoch 74/8192
# 2s - loss: 0.3717 - val_loss: 0.4580
# Epoch 75/8192
# 2s - loss: 0.3718 - val_loss: 0.4570
# Epoch 76/8192
# 2s - loss: 0.3716 - val_loss: 0.4551
# Epoch 77/8192
# 4s - loss: 0.3716 - val_loss: 0.4532
# Epoch 78/8192
# 2s - loss: 0.3712 - val_loss: 0.4585
# Epoch 79/8192
# 2s - loss: 0.3712 - val_loss: 0.4589
# Epoch 80/8192
# 2s - loss: 0.3712 - val_loss: 0.4567
# Epoch 81/8192
# 4s - loss: 0.3710 - val_loss: 0.4524
# Epoch 82/8192
# 2s - loss: 0.3709 - val_loss: 0.4551
# Epoch 83/8192
# 2s - loss: 0.3706 - val_loss: 0.4566
# Epoch 84/8192
# 2s - loss: 0.3707 - val_loss: 0.4534
# Epoch 85/8192
# 2s - loss: 0.3704 - val_loss: 0.4534
# Epoch 86/8192
# 2s - loss: 0.3703 - val_loss: 0.4559
# Epoch 87/8192
# 2s - loss: 0.3701 - val_loss: 0.4573
# Epoch 88/8192
# 2s - loss: 0.3701 - val_loss: 0.4527
# Epoch 89/8192
# 5s - loss: 0.3700 - val_loss: 0.4498
# Epoch 90/8192
# 2s - loss: 0.3696 - val_loss: 0.4538
# Epoch 91/8192
# 2s - loss: 0.3695 - val_loss: 0.4550
# Epoch 92/8192
# 2s - loss: 0.3694 - val_loss: 0.4517
# Epoch 93/8192
# 4s - loss: 0.3693 - val_loss: 0.4489
# Epoch 94/8192
# 3s - loss: 0.3689 - val_loss: 0.4542
# Epoch 95/8192
# 3s - loss: 0.3689 - val_loss: 0.4534
# Epoch 96/8192
# 2s - loss: 0.3689 - val_loss: 0.4509
# Epoch 97/8192
# 5s - loss: 0.3685 - val_loss: 0.4471
# Epoch 98/8192
# 3s - loss: 0.3684 - val_loss: 0.4511
# Epoch 99/8192
# 2s - loss: 0.3682 - val_loss: 0.4514
# Epoch 100/8192
# 3s - loss: 0.3681 - val_loss: 0.4476
# Epoch 101/8192
# 3s - loss: 0.3679 - val_loss: 0.4472
# Epoch 102/8192
# 2s - loss: 0.3676 - val_loss: 0.4517
# Epoch 103/8192
# 2s - loss: 0.3675 - val_loss: 0.4526
# Epoch 104/8192
# 2s - loss: 0.3673 - val_loss: 0.4498
# Epoch 105/8192
# 5s - loss: 0.3673 - val_loss: 0.4441
# Epoch 106/8192
# 3s - loss: 0.3668 - val_loss: 0.4494
# Epoch 107/8192
# 2s - loss: 0.3668 - val_loss: 0.4487
# Epoch 108/8192
# 2s - loss: 0.3666 - val_loss: 0.4467
# Epoch 109/8192
# 2s - loss: 0.3664 - val_loss: 0.4448
# Epoch 110/8192
# 2s - loss: 0.3661 - val_loss: 0.4502
# Epoch 111/8192
# 2s - loss: 0.3659 - val_loss: 0.4502
# Epoch 112/8192
# 2s - loss: 0.3659 - val_loss: 0.4456
# Epoch 113/8192
# 5s - loss: 0.3656 - val_loss: 0.4431
# Epoch 114/8192
# 2s - loss: 0.3654 - val_loss: 0.4469
# Epoch 115/8192
# 2s - loss: 0.3651 - val_loss: 0.4481
# Epoch 116/8192
# 6s - loss: 0.3650 - val_loss: 0.4430
# Epoch 117/8192
# 2s - loss: 0.3648 - val_loss: 0.4437
# Epoch 118/8192
# 2s - loss: 0.3645 - val_loss: 0.4463
# Epoch 119/8192
# 2s - loss: 0.3645 - val_loss: 0.4469
# Epoch 120/8192
# 2s - loss: 0.3642 - val_loss: 0.4435
# Epoch 121/8192
# 6s - loss: 0.3642 - val_loss: 0.4413
# Epoch 122/8192
# 2s - loss: 0.3638 - val_loss: 0.4446
# Epoch 123/8192
# 2s - loss: 0.3637 - val_loss: 0.4444
# Epoch 124/8192
# 2s - loss: 0.3636 - val_loss: 0.4416
# Epoch 125/8192
# 5s - loss: 0.3634 - val_loss: 0.4395
# Epoch 126/8192
# 2s - loss: 0.3632 - val_loss: 0.4439
# Epoch 127/8192
# 2s - loss: 0.3629 - val_loss: 0.4452
# Epoch 128/8192
# 2s - loss: 0.3630 - val_loss: 0.4422
# Epoch 129/8192
# 5s - loss: 0.3627 - val_loss: 0.4377
# Epoch 130/8192
# 2s - loss: 0.3626 - val_loss: 0.4411
# Epoch 131/8192
# 2s - loss: 0.3624 - val_loss: 0.4423
# Epoch 132/8192
# 2s - loss: 0.3623 - val_loss: 0.4394
# Epoch 133/8192
# 2s - loss: 0.3622 - val_loss: 0.4392
# Epoch 134/8192
# 2s - loss: 0.3618 - val_loss: 0.4435
# Epoch 135/8192
# 2s - loss: 0.3619 - val_loss: 0.4419
# Epoch 136/8192
# 2s - loss: 0.3617 - val_loss: 0.4400
# Epoch 137/8192
# 5s - loss: 0.3616 - val_loss: 0.4364
# Epoch 138/8192
# 2s - loss: 0.3613 - val_loss: 0.4414
# Epoch 139/8192
# 2s - loss: 0.3612 - val_loss: 0.4406
# Epoch 140/8192
# 2s - loss: 0.3612 - val_loss: 0.4388
# Epoch 141/8192
# 2s - loss: 0.3609 - val_loss: 0.4373
# Epoch 142/8192
# 2s - loss: 0.3608 - val_loss: 0.4400
# Epoch 143/8192
# 2s - loss: 0.3605 - val_loss: 0.4415
# Epoch 144/8192
# 2s - loss: 0.3605 - val_loss: 0.4387
# Epoch 145/8192
# 5s - loss: 0.3603 - val_loss: 0.4353
# Epoch 146/8192
# 2s - loss: 0.3601 - val_loss: 0.4384
# Epoch 147/8192
# 2s - loss: 0.3600 - val_loss: 0.4401
# Epoch 148/8192
# 4s - loss: 0.3599 - val_loss: 0.4353
# Epoch 149/8192
# 5s - loss: 0.3598 - val_loss: 0.4341
# Epoch 150/8192
# 2s - loss: 0.3593 - val_loss: 0.4385
# Epoch 151/8192
# 2s - loss: 0.3593 - val_loss: 0.4396
# Epoch 152/8192
# 2s - loss: 0.3591 - val_loss: 0.4361
# Epoch 153/8192
# 5s - loss: 0.3591 - val_loss: 0.4321
# Epoch 154/8192
# 2s - loss: 0.3588 - val_loss: 0.4363
# Epoch 155/8192
# 2s - loss: 0.3586 - val_loss: 0.4358
# Epoch 156/8192
# 2s - loss: 0.3586 - val_loss: 0.4329
# Epoch 157/8192
# 4s - loss: 0.3582 - val_loss: 0.4320
# Epoch 158/8192
# 2s - loss: 0.3581 - val_loss: 0.4358
# Epoch 159/8192
# 2s - loss: 0.3578 - val_loss: 0.4359
# Epoch 160/8192
# 2s - loss: 0.3578 - val_loss: 0.4322
# Epoch 161/8192
# 5s - loss: 0.3576 - val_loss: 0.4288
# Epoch 162/8192
# 2s - loss: 0.3573 - val_loss: 0.4331
# Epoch 163/8192
# 2s - loss: 0.3572 - val_loss: 0.4349
# Epoch 164/8192
# 2s - loss: 0.3570 - val_loss: 0.4313
# Epoch 165/8192
# 5s - loss: 0.3569 - val_loss: 0.4280
# Epoch 166/8192
# 2s - loss: 0.3565 - val_loss: 0.4329
# Epoch 167/8192
# 2s - loss: 0.3564 - val_loss: 0.4333
# Epoch 168/8192
# 2s - loss: 0.3563 - val_loss: 0.4304
# Epoch 169/8192
# 5s - loss: 0.3561 - val_loss: 0.4272
# Epoch 170/8192
# 2s - loss: 0.3559 - val_loss: 0.4322
# Epoch 171/8192
# 2s - loss: 0.3557 - val_loss: 0.4312
# Epoch 172/8192
# 5s - loss: 0.3557 - val_loss: 0.4272
# Epoch 173/8192
# 2s - loss: 0.3554 - val_loss: 0.4273
# Epoch 174/8192
# 2s - loss: 0.3552 - val_loss: 0.4310
# Epoch 175/8192
# 2s - loss: 0.3550 - val_loss: 0.4321
# Epoch 176/8192
# 2s - loss: 0.3550 - val_loss: 0.4277
# Epoch 177/8192
# 5s - loss: 0.3548 - val_loss: 0.4254
# Epoch 178/8192
# 2s - loss: 0.3546 - val_loss: 0.4281
# Epoch 179/8192
# 2s - loss: 0.3545 - val_loss: 0.4290
# Epoch 180/8192
# 2s - loss: 0.3543 - val_loss: 0.4260
# Epoch 181/8192
# 5s - loss: 0.3542 - val_loss: 0.4250
# Epoch 182/8192
# 2s - loss: 0.3539 - val_loss: 0.4288
# Epoch 183/8192
# 2s - loss: 0.3539 - val_loss: 0.4286
# Epoch 184/8192
# 2s - loss: 0.3538 - val_loss: 0.4259
# Epoch 185/8192
# 5s - loss: 0.3537 - val_loss: 0.4220
# Epoch 186/8192
# 2s - loss: 0.3535 - val_loss: 0.4268
# Epoch 187/8192
# 2s - loss: 0.3533 - val_loss: 0.4273
# Epoch 188/8192
# 2s - loss: 0.3534 - val_loss: 0.4241
# Epoch 189/8192
# 2s - loss: 0.3532 - val_loss: 0.4231
# Epoch 190/8192
# 2s - loss: 0.3530 - val_loss: 0.4264
# Epoch 191/8192
# 2s - loss: 0.3528 - val_loss: 0.4268
# Epoch 192/8192
# 2s - loss: 0.3528 - val_loss: 0.4245
# Epoch 193/8192
# 4s - loss: 0.3529 - val_loss: 0.4218
# Epoch 194/8192
# 2s - loss: 0.3525 - val_loss: 0.4261
# Epoch 195/8192
# 2s - loss: 0.3526 - val_loss: 0.4253
# Epoch 196/8192
# 2s - loss: 0.3525 - val_loss: 0.4233
# Epoch 197/8192
# 2s - loss: 0.3524 - val_loss: 0.4221
# Epoch 198/8192
# 2s - loss: 0.3521 - val_loss: 0.4267
# Epoch 199/8192
# 2s - loss: 0.3521 - val_loss: 0.4267
# Epoch 200/8192
# 2s - loss: 0.3521 - val_loss: 0.4251
# Epoch 201/8192
# 5s - loss: 0.3520 - val_loss: 0.4210
# Epoch 202/8192
# 2s - loss: 0.3519 - val_loss: 0.4242
# Epoch 203/8192
# 2s - loss: 0.3518 - val_loss: 0.4254
# Epoch 204/8192
# 2s - loss: 0.3519 - val_loss: 0.4224
# Epoch 205/8192
# 2s - loss: 0.3516 - val_loss: 0.4223
# Epoch 206/8192
# 2s - loss: 0.3516 - val_loss: 0.4252
# Epoch 207/8192
# 2s - loss: 0.3515 - val_loss: 0.4270
# Epoch 208/8192
# 2s - loss: 0.3515 - val_loss: 0.4224
# Epoch 209/8192
# 4s - loss: 0.3515 - val_loss: 0.4198
# Epoch 210/8192
# 2s - loss: 0.3512 - val_loss: 0.4238
# Epoch 211/8192
# 2s - loss: 0.3512 - val_loss: 0.4256
# Epoch 212/8192
# 2s - loss: 0.3512 - val_loss: 0.4222
# Epoch 213/8192
# 2s - loss: 0.3511 - val_loss: 0.4201
# Epoch 214/8192
# 2s - loss: 0.3509 - val_loss: 0.4247
# Epoch 215/8192
# 3s - loss: 0.3509 - val_loss: 0.4246
# Epoch 216/8192
# 3s - loss: 0.3510 - val_loss: 0.4223
# Epoch 217/8192
# 5s - loss: 0.3508 - val_loss: 0.4191
# Epoch 218/8192
# 2s - loss: 0.3507 - val_loss: 0.4233
# Epoch 219/8192
# 2s - loss: 0.3506 - val_loss: 0.4234
# Epoch 220/8192
# 2s - loss: 0.3507 - val_loss: 0.4200
# Epoch 221/8192
# 2s - loss: 0.3505 - val_loss: 0.4194
# Epoch 222/8192
# 3s - loss: 0.3504 - val_loss: 0.4243
# Epoch 223/8192
# 2s - loss: 0.3504 - val_loss: 0.4253
# Epoch 224/8192
# 2s - loss: 0.3503 - val_loss: 0.4223
# Epoch 225/8192
# 5s - loss: 0.3504 - val_loss: 0.4176
# Epoch 226/8192
# 2s - loss: 0.3501 - val_loss: 0.4228
# Epoch 227/8192
# 2s - loss: 0.3502 - val_loss: 0.4233
# Epoch 228/8192
# 2s - loss: 0.3501 - val_loss: 0.4211
# Epoch 229/8192
# 2s - loss: 0.3500 - val_loss: 0.4196
# Epoch 230/8192
# 2s - loss: 0.3499 - val_loss: 0.4250
# Epoch 231/8192
# 2s - loss: 0.3498 - val_loss: 0.4246
# Epoch 232/8192
# 2s - loss: 0.3500 - val_loss: 0.4209
# Epoch 233/8192
# 2s - loss: 0.3497 - val_loss: 0.4183
# Epoch 234/8192
# 2s - loss: 0.3497 - val_loss: 0.4226
# Epoch 235/8192
# 2s - loss: 0.3496 - val_loss: 0.4237
# Epoch 236/8192
# 2s - loss: 0.3497 - val_loss: 0.4199
# Epoch 237/8192
# 2s - loss: 0.3496 - val_loss: 0.4201
# Epoch 238/8192
# 2s - loss: 0.3493 - val_loss: 0.4228
# Epoch 239/8192
# 2s - loss: 0.3495 - val_loss: 0.4239
# Epoch 240/8192
# 2s - loss: 0.3493 - val_loss: 0.4208
# Epoch 241/8192
# 2s - loss: 0.3494 - val_loss: 0.4182
# Epoch 242/8192
# 2s - loss: 0.3491 - val_loss: 0.4219
# Epoch 243/8192
# 2s - loss: 0.3492 - val_loss: 0.4218
# Epoch 244/8192
# 2s - loss: 0.3492 - val_loss: 0.4193
# Epoch 245/8192
# 2s - loss: 0.3490 - val_loss: 0.4177
# Epoch 246/8192
# 2s - loss: 0.3490 - val_loss: 0.4223
# Epoch 247/8192
# 2s - loss: 0.3488 - val_loss: 0.4233
# Epoch 248/8192
# 2s - loss: 0.3490 - val_loss: 0.4203
# Epoch 249/8192
# 5s - loss: 0.3489 - val_loss: 0.4167
# Epoch 250/8192
# 2s - loss: 0.3488 - val_loss: 0.4201
# Epoch 251/8192
# 2s - loss: 0.3486 - val_loss: 0.4210
# Epoch 252/8192
# 2s - loss: 0.3487 - val_loss: 0.4186
# Epoch 253/8192
# 2s - loss: 0.3486 - val_loss: 0.4186
# Epoch 254/8192
# 2s - loss: 0.3483 - val_loss: 0.4229
# Epoch 255/8192
# 2s - loss: 0.3485 - val_loss: 0.4215
# Epoch 256/8192
# 2s - loss: 0.3484 - val_loss: 0.4196
# Epoch 257/8192
# 4s - loss: 0.3484 - val_loss: 0.4163
# Epoch 258/8192
# 2s - loss: 0.3482 - val_loss: 0.4212
# Epoch 259/8192
# 2s - loss: 0.3482 - val_loss: 0.4213
# Epoch 260/8192
# 2s - loss: 0.3482 - val_loss: 0.4195
# Epoch 261/8192
# 2s - loss: 0.3481 - val_loss: 0.4177
# Epoch 262/8192
# 2s - loss: 0.3481 - val_loss: 0.4210
# Epoch 263/8192
# 2s - loss: 0.3479 - val_loss: 0.4225
# Epoch 264/8192
# 2s - loss: 0.3480 - val_loss: 0.4197
# Epoch 265/8192
# 2s - loss: 0.3479 - val_loss: 0.4165
# Epoch 266/8192
# 2s - loss: 0.3478 - val_loss: 0.4198
# Epoch 267/8192
# 2s - loss: 0.3477 - val_loss: 0.4216
# Epoch 268/8192
# 2s - loss: 0.3477 - val_loss: 0.4175
# Epoch 269/8192
# 2s - loss: 0.3478 - val_loss: 0.4170
# Epoch 270/8192
# 2s - loss: 0.3474 - val_loss: 0.4213
# Epoch 271/8192
# 2s - loss: 0.3475 - val_loss: 0.4224
# Epoch 272/8192
# 2s - loss: 0.3475 - val_loss: 0.4194
# Epoch 273/8192
# 6s - loss: 0.3475 - val_loss: 0.4151
# Epoch 274/8192
# 2s - loss: 0.3473 - val_loss: 0.4195
# Epoch 275/8192
# 2s - loss: 0.3473 - val_loss: 0.4191
# Epoch 276/8192
# 2s - loss: 0.3474 - val_loss: 0.4169
# Epoch 277/8192
# 2s - loss: 0.3471 - val_loss: 0.4161
# Epoch 278/8192
# 3s - loss: 0.3472 - val_loss: 0.4205
# Epoch 279/8192
# 2s - loss: 0.3470 - val_loss: 0.4211
# Epoch 280/8192
# 2s - loss: 0.3472 - val_loss: 0.4172
# Epoch 281/8192
# 5s - loss: 0.3470 - val_loss: 0.4149
# Epoch 282/8192
# 2s - loss: 0.3469 - val_loss: 0.4192
# Epoch 283/8192
# 3s - loss: 0.3469 - val_loss: 0.4204
# Epoch 284/8192
# 2s - loss: 0.3468 - val_loss: 0.4176
# Epoch 285/8192
# 3s - loss: 0.3469 - val_loss: 0.4154
# Epoch 286/8192
# 2s - loss: 0.3466 - val_loss: 0.4198
# Epoch 287/8192
# 2s - loss: 0.3467 - val_loss: 0.4200
# Epoch 288/8192
# 2s - loss: 0.3467 - val_loss: 0.4182
# Epoch 289/8192
# 2s - loss: 0.3466 - val_loss: 0.4149
# Epoch 290/8192
# 2s - loss: 0.3465 - val_loss: 0.4197
# Epoch 291/8192
# 2s - loss: 0.3464 - val_loss: 0.4196
# Epoch 292/8192
# 2s - loss: 0.3466 - val_loss: 0.4156
# Epoch 293/8192
# 2s - loss: 0.3464 - val_loss: 0.4156
# Epoch 294/8192
# 2s - loss: 0.3463 - val_loss: 0.4199
# Epoch 295/8192
# 2s - loss: 0.3462 - val_loss: 0.4215
# Epoch 296/8192
# 2s - loss: 0.3463 - val_loss: 0.4173
# Epoch 297/8192
# 2s - loss: 0.3463 - val_loss: 0.4150
# Epoch 298/8192
# 2s - loss: 0.3461 - val_loss: 0.4178
# Epoch 299/8192
# 2s - loss: 0.3461 - val_loss: 0.4191
# Epoch 300/8192
# 2s - loss: 0.3460 - val_loss: 0.4160
# Epoch 301/8192
# 2s - loss: 0.3460 - val_loss: 0.4157
# Epoch 302/8192
# 2s - loss: 0.3459 - val_loss: 0.4195
# Epoch 303/8192
# 2s - loss: 0.3459 - val_loss: 0.4189
# Epoch 304/8192
# 2s - loss: 0.3459 - val_loss: 0.4170
# Epoch 305/8192
# 5s - loss: 0.3459 - val_loss: 0.4132
# Epoch 306/8192
# 2s - loss: 0.3458 - val_loss: 0.4179
# Epoch 307/8192
# 2s - loss: 0.3456 - val_loss: 0.4184
# Epoch 308/8192
# 2s - loss: 0.3458 - val_loss: 0.4155
# Epoch 309/8192
# 2s - loss: 0.3456 - val_loss: 0.4141
# Epoch 310/8192
# 2s - loss: 0.3456 - val_loss: 0.4180
# Epoch 311/8192
# 2s - loss: 0.3455 - val_loss: 0.4190
# Epoch 312/8192
# 2s - loss: 0.3455 - val_loss: 0.4166
# Epoch 313/8192
# 2s - loss: 0.3455 - val_loss: 0.4139
# Epoch 314/8192
# 2s - loss: 0.3453 - val_loss: 0.4185
# Epoch 315/8192
# 2s - loss: 0.3454 - val_loss: 0.4171
# Epoch 316/8192
# 2s - loss: 0.3453 - val_loss: 0.4153
# Epoch 317/8192
# 2s - loss: 0.3453 - val_loss: 0.4137
# Epoch 318/8192
# 2s - loss: 0.3451 - val_loss: 0.4187
# Epoch 319/8192
# 2s - loss: 0.3451 - val_loss: 0.4191
# Epoch 320/8192
# 2s - loss: 0.3452 - val_loss: 0.4173
# Epoch 321/8192
# 2s - loss: 0.3451 - val_loss: 0.4137
# Epoch 322/8192
# 2s - loss: 0.3451 - val_loss: 0.4165
# Epoch 323/8192
# 2s - loss: 0.3449 - val_loss: 0.4182
# Epoch 324/8192
# 2s - loss: 0.3451 - val_loss: 0.4152
# Epoch 325/8192
# 2s - loss: 0.3449 - val_loss: 0.4147
# Epoch 326/8192
# 2s - loss: 0.3448 - val_loss: 0.4177
# Epoch 327/8192
# 2s - loss: 0.3447 - val_loss: 0.4196
# Epoch 328/8192
# 2s - loss: 0.3448 - val_loss: 0.4153
# Epoch 329/8192
# 5s - loss: 0.3449 - val_loss: 0.4126
# Epoch 330/8192
# 2s - loss: 0.3446 - val_loss: 0.4166
# Epoch 331/8192
# 2s - loss: 0.3447 - val_loss: 0.4185
# Epoch 332/8192
# 2s - loss: 0.3447 - val_loss: 0.4148
# Epoch 333/8192
# 2s - loss: 0.3446 - val_loss: 0.4133
# Epoch 334/8192
# 2s - loss: 0.3444 - val_loss: 0.4172
# Epoch 335/8192
# 2s - loss: 0.3444 - val_loss: 0.4172
# Epoch 336/8192
# 2s - loss: 0.3445 - val_loss: 0.4149
# Epoch 337/8192
# 4s - loss: 0.3444 - val_loss: 0.4126
# Epoch 338/8192
# 2s - loss: 0.3444 - val_loss: 0.4166
# Epoch 339/8192
# 2s - loss: 0.3443 - val_loss: 0.4165
# Epoch 340/8192
# 2s - loss: 0.3444 - val_loss: 0.4132
# Epoch 341/8192
# 2s - loss: 0.3442 - val_loss: 0.4127
# Epoch 342/8192
# 2s - loss: 0.3441 - val_loss: 0.4173
# Epoch 343/8192
# 2s - loss: 0.3441 - val_loss: 0.4186
# Epoch 344/8192
# 2s - loss: 0.3441 - val_loss: 0.4160
# Epoch 345/8192
# 4s - loss: 0.3442 - val_loss: 0.4107
# Epoch 346/8192
# 2s - loss: 0.3439 - val_loss: 0.4159
# Epoch 347/8192
# 2s - loss: 0.3440 - val_loss: 0.4163
# Epoch 348/8192
# 2s - loss: 0.3440 - val_loss: 0.4144
# Epoch 349/8192
# 2s - loss: 0.3439 - val_loss: 0.4126
# Epoch 350/8192
# 2s - loss: 0.3438 - val_loss: 0.4178
# Epoch 351/8192
# 2s - loss: 0.3437 - val_loss: 0.4178
# Epoch 352/8192
# 2s - loss: 0.3439 - val_loss: 0.4141
# Epoch 353/8192
# 2s - loss: 0.3437 - val_loss: 0.4122
# Epoch 354/8192
# 2s - loss: 0.3437 - val_loss: 0.4162
# Epoch 355/8192
# 2s - loss: 0.3436 - val_loss: 0.4173
# Epoch 356/8192
# 2s - loss: 0.3437 - val_loss: 0.4137
# Epoch 357/8192
# 2s - loss: 0.3437 - val_loss: 0.4134
# Epoch 358/8192
# 2s - loss: 0.3435 - val_loss: 0.4161
# Epoch 359/8192
# 2s - loss: 0.3435 - val_loss: 0.4170
# Epoch 360/8192
# 2s - loss: 0.3435 - val_loss: 0.4142
# Epoch 361/8192
# 2s - loss: 0.3436 - val_loss: 0.4117
# Epoch 362/8192
# 2s - loss: 0.3433 - val_loss: 0.4156
# Epoch 363/8192
# 2s - loss: 0.3435 - val_loss: 0.4159
# Epoch 364/8192
# 2s - loss: 0.3435 - val_loss: 0.4130
# Epoch 365/8192
# 2s - loss: 0.3433 - val_loss: 0.4115
# Epoch 366/8192
# 2s - loss: 0.3432 - val_loss: 0.4162
# Epoch 367/8192
# 2s - loss: 0.3431 - val_loss: 0.4170
# Epoch 368/8192
# 2s - loss: 0.3433 - val_loss: 0.4138
# Epoch 369/8192
# 2s - loss: 0.3432 - val_loss: 0.4110
# Epoch 370/8192
# 2s - loss: 0.3431 - val_loss: 0.4146
# Epoch 371/8192
# 2s - loss: 0.3431 - val_loss: 0.4152
# Epoch 372/8192
# 2s - loss: 0.3431 - val_loss: 0.4128
# Epoch 373/8192
# 2s - loss: 0.3431 - val_loss: 0.4127
# Epoch 374/8192
# 2s - loss: 0.3429 - val_loss: 0.4167
# Epoch 375/8192
# 2s - loss: 0.3430 - val_loss: 0.4157
# Epoch 376/8192
# 2s - loss: 0.3429 - val_loss: 0.4137
# Epoch 377/8192
# 5s - loss: 0.3430 - val_loss: 0.4104
# Epoch 378/8192
# 2s - loss: 0.3428 - val_loss: 0.4151
# Epoch 379/8192
# 2s - loss: 0.3428 - val_loss: 0.4158
# Epoch 380/8192
# 2s - loss: 0.3429 - val_loss: 0.4141
# Epoch 381/8192
# 2s - loss: 0.3429 - val_loss: 0.4117
# Epoch 382/8192
# 2s - loss: 0.3427 - val_loss: 0.4153
# Epoch 383/8192
# 2s - loss: 0.3426 - val_loss: 0.4169
# Epoch 384/8192
# 2s - loss: 0.3427 - val_loss: 0.4138
# Epoch 385/8192
# 2s - loss: 0.3426 - val_loss: 0.4113
# Epoch 386/8192
# 2s - loss: 0.3426 - val_loss: 0.4146
# Epoch 387/8192
# 2s - loss: 0.3425 - val_loss: 0.4159
# Epoch 388/8192
# 2s - loss: 0.3426 - val_loss: 0.4119
# Epoch 389/8192
# 2s - loss: 0.3426 - val_loss: 0.4115
# Epoch 390/8192
# 2s - loss: 0.3423 - val_loss: 0.4158
# Epoch 391/8192
# 2s - loss: 0.3424 - val_loss: 0.4166
# Epoch 392/8192
# 2s - loss: 0.3424 - val_loss: 0.4137
# Epoch 393/8192
# 4s - loss: 0.3425 - val_loss: 0.4099
# Epoch 394/8192
# 2s - loss: 0.3423 - val_loss: 0.4142
# Epoch 395/8192
# 2s - loss: 0.3422 - val_loss: 0.4144
# Epoch 396/8192
# 2s - loss: 0.3424 - val_loss: 0.4121
# Epoch 397/8192
# 2s - loss: 0.3422 - val_loss: 0.4110
# Epoch 398/8192
# 2s - loss: 0.3422 - val_loss: 0.4155
# Epoch 399/8192
# 2s - loss: 0.3421 - val_loss: 0.4156
# Epoch 400/8192
# 3s - loss: 0.3422 - val_loss: 0.4122
# Epoch 401/8192
# 5s - loss: 0.3421 - val_loss: 0.4091
# Epoch 402/8192
# 2s - loss: 0.3420 - val_loss: 0.4141
# Epoch 403/8192
# 2s - loss: 0.3421 - val_loss: 0.4154
# Epoch 404/8192
# 2s - loss: 0.3421 - val_loss: 0.4124
# Epoch 405/8192
# 2s - loss: 0.3421 - val_loss: 0.4106
# Epoch 406/8192
# 2s - loss: 0.3419 - val_loss: 0.4151
# Epoch 407/8192
# 2s - loss: 0.3420 - val_loss: 0.4153
# Epoch 408/8192
# 2s - loss: 0.3419 - val_loss: 0.4134
# Epoch 409/8192
# 2s - loss: 0.3419 - val_loss: 0.4099
# Epoch 410/8192
# 3s - loss: 0.3418 - val_loss: 0.4148
# Epoch 411/8192
# 2s - loss: 0.3417 - val_loss: 0.4148
# Epoch 412/8192
# 2s - loss: 0.3419 - val_loss: 0.4115
# Epoch 413/8192
# 2s - loss: 0.3417 - val_loss: 0.4108
# Epoch 414/8192
# 2s - loss: 0.3417 - val_loss: 0.4152
# Epoch 415/8192
# 2s - loss: 0.3416 - val_loss: 0.4168
# Epoch 416/8192
# 2s - loss: 0.3417 - val_loss: 0.4127
# Epoch 417/8192
# 2s - loss: 0.3417 - val_loss: 0.4103
# Epoch 418/8192
# 2s - loss: 0.3415 - val_loss: 0.4131
# Epoch 419/8192
# 2s - loss: 0.3416 - val_loss: 0.4141
# Epoch 420/8192
# 2s - loss: 0.3415 - val_loss: 0.4113
# Epoch 421/8192
# 2s - loss: 0.3415 - val_loss: 0.4114
# Epoch 422/8192
# 2s - loss: 0.3414 - val_loss: 0.4151
# Epoch 423/8192
# 2s - loss: 0.3415 - val_loss: 0.4145
# Epoch 424/8192
# 2s - loss: 0.3415 - val_loss: 0.4123
# Epoch 425/8192
# 5s - loss: 0.3414 - val_loss: 0.4089
# Epoch 426/8192
# 3s - loss: 0.3414 - val_loss: 0.4132
# Epoch 427/8192
# 2s - loss: 0.3412 - val_loss: 0.4142
# Epoch 428/8192
# 2s - loss: 0.3414 - val_loss: 0.4113
# Epoch 429/8192
# 2s - loss: 0.3413 - val_loss: 0.4098
# Epoch 430/8192
# 2s - loss: 0.3412 - val_loss: 0.4135
# Epoch 431/8192
# 2s - loss: 0.3412 - val_loss: 0.4145
# Epoch 432/8192
# 2s - loss: 0.3412 - val_loss: 0.4123
# Epoch 433/8192
# 2s - loss: 0.3413 - val_loss: 0.4094
# Epoch 434/8192
# 2s - loss: 0.3410 - val_loss: 0.4135
# Epoch 435/8192
# 2s - loss: 0.3411 - val_loss: 0.4128
# Epoch 436/8192
# 2s - loss: 0.3411 - val_loss: 0.4107
# Epoch 437/8192
# 2s - loss: 0.3411 - val_loss: 0.4099
# Epoch 438/8192
# 2s - loss: 0.3409 - val_loss: 0.4148
# Epoch 439/8192
# 2s - loss: 0.3409 - val_loss: 0.4148
# Epoch 440/8192
# 2s - loss: 0.3410 - val_loss: 0.4132
# Epoch 441/8192
# 2s - loss: 0.3410 - val_loss: 0.4093
# Epoch 442/8192
# 2s - loss: 0.3409 - val_loss: 0.4125
# Epoch 443/8192
# 2s - loss: 0.3408 - val_loss: 0.4136
# Epoch 444/8192
# 2s - loss: 0.3409 - val_loss: 0.4110
# Epoch 445/8192
# 2s - loss: 0.3407 - val_loss: 0.4105
# Epoch 446/8192
# 2s - loss: 0.3409 - val_loss: 0.4138
# Epoch 447/8192
# 2s - loss: 0.3407 - val_loss: 0.4154
# Epoch 448/8192
# 2s - loss: 0.3408 - val_loss: 0.4113
# Epoch 449/8192
# 5s - loss: 0.3408 - val_loss: 0.4087
# Epoch 450/8192
# 2s - loss: 0.3405 - val_loss: 0.4127
# Epoch 451/8192
# 2s - loss: 0.3406 - val_loss: 0.4137
# Epoch 452/8192
# 2s - loss: 0.3406 - val_loss: 0.4108
# Epoch 453/8192
# 2s - loss: 0.3406 - val_loss: 0.4090
# Epoch 454/8192
# 2s - loss: 0.3404 - val_loss: 0.4136
# Epoch 455/8192
# 2s - loss: 0.3405 - val_loss: 0.4131
# Epoch 456/8192
# 2s - loss: 0.3407 - val_loss: 0.4110
# Epoch 457/8192
# 5s - loss: 0.3404 - val_loss: 0.4084
# Epoch 458/8192
# 2s - loss: 0.3404 - val_loss: 0.4125
# Epoch 459/8192
# 2s - loss: 0.3403 - val_loss: 0.4124
# Epoch 460/8192
# 2s - loss: 0.3404 - val_loss: 0.4091
# Epoch 461/8192
# 2s - loss: 0.3402 - val_loss: 0.4086
# Epoch 462/8192
# 3s - loss: 0.3401 - val_loss: 0.4130
# Epoch 463/8192
# 2s - loss: 0.3401 - val_loss: 0.4145
# Epoch 464/8192
# 2s - loss: 0.3401 - val_loss: 0.4119
# Epoch 465/8192
# 5s - loss: 0.3403 - val_loss: 0.4072
# Epoch 466/8192
# 2s - loss: 0.3400 - val_loss: 0.4119
# Epoch 467/8192
# 2s - loss: 0.3401 - val_loss: 0.4126
# Epoch 468/8192
# 2s - loss: 0.3401 - val_loss: 0.4101
# Epoch 469/8192
# 2s - loss: 0.3400 - val_loss: 0.4087
# Epoch 470/8192
# 2s - loss: 0.3399 - val_loss: 0.4139
# Epoch 471/8192
# 2s - loss: 0.3399 - val_loss: 0.4136
# Epoch 472/8192
# 2s - loss: 0.3401 - val_loss: 0.4101
# Epoch 473/8192
# 2s - loss: 0.3399 - val_loss: 0.4080
# Epoch 474/8192
# 2s - loss: 0.3398 - val_loss: 0.4124
# Epoch 475/8192
# 2s - loss: 0.3398 - val_loss: 0.4131
# Epoch 476/8192
# 2s - loss: 0.3399 - val_loss: 0.4092
# Epoch 477/8192
# 2s - loss: 0.3398 - val_loss: 0.4092
# Epoch 478/8192
# 2s - loss: 0.3396 - val_loss: 0.4121
# Epoch 479/8192
# 2s - loss: 0.3397 - val_loss: 0.4132
# Epoch 480/8192
# 2s - loss: 0.3397 - val_loss: 0.4105
# Epoch 481/8192
# 2s - loss: 0.3398 - val_loss: 0.4080
# Epoch 482/8192
# 2s - loss: 0.3396 - val_loss: 0.4117
# Epoch 483/8192
# 2s - loss: 0.3396 - val_loss: 0.4115
# Epoch 484/8192
# 2s - loss: 0.3396 - val_loss: 0.4091
# Epoch 485/8192
# 5s - loss: 0.3395 - val_loss: 0.4071
# Epoch 486/8192
# 2s - loss: 0.3395 - val_loss: 0.4122
# Epoch 487/8192
# 2s - loss: 0.3393 - val_loss: 0.4128
# Epoch 488/8192
# 2s - loss: 0.3395 - val_loss: 0.4102
# Epoch 489/8192
# 5s - loss: 0.3394 - val_loss: 0.4068
# Epoch 490/8192
# 2s - loss: 0.3394 - val_loss: 0.4105
# Epoch 491/8192
# 2s - loss: 0.3393 - val_loss: 0.4111
# Epoch 492/8192
# 2s - loss: 0.3393 - val_loss: 0.4088
# Epoch 493/8192
# 2s - loss: 0.3393 - val_loss: 0.4085
# Epoch 494/8192
# 2s - loss: 0.3391 - val_loss: 0.4125
# Epoch 495/8192
# 2s - loss: 0.3392 - val_loss: 0.4116
# Epoch 496/8192
# 2s - loss: 0.3392 - val_loss: 0.4096
# Epoch 497/8192
# 5s - loss: 0.3392 - val_loss: 0.4065
# Epoch 498/8192
# 2s - loss: 0.3391 - val_loss: 0.4113
# Epoch 499/8192
# 2s - loss: 0.3390 - val_loss: 0.4117
# Epoch 500/8192
# 2s - loss: 0.3391 - val_loss: 0.4097
# Epoch 501/8192
# 2s - loss: 0.3390 - val_loss: 0.4079
# Epoch 502/8192
# 2s - loss: 0.3390 - val_loss: 0.4108
# Epoch 503/8192
# 2s - loss: 0.3388 - val_loss: 0.4124
# Epoch 504/8192
# 2s - loss: 0.3390 - val_loss: 0.4096
# Epoch 505/8192
# 2s - loss: 0.3390 - val_loss: 0.4074
# Epoch 506/8192
# 2s - loss: 0.3388 - val_loss: 0.4103
# Epoch 507/8192
# 3s - loss: 0.3388 - val_loss: 0.4116
# Epoch 508/8192
# 2s - loss: 0.3388 - val_loss: 0.4077
# Epoch 509/8192
# 2s - loss: 0.3388 - val_loss: 0.4073
# Epoch 510/8192
# 2s - loss: 0.3386 - val_loss: 0.4113
# Epoch 511/8192
# 2s - loss: 0.3387 - val_loss: 0.4124
# Epoch 512/8192
# 2s - loss: 0.3387 - val_loss: 0.4095
# Epoch 513/8192
# 5s - loss: 0.3387 - val_loss: 0.4056
# Epoch 514/8192
# 2s - loss: 0.3386 - val_loss: 0.4100
# Epoch 515/8192
# 2s - loss: 0.3386 - val_loss: 0.4102
# Epoch 516/8192
# 2s - loss: 0.3387 - val_loss: 0.4079
# Epoch 517/8192
# 2s - loss: 0.3385 - val_loss: 0.4066
# Epoch 518/8192
# 2s - loss: 0.3384 - val_loss: 0.4107
# Epoch 519/8192
# 2s - loss: 0.3383 - val_loss: 0.4110
# Epoch 520/8192
# 2s - loss: 0.3385 - val_loss: 0.4079
# Epoch 521/8192
# 5s - loss: 0.3384 - val_loss: 0.4053
# Epoch 522/8192
# 2s - loss: 0.3383 - val_loss: 0.4100
# Epoch 523/8192
# 2s - loss: 0.3384 - val_loss: 0.4110
# Epoch 524/8192
# 3s - loss: 0.3383 - val_loss: 0.4085
# Epoch 525/8192
# 2s - loss: 0.3384 - val_loss: 0.4056
# Epoch 526/8192
# 2s - loss: 0.3382 - val_loss: 0.4105
# Epoch 527/8192
# 2s - loss: 0.3382 - val_loss: 0.4106
# Epoch 528/8192
# 2s - loss: 0.3382 - val_loss: 0.4084
# Epoch 529/8192
# 20s - loss: 0.3382 - val_loss: 0.4052
# Epoch 530/8192
# 2s - loss: 0.3381 - val_loss: 0.4106
# Epoch 531/8192
# 2s - loss: 0.3381 - val_loss: 0.4106
# Epoch 532/8192
# 2s - loss: 0.3382 - val_loss: 0.4067
# Epoch 533/8192
# 2s - loss: 0.3380 - val_loss: 0.4070
# Epoch 534/8192
# 2s - loss: 0.3382 - val_loss: 0.4107
# Epoch 535/8192
# 2s - loss: 0.3380 - val_loss: 0.4117
# Epoch 536/8192
# 2s - loss: 0.3381 - val_loss: 0.4078
# Epoch 537/8192
# 2s - loss: 0.3380 - val_loss: 0.4061
# Epoch 538/8192
# 2s - loss: 0.3379 - val_loss: 0.4087
# Epoch 539/8192
# 2s - loss: 0.3380 - val_loss: 0.4095
# Epoch 540/8192
# 2s - loss: 0.3379 - val_loss: 0.4070
# Epoch 541/8192
# 2s - loss: 0.3379 - val_loss: 0.4066
# Epoch 542/8192
# 2s - loss: 0.3377 - val_loss: 0.4101
# Epoch 543/8192
# 2s - loss: 0.3378 - val_loss: 0.4100
# Epoch 544/8192
# 2s - loss: 0.3378 - val_loss: 0.4076
# Epoch 545/8192
# 5s - loss: 0.3377 - val_loss: 0.4040
# Epoch 546/8192
# 2s - loss: 0.3377 - val_loss: 0.4088
# Epoch 547/8192
# 2s - loss: 0.3377 - val_loss: 0.4100
# Epoch 548/8192
# 2s - loss: 0.3378 - val_loss: 0.4069
# Epoch 549/8192
# 2s - loss: 0.3376 - val_loss: 0.4053
# Epoch 550/8192
# 2s - loss: 0.3376 - val_loss: 0.4088
# Epoch 551/8192
# 2s - loss: 0.3376 - val_loss: 0.4099
# Epoch 552/8192
# 2s - loss: 0.3376 - val_loss: 0.4074
# Epoch 553/8192
# 2s - loss: 0.3376 - val_loss: 0.4050
# Epoch 554/8192
# 2s - loss: 0.3374 - val_loss: 0.4092
# Epoch 555/8192
# 2s - loss: 0.3376 - val_loss: 0.4081
# Epoch 556/8192
# 2s - loss: 0.3375 - val_loss: 0.4064
# Epoch 557/8192
# 2s - loss: 0.3375 - val_loss: 0.4052
# Epoch 558/8192
# 3s - loss: 0.3373 - val_loss: 0.4101
# Epoch 559/8192
# 2s - loss: 0.3373 - val_loss: 0.4100
# Epoch 560/8192
# 2s - loss: 0.3375 - val_loss: 0.4084
# Epoch 561/8192
# 2s - loss: 0.3373 - val_loss: 0.4045
# Epoch 562/8192
# 2s - loss: 0.3373 - val_loss: 0.4078
# Epoch 563/8192
# 2s - loss: 0.3373 - val_loss: 0.4094
# Epoch 564/8192
# 2s - loss: 0.3374 - val_loss: 0.4066
# Epoch 565/8192
# 2s - loss: 0.3373 - val_loss: 0.4058
# Epoch 566/8192
# 2s - loss: 0.3372 - val_loss: 0.4094
# Epoch 567/8192
# 2s - loss: 0.3372 - val_loss: 0.4104
# Epoch 568/8192
# 2s - loss: 0.3373 - val_loss: 0.4066
# Epoch 569/8192
# 5s - loss: 0.3373 - val_loss: 0.4040
# Epoch 570/8192
# 2s - loss: 0.3370 - val_loss: 0.4081
# Epoch 571/8192
# 2s - loss: 0.3371 - val_loss: 0.4092
# Epoch 572/8192
# 2s - loss: 0.3371 - val_loss: 0.4064
# Epoch 573/8192
# 2s - loss: 0.3372 - val_loss: 0.4048
# Epoch 574/8192
# 2s - loss: 0.3370 - val_loss: 0.4087
# Epoch 575/8192
# 3s - loss: 0.3370 - val_loss: 0.4089
# Epoch 576/8192
# 2s - loss: 0.3371 - val_loss: 0.4066
# Epoch 577/8192
# 5s - loss: 0.3370 - val_loss: 0.4038
# Epoch 578/8192
# 2s - loss: 0.3369 - val_loss: 0.4078
# Epoch 579/8192
# 2s - loss: 0.3369 - val_loss: 0.4083
# Epoch 580/8192
# 2s - loss: 0.3370 - val_loss: 0.4051
# Epoch 581/8192
# 2s - loss: 0.3369 - val_loss: 0.4042
# Epoch 582/8192
# 2s - loss: 0.3368 - val_loss: 0.4085
# Epoch 583/8192
# 2s - loss: 0.3369 - val_loss: 0.4104
# Epoch 584/8192
# 2s - loss: 0.3370 - val_loss: 0.4071
# Epoch 585/8192
# 5s - loss: 0.3370 - val_loss: 0.4030
# Epoch 586/8192
# 2s - loss: 0.3368 - val_loss: 0.4073
# Epoch 587/8192
# 2s - loss: 0.3368 - val_loss: 0.4078
# Epoch 588/8192
# 2s - loss: 0.3368 - val_loss: 0.4060
# Epoch 589/8192
# 2s - loss: 0.3368 - val_loss: 0.4049
# Epoch 590/8192
# 2s - loss: 0.3368 - val_loss: 0.4098
# Epoch 591/8192
# 2s - loss: 0.3366 - val_loss: 0.4095
# Epoch 592/8192
# 2s - loss: 0.3369 - val_loss: 0.4061
# Epoch 593/8192
# 2s - loss: 0.3367 - val_loss: 0.4041
# Epoch 594/8192
# 2s - loss: 0.3366 - val_loss: 0.4078
# Epoch 595/8192
# 2s - loss: 0.3366 - val_loss: 0.4089
# Epoch 596/8192
# 2s - loss: 0.3367 - val_loss: 0.4055
# Epoch 597/8192
# 2s - loss: 0.3366 - val_loss: 0.4049
# Epoch 598/8192
# 2s - loss: 0.3365 - val_loss: 0.4079
# Epoch 599/8192
# 2s - loss: 0.3366 - val_loss: 0.4090
# Epoch 600/8192
# 2s - loss: 0.3365 - val_loss: 0.4065
# Epoch 601/8192
# 2s - loss: 0.3366 - val_loss: 0.4037
# Epoch 602/8192
# 2s - loss: 0.3365 - val_loss: 0.4075
# Epoch 603/8192
# 2s - loss: 0.3366 - val_loss: 0.4076
# Epoch 604/8192
# 2s - loss: 0.3365 - val_loss: 0.4051
# Epoch 605/8192
# 2s - loss: 0.3364 - val_loss: 0.4037
# Epoch 606/8192
# 2s - loss: 0.3364 - val_loss: 0.4081
# Epoch 607/8192
# 2s - loss: 0.3363 - val_loss: 0.4088
# Epoch 608/8192
# 2s - loss: 0.3364 - val_loss: 0.4064
# Epoch 609/8192
# 2s - loss: 0.3364 - val_loss: 0.4031
# Epoch 610/8192
# 2s - loss: 0.3363 - val_loss: 0.4064
# Epoch 611/8192
# 2s - loss: 0.3363 - val_loss: 0.4069
# Epoch 612/8192
# 2s - loss: 0.3363 - val_loss: 0.4051
# Epoch 613/8192
# 2s - loss: 0.3363 - val_loss: 0.4045
# Epoch 614/8192
# 2s - loss: 0.3361 - val_loss: 0.4085
# Epoch 615/8192
# 2s - loss: 0.3363 - val_loss: 0.4082
# Epoch 616/8192
# 2s - loss: 0.3363 - val_loss: 0.4059
# Epoch 617/8192
# 2s - loss: 0.3363 - val_loss: 0.4031
# Epoch 618/8192
# 2s - loss: 0.3362 - val_loss: 0.4076
# Epoch 00617: early stopping

# %%
def plot_loss(data, title):
    """Plots the training and validation loss"""
    plt.figure()
    plt.xlabel("Epoch")
    plt.ylabel("Loss")
    plt.title(title)
    plt.plot(data["loss"], linestyle=line_styles[0], color=color_palette["Indigo"][900], linewidth=3)
    plt.plot(data["val_loss"], linestyle=line_styles[2], color=color_palette["Teal"][300], linewidth=3)
    plt.legend(["Train", "Validation"], loc="upper right", frameon=False)
    plt.yscale("log")
    plt.show();

plot_loss(history, "Original model loss")

# %%
# Reload saved model

autoencoder = load_model("%s%s.h5" % (model_directory, model_name))

# %%
# Run predictions

predictions = autoencoder.predict(X_test)

# %% [markdown]
# # Calculating Mean Square of features

# %%
mean_square = np.mean(np.power(X_test, 2), axis=1)

# %% [markdown]
# # Evaluation

# %%
legend = [{"name": 'pf_jets', "start": 0, "end": 777, "color": color_palette["Indigo"][100]},
          {"name": 'cal_jet_mets', "start": 778, "end": 946, "color": color_palette["Indigo"][300]},
          {"name": 'pho', "start": 947, "end": 1283, "color": color_palette["Indigo"][500]},
          {"name": 'muons', "start": 1284, "end": 1788, "color": color_palette["Indigo"][700]},
          {"name": 'pf_jets2', "start": 1789, "end": 1894, "color": color_palette["Indigo"][900]},
          {"name": 'pf_mets', "start": 1895, "end": 1923, "color": color_palette["Indigo"][200]},
          {"name": 'nvtx', "start": 1924, "end": 1925, "color": color_palette["Indigo"][400]},
          {"name": 'cal_jet_mets2', "start": 1925, "end": 2037, "color": color_palette["Indigo"][600]},
          {"name": 'sc', "start": 2038, "end": 2129, "color": color_palette["Indigo"][800]},
          {"name": 'cc', "start": 2130, "end": 2172, "color": color_palette["Teal"][100]},
          {"name": 'pho2', "start": 2173, "end": 2369, "color": color_palette["Teal"][300]},
          {"name": 'muons2', "start": 2370, "end": 2476, "color": color_palette["Teal"][500]},
          {"name": 'ebs', "start": 2497, "end": 2707, "color": color_palette["Teal"][700]},
          {"name": 'hbhef', "start": 2708, "end": 2771, "color": color_palette["Teal"][900]},
          {"name": 'presh', "start": 2772, "end": 2810, "color": color_palette["Teal"][400]}]

# %%
# Get error

def get_error_df(X_test, predictions, mode="allmean", n_highest = 100):
    
    if mode == "allmean":
        return np.mean(np.power(X_test - predictions, 2), axis=1)
    
    elif mode == "topn":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.mean(result, axis=1)
    
    elif mode == "perobj":
        mses = []
        for l in legend:
            mse = np.mean(
                np.power(X_test[:,l["start"]:l["end"]] - predictions[:,l["start"]:l["end"]], 2),
                axis=1)
            mses.append(mse)
     
        return np.maximum.reduce(mses)

scores = get_error_df(X_test, predictions, mode="topn")

# %%
#Make ROC_curve

from sklearn.metrics import auc, roc_curve                            

def get_roc_curve(label, score, legend_label):
    """Generates ROC Curves for a given array"""
    fig, ax = plt.subplots()

    fpr, tpr, thresholds = roc_curve(label, score)
    roc_auc = auc(fpr, tpr)
    
    plt.plot(fpr,
             tpr,
             linewidth=3,
             color=color_palette["Indigo"][400],
             linestyle=line_styles[0],
             label=("Autoencoder AUC: %s" % (roc_auc)))
    
    fpr_ms, tpr_ms, thresholds_ms = roc_curve(label, mean_square)
    roc_auc_ms = auc(fpr_ms, tpr_ms)
    
    plt.plot(fpr_ms,
             tpr_ms,
             linewidth=3,
             color=color_palette["Teal"][400],
             linestyle=line_styles[0],
             label=("Mean square AUC: %s" % (roc_auc_ms)))

    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0.5, 1])
    plt.xlim([0, 0.5])
    plt.show();
    
get_roc_curve(y_test.values, scores, "Original autoencoder vs mean square")

# %%
from sklearn.metrics import accuracy_score

def find_optimal_cutoff(y_true, scores):
    step_factor = 1000
    max_acc = 0
    best_threshold = None
    for threshold in tqdm(np.geomspace(min(scores), max(scores), step_factor)):
        y_pred = [1 if e > threshold else 0 for e in scores]
        acc = accuracy_score(y_true, y_pred)
        if acc > max_acc:
            max_acc = acc
            best_threshold = threshold
    return best_threshold, max_acc

ae_cutoff, ae_acc = find_optimal_cutoff(y_test.values, scores)
ms_cutoff, ms_acc = find_optimal_cutoff(y_test.values, mean_square)
# Out:
# 100%|██████████| 1000/1000 [00:48<00:00, 20.73it/s]
# 100%|██████████| 1000/1000 [00:47<00:00, 20.99it/s]

# %%
# Calculate F1 score (2 * (precision * recall) / (precision + recall))

from sklearn.metrics import f1_score

y_pred_ae = [1 if e > ae_cutoff else 0 for e in scores]
ae_f1_score = f1_score(y_test.values, y_pred_ae)

y_pred_ms = [1 if e > ms_cutoff else 0 for e in mean_square]
ms_f1_score = f1_score(y_test.values, y_pred_ms)

print("Autoencoder F1 score:", ae_f1_score)
print("Mean square F1 score:", ms_f1_score)
# Out:
# Autoencoder F1 score: 0.518545192654
# Mean square F1 score: 0.444787644788

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

LABELS = ["Normal", "Anomalous"]

def conf_matrix(scores, threshold, title):
    print("Threshold:", threshold)
    y_pred = [1 if e > threshold else 0 for e in scores]
    conf_matrix = confusion_matrix(y_test.values, y_pred)

    plt.figure(figsize=(12, 12))
    sns.heatmap(conf_matrix, xticklabels=LABELS, yticklabels=LABELS, annot=True, fmt="d");
    plt.title("Confusion matrix")
    plt.ylabel('True class')
    plt.xlabel('Predicted class')
    plt.title(title)
    plt.show()

    acc = accuracy_score(y_test.values, y_pred)
    class_imbal = np.mean(1 - y_test.values)
    adj_acc = (acc - class_imbal) / (1 - class_imbal)

    print("Adjusted accuracy:", adj_acc)

# %%
conf_matrix(scores, ae_cutoff, "Autoencoder")
# Out:
# Threshold: 175.538024554
# Adjusted accuracy: 0.266190998902

# %%
conf_matrix(mean_square, ms_cutoff, "Mean square")
# Out:
# Threshold: 22.3902559057
# Adjusted accuracy: 0.21075740944

# %%
# Plot lumi vs error
def plot_lumi_error(scores, threshold=None):
    fig, ax = plt.subplots()

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 0],
             scores[y_test == 0],
             color=color_palette["Teal"][300],
             linestyle='',
             ms=2,
             marker='o',
             label="Outlier")

    plt.plot(np.array([i for i in range(len(scores))])[y_test == 1],
             scores[y_test == 1],
             color=color_palette["Indigo"][700],
             linestyle='',
             ms=2,
             marker='o',
             label="Inlier")

    ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
    
    ax.set_yscale("log")
    plt.ylabel("Score")
    plt.xlabel("Lumisection #")
    plt.show();

# %%
# Plot lumi vs error AE
plot_lumi_error(scores, ae_cutoff)

# %%
# Plot lumi vs error MS
plot_lumi_error(mean_square, ms_cutoff)

# %%
# Plot something over features
def plot_over_features(array, label, y_low=-20, y_high=20):
    features = [i for i in range(array.shape[0])]

    for l in legend:
        plt.plot(features[l["start"]:l["end"]],
                 array[l["start"]:l["end"]],
                 color=l["color"])

    plt.ylabel(label)
#     plt.ylim([y_low, y_high])
    plt.xticks([l["start"] for l in legend], [l["name"] for l in legend], rotation='vertical')
    plt.show();

# %%
# Choose lumisection
INDEX = 0

# Print label
print("Label:", y_test.values[0])

plot_over_features(X_test[INDEX], "Features values")
plot_over_features(predictions[INDEX], "AE predictions")

reco_error = abs(X_test[INDEX] - predictions[INDEX])
plot_over_features(reco_error, "Difference between features and predictions", 0)

abs_features = abs(X_test[INDEX])
plot_over_features(abs_features, "Absolute features values (AFS)", 0)

plot_over_features(scores, "Reconstruction error (RE)", 0)

# plot_over_features(abs(scores - abs_features), "Features - AFS", 0)
# Out:
# Label: 0
