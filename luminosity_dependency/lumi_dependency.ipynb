# %% [markdown]
# # Luminosity dependency of reconstruction error on split 10/90

# %%
import getpass
import h5py
import matplotlib
import matplotlib.pyplot as plt
import os
import json
import numpy as np
import pandas as pd
import pickle

from tqdm import tqdm
from sklearn.metrics import roc_auc_score

# %%
# %matplotlib inline

matplotlib.rcParams["figure.figsize"] = (16, 8)

# %%
# Make ROC_curve

from sklearn.metrics import auc, roc_curve, roc_auc_score                          

def get_roc_curve(label, scores, names):
    """Generates ROC Curves for a given array"""
    fig, ax = plt.subplots()
    
    for i in range(len(scores)):
        fpr, tpr, thresholds = roc_curve(label, scores[i])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr,
                 tpr,
                 linewidth=3,
                 #linestyle=line_styles[0],
                 label=("%s AUC: %s" % (names[i], roc_auc)))
        
    plt.legend(frameon=False)
    plt.ylabel("Sensitivity (TPR)")
    plt.xlabel("Fall-out (TNR)")
    plt.ylim([0, 1])
    plt.xlim([0, 1])
    plt.title("ROC curves for classifiers")
    plt.show();

# %%
# Get permission to access EOS (Insert your NICE password)

os.system("echo %s | kinit" % getpass.getpass())
# Out:
# ········
# 0

# %%
files_dir_01 = "/eos/user/t/tkrzyzek/autoencoder/lumi_dep/split01/"
files_dir_08 = "/eos/user/t/tkrzyzek/autoencoder/lumi_dep/split08/"
files_dir_single_muon = "/eos/user/t/tkrzyzek/autoencoder/single_muon/"

files_dir = files_dir_single_muon

# %%
ae_pred = pickle.load(open(files_dir + "ae_pred.p", "rb"))

# %%
ae_scores = pickle.load(open(files_dir + "ae_score.p", "rb"))

# %%
#ae_pred_no_reg = pickle.load(open(files_dir + "ae_pred_no_reg.p", "rb"))

# %%
ms_scores = pickle.load(open(files_dir + "ms_score.p", "rb"))
rf_scores = pickle.load(open(files_dir + "rf_score.p", "rb"))
true_labels = pickle.load(open(files_dir + "true_labels.p", "rb"))
luminosity = pickle.load(open(files_dir + "luminosity.p", "rb"))

# %%
# X_test = pickle.load(open(files_dir + "x_test.p", "rb"))

# %%
# true_labels = true_labels[0]
# ms_scores = ms_scores[0]
# rf_scores = rf_scores[0]

# %%
def get_error_df(X_test, predictions, mode="allmean", n_highest = 100):
    
    if mode == "allmean":
        return np.mean(np.power(X_test - predictions, 2), axis=1)
    
    elif mode == "topn":
        temp = np.partition(-np.power(X_test - predictions, 2), n_highest)
        result = -temp[:,:n_highest]
        return np.mean(result, axis=1)
    
    elif mode == "perobj":
        mses = []
        for l in legend:
            mse = np.mean(
                np.power(X_test[:,l["start"]:l["end"]] - predictions[:,l["start"]:l["end"]], 2),
                axis=1)
            mses.append(mse)
     
        return np.maximum.reduce(mses)

# %%
# ae_scores = get_error_df(X_test, ae_pred, mode="topn")
# ae_scores_no_reg = get_error_df(X_test, ae_pred_no_reg, mode="topn")

# %%
names = ["Autoencoder", "Autoencoder wo regularization", "Mean square", "Random forest"]

# %%
inliers = len(X_test[true_labels == 0])
outliers = len(X_test[true_labels == 1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-a8ce6f139ecc> in <module>()
# ----> 1 inliers = len(X_test[true_labels == 0])
#       2 outliers = len(X_test[true_labels == 1])
#
# NameError: name 'X_test' is not defined

# %%
# print("Good lumis:", inliers)
# print("Bad lumis:", outliers)
# print("Ratio of bad lumis:", outliers/len(true_labels))
get_roc_curve(true_labels, [ae_scores, ae_scores_no_reg, ms_scores, rf_scores], names)

# %%
# Index from zero
luminosity = luminosity.reset_index(drop=True)

# %%
def print_lumis():
    lumi_df = pd.DataFrame({'luminosity': luminosity,
                           'true_label': true_labels})
    
    print(lumi_df[start:end].to_string())

# %%
def pred_vs_feature(y_val, x_val, y_class, y_name="", x_name="", selected=[], linear=False,
                    limit=False, title=""):
    '''
    Plots two arbitrary values agains each other.
    '''
    df = pd.DataFrame({'y_val': y_val,
                       'x_val': x_val,
                       'y_class': y_class})

    groups = df.groupby('y_class')
    fig, ax = plt.subplots()

    for name, group in groups:
        ax.plot(group.x_val, 
                group.y_val,
                color="r" if name == 1 else "g",
                marker='o',
                ms=2,
                linestyle='',
                label= "Anomaly" if name == 1 else "Normal")

    for i in selected:
        ax.plot(x_val[i],
                y_val[i],
                color="b",
                marker='o',
                ms=4,
                #alpha=0.1,
                linestyle='')
                 
    ax.legend()
    if not linear:
        ax.set_yscale('log')
    if limit:
        plt.xlim([limit[0], limit[1]])
    plt.grid()
    plt.ylabel(y_name)
    plt.xlabel(x_name)
    plt.title(title)
    plt.show()

# %% [markdown]
# # Luminosity across time

# %%
pred_vs_feature(luminosity, range(len(true_labels)), true_labels, "Luminosity", 
                "Lumisection #", linear=True, title="Luminosity across time")

# %% [markdown]
# # Reconstruction error across time

# %%
pred_vs_feature(ae_scores, range(len(true_labels)), true_labels, "AE reco error", 
                "Lumisection #", title="Autoencoder reconstruction error across time")

# %%
pred_vs_feature(ae_scores_no_reg, range(len(true_labels)), true_labels, "AE reco error", 
                "Lumisection #", title="Autoencoder w/o regularization reconstruction error across time")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-c1a694d72b82> in <module>()
# ----> 1 pred_vs_feature(ae_scores_no_reg, range(len(true_labels)), true_labels, "AE reco error",
#       2                 "Lumisection #", title="Autoencoder w/o regularization reconstruction error across time")
#
# NameError: name 'ae_scores_no_reg' is not defined

# %%
pred_vs_feature(ms_scores, range(len(true_labels)), true_labels, "AE reco error", 
                "Lumisection #", title="Mean square of feature values across time")

# %% [markdown]
# ## Let's try to select lumisections range of the bad lumis cluster. Selected lumisections are marked in green.

# %%
begin = 0
end = 0

lumis_range = range(begin, end)

# %%
pred_vs_feature(ae_scores, range(len(true_labels)), true_labels, "AE reco error", 
                "Lumisection #", selected=lumis_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-8f5ebdf9ecdb> in <module>()
#       1 pred_vs_feature(ae_scores, range(len(true_labels)), true_labels, "AE reco error",
# ----> 2                 "Lumisection #", selected=lumis_range)
#
# NameError: name 'lumis_range' is not defined

# %% [markdown]
# ## Selected lumisections' luminosity (again in green)

# %%
pred_vs_feature(luminosity, range(len(true_labels)), true_labels, "Luminosity", 
                "Lumisection #", linear=True, selected=lumis_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-cf5c76c11e35> in <module>()
#       1 pred_vs_feature(luminosity, range(len(true_labels)), true_labels, "Luminosity",
# ----> 2                 "Lumisection #", linear=True, selected=lumis_range)
#
# NameError: name 'lumis_range' is not defined

# %% [markdown]
# ## Zoom in to the selected range:

# %%
pred_vs_feature(luminosity, range(len(true_labels)), true_labels, "Luminosity", 
                "Lumisection #", linear=True, selected=lumis_range, limit=(begin, end))
# Out:
# /opt/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0, right=0
#   'left=%s, right=%s') % (left, right))

# %% [markdown]
# # Histogram of luminosity of the selected lumisections

# %%
plt.hist(luminosity[begin:end], bins=np.arange(0, 0.4, 0.05))
plt.show()

# %% [markdown]
# # Reconstruction error vs luminosity

# %% [markdown]
# ## AE reconstruction error vs luminosity

# %%
pred_vs_feature(ae_scores, luminosity, true_labels, "AE reco error", "Luminosity", 
                title="Autoencoder reconstruction error across luminosity")

# %%
pred_vs_feature(ae_scores_no_reg, luminosity, true_labels, "AE w/o regularization reco error", 
                "Luminosity", title="Autoencoder w/o regularization reconstruction error across luminosity")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-eb218e588d54> in <module>()
# ----> 1 pred_vs_feature(ae_scores_no_reg, luminosity, true_labels, "AE w/o regularization reco error",
#       2                 "Luminosity", title="Autoencoder w/o regularization reconstruction error across luminosity")
#
# NameError: name 'ae_scores_no_reg' is not defined

# %%
pred_vs_feature(ms_scores, luminosity, true_labels, "Mean square", "Luminosity", 
               title="Mean square of feature values across luminosity")

# %% [markdown]
# ## ... with the cluster selected above marked in green

# %%
pred_vs_feature(ae_scores, luminosity, true_labels, "AE reco error", "Luminosity",
               lumis_range)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-fe14cb77af9a> in <module>()
#       1 pred_vs_feature(ae_scores, luminosity, true_labels, "AE reco error", "Luminosity",
# ----> 2                lumis_range)
#
# NameError: name 'lumis_range' is not defined

# %%
STEP = 0.05
#SAMPLE_SIZE = 2377
SAMPLE_SIZE=100

features_good = []
features_bad = []

good_mean_mean = []
good_mean_median = []
bad_mean_mean = []
bad_mean_median = []

ae_auc_scores = []
ms_auc_scores = []

def plot_mean_features(X, y):
    
    lower_bounds = np.arange(0, 0.35, STEP)
    X_orig = X
    y_orig = y
    
    for i in lower_bounds:
        print("Luminosity range:", i, "-", i+STEP)
        
        X = pd.DataFrame(X_orig)
        
        X = X[(luminosity >= i) & (luminosity < i+STEP)]
        y = y_orig[(luminosity >= i) & (luminosity < i+STEP)]
        print("Dataset size:", len(X))
        
        X = X.iloc[:, 0:2806]
        X_good = X[y == 0]
        X_bad = X[y == 1]

        print("Good samples:", len(X_good))
        print("Bad samples:", len(X_bad))
            
        sample_good = X_good.sample(SAMPLE_SIZE)        
        good_mean = abs(np.mean(sample_good, axis=0))
        good_median = abs(np.median(sample_good, axis=0))
        
        if len(X_bad) > 0:
            ae_auc = roc_auc_score(y, ae_scores[(luminosity >= i) & (luminosity < i+STEP)])
            ae_auc_scores.append(ae_auc)
            print("AE ROC AUC:", ae_auc)

            ms_auc = roc_auc_score(y, ms_scores[(luminosity >= i) & (luminosity < i+STEP)])
            ms_auc_scores.append(ms_auc)
            print("MS ROC AUC:", ms_auc)
        
            bad_sample = X_bad.sample(SAMPLE_SIZE)
            bad_mean = abs(np.mean(bad_sample, axis=0))
            bad_median = abs(np.median(bad_sample, axis=0))
            bad_mean_mean.append(np.mean(bad_mean))
            bad_mean_median.append(np.mean(bad_median))
        else:
            bad_mean_mean.append(0)
            bad_mean_median.append(0)
            
        good_mean_mean.append(np.mean(good_mean))
        good_mean_median.append(np.mean(good_median))

        fig, (ax1, ax2) = plt.subplots(2, sharex=True)
        
        ax1.plot(np.array([i for i in range(len(bad_mean))]),
                 bad_mean,
                 color="red",
                 linestyle='-',
                 ms=2,
                 marker='o',
                 alpha=0.5,
                 label="Bad")
                 
        ax1.plot(np.array([i for i in range(len(good_mean))]),
                 good_mean,
                 color="b",
                 linestyle='-',
                 ms=2,
                 marker='o',
                 alpha=0.5,
                 label="Good")
        
        ax2.plot(np.array([i for i in range(len(bad_median))]),
                 bad_median,
                 color="red",
                 linestyle='-',
                 ms=2,
                 alpha=0.5,
                 marker='o',
                 label="Bad")
                 
        ax2.plot(np.array([i for i in range(len(good_median))]),
                 good_median,
                 color="b",
                 linestyle='-',
                 alpha=0.5,
                 ms=2,
                 marker='o',
                 label="Good")
        
        ax1.legend()
        ax2.legend()
        ax1.set_ylim(0, 100)
        ax2.set_ylim(0, 100)
        ax1.set_title("Mean")
        ax2.set_title("Median")
        plt.show()

# %% [markdown]
# ## Plots showing mean and median of each feature across randomly chosen 100 good and 100 bad lumisections (separately) in luminosity ranges
#
# Note: values of test set scaled with parameters from training set!

# %%
matplotlib.rcParams["figure.figsize"] = (16, 8)
plot_mean_features(X_test, true_labels)
# Out:
# Luminosity range: 0.0 - 0.05
# Dataset size: 648
# Good samples: 239
# Bad samples: 409
# AE ROC AUC: 0.842845597487
# MS ROC AUC: 0.834712688361
# Luminosity range: 0.05 - 0.1
# Dataset size: 768
# Good samples: 664
# Bad samples: 104
# AE ROC AUC: 0.904193697868
# MS ROC AUC: 0.867209221501
# Luminosity range: 0.1 - 0.15
# Dataset size: 7149
# Good samples: 7124
# Bad samples: 25
# AE ROC AUC: 0.966030320045
# MS ROC AUC: 0.961796743403
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-77b715addc53> in <module>()
#       1 matplotlib.rcParams["figure.figsize"] = (16, 8)
# ----> 2 plot_mean_features(X_test, true_labels)
#
# <ipython-input-88-051a0a3cd70c> in plot_mean_features(X, y)
#      49             print("MS ROC AUC:", ms_auc)
#      50
# ---> 51             bad_sample = X_bad.sample(SAMPLE_SIZE)
#      52             bad_mean = abs(np.mean(bad_sample, axis=0))
#      53             bad_median = abs(np.median(bad_sample, axis=0))
#
# /opt/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis)
#    4195                              "provide positive value.")
#    4196
# -> 4197         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    4198         return self.take(locs, axis=axis, is_copy=False)
#    4199
#
# mtrand.pyx in mtrand.RandomState.choice (numpy/random/mtrand/mtrand.c:18155)()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
def plot_means():
    matplotlib.rcParams["figure.figsize"] = (15, 10)

    fig, (ax1, ax2) = plt.subplots(2, sharex=True)
    ax1.bar(np.arange(0, 0.35, STEP),
           good_mean_mean,
           align='edge',
           width=0.05,
           color='b',
           alpha=0.5,
           label="Good")

    ax1.bar(np.arange(0, 0.35, STEP),
           bad_mean_mean,
           align='edge',
           width=0.05,
           color='r',
           alpha=0.5,
           label="Bad")

    ax1.set_ylabel("Mean mean")
    ax1.set_ylim((0, 5))
    ax1.set_title('Mean mean of lumisections')
    ax1.grid()
    ax1.legend()

    ax2.bar(np.arange(0, 0.35, STEP),
           good_mean_median,
           align='edge',
           width=0.05,
           color='b',
           alpha=0.5,
           label="Good")

    ax2.bar(np.arange(0, 0.35, STEP),
           bad_mean_median,
           align='edge',
           width=0.05,
           color='r',
           alpha=0.5,
           label="Bad")

    ax2.set_ylim((0, 5))
    ax2.set_ylabel("Mean median")
    ax2.set_title('Mean median of lumisections')
    ax2.grid()
    ax2.legend()
    plt.xlabel('Luminosity')
    plt.show()
    
    fig, (ax1, ax2) = plt.subplots(2, sharex=True)
    ax1.bar(np.arange(0, 0.35, STEP),
           np.asarray(good_mean_mean) - np.asarray(bad_mean_mean),
           align='edge',
           width=0.05,
           color='y',
           alpha=0.5)

    ax1.set_ylabel("Good median - bad median")
    ax1.set_ylim((-5, 5))
    ax1.set_title('Good median - bad median')
    ax1.grid()

    ax2.bar(np.arange(0, 0.35, STEP),
           np.asarray(good_mean_median) - np.asarray(bad_mean_median),
           align='edge',
           width=0.05,
           color='y',
           alpha=0.5)

    ax2.set_ylim((-5, 5))
    ax2.set_ylabel("Good median - bad median")
    ax2.set_title('Good median - bad median')
    ax2.grid()
    plt.xlabel('Luminosity')
    plt.show()

# %% [markdown]
# ## Mean of above values

# %%
plot_means()

# %%
def plot_ae_vs_ms():
    fig, ax1 = plt.subplots()
    ax1.bar(np.arange(0, 0.3, STEP),
           ae_auc_scores,
           align='edge',
           width=0.02,
           color='b',
           alpha=0.5,
           label="Autoencoder")

    ax1.bar(np.arange(0.02, 0.32, STEP),
           ms_auc_scores,
           align='edge',
           width=0.02,
           color='r',
           alpha=0.5,
           label="Mean square")

    ax1.set_ylabel("ROC AUC")
    ax1.set_ylim((0, 1))
    ax1.set_xlim((0, 0.35))
    ax1.set_title('AE vs MS')
    ax1.grid()

    plt.legend()
    plt.xlabel('Luminosity')
    plt.show()

# %% [markdown]
# ## Autoencoder vs mean square in luminosity ranges

# %%
matplotlib.rcParams["figure.figsize"] = (10, 20)
plot_ae_vs_ms()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-105-157162ec98b3> in <module>()
#       1 matplotlib.rcParams["figure.figsize"] = (10, 20)
# ----> 2 plot_ae_vs_ms()
#
# <ipython-input-104-dd94391b7292> in plot_ae_vs_ms()
#       7            color='b',
#       8            alpha=0.5,
# ----> 9            label="Autoencoder")
#      10
#      11     ax1.bar(np.arange(0.02, 0.32, STEP),
#
# /opt/anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /opt/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, left, height, width, bottom, **kwargs)
#    2077         if len(height) != nbars:
#    2078             raise ValueError("incompatible sizes: argument 'height' "
# -> 2079                               "must be length %d or scalar" % nbars)
#    2080         if len(width) != nbars:
#    2081             raise ValueError("incompatible sizes: argument 'width' "
#
# ValueError: incompatible sizes: argument 'height' must be length 6 or scalar
